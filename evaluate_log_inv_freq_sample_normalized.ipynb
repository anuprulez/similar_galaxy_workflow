# %%
import numpy as np
import json
import warnings
import operator

import h5py
from keras.models import model_from_json
from keras import backend as K

from matplotlib import pyplot as plt

warnings.filterwarnings("ignore")

size_title = 18
size_label = 14
n_pred = 2

base_path = "data/evaluate_log_inv_freq_sample_normalized/"

path_data_dict = base_path + "data_dict.txt"
path_inverted_wt = base_path + "inverted_weights.txt"
path_usage_wt = base_path + "usage_prediction.txt"
path_class_wt = base_path + "class_weights.txt"
path_test_data = base_path + "test_paths_dict.txt"
model_path = base_path + "trained_model.hdf5"

def read_file(file_path):
    with open(file_path, 'r') as data_file:
        data = json.loads(data_file.read())
    return data

class_weights = read_file(path_class_wt)
usage_weights = read_file(path_usage_wt)
inverted_weights = read_file(path_inverted_wt)
data_dict = read_file(path_data_dict)

def create_model(model_path):
    trained_model = h5py.File(model_path, 'r')
    model_config = json.loads(trained_model.get('model_config').value)
    loaded_model = model_from_json(model_config)
    dictionary = json.loads(trained_model.get('data_dictionary').value)
    compatibile_tools = json.loads(trained_model.get('compatible_tools').value)
    reverse_dictionary = dict((str(v), k) for k, v in dictionary.items())
    model_weights = list()
    weight_ctr = 0
    while True:
        try:
            d_key = "weight_" + str(weight_ctr)
            weights = trained_model.get(d_key).value
            model_weights.append(weights)
            weight_ctr += 1
        except Exception as exception:
            break
    # set the model weights
    loaded_model.set_weights(model_weights)
    return loaded_model, dictionary, reverse_dictionary, compatibile_tools

model, dictionary, reverse_dictionary, compatibile_tools = create_model(model_path)
# Out:
# Using TensorFlow backend.

# %%
reverse_dictionary
# Out:
# {'1': 'MzTabExporter',
#  '2': 'mothur_dist_seqs',
#  '3': 'tp_cat',
#  '4': 'TextExporter',
#  '5': 'bamtools',
#  '6': 'minfi_qc',
#  '7': 'get_feature_info',
#  '8': 'snpEff_download',
#  '9': 'sam_bw_filter',
#  '10': 'deeptools_bigwigCompare',
#  '11': 'hicexplorer_hicpca',
#  '12': 'tp_uniq_tool',
#  '13': 'picard_CollectRnaSeqMetrics',
#  '14': 'ctb_compound_convert',
#  '15': 'lca1',
#  '16': 'gemini_db_info',
#  '17': 'minfi_dropsnp',
#  '18': 'idpqonvert',
#  '19': 'varscan_copynumber',
#  '20': 'cardinal_spectra_plots',
#  '21': 'qiime_assign_taxonomy',
#  '22': 'hicexplorer_hicplottads',
#  '23': 'gatk2_reduce_reads',
#  '24': 'spades',
#  '25': 'bedtools_annotatebed',
#  '26': 'humann2_genefamilies_genus_level',
#  '27': 'EMBOSS: getorf42',
#  '28': 'iuc_pear',
#  '29': 'openms_id_file_converter',
#  '30': 'secretbt2test',
#  '31': 'gemini_comp_hets',
#  '32': 'query_tabular',
#  '33': 'mothur_nmds',
#  '34': 'viennarna_rnafold',
#  '35': 'picard_FilterSamReads',
#  '36': 'pileup_parser',
#  '37': 'bg_find_subsequences',
#  '38': 'mothur_summary_seqs',
#  '39': 'mothur_summary_single',
#  '40': 'qiime_pick_open_reference_otus',
#  '41': 'methtools_dmr',
#  '42': 'QCCalculator',
#  '43': 'hmmer_hmmsearch',
#  '44': 'pileup_interval',
#  '45': 'bctools_remove_spurious_events',
#  '46': 'cshl_fastx_nucleotides_distribution',
#  '47': 'bcftools_consensus',
#  '48': 'ncbi_tblastn_wrapper',
#  '49': 'flexbar_split_RYYR_bcs',
#  '50': 'goenrichment',
#  '51': 'Extract genomic DNA 1',
#  '52': 'treebest_best',
#  '53': 'predict_pipeline',
#  '54': 'Datamash',
#  '55': 'velvetoptimiser',
#  '56': 'ggplot_point',
#  '57': 'rm_spurious_events.py',
#  '58': 'cshl_fastx_collapser',
#  '59': 'idpassemble',
#  '60': 'cmv',
#  '61': 'vcftools_isec',
#  '62': 'jbrowse',
#  '63': 'merge_pcr_duplicates.py',
#  '64': 'vcfcombine',
#  '65': 'minimap2',
#  '66': 'cshl_awk_replace_in_column',
#  '67': 'mothur_count_groups',
#  '68': 'fasttree',
#  '69': 'sklearn_feature_selection',
#  '70': 'peakachu',
#  '71': 'CONVERTER_interval_to_bedstrict_0',
#  '72': 'svm_classifier',
#  '73': 'trimmomatic',
#  '74': 'qiime_split_libraries_fastq',
#  '75': 'rnbeads',
#  '76': 'sed_stream_editor',
#  '77': 'picard_CASM',
#  '78': 'cummerbund_to_cuffdiff',
#  '79': 'datamash_transpose',
#  '80': 'tsne',
#  '81': 'mlocarna',
#  '82': 'hicexplorer_hictransform',
#  '83': 'ChangeCase',
#  '84': 'gene2exon1',
#  '85': 'EMBOSS: shuffleseq87',
#  '86': 'modencode_peakcalling_spp',
#  '87': 'freebayes',
#  '88': 'numeric_clustering',
#  '89': '__MERGE_COLLECTION__',
#  '90': 'mothur_heatmap_bin',
#  '91': 'hicexplorer_hicsummatrices',
#  '92': 'rgPicFixMate',
#  '93': 'xpath',
#  '94': 'mothur_make_shared',
#  '95': 'comp1',
#  '96': 'EMBOSS: seqret84',
#  '97': 'deeptools_bamCompare',
#  '98': 'deeptools_compute_matrix_operations',
#  '99': 'addName',
#  '100': 'addValue',
#  '101': 'cuffnorm',
#  '102': 'varscan_somatic',
#  '103': 'tp_replace_in_column',
#  '104': 'CONVERTER_gff_to_interval_index_0',
#  '105': 'IDConflictResolver',
#  '106': 'humann2_renorm_table',
#  '107': 'lfq_protein_quant',
#  '108': 'tophat',
#  '109': 'hmmer_hmmbuild',
#  '110': 'bg_uniq',
#  '111': 'fastq_join',
#  '112': 'bedtools_multicovtbed',
#  '113': 'picard_ValidateSamFile',
#  '114': 'circgraph',
#  '115': 'CONVERTER_bed_to_bgzip_0',
#  '116': 'hicexplorer_hicbuildmatrix',
#  '117': 'bams2ratio',
#  '118': 'gmx_setup',
#  '119': 'bedtools_slopbed',
#  '120': 'get_sequences',
#  '121': 'fastq_quality_trimmer',
#  '122': 'cardinal_segmentations',
#  '123': 'samtools_filter',
#  '124': 'mothur_get_communitytype',
#  '125': 'FeatureLinkerUnlabeledQT',
#  '126': 'ProteinInference',
#  '127': 'vegan_rarefaction',
#  '128': '__SORTLIST__',
#  '129': 'rbc_rnacode',
#  '130': 'dt_profiler',
#  '131': 'mergeCols1',
#  '132': 'IDMerger',
#  '133': 'gatk2_variant_annotator',
#  '134': 'bed_to_bigwig',
#  '135': 'ctb_remIons',
#  '136': 'sklearn_nn_classifier',
#  '137': 'bwa_wrapper',
#  '138': 'ggplot2_point',
#  '139': 'vegan_diversity',
#  '140': 'gatk2_unified_genotyper',
#  '141': 'unicycler',
#  '142': 'bedtools_intersectbed_bam',
#  '143': 'bandage_image',
#  '144': 'datamash_ops',
#  '145': 'vcfselectsamples',
#  '146': 'raceid_inspecttrajectory',
#  '147': 'wolf_psort',
#  '148': 'blastxml_to_tabular',
#  '149': 'PicardASMetrics',
#  '150': 'mothur_venn',
#  '151': 'samtools_bedcov',
#  '152': 'gatk2_base_recalibrator',
#  '153': 'samtools_flag_filter',
#  '154': 'snpfinder',
#  '155': 'cor2',
#  '156': 'Extractor',
#  '157': 'samtools_rmdup',
#  '158': 'tp_multijoin_tool',
#  '159': 'deeptools_multi_bam_summary',
#  '160': 'ctb_silicos_qed',
#  '161': 'viz_overlay_moving_and_fixed_image',
#  '162': 'cshl_fastx_renamer',
#  '163': 'piranha',
#  '164': 'unipept',
#  '165': 'genbank_to_gff',
#  '166': 'gatk_realigner_target_creator',
#  '167': 'mothur_remove_seqs',
#  '168': 'rgPicardMarkDups',
#  '169': 'TrimByN',
#  '170': 'ggplot_histogram',
#  '171': 'flexbar_no_split',
#  '172': 'rarefaction',
#  '173': 'tabular_to_fastq',
#  '174': 'methtools_calling',
#  '175': 'vcftools_merge',
#  '176': 'gemini_load',
#  '177': 'translate_bed_sequences',
#  '178': 'fastq_paired_end_joiner',
#  '179': 'deeptools_bam_compare',
#  '180': 'tp_easyjoin_tool',
#  '181': 'picard_SortSam',
#  '182': 'cd_hit_dup',
#  '183': 'je_clip',
#  '184': 'locarna_best_subtree',
#  '185': 'deeptools_plot_pca',
#  '186': 'Show beginning1',
#  '187': 'extract_element_from_collection',
#  '188': 'igvtools_count',
#  '189': 'raceid_main',
#  '190': 'join1',
#  '191': 'bigwig_to_bedgraph',
#  '192': 'deeptools_plot_correlation',
#  '193': 'glimmer_not-knowlegde-based',
#  '194': 'gops_cluster_1',
#  '195': 'FidoAdapter',
#  '196': 'umi_tools_group',
#  '197': 'samtools_mpileup',
#  '198': 'EMBOSS: textsearch98',
#  '199': 'clustalw',
#  '200': 'kraken-filter',
#  '201': 'hgv_linkToGProfile',
#  '202': 'mimodd_varcall',
#  '203': 'gatk2_variant_recalibrator',
#  '204': 'minfi_dmr',
#  '205': 'FROGS_filters',
#  '206': 'gemini_burden',
#  '207': 'bed_to_bigBed',
#  '208': 'FileMerger',
#  '209': 'deeptools_bamFingerprint',
#  '210': 'cshl_sed_tool',
#  '211': 'cuffdiff',
#  '212': 'qiime_validate_mapping_file',
#  '213': 'sqlite_to_tabular',
#  '214': 'FalseDiscoveryRate',
#  '215': 'rsem_prepare_reference',
#  '216': 'FileConverter',
#  '217': 'cmFinder',
#  '218': 'egsea',
#  '219': 'seq_composition',
#  '220': 'Extract_features1',
#  '221': 'vcffilter2',
#  '222': 'tp_sorted_uniq',
#  '223': 'bg_sortmerna',
#  '224': 'peakcalling_macs14',
#  '225': 'bedtools_genomecoveragebed_histogram',
#  '226': 'bctools_extract_alignment_ends',
#  '227': 'mass_spectrometry_imaging_preprocessing',
#  '228': '__ZIP_COLLECTION__',
#  '229': 'minfi_read450k',
#  '230': 'DatamashTranspose',
#  '231': 'uchime',
#  '232': 'bedtools_subtractbed',
#  '233': 'gemini_actionable_mutations',
#  '234': 'proteomics_search_peptide_prophet_1',
#  '235': 'RNAlien',
#  '236': 'FeatureLinkerUnlabeled',
#  '237': 'Convert characters1',
#  '238': 'Grep1',
#  '239': 'NSPDK_candidateClust',
#  '240': 'cshl_multijoin',
#  '241': 'meme_meme',
#  '242': 'qiime_pick_rep_set',
#  '243': 'combine_metaphlan2_humann2',
#  '244': 'meme_chip',
#  '245': 'blockbuster',
#  '246': 'deeptools_multi_bigwig_summary',
#  '247': 'metaspades',
#  '248': 'PeakPickerHiRes',
#  '249': 'cardinal_preprocessing',
#  '250': 'w4mjoinpn',
#  '251': 'FROGS_remove_chimera',
#  '252': 'sickle',
#  '253': 'stacks_denovomap',
#  '254': 'ctb_ob_genProp',
#  '255': 'MAF_To_Fasta1',
#  '256': 'barchart_gnuplot',
#  '257': 'cardinal_combine',
#  '258': 'proteomics_search_tandem_1',
#  '259': 'vcffilter',
#  '260': 'abims_xcms_group',
#  '261': 'cshl_fasta_formatter',
#  '262': 'picard_ARRG',
#  '263': 'gmx_md',
#  '264': 'ConsensusMapNormalizer',
#  '265': 'CONVERTER_gz_to_uncompressed',
#  '266': 'ete_genetree_splitter',
#  '267': 'scpipe',
#  '268': 'xcms_merge',
#  '269': 'plotly_parallel_coordinates_plot',
#  '270': 'fastq_filter',
#  '271': 'tp_sed_tool',
#  '272': 'Nucleosome',
#  '273': 'flexbar_split_RR_bcs',
#  '274': 'hgv_snpFreq',
#  '275': 'edger',
#  '276': 'histogram_rpy',
#  '277': 'bcftools_norm',
#  '278': 'bedtools_intersectBed',
#  '279': 'Show tail1',
#  '280': 'snpSift_annotate',
#  '281': 'viennarna_rnaplot',
#  '282': 'velvetg_jgi',
#  '283': 'CONVERTER_fasta_to_tabular',
#  '284': 'mothur_dist_shared',
#  '285': 'EMBOSS: fuzzpro38',
#  '286': 'XTandemAdapter',
#  '287': 'sklear_numeric_clustering',
#  '288': 'heinz',
#  '289': 'samtools_flagstat',
#  '290': 'raceid_trajectory',
#  '291': 'vcf2pgSnp',
#  '292': 'rseqc_infer_experiment',
#  '293': 'raceid_filtnormconf',
#  '294': 'peptide_shaker',
#  '295': 'gops_coverage_1',
#  '296': 'graphicsmagick_image_convert',
#  '297': 'TrimByLength',
#  '298': 'vcf2tsv',
#  '299': 'gtftobed12',
#  '300': 'sailfish',
#  '301': 'cast',
#  '302': 'eden_vectorizer',
#  '303': 'bedtools_map',
#  '304': 'kraken-report',
#  '305': 'picard_NormalizeFasta',
#  '306': 'deeptools_plot_heatmap',
#  '307': 'ggplot2_heatmap2',
#  '308': 'resistome_analyzer',
#  '309': 'filter_bed_on_splice_junctions',
#  '310': 'structure_to_gspan',
#  '311': 'fastq collapser',
#  '312': 'mothur_sub_sample',
#  '313': 'mothur_cluster_split',
#  '314': 'trinity',
#  '315': 'plotly_regression_performance_plots',
#  '316': 'hicexplorer_hiccorrectmatrix',
#  '317': 'picard_CollectWgsMetrics',
#  '318': 'gemini_windower',
#  '319': 'table_annovar',
#  '320': 'maldi_quant_preprocessing',
#  '321': 'aragorn_trna',
#  '322': 'PeptideIndexer',
#  '323': 'bg_diamond',
#  '324': 'rseqc_bam_stat',
#  '325': 'collection_column_join',
#  '326': 'mimodd_varreport',
#  '327': 'tp_tac',
#  '328': 'seq_filter_by_mapping',
#  '329': 'column_order_header_sort',
#  '330': 'gops_join_1',
#  '331': 'Filter1',
#  '332': 'wc_gnu',
#  '333': 'chipsequtil_maptoknowngenes',
#  '334': 'samtools_sort',
#  '335': 'mothur_tree_shared',
#  '336': 'deeptools_bigwig_compare',
#  '337': 'samtools_slice_bam',
#  '338': 'gff_to_sequence',
#  '339': 'vcffixup',
#  '340': 'IDScoreSwitcher',
#  '341': 'gops_merge_1',
#  '342': 'silac_analyzer',
#  '343': 'rseqc_bam2wig',
#  '344': 'snpSift_geneSets',
#  '345': 'cshl_grep_tool',
#  '346': 'kraken-translate',
#  '347': 'gemini_pathways',
#  '348': 'Fetch Taxonomic Ranks',
#  '349': 'rarefaction_analyzer',
#  '350': 'mothur_amova',
#  '351': 'msconvert2_raw',
#  '352': 'ngsutils_bam_filter',
#  '353': 'ctb_remSmall',
#  '354': 'deeptools_profiler',
#  '355': 'map_peptides_to_bed',
#  '356': 'flexbar',
#  '357': 'tophat2',
#  '358': 'mothur_corr_axes',
#  '359': 'varscan',
#  '360': 'cardinal_mz_images',
#  '361': 'bg_statistical_hypothesis_testing',
#  '362': 'metaphlan_hclust_heatmap',
#  '363': 'picard_MarkDuplicates',
#  '364': 'qiime_pick_otus',
#  '365': 'IsobaricAnalyzer',
#  '366': 'FROGS_affiliations_stat',
#  '367': 'preMloc',
#  '368': 'abims_xcms_summary',
#  '369': 'valet',
#  '370': 'mass_spectrometry_imaging_filtering',
#  '371': 'sklearn_numeric_clustering',
#  '372': '__FILTER_FAILED_DATASETS__',
#  '373': 'bedtools_mergebed',
#  '374': 'mass_spectrometry_imaging_combine',
#  '375': 'goslimmer',
#  '376': 'mcClust',
#  '377': 'vt_normalize',
#  '378': 'gemini_de_novo',
#  '379': 'msconvert3_raw',
#  '380': 'convert_bc_to_binary_RY.py',
#  '381': 'rcas',
#  '382': 'samtools_stats',
#  '383': 'gmx_npt',
#  '384': 'sam2interval',
#  '385': 'metams_runGC',
#  '386': 'IDMassAccuracy',
#  '387': 'bwa',
#  '388': 'gmx_solvate',
#  '389': 'cutadapt',
#  '390': 'uparse',
#  '391': 'IDMapper',
#  '392': 'remove_tail.py',
#  '393': 'mothur_classify_rf',
#  '394': 'minfi_dmp',
#  '395': 'bamCompare_deepTools',
#  '396': '__APPLY_RULES__',
#  '397': 'heatmap2',
#  '398': 'gafa',
#  '399': 'collapse_dataset',
#  '400': 'uniprot',
#  '401': 'dbbuilder',
#  '402': 'modencode_peakcalling_macs2',
#  '403': 'cshl_fastx_trimmer',
#  '404': 'mothur_parsimony',
#  '405': 'vcftools_annotate',
#  '406': 'CONVERTER_fasta_to_fai',
#  '407': 'rseqc_geneBody_coverage',
#  '408': 'hisat',
#  '409': 'wig_to_bigWig',
#  '410': 'rbc_mirdeep2_quantifier',
#  '411': 'mothur_pcoa',
#  '412': 'stacks_procrad',
#  '413': 'CONVERTER_sam_to_unsorted_bam',
#  '414': 'rbc_mirdeep2',
#  '415': 'CONVERTER_interval_to_bgzip_0',
#  '416': 'Determine_BC',
#  '417': 'bedtools_coveragebed',
#  '418': 'meme_fimo',
#  '419': 'deeptools_bam_coverage',
#  '420': 'bamFilter',
#  '421': 'mothur_filter_seqs',
#  '422': 'stringtie_merge',
#  '423': 'vcfallelicprimitives',
#  '424': 'rnafold',
#  '425': 'SequenceCoverageCalculator',
#  '426': 'mothur_pre_cluster',
#  '427': 'w4mcorcov',
#  '428': 'pilon',
#  '429': 'annotateMyIDs',
#  '430': 'dexseq_annotate',
#  '431': 'Univariate',
#  '432': 'bedtools_coveragebed_counts',
#  '433': 'lastz_wrapper_2',
#  '434': 'cshl_fastx_quality_statistics',
#  '435': 'vcfgenotypes',
#  '436': 'Digestor',
#  '437': 'rsem_calculate_expression',
#  '438': 'mothur_remove_lineage',
#  '439': 'rbc_mafft',
#  '440': 'seq_filter_by_id',
#  '441': 'tp_find_and_replace',
#  '442': 'mothur_get_groups',
#  '443': 'cshl_easyjoin',
#  '444': 'Flash',
#  '445': 'tp_unfold_column_tool',
#  '446': 'smf_utils_fix-fasta-headers',
#  '447': 'ia_coordinates_of_roi',
#  '448': 'Multivariate',
#  '449': 'bwa_mem',
#  '450': 'FROGS_preprocess',
#  '451': 'vcf_filter',
#  '452': 'decoyfasta',
#  '453': 'prokka',
#  '454': 'goseq',
#  '455': 'mycrobiota-split-multi-otutable',
#  '456': 'prokaryotic_ncbi_submission',
#  '457': 'shovill',
#  '458': 'annotatemyids',
#  '459': 'vcfflatten2',
#  '460': 'pureclip',
#  '461': 'secure_hash_message_digest',
#  '462': 'correct_barcodes',
#  '463': 'term_id_vs_term_name',
#  '464': 'EMBOSS: fuzztran39',
#  '465': 'selectsequencesfrommsa',
#  '466': 'stacks_populations',
#  '467': 'gatk_depth_of_coverage',
#  '468': 'melt',
#  '469': 'mothur_heatmap_sim',
#  '470': 'get_read_pipeline',
#  '471': 'CONVERTER_bedgraph_to_bigwig',
#  '472': 'regex_replace',
#  '473': 'vcfbedintersect',
#  '474': 'graphclust_aggregate_alignments',
#  '475': 'ncbi_makeblastdb',
#  '476': 'gtf_filter_by_attribute_values_list',
#  '477': 'iReport',
#  '478': 'featurecounts',
#  '479': 'FROGS_affiliation_OTU',
#  '480': 'p_clip_peaks',
#  '481': 'fastq_paired_end_interlacer',
#  '482': 'cat1',
#  '483': 'transpose',
#  '484': 'infernal_cmsearch',
#  '485': 'deeptools_correctGCBias',
#  '486': 'heatmapper_deepTools',
#  '487': 'abims_xcms_xcmsSet',
#  '488': 'sklearn_ensemble',
#  '489': 'MapAlignerPoseClustering',
#  '490': 'meme_psp_gen',
#  '491': 'bundle_collection',
#  '492': 'peakcalling_macs',
#  '493': 'EMBOSS: water107',
#  '494': 'gemini_interactions',
#  '495': 'mothur_seq_error',
#  '496': 'gatk2_realigner_target_creator',
#  '497': 't2t_report',
#  '498': 'pynast',
#  '499': 'minfi_methcpg',
#  '500': 'trimmer',
#  '501': 'CONVERTER_fastqgz_to_fastq',
#  '502': 'blast_parser',
#  '503': 'cuffquant',
#  '504': 'velveth_jgi',
#  '505': 'kallisto_quant',
#  '506': 'flexbardsc',
#  '507': 'createInterval',
#  '508': 'minfi_mset',
#  '509': 'graphlan_annotate',
#  '510': 'fasplit',
#  '511': 'deeptools_heatmapper',
#  '512': 'graphclust_glob_report_no_align',
#  '513': 'qiime_count_seqs',
#  '514': 'Grouping1',
#  '515': 'je_markdupes',
#  '516': 'charts',
#  '517': 'make_families',
#  '518': 'gops_subtract_1',
#  '519': 'ctb_change_title',
#  '520': 'proteomics_search_protein_prophet_1',
#  '521': 'naive_variant_caller',
#  '522': 'bedtools_genomecoveragebed_bedgraph',
#  '523': 'picard_BamIndexStats',
#  '524': 'bismark_bowtie',
#  '525': 'porechop',
#  '526': 'get_subontology_from',
#  '527': 'graphlan',
#  '528': 'fragmenter',
#  '529': 'EMBOSS: geecee41',
#  '530': 'fastq_to_fasta_python',
#  '531': 'fastq_groomer',
#  '532': 'FeatureFinderCentroided',
#  '533': 'FeatureFinderMultiplex',
#  '534': 't_coffee',
#  '535': 'MassCalculator',
#  '536': 'minfi_getM',
#  '537': 'cshl_fastq_to_fasta',
#  '538': 'fasta_filter_by_length',
#  '539': 'nspdk_sparse',
#  '540': 'infernal_cmstat',
#  '541': 'mimodd_vcf_filter',
#  '542': 'tp_split_on_column',
#  '543': 'term_id_vs_term_def',
#  '544': 'macs2_bdgcmp',
#  '545': 'ncbi_blastx_wrapper',
#  '546': 'cshl_cut_tool',
#  '547': 'EMBOSS: tranalign100',
#  '548': 'Cut1',
#  '549': 'replace_column_with_key_value_file',
#  '550': 'metilene',
#  '551': 'macs2_predictd',
#  '552': 'cshl_fastq_quality_boxplot',
#  '553': 'tp_head_tool',
#  '554': 'gtf2bedgraph',
#  '555': 'snpsift_vartype',
#  '556': 'tp_text_file_with_recurring_lines',
#  '557': 'gemini_query',
#  '558': 'get_flanks1',
#  '559': 'bismark_bowtie2',
#  '560': 'mothur_classify_otu',
#  '561': 'mothur_rarefaction_single',
#  '562': 'filtlong',
#  '563': 'picard_ReorderSam',
#  '564': 'sort1',
#  '565': 'tp_cut_tool',
#  '566': 'cardinal_quality_report',
#  '567': 'heinz_bum',
#  '568': 'gops_concat_1',
#  '569': 'dexseq_count',
#  '570': 're_he_maldi_image_registration',
#  '571': 'deeptools_bamCorrelate',
#  '572': 'samtools_calmd',
#  '573': 'FileInfo',
#  '574': 'length_and_gc_content',
#  '575': 'meme_dreme',
#  '576': 'samtools_split',
#  '577': 'deeptools_plot_enrichment',
#  '578': 'flanking_features_1',
#  '579': 'gemini_annotate',
#  '580': 'heatmapper',
#  '581': 'bedtools_sortbed',
#  '582': 'ProteinResolver',
#  '583': 'CONVERTER_gff_to_bed_0',
#  '584': 'bedtools_shufflebed',
#  '585': 'checkFormat',
#  '586': 'deeptools_computeGCBias',
#  '587': 'mass_spectrometry_imaging_mzplots',
#  '588': 'cuffcompare',
#  '589': 'GeneModelMapper',
#  '590': 'dunovo',
#  '591': 'picard_AddOrReplaceReadGroups',
#  '592': 'metaphlan2',
#  '593': 'mass_spectrometry_imaging_classification',
#  '594': 'segemehl',
#  '595': 'bedtools_windowbed',
#  '596': 'ProteinQuantifier',
#  '597': 'fastq_paired_end_splitter',
#  '598': 'Psortb',
#  '599': 'mothur_remove_groups',
#  '600': 'blastxml_to_top_descr',
#  '601': 'sam_merge2',
#  '602': 'msgfplus',
#  '603': 'deeptools_compute_gc_bias',
#  '604': 'openms_protein_quantifier',
#  '605': 'mothur_taxonomy_to_krona',
#  '606': 'r_correlation_matrix',
#  '607': 'EMBOSS: newseq59',
#  '608': 'megablast_wrapper',
#  '609': 'gmx_nvt',
#  '610': 'gatk2_variant_apply_recalibration',
#  '611': 'bedtools_genomecoveragebed',
#  '612': 'deeptools_bamCoverage',
#  '613': 'IDFilter',
#  '614': 'cshl_fastx_artifacts_filter',
#  '615': 'rgweblogo3',
#  '616': 'cshl_princeton_fastx_barcode_splitter',
#  '617': 'cufflinks',
#  '618': 'bedtools_bamtofastq',
#  '619': 'hisat2',
#  '620': 'deeptools_correct_gc_bias',
#  '621': 'rseqc_junction_saturation',
#  '622': 'ete_homology_classifier',
#  '623': 'stacks_genotypes',
#  '624': 'gspan',
#  '625': '__FLATTEN__',
#  '626': 'deeptools_compute_matrix',
#  '627': 'tmhmm2',
#  '628': 'PicardInsertSize',
#  '629': 'trim_galore',
#  '630': 'hicexplorer_hicfindtads',
#  '631': 'search_gui',
#  '632': 'rseqc_read_distribution',
#  '633': 'gff2bed1',
#  '634': 'group_humann2_uniref_abundances_to_go',
#  '635': 'ConsensusID',
#  '636': 'cuffmerge',
#  '637': 'fastq_paired_end_deinterlacer',
#  '638': 'megablast_xml_parser',
#  '639': 'thermo_raw_file_converter',
#  '640': 'nn_classifier',
#  '641': 'EMBOSS: revseq82',
#  '642': 'tp_awk_tool',
#  '643': 'blockclust',
#  '644': 'mycrobiota-make-multi-otutable',
#  '645': 'fasta2tab',
#  '646': 'gatk2_print_reads',
#  '647': 'hicexplorer_hicmergematrixbins',
#  '648': 'column_remove_by_header',
#  '649': 'mycrobiota-correct-replicates',
#  '650': 'picard_MarkDuplicatesWithMateCigar',
#  '651': 'ncbi_blastn_wrapper',
#  '652': 'picard_MergeSamFiles',
#  '653': 'extract_aln_ends.py',
#  '654': 'cshl_word_list_grep',
#  '655': 'gops_intersect_1',
#  '656': 'minfi_maptogenome',
#  '657': 'minfi_getanno',
#  '658': 'bcftools_view',
#  '659': 'rbc_mirdeep2_mapper',
#  '660': 'mothur_cluster',
#  '661': 'deeptools_plot_coverage',
#  '662': 'salmon',
#  '663': 'smf_utils_estimate-energy',
#  '664': 'MapStatistics',
#  '665': 'FastTree',
#  '666': 'abims_CAMERA_annotateDiffreport',
#  '667': 'fastq_to_tabular',
#  '668': 'rseqc_inner_distance',
#  '669': 'mycrobiota-otutable_add_blast',
#  '670': 'umi_tools_extract',
#  '671': 'mothur_chimera_vsearch',
#  '672': 'fastq_dump',
#  '673': 'align_families',
#  '674': 'velvet',
#  '675': 'quast',
#  '676': 'sklearn_searchcv',
#  '677': 'mothur_homova',
#  '678': 'deeptools_plot_fingerprint',
#  '679': 'cardinal_filtering',
#  '680': 'mimodd_map',
#  '681': 'ucsc-twobittofa',
#  '682': 'heinz_visualization',
#  '683': 'gff_filter_by_attribute',
#  '684': 'ggplot2_heatmap',
#  '685': 'nonpareil',
#  '686': 'cshl_fastx_clipper',
#  '687': 'varscan_mpileup',
#  '688': 'Remove_ending',
#  '689': 'mimodd_varextract',
#  '690': 'Interval_Maf_Merged_Fasta2',
#  '691': 'tag_stat2',
#  '692': 'snpeff_to_peptides',
#  '693': 'deg_annotate',
#  '694': 'fraggenescan',
#  '695': 'flye',
#  '696': 'DecoyDatabase',
#  '697': 'Summary_Statistics1',
#  '698': 'hcluster_sg',
#  '699': 'mothur_make_contigs',
#  '700': 'DatamashOps',
#  '701': 'EMBOSS: wordcount109',
#  '702': 'disco',
#  '703': 'bedtools_bamtobed',
#  '704': 'FROGS_clustering',
#  '705': 'bam_to_bigwig',
#  '706': 'samtool_filter2',
#  '707': 'kraken',
#  '708': 'cardinal_data_exporter',
#  '709': 'infernal_cmbuild',
#  '710': 'glimmer_build-icm',
#  '711': 'CONVERTER_interval_to_bed_0',
#  '712': 'picard_FixMateInformation',
#  '713': 'idpquery',
#  '714': 'cshl_fastx_reverse_complement',
#  '715': 'hcluster_sg_parser',
#  '716': 'stringtie',
#  '717': 'umi_tools_whitelist',
#  '718': 'gffread',
#  '719': 'ncbi_blastp_wrapper',
#  '720': 'abricate',
#  '721': 'cshl_uniq_tool',
#  '722': 'transdecoder',
#  '723': 'find_in_reference',
#  '724': 'random_lines1',
#  '725': 'IDPosteriorErrorProbability',
#  '726': 'Batch_correction',
#  '727': 'ExtractFASTAfromFASTQ',
#  '728': '16Saligner',
#  '729': 'tp_replace_in_line',
#  '730': 'scale_image',
#  '731': 'qiime_make_otu_heatmap',
#  '732': 'fastqc',
#  '733': 'deseq2',
#  '734': 'bam_to_sam',
#  '735': 'bedtools_intersectbed',
#  '736': 'rseqc_read_duplication',
#  '737': 'abims_xcms_fillPeaks',
#  '738': 'snippy_core',
#  '739': 'mothur_align_seqs',
#  '740': 'cshl_fasta_nucleotides_changer',
#  '741': 'HighResPrecursorMassCorrector',
#  '742': 'bg_protein_properties',
#  '743': 'pieplots_macs',
#  '744': 'qiime_pick_closed_reference_otus',
#  '745': 'mycrobiota-krona-mothur',
#  '746': 'IDFileConverter',
#  '747': 'signalp3',
#  '748': 'bedtools_multiintersectbed',
#  '749': 'fastq_manipulation',
#  '750': 'Btrim64',
#  '751': '__RELABEL_FROM_FILE__',
#  '752': 'Paste1',
#  '753': 'FileFilter',
#  '754': 'mothur_make_biom',
#  '755': 'humann2',
#  '756': 'FeatureLinkerUnlabeledKD',
#  '757': 'tab2fasta',
#  '758': 'computeMatrix',
#  '759': 'bwameth',
#  '760': 'fasta_merge_files_and_filter_unique_sequences',
#  '761': 'cshl_sort_header',
#  '762': 'methtools_filter',
#  '763': 'mothur_lefse',
#  '764': 'metaphlan2krona',
#  '765': 'mycrobiota-qc-report',
#  '766': 'megahit',
#  '767': 'rna_star',
#  '768': 'ctb_simsearch',
#  '769': 'umi_tools_dedup',
#  '770': 'minfi_rset',
#  '771': 'gmx_em',
#  '772': 'qiime_make_phylogeny',
#  '773': 'mothur_merge_files',
#  '774': 'regex1',
#  '775': 'bamleftalign',
#  '776': '16Sclassifier',
#  '777': 'mothur_trim_seqs',
#  '778': 'Remove beginning1',
#  '779': 'CONVERTER_bed_gff_or_vcf_to_bigwig_0',
#  '780': 'tophat_fusion_post',
#  '781': 'Heatmap',
#  '782': 'picard_SamToFastq',
#  '783': 'snippy',
#  '784': 'deeptools_computeMatrix',
#  '785': 'idr-embl',
#  '786': 'bcftools_call',
#  '787': 'gd_raxml',
#  '788': 'sklearn_build_pipeline',
#  '789': 'Count1',
#  '790': 'fastq_combiner',
#  '791': 'gffcompare',
#  '792': 'preproc',
#  '793': 'gatk_indel_realigner',
#  '794': 'deeptools_plot_profile',
#  '795': 'umi_tools_count',
#  '796': 'fastq_trimmer',
#  '797': 'stacks_refmap',
#  '798': 'subtract_query1',
#  '799': 'mass_spectrometry_imaging_segmentations',
#  '800': 'qiime_align_seqs',
#  '801': 'bedtools_unionbedgraph',
#  '802': 'rbc_splitfasta',
#  '803': 'raceid_inspectclusters',
#  '804': 'ChooseTag',
#  '805': 'maldi_quant_peak_detection',
#  '806': 'ncbi_rpsblast_wrapper',
#  '807': 'bedtools_getfastabed',
#  '808': 'eukaryotic_ncbi_submission',
#  '809': 'taxonomy_krona_chart',
#  '810': 'ctb_online_data_fetch',
#  '811': 'augustus',
#  '812': 'NFS_transfer',
#  '813': 'gatk2_variant_filtration',
#  '814': 'trim_reads',
#  '815': 'MapRTTransformer',
#  '816': 'multiqc',
#  '817': 'gatk2_depth_of_coverage',
#  '818': 'je_demultiplex',
#  '819': 'mothur_classify_seqs',
#  '820': 'bedtools_bedtobam',
#  '821': 'glob_report',
#  '822': 'racon',
#  '823': 'limma_voom',
#  '824': 'deseq2_single',
#  '825': 'mothur_get_oturep',
#  '826': 'bctools_remove_tail',
#  '827': 'nanoplot',
#  '828': 'sample_seqs',
#  '829': 'biosigner',
#  '830': 'react_cal_pipeline',
#  '831': 'Draw_phylogram',
#  '832': 'cshl_fastx_barcode_splitter',
#  '833': 'CONVERTER_bed_to_gff_0',
#  '834': 'EMBOSS: transeq101',
#  '835': 'ctb_filter',
#  '836': 'proteomics_moff',
#  '837': 'filter_by_fasta_ids',
#  '838': 'graphclust_align_cluster',
#  '839': 'mass_spectrometry_imaging_qc',
#  '840': 'eden_sequence_converter',
#  '841': 'mothur_make_group',
#  '842': 'vsearch_dereplication',
#  '843': 'XY_Plot_1',
#  '844': 'smf_utils_filter-by-energy',
#  '845': 'smf_utils_extract-boxed-sequences',
#  '846': 'mothur_get_seqs',
#  '847': 'mothur_count_seqs',
#  '848': 'gatk2_haplotype_caller',
#  '849': 'tp_tail_tool',
#  '850': 'w4mclstrpeakpics',
#  '851': '__FILTER_FROM_FILE__',
#  '852': 'bam2wig',
#  '853': '__UNZIP_COLLECTION__',
#  '854': 'picard_EstimateLibraryComplexity',
#  '855': 'cshl_awk_tool',
#  '856': 'export2graphlan',
#  '857': 'vcfsort',
#  '858': 'wiggle2simple1',
#  '859': 'macs2_callpeak',
#  '860': 'heinz_scoring',
#  '861': 'samtools_idxstats',
#  '862': 'mothur_unique_seqs',
#  '863': 'join_files_on_column_fuzzy',
#  '864': 'fgsea',
#  '865': 'tp_sort_header_tool',
#  '866': 'cummeRbund',
#  '867': 'bg_column_arrange_by_header',
#  '868': 'tp_grep_tool',
#  '869': 'snpEff',
#  '870': 'gatk2_indel_realigner',
#  '871': 'bam-filter',
#  '872': 'interproscan',
#  '873': 'roary',
#  '874': 'EMBOSS: extractseq35',
#  '875': 'sequence_content_trimmer',
#  '876': 'bowtie_wrapper',
#  '877': 'allele_counts_1',
#  '878': 'enhanced_bowtie_wrapper',
#  '879': 'ctb_chemfp_mol2fps',
#  '880': 'vcfannotate',
#  '881': 'Extract_RNA_seq_Evidence',
#  '882': 'FeatureFinderMetabo',
#  '883': 'picard_CollectInsertSizeMetrics',
#  '884': 'viennarna_rnaalifold',
#  '885': 'mothur_chimera_uchime',
#  '886': 'vcfvcfintersect',
#  '887': 'cshl_fastq_quality_filter',
#  '888': 'bgchem_fragment_merger',
#  '889': 'ggplot2_histogram',
#  '890': 'gops_basecoverage_1',
#  '891': 'msconvert_nix',
#  '892': 'blastxml_to_tabular_selectable',
#  '893': 'humann2_regroup_table',
#  '894': 'scaffold2fasta',
#  '895': 'smf_utils_find-boxes',
#  '896': 'gatk_unified_genotyper',
#  '897': 'rmcontamination',
#  '898': 'newick_display',
#  '899': 'mothur_screen_seqs',
#  '900': 'get_child_terms',
#  '901': 'gemini_recessive_and_dominant',
#  '902': 'cshl_find_and_replace',
#  '903': 'blast2go',
#  '904': 'methtools_plot',
#  '905': 'snpSift_filter',
#  '906': 'sklearn_svm_classifier',
#  '907': 'hgv_david',
#  '908': 'tp_sort_rows',
#  '909': 'mz_to_sqlite',
#  '910': 'smooth_running_window',
#  '911': 'MultiplexResolver',
#  '912': 'raceid_clustering',
#  '913': 'minfi_ppfun',
#  '914': 'cufflinks_prok',
#  '915': 'bed2gff1',
#  '916': 'bctools_extract_crosslinked_nucleotides',
#  '917': 'MSGFPlusAdapter',
#  '918': 'w4mclassfilter',
#  '919': 'ip_projective_transformation_points',
#  '920': 'mass_spectrometry_imaging_ion_images',
#  '921': 'dexseq',
#  '922': 'krona-text',
#  '923': 'sam_to_bam',
#  '924': 'plotly_ml_performance_plots',
#  '925': 'format_metaphlan2_output',
#  '926': 'muscle',
#  '927': 'mothur_phylotype',
#  '928': 'fasta-stats',
#  '929': 'pileometh',
#  '930': 'fasta_compute_length',
#  '931': 'seurat',
#  '932': 'openms_id_mapper',
#  '933': 'gatk2_variant_select',
#  '934': 'extract_bcs.py',
#  '935': 'diffbind-embl',
#  '936': 'bowtie2',
#  '937': 'venn_list',
#  '938': 'glimmer_knowlegde-based',
#  '939': 'nanopolish_variants',
#  '940': 'sam_pileup',
#  '941': 'antismash',
#  '942': 'htseq_count',
#  '943': 'minfi_getbeta',
#  '944': 'gbk_to_orf',
#  '945': 'Add_a_column1',
#  '946': 'coords2clnt.py',
#  '947': 'hicexplorer_hicplotmatrix',
#  '948': 'TrimPrimer',
#  '949': 'snpSift_dbnsfp_generic',
#  '950': 'correctGCBias',
#  '951': 'qiime_core_diversity',
#  '952': 'ruvseq',
#  '953': 'mothur_metastats',
#  '954': 'bamCoverage_deepTools',
#  '955': 'picard_CleanSam',
#  '956': 'GeMoMa_Annotation_Filter',
#  '957': 'wsdl_hmdb',
#  '958': 'locarna_multiple',
#  '959': 'myrimatch',
#  '960': 'paralyzer',
#  '961': 'ssake',
#  '962': 'CONVERTER_Bam_Bai_0',
#  '963': 'aggregate_scores_in_intervals2',
#  '964': 'bedtools_complementbed',
#  '965': 'chipseeker',
#  '966': 'rnaz',
#  '967': 'htseq-count',
#  '968': 'CometAdapter',
#  '969': 'ip_projective_transformation',
#  '970': 'methtools_tiling',
#  '971': 'methtools_destrand'}

# %%
def verify_model(model, tool_sequence, labels, dictionary, reverse_dictionary, compatible_tools, topk=20, max_seq_len=25):
    tl_seq = tool_sequence.split(",")
    last_tool_name = reverse_dictionary[str(tl_seq[-1])]
    last_compatible_tools = compatible_tools[last_tool_name]
    sample = np.zeros(max_seq_len)
    for idx, tool_id in enumerate(tl_seq):
        sample[idx] = int(tool_id)
    sample_reshaped = np.reshape(sample, (1, max_seq_len))
    
    tool_sequence_names = [reverse_dictionary[str(tool_pos)] for tool_pos in tool_sequence.split(",")]
    print("Tool seq: %s" % ",".join(tool_sequence_names))
    # predict next tools for a test path
    prediction = model.predict(sample_reshaped, verbose=0)
    prediction = np.reshape(prediction, (prediction.shape[1],))
    prediction_pos = np.argsort(prediction, axis=-1)

    # get topk prediction
    topk_prediction_pos = prediction_pos[-topk:]
    topk_prediction_val = [np.round(prediction[pos] * 100, 2) for pos in topk_prediction_pos]

    # read tool names using reverse dictionary
    pred_tool_ids = [reverse_dictionary[str(tool_pos)] for tool_pos in topk_prediction_pos]
    actual_next_tool_ids = list(set(pred_tool_ids).intersection(set(last_compatible_tools.split(","))))      
        
    #print("Predicted tools: %s" % ",".join(pred_tool_ids))
    print()
    pred_tool_ids_sorted = dict()
    for (tool_pos, tool_pred_val) in zip(topk_prediction_pos, topk_prediction_val):
        tool_name = reverse_dictionary[str(tool_pos)]
        if tool_name in actual_next_tool_ids:
            pred_tool_ids_sorted[tool_name] = tool_pred_val
    pred_tool_ids_sorted = dict(sorted(pred_tool_ids_sorted.items(), key=lambda kv: kv[1], reverse=True))
    
    cls_wt = dict()
    usg_wt = dict()
    inv_wt = dict()
    ids_tools = dict()
    keys = list(pred_tool_ids_sorted.keys())
    for k in keys:
        try:
            cls_wt[k] = np.round(class_weights[str(data_dict[k])], 2)
            usg_wt[k] = np.round(usage_weights[k], 2)
            inv_wt[k] = np.round(inverted_weights[str(data_dict[k])], 2)
        except:
            continue
    print("Predicted tools: \n")
    print(pred_tool_ids_sorted)
    print()
    print("Class weights: \n")
    cls_wt = dict(sorted(cls_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(cls_wt)
    print()
    print("Usage weights: \n")
    usg_wt = dict(sorted(usg_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(usg_wt)
    print()
    total_usage_wt = np.sum(list(usg_wt.values()))
    print("Sum usage wt: %0.4f" % (total_usage_wt))
    print()
    print("Inverted weights: \n")
    inv_wt = dict(sorted(inv_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(inv_wt)
    for key in pred_tool_ids_sorted:
        ids_tools[key] = dictionary[key]
    print()
    print("Tool ids")
    print(ids_tools)
    print("======================================")
    return cls_wt, usg_wt, inv_wt, pred_tool_ids_sorted

topk = 10
tool_seq = "449,116"
class_wt, usage_wt, inverse_wt, pred_tools = verify_model(model, tool_seq, "", dictionary, reverse_dictionary, compatibile_tools, topk)
# Out:
# Tool seq: bwa_mem,hicexplorer_hicbuildmatrix
#
# Predicted tools:
#
# {}
#
# Class weights:
#
# {}
#
# Usage weights:
#
# {}
#
# Sum usage wt: 0.0000
#
# Inverted weights:
#
# {}
#
# Tool ids
# {}
# ======================================

# %%
list_cls_wt = list()
list_usage_wt = list()
list_pred_wt = list()
list_inv_wt = list()
division_pt = int(len(pred_tools) / 2)

for tool in pred_tools:
    list_pred_wt.append(pred_tools[tool])
    #try:
    list_inv_wt.append(inverse_wt[tool])
    list_usage_wt.append(usage_wt[tool])
    #except:
    #list_inv_wt.append(1)

def plot_scatter(y_val, title, xlabel, ylabel):
    x_val = range(1, len(y_val) + 1)
    plt.figure(figsize=(8, 8))
    plt.plot(x_val[:division_pt], y_val[:division_pt], 'ro')
    plt.plot(x_val[division_pt:], y_val[division_pt:], 'b^')
    plt.xlabel(xlabel, size=size_label)
    plt.ylabel(ylabel, size=size_label)
    plt.legend([("First top-%s" % str(division_pt)), ("Next top-%s" % str(division_pt))])
    plt.title(title, size=size_title)
    plt.grid(True)
    plt.show()

plot_scatter(list_usage_wt, "Usage weights for tools", "Number of tools", "Class weights")
#plot_scatter(ave_prediction_weights, ave_usage_weights, "Prediction vs usage weights", "Prediction scores", "Usage weights")
#plot_scatter(ave_prediction_weights, ave_inverted_weights, "Prediction vs inverted weights", "Prediction scores", "Inverted weights")
