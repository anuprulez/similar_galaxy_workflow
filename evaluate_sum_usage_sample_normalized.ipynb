# %%
import numpy as np
import json
import warnings
import operator

import h5py
from keras.models import model_from_json
from keras import backend as K

from matplotlib import pyplot as plt

warnings.filterwarnings("ignore")

size_title = 18
size_label = 14
n_pred = 2

base_path = "data/evaluate_sum_usage_sample_normalized/"

path_data_dict = base_path + "data_dict.txt"
path_inverted_wt = base_path + "inverted_weights.txt"
path_usage_wt = base_path + "usage_prediction.txt"
path_class_wt = base_path + "class_weights.txt"
path_test_data = base_path + "test_paths_dict.txt"
model_path = base_path + "trained_model.hdf5"

def read_file(file_path):
    with open(file_path, 'r') as data_file:
        data = json.loads(data_file.read())
    return data

class_weights = read_file(path_class_wt)
usage_weights = read_file(path_usage_wt)
inverted_weights = read_file(path_inverted_wt)
data_dict = read_file(path_data_dict)

def create_model(model_path):
    trained_model = h5py.File(model_path, 'r')
    model_config = json.loads(trained_model.get('model_config').value)
    loaded_model = model_from_json(model_config)
    dictionary = json.loads(trained_model.get('data_dictionary').value)
    compatibile_tools = json.loads(trained_model.get('compatible_tools').value)
    reverse_dictionary = dict((str(v), k) for k, v in dictionary.items())
    model_weights = list()
    weight_ctr = 0
    while True:
        try:
            d_key = "weight_" + str(weight_ctr)
            weights = trained_model.get(d_key).value
            model_weights.append(weights)
            weight_ctr += 1
        except Exception as exception:
            break
    # set the model weights
    loaded_model.set_weights(model_weights)
    return loaded_model, dictionary, reverse_dictionary, compatibile_tools

model, dictionary, reverse_dictionary, compatibile_tools = create_model(model_path)
# Out:
# Using TensorFlow backend.

# %%
reverse_dictionary
# Out:
# {'1': 'vcfcombine',
#  '2': 'histogram_rpy',
#  '3': 'blastxml_to_tabular',
#  '4': 'cshl_multijoin',
#  '5': 'dunovo',
#  '6': 'rnbeads',
#  '7': 'graphclust_aggregate_alignments',
#  '8': 'rseqc_bam2wig',
#  '9': 'tp_sorted_uniq',
#  '10': 'mothur_tree_shared',
#  '11': 'minfi_dmr',
#  '12': 'maldi_quant_preprocessing',
#  '13': 'ncbi_blastn_wrapper',
#  '14': 'sklearn_numeric_clustering',
#  '15': 'secure_hash_message_digest',
#  '16': 'mothur_classify_seqs',
#  '17': 'deeptools_heatmapper',
#  '18': 'PicardInsertSize',
#  '19': 'Determine_BC',
#  '20': 'goslimmer',
#  '21': 'mass_spectrometry_imaging_ion_images',
#  '22': 'transpose',
#  '23': 'smf_utils_find-boxes',
#  '24': 'cshl_fasta_nucleotides_changer',
#  '25': 'nanopolish_variants',
#  '26': 'collapse_dataset',
#  '27': 'blockbuster',
#  '28': 'muscle',
#  '29': 'bedtools_subtractbed',
#  '30': 'barchart_gnuplot',
#  '31': 'msconvert3_raw',
#  '32': 'salmon',
#  '33': 'tp_replace_in_column',
#  '34': 'genbank_to_gff',
#  '35': 'vcffilter',
#  '36': 'mothur_align_seqs',
#  '37': 'deg_annotate',
#  '38': 'fgsea',
#  '39': 'bismark_bowtie',
#  '40': 'bundle_collection',
#  '41': 'vcfbedintersect',
#  '42': 'nonpareil',
#  '43': 'createInterval',
#  '44': 'Cut1',
#  '45': 'sklearn_ensemble',
#  '46': 'umi_tools_whitelist',
#  '47': 'annotatemyids',
#  '48': 'velveth_jgi',
#  '49': 'r_correlation_matrix',
#  '50': 'RNAlien',
#  '51': 'cardinal_preprocessing',
#  '52': 'sickle',
#  '53': 'dexseq_count',
#  '54': 'bamtools',
#  '55': 'bed_to_bigBed',
#  '56': 'fasta2tab',
#  '57': 'bwa',
#  '58': 'gemini_query',
#  '59': 'tp_find_and_replace',
#  '60': 'pilon',
#  '61': 'treebest_best',
#  '62': 'mothur_venn',
#  '63': 'idpqonvert',
#  '64': 'mycrobiota-correct-replicates',
#  '65': 'vcftools_isec',
#  '66': 'picard_CollectRnaSeqMetrics',
#  '67': 'raceid_inspecttrajectory',
#  '68': 'vcf_filter',
#  '69': 'dbbuilder',
#  '70': 'cshl_cut_tool',
#  '71': 'charts',
#  '72': 'lfq_protein_quant',
#  '73': 'metaphlan2krona',
#  '74': 'FeatureLinkerUnlabeledKD',
#  '75': 'IDMerger',
#  '76': 'checkFormat',
#  '77': 'peakcalling_macs14',
#  '78': 'minfi_read450k',
#  '79': 'hicexplorer_hicpca',
#  '80': 'extract_element_from_collection',
#  '81': 'addName',
#  '82': 'sqlite_to_tabular',
#  '83': 'computeMatrix',
#  '84': 'mothur_remove_groups',
#  '85': 'flye',
#  '86': '__UNZIP_COLLECTION__',
#  '87': 'mothur_remove_seqs',
#  '88': 'dexseq_annotate',
#  '89': 'IDFilter',
#  '90': 'cufflinks',
#  '91': 'ngsutils_bam_filter',
#  '92': 'ConsensusMapNormalizer',
#  '93': 'plotly_parallel_coordinates_plot',
#  '94': 'EMBOSS: getorf42',
#  '95': 'rsem_prepare_reference',
#  '96': 'picard_EstimateLibraryComplexity',
#  '97': 'gemini_load',
#  '98': 'ProteinQuantifier',
#  '99': 'bg_column_arrange_by_header',
#  '100': 'cuffmerge',
#  '101': 'cmv',
#  '102': 'goseq',
#  '103': '16Sclassifier',
#  '104': 'bandage_image',
#  '105': 'htseq-count',
#  '106': 'seq_filter_by_id',
#  '107': 'goenrichment',
#  '108': 'mothur_chimera_vsearch',
#  '109': 'hicexplorer_hicsummatrices',
#  '110': 'cuffcompare',
#  '111': 'fasta-stats',
#  '112': 'graphicsmagick_image_convert',
#  '113': 'picard_AddOrReplaceReadGroups',
#  '114': 'rarefaction_analyzer',
#  '115': 'varscan_mpileup',
#  '116': 'cshl_princeton_fastx_barcode_splitter',
#  '117': 'tophat',
#  '118': 'rsem_calculate_expression',
#  '119': 'ruvseq',
#  '120': 'msgfplus',
#  '121': 'deeptools_plot_fingerprint',
#  '122': 'picard_SortSam',
#  '123': 'deeptools_correct_gc_bias',
#  '124': 'FROGS_affiliations_stat',
#  '125': 'gmx_solvate',
#  '126': 'trim_reads',
#  '127': 'deeptools_bamCompare',
#  '128': 'annotateMyIDs',
#  '129': 'Convert characters1',
#  '130': 'cshl_fastq_to_fasta',
#  '131': 'pileup_parser',
#  '132': 'bedtools_multicovtbed',
#  '133': 'tp_unfold_column_tool',
#  '134': 'mothur_cluster_split',
#  '135': 'bedtools_sortbed',
#  '136': 'bctools_extract_alignment_ends',
#  '137': 'quast',
#  '138': 'je_demultiplex',
#  '139': 'ip_projective_transformation',
#  '140': 'mothur_dist_seqs',
#  '141': 'MultiplexResolver',
#  '142': 'tp_tac',
#  '143': 'stringtie_merge',
#  '144': 'picard_NormalizeFasta',
#  '145': 'mothur_pre_cluster',
#  '146': 'FastTree',
#  '147': 'sed_stream_editor',
#  '148': 'samtools_slice_bam',
#  '149': 'Univariate',
#  '150': 'kraken-report',
#  '151': 'decoyfasta',
#  '152': 'raceid_inspectclusters',
#  '153': 'cshl_grep_tool',
#  '154': 'xcms_merge',
#  '155': 'racon',
#  '156': 'rgPicardMarkDups',
#  '157': 'hgv_snpFreq',
#  '158': 'ctb_online_data_fetch',
#  '159': 'uchime',
#  '160': 'snpEff_download',
#  '161': 'tp_split_on_column',
#  '162': 'minfi_dmp',
#  '163': 'aragorn_trna',
#  '164': 'mothur_cluster',
#  '165': 'mothur_rarefaction_single',
#  '166': 'rarefaction',
#  '167': 'prokka',
#  '168': 'cast',
#  '169': 'blast_parser',
#  '170': 'cshl_fastx_artifacts_filter',
#  '171': 'limma_voom',
#  '172': 'blastxml_to_top_descr',
#  '173': 'minfi_getanno',
#  '174': 'tp_cat',
#  '175': 'preproc',
#  '176': 'FeatureFinderCentroided',
#  '177': 'tmhmm2',
#  '178': 'cufflinks_prok',
#  '179': 'mlocarna',
#  '180': 'piranha',
#  '181': 'bg_statistical_hypothesis_testing',
#  '182': 'format_metaphlan2_output',
#  '183': 'ncbi_rpsblast_wrapper',
#  '184': 'flexbar',
#  '185': 'MzTabExporter',
#  '186': 'bams2ratio',
#  '187': 'CONVERTER_bed_gff_or_vcf_to_bigwig_0',
#  '188': 'Extract_features1',
#  '189': 'QCCalculator',
#  '190': 'umi_tools_extract',
#  '191': 'msconvert2_raw',
#  '192': 'qiime_align_seqs',
#  '193': 'gatk2_variant_select',
#  '194': 'methtools_calling',
#  '195': 'cat1',
#  '196': 'FeatureFinderMultiplex',
#  '197': 'proteomics_moff',
#  '198': 'heinz_visualization',
#  '199': 'viennarna_rnaalifold',
#  '200': 'Extract genomic DNA 1',
#  '201': 'scale_image',
#  '202': 'ggplot2_heatmap',
#  '203': 'get_subontology_from',
#  '204': 'cshl_awk_replace_in_column',
#  '205': 'bedtools_genomecoveragebed_bedgraph',
#  '206': 'sklearn_feature_selection',
#  '207': 'tophat2',
#  '208': 'picard_BamIndexStats',
#  '209': 'MassCalculator',
#  '210': 'viz_overlay_moving_and_fixed_image',
#  '211': 'deeptools_bamCoverage',
#  '212': 'qiime_pick_open_reference_otus',
#  '213': 'paralyzer',
#  '214': 'ete_homology_classifier',
#  '215': 'aggregate_scores_in_intervals2',
#  '216': 'rmcontamination',
#  '217': 'samtools_flagstat',
#  '218': 'graphlan',
#  '219': 'sklearn_svm_classifier',
#  '220': 'TrimPrimer',
#  '221': 'join_files_on_column_fuzzy',
#  '222': 'find_in_reference',
#  '223': 'bismark_bowtie2',
#  '224': 'je_markdupes',
#  '225': 'Filter1',
#  '226': 'comp1',
#  '227': 'xpath',
#  '228': 'bedtools_bamtofastq',
#  '229': 'bedtools_getfastabed',
#  '230': 'filter_bed_on_splice_junctions',
#  '231': 'gtf2bedgraph',
#  '232': 'TrimByLength',
#  '233': 'gatk2_variant_recalibrator',
#  '234': 'seq_filter_by_mapping',
#  '235': 'ete_genetree_splitter',
#  '236': 'meme_meme',
#  '237': 'cuffnorm',
#  '238': 'rseqc_infer_experiment',
#  '239': 'picard_ARRG',
#  '240': 'regex_replace',
#  '241': 'deeptools_bamFingerprint',
#  '242': 'snpEff',
#  '243': 'abims_xcms_fillPeaks',
#  '244': 'gatk_depth_of_coverage',
#  '245': 'ctb_filter',
#  '246': 'cshl_sed_tool',
#  '247': 'samtools_filter',
#  '248': 'minfi_qc',
#  '249': 'sam_merge2',
#  '250': 'metams_runGC',
#  '251': 'deeptools_multi_bigwig_summary',
#  '252': 'pynast',
#  '253': 'vcffixup',
#  '254': 'cuffdiff',
#  '255': 'bamFilter',
#  '256': 'minimap2',
#  '257': 'Add_a_column1',
#  '258': 'EMBOSS: newseq59',
#  '259': 'eukaryotic_ncbi_submission',
#  '260': 'FeatureFinderMetabo',
#  '261': 'bowtie_wrapper',
#  '262': 'mothur_amova',
#  '263': 'ExtractFASTAfromFASTQ',
#  '264': 'picard_ReorderSam',
#  '265': 'signalp3',
#  '266': 'gatk2_depth_of_coverage',
#  '267': 'HighResPrecursorMassCorrector',
#  '268': 'hicexplorer_hicbuildmatrix',
#  '269': 'gffread',
#  '270': 'rseqc_bam_stat',
#  '271': 'taxonomy_krona_chart',
#  '272': 'bam2wig',
#  '273': 'fastq_trimmer',
#  '274': 'cor2',
#  '275': 'gd_raxml',
#  '276': 'CONVERTER_Bam_Bai_0',
#  '277': '__APPLY_RULES__',
#  '278': 'bwa_mem',
#  '279': 'mothur_get_communitytype',
#  '280': 'meme_psp_gen',
#  '281': 'cardinal_spectra_plots',
#  '282': 'raceid_filtnormconf',
#  '283': 'ggplot2_heatmap2',
#  '284': 'sailfish',
#  '285': 'dexseq',
#  '286': 'IDFileConverter',
#  '287': 'remove_tail.py',
#  '288': 'cshl_find_and_replace',
#  '289': 'ncbi_tblastn_wrapper',
#  '290': 'gffcompare',
#  '291': 'sam_bw_filter',
#  '292': 'bgchem_fragment_merger',
#  '293': 'mothur_phylotype',
#  '294': 'fastq_dump',
#  '295': 'interproscan',
#  '296': 'vcfselectsamples',
#  '297': 'mz_to_sqlite',
#  '298': 'vcfsort',
#  '299': 'bamCompare_deepTools',
#  '300': 'cshl_fasta_formatter',
#  '301': 'fastq_combiner',
#  '302': 're_he_maldi_image_registration',
#  '303': 'heatmapper_deepTools',
#  '304': 'numeric_clustering',
#  '305': 'CONVERTER_fastqgz_to_fastq',
#  '306': 'minfi_getbeta',
#  '307': 'mothur_homova',
#  '308': 'snpSift_geneSets',
#  '309': 'fastq_to_fasta_python',
#  '310': 'CONVERTER_gff_to_interval_index_0',
#  '311': 'ucsc-twobittofa',
#  '312': 'gops_coverage_1',
#  '313': 'rseqc_read_distribution',
#  '314': 'myrimatch',
#  '315': 'ChooseTag',
#  '316': 'fasta_compute_length',
#  '317': 'mothur_metastats',
#  '318': 'extract_bcs.py',
#  '319': 'cd_hit_dup',
#  '320': 'abims_xcms_group',
#  '321': 'TrimByN',
#  '322': 'ctb_compound_convert',
#  '323': 'gatk2_unified_genotyper',
#  '324': 't_coffee',
#  '325': 'hicexplorer_hicfindtads',
#  '326': 'gff2bed1',
#  '327': 'get_feature_info',
#  '328': 'FileFilter',
#  '329': 'get_flanks1',
#  '330': 'sklearn_nn_classifier',
#  '331': 'chipseeker',
#  '332': 'deeptools_computeMatrix',
#  '333': 'ctb_ob_genProp',
#  '334': 'humann2_renorm_table',
#  '335': 'gemini_interactions',
#  '336': 'mothur_summary_seqs',
#  '337': 'samtools_flag_filter',
#  '338': 'Batch_correction',
#  '339': 'bowtie2',
#  '340': 'msconvert_nix',
#  '341': 'mothur_parsimony',
#  '342': 'gatk_unified_genotyper',
#  '343': 'bamCoverage_deepTools',
#  '344': 'metaphlan2',
#  '345': 'bam_to_bigwig',
#  '346': 'cshl_fastx_quality_statistics',
#  '347': 'minfi_mset',
#  '348': 'bedtools_coveragebed_counts',
#  '349': 'trim_galore',
#  '350': 'EMBOSS: tranalign100',
#  '351': 'stacks_genotypes',
#  '352': 'smf_utils_extract-boxed-sequences',
#  '353': 'Heatmap',
#  '354': 'gemini_db_info',
#  '355': 'rgPicFixMate',
#  '356': 'mcClust',
#  '357': 't2t_report',
#  '358': 'rseqc_geneBody_coverage',
#  '359': 'heinz_scoring',
#  '360': 'fraggenescan',
#  '361': 'ssake',
#  '362': 'EMBOSS: water107',
#  '363': 'EMBOSS: revseq82',
#  '364': 'ConsensusID',
#  '365': 'mothur_get_oturep',
#  '366': 'bedtools_coveragebed',
#  '367': 'structure_to_gspan',
#  '368': 'varscan',
#  '369': 'bedtools_genomecoveragebed_histogram',
#  '370': 'tp_easyjoin_tool',
#  '371': 'EMBOSS: transeq101',
#  '372': 'glimmer_not-knowlegde-based',
#  '373': 'Show tail1',
#  '374': 'vcfvcfintersect',
#  '375': 'kraken-filter',
#  '376': 'samtools_rmdup',
#  '377': 'snippy_core',
#  '378': 'vegan_diversity',
#  '379': 'lca1',
#  '380': 'methtools_plot',
#  '381': 'subtract_query1',
#  '382': 'gatk2_variant_filtration',
#  '383': 'metaphlan_hclust_heatmap',
#  '384': 'infernal_cmbuild',
#  '385': 'hgv_david',
#  '386': 'Interval_Maf_Merged_Fasta2',
#  '387': 'w4mjoinpn',
#  '388': '__FILTER_FAILED_DATASETS__',
#  '389': 'kraken-translate',
#  '390': 'abricate',
#  '391': 'antismash',
#  '392': 'snpsift_vartype',
#  '393': 'GeneModelMapper',
#  '394': 'flexbardsc',
#  '395': 'sam_pileup',
#  '396': 'gspan',
#  '397': 'plotly_regression_performance_plots',
#  '398': 'augustus',
#  '399': 'picard_MarkDuplicatesWithMateCigar',
#  '400': 'mothur_count_groups',
#  '401': 'gops_join_1',
#  '402': 'samtools_idxstats',
#  '403': 'deeptools_plot_enrichment',
#  '404': 'snpSift_filter',
#  '405': 'Remove_ending',
#  '406': 'vt_normalize',
#  '407': 'vcfannotate',
#  '408': 'gops_basecoverage_1',
#  '409': 'gatk_indel_realigner',
#  '410': 'bigwig_to_bedgraph',
#  '411': 'MSGFPlusAdapter',
#  '412': 'FileConverter',
#  '413': 'mycrobiota-qc-report',
#  '414': 'melt',
#  '415': 'iReport',
#  '416': 'bedtools_intersectBed',
#  '417': 'rna_star',
#  '418': 'cardinal_combine',
#  '419': 'methtools_destrand',
#  '420': 'TextExporter',
#  '421': 'je_clip',
#  '422': 'minfi_maptogenome',
#  '423': 'bamleftalign',
#  '424': 'gatk2_variant_annotator',
#  '425': 'cummeRbund',
#  '426': 'krona-text',
#  '427': 'deeptools_plot_profile',
#  '428': 'qiime_pick_closed_reference_otus',
#  '429': 'gmx_setup',
#  '430': 'fastq collapser',
#  '431': 'fastq_groomer',
#  '432': 'circgraph',
#  '433': 'bctools_remove_tail',
#  '434': 'hicexplorer_hicmergematrixbins',
#  '435': 'mycrobiota-make-multi-otutable',
#  '436': 'XY_Plot_1',
#  '437': 'abims_CAMERA_annotateDiffreport',
#  '438': 'samtools_bedcov',
#  '439': 'rbc_rnacode',
#  '440': 'samtools_split',
#  '441': 'trimmer',
#  '442': 'FileMerger',
#  '443': 'humann2_regroup_table',
#  '444': 'PicardASMetrics',
#  '445': 'uparse',
#  '446': 'Datamash',
#  '447': 'sequence_content_trimmer',
#  '448': 'graphclust_glob_report_no_align',
#  '449': 'FileInfo',
#  '450': 'cshl_fastx_collapser',
#  '451': 'mothur_get_seqs',
#  '452': 'megahit',
#  '453': 'hicexplorer_hictransform',
#  '454': 'tophat_fusion_post',
#  '455': 'qiime_assign_taxonomy',
#  '456': 'gatk_realigner_target_creator',
#  '457': 'group_humann2_uniref_abundances_to_go',
#  '458': 'FROGS_clustering',
#  '459': 'ctb_silicos_qed',
#  '460': 'cummerbund_to_cuffdiff',
#  '461': 'thermo_raw_file_converter',
#  '462': 'gemini_annotate',
#  '463': 'mass_spectrometry_imaging_classification',
#  '464': 'tp_head_tool',
#  '465': 'ip_projective_transformation_points',
#  '466': 'mothur_corr_axes',
#  '467': 'correctGCBias',
#  '468': 'featurecounts',
#  '469': 'mothur_get_groups',
#  '470': 'bedtools_map',
#  '471': 'deeptools_plot_coverage',
#  '472': 'deeptools_compute_matrix',
#  '473': 'silac_analyzer',
#  '474': 'viennarna_rnafold',
#  '475': 'MapStatistics',
#  '476': 'ctb_change_title',
#  '477': 'nanoplot',
#  '478': 'hcluster_sg_parser',
#  '479': 'raceid_main',
#  '480': 'mothur_pcoa',
#  '481': 'Flash',
#  '482': 'Nucleosome',
#  '483': 'Summary_Statistics1',
#  '484': 'MapAlignerPoseClustering',
#  '485': 'naive_variant_caller',
#  '486': 'diffbind-embl',
#  '487': 'macs2_predictd',
#  '488': 'varscan_somatic',
#  '489': 'DecoyDatabase',
#  '490': 'minfi_dropsnp',
#  '491': 'mimodd_map',
#  '492': 'preMloc',
#  '493': 'gemini_burden',
#  '494': 'locarna_multiple',
#  '495': 'collection_column_join',
#  '496': 'pieplots_macs',
#  '497': 'methtools_filter',
#  '498': 'velvetoptimiser',
#  '499': 'vcftools_merge',
#  '500': 'hisat2',
#  '501': 'stacks_denovomap',
#  '502': 'wig_to_bigWig',
#  '503': 'hicexplorer_hicplottads',
#  '504': 'mimodd_vcf_filter',
#  '505': 'mass_spectrometry_imaging_segmentations',
#  '506': 'ProteinInference',
#  '507': 'IDConflictResolver',
#  '508': 'correct_barcodes',
#  '509': 'blast2go',
#  '510': 'PeptideIndexer',
#  '511': 'samtools_stats',
#  '512': 'mycrobiota-krona-mothur',
#  '513': 'picard_FilterSamReads',
#  '514': 'openms_id_file_converter',
#  '515': 'mothur_heatmap_bin',
#  '516': 'gatk2_print_reads',
#  '517': 'vcf2pgSnp',
#  '518': 'secretbt2test',
#  '519': 'gops_cluster_1',
#  '520': 'rbc_mirdeep2_mapper',
#  '521': 'megablast_wrapper',
#  '522': 'hmmer_hmmsearch',
#  '523': 'idpassemble',
#  '524': 'fastq_join',
#  '525': 'proteomics_search_tandem_1',
#  '526': 'rseqc_inner_distance',
#  '527': 'mycrobiota-split-multi-otutable',
#  '528': 'vcfallelicprimitives',
#  '529': 'fastq_manipulation',
#  '530': 'XTandemAdapter',
#  '531': 'eden_sequence_converter',
#  '532': 'CONVERTER_bed_to_gff_0',
#  '533': 'gemini_windower',
#  '534': 'get_sequences',
#  '535': 'fastq_paired_end_deinterlacer',
#  '536': 'map_peptides_to_bed',
#  '537': 'openms_id_mapper',
#  '538': 'graphlan_annotate',
#  '539': 'pileup_interval',
#  '540': 'raceid_trajectory',
#  '541': 'metilene',
#  '542': 'ncbi_makeblastdb',
#  '543': 'bedtools_mergebed',
#  '544': 'join1',
#  '545': 'mothur_unique_seqs',
#  '546': 'hicexplorer_hicplotmatrix',
#  '547': 'ncbi_blastx_wrapper',
#  '548': 'methtools_tiling',
#  '549': 'addValue',
#  '550': 'sam_to_bam',
#  '551': 'rbc_mirdeep2_quantifier',
#  '552': 'cshl_fastx_renamer',
#  '553': 'gbk_to_orf',
#  '554': 'rgweblogo3',
#  '555': 'CONVERTER_gff_to_bed_0',
#  '556': 'enhanced_bowtie_wrapper',
#  '557': 'rbc_mafft',
#  '558': 'samtool_filter2',
#  '559': 'unipept',
#  '560': 'cutadapt',
#  '561': 'venn_list',
#  '562': 'picard_FixMateInformation',
#  '563': 'CONVERTER_fasta_to_tabular',
#  '564': 'mothur_trim_seqs',
#  '565': 'gafa',
#  '566': 'gemini_comp_hets',
#  '567': 'bam_to_sam',
#  '568': 'tp_awk_tool',
#  '569': '__FLATTEN__',
#  '570': 'CONVERTER_interval_to_bedstrict_0',
#  '571': 'deeptools_compute_matrix_operations',
#  '572': 'w4mcorcov',
#  '573': 'vcfgenotypes',
#  '574': 'sort1',
#  '575': 'smf_utils_fix-fasta-headers',
#  '576': 'Btrim64',
#  '577': 'mothur_count_seqs',
#  '578': 'cshl_fastx_barcode_splitter',
#  '579': 'mothur_make_group',
#  '580': 'ctb_chemfp_mol2fps',
#  '581': 'meme_chip',
#  '582': 'roary',
#  '583': 'regex1',
#  '584': 'FROGS_preprocess',
#  '585': 'glob_report',
#  '586': 'dt_profiler',
#  '587': 'seq_composition',
#  '588': 'gatk2_haplotype_caller',
#  '589': 'qiime_pick_otus',
#  '590': 'tp_sort_rows',
#  '591': 'picard_CollectInsertSizeMetrics',
#  '592': 'macs2_callpeak',
#  '593': 'gops_concat_1',
#  '594': 'peakachu',
#  '595': 'DatamashOps',
#  '596': 'CONVERTER_gz_to_uncompressed',
#  '597': 'selectsequencesfrommsa',
#  '598': 'deeptools_correctGCBias',
#  '599': 'mothur_heatmap_sim',
#  '600': 'newick_display',
#  '601': 'picard_SamToFastq',
#  '602': 'column_remove_by_header',
#  '603': 'flexbar_no_split',
#  '604': 'nn_classifier',
#  '605': 'viennarna_rnaplot',
#  '606': 'SequenceCoverageCalculator',
#  '607': 'Fetch Taxonomic Ranks',
#  '608': 'Show beginning1',
#  '609': 'react_cal_pipeline',
#  '610': 'bedtools_complementbed',
#  '611': 'flexbar_split_RR_bcs',
#  '612': 'mycrobiota-otutable_add_blast',
#  '613': 'NSPDK_candidateClust',
#  '614': 'meme_dreme',
#  '615': '__SORTLIST__',
#  '616': 'ChangeCase',
#  '617': 'GeMoMa_Annotation_Filter',
#  '618': '__RELABEL_FROM_FILE__',
#  '619': 'datamash_transpose',
#  '620': 'term_id_vs_term_name',
#  '621': 'CometAdapter',
#  '622': 'sklearn_build_pipeline',
#  '623': 'tp_cut_tool',
#  '624': 'Remove beginning1',
#  '625': 'bwameth',
#  '626': 'cshl_word_list_grep',
#  '627': 'allele_counts_1',
#  '628': 'disco',
#  '629': 'Draw_phylogram',
#  '630': 'IDMapper',
#  '631': 'ia_coordinates_of_roi',
#  '632': 'prokaryotic_ncbi_submission',
#  '633': '__ZIP_COLLECTION__',
#  '634': 'mass_spectrometry_imaging_combine',
#  '635': 'bctools_extract_crosslinked_nucleotides',
#  '636': 'ggplot2_point',
#  '637': 'bedtools_slopbed',
#  '638': 'biosigner',
#  '639': 'mothur_taxonomy_to_krona',
#  '640': 'FidoAdapter',
#  '641': 'minfi_rset',
#  '642': 'FeatureLinkerUnlabeledQT',
#  '643': 'p_clip_peaks',
#  '644': 'coords2clnt.py',
#  '645': 'tabular_to_fastq',
#  '646': 'cardinal_data_exporter',
#  '647': 'qiime_split_libraries_fastq',
#  '648': 'bg_sortmerna',
#  '649': 'smooth_running_window',
#  '650': 'fastq_paired_end_joiner',
#  '651': 'hisat',
#  '652': 'glimmer_build-icm',
#  '653': 'modencode_peakcalling_macs2',
#  '654': 'bedtools_multiintersectbed',
#  '655': 'deseq2_single',
#  '656': 'rm_spurious_events.py',
#  '657': 'scpipe',
#  '658': 'sklear_numeric_clustering',
#  '659': 'datamash_ops',
#  '660': 'maldi_quant_peak_detection',
#  '661': 'egsea',
#  '662': 'smf_utils_filter-by-energy',
#  '663': 'glimmer_knowlegde-based',
#  '664': 'EMBOSS: fuzzpro38',
#  '665': 'deeptools_plot_pca',
#  '666': 'Digestor',
#  '667': 'bedtools_genomecoveragebed',
#  '668': 'gops_subtract_1',
#  '669': 'mass_spectrometry_imaging_qc',
#  '670': 'mimodd_varextract',
#  '671': 'minfi_methcpg',
#  '672': 'openms_protein_quantifier',
#  '673': 'tp_tail_tool',
#  '674': 'pileometh',
#  '675': 'snpSift_dbnsfp_generic',
#  '676': 'IDScoreSwitcher',
#  '677': 'spades',
#  '678': 'mothur_make_biom',
#  '679': 'scaffold2fasta',
#  '680': 'vcffilter2',
#  '681': '__FILTER_FROM_FILE__',
#  '682': 'vcf2tsv',
#  '683': 'EMBOSS: geecee41',
#  '684': 'hcluster_sg',
#  '685': 'bedtools_bamtobed',
#  '686': 'gff_to_sequence',
#  '687': 'tp_uniq_tool',
#  '688': 'translate_bed_sequences',
#  '689': 'fastq_paired_end_interlacer',
#  '690': 'tag_stat2',
#  '691': 'mimodd_varcall',
#  '692': 'shovill',
#  '693': 'fastq_to_tabular',
#  '694': 'idpquery',
#  '695': 'gmx_nvt',
#  '696': 'heatmap2',
#  '697': 'deeptools_plot_correlation',
#  '698': 'uniprot',
#  '699': 'bam-filter',
#  '700': 'jbrowse',
#  '701': 'ggplot_point',
#  '702': 'Extractor',
#  '703': 'nspdk_sparse',
#  '704': 'ctb_simsearch',
#  '705': 'bed_to_bigwig',
#  '706': 'gops_intersect_1',
#  '707': '16Saligner',
#  '708': 'mothur_filter_seqs',
#  '709': 'export2graphlan',
#  '710': 'bedtools_windowbed',
#  '711': 'Grouping1',
#  '712': 'svm_classifier',
#  '713': 'gemini_actionable_mutations',
#  '714': 'IDMassAccuracy',
#  '715': 'FROGS_affiliation_OTU',
#  '716': 'tp_sed_tool',
#  '717': 'length_and_gc_content',
#  '718': 'lastz_wrapper_2',
#  '719': 'sklearn_searchcv',
#  '720': 'vsearch_dereplication',
#  '721': 'snippy',
#  '722': 'kraken',
#  '723': 'merge_pcr_duplicates.py',
#  '724': 'tp_text_file_with_recurring_lines',
#  '725': 'umi_tools_dedup',
#  '726': 'sample_seqs',
#  '727': 'peakcalling_macs',
#  '728': 'velvet',
#  '729': 'deeptools_bigwig_compare',
#  '730': 'MAF_To_Fasta1',
#  '731': 'mothur_nmds',
#  '732': 'bed2gff1',
#  '733': 'FalseDiscoveryRate',
#  '734': 'qiime_core_diversity',
#  '735': 'qiime_make_phylogeny',
#  '736': 'humann2_genefamilies_genus_level',
#  '737': 'gmx_npt',
#  '738': 'velvetg_jgi',
#  '739': 'replace_column_with_key_value_file',
#  '740': 'infernal_cmstat',
#  '741': 'chipsequtil_maptoknowngenes',
#  '742': 'wc_gnu',
#  '743': 'snpeff_to_peptides',
#  '744': 'cardinal_mz_images',
#  '745': 'bedtools_intersectbed',
#  '746': 'fastq_paired_end_splitter',
#  '747': 'qiime_validate_mapping_file',
#  '748': 'PeakPickerHiRes',
#  '749': 'flexbar_split_RYYR_bcs',
#  '750': 'vegan_rarefaction',
#  '751': 'gtftobed12',
#  '752': 'query_tabular',
#  '753': 'megablast_xml_parser',
#  '754': 'plotly_ml_performance_plots',
#  '755': 'clustalw',
#  '756': 'tp_sort_header_tool',
#  '757': 'minfi_getM',
#  '758': 'ctb_remIons',
#  '759': 'CONVERTER_bed_to_bgzip_0',
#  '760': 'FROGS_filters',
#  '761': 'column_order_header_sort',
#  '762': 'CONVERTER_sam_to_unsorted_bam',
#  '763': 'cshl_easyjoin',
#  '764': 'rseqc_junction_saturation',
#  '765': 'mothur_sub_sample',
#  '766': 'vcftools_annotate',
#  '767': 'rseqc_read_duplication',
#  '768': 'Multivariate',
#  '769': 'peptide_shaker',
#  '770': 'bcftools_call',
#  '771': 'cshl_fastq_quality_boxplot',
#  '772': 'hgv_linkToGProfile',
#  '773': 'gatk2_indel_realigner',
#  '774': 'filter_by_fasta_ids',
#  '775': 'ggplot2_histogram',
#  '776': 'deeptools_bam_compare',
#  '777': 'wsdl_hmdb',
#  '778': 'cardinal_segmentations',
#  '779': 'picard_ValidateSamFile',
#  '780': 'EMBOSS: textsearch98',
#  '781': 'bg_diamond',
#  '782': 'htseq_count',
#  '783': 'varscan_copynumber',
#  '784': 'samtools_calmd',
#  '785': 'deeptools_bam_coverage',
#  '786': 'mothur_chimera_uchime',
#  '787': 'freebayes',
#  '788': 'IsobaricAnalyzer',
#  '789': 'bwa_wrapper',
#  '790': 'sam2interval',
#  '791': 'multiqc',
#  '792': 'unicycler',
#  '793': 'fasttree',
#  '794': 'picard_CleanSam',
#  '795': 'gatk2_base_recalibrator',
#  '796': 'qiime_pick_rep_set',
#  '797': 'stacks_populations',
#  '798': 'rcas',
#  '799': 'EMBOSS: fuzztran39',
#  '800': 'bedtools_unionbedgraph',
#  '801': 'MapRTTransformer',
#  '802': 'mimodd_varreport',
#  '803': 'bcftools_consensus',
#  '804': 'pureclip',
#  '805': 'snpSift_annotate',
#  '806': 'EMBOSS: seqret84',
#  '807': 'vcfflatten2',
#  '808': 'methtools_dmr',
#  '809': 'Psortb',
#  '810': 'eden_vectorizer',
#  '811': 'mergeCols1',
#  '812': 'porechop',
#  '813': 'bg_uniq',
#  '814': 'cshl_awk_tool',
#  '815': 'kallisto_quant',
#  '816': 'term_id_vs_term_def',
#  '817': 'qiime_make_otu_heatmap',
#  '818': 'gene2exon1',
#  '819': 'picard_MarkDuplicates',
#  '820': 'ncbi_blastp_wrapper',
#  '821': 'seurat',
#  '822': 'w4mclstrpeakpics',
#  '823': 'random_lines1',
#  '824': 'bg_protein_properties',
#  '825': 'Grep1',
#  '826': 'EMBOSS: wordcount109',
#  '827': 'samtools_mpileup',
#  '828': 'tp_replace_in_line',
#  '829': 'mothur_make_shared',
#  '830': 'gff_filter_by_attribute',
#  '831': 'umi_tools_count',
#  '832': 'cshl_fastx_reverse_complement',
#  '833': 'convert_bc_to_binary_RY.py',
#  '834': 'infernal_cmsearch',
#  '835': 'mass_spectrometry_imaging_mzplots',
#  '836': 'graphclust_align_cluster',
#  '837': 'rnafold',
#  '838': 'edger',
#  '839': 'CONVERTER_interval_to_bed_0',
#  '840': 'CONVERTER_interval_to_bgzip_0',
#  '841': 'fastq_filter',
#  '842': 'tsne',
#  '843': 'transdecoder',
#  '844': 'gmx_em',
#  '845': 'DatamashTranspose',
#  '846': 'FROGS_remove_chimera',
#  '847': 'heinz',
#  '848': 'w4mclassfilter',
#  '849': 'EMBOSS: shuffleseq87',
#  '850': 'EMBOSS: extractseq35',
#  '851': 'gatk2_reduce_reads',
#  '852': 'deseq2',
#  '853': 'combine_metaphlan2_humann2',
#  '854': 'picard_MergeSamFiles',
#  '855': 'bedtools_annotatebed',
#  '856': 'tp_multijoin_tool',
#  '857': 'cardinal_quality_report',
#  '858': 'proteomics_search_protein_prophet_1',
#  '859': 'deeptools_computeGCBias',
#  '860': 'table_annovar',
#  '861': 'IDPosteriorErrorProbability',
#  '862': 'fasplit',
#  '863': 'fastqc',
#  '864': 'search_gui',
#  '865': 'stacks_procrad',
#  '866': 'bedtools_intersectbed_bam',
#  '867': 'wiggle2simple1',
#  '868': 'stacks_refmap',
#  '869': 'cshl_fastx_nucleotides_distribution',
#  '870': 'get_child_terms',
#  '871': 'rnaz',
#  '872': 'bcftools_view',
#  '873': 'mothur_dist_shared',
#  '874': 'extract_aln_ends.py',
#  '875': 'deeptools_multi_bam_summary',
#  '876': 'metaspades',
#  '877': 'fasta_merge_files_and_filter_unique_sequences',
#  '878': 'mothur_classify_rf',
#  '879': 'cshl_uniq_tool',
#  '880': 'mothur_seq_error',
#  '881': 'cshl_sort_header',
#  '882': 'locarna_best_subtree',
#  '883': 'ctb_remSmall',
#  '884': 'mass_spectrometry_imaging_preprocessing',
#  '885': '__MERGE_COLLECTION__',
#  '886': 'bcftools_norm',
#  '887': 'gops_merge_1',
#  '888': 'deeptools_profiler',
#  '889': 'raceid_clustering',
#  '890': 'gatk2_variant_apply_recalibration',
#  '891': 'gemini_pathways',
#  '892': 'mothur_remove_lineage',
#  '893': 'umi_tools_group',
#  '894': 'samtools_sort',
#  '895': 'blastxml_to_tabular_selectable',
#  '896': 'gemini_de_novo',
#  '897': 'align_families',
#  '898': 'NFS_transfer',
#  '899': 'abims_xcms_summary',
#  '900': 'hicexplorer_hiccorrectmatrix',
#  '901': 'bedtools_bedtobam',
#  '902': 'gemini_recessive_and_dominant',
#  '903': 'rbc_splitfasta',
#  '904': 'stringtie',
#  '905': 'proteomics_search_peptide_prophet_1',
#  '906': 'segemehl',
#  '907': 'humann2',
#  '908': 'mothur_make_contigs',
#  '909': 'Extract_RNA_seq_Evidence',
#  '910': 'igvtools_count',
#  '911': 'trimmomatic',
#  '912': 'tab2fasta',
#  '913': 'Count1',
#  '914': 'fasta_filter_by_length',
#  '915': 'deeptools_bamCorrelate',
#  '916': 'gtf_filter_by_attribute_values_list',
#  '917': 'minfi_ppfun',
#  '918': 'smf_utils_estimate-energy',
#  '919': 'fragmenter',
#  '920': 'flanking_features_1',
#  '921': 'filtlong',
#  '922': 'fastq_quality_trimmer',
#  '923': 'rbc_mirdeep2',
#  '924': 'Paste1',
#  '925': 'mothur_merge_files',
#  '926': 'cshl_fastq_quality_filter',
#  '927': 'valet',
#  '928': 'resistome_analyzer',
#  '929': 'blockclust',
#  '930': 'deeptools_compute_gc_bias',
#  '931': 'deeptools_plot_heatmap',
#  '932': 'tp_grep_tool',
#  '933': 'macs2_bdgcmp',
#  '934': 'cuffquant',
#  '935': 'heinz_bum',
#  '936': 'ggplot_histogram',
#  '937': 'gatk2_realigner_target_creator',
#  '938': 'iuc_pear',
#  '939': 'bg_find_subsequences',
#  '940': 'heatmapper',
#  '941': 'mothur_lefse',
#  '942': 'qiime_count_seqs',
#  '943': 'mass_spectrometry_imaging_filtering',
#  '944': 'snpfinder',
#  '945': 'cardinal_filtering',
#  '946': 'mothur_classify_otu',
#  '947': 'bctools_remove_spurious_events',
#  '948': 'FeatureLinkerUnlabeled',
#  '949': 'bedtools_shufflebed',
#  '950': 'predict_pipeline',
#  '951': 'trinity',
#  '952': 'CONVERTER_bedgraph_to_bigwig',
#  '953': 'picard_CASM',
#  '954': 'get_read_pipeline',
#  '955': 'picard_CollectWgsMetrics',
#  '956': 'abims_xcms_xcmsSet',
#  '957': 'gmx_md',
#  '958': 'modencode_peakcalling_spp',
#  '959': 'idr-embl',
#  '960': 'ProteinResolver',
#  '961': 'deeptools_bigwigCompare',
#  '962': 'cshl_fastx_clipper',
#  '963': 'make_families',
#  '964': 'mothur_summary_single',
#  '965': 'CONVERTER_fasta_to_fai',
#  '966': 'meme_fimo',
#  '967': 'hmmer_hmmbuild',
#  '968': 'wolf_psort',
#  '969': 'cshl_fastx_trimmer',
#  '970': 'cmFinder',
#  '971': 'mothur_screen_seqs'}

# %%
def verify_model(model, tool_sequence, labels, dictionary, reverse_dictionary, compatible_tools, topk=20, max_seq_len=25):
    tl_seq = tool_sequence.split(",")
    last_tool_name = reverse_dictionary[str(tl_seq[-1])]
    last_compatible_tools = compatible_tools[last_tool_name]
    sample = np.zeros(max_seq_len)
    for idx, tool_id in enumerate(tl_seq):
        sample[idx] = int(tool_id)
    sample_reshaped = np.reshape(sample, (1, max_seq_len))
    
    tool_sequence_names = [reverse_dictionary[str(tool_pos)] for tool_pos in tool_sequence.split(",")]
    print("Tool seq: %s" % ",".join(tool_sequence_names))
    # predict next tools for a test path
    prediction = model.predict(sample_reshaped, verbose=0)
    prediction = np.reshape(prediction, (prediction.shape[1],))
    prediction_pos = np.argsort(prediction, axis=-1)

    # get topk prediction
    topk_prediction_pos = prediction_pos[-topk:]
    topk_prediction_val = [np.round(prediction[pos] * 100, 2) for pos in topk_prediction_pos]

    # read tool names using reverse dictionary
    pred_tool_ids = [reverse_dictionary[str(tool_pos)] for tool_pos in topk_prediction_pos]
    actual_next_tool_ids = list(set(pred_tool_ids).intersection(set(last_compatible_tools.split(","))))      
        
    #print("Predicted tools: %s" % ",".join(pred_tool_ids))
    print()
    pred_tool_ids_sorted = dict()
    for (tool_pos, tool_pred_val) in zip(topk_prediction_pos, topk_prediction_val):
        tool_name = reverse_dictionary[str(tool_pos)]
        if tool_name in actual_next_tool_ids:
            pred_tool_ids_sorted[tool_name] = tool_pred_val
    pred_tool_ids_sorted = dict(sorted(pred_tool_ids_sorted.items(), key=lambda kv: kv[1], reverse=True))
    
    cls_wt = dict()
    usg_wt = dict()
    inv_wt = dict()
    ids_tools = dict()
    keys = list(pred_tool_ids_sorted.keys())
    for k in keys:
        try:
            cls_wt[k] = np.round(class_weights[str(data_dict[k])], 2)
            usg_wt[k] = np.round(usage_weights[k], 2)
            inv_wt[k] = np.round(inverted_weights[str(data_dict[k])], 2)
        except:
            continue
    print("Predicted tools: \n")
    print(pred_tool_ids_sorted)
    print()
    print("Class weights: \n")
    cls_wt = dict(sorted(cls_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(cls_wt)
    print()
    print("Usage weights: \n")
    usg_wt = dict(sorted(usg_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(usg_wt)
    print()
    total_usage_wt = np.sum(list(usg_wt.values()))
    print("Sum usage wt: %0.4f" % (total_usage_wt))
    print()
    print("Inverted weights: \n")
    inv_wt = dict(sorted(inv_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(inv_wt)
    for key in pred_tool_ids_sorted:
        ids_tools[key] = dictionary[key]
    print()
    print("Tool ids")
    print(ids_tools)
    print("======================================")
    return cls_wt, usg_wt, inv_wt, pred_tool_ids_sorted

topk = 10
tool_seq = "500" # ,875,223,17
class_wt, usage_wt, inverse_wt, pred_tools = verify_model(model, tool_seq, "", dictionary, reverse_dictionary, compatibile_tools, topk)
# Out:
# Tool seq: hisat2
#
# Predicted tools:
#
# {'htseq_count': 1.98, 'bam_to_sam': 1.51}
#
# Class weights:
#
# {'htseq_count': 1490.51, 'bam_to_sam': 1315.27}
#
# Usage weights:
#
# {'htseq_count': 538.31, 'bam_to_sam': 68.97}
#
# Sum usage wt: 607.2800
#
# Inverted weights:
#
# {'htseq_count': 1489.51, 'bam_to_sam': 1314.27}
#
# Tool ids
# {'htseq_count': 782, 'bam_to_sam': 567}
# ======================================

# %%
list_cls_wt = list()
list_usage_wt = list()
list_pred_wt = list()
list_inv_wt = list()
division_pt = int(len(pred_tools) / 2)

for tool in pred_tools:
    list_pred_wt.append(pred_tools[tool])
    #try:
    list_inv_wt.append(inverse_wt[tool])
    list_usage_wt.append(usage_wt[tool])
    #except:
    #list_inv_wt.append(1)

def plot_scatter(y_val, title, xlabel, ylabel):
    x_val = range(1, len(y_val) + 1)
    plt.figure(figsize=(8, 8))
    plt.plot(x_val[:division_pt], y_val[:division_pt], 'ro')
    plt.plot(x_val[division_pt:], y_val[division_pt:], 'b^')
    plt.xlabel(xlabel, size=size_label)
    plt.ylabel(ylabel, size=size_label)
    plt.legend([("First top-%s" % str(division_pt)), ("Next top-%s" % str(division_pt))])
    plt.title(title, size=size_title)
    plt.grid(True)
    plt.show()

plot_scatter(list_usage_wt, "Usage weights for tools", "Number of tools", "Class weights")
#plot_scatter(ave_prediction_weights, ave_usage_weights, "Prediction vs usage weights", "Prediction scores", "Usage weights")
#plot_scatter(ave_prediction_weights, ave_inverted_weights, "Prediction vs inverted weights", "Prediction scores", "Inverted weights")
