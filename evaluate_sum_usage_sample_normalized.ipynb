# %%
import numpy as np
import json
import warnings
import operator

import h5py
from keras.models import model_from_json
from keras import backend as K

from matplotlib import pyplot as plt

warnings.filterwarnings("ignore")

size_title = 18
size_label = 14
n_pred = 2

base_path = "data/evaluate_sum_usage_sample_normalized/"

path_data_dict = base_path + "data_dict.txt"
path_inverted_wt = base_path + "inverted_weights.txt"
path_usage_wt = base_path + "usage_prediction.txt"
path_class_wt = base_path + "class_weights.txt"
path_test_data = base_path + "test_paths_dict.txt"
model_path = base_path + "trained_model.hdf5"

def read_file(file_path):
    with open(file_path, 'r') as data_file:
        data = json.loads(data_file.read())
    return data

class_weights = read_file(path_class_wt)
usage_weights = read_file(path_usage_wt)
inverted_weights = read_file(path_inverted_wt)
data_dict = read_file(path_data_dict)

def create_model(model_path):
    trained_model = h5py.File(model_path, 'r')
    model_config = json.loads(trained_model.get('model_config').value)
    loaded_model = model_from_json(model_config)
    dictionary = json.loads(trained_model.get('data_dictionary').value)
    compatibile_tools = json.loads(trained_model.get('compatible_tools').value)
    reverse_dictionary = dict((str(v), k) for k, v in dictionary.items())
    model_weights = list()
    weight_ctr = 0
    while True:
        try:
            d_key = "weight_" + str(weight_ctr)
            weights = trained_model.get(d_key).value
            model_weights.append(weights)
            weight_ctr += 1
        except Exception as exception:
            break
    # set the model weights
    loaded_model.set_weights(model_weights)
    return loaded_model, dictionary, reverse_dictionary, compatibile_tools

model, dictionary, reverse_dictionary, compatibile_tools = create_model(model_path)
# Out:
# Using TensorFlow backend.

# %%
reverse_dictionary
# Out:
# {'1': 'rna_star',
#  '2': 'picard_CleanSam',
#  '3': 'NSPDK_candidateClust',
#  '4': 'rgPicardMarkDups',
#  '5': 'piranha',
#  '6': 'nn_classifier',
#  '7': 'biosigner',
#  '8': 'cutadapt',
#  '9': 'xpath',
#  '10': 'cast',
#  '11': 'graphclust_aggregate_alignments',
#  '12': 'gemini_actionable_mutations',
#  '13': 'kallisto_quant',
#  '14': 'mothur_pcoa',
#  '15': 'vcf2pgSnp',
#  '16': 'bedtools_coveragebed_counts',
#  '17': 'bam_to_sam',
#  '18': 'IDScoreSwitcher',
#  '19': 'fraggenescan',
#  '20': 'kraken-filter',
#  '21': 'FROGS_remove_chimera',
#  '22': 'get_sequences',
#  '23': 'bwa',
#  '24': 'mothur_dist_seqs',
#  '25': 'hcluster_sg',
#  '26': 'gemini_db_info',
#  '27': 'trinity',
#  '28': 'gops_coverage_1',
#  '29': 'qiime_pick_rep_set',
#  '30': 'interproscan',
#  '31': 'gatk2_realigner_target_creator',
#  '32': 'picard_FilterSamReads',
#  '33': 'snpEff',
#  '34': 'mass_spectrometry_imaging_qc',
#  '35': 'plotly_ml_performance_plots',
#  '36': 'humann2_renorm_table',
#  '37': 'minfi_methcpg',
#  '38': 'metaphlan2krona',
#  '39': 'spades',
#  '40': 'diffbind-embl',
#  '41': 'samtools_calmd',
#  '42': 'Extract_features1',
#  '43': 'gatk2_variant_annotator',
#  '44': 'metams_runGC',
#  '45': 'mass_spectrometry_imaging_filtering',
#  '46': 'umi_tools_group',
#  '47': 'preMloc',
#  '48': 'pileometh',
#  '49': 'gmx_solvate',
#  '50': 'modencode_peakcalling_macs2',
#  '51': 'fastq_paired_end_deinterlacer',
#  '52': 'gatk_realigner_target_creator',
#  '53': 'mycrobiota-split-multi-otutable',
#  '54': 'samtools_filter',
#  '55': 'sort1',
#  '56': 'fasttree',
#  '57': 'hgv_linkToGProfile',
#  '58': 'bam2wig',
#  '59': 'hgv_david',
#  '60': 'gemini_burden',
#  '61': 'picard_ValidateSamFile',
#  '62': 'raceid_inspectclusters',
#  '63': 'allele_counts_1',
#  '64': 'unipept',
#  '65': 'hicexplorer_hicfindtads',
#  '66': 'collapse_dataset',
#  '67': 'DecoyDatabase',
#  '68': 'nspdk_sparse',
#  '69': 'mothur_metastats',
#  '70': 'wc_gnu',
#  '71': 'mothur_count_groups',
#  '72': 'kraken',
#  '73': 'mergeCols1',
#  '74': 'sed_stream_editor',
#  '75': 'FidoAdapter',
#  '76': 'Multivariate',
#  '77': 'mimodd_map',
#  '78': 'rbc_mafft',
#  '79': 'cuffcompare',
#  '80': 'velvetoptimiser',
#  '81': 'flanking_features_1',
#  '82': 'meme_fimo',
#  '83': 'fasta-stats',
#  '84': 'abims_xcms_fillPeaks',
#  '85': 'seq_composition',
#  '86': 'bismark_bowtie',
#  '87': 'hisat2',
#  '88': 'treebest_best',
#  '89': 'venn_list',
#  '90': 'EMBOSS: geecee41',
#  '91': 'Remove_ending',
#  '92': 'mothur_remove_lineage',
#  '93': 'mothur_amova',
#  '94': 'svm_classifier',
#  '95': 'fastq_manipulation',
#  '96': 'hicexplorer_hicsummatrices',
#  '97': 'rbc_mirdeep2_quantifier',
#  '98': 'rseqc_bam_stat',
#  '99': 'bam-filter',
#  '100': 'picard_ARRG',
#  '101': '__MERGE_COLLECTION__',
#  '102': 'cor2',
#  '103': 'GeneModelMapper',
#  '104': 'map_peptides_to_bed',
#  '105': 'deeptools_correct_gc_bias',
#  '106': 'bedtools_shufflebed',
#  '107': 'minfi_maptogenome',
#  '108': 'subtract_query1',
#  '109': 'column_remove_by_header',
#  '110': 'Extract_RNA_seq_Evidence',
#  '111': 'gatk2_variant_apply_recalibration',
#  '112': 'newick_display',
#  '113': 'mycrobiota-qc-report',
#  '114': 'EMBOSS: water107',
#  '115': 'picard_CollectWgsMetrics',
#  '116': '16Sclassifier',
#  '117': 'chipsequtil_maptoknowngenes',
#  '118': 'minfi_ppfun',
#  '119': 'heatmapper',
#  '120': 'mothur_screen_seqs',
#  '121': 'nanoplot',
#  '122': 'blastxml_to_top_descr',
#  '123': 'minfi_getM',
#  '124': 'ctb_filter',
#  '125': 'tp_tail_tool',
#  '126': 'vcfcombine',
#  '127': 'krona-text',
#  '128': 'deeptools_compute_gc_bias',
#  '129': 'CometAdapter',
#  '130': 'ConsensusMapNormalizer',
#  '131': 'glob_report',
#  '132': 'fastq_join',
#  '133': 'fastq_quality_trimmer',
#  '134': 'filtlong',
#  '135': 'megablast_xml_parser',
#  '136': 'Extract genomic DNA 1',
#  '137': 'regex_replace',
#  '138': 'qiime_split_libraries_fastq',
#  '139': 'gemini_annotate',
#  '140': 'nanopolish_variants',
#  '141': 'ExtractFASTAfromFASTQ',
#  '142': 'Convert characters1',
#  '143': 'cshl_fastx_clipper',
#  '144': 'secretbt2test',
#  '145': 'fastq_filter',
#  '146': 'rnbeads',
#  '147': 'vcftools_annotate',
#  '148': 'picard_CollectRnaSeqMetrics',
#  '149': 'charts',
#  '150': 'deeptools_compute_matrix_operations',
#  '151': 'deeptools_correctGCBias',
#  '152': 'smf_utils_filter-by-energy',
#  '153': 'smf_utils_extract-boxed-sequences',
#  '154': 'filter_by_fasta_ids',
#  '155': 'methtools_filter',
#  '156': 'bowtie_wrapper',
#  '157': 'FROGS_filters',
#  '158': 'blastxml_to_tabular_selectable',
#  '159': 'fgsea',
#  '160': 'gene2exon1',
#  '161': 'paralyzer',
#  '162': 'cuffmerge',
#  '163': 'flexbar_no_split',
#  '164': 'abims_CAMERA_annotateDiffreport',
#  '165': 'EMBOSS: transeq101',
#  '166': 'bedtools_intersectBed',
#  '167': 'sklearn_build_pipeline',
#  '168': 'ctb_online_data_fetch',
#  '169': 'bcftools_consensus',
#  '170': 'TrimByN',
#  '171': 'transdecoder',
#  '172': 'fastq_paired_end_joiner',
#  '173': 'mimodd_vcf_filter',
#  '174': 'IDMapper',
#  '175': 'samtools_bedcov',
#  '176': 'minfi_dmp',
#  '177': 'gemini_recessive_and_dominant',
#  '178': 'methtools_destrand',
#  '179': 'bedtools_coveragebed',
#  '180': 'ggplot2_point',
#  '181': 'cardinal_data_exporter',
#  '182': 'qiime_pick_closed_reference_otus',
#  '183': 'cardinal_filtering',
#  '184': 'raceid_filtnormconf',
#  '185': 'hicexplorer_hicplotmatrix',
#  '186': 'gatk2_base_recalibrator',
#  '187': 'mothur_merge_files',
#  '188': 'Fetch Taxonomic Ranks',
#  '189': 'qiime_count_seqs',
#  '190': 'graphclust_glob_report_no_align',
#  '191': 'EMBOSS: seqret84',
#  '192': 'deeptools_bamCompare',
#  '193': 'XTandemAdapter',
#  '194': 'table_annovar',
#  '195': 'pieplots_macs',
#  '196': 'openms_id_mapper',
#  '197': 'tp_grep_tool',
#  '198': 'uchime',
#  '199': 'CONVERTER_gff_to_bed_0',
#  '200': 'snippy',
#  '201': 'msconvert2_raw',
#  '202': 'picard_CollectInsertSizeMetrics',
#  '203': 'extract_aln_ends.py',
#  '204': 'MSGFPlusAdapter',
#  '205': 'deeptools_plot_correlation',
#  '206': 'PeakPickerHiRes',
#  '207': 'kraken-translate',
#  '208': 'cshl_word_list_grep',
#  '209': 'wolf_psort',
#  '210': 'get_feature_info',
#  '211': 'picard_ReorderSam',
#  '212': 'snpSift_annotate',
#  '213': 'mothur_chimera_uchime',
#  '214': 'ssake',
#  '215': 'gatk2_print_reads',
#  '216': 'viennarna_rnafold',
#  '217': 'samtools_flagstat',
#  '218': 'rnafold',
#  '219': 'remove_tail.py',
#  '220': 'bedtools_multicovtbed',
#  '221': 'Extractor',
#  '222': 'bedtools_sortbed',
#  '223': 'MAF_To_Fasta1',
#  '224': 'glimmer_build-icm',
#  '225': 'deeptools_computeMatrix',
#  '226': 'snpeff_to_peptides',
#  '227': 'myrimatch',
#  '228': 'smf_utils_find-boxes',
#  '229': 'metilene',
#  '230': 'cshl_fastq_quality_filter',
#  '231': 'Batch_correction',
#  '232': 'Btrim64',
#  '233': 'bamCoverage_deepTools',
#  '234': 'methtools_tiling',
#  '235': 'snpEff_download',
#  '236': 'rnaz',
#  '237': '__SORTLIST__',
#  '238': 'msconvert_nix',
#  '239': 'qiime_assign_taxonomy',
#  '240': 'sam_pileup',
#  '241': 'mothur_filter_seqs',
#  '242': 'cshl_awk_tool',
#  '243': 'cuffdiff',
#  '244': 'mothur_cluster',
#  '245': 'dbbuilder',
#  '246': 'blockclust',
#  '247': 'EMBOSS: shuffleseq87',
#  '248': 'gemini_query',
#  '249': 'Digestor',
#  '250': 'bedtools_genomecoveragebed_bedgraph',
#  '251': 'metaphlan_hclust_heatmap',
#  '252': 'get_subontology_from',
#  '253': 'peakcalling_macs',
#  '254': 'preproc',
#  '255': 'FROGS_preprocess',
#  '256': 'bandage_image',
#  '257': 'bctools_extract_crosslinked_nucleotides',
#  '258': 'scale_image',
#  '259': 'group_humann2_uniref_abundances_to_go',
#  '260': 'taxonomy_krona_chart',
#  '261': 'bg_column_arrange_by_header',
#  '262': 'porechop',
#  '263': 'cshl_fastq_to_fasta',
#  '264': 'igvtools_count',
#  '265': 'cufflinks',
#  '266': 'hcluster_sg_parser',
#  '267': 'minfi_dropsnp',
#  '268': 'trim_galore',
#  '269': 'sklearn_nn_classifier',
#  '270': 'ncbi_blastp_wrapper',
#  '271': 'vegan_diversity',
#  '272': 'correctGCBias',
#  '273': 'umi_tools_extract',
#  '274': 'salmon',
#  '275': 'featurecounts',
#  '276': 'picard_BamIndexStats',
#  '277': 'bcftools_norm',
#  '278': 'mothur_dist_shared',
#  '279': 'viennarna_rnaalifold',
#  '280': 'samtools_split',
#  '281': 'bedtools_map',
#  '282': 'collection_column_join',
#  '283': 'muscle',
#  '284': 'EMBOSS: getorf42',
#  '285': 'methtools_calling',
#  '286': 'stacks_refmap',
#  '287': 'locarna_multiple',
#  '288': 'tophat_fusion_post',
#  '289': 'fasta_compute_length',
#  '290': 'cshl_uniq_tool',
#  '291': 'EMBOSS: fuzzpro38',
#  '292': 'cshl_awk_replace_in_column',
#  '293': 'CONVERTER_bed_to_bgzip_0',
#  '294': 'ngsutils_bam_filter',
#  '295': 'mimodd_varextract',
#  '296': 'bedtools_slopbed',
#  '297': 'deg_annotate',
#  '298': 'ncbi_makeblastdb',
#  '299': 'meme_meme',
#  '300': 'fastq_paired_end_interlacer',
#  '301': 'rgweblogo3',
#  '302': 'FeatureLinkerUnlabeledQT',
#  '303': 'deeptools_computeGCBias',
#  '304': 'numeric_clustering',
#  '305': 'gbk_to_orf',
#  '306': 'CONVERTER_fastqgz_to_fastq',
#  '307': 'mimodd_varreport',
#  '308': 'samtools_sort',
#  '309': 'graphclust_align_cluster',
#  '310': 'ip_projective_transformation_points',
#  '311': 'mothur_align_seqs',
#  '312': 'PeptideIndexer',
#  '313': 'mothur_classify_otu',
#  '314': 'prokka',
#  '315': 'eden_sequence_converter',
#  '316': 'abims_xcms_summary',
#  '317': 'vcffilter2',
#  '318': 'resistome_analyzer',
#  '319': 'ete_homology_classifier',
#  '320': 'gmx_em',
#  '321': 'tp_easyjoin_tool',
#  '322': 'EMBOSS: fuzztran39',
#  '323': 'join_files_on_column_fuzzy',
#  '324': 'align_families',
#  '325': 'humann2',
#  '326': 'vcf2tsv',
#  '327': 'unicycler',
#  '328': 'cummerbund_to_cuffdiff',
#  '329': 'peakcalling_macs14',
#  '330': 'naive_variant_caller',
#  '331': 'peptide_shaker',
#  '332': 'samtools_slice_bam',
#  '333': 'MultiplexResolver',
#  '334': 'ctb_change_title',
#  '335': 'hicexplorer_hicbuildmatrix',
#  '336': 'FeatureFinderCentroided',
#  '337': 'mlocarna',
#  '338': 'bedtools_mergebed',
#  '339': 'bedtools_intersectbed',
#  '340': 'replace_column_with_key_value_file',
#  '341': 'Flash',
#  '342': 'tophat',
#  '343': 'samtools_idxstats',
#  '344': 'Grouping1',
#  '345': 'cshl_fastx_reverse_complement',
#  '346': 'gops_basecoverage_1',
#  '347': 'Paste1',
#  '348': 'bedtools_genomecoveragebed',
#  '349': 'bedtools_genomecoveragebed_histogram',
#  '350': 'Heatmap',
#  '351': 'deeptools_bam_compare',
#  '352': 'scaffold2fasta',
#  '353': 'snpfinder',
#  '354': 'rseqc_geneBody_coverage',
#  '355': 'hicexplorer_hicmergematrixbins',
#  '356': 'IDMerger',
#  '357': 'heatmapper_deepTools',
#  '358': 'vcfsort',
#  '359': 'tp_cat',
#  '360': 'checkFormat',
#  '361': 'rseqc_inner_distance',
#  '362': 'freebayes',
#  '363': 'meme_dreme',
#  '364': 'tp_sed_tool',
#  '365': 'FROGS_clustering',
#  '366': 'CONVERTER_fasta_to_fai',
#  '367': 'FeatureFinderMetabo',
#  '368': 'snpSift_geneSets',
#  '369': 'QCCalculator',
#  '370': 'TextExporter',
#  '371': 'xcms_merge',
#  '372': 'mass_spectrometry_imaging_combine',
#  '373': 'mothur_classify_rf',
#  '374': 'eukaryotic_ncbi_submission',
#  '375': 'bg_find_subsequences',
#  '376': 'scpipe',
#  '377': 'glimmer_knowlegde-based',
#  '378': 'bg_protein_properties',
#  '379': 'bedtools_windowbed',
#  '380': 'mothur_heatmap_sim',
#  '381': 'bg_statistical_hypothesis_testing',
#  '382': 'Determine_BC',
#  '383': 'egsea',
#  '384': 'metaspades',
#  '385': 'gatk_depth_of_coverage',
#  '386': 'gatk2_indel_realigner',
#  '387': 'fasplit',
#  '388': 'sqlite_to_tabular',
#  '389': 'sam2interval',
#  '390': 'IDConflictResolver',
#  '391': 'Show tail1',
#  '392': 'sklearn_ensemble',
#  '393': 'column_order_header_sort',
#  '394': 'join1',
#  '395': 'find_in_reference',
#  '396': 'CONVERTER_bed_to_gff_0',
#  '397': 'IDFileConverter',
#  '398': 'mothur_make_biom',
#  '399': 'mothur_make_group',
#  '400': 'kraken-report',
#  '401': 'proteomics_search_peptide_prophet_1',
#  '402': 'bctools_remove_tail',
#  '403': 'vcfallelicprimitives',
#  '404': 'deeptools_bamCoverage',
#  '405': 'hicexplorer_hicpca',
#  '406': 'bamtools',
#  '407': 'cshl_sort_header',
#  '408': 'gatk2_haplotype_caller',
#  '409': 'deeptools_heatmapper',
#  '410': 'bctools_extract_alignment_ends',
#  '411': 'extract_bcs.py',
#  '412': 'bcftools_view',
#  '413': 'cshl_princeton_fastx_barcode_splitter',
#  '414': 'melt',
#  '415': 'ProteinQuantifier',
#  '416': 'deeptools_bigwig_compare',
#  '417': 'fastq_groomer',
#  '418': 'tp_cut_tool',
#  '419': 'htseq-count',
#  '420': 'vcfselectsamples',
#  '421': 'filter_bed_on_splice_junctions',
#  '422': 'goenrichment',
#  '423': 'Psortb',
#  '424': 'CONVERTER_fasta_to_tabular',
#  '425': 'fragmenter',
#  '426': 'FileConverter',
#  '427': '16Saligner',
#  '428': 'gatk2_depth_of_coverage',
#  '429': 'mothur_make_shared',
#  '430': 'tabular_to_fastq',
#  '431': 'varscan',
#  '432': 'react_cal_pipeline',
#  '433': 'Univariate',
#  '434': 'flye',
#  '435': 'mimodd_varcall',
#  '436': 'CONVERTER_interval_to_bedstrict_0',
#  '437': '__RELABEL_FROM_FILE__',
#  '438': 'fastq_dump',
#  '439': 'Show beginning1',
#  '440': 'ProteinInference',
#  '441': 'tp_text_file_with_recurring_lines',
#  '442': 'IDMassAccuracy',
#  '443': 'edger',
#  '444': 'shovill',
#  '445': 'valet',
#  '446': 'ConsensusID',
#  '447': 'vt_normalize',
#  '448': 'vcfvcfintersect',
#  '449': 'bedtools_intersectbed_bam',
#  '450': 'sailfish',
#  '451': 'annotateMyIDs',
#  '452': 'deeptools_bamFingerprint',
#  '453': 'abims_xcms_xcmsSet',
#  '454': 'aragorn_trna',
#  '455': 'ete_genetree_splitter',
#  '456': 'fastqc',
#  '457': 'tp_sort_header_tool',
#  '458': 'sample_seqs',
#  '459': 'fastq_trimmer',
#  '460': 'mass_spectrometry_imaging_mzplots',
#  '461': 'gffcompare',
#  '462': 'mothur_homova',
#  '463': 'tsne',
#  '464': 'FeatureLinkerUnlabeled',
#  '465': 'sam_to_bam',
#  '466': 'heinz_scoring',
#  '467': 'cshl_multijoin',
#  '468': 'get_child_terms',
#  '469': 'mcClust',
#  '470': 'signalp3',
#  '471': 'gatk_indel_realigner',
#  '472': 'fasta_merge_files_and_filter_unique_sequences',
#  '473': 'vcffilter',
#  '474': 'fastq_combiner',
#  '475': 'snippy_core',
#  '476': 'sklearn_feature_selection',
#  '477': 'umi_tools_count',
#  '478': 'Remove beginning1',
#  '479': 'bedtools_bamtofastq',
#  '480': 't_coffee',
#  '481': 'stringtie_merge',
#  '482': 'circgraph',
#  '483': 'fasta_filter_by_length',
#  '484': 'tp_unfold_column_tool',
#  '485': 'metaphlan2',
#  '486': 'cardinal_preprocessing',
#  '487': 'deeptools_plot_pca',
#  '488': 'CONVERTER_Bam_Bai_0',
#  '489': 'cufflinks_prok',
#  '490': 'infernal_cmsearch',
#  '491': 'merge_pcr_duplicates.py',
#  '492': 'trimmer',
#  '493': 'Cut1',
#  '494': 'je_clip',
#  '495': 'FileFilter',
#  '496': 'r_correlation_matrix',
#  '497': 'TrimPrimer',
#  '498': 'rbc_rnacode',
#  '499': 'HighResPrecursorMassCorrector',
#  '500': 'varscan_somatic',
#  '501': 're_he_maldi_image_registration',
#  '502': 'infernal_cmstat',
#  '503': 'qiime_core_diversity',
#  '504': 'mothur_parsimony',
#  '505': 'mothur_count_seqs',
#  '506': 'mass_spectrometry_imaging_classification',
#  '507': 'cshl_fastx_barcode_splitter',
#  '508': 'CONVERTER_gff_to_interval_index_0',
#  '509': 'abims_xcms_group',
#  '510': 'velvetg_jgi',
#  '511': 'FROGS_affiliations_stat',
#  '512': 'DatamashOps',
#  '513': 'je_markdupes',
#  '514': 'iReport',
#  '515': 'combine_metaphlan2_humann2',
#  '516': 'mothur_summary_single',
#  '517': 'bismark_bowtie2',
#  '518': 'CONVERTER_bedgraph_to_bigwig',
#  '519': 'Filter1',
#  '520': 'proteomics_moff',
#  '521': 'pilon',
#  '522': 'gops_subtract_1',
#  '523': 'gff2bed1',
#  '524': 'EMBOSS: tranalign100',
#  '525': 'clustalw',
#  '526': 'mothur_seq_error',
#  '527': 'bams2ratio',
#  '528': 'tp_replace_in_line',
#  '529': '__FILTER_FAILED_DATASETS__',
#  '530': 'infernal_cmbuild',
#  '531': 'flexbar_split_RR_bcs',
#  '532': 'mothur_get_groups',
#  '533': 'mothur_phylotype',
#  '534': 'stacks_genotypes',
#  '535': 'Grep1',
#  '536': 'megahit',
#  '537': 'humann2_regroup_table',
#  '538': 'cshl_easyjoin',
#  '539': 'mothur_cluster_split',
#  '540': 'je_demultiplex',
#  '541': 'MzTabExporter',
#  '542': 'CONVERTER_interval_to_bgzip_0',
#  '543': 'gops_intersect_1',
#  '544': 'gops_concat_1',
#  '545': 'methtools_plot',
#  '546': 'addName',
#  '547': 'length_and_gc_content',
#  '548': 'tp_awk_tool',
#  '549': 'hicexplorer_hictransform',
#  '550': 'regex1',
#  '551': 'mz_to_sqlite',
#  '552': 'ncbi_blastx_wrapper',
#  '553': 'qiime_make_otu_heatmap',
#  '554': 'umi_tools_dedup',
#  '555': 'jbrowse',
#  '556': 'mycrobiota-correct-replicates',
#  '557': 'cardinal_quality_report',
#  '558': 'flexbar_split_RYYR_bcs',
#  '559': 'gff_filter_by_attribute',
#  '560': 'bedtools_annotatebed',
#  '561': 'mass_spectrometry_imaging_preprocessing',
#  '562': 'raceid_clustering',
#  '563': 'deeptools_plot_enrichment',
#  '564': 'w4mjoinpn',
#  '565': 'rm_spurious_events.py',
#  '566': 'picard_FixMateInformation',
#  '567': 'ggplot_histogram',
#  '568': 'p_clip_peaks',
#  '569': 'heinz_bum',
#  '570': 'bedtools_bedtobam',
#  '571': '__ZIP_COLLECTION__',
#  '572': 'bundle_collection',
#  '573': 'hisat',
#  '574': 'ctb_chemfp_mol2fps',
#  '575': 'openms_id_file_converter',
#  '576': 'gatk2_variant_recalibrator',
#  '577': 'rarefaction_analyzer',
#  '578': 'samtool_filter2',
#  '579': 'ip_projective_transformation',
#  '580': 'tag_stat2',
#  '581': 'tp_uniq_tool',
#  '582': 'picard_SortSam',
#  '583': 'maldi_quant_peak_detection',
#  '584': 'picard_MarkDuplicatesWithMateCigar',
#  '585': 'graphlan',
#  '586': 'MassCalculator',
#  '587': 'ggplot2_histogram',
#  '588': 'tmhmm2',
#  '589': 'umi_tools_whitelist',
#  '590': 'get_read_pipeline',
#  '591': 'seurat',
#  '592': 'GeMoMa_Annotation_Filter',
#  '593': 'ctb_simsearch',
#  '594': 'mothur_remove_groups',
#  '595': 'ia_coordinates_of_roi',
#  '596': 'macs2_callpeak',
#  '597': 'rgPicFixMate',
#  '598': 'fastq_paired_end_splitter',
#  '599': 'gemini_de_novo',
#  '600': 'cardinal_segmentations',
#  '601': 'smf_utils_estimate-energy',
#  '602': 'tp_find_and_replace',
#  '603': 'ruvseq',
#  '604': 'bigwig_to_bedgraph',
#  '605': 'bed_to_bigBed',
#  '606': 'cshl_fastx_renamer',
#  '607': 'peakachu',
#  '608': 'antismash',
#  '609': 'ChangeCase',
#  '610': 'bwameth',
#  '611': 'bowtie2',
#  '612': 'pileup_interval',
#  '613': 'rseqc_infer_experiment',
#  '614': 'goseq',
#  '615': 'dexseq_count',
#  '616': 'bwa_wrapper',
#  '617': 'vcfgenotypes',
#  '618': 'extract_element_from_collection',
#  '619': 'coords2clnt.py',
#  '620': 'bamleftalign',
#  '621': 'msgfplus',
#  '622': 'addValue',
#  '623': 'cshl_fastx_quality_statistics',
#  '624': 'picard_EstimateLibraryComplexity',
#  '625': 'EMBOSS: revseq82',
#  '626': 'enhanced_bowtie_wrapper',
#  '627': 'rarefaction',
#  '628': 'heinz',
#  '629': 'nonpareil',
#  '630': 'gemini_pathways',
#  '631': 'pileup_parser',
#  '632': 'hmmer_hmmbuild',
#  '633': 'rcas',
#  '634': 'velvet',
#  '635': 'gmx_npt',
#  '636': 'raceid_inspecttrajectory',
#  '637': 'genbank_to_gff',
#  '638': 'EMBOSS: wordcount109',
#  '639': 'mycrobiota-make-multi-otutable',
#  '640': 'deseq2_single',
#  '641': 'gatk2_variant_select',
#  '642': 'mothur_taxonomy_to_krona',
#  '643': 'stacks_populations',
#  '644': 'modencode_peakcalling_spp',
#  '645': 'dexseq',
#  '646': 'fastq_to_fasta_python',
#  '647': 'disco',
#  '648': 'tp_split_on_column',
#  '649': 'locarna_best_subtree',
#  '650': 'raceid_main',
#  '651': 'snpSift_filter',
#  '652': 'minimap2',
#  '653': 'mothur_venn',
#  '654': 'vcf_filter',
#  '655': 'term_id_vs_term_name',
#  '656': 'gtf_filter_by_attribute_values_list',
#  '657': 'gemini_load',
#  '658': 'gatk2_reduce_reads',
#  '659': 'CONVERTER_gz_to_uncompressed',
#  '660': 'stacks_denovomap',
#  '661': 'bgchem_fragment_merger',
#  '662': 'proteomics_search_protein_prophet_1',
#  '663': 'cuffquant',
#  '664': 'cshl_fastx_trimmer',
#  '665': 'bedtools_bamtobed',
#  '666': 'mothur_make_contigs',
#  '667': 'comp1',
#  '668': 'Add_a_column1',
#  '669': 'mothur_rarefaction_single',
#  '670': 'rbc_mirdeep2',
#  '671': 'term_id_vs_term_def',
#  '672': 'fastq_to_tabular',
#  '673': 'TrimByLength',
#  '674': 'sklearn_searchcv',
#  '675': 'selectsequencesfrommsa',
#  '676': 'maldi_quant_preprocessing',
#  '677': 'rbc_mirdeep2_mapper',
#  '678': 'tp_tac',
#  '679': 'IDFilter',
#  '680': 'macs2_predictd',
#  '681': 'w4mclstrpeakpics',
#  '682': 'mothur_heatmap_bin',
#  '683': 'idpquery',
#  '684': 'thermo_raw_file_converter',
#  '685': 'bedtools_unionbedgraph',
#  '686': 'sam_bw_filter',
#  '687': 'eden_vectorizer',
#  '688': 'ncbi_rpsblast_wrapper',
#  '689': 'rseqc_read_duplication',
#  '690': 'velveth_jgi',
#  '691': 'cuffnorm',
#  '692': 'flexbardsc',
#  '693': 'prokaryotic_ncbi_submission',
#  '694': 'rseqc_bam2wig',
#  '695': 'varscan_mpileup',
#  '696': 'blockbuster',
#  '697': 'stringtie',
#  '698': '__FILTER_FROM_FILE__',
#  '699': 'bed2gff1',
#  '700': 'gatk_unified_genotyper',
#  '701': 'gafa',
#  '702': 'bam_to_bigwig',
#  '703': 'bamCompare_deepTools',
#  '704': 'cshl_fastx_artifacts_filter',
#  '705': 'cshl_grep_tool',
#  '706': 'roary',
#  '707': 'dt_profiler',
#  '708': 'wsdl_hmdb',
#  '709': 'sklear_numeric_clustering',
#  '710': 'gffread',
#  '711': 'vcftools_isec',
#  '712': 'tophat2',
#  '713': 'CONVERTER_interval_to_bed_0',
#  '714': 'bcftools_call',
#  '715': 'cshl_fastx_nucleotides_distribution',
#  '716': 'gemini_windower',
#  '717': 'picard_SamToFastq',
#  '718': 'datamash_ops',
#  '719': 'computeMatrix',
#  '720': 'idr-embl',
#  '721': 'sklearn_svm_classifier',
#  '722': 'Datamash',
#  '723': 'deeptools_bigwigCompare',
#  '724': 'vegan_rarefaction',
#  '725': 'gatk2_variant_filtration',
#  '726': 'proteomics_search_tandem_1',
#  '727': 'segemehl',
#  '728': 'XY_Plot_1',
#  '729': 'convert_bc_to_binary_RY.py',
#  '730': 'translate_bed_sequences',
#  '731': 'qiime_pick_open_reference_otus',
#  '732': 'meme_psp_gen',
#  '733': 'random_lines1',
#  '734': 'htseq_count',
#  '735': 'silac_analyzer',
#  '736': 'gops_join_1',
#  '737': 'ggplot_point',
#  '738': 'mothur_nmds',
#  '739': 'cshl_fasta_formatter',
#  '740': 'export2graphlan',
#  '741': 'gtftobed12',
#  '742': 'trimmomatic',
#  '743': 'seq_filter_by_id',
#  '744': 'RNAlien',
#  '745': '__UNZIP_COLLECTION__',
#  '746': 'IDPosteriorErrorProbability',
#  '747': 'vsearch_dereplication',
#  '748': 'picard_AddOrReplaceReadGroups',
#  '749': 'minfi_getbeta',
#  '750': 'vcffixup',
#  '751': 'mothur_lefse',
#  '752': 'deeptools_plot_fingerprint',
#  '753': 'qiime_align_seqs',
#  '754': 'picard_NormalizeFasta',
#  '755': 'mycrobiota-otutable_add_blast',
#  '756': 'smooth_running_window',
#  '757': 'structure_to_gspan',
#  '758': 'transpose',
#  '759': 'mothur_pre_cluster',
#  '760': 'meme_chip',
#  '761': 'hicexplorer_hicplottads',
#  '762': 'seq_filter_by_mapping',
#  '763': 'bwa_mem',
#  '764': 'gmx_setup',
#  '765': 'minfi_read450k',
#  '766': 'bedtools_multiintersectbed',
#  '767': 'dunovo',
#  '768': 'macs2_bdgcmp',
#  '769': 'picard_MergeSamFiles',
#  '770': 'gemini_interactions',
#  '771': 'picard_MarkDuplicates',
#  '772': 'ucsc-twobittofa',
#  '773': 'cardinal_combine',
#  '774': 'blast_parser',
#  '775': 'createInterval',
#  '776': 'graphicsmagick_image_convert',
#  '777': 'bg_sortmerna',
#  '778': 'rsem_prepare_reference',
#  '779': 'chipseeker',
#  '780': 'mothur_get_oturep',
#  '781': 'fasta2tab',
#  '782': 'viz_overlay_moving_and_fixed_image',
#  '783': 'rseqc_junction_saturation',
#  '784': 'ctb_remIons',
#  '785': 'cardinal_mz_images',
#  '786': 'heinz_visualization',
#  '787': 'ChooseTag',
#  '788': 'blastxml_to_tabular',
#  '789': 'barchart_gnuplot',
#  '790': 'minfi_mset',
#  '791': 'SequenceCoverageCalculator',
#  '792': 'smf_utils_fix-fasta-headers',
#  '793': 'FalseDiscoveryRate',
#  '794': 'FROGS_affiliation_OTU',
#  '795': 'predict_pipeline',
#  '796': 'minfi_dmr',
#  '797': 'bg_diamond',
#  '798': 'secure_hash_message_digest',
#  '799': 'gemini_comp_hets',
#  '800': 'mothur_trim_seqs',
#  '801': 'samtools_stats',
#  '802': 'cshl_cut_tool',
#  '803': 'decoyfasta',
#  '804': 'dexseq_annotate',
#  '805': 'lastz_wrapper_2',
#  '806': 'annotatemyids',
#  '807': 'mass_spectrometry_imaging_ion_images',
#  '808': 'ctb_silicos_qed',
#  '809': 'deeptools_plot_profile',
#  '810': 'FeatureLinkerUnlabeledKD',
#  '811': 'bedtools_subtractbed',
#  '812': 'Interval_Maf_Merged_Fasta2',
#  '813': 'FeatureFinderMultiplex',
#  '814': 'Nucleosome',
#  '815': 'bed_to_bigwig',
#  '816': 'query_tabular',
#  '817': 'cardinal_spectra_plots',
#  '818': 'wig_to_bigWig',
#  '819': 'mothur_get_seqs',
#  '820': 'methtools_dmr',
#  '821': 'humann2_genefamilies_genus_level',
#  '822': 'ctb_ob_genProp',
#  '823': 'CONVERTER_sam_to_unsorted_bam',
#  '824': 'hicexplorer_hiccorrectmatrix',
#  '825': 'FastTree',
#  '826': 'glimmer_not-knowlegde-based',
#  '827': 'lfq_protein_quant',
#  '828': 'mothur_classify_seqs',
#  '829': 'mothur_corr_axes',
#  '830': 'deeptools_multi_bam_summary',
#  '831': 'deeptools_plot_heatmap',
#  '832': '__FLATTEN__',
#  '833': 'FileInfo',
#  '834': 'viennarna_rnaplot',
#  '835': 'racon',
#  '836': 'multiqc',
#  '837': 'gff_to_sequence',
#  '838': 'tp_multijoin_tool',
#  '839': 'bamFilter',
#  '840': 'NFS_transfer',
#  '841': 'sklearn_numeric_clustering',
#  '842': 'cshl_fastq_quality_boxplot',
#  '843': 'trim_reads',
#  '844': 'cshl_fasta_nucleotides_changer',
#  '845': 'deeptools_multi_bigwig_summary',
#  '846': 'bedtools_complementbed',
#  '847': 'mothur_tree_shared',
#  '848': 'bg_uniq',
#  '849': 'samtools_mpileup',
#  '850': 'minfi_rset',
#  '851': 'PicardASMetrics',
#  '852': 'ggplot2_heatmap',
#  '853': 'vcfannotate',
#  '854': 'mothur_summary_seqs',
#  '855': 'ncbi_tblastn_wrapper',
#  '856': 'ctb_compound_convert',
#  '857': 'openms_protein_quantifier',
#  '858': 'vcftools_merge',
#  '859': 'minfi_getanno',
#  '860': 'gtf2bedgraph',
#  '861': 'deeptools_plot_coverage',
#  '862': 'histogram_rpy',
#  '863': 'cmv',
#  '864': 'pynast',
#  '865': 'megablast_wrapper',
#  '866': 'ncbi_blastn_wrapper',
#  '867': 'w4mclassfilter',
#  '868': 'raceid_trajectory',
#  '869': 'deseq2',
#  '870': 'rbc_splitfasta',
#  '871': 'deeptools_compute_matrix',
#  '872': 'hgv_snpFreq',
#  '873': 'deeptools_bamCorrelate',
#  '874': 'deeptools_profiler',
#  '875': 'wiggle2simple1',
#  '876': 'MapStatistics',
#  '877': 'bctools_remove_spurious_events',
#  '878': 'vcfbedintersect',
#  '879': 'uparse',
#  '880': 'FileMerger',
#  '881': 'mothur_chimera_vsearch',
#  '882': 'uniprot',
#  '883': 'mass_spectrometry_imaging_segmentations',
#  '884': 'qiime_validate_mapping_file',
#  '885': 'PicardInsertSize',
#  '886': 'cshl_fastx_collapser',
#  '887': 'Draw_phylogram',
#  '888': 'CONVERTER_bed_gff_or_vcf_to_bigwig_0',
#  '889': 'qiime_make_phylogeny',
#  '890': 'EMBOSS: textsearch98',
#  '891': 'minfi_qc',
#  '892': 'tp_sorted_uniq',
#  '893': 'ctb_remSmall',
#  '894': 'MapRTTransformer',
#  '895': 'cummeRbund',
#  '896': 'gops_merge_1',
#  '897': 'sam_merge2',
#  '898': 'aggregate_scores_in_intervals2',
#  '899': 'vcfflatten2',
#  '900': 'tp_sort_rows',
#  '901': 'quast',
#  '902': 'limma_voom',
#  '903': '__APPLY_RULES__',
#  '904': 'tp_head_tool',
#  '905': 'varscan_copynumber',
#  '906': 'hmmer_hmmsearch',
#  '907': 't2t_report',
#  '908': 'mycrobiota-krona-mothur',
#  '909': 'mothur_get_communitytype',
#  '910': 'tab2fasta',
#  '911': 'deeptools_bam_coverage',
#  '912': 'DatamashTranspose',
#  '913': 'rseqc_read_distribution',
#  '914': 'plotly_regression_performance_plots',
#  '915': 'msconvert3_raw',
#  '916': 'lca1',
#  '917': 'stacks_procrad',
#  '918': 'rsem_calculate_expression',
#  '919': 'samtools_flag_filter',
#  '920': 'idpassemble',
#  '921': 'datamash_transpose',
#  '922': 'pureclip',
#  '923': 'sequence_content_trimmer',
#  '924': 'EMBOSS: extractseq35',
#  '925': 'mothur_unique_seqs',
#  '926': 'mothur_remove_seqs',
#  '927': 'iuc_pear',
#  '928': 'heatmap2',
#  '929': 'IsobaricAnalyzer',
#  '930': 'gops_cluster_1',
#  '931': 'qiime_pick_otus',
#  '932': 'w4mcorcov',
#  '933': 'picard_CASM',
#  '934': 'Summary_Statistics1',
#  '935': 'get_flanks1',
#  '936': 'samtools_rmdup',
#  '937': 'sickle',
#  '938': 'cshl_sed_tool',
#  '939': 'EMBOSS: newseq59',
#  '940': 'cmFinder',
#  '941': 'flexbar',
#  '942': 'gatk2_unified_genotyper',
#  '943': 'gmx_md',
#  '944': 'goslimmer',
#  '945': 'ggplot2_heatmap2',
#  '946': 'snpSift_dbnsfp_generic',
#  '947': 'gd_raxml',
#  '948': 'Count1',
#  '949': 'blast2go',
#  '950': 'cshl_find_and_replace',
#  '951': 'fastq collapser',
#  '952': 'MapAlignerPoseClustering',
#  '953': 'rmcontamination',
#  '954': 'snpsift_vartype',
#  '955': 'make_families',
#  '956': 'correct_barcodes',
#  '957': 'bedtools_getfastabed',
#  '958': 'cd_hit_dup',
#  '959': 'ProteinResolver',
#  '960': 'gmx_nvt',
#  '961': 'graphlan_annotate',
#  '962': 'idpqonvert',
#  '963': 'tp_replace_in_column',
#  '964': 'search_gui',
#  '965': 'abricate',
#  '966': 'plotly_parallel_coordinates_plot',
#  '967': 'cat1',
#  '968': 'format_metaphlan2_output',
#  '969': 'augustus',
#  '970': 'mothur_sub_sample',
#  '971': 'gspan'}

# %%
def verify_model(model, tool_sequence, labels, dictionary, reverse_dictionary, compatible_tools, topk=20, max_seq_len=25):
    tl_seq = tool_sequence.split(",")
    last_tool_name = reverse_dictionary[str(tl_seq[-1])]
    last_compatible_tools = compatible_tools[last_tool_name]
    sample = np.zeros(max_seq_len)
    for idx, tool_id in enumerate(tl_seq):
        sample[idx] = int(tool_id)
    sample_reshaped = np.reshape(sample, (1, max_seq_len))
    
    tool_sequence_names = [reverse_dictionary[str(tool_pos)] for tool_pos in tool_sequence.split(",")]
    print("Tool seq: %s" % ",".join(tool_sequence_names))
    # predict next tools for a test path
    prediction = model.predict(sample_reshaped, verbose=0)
    prediction = np.reshape(prediction, (prediction.shape[1],))
    prediction_pos = np.argsort(prediction, axis=-1)

    # get topk prediction
    topk_prediction_pos = prediction_pos[-topk:]
    topk_prediction_val = [np.round(prediction[pos] * 100, 2) for pos in topk_prediction_pos]

    # read tool names using reverse dictionary
    pred_tool_ids = [reverse_dictionary[str(tool_pos)] for tool_pos in topk_prediction_pos]
    actual_next_tool_ids = list(set(pred_tool_ids).intersection(set(last_compatible_tools.split(","))))      
        
    #print("Predicted tools: %s" % ",".join(pred_tool_ids))
    print()
    pred_tool_ids_sorted = dict()
    for (tool_pos, tool_pred_val) in zip(topk_prediction_pos, topk_prediction_val):
        tool_name = reverse_dictionary[str(tool_pos)]
        if tool_name in actual_next_tool_ids:
            pred_tool_ids_sorted[tool_name] = tool_pred_val
    pred_tool_ids_sorted = dict(sorted(pred_tool_ids_sorted.items(), key=lambda kv: kv[1], reverse=True))
    
    cls_wt = dict()
    usg_wt = dict()
    inv_wt = dict()
    ids_tools = dict()
    keys = list(pred_tool_ids_sorted.keys())
    for k in keys:
        try:
            cls_wt[k] = np.round(class_weights[str(data_dict[k])], 2)
            usg_wt[k] = np.round(usage_weights[k], 2)
            inv_wt[k] = np.round(inverted_weights[str(data_dict[k])], 2)
        except:
            continue
    print("Predicted tools: \n")
    print(pred_tool_ids_sorted)
    print()
    print("Class weights: \n")
    cls_wt = dict(sorted(cls_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(cls_wt)
    print()
    print("Usage weights: \n")
    usg_wt = dict(sorted(usg_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(usg_wt)
    print()
    total_usage_wt = np.mean(list(usg_wt.values()))
    print("Mean usage wt: %0.4f" % (total_usage_wt))
    print()
    print("Inverted weights: \n")
    inv_wt = dict(sorted(inv_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(inv_wt)
    for key in pred_tool_ids_sorted:
        ids_tools[key] = dictionary[key]
    print()
    print("Tool ids")
    print(ids_tools)
    print("======================================")
    return cls_wt, usg_wt, inv_wt, pred_tool_ids_sorted

topk = 10
tool_seq = "254"
class_wt, usage_wt, inverse_wt, pred_tools = verify_model(model, tool_seq, "", dictionary, reverse_dictionary, compatibile_tools, topk)
# Out:
# Tool seq: preproc
#
# Predicted tools:
#
# {'glob_report': 41.17, 'graphclust_glob_report_no_align': 9.02, 'infernal_cmsearch': 1.86, 'locarna_best_subtree': 1.09, 'preMloc': 0.64, 'NSPDK_candidateClust': 0.54}
#
# Class weights:
#
# {'NSPDK_candidateClust': 17539.62, 'preMloc': 8773.12, 'locarna_best_subtree': 8732.96, 'graphclust_glob_report_no_align': 5845.33, 'infernal_cmsearch': 2850.96, 'glob_report': 2071.64}
#
# Usage weights:
#
# {'infernal_cmsearch': 763.69, 'locarna_best_subtree': 763.42, 'glob_report': 32.92, 'preMloc': 6.62, 'NSPDK_candidateClust': 6.62, 'graphclust_glob_report_no_align': 1.0}
#
# Mean usage wt: 262.3783
#
# Inverted weights:
#
# {'NSPDK_candidateClust': 17533.0, 'preMloc': 8766.5, 'locarna_best_subtree': 7969.55, 'graphclust_glob_report_no_align': 5844.33, 'infernal_cmsearch': 2087.26, 'glob_report': 2038.72}
#
# Tool ids
# {'glob_report': 131, 'graphclust_glob_report_no_align': 190, 'infernal_cmsearch': 490, 'locarna_best_subtree': 649, 'preMloc': 47, 'NSPDK_candidateClust': 3}
# ======================================

# %%
list_cls_wt = list()
list_usage_wt = list()
list_pred_wt = list()
list_inv_wt = list()
division_pt = int(len(pred_tools) / 2)

for tool in pred_tools:
    list_pred_wt.append(pred_tools[tool])
    #try:
    list_inv_wt.append(inverse_wt[tool])
    list_usage_wt.append(usage_wt[tool])
    #except:
    #list_inv_wt.append(1)

def plot_scatter(y_val, title, xlabel, ylabel):
    x_val = range(1, len(y_val) + 1)
    plt.figure(figsize=(8, 8))
    plt.plot(x_val[:division_pt], y_val[:division_pt], 'ro')
    plt.plot(x_val[division_pt:], y_val[division_pt:], 'b^')
    plt.xlabel(xlabel, size=size_label)
    plt.ylabel(ylabel, size=size_label)
    plt.legend([("First top-%s" % str(division_pt)), ("Next top-%s" % str(division_pt))])
    plt.title(title, size=size_title)
    plt.grid(True)
    plt.show()

plot_scatter(list_usage_wt, "Usage weights for tools", "Number of tools", "Class weights")
#plot_scatter(ave_prediction_weights, ave_usage_weights, "Prediction vs usage weights", "Prediction scores", "Usage weights")
#plot_scatter(ave_prediction_weights, ave_inverted_weights, "Prediction vs inverted weights", "Prediction scores", "Inverted weights")
