# %%
import numpy as np
import json
import warnings
import operator

import h5py
from keras.models import model_from_json
from keras import backend as K

from matplotlib import pyplot as plt

warnings.filterwarnings("ignore")

size_title = 18
size_label = 14
n_pred = 2 

base_path = "data/evaluate_usage_softmax_22_03/" # cluster path: 1_similar_galaxy_workflow

path_data_dict = base_path + "data_dict.txt"
#path_inverted_wt = base_path + "inverted_weights.txt"
path_usage_wt = base_path + "usage_prediction.txt"
path_class_wt = base_path + "class_weights.txt"
path_test_data = base_path + "test_paths_dict.txt"
model_path = base_path + "trained_model.hdf5"

def read_file(file_path):
    with open(file_path, 'r') as data_file:
        data = json.loads(data_file.read())
    return data

class_weights = read_file(path_class_wt)
usage_weights = read_file(path_usage_wt)
#inverted_weights = read_file(path_inverted_wt)
data_dict = read_file(path_data_dict)

def create_model(model_path):
    trained_model = h5py.File(model_path, 'r')
    model_config = json.loads(trained_model.get('model_config').value)
    loaded_model = model_from_json(model_config)
    dictionary = json.loads(trained_model.get('data_dictionary').value)
    compatibile_tools = json.loads(trained_model.get('compatible_tools').value)
    reverse_dictionary = dict((str(v), k) for k, v in dictionary.items())
    model_weights = list()
    weight_ctr = 0
    while True:
        try:
            d_key = "weight_" + str(weight_ctr)
            weights = trained_model.get(d_key).value
            model_weights.append(weights)
            weight_ctr += 1
        except Exception as exception:
            break
    # set the model weights
    loaded_model.set_weights(model_weights)
    return loaded_model, dictionary, reverse_dictionary, compatibile_tools

model, dictionary, reverse_dictionary, compatibile_tools = create_model(model_path)
# Out:
# Using TensorFlow backend.

# %%
reverse_dictionary
# Out:
# {'1': 'cummeRbund',
#  '2': 'rseqc_read_distribution',
#  '3': 'flexbar_no_split',
#  '4': 'bed_to_bigBed',
#  '5': 'rgPicFixMate',
#  '6': 'EMBOSS: newseq59',
#  '7': 'blastxml_to_tabular',
#  '8': 'proteomics_moff',
#  '9': 'tp_easyjoin_tool',
#  '10': 'correct_barcodes',
#  '11': 'treebest_best',
#  '12': 'idpassemble',
#  '13': 'cmv',
#  '14': 'egsea',
#  '15': 'bedtools_map',
#  '16': 'mothur_align_seqs',
#  '17': 'ctb_ob_genProp',
#  '18': 'qiime_align_seqs',
#  '19': 'quast',
#  '20': 'tp_multijoin_tool',
#  '21': '16Saligner',
#  '22': 'snpSift_dbnsfp_generic',
#  '23': 'gemini_query',
#  '24': 'deeptools_bigwigCompare',
#  '25': 'filtlong',
#  '26': 'gemini_pathways',
#  '27': 'SequenceCoverageCalculator',
#  '28': 'bedtools_intersectbed',
#  '29': 'bamFilter',
#  '30': 'sed_stream_editor',
#  '31': 'rseqc_bam_stat',
#  '32': 'ctb_change_title',
#  '33': 'aragorn_trna',
#  '34': 'deeptools_plot_pca',
#  '35': 'vcftools_annotate',
#  '36': 'peakcalling_macs14',
#  '37': 'get_flanks1',
#  '38': 'tsne',
#  '39': 'blastxml_to_tabular_selectable',
#  '40': 'comp1',
#  '41': 'ncbi_makeblastdb',
#  '42': 'biosigner',
#  '43': 'TrimByN',
#  '44': 'Nucleosome',
#  '45': 'msconvert_nix',
#  '46': 'velveth_jgi',
#  '47': 'bedtools_multiintersectbed',
#  '48': 'ChangeCase',
#  '49': 'mothur_chimera_vsearch',
#  '50': 'mycrobiota-split-multi-otutable',
#  '51': 'gemini_annotate',
#  '52': 'filter_bed_on_splice_junctions',
#  '53': 'cshl_fastx_clipper',
#  '54': 'get_read_pipeline',
#  '55': 'FeatureFinderMetabo',
#  '56': 'cardinal_segmentations',
#  '57': 'datamash_ops',
#  '58': '16Sclassifier',
#  '59': 'bcftools_consensus',
#  '60': 'cshl_easyjoin',
#  '61': 'bedtools_unionbedgraph',
#  '62': 'augustus',
#  '63': 'cshl_fastq_quality_boxplot',
#  '64': 'goenrichment',
#  '65': 'secure_hash_message_digest',
#  '66': 'qiime_validate_mapping_file',
#  '67': 'gemini_comp_hets',
#  '68': 'mothur_unique_seqs',
#  '69': 'samtools_flagstat',
#  '70': 'newick_display',
#  '71': 'vegan_diversity',
#  '72': 'IDConflictResolver',
#  '73': 'cshl_fastx_nucleotides_distribution',
#  '74': 'cufflinks_prok',
#  '75': 'mothur_make_group',
#  '76': 'smooth_running_window',
#  '77': 'seq_composition',
#  '78': 'spades',
#  '79': 'Add_a_column1',
#  '80': 'xcms_merge',
#  '81': 'IDPosteriorErrorProbability',
#  '82': 'merge_pcr_duplicates.py',
#  '83': 'abricate',
#  '84': 'fragmenter',
#  '85': 'addName',
#  '86': 'FROGS_preprocess',
#  '87': 'remove_tail.py',
#  '88': 'mothur_screen_seqs',
#  '89': 'graphclust_glob_report_no_align',
#  '90': 'bedtools_sortbed',
#  '91': 'deseq2',
#  '92': 'cummerbund_to_cuffdiff',
#  '93': 'deeptools_bamCoverage',
#  '94': 'hicexplorer_hicsummatrices',
#  '95': 'trim_reads',
#  '96': 'jbrowse',
#  '97': 'metaphlan_hclust_heatmap',
#  '98': 'bedtools_multicovtbed',
#  '99': 'metaspades',
#  '100': 'mothur_pcoa',
#  '101': 'sklearn_feature_selection',
#  '102': 'ctb_online_data_fetch',
#  '103': 'rseqc_read_duplication',
#  '104': 'wiggle2simple1',
#  '105': 'vt_normalize',
#  '106': 'deeptools_plot_enrichment',
#  '107': 'EMBOSS: geecee41',
#  '108': 'mimodd_varcall',
#  '109': 'mothur_homova',
#  '110': 'eden_sequence_converter',
#  '111': 'mothur_corr_axes',
#  '112': 'bamCompare_deepTools',
#  '113': 'cshl_fasta_nucleotides_changer',
#  '114': 'sequence_content_trimmer',
#  '115': 'picard_CleanSam',
#  '116': 'bedtools_intersectbed_bam',
#  '117': 'mothur_seq_error',
#  '118': 'sklearn_svm_classifier',
#  '119': 'CONVERTER_bed_gff_or_vcf_to_bigwig_0',
#  '120': 'picard_NormalizeFasta',
#  '121': 'sqlite_to_tabular',
#  '122': 'Cut1',
#  '123': 'diffbind-embl',
#  '124': 'kraken-translate',
#  '125': 'gmx_md',
#  '126': 'mothur_amova',
#  '127': '__SORTLIST__',
#  '128': 'gbk_to_orf',
#  '129': 'sklearn_numeric_clustering',
#  '130': 'idpqonvert',
#  '131': 'msconvert2_raw',
#  '132': 'collection_column_join',
#  '133': 'gmx_npt',
#  '134': 'cat1',
#  '135': 'checkFormat',
#  '136': 'bctools_remove_tail',
#  '137': 'cshl_fastx_artifacts_filter',
#  '138': 'mothur_phylotype',
#  '139': 'openms_id_mapper',
#  '140': 'length_and_gc_content',
#  '141': 'TextExporter',
#  '142': 'svm_classifier',
#  '143': 'tophat',
#  '144': 'bismark_bowtie2',
#  '145': 'varscan_mpileup',
#  '146': 'cardinal_spectra_plots',
#  '147': 'convert_bc_to_binary_RY.py',
#  '148': 'selectsequencesfrommsa',
#  '149': 'EMBOSS: revseq82',
#  '150': 'wolf_psort',
#  '151': 'vcfannotate',
#  '152': 'fraggenescan',
#  '153': 'rnafold',
#  '154': 'cmFinder',
#  '155': 'deeptools_plot_profile',
#  '156': '__ZIP_COLLECTION__',
#  '157': 'velvetg_jgi',
#  '158': 'gff_to_sequence',
#  '159': 'idr-embl',
#  '160': 'uniprot',
#  '161': '__FLATTEN__',
#  '162': 'stacks_refmap',
#  '163': 'enhanced_bowtie_wrapper',
#  '164': 'signalp3',
#  '165': 'gemini_windower',
#  '166': 'mothur_cluster_split',
#  '167': 'dexseq',
#  '168': 'vcfflatten2',
#  '169': 'humann2_renorm_table',
#  '170': 'minfi_dmp',
#  '171': 'samtools_stats',
#  '172': 'qiime_core_diversity',
#  '173': 'ggplot2_point',
#  '174': 'FastTree',
#  '175': 'nanoplot',
#  '176': '__RELABEL_FROM_FILE__',
#  '177': 'mothur_tree_shared',
#  '178': 'pileup_interval',
#  '179': 'mass_spectrometry_imaging_ion_images',
#  '180': 'bg_diamond',
#  '181': 'ctb_remSmall',
#  '182': 'EMBOSS: seqret84',
#  '183': 'interproscan',
#  '184': 'scale_image',
#  '185': 'mimodd_varextract',
#  '186': 'stringtie_merge',
#  '187': 'regex1',
#  '188': 'cshl_word_list_grep',
#  '189': 'cshl_fasta_formatter',
#  '190': 'PeakPickerHiRes',
#  '191': 'fastq_combiner',
#  '192': 'msgfplus',
#  '193': 'bismark_bowtie',
#  '194': 'rnbeads',
#  '195': 'ip_projective_transformation',
#  '196': 'kallisto_quant',
#  '197': 'thermo_raw_file_converter',
#  '198': 'tp_sort_rows',
#  '199': 'flexbardsc',
#  '200': 'peakcalling_macs',
#  '201': 'mass_spectrometry_imaging_filtering',
#  '202': 'minfi_dropsnp',
#  '203': 'kraken-report',
#  '204': 'Interval_Maf_Merged_Fasta2',
#  '205': 'picard_CollectInsertSizeMetrics',
#  '206': 'Multivariate',
#  '207': 'GeMoMa_Annotation_Filter',
#  '208': 'tophat_fusion_post',
#  '209': 'cshl_multijoin',
#  '210': 'EMBOSS: transeq101',
#  '211': 'mothur_remove_groups',
#  '212': 'fasttree',
#  '213': 'mothur_make_contigs',
#  '214': 'FROGS_affiliation_OTU',
#  '215': 'rnaz',
#  '216': 'mycrobiota-make-multi-otutable',
#  '217': 'Digestor',
#  '218': 'sam_pileup',
#  '219': 'picard_MarkDuplicates',
#  '220': 'raceid_inspecttrajectory',
#  '221': 'gspan',
#  '222': 'Datamash',
#  '223': 'minfi_read450k',
#  '224': 'rm_spurious_events.py',
#  '225': 'fasta-stats',
#  '226': 'ChooseTag',
#  '227': 'ctb_filter',
#  '228': 'tp_sort_header_tool',
#  '229': 'decoyfasta',
#  '230': 'gemini_actionable_mutations',
#  '231': 'velvetoptimiser',
#  '232': 'samtools_slice_bam',
#  '233': 'naive_variant_caller',
#  '234': 'minfi_maptogenome',
#  '235': 'tp_find_and_replace',
#  '236': 'gops_cluster_1',
#  '237': 'random_lines1',
#  '238': 'deseq2_single',
#  '239': 'gops_coverage_1',
#  '240': 'modencode_peakcalling_spp',
#  '241': 'w4mclstrpeakpics',
#  '242': 'mass_spectrometry_imaging_classification',
#  '243': 'sailfish',
#  '244': 'macs2_callpeak',
#  '245': 'Remove_ending',
#  '246': 'column_remove_by_header',
#  '247': 'rarefaction',
#  '248': 'ip_projective_transformation_points',
#  '249': 'graphclust_align_cluster',
#  '250': 't2t_report',
#  '251': 'picard_FilterSamReads',
#  '252': 'Btrim64',
#  '253': 'sort1',
#  '254': 'featurecounts',
#  '255': 'hgv_david',
#  '256': 'minimap2',
#  '257': 'bedtools_windowbed',
#  '258': 'ProteinInference',
#  '259': 'methtools_tiling',
#  '260': 'mass_spectrometry_imaging_combine',
#  '261': 'mothur_summary_single',
#  '262': 'sample_seqs',
#  '263': 'bctools_extract_crosslinked_nucleotides',
#  '264': 'maldi_quant_preprocessing',
#  '265': 'openms_id_file_converter',
#  '266': 'CONVERTER_gff_to_interval_index_0',
#  '267': 'gatk_depth_of_coverage',
#  '268': 'velvet',
#  '269': 'mothur_classify_otu',
#  '270': 'secretbt2test',
#  '271': 'CONVERTER_interval_to_bed_0',
#  '272': 'blast2go',
#  '273': 'je_clip',
#  '274': '__MERGE_COLLECTION__',
#  '275': 'freebayes',
#  '276': 'w4mjoinpn',
#  '277': 'varscan_copynumber',
#  '278': 'rbc_mirdeep2_quantifier',
#  '279': 'MAF_To_Fasta1',
#  '280': 'fastq_quality_trimmer',
#  '281': 'IDScoreSwitcher',
#  '282': 'pileup_parser',
#  '283': 'samtools_calmd',
#  '284': 'tp_tail_tool',
#  '285': 'tp_head_tool',
#  '286': 'gmx_setup',
#  '287': 'deeptools_bam_coverage',
#  '288': 'blast_parser',
#  '289': 'IDFileConverter',
#  '290': 'picard_SamToFastq',
#  '291': 'IDMassAccuracy',
#  '292': 'find_in_reference',
#  '293': 'vcffilter',
#  '294': 'gops_subtract_1',
#  '295': 'picard_MarkDuplicatesWithMateCigar',
#  '296': 'dt_profiler',
#  '297': 'deeptools_profiler',
#  '298': 'gops_merge_1',
#  '299': 'meme_psp_gen',
#  '300': 'Flash',
#  '301': 'hicexplorer_hicfindtads',
#  '302': 'ConsensusMapNormalizer',
#  '303': 'iuc_pear',
#  '304': 'structure_to_gspan',
#  '305': 'megahit',
#  '306': 'rseqc_inner_distance',
#  '307': 'circgraph',
#  '308': 'heinz_visualization',
#  '309': 'bedtools_intersectBed',
#  '310': 'tp_replace_in_column',
#  '311': 'cshl_find_and_replace',
#  '312': '__APPLY_RULES__',
#  '313': 'mothur_venn',
#  '314': 'cardinal_filtering',
#  '315': 'megablast_xml_parser',
#  '316': 'methtools_filter',
#  '317': 'heatmap2',
#  '318': 'translate_bed_sequences',
#  '319': 'resistome_analyzer',
#  '320': 'edger',
#  '321': 'trimmomatic',
#  '322': 'minfi_mset',
#  '323': 'vcfgenotypes',
#  '324': 'mass_spectrometry_imaging_preprocessing',
#  '325': 'cuffcompare',
#  '326': 'picard_CASM',
#  '327': 'locarna_best_subtree',
#  '328': 'picard_MergeSamFiles',
#  '329': 'smf_utils_find-boxes',
#  '330': 'mothur_get_groups',
#  '331': 'hisat2',
#  '332': 'ExtractFASTAfromFASTQ',
#  '333': 'snpSift_geneSets',
#  '334': 'CONVERTER_interval_to_bedstrict_0',
#  '335': 'get_subontology_from',
#  '336': 'DatamashOps',
#  '337': 'samtools_bedcov',
#  '338': 'picard_SortSam',
#  '339': 'bwa_mem',
#  '340': 'bctools_extract_alignment_ends',
#  '341': 'bedtools_annotatebed',
#  '342': 'gemini_load',
#  '343': 'umi_tools_group',
#  '344': 'datamash_transpose',
#  '345': 'tp_split_on_column',
#  '346': 'export2graphlan',
#  '347': 'mothur_filter_seqs',
#  '348': 'deeptools_bigwig_compare',
#  '349': 'rbc_mafft',
#  '350': 'preMloc',
#  '351': 'FeatureFinderMultiplex',
#  '352': 'get_feature_info',
#  '353': 'FROGS_filters',
#  '354': 'bedtools_bamtobed',
#  '355': '__FILTER_FAILED_DATASETS__',
#  '356': 'mothur_get_seqs',
#  '357': 'predict_pipeline',
#  '358': 'snpfinder',
#  '359': 'cshl_cut_tool',
#  '360': 'bedtools_genomecoveragebed_histogram',
#  '361': 'pileometh',
#  '362': 'snpEff_download',
#  '363': 'EMBOSS: textsearch98',
#  '364': 'gatk_realigner_target_creator',
#  '365': 'venn_list',
#  '366': 'melt',
#  '367': 'graphclust_aggregate_alignments',
#  '368': 'tag_stat2',
#  '369': 'tophat2',
#  '370': 'qiime_make_phylogeny',
#  '371': 'Paste1',
#  '372': 'snpeff_to_peptides',
#  '373': 'lca1',
#  '374': 'mothur_merge_files',
#  '375': 'prokaryotic_ncbi_submission',
#  '376': 'fastq_paired_end_joiner',
#  '377': 'barchart_gnuplot',
#  '378': 'deeptools_plot_correlation',
#  '379': 'humann2_regroup_table',
#  '380': 'rbc_mirdeep2',
#  '381': 'samtools_filter',
#  '382': 'ngsutils_bam_filter',
#  '383': 'gatk2_depth_of_coverage',
#  '384': 'ruvseq',
#  '385': 'Show tail1',
#  '386': 'infernal_cmsearch',
#  '387': 'Grouping1',
#  '388': 'smf_utils_estimate-energy',
#  '389': 'gatk2_print_reads',
#  '390': 'gafa',
#  '391': 'metaphlan2',
#  '392': 'antismash',
#  '393': 'EMBOSS: water107',
#  '394': 'Univariate',
#  '395': 'htseq-count',
#  '396': 'bg_protein_properties',
#  '397': 'stacks_procrad',
#  '398': 'fastq_dump',
#  '399': 'taxonomy_krona_chart',
#  '400': 'bedtools_genomecoveragebed',
#  '401': 'ConsensusID',
#  '402': 'je_demultiplex',
#  '403': 'vcfvcfintersect',
#  '404': 'annotatemyids',
#  '405': 'cardinal_mz_images',
#  '406': 'deeptools_plot_coverage',
#  '407': 'paralyzer',
#  '408': 'snippy_core',
#  '409': 'cutadapt',
#  '410': 'join1',
#  '411': 'EMBOSS: shuffleseq87',
#  '412': 'gops_basecoverage_1',
#  '413': 'rseqc_bam2wig',
#  '414': 'plotly_regression_performance_plots',
#  '415': 'Remove beginning1',
#  '416': 'mlocarna',
#  '417': 'ssake',
#  '418': 'proteomics_search_peptide_prophet_1',
#  '419': 'rgweblogo3',
#  '420': 'picard_BamIndexStats',
#  '421': 'mothur_summary_seqs',
#  '422': 'shovill',
#  '423': 'bg_sortmerna',
#  '424': 'Draw_phylogram',
#  '425': 'vcftools_merge',
#  '426': 'eukaryotic_ncbi_submission',
#  '427': 'silac_analyzer',
#  '428': 'wc_gnu',
#  '429': 'ctb_chemfp_mol2fps',
#  '430': 'gtf2bedgraph',
#  '431': 'tp_cut_tool',
#  '432': 'piranha',
#  '433': 't_coffee',
#  '434': 'ete_genetree_splitter',
#  '435': 'flanking_features_1',
#  '436': 'IsobaricAnalyzer',
#  '437': 'sklearn_ensemble',
#  '438': 'qiime_pick_closed_reference_otus',
#  '439': 'hicexplorer_hictransform',
#  '440': 'ncbi_rpsblast_wrapper',
#  '441': 'mothur_cluster',
#  '442': 'minfi_qc',
#  '443': 'FileMerger',
#  '444': 'MapStatistics',
#  '445': 'seurat',
#  '446': 'seq_filter_by_id',
#  '447': 'bamleftalign',
#  '448': 'bwa',
#  '449': 'bedtools_bedtobam',
#  '450': 'sklearn_nn_classifier',
#  '451': 'hisat',
#  '452': 'picard_ReorderSam',
#  '453': 'EMBOSS: extractseq35',
#  '454': 'cardinal_preprocessing',
#  '455': 'cardinal_combine',
#  '456': 'vcfallelicprimitives',
#  '457': 'ggplot2_heatmap2',
#  '458': 'nspdk_sparse',
#  '459': 'viz_overlay_moving_and_fixed_image',
#  '460': 'CONVERTER_interval_to_bgzip_0',
#  '461': 'gatk2_variant_annotator',
#  '462': 'flexbar',
#  '463': 'MSGFPlusAdapter',
#  '464': 'HighResPrecursorMassCorrector',
#  '465': 'rmcontamination',
#  '466': 'xpath',
#  '467': 'minfi_dmr',
#  '468': 'chipsequtil_maptoknowngenes',
#  '469': 'rseqc_junction_saturation',
#  '470': 'numeric_clustering',
#  '471': 'mothur_remove_seqs',
#  '472': 'QCCalculator',
#  '473': 'EMBOSS: getorf42',
#  '474': 'smf_utils_fix-fasta-headers',
#  '475': 'hicexplorer_hicpca',
#  '476': 'raceid_clustering',
#  '477': 'humann2',
#  '478': 'preproc',
#  '479': 'stringtie',
#  '480': 'addValue',
#  '481': 'disco',
#  '482': 'Filter1',
#  '483': 'abims_xcms_summary',
#  '484': 'cardinal_data_exporter',
#  '485': 'mothur_count_groups',
#  '486': 'plotly_ml_performance_plots',
#  '487': 'CONVERTER_bedgraph_to_bigwig',
#  '488': 'ggplot2_histogram',
#  '489': 'mothur_dist_shared',
#  '490': 'hicexplorer_hicbuildmatrix',
#  '491': 'qiime_assign_taxonomy',
#  '492': 'MultiplexResolver',
#  '493': 'CONVERTER_sam_to_unsorted_bam',
#  '494': 'fastq_groomer',
#  '495': 'abims_xcms_group',
#  '496': 'term_id_vs_term_name',
#  '497': 'CONVERTER_bed_to_gff_0',
#  '498': 'mothur_dist_seqs',
#  '499': 'replace_column_with_key_value_file',
#  '500': 'glimmer_not-knowlegde-based',
#  '501': 'samtools_flag_filter',
#  '502': 'FeatureFinderCentroided',
#  '503': 'fastq_filter',
#  '504': 'fastq_paired_end_interlacer',
#  '505': 'tp_replace_in_line',
#  '506': 'bowtie_wrapper',
#  '507': 'deeptools_correctGCBias',
#  '508': 'samtools_rmdup',
#  '509': 'heinz_scoring',
#  '510': 'vcfsort',
#  '511': 'deeptools_multi_bigwig_summary',
#  '512': 'mothur_heatmap_bin',
#  '513': 'trim_galore',
#  '514': 'uparse',
#  '515': 'extract_element_from_collection',
#  '516': 'infernal_cmstat',
#  '517': 'pynast',
#  '518': 'pieplots_macs',
#  '519': 'macs2_bdgcmp',
#  '520': 'ggplot2_heatmap',
#  '521': 'histogram_rpy',
#  '522': 'plotly_parallel_coordinates_plot',
#  '523': 'vcffixup',
#  '524': 'glimmer_build-icm',
#  '525': 'gff_filter_by_attribute',
#  '526': 'abims_xcms_fillPeaks',
#  '527': 'fastq_to_fasta_python',
#  '528': 'picard_AddOrReplaceReadGroups',
#  '529': 'snpEff',
#  '530': 'bowtie2',
#  '531': 'wig_to_bigWig',
#  '532': 'mothur_rarefaction_single',
#  '533': 'bcftools_norm',
#  '534': 'IDMapper',
#  '535': 'vcf_filter',
#  '536': 'cshl_fastx_trimmer',
#  '537': 'collapse_dataset',
#  '538': 'FidoAdapter',
#  '539': 'mothur_metastats',
#  '540': 'heinz_bum',
#  '541': 'qiime_pick_otus',
#  '542': 'cshl_fastx_barcode_splitter',
#  '543': 'cshl_uniq_tool',
#  '544': 'minfi_getbeta',
#  '545': 'meme_fimo',
#  '546': 'Convert characters1',
#  '547': 'blastxml_to_top_descr',
#  '548': 'methtools_calling',
#  '549': 'deeptools_plot_fingerprint',
#  '550': 'CONVERTER_Bam_Bai_0',
#  '551': 'stacks_denovomap',
#  '552': 'align_families',
#  '553': 'PicardASMetrics',
#  '554': 'tmhmm2',
#  '555': 'maldi_quant_peak_detection',
#  '556': 'je_markdupes',
#  '557': 'rseqc_geneBody_coverage',
#  '558': 'join_files_on_column_fuzzy',
#  '559': 'Extractor',
#  '560': 'Count1',
#  '561': 'fastq_paired_end_splitter',
#  '562': 'gtf_filter_by_attribute_values_list',
#  '563': 'bedtools_subtractbed',
#  '564': 'Heatmap',
#  '565': 'peptide_shaker',
#  '566': 'combine_metaphlan2_humann2',
#  '567': 'deeptools_bamFingerprint',
#  '568': 'MapRTTransformer',
#  '569': 'fasta_compute_length',
#  '570': 'cufflinks',
#  '571': 'methtools_plot',
#  '572': 'rgPicardMarkDups',
#  '573': 'qiime_split_libraries_fastq',
#  '574': 'glob_report',
#  '575': 'dbbuilder',
#  '576': 'htseq_count',
#  '577': 'mothur_heatmap_sim',
#  '578': 'transdecoder',
#  '579': 'rsem_prepare_reference',
#  '580': 'tp_awk_tool',
#  '581': 'openms_protein_quantifier',
#  '582': 'PicardInsertSize',
#  '583': 'methtools_destrand',
#  '584': 'EMBOSS: fuzzpro38',
#  '585': 'vcfcombine',
#  '586': 'samtool_filter2',
#  '587': 'mothur_remove_lineage',
#  '588': 'wsdl_hmdb',
#  '589': 'porechop',
#  '590': 'qiime_make_otu_heatmap',
#  '591': 'sam_bw_filter',
#  '592': 'glimmer_knowlegde-based',
#  '593': 'ucsc-twobittofa',
#  '594': 'extract_bcs.py',
#  '595': 'deeptools_computeGCBias',
#  '596': 'gemini_de_novo',
#  '597': 'gatk2_variant_recalibrator',
#  '598': 'bedtools_genomecoveragebed_bedgraph',
#  '599': 'hicexplorer_hiccorrectmatrix',
#  '600': 'sickle',
#  '601': 'bedtools_mergebed',
#  '602': 'hicexplorer_hicmergematrixbins',
#  '603': 'mothur_make_shared',
#  '604': 'GeneModelMapper',
#  '605': 'flexbar_split_RR_bcs',
#  '606': 'goslimmer',
#  '607': 'bandage_image',
#  '608': '__FILTER_FROM_FILE__',
#  '609': 'cardinal_quality_report',
#  '610': 'ncbi_tblastn_wrapper',
#  '611': 'CONVERTER_fasta_to_fai',
#  '612': 'CONVERTER_fastqgz_to_fastq',
#  '613': 'IDMerger',
#  '614': 'FROGS_clustering',
#  '615': 'gatk_indel_realigner',
#  '616': 'ctb_compound_convert',
#  '617': 'gatk2_variant_select',
#  '618': 'FROGS_remove_chimera',
#  '619': 'picard_ARRG',
#  '620': 'sklearn_searchcv',
#  '621': 'humann2_genefamilies_genus_level',
#  '622': 'bedtools_bamtofastq',
#  '623': 'rcas',
#  '624': 'limma_voom',
#  '625': 'peakachu',
#  '626': 'get_child_terms',
#  '627': 'Extract genomic DNA 1',
#  '628': 'mothur_trim_seqs',
#  '629': 'picard_ValidateSamFile',
#  '630': 'tab2fasta',
#  '631': 'mass_spectrometry_imaging_segmentations',
#  '632': 'unipept',
#  '633': 'vsearch_dereplication',
#  '634': 'genbank_to_gff',
#  '635': 'gatk2_haplotype_caller',
#  '636': 'nonpareil',
#  '637': 'cuffdiff',
#  '638': 'tp_unfold_column_tool',
#  '639': 'deeptools_compute_gc_bias',
#  '640': 'FileConverter',
#  '641': 'stacks_genotypes',
#  '642': 'CONVERTER_bed_to_bgzip_0',
#  '643': 'TrimByLength',
#  '644': 'muscle',
#  '645': 'dunovo',
#  '646': 'hgv_linkToGProfile',
#  '647': 'deeptools_bam_compare',
#  '648': 'proteomics_search_protein_prophet_1',
#  '649': 'samtools_idxstats',
#  '650': 'CONVERTER_fasta_to_tabular',
#  '651': 'fastq_paired_end_deinterlacer',
#  '652': 'multiqc',
#  '653': 'bedtools_coveragebed',
#  '654': 'gemini_burden',
#  '655': 'MapAlignerPoseClustering',
#  '656': 'createInterval',
#  '657': 'bigwig_to_bedgraph',
#  '658': 'dexseq_annotate',
#  '659': 'cshl_fastq_to_fasta',
#  '660': 'cshl_awk_replace_in_column',
#  '661': 'seq_filter_by_mapping',
#  '662': 'gatk2_indel_realigner',
#  '663': 'Determine_BC',
#  '664': 'make_families',
#  '665': 'uchime',
#  '666': 'bundle_collection',
#  '667': 'mothur_count_seqs',
#  '668': 'qiime_count_seqs',
#  '669': 'mcClust',
#  '670': 'tp_sorted_uniq',
#  '671': 'Show beginning1',
#  '672': 'mimodd_varreport',
#  '673': 'fastq collapser',
#  '674': 'bctools_remove_spurious_events',
#  '675': 'bam_to_bigwig',
#  '676': 'gffread',
#  '677': 'idpquery',
#  '678': 'mycrobiota-krona-mothur',
#  '679': 'filter_by_fasta_ids',
#  '680': 'samtools_mpileup',
#  '681': 'NFS_transfer',
#  '682': 'bedtools_complementbed',
#  '683': 'eden_vectorizer',
#  '684': 'gatk2_realigner_target_creator',
#  '685': 'stacks_populations',
#  '686': 'smf_utils_filter-by-energy',
#  '687': 'sklear_numeric_clustering',
#  '688': 'bam_to_sam',
#  '689': 'abims_xcms_xcmsSet',
#  '690': 'tp_uniq_tool',
#  '691': 'minfi_methcpg',
#  '692': 'pilon',
#  '693': 'deeptools_bamCorrelate',
#  '694': 'vcffilter2',
#  '695': 'raceid_inspectclusters',
#  '696': 'vcf2pgSnp',
#  '697': 'raceid_filtnormconf',
#  '698': 'mothur_get_oturep',
#  '699': 'graphicsmagick_image_convert',
#  '700': 'tabular_to_fastq',
#  '701': 'gff2bed1',
#  '702': 'scpipe',
#  '703': 'extract_aln_ends.py',
#  '704': 'metilene',
#  '705': 'igvtools_count',
#  '706': 'p_clip_peaks',
#  '707': 'gops_intersect_1',
#  '708': 'fastq_trimmer',
#  '709': 'umi_tools_extract',
#  '710': 'mycrobiota-correct-replicates',
#  '711': 'tp_cat',
#  '712': 'gemini_db_info',
#  '713': 'lfq_protein_quant',
#  '714': 'Grep1',
#  '715': 'w4mclassfilter',
#  '716': 'format_metaphlan2_output',
#  '717': 'ia_coordinates_of_roi',
#  '718': 'bamtools',
#  '719': 'tp_tac',
#  '720': 'kraken',
#  '721': 'gemini_recessive_and_dominant',
#  '722': 'unicycler',
#  '723': 'search_gui',
#  '724': 'heinz',
#  '725': 'FeatureLinkerUnlabeled',
#  '726': 'bwameth',
#  '727': 'vegan_rarefaction',
#  '728': 'fgsea',
#  '729': 'table_annovar',
#  '730': 'scaffold2fasta',
#  '731': 'qiime_pick_open_reference_otus',
#  '732': 'gatk2_variant_apply_recalibration',
#  '733': 'EMBOSS: fuzztran39',
#  '734': 'chipseeker',
#  '735': 'get_sequences',
#  '736': 'snpSift_filter',
#  '737': 'rbc_mirdeep2_mapper',
#  '738': 'gatk2_variant_filtration',
#  '739': 'react_cal_pipeline',
#  '740': 'annotateMyIDs',
#  '741': 'blockclust',
#  '742': 'racon',
#  '743': 'ncbi_blastx_wrapper',
#  '744': 'vcftools_isec',
#  '745': 'Summary_Statistics1',
#  '746': 'fasta2tab',
#  '747': 'msconvert3_raw',
#  '748': 'gmx_solvate',
#  '749': 'RNAlien',
#  '750': 'vcfselectsamples',
#  '751': 'mz_to_sqlite',
#  '752': 'rbc_rnacode',
#  '753': 'FeatureLinkerUnlabeledKD',
#  '754': 'group_humann2_uniref_abundances_to_go',
#  '755': 'meme_meme',
#  '756': 'fastq_join',
#  '757': 'cast',
#  '758': 'blockbuster',
#  '759': 'tp_sed_tool',
#  '760': 'graphlan',
#  '761': 'segemehl',
#  '762': 'TrimPrimer',
#  '763': 'Psortb',
#  '764': 'flye',
#  '765': 'smf_utils_extract-boxed-sequences',
#  '766': 'FROGS_affiliations_stat',
#  '767': 'mothur_chimera_uchime',
#  '768': 'allele_counts_1',
#  '769': 'ggplot_point',
#  '770': 'cor2',
#  '771': 'Extract_RNA_seq_Evidence',
#  '772': 'sklearn_build_pipeline',
#  '773': 'cuffmerge',
#  '774': 'metaphlan2krona',
#  '775': 'hcluster_sg',
#  '776': 'gops_concat_1',
#  '777': 'coords2clnt.py',
#  '778': 'fasplit',
#  '779': 'bg_uniq',
#  '780': 'query_tabular',
#  '781': 'subtract_query1',
#  '782': 'FalseDiscoveryRate',
#  '783': '__UNZIP_COLLECTION__',
#  '784': 'prokka',
#  '785': 'sam_merge2',
#  '786': 'mothur_taxonomy_to_krona',
#  '787': 'goseq',
#  '788': 'mothur_get_communitytype',
#  '789': 'FileInfo',
#  '790': 'bcftools_call',
#  '791': 'sam_to_bam',
#  '792': 'qiime_pick_rep_set',
#  '793': 'samtools_sort',
#  '794': 'ncbi_blastp_wrapper',
#  '795': 'valet',
#  '796': 'cshl_fastx_reverse_complement',
#  '797': 'mass_spectrometry_imaging_mzplots',
#  '798': 'mothur_make_biom',
#  '799': 'mothur_lefse',
#  '800': 'mothur_classify_seqs',
#  '801': 'cshl_sort_header',
#  '802': 'roary',
#  '803': 'samtools_split',
#  '804': 'r_correlation_matrix',
#  '805': 'bg_find_subsequences',
#  '806': 'gatk2_base_recalibrator',
#  '807': 'bedtools_shufflebed',
#  '808': 'bg_column_arrange_by_header',
#  '809': 'trimmer',
#  '810': 'gmx_nvt',
#  '811': 'rsem_calculate_expression',
#  '812': 'transpose',
#  '813': 'gtftobed12',
#  '814': 'gemini_interactions',
#  '815': 'mycrobiota-qc-report',
#  '816': 'XY_Plot_1',
#  '817': 'lastz_wrapper_2',
#  '818': 'tp_text_file_with_recurring_lines',
#  '819': 'bamCoverage_deepTools',
#  '820': 'iReport',
#  '821': 'umi_tools_dedup',
#  '822': 're_he_maldi_image_registration',
#  '823': 'bams2ratio',
#  '824': 'mothur_sub_sample',
#  '825': 'cd_hit_dup',
#  '826': 'ctb_simsearch',
#  '827': 'bg_statistical_hypothesis_testing',
#  '828': 'nanopolish_variants',
#  '829': 'mothur_nmds',
#  '830': 'umi_tools_count',
#  '831': 'ncbi_blastn_wrapper',
#  '832': 'deg_annotate',
#  '833': 'hmmer_hmmsearch',
#  '834': 'minfi_ppfun',
#  '835': 'viennarna_rnafold',
#  '836': 'flexbar_split_RYYR_bcs',
#  '837': 'megablast_wrapper',
#  '838': 'vcfbedintersect',
#  '839': 'computeMatrix',
#  '840': 'fasta_merge_files_and_filter_unique_sequences',
#  '841': 'hmmer_hmmbuild',
#  '842': 'gd_raxml',
#  '843': 'XTandemAdapter',
#  '844': 'sam2interval',
#  '845': 'hicexplorer_hicplottads',
#  '846': 'abims_CAMERA_annotateDiffreport',
#  '847': 'cshl_grep_tool',
#  '848': 'bedtools_coveragebed_counts',
#  '849': 'bedtools_slopbed',
#  '850': 'bcftools_view',
#  '851': 'macs2_predictd',
#  '852': 'bgchem_fragment_merger',
#  '853': 'heatmapper',
#  '854': 'bam2wig',
#  '855': 'term_id_vs_term_def',
#  '856': 'bedtools_getfastabed',
#  '857': 'PeptideIndexer',
#  '858': 'metams_runGC',
#  '859': 'mimodd_map',
#  '860': 'cshl_fastx_renamer',
#  '861': 'charts',
#  '862': 'bed2gff1',
#  '863': 'Fetch Taxonomic Ranks',
#  '864': 'cshl_fastx_collapser',
#  '865': 'EMBOSS: wordcount109',
#  '866': 'deeptools_compute_matrix',
#  '867': 'meme_chip',
#  '868': 'cshl_princeton_fastx_barcode_splitter',
#  '869': 'dexseq_count',
#  '870': 'mycrobiota-otutable_add_blast',
#  '871': 'rna_star',
#  '872': 'raceid_trajectory',
#  '873': 'kraken-filter',
#  '874': 'deeptools_bamCompare',
#  '875': 'picard_FixMateInformation',
#  '876': 'mimodd_vcf_filter',
#  '877': 'mergeCols1',
#  '878': 'gffcompare',
#  '879': 'locarna_multiple',
#  '880': 'mass_spectrometry_imaging_qc',
#  '881': 'hgv_snpFreq',
#  '882': 'ctb_silicos_qed',
#  '883': 'MzTabExporter',
#  '884': 'aggregate_scores_in_intervals2',
#  '885': 'gatk2_reduce_reads',
#  '886': 'nn_classifier',
#  '887': 'rarefaction_analyzer',
#  '888': 'bwa_wrapper',
#  '889': 'deeptools_plot_heatmap',
#  '890': 'NSPDK_candidateClust',
#  '891': 'myrimatch',
#  '892': 'CONVERTER_gz_to_uncompressed',
#  '893': 'ProteinResolver',
#  '894': 'fastq_to_tabular',
#  '895': 'graphlan_annotate',
#  '896': 'cuffquant',
#  '897': 'krona-text',
#  '898': 'mothur_classify_rf',
#  '899': 'varscan',
#  '900': 'gmx_em',
#  '901': 'picard_CollectWgsMetrics',
#  '902': 'ete_homology_classifier',
#  '903': 'cshl_fastx_quality_statistics',
#  '904': 'fastqc',
#  '905': 'regex_replace',
#  '906': 'umi_tools_whitelist',
#  '907': 'deeptools_correct_gc_bias',
#  '908': 'snpSift_annotate',
#  '909': 'FileFilter',
#  '910': 'ProteinQuantifier',
#  '911': 'Extract_features1',
#  '912': 'ggplot_histogram',
#  '913': 'cshl_fastq_quality_filter',
#  '914': 'cshl_awk_tool',
#  '915': 'clustalw',
#  '916': 'EMBOSS: tranalign100',
#  '917': 'column_order_header_sort',
#  '918': 'trinity',
#  '919': 'DecoyDatabase',
#  '920': 'gops_join_1',
#  '921': 'deeptools_multi_bam_summary',
#  '922': 'tp_grep_tool',
#  '923': 'meme_dreme',
#  '924': 'raceid_main',
#  '925': 'rseqc_infer_experiment',
#  '926': 'picard_EstimateLibraryComplexity',
#  '927': 'CometAdapter',
#  '928': 'viennarna_rnaplot',
#  '929': 'proteomics_search_tandem_1',
#  '930': 'hicexplorer_hicplotmatrix',
#  '931': 'MassCalculator',
#  '932': 'IDFilter',
#  '933': 'salmon',
#  '934': 'CONVERTER_gff_to_bed_0',
#  '935': 'rbc_splitfasta',
#  '936': 'minfi_rset',
#  '937': 'DatamashTranspose',
#  '938': 'gatk_unified_genotyper',
#  '939': 'fasta_filter_by_length',
#  '940': 'picard_CollectRnaSeqMetrics',
#  '941': 'gatk2_unified_genotyper',
#  '942': 'w4mcorcov',
#  '943': 'deeptools_compute_matrix_operations',
#  '944': 'mothur_parsimony',
#  '945': 'map_peptides_to_bed',
#  '946': 'bed_to_bigwig',
#  '947': 'vcf2tsv',
#  '948': 'ctb_remIons',
#  '949': 'pureclip',
#  '950': 'FeatureLinkerUnlabeledQT',
#  '951': 'heatmapper_deepTools',
#  '952': 'varscan_somatic',
#  '953': 'Batch_correction',
#  '954': 'deeptools_heatmapper',
#  '955': 'methtools_dmr',
#  '956': 'snippy',
#  '957': 'snpsift_vartype',
#  '958': 'infernal_cmbuild',
#  '959': 'mothur_pre_cluster',
#  '960': 'fastq_manipulation',
#  '961': 'minfi_getanno',
#  '962': 'modencode_peakcalling_macs2',
#  '963': 'cshl_sed_tool',
#  '964': 'minfi_getM',
#  '965': 'viennarna_rnaalifold',
#  '966': 'deeptools_computeMatrix',
#  '967': 'correctGCBias',
#  '968': 'bam-filter',
#  '969': 'gene2exon1',
#  '970': 'hcluster_sg_parser',
#  '971': 'cuffnorm'}

# %%
def verify_model(model, tool_sequence, labels, dictionary, reverse_dictionary, compatible_tools, topk=20, max_seq_len=25):
    tl_seq = tool_sequence.split(",")
    last_tool_name = reverse_dictionary[str(tl_seq[-1])]
    last_compatible_tools = compatible_tools[last_tool_name]
    sample = np.zeros(max_seq_len)
    for idx, tool_id in enumerate(tl_seq):
        sample[idx] = int(tool_id)
    sample_reshaped = np.reshape(sample, (1, max_seq_len))

    tool_sequence_names = [reverse_dictionary[str(tool_pos)] for tool_pos in tool_sequence.split(",")]
    print("Tool seq: %s" % ",".join(tool_sequence_names))

    # predict next tools for a test path
    prediction = model.predict(sample_reshaped, verbose=0)
    prediction = np.reshape(prediction, (prediction.shape[1],))
    prediction_pos = np.argsort(prediction, axis=-1)

    # get topk prediction
    topk_prediction_pos = prediction_pos[-topk:]
    topk_prediction_val = [np.round(prediction[pos] * 100, 2) for pos in topk_prediction_pos]

    # read tool names using reverse dictionary
    pred_tool_ids = [reverse_dictionary[str(tool_pos)] for tool_pos in topk_prediction_pos]
    actual_next_tool_ids = list(set(pred_tool_ids).intersection(set(last_compatible_tools.split(","))))      

    print()
    pred_tool_ids_sorted = dict()
    for (tool_pos, tool_pred_val) in zip(topk_prediction_pos, topk_prediction_val):
        tool_name = reverse_dictionary[str(tool_pos)]
        if tool_name in actual_next_tool_ids:
            pred_tool_ids_sorted[tool_name] = tool_pred_val
    pred_tool_ids_sorted = dict(sorted(pred_tool_ids_sorted.items(), key=lambda kv: kv[1], reverse=True))
    
    cls_wt = dict()
    usg_wt = dict()
    inv_wt = dict()
    ids_tools = dict()
    keys = list(pred_tool_ids_sorted.keys())
    for k in keys:
        try:
            cls_wt[k] = np.round(class_weights[str(data_dict[k])], 2)
            usg_wt[k] = np.round(usage_weights[k], 2)
            inv_wt[k] = np.round(inverted_weights[str(data_dict[k])], 2)
        except:
            continue
    print("Predicted tools: \n")
    print(pred_tool_ids_sorted)
    print()
    print("Class weights: \n")
    cls_wt = dict(sorted(cls_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(cls_wt)
    print()
    print("Usage weights: \n")
    usg_wt = dict(sorted(usg_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(usg_wt)
    print()
    total_usage_wt = np.mean(list(usg_wt.values()))
    print("Mean usage wt: %0.4f" % (total_usage_wt))
    print()
    print("Inverted weights: \n")
    inv_wt = dict(sorted(inv_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(inv_wt)
    for key in pred_tool_ids_sorted:
        ids_tools[key] = dictionary[key]
    print()
    print("Tool ids")
    print(ids_tools)
    print("======================================")
    return cls_wt, usg_wt, inv_wt, pred_tool_ids_sorted

topk = 20
tool_seq = "213"
class_wt, usage_wt, inverse_wt, pred_tools = verify_model(model, tool_seq, "", dictionary, reverse_dictionary, compatibile_tools, topk)
# Out:
# Tool seq: mothur_make_contigs
#
# Predicted tools:
#
# {'mothur_summary_seqs': 13.88, 'fastqc': 2.54, 'mothur_count_seqs': 2.4, 'mothur_unique_seqs': 2.3, 'mothur_screen_seqs': 1.7}
#
# Class weights:
#
# {'fastqc': 5879.0, 'mothur_summary_seqs': 53.28, 'mothur_screen_seqs': 41.56, 'mothur_unique_seqs': 40.45, 'mothur_count_seqs': 17.52}
#
# Usage weights:
#
# {'fastqc': 5879.0, 'mothur_summary_seqs': 53.28, 'mothur_screen_seqs': 41.56, 'mothur_unique_seqs': 40.45, 'mothur_count_seqs': 17.52}
#
# Mean usage wt: 1206.3620
#
# Inverted weights:
#
# {}
#
# Tool ids
# {'mothur_summary_seqs': 421, 'fastqc': 904, 'mothur_count_seqs': 667, 'mothur_unique_seqs': 68, 'mothur_screen_seqs': 88}
# ======================================

# %%
list_cls_wt = list()
list_usage_wt = list()
list_pred_wt = list()
list_inv_wt = list()
division_pt = int(len(pred_tools) / 2)

for tool in pred_tools:
    list_pred_wt.append(pred_tools[tool])
    #try:
    list_inv_wt.append(inverse_wt[tool])
    list_usage_wt.append(usage_wt[tool])
    #except:
    #list_inv_wt.append(1)

def plot_scatter(y_val, title, xlabel, ylabel):
    x_val = range(1, len(y_val) + 1)
    plt.figure(figsize=(8, 8))
    plt.plot(x_val[:division_pt], y_val[:division_pt], 'ro')
    plt.plot(x_val[division_pt:], y_val[division_pt:], 'b^')
    plt.xlabel(xlabel, size=size_label)
    plt.ylabel(ylabel, size=size_label)
    plt.legend([("First top-%s" % str(division_pt)), ("Next top-%s" % str(division_pt))])
    plt.title(title, size=size_title)
    plt.grid(True)
    plt.show()

plot_scatter(list_usage_wt, "Usage weights for tools", "Number of tools", "Class weights")
#plot_scatter(ave_prediction_weights, ave_usage_weights, "Prediction vs usage weights", "Prediction scores", "Usage weights")
#plot_scatter(ave_prediction_weights, ave_inverted_weights, "Prediction vs inverted weights", "Prediction scores", "Inverted weights")
