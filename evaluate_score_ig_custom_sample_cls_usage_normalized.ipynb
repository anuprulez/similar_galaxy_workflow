# %%
import numpy as np
import json
import warnings
import operator

import h5py
from keras.models import model_from_json
from keras import backend as K

from matplotlib import pyplot as plt

warnings.filterwarnings("ignore")

size_title = 18
size_label = 14
n_pred = 2

base_path = "data/remote_cls_sample_wt_normalised/"

path_data_dict = base_path + "data_dict.txt"
path_inverted_wt = base_path + "inverted_weights.txt"
path_usage_wt = base_path + "usage_prediction.txt"
path_class_wt = base_path + "class_weights.txt"
path_test_data = base_path + "test_paths_dict.txt"
model_path = base_path + "trained_model.hdf5"

def read_file(file_path):
    with open(file_path, 'r') as data_file:
        data = json.loads(data_file.read())
    return data

class_weights = read_file(path_class_wt)
usage_weights = read_file(path_usage_wt)
inverted_weights = read_file(path_inverted_wt)
data_dict = read_file(path_data_dict)

def create_model(model_path):
    trained_model = h5py.File(model_path, 'r')
    model_config = json.loads(trained_model.get('model_config').value)
    loaded_model = model_from_json(model_config)
    dictionary = json.loads(trained_model.get('data_dictionary').value)
    compatibile_tools = json.loads(trained_model.get('compatible_tools').value)
    reverse_dictionary = dict((str(v), k) for k, v in dictionary.items())
    model_weights = list()
    weight_ctr = 0
    while True:
        try:
            d_key = "weight_" + str(weight_ctr)
            weights = trained_model.get(d_key).value
            model_weights.append(weights)
            weight_ctr += 1
        except Exception as exception:
            break
    # set the model weights
    loaded_model.set_weights(model_weights)
    return loaded_model, dictionary, reverse_dictionary, compatibile_tools

model, dictionary, reverse_dictionary, compatibile_tools = create_model(model_path)

# %%
reverse_dictionary
# Out:
# {'1': 'r_correlation_matrix',
#  '2': 'mycrobiota-qc-report',
#  '3': 'mycrobiota-otutable_add_blast',
#  '4': 'xpath',
#  '5': 'xcms_merge',
#  '6': 'sample_seqs',
#  '7': 'ncbi_makeblastdb',
#  '8': 'metaspades',
#  '9': 'cshl_fastx_barcode_splitter',
#  '10': 'bedtools_intersectBed',
#  '11': 'wolf_psort',
#  '12': 'heatmapper',
#  '13': 'krona-text',
#  '14': 'gafa',
#  '15': 'Draw_phylogram',
#  '16': 'raceid_clustering',
#  '17': 'gops_merge_1',
#  '18': 'myrimatch',
#  '19': 'resistome_analyzer',
#  '20': 'minfi_qc',
#  '21': 'pileup_parser',
#  '22': 'genbank_to_gff',
#  '23': 'addName',
#  '24': 'heinz_visualization',
#  '25': 'hicexplorer_hicfindtads',
#  '26': 'computeMatrix',
#  '27': 'ggplot2_heatmap2',
#  '28': 'mothur_lefse',
#  '29': 'rseqc_read_duplication',
#  '30': 'mycrobiota-krona-mothur',
#  '31': 'humann2',
#  '32': 'Psortb',
#  '33': 'hgv_linkToGProfile',
#  '34': 'thermo_raw_file_converter',
#  '35': 'cshl_sort_header',
#  '36': 'ExtractFASTAfromFASTQ',
#  '37': 'gffread',
#  '38': 'qiime_assign_taxonomy',
#  '39': '__FILTER_FROM_FILE__',
#  '40': 'CONVERTER_Bam_Bai_0',
#  '41': 'vcf2tsv',
#  '42': 'gemini_windower',
#  '43': 'FeatureFinderCentroided',
#  '44': 'tp_replace_in_line',
#  '45': 'maldi_quant_preprocessing',
#  '46': 'hicexplorer_hicplotmatrix',
#  '47': 'bgchem_fragment_merger',
#  '48': 'bctools_extract_alignment_ends',
#  '49': 'graphlan_annotate',
#  '50': 'bedtools_getfastabed',
#  '51': 'megahit',
#  '52': 'gemini_interactions',
#  '53': 'unipept',
#  '54': 'PicardInsertSize',
#  '55': 'sklearn_numeric_clustering',
#  '56': 'Batch_correction',
#  '57': 'meme_meme',
#  '58': 'gatk2_variant_recalibrator',
#  '59': 'stacks_denovomap',
#  '60': 'get_read_pipeline',
#  '61': 'glimmer_knowlegde-based',
#  '62': 'TextExporter',
#  '63': 'ctb_chemfp_mol2fps',
#  '64': 'samtools_flagstat',
#  '65': 'bedtools_slopbed',
#  '66': 'MapAlignerPoseClustering',
#  '67': 'rcas',
#  '68': 'deeptools_multi_bigwig_summary',
#  '69': 'varscan',
#  '70': 'mothur_filter_seqs',
#  '71': 'qiime_core_diversity',
#  '72': 'mass_spectrometry_imaging_segmentations',
#  '73': 'mimodd_map',
#  '74': 'PeakPickerHiRes',
#  '75': 'ctb_compound_convert',
#  '76': 'samtools_split',
#  '77': 'replace_column_with_key_value_file',
#  '78': 'cuffnorm',
#  '79': 'subtract_query1',
#  '80': 'gd_raxml',
#  '81': 'featurecounts',
#  '82': 'biosigner',
#  '83': 'hicexplorer_hictransform',
#  '84': 'Datamash',
#  '85': 'mothur_taxonomy_to_krona',
#  '86': 'mothur_get_communitytype',
#  '87': 'bowtie2',
#  '88': 'smooth_running_window',
#  '89': 'gops_coverage_1',
#  '90': 'nonpareil',
#  '91': 'format_metaphlan2_output',
#  '92': 'stacks_refmap',
#  '93': 'EMBOSS: shuffleseq87',
#  '94': 'graphicsmagick_image_convert',
#  '95': 'raceid_main',
#  '96': 'fgsea',
#  '97': 'gffcompare',
#  '98': 'seurat',
#  '99': 'cd_hit_dup',
#  '100': 'picard_CollectInsertSizeMetrics',
#  '101': 'export2graphlan',
#  '102': 'PeptideIndexer',
#  '103': 'fasplit',
#  '104': 'samtools_bedcov',
#  '105': 'bedtools_map',
#  '106': 'picard_ARRG',
#  '107': 'gspan',
#  '108': 'minfi_maptogenome',
#  '109': 'mothur_unique_seqs',
#  '110': 'NSPDK_candidateClust',
#  '111': 'pynast',
#  '112': 'goslimmer',
#  '113': 'cshl_fastx_collapser',
#  '114': 'collection_column_join',
#  '115': 'rarefaction',
#  '116': 'umi_tools_dedup',
#  '117': 'flanking_features_1',
#  '118': 'bed_to_bigwig',
#  '119': 'hicexplorer_hicpca',
#  '120': 'quast',
#  '121': 'sklearn_nn_classifier',
#  '122': 'qiime_pick_closed_reference_otus',
#  '123': 'EMBOSS: tranalign100',
#  '124': 'humann2_genefamilies_genus_level',
#  '125': 'picard_MarkDuplicates',
#  '126': 'FastTree',
#  '127': 'varscan_somatic',
#  '128': 'search_gui',
#  '129': 'EMBOSS: fuzztran39',
#  '130': 'gatk2_depth_of_coverage',
#  '131': 'deeptools_correct_gc_bias',
#  '132': 'IDMassAccuracy',
#  '133': 'pileometh',
#  '134': 'tophat_fusion_post',
#  '135': 'gemini_comp_hets',
#  '136': 'deeptools_multi_bam_summary',
#  '137': 'ProteinInference',
#  '138': 'qiime_pick_otus',
#  '139': 'flexbar',
#  '140': 'XY_Plot_1',
#  '141': 'bg_protein_properties',
#  '142': 'wig_to_bigWig',
#  '143': 'cufflinks',
#  '144': 'bg_diamond',
#  '145': 'Digestor',
#  '146': 'mergeCols1',
#  '147': 'minfi_mset',
#  '148': 'bamtools',
#  '149': 're_he_maldi_image_registration',
#  '150': 'picard_BamIndexStats',
#  '151': 'racon',
#  '152': 'minfi_dmp',
#  '153': 'velvetg_jgi',
#  '154': '__RELABEL_FROM_FILE__',
#  '155': 'vegan_diversity',
#  '156': 'cardinal_quality_report',
#  '157': 'kraken-report',
#  '158': 'Interval_Maf_Merged_Fasta2',
#  '159': 'ggplot2_histogram',
#  '160': 'megablast_xml_parser',
#  '161': 'sequence_content_trimmer',
#  '162': 'FROGS_affiliation_OTU',
#  '163': 'histogram_rpy',
#  '164': 'vcffixup',
#  '165': 'createInterval',
#  '166': 'gene2exon1',
#  '167': 'cummerbund_to_cuffdiff',
#  '168': 'ncbi_blastp_wrapper',
#  '169': 'hicexplorer_hicmergematrixbins',
#  '170': '__FILTER_FAILED_DATASETS__',
#  '171': 'fastq_paired_end_splitter',
#  '172': 'ChooseTag',
#  '173': 'CONVERTER_gff_to_bed_0',
#  '174': 'MapStatistics',
#  '175': 'goseq',
#  '176': 'antismash',
#  '177': 'rm_spurious_events.py',
#  '178': 'vt_normalize',
#  '179': 'methtools_filter',
#  '180': 'msconvert3_raw',
#  '181': 'je_clip',
#  '182': 'minfi_rset',
#  '183': 'column_remove_by_header',
#  '184': 'picard_SortSam',
#  '185': 'fastq_combiner',
#  '186': 'Grouping1',
#  '187': 'FileInfo',
#  '188': 'gops_intersect_1',
#  '189': 'cshl_fastx_clipper',
#  '190': 'bedtools_multiintersectbed',
#  '191': 'hgv_david',
#  '192': 'rsem_calculate_expression',
#  '193': 'mothur_merge_files',
#  '194': 'gemini_db_info',
#  '195': 'minfi_dmr',
#  '196': 'blast2go',
#  '197': 'mothur_pcoa',
#  '198': 'Btrim64',
#  '199': 'gatk_depth_of_coverage',
#  '200': 'column_order_header_sort',
#  '201': 'EMBOSS: fuzzpro38',
#  '202': 'graphclust_align_cluster',
#  '203': 'sqlite_to_tabular',
#  '204': 'snpsift_vartype',
#  '205': 'gff_filter_by_attribute',
#  '206': 'fastq_paired_end_interlacer',
#  '207': 'mass_spectrometry_imaging_mzplots',
#  '208': 'taxonomy_krona_chart',
#  '209': 'sam2interval',
#  '210': 'aragorn_trna',
#  '211': 'mothur_classify_otu',
#  '212': 'gemini_load',
#  '213': 'rna_star',
#  '214': 'htseq_count',
#  '215': 'bam2wig',
#  '216': 'fastq_manipulation',
#  '217': 'tabular_to_fastq',
#  '218': 'naive_variant_caller',
#  '219': 'infernal_cmstat',
#  '220': 'MSGFPlusAdapter',
#  '221': 'cshl_uniq_tool',
#  '222': 'align_families',
#  '223': 'mycrobiota-correct-replicates',
#  '224': 'lfq_protein_quant',
#  '225': 'Show beginning1',
#  '226': 'bam_to_sam',
#  '227': 'gff_to_sequence',
#  '228': 'glimmer_not-knowlegde-based',
#  '229': 'mothur_parsimony',
#  '230': 'viennarna_rnaplot',
#  '231': 'bedtools_bamtofastq',
#  '232': 'FeatureFinderMultiplex',
#  '233': 'heatmapper_deepTools',
#  '234': 'hisat',
#  '235': 'Summary_Statistics1',
#  '236': 'GeneModelMapper',
#  '237': 'DecoyDatabase',
#  '238': 'blastxml_to_tabular_selectable',
#  '239': 'bctools_remove_spurious_events',
#  '240': 'numeric_clustering',
#  '241': 'abims_xcms_group',
#  '242': 'tp_uniq_tool',
#  '243': 'FeatureLinkerUnlabeledKD',
#  '244': 'rbc_mafft',
#  '245': 'mothur_chimera_vsearch',
#  '246': 'mothur_classify_rf',
#  '247': 'sam_to_bam',
#  '248': 'limma_voom',
#  '249': 'snpEff',
#  '250': 'bwa_mem',
#  '251': 'gemini_recessive_and_dominant',
#  '252': 'cshl_fastx_artifacts_filter',
#  '253': 'EMBOSS: transeq101',
#  '254': 'bedtools_genomecoveragebed_bedgraph',
#  '255': 'cardinal_filtering',
#  '256': 'eden_sequence_converter',
#  '257': 'tophat',
#  '258': 'mycrobiota-split-multi-otutable',
#  '259': 'bowtie_wrapper',
#  '260': 'Grep1',
#  '261': 'fasta-stats',
#  '262': 'tp_sort_rows',
#  '263': 'qiime_pick_open_reference_otus',
#  '264': 'bedtools_shufflebed',
#  '265': 'velvet',
#  '266': 'ctb_ob_genProp',
#  '267': 'infernal_cmbuild',
#  '268': 'gemini_query',
#  '269': 'IDConflictResolver',
#  '270': 'bamCoverage_deepTools',
#  '271': 'velvetoptimiser',
#  '272': 'flye',
#  '273': 'vcfselectsamples',
#  '274': 'ggplot_histogram',
#  '275': 'minfi_read450k',
#  '276': 'FalseDiscoveryRate',
#  '277': 'minfi_methcpg',
#  '278': 'ngsutils_bam_filter',
#  '279': 'modencode_peakcalling_macs2',
#  '280': 'freebayes',
#  '281': 'bedtools_subtractbed',
#  '282': 'egsea',
#  '283': 'comp1',
#  '284': 'mothur_remove_lineage',
#  '285': 'signalp3',
#  '286': 'rgweblogo3',
#  '287': 'vcfbedintersect',
#  '288': 'sam_bw_filter',
#  '289': 'cshl_sed_tool',
#  '290': 'HighResPrecursorMassCorrector',
#  '291': 'seq_filter_by_id',
#  '292': 'heinz_scoring',
#  '293': 'roary',
#  '294': 'stringtie',
#  '295': 'Count1',
#  '296': 'metams_runGC',
#  '297': 'regex_replace',
#  '298': 'Extract genomic DNA 1',
#  '299': 'ncbi_tblastn_wrapper',
#  '300': 'CONVERTER_bed_gff_or_vcf_to_bigwig_0',
#  '301': 'tp_split_on_column',
#  '302': 'piranha',
#  '303': 'blastxml_to_tabular',
#  '304': 'minfi_getanno',
#  '305': 'methtools_plot',
#  '306': 'cmFinder',
#  '307': 'charts',
#  '308': 'bedtools_annotatebed',
#  '309': 'qiime_make_phylogeny',
#  '310': 'deeptools_bamCompare',
#  '311': 'mothur_trim_seqs',
#  '312': 'fasttree',
#  '313': 'blockbuster',
#  '314': 'fastq_trimmer',
#  '315': 'samtools_filter',
#  '316': 'cshl_fastq_quality_boxplot',
#  '317': 'Show tail1',
#  '318': 'pileup_interval',
#  '319': 'fastq_filter',
#  '320': 'abims_xcms_fillPeaks',
#  '321': '__UNZIP_COLLECTION__',
#  '322': 'Fetch Taxonomic Ranks',
#  '323': 'ucsc-twobittofa',
#  '324': 'preMloc',
#  '325': 'Add_a_column1',
#  '326': 'cshl_grep_tool',
#  '327': 'cshl_fastx_quality_statistics',
#  '328': 'bams2ratio',
#  '329': 'uniprot',
#  '330': 'hmmer_hmmbuild',
#  '331': 'bwameth',
#  '332': 'nspdk_sparse',
#  '333': 'blast_parser',
#  '334': 'qiime_count_seqs',
#  '335': 'get_flanks1',
#  '336': 'CONVERTER_interval_to_bgzip_0',
#  '337': '__MERGE_COLLECTION__',
#  '338': 'bedtools_bamtobed',
#  '339': 'gmx_md',
#  '340': 'minfi_ppfun',
#  '341': 'ggplot2_point',
#  '342': 'selectsequencesfrommsa',
#  '343': 'bwa_wrapper',
#  '344': 'GeMoMa_Annotation_Filter',
#  '345': 'ctb_remSmall',
#  '346': 'QCCalculator',
#  '347': 'ggplot_point',
#  '348': 'samtools_mpileup',
#  '349': 'minfi_getbeta',
#  '350': 'deeptools_bigwigCompare',
#  '351': 'bedtools_mergebed',
#  '352': 'proteomics_search_protein_prophet_1',
#  '353': 'flexbar_split_RR_bcs',
#  '354': 'smf_utils_extract-boxed-sequences',
#  '355': 'FROGS_clustering',
#  '356': 'IDScoreSwitcher',
#  '357': 'Heatmap',
#  '358': 'gemini_de_novo',
#  '359': 'rbc_mirdeep2_mapper',
#  '360': 'snpfinder',
#  '361': 'Filter1',
#  '362': 'coords2clnt.py',
#  '363': 'macs2_callpeak',
#  '364': 'tab2fasta',
#  '365': 'deeptools_bam_coverage',
#  '366': 'gatk2_variant_filtration',
#  '367': 'samtools_sort',
#  '368': 'proteomics_moff',
#  '369': 'tsne',
#  '370': 'hicexplorer_hiccorrectmatrix',
#  '371': 'idpassemble',
#  '372': 'idr-embl',
#  '373': 'mz_to_sqlite',
#  '374': 'mothur_count_seqs',
#  '375': 'stringtie_merge',
#  '376': 'edger',
#  '377': 't2t_report',
#  '378': 'vcfallelicprimitives',
#  '379': 'gmx_npt',
#  '380': 'ip_projective_transformation',
#  '381': 'deeptools_plot_fingerprint',
#  '382': 'correct_barcodes',
#  '383': 'viennarna_rnaalifold',
#  '384': 'IDMapper',
#  '385': 'EMBOSS: extractseq35',
#  '386': 'IDPosteriorErrorProbability',
#  '387': 'Remove beginning1',
#  '388': 'blastxml_to_top_descr',
#  '389': 'rseqc_junction_saturation',
#  '390': 'bedtools_bedtobam',
#  '391': 'deeptools_computeGCBias',
#  '392': 'minfi_getM',
#  '393': 'gatk2_variant_annotator',
#  '394': 'cutadapt',
#  '395': 'vcftools_annotate',
#  '396': 'igvtools_count',
#  '397': 'raceid_inspecttrajectory',
#  '398': 'bedtools_windowbed',
#  '399': 'rseqc_bam2wig',
#  '400': 'Determine_BC',
#  '401': 'samtools_slice_bam',
#  '402': 'picard_CleanSam',
#  '403': 'secure_hash_message_digest',
#  '404': 'fastq collapser',
#  '405': 'mothur_cluster',
#  '406': 'rgPicFixMate',
#  '407': 'structure_to_gspan',
#  '408': 'nanopolish_variants',
#  '409': 'humann2_renorm_table',
#  '410': 'iReport',
#  '411': 'ctb_remIons',
#  '412': 'je_demultiplex',
#  '413': 'fastq_paired_end_deinterlacer',
#  '414': 'bandage_image',
#  '415': 'mothur_tree_shared',
#  '416': 'w4mclstrpeakpics',
#  '417': 'trinity',
#  '418': 'segemehl',
#  '419': 'uchime',
#  '420': 'bedtools_genomecoveragebed_histogram',
#  '421': 'mothur_dist_seqs',
#  '422': '__SORTLIST__',
#  '423': 'locarna_multiple',
#  '424': 'ProteinQuantifier',
#  '425': 'valet',
#  '426': 'EMBOSS: seqret84',
#  '427': 'CONVERTER_gff_to_interval_index_0',
#  '428': 'abims_xcms_summary',
#  '429': 'gtf2bedgraph',
#  '430': 'hicexplorer_hicsummatrices',
#  '431': 'cuffquant',
#  '432': '__APPLY_RULES__',
#  '433': 'humann2_regroup_table',
#  '434': 'umi_tools_count',
#  '435': 'gatk2_variant_select',
#  '436': 'melt',
#  '437': 'diffbind-embl',
#  '438': 'term_id_vs_term_def',
#  '439': 'snpSift_geneSets',
#  '440': 'Extract_RNA_seq_Evidence',
#  '441': 'w4mclassfilter',
#  '442': 'bcftools_norm',
#  '443': 'filter_bed_on_splice_junctions',
#  '444': 'tp_sorted_uniq',
#  '445': 'Paste1',
#  '446': 'FROGS_remove_chimera',
#  '447': 'gmx_solvate',
#  '448': 'bg_sortmerna',
#  '449': 'openms_id_file_converter',
#  '450': 'random_lines1',
#  '451': 'mothur_heatmap_sim',
#  '452': 'vcftools_isec',
#  '453': 'sailfish',
#  '454': 'picard_NormalizeFasta',
#  '455': 'shovill',
#  '456': 'gbk_to_orf',
#  '457': 'hicexplorer_hicplottads',
#  '458': 'dunovo',
#  '459': 'mothur_get_oturep',
#  '460': 'meme_dreme',
#  '461': 'filter_by_fasta_ids',
#  '462': 'samtools_stats',
#  '463': 'bundle_collection',
#  '464': 'w4mjoinpn',
#  '465': 'picard_FilterSamReads',
#  '466': 'gmx_em',
#  '467': 'qiime_validate_mapping_file',
#  '468': 'cmv',
#  '469': 'bedtools_multicovtbed',
#  '470': 'rbc_rnacode',
#  '471': 'glimmer_build-icm',
#  '472': 'mothur_dist_shared',
#  '473': 'sort1',
#  '474': 'FileMerger',
#  '475': 'predict_pipeline',
#  '476': 'bamleftalign',
#  '477': 'get_feature_info',
#  '478': 'deeptools_bamCorrelate',
#  '479': 'vcfvcfintersect',
#  '480': 'augustus',
#  '481': 'fasta2tab',
#  '482': 'fraggenescan',
#  '483': 'viz_overlay_moving_and_fixed_image',
#  '484': 'dexseq_count',
#  '485': 'rseqc_inner_distance',
#  '486': 'addValue',
#  '487': 'CONVERTER_bed_to_bgzip_0',
#  '488': 'Extract_features1',
#  '489': 'methtools_tiling',
#  '490': 'picard_CASM',
#  '491': 'rseqc_infer_experiment',
#  '492': 'Nucleosome',
#  '493': 'tp_multijoin_tool',
#  '494': 'bam-filter',
#  '495': 'smf_utils_fix-fasta-headers',
#  '496': 'TrimByLength',
#  '497': 'tp_unfold_column_tool',
#  '498': 'svm_classifier',
#  '499': 'bg_column_arrange_by_header',
#  '500': 'plotly_ml_performance_plots',
#  '501': 'heinz_bum',
#  '502': 'tp_head_tool',
#  '503': 'je_markdupes',
#  '504': 'cshl_fastq_quality_filter',
#  '505': 'mothur_heatmap_bin',
#  '506': 'cshl_fastq_to_fasta',
#  '507': 'snippy',
#  '508': 'hcluster_sg',
#  '509': 'salmon',
#  '510': 'mothur_venn',
#  '511': 'ConsensusMapNormalizer',
#  '512': 'kraken',
#  '513': 'seq_filter_by_mapping',
#  '514': 'metilene',
#  '515': 'iuc_pear',
#  '516': 'deeptools_profiler',
#  '517': 'CONVERTER_fasta_to_fai',
#  '518': 'bcftools_consensus',
#  '519': 'XTandemAdapter',
#  '520': 'mass_spectrometry_imaging_ion_images',
#  '521': 'chipseeker',
#  '522': 'goenrichment',
#  '523': 'deeptools_plot_profile',
#  '524': 'modencode_peakcalling_spp',
#  '525': 'IDFileConverter',
#  '526': 'mimodd_varextract',
#  '527': 'tmhmm2',
#  '528': 'gatk2_haplotype_caller',
#  '529': 'mothur_sub_sample',
#  '530': 'get_sequences',
#  '531': 'annotateMyIDs',
#  '532': 'bwa',
#  '533': 'fastqc',
#  '534': 'RNAlien',
#  '535': 'cshl_multijoin',
#  '536': 'find_in_reference',
#  '537': 'combine_metaphlan2_humann2',
#  '538': 'picard_FixMateInformation',
#  '539': 'scpipe',
#  '540': 'vcftools_merge',
#  '541': 'nn_classifier',
#  '542': 'dbbuilder',
#  '543': 'vsearch_dereplication',
#  '544': 'filtlong',
#  '545': 'table_annovar',
#  '546': 'FidoAdapter',
#  '547': 'graphlan',
#  '548': 'NFS_transfer',
#  '549': 'prokaryotic_ncbi_submission',
#  '550': 'ggplot2_heatmap',
#  '551': 'mothur_pre_cluster',
#  '552': 'newick_display',
#  '553': 'MAF_To_Fasta1',
#  '554': 'rbc_mirdeep2',
#  '555': 'porechop',
#  '556': 'idpquery',
#  '557': 'transdecoder',
#  '558': 'spades',
#  '559': 'clustalw',
#  '560': 'tp_text_file_with_recurring_lines',
#  '561': '16Saligner',
#  '562': 'FROGS_affiliations_stat',
#  '563': 'ctb_online_data_fetch',
#  '564': 'picard_CollectRnaSeqMetrics',
#  '565': 'deeptools_plot_pca',
#  '566': 'snpSift_dbnsfp_generic',
#  '567': 'gtftobed12',
#  '568': 'rnafold',
#  '569': 'picard_ReorderSam',
#  '570': 'deeptools_plot_correlation',
#  '571': 'mothur_cluster_split',
#  '572': 'CONVERTER_bedgraph_to_bigwig',
#  '573': 'make_families',
#  '574': 'plotly_regression_performance_plots',
#  '575': 'CONVERTER_interval_to_bedstrict_0',
#  '576': 'eden_vectorizer',
#  '577': 'MassCalculator',
#  '578': 'mass_spectrometry_imaging_classification',
#  '579': 'bedtools_unionbedgraph',
#  '580': 'disco',
#  '581': 'multiqc',
#  '582': 'picard_EstimateLibraryComplexity',
#  '583': 'EMBOSS: wordcount109',
#  '584': 'term_id_vs_term_name',
#  '585': 'gff2bed1',
#  '586': 'cshl_awk_replace_in_column',
#  '587': 'vcfcombine',
#  '588': 'treebest_best',
#  '589': 'circgraph',
#  '590': 'mothur_get_seqs',
#  '591': 'velveth_jgi',
#  '592': 'mothur_make_contigs',
#  '593': 'fastq_dump',
#  '594': 'openms_id_mapper',
#  '595': 'mothur_metastats',
#  '596': 'Cut1',
#  '597': 'picard_CollectWgsMetrics',
#  '598': 'gtf_filter_by_attribute_values_list',
#  '599': 'bctools_extract_crosslinked_nucleotides',
#  '600': 'cardinal_segmentations',
#  '601': 'deeptools_correctGCBias',
#  '602': 'vcfgenotypes',
#  '603': 'htseq-count',
#  '604': 'gops_cluster_1',
#  '605': 'varscan_mpileup',
#  '606': 'hicexplorer_hicbuildmatrix',
#  '607': '__FLATTEN__',
#  '608': 'peakcalling_macs',
#  '609': 'ncbi_blastx_wrapper',
#  '610': 'rseqc_geneBody_coverage',
#  '611': 'samtools_flag_filter',
#  '612': 'deeptools_bam_compare',
#  '613': 'EMBOSS: textsearch98',
#  '614': 'infernal_cmsearch',
#  '615': 'snpEff_download',
#  '616': 'mothur_make_shared',
#  '617': 't_coffee',
#  '618': 'wsdl_hmdb',
#  '619': 'tp_easyjoin_tool',
#  '620': 'barchart_gnuplot',
#  '621': 'extract_element_from_collection',
#  '622': 'TrimByN',
#  '623': 'gatk2_unified_genotyper',
#  '624': 'pilon',
#  '625': 'ssake',
#  '626': 'wc_gnu',
#  '627': 'EMBOSS: newseq59',
#  '628': 'gemini_actionable_mutations',
#  '629': 'Multivariate',
#  '630': 'sam_pileup',
#  '631': 'gemini_annotate',
#  '632': 'gops_subtract_1',
#  '633': 'uparse',
#  '634': 'cshl_fasta_nucleotides_changer',
#  '635': 'mothur_summary_single',
#  '636': 'tp_sort_header_tool',
#  '637': 'CONVERTER_fastqgz_to_fastq',
#  '638': 'gatk2_reduce_reads',
#  '639': 'allele_counts_1',
#  '640': 'ruvseq',
#  '641': 'smf_utils_find-boxes',
#  '642': 'msconvert_nix',
#  '643': 'IsobaricAnalyzer',
#  '644': 'transpose',
#  '645': 'mothur_screen_seqs',
#  '646': 'flexbar_split_RYYR_bcs',
#  '647': 'mothur_remove_groups',
#  '648': 'secretbt2test',
#  '649': 'mothur_count_groups',
#  '650': 'fastq_to_tabular',
#  '651': 'heinz',
#  '652': 'mothur_amova',
#  '653': 'ChangeCase',
#  '654': 'fastq_groomer',
#  '655': 'EMBOSS: geecee41',
#  '656': 'qiime_align_seqs',
#  '657': 'convert_bc_to_binary_RY.py',
#  '658': 'get_child_terms',
#  '659': 'gemini_burden',
#  '660': 'mothur_make_biom',
#  '661': 'gatk2_variant_apply_recalibration',
#  '662': 'viennarna_rnafold',
#  '663': 'mass_spectrometry_imaging_qc',
#  '664': 'bamCompare_deepTools',
#  '665': 'FROGS_filters',
#  '666': 'fasta_compute_length',
#  '667': 'methtools_destrand',
#  '668': 'Flash',
#  '669': 'datamash_ops',
#  '670': 'stacks_populations',
#  '671': 'sklearn_svm_classifier',
#  '672': 'sklearn_feature_selection',
#  '673': 'eukaryotic_ncbi_submission',
#  '674': 'deeptools_compute_matrix_operations',
#  '675': 'qiime_pick_rep_set',
#  '676': 'mothur_corr_axes',
#  '677': 'bg_uniq',
#  '678': 'samtools_idxstats',
#  '679': 'bismark_bowtie2',
#  '680': 'bg_find_subsequences',
#  '681': 'ctb_silicos_qed',
#  '682': 'rbc_mirdeep2_quantifier',
#  '683': 'methtools_dmr',
#  '684': 'vcf_filter',
#  '685': 'pieplots_macs',
#  '686': 'DatamashOps',
#  '687': 'mothur_summary_seqs',
#  '688': 'gatk2_indel_realigner',
#  '689': 'trim_galore',
#  '690': 'ctb_change_title',
#  '691': 'locarna_best_subtree',
#  '692': 'ConsensusID',
#  '693': 'lca1',
#  '694': 'vcfsort',
#  '695': 'raceid_filtnormconf',
#  '696': 'cast',
#  '697': 'hmmer_hmmsearch',
#  '698': 'maldi_quant_peak_detection',
#  '699': 'bedtools_coveragebed',
#  '700': 'CONVERTER_gz_to_uncompressed',
#  '701': 'w4mcorcov',
#  '702': 'tp_sed_tool',
#  '703': 'enhanced_bowtie_wrapper',
#  '704': 'deg_annotate',
#  '705': 'cshl_fastx_trimmer',
#  '706': 'mothur_rarefaction_single',
#  '707': 'umi_tools_group',
#  '708': 'dexseq_annotate',
#  '709': 'extract_bcs.py',
#  '710': 'silac_analyzer',
#  '711': 'raceid_trajectory',
#  '712': '__ZIP_COLLECTION__',
#  '713': 'minfi_dropsnp',
#  '714': 'kraken-translate',
#  '715': 'annotatemyids',
#  '716': 'group_humann2_uniref_abundances_to_go',
#  '717': '16Sclassifier',
#  '718': 'openms_protein_quantifier',
#  '719': 'vcfannotate',
#  '720': 'join1',
#  '721': 'CONVERTER_interval_to_bed_0',
#  '722': 'mass_spectrometry_imaging_combine',
#  '723': 'cardinal_spectra_plots',
#  '724': 'cshl_cut_tool',
#  '725': 'cardinal_data_exporter',
#  '726': 'query_tabular',
#  '727': 'bedtools_intersectbed',
#  '728': 'vegan_rarefaction',
#  '729': 'flexbar_no_split',
#  '730': 'tp_cut_tool',
#  '731': 'hisat2',
#  '732': 'cardinal_mz_images',
#  '733': 'ncbi_rpsblast_wrapper',
#  '734': 'msgfplus',
#  '735': 'gops_join_1',
#  '736': 'samtools_calmd',
#  '737': 'bctools_remove_tail',
#  '738': 'trim_reads',
#  '739': 'fastq_quality_trimmer',
#  '740': 'cshl_fastx_nucleotides_distribution',
#  '741': 'metaphlan_hclust_heatmap',
#  '742': 'fastq_to_fasta_python',
#  '743': 'rnbeads',
#  '744': 'mimodd_varreport',
#  '745': 'cufflinks_prok',
#  '746': 'gatk2_realigner_target_creator',
#  '747': 'length_and_gc_content',
#  '748': 'ia_coordinates_of_roi',
#  '749': 'CONVERTER_sam_to_unsorted_bam',
#  '750': 'picard_MarkDuplicatesWithMateCigar',
#  '751': 'metaphlan2krona',
#  '752': 'cuffcompare',
#  '753': 'react_cal_pipeline',
#  '754': 'seq_composition',
#  '755': 'tp_grep_tool',
#  '756': 'umi_tools_whitelist',
#  '757': 'IDFilter',
#  '758': 'bcftools_call',
#  '759': 'FeatureLinkerUnlabeled',
#  '760': 'gatk_realigner_target_creator',
#  '761': 'ip_projective_transformation_points',
#  '762': 'lastz_wrapper_2',
#  '763': 'vcffilter2',
#  '764': 'bcftools_view',
#  '765': 'abims_CAMERA_annotateDiffreport',
#  '766': 'graphclust_aggregate_alignments',
#  '767': 'rnaz',
#  '768': 'p_clip_peaks',
#  '769': 'deeptools_compute_gc_bias',
#  '770': 'Extractor',
#  '771': 'tp_find_and_replace',
#  '772': 'deeptools_bigwig_compare',
#  '773': 'bedtools_sortbed',
#  '774': 'hcluster_sg_parser',
#  '775': 'cshl_awk_tool',
#  '776': 'fasta_filter_by_length',
#  '777': 'smf_utils_filter-by-energy',
#  '778': 'correctGCBias',
#  '779': 'CONVERTER_fasta_to_tabular',
#  '780': 'megablast_wrapper',
#  '781': 'MapRTTransformer',
#  '782': 'deeptools_plot_coverage',
#  '783': 'picard_AddOrReplaceReadGroups',
#  '784': 'mimodd_varcall',
#  '785': 'sed_stream_editor',
#  '786': 'DatamashTranspose',
#  '787': 'picard_SamToFastq',
#  '788': 'rbc_splitfasta',
#  '789': 'smf_utils_estimate-energy',
#  '790': 'methtools_calling',
#  '791': 'gops_concat_1',
#  '792': 'join_files_on_column_fuzzy',
#  '793': 'qiime_make_otu_heatmap',
#  '794': 'vcf2pgSnp',
#  '795': 'cshl_princeton_fastx_barcode_splitter',
#  '796': 'decoyfasta',
#  '797': 'cuffmerge',
#  '798': 'tophat2',
#  '799': 'CometAdapter',
#  '800': 'metaphlan2',
#  '801': 'CONVERTER_bed_to_gff_0',
#  '802': 'bam_to_bigwig',
#  '803': 'rseqc_read_distribution',
#  '804': 'rmcontamination',
#  '805': 'cshl_easyjoin',
#  '806': 'rseqc_bam_stat',
#  '807': 'dexseq',
#  '808': 'kallisto_quant',
#  '809': 'fragmenter',
#  '810': 'ctb_simsearch',
#  '811': 'tp_awk_tool',
#  '812': 'gatk2_base_recalibrator',
#  '813': 'flexbardsc',
#  '814': 'cummeRbund',
#  '815': 'rsem_prepare_reference',
#  '816': 'merge_pcr_duplicates.py',
#  '817': 'deeptools_plot_heatmap',
#  '818': 'Univariate',
#  '819': 'raceid_inspectclusters',
#  '820': 'scaffold2fasta',
#  '821': 'bed2gff1',
#  '822': 'deseq2_single',
#  '823': 'deeptools_heatmapper',
#  '824': 'peptide_shaker',
#  '825': 'aggregate_scores_in_intervals2',
#  '826': 'cshl_fasta_formatter',
#  '827': 'qiime_split_libraries_fastq',
#  '828': 'abims_xcms_xcmsSet',
#  '829': 'Convert characters1',
#  '830': 'sickle',
#  '831': 'msconvert2_raw',
#  '832': 'FROGS_preprocess',
#  '833': 'mothur_align_seqs',
#  '834': 'abricate',
#  '835': 'umi_tools_extract',
#  '836': 'interproscan',
#  '837': 'ete_genetree_splitter',
#  '838': 'cardinal_combine',
#  '839': 'gmx_setup',
#  '840': 'gemini_pathways',
#  '841': 'gops_basecoverage_1',
#  '842': 'plotly_parallel_coordinates_plot',
#  '843': 'mothur_chimera_uchime',
#  '844': 'picard_MergeSamFiles',
#  '845': 'samtool_filter2',
#  '846': 'MultiplexResolver',
#  '847': 'nanoplot',
#  '848': 'ProteinResolver',
#  '849': 'scale_image',
#  '850': 'trimmer',
#  '851': 'preproc',
#  '852': 'bedtools_coveragebed_counts',
#  '853': 'mothur_classify_seqs',
#  '854': 'snippy_core',
#  '855': 'mothur_seq_error',
#  '856': 'kraken-filter',
#  '857': 'sam_merge2',
#  '858': 'sklearn_build_pipeline',
#  '859': 'cshl_fastx_renamer',
#  '860': 'bigwig_to_bedgraph',
#  '861': 'peakcalling_macs14',
#  '862': 'snpeff_to_peptides',
#  '863': 'minimap2',
#  '864': 'tag_stat2',
#  '865': 'varscan_copynumber',
#  '866': 'remove_tail.py',
#  '867': 'FeatureLinkerUnlabeledQT',
#  '868': 'tp_tac',
#  '869': 'pureclip',
#  '870': 'sklear_numeric_clustering',
#  '871': 'bed_to_bigBed',
#  '872': 'get_subontology_from',
#  '873': 'fasta_merge_files_and_filter_unique_sequences',
#  '874': 'mothur_phylotype',
#  '875': 'macs2_predictd',
#  '876': 'unicycler',
#  '877': 'deseq2',
#  '878': 'deeptools_bamFingerprint',
#  '879': 'checkFormat',
#  '880': 'picard_ValidateSamFile',
#  '881': 'glob_report',
#  '882': 'fastq_join',
#  '883': 'dt_profiler',
#  '884': 'mothur_homova',
#  '885': 'PicardASMetrics',
#  '886': 'stacks_genotypes',
#  '887': 'tp_tail_tool',
#  '888': 'meme_psp_gen',
#  '889': 'deeptools_computeMatrix',
#  '890': 'SequenceCoverageCalculator',
#  '891': 'meme_chip',
#  '892': 'proteomics_search_peptide_prophet_1',
#  '893': 'peakachu',
#  '894': 'collapse_dataset',
#  '895': 'trimmomatic',
#  '896': 'datamash_transpose',
#  '897': 'venn_list',
#  '898': 'translate_bed_sequences',
#  '899': 'ncbi_blastn_wrapper',
#  '900': 'mass_spectrometry_imaging_filtering',
#  '901': 'deeptools_compute_matrix',
#  '902': 'stacks_procrad',
#  '903': 'TrimPrimer',
#  '904': 'macs2_bdgcmp',
#  '905': 'mothur_make_group',
#  '906': 'samtools_rmdup',
#  '907': 'gatk_indel_realigner',
#  '908': 'proteomics_search_tandem_1',
#  '909': 'gatk2_print_reads',
#  '910': 'mycrobiota-make-multi-otutable',
#  '911': 'vcfflatten2',
#  '912': 'cardinal_preprocessing',
#  '913': 'bedtools_complementbed',
#  '914': 'deeptools_bamCoverage',
#  '915': 'gatk_unified_genotyper',
#  '916': 'sklearn_searchcv',
#  '917': 'cor2',
#  '918': 'chipsequtil_maptoknowngenes',
#  '919': 'extract_aln_ends.py',
#  '920': 'EMBOSS: getorf42',
#  '921': 'MzTabExporter',
#  '922': 'ete_homology_classifier',
#  '923': 'cshl_fastx_reverse_complement',
#  '924': 'prokka',
#  '925': 'cshl_find_and_replace',
#  '926': 'regex1',
#  '927': 'sklearn_ensemble',
#  '928': 'IDMerger',
#  '929': 'heatmap2',
#  '930': 'deeptools_plot_enrichment',
#  '931': 'jbrowse',
#  '932': 'muscle',
#  '933': 'EMBOSS: revseq82',
#  '934': 'rgPicardMarkDups',
#  '935': 'mothur_get_groups',
#  '936': 'tp_replace_in_column',
#  '937': 'mothur_nmds',
#  '938': 'meme_fimo',
#  '939': 'hgv_snpFreq',
#  '940': 'FileFilter',
#  '941': 'fastq_paired_end_joiner',
#  '942': 'paralyzer',
#  '943': 'cat1',
#  '944': 'vcffilter',
#  '945': 'cuffdiff',
#  '946': 'snpSift_filter',
#  '947': 'mlocarna',
#  '948': 'snpSift_annotate',
#  '949': 'gmx_nvt',
#  '950': 'FileConverter',
#  '951': 'idpqonvert',
#  '952': 'Remove_ending',
#  '953': 'mothur_remove_seqs',
#  '954': 'ctb_filter',
#  '955': 'mcClust',
#  '956': 'cshl_word_list_grep',
#  '957': 'rarefaction_analyzer',
#  '958': 'bedtools_genomecoveragebed',
#  '959': 'bamFilter',
#  '960': 'mimodd_vcf_filter',
#  '961': 'mass_spectrometry_imaging_preprocessing',
#  '962': 'bg_statistical_hypothesis_testing',
#  '963': 'bismark_bowtie',
#  '964': 'map_peptides_to_bed',
#  '965': 'tp_cat',
#  '966': 'wiggle2simple1',
#  '967': 'graphclust_glob_report_no_align',
#  '968': 'bedtools_intersectbed_bam',
#  '969': 'EMBOSS: water107',
#  '970': 'blockclust',
#  '971': 'FeatureFinderMetabo'}

# %%
def verify_model(model, tool_sequence, labels, dictionary, reverse_dictionary, compatible_tools, topk=30, max_seq_len=25):
    tl_seq = tool_sequence.split(",")
    last_tool_name = reverse_dictionary[str(tl_seq[-1])]
    last_compatible_tools = compatible_tools[last_tool_name]
    sample = np.zeros(max_seq_len)
    for idx, tool_id in enumerate(tl_seq):
        sample[idx] = int(tool_id)
    sample_reshaped = np.reshape(sample, (1, max_seq_len))
    
    tool_sequence_names = [reverse_dictionary[str(tool_pos)] for tool_pos in tool_sequence.split(",")]
    print("Tool seq: %s" % ",".join(tool_sequence_names))
    # predict next tools for a test path
    prediction = model.predict(sample_reshaped, verbose=0)
    prediction = np.reshape(prediction, (prediction.shape[1],))
    prediction_pos = np.argsort(prediction, axis=-1)

    # get topk prediction
    topk_prediction_pos = prediction_pos[-topk:]
    topk_prediction_val = [np.round(prediction[pos] * 100, 2) for pos in topk_prediction_pos]

    # read tool names using reverse dictionary
    pred_tool_ids = [reverse_dictionary[str(tool_pos)] for tool_pos in topk_prediction_pos]
    actual_next_tool_ids = list(set(pred_tool_ids).intersection(set(last_compatible_tools.split(","))))      
        
    #print("Predicted tools: %s" % ",".join(pred_tool_ids))
    print()
    pred_tool_ids_sorted = dict()
    for (tool_pos, tool_pred_val) in zip(topk_prediction_pos, topk_prediction_val):
        tool_name = reverse_dictionary[str(tool_pos)]
        if tool_name in actual_next_tool_ids:
            pred_tool_ids_sorted[tool_name] = tool_pred_val
    pred_tool_ids_sorted = dict(sorted(pred_tool_ids_sorted.items(), key=lambda kv: kv[1], reverse=True))
    
    cls_wt = dict()
    usg_wt = dict()
    inv_wt = dict()
    ids_tools = dict()
    keys = list(pred_tool_ids_sorted.keys())
    for k in keys:
        try:
            cls_wt[k] = np.round(class_weights[str(data_dict[k])], 6)
            usg_wt[k] = np.round(usage_weights[k], 6)
            inv_wt[k] = np.round(inverted_weights[str(data_dict[k])], 6)
        except:
            continue
    print("Predicted tools: \n")
    print(pred_tool_ids_sorted)
    print()
    print("Class weights: \n")
    cls_wt = dict(sorted(cls_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(cls_wt)
    print()
    print("Usage weights: \n")
    usg_wt = dict(sorted(usg_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(usg_wt)
    print()
    print("Inverted weights: \n")
    inv_wt = dict(sorted(inv_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(inv_wt)
    for key in pred_tool_ids_sorted:
        ids_tools[key] = dictionary[key]
    print()
    print("Tool ids")
    print(ids_tools)
    print("======================================")
    return cls_wt, usg_wt, inv_wt, pred_tool_ids_sorted

topk = 10
# 895,533,260,894,596,114,297,896,387,626,486,720,361,283,943
tool_seq = "895"
class_wt, usage_wt, inverse_wt, pred_tools = verify_model(model, tool_seq, "", dictionary, reverse_dictionary, compatibile_tools, topk)
# Out:
# Tool seq: trimmomatic
#
# Predicted tools:
#
# {'fastqc': 61.53, 'rna_star': 4.29}
#
# Class weights:
#
# {'fastqc': 2.488489, 'rna_star': 1.015741}
#
# Usage weights:
#
# {'fastqc': 5879.0, 'rna_star': 642.153657}
#
# Inverted weights:
#
# {'rna_star': 2165.677419, 'fastqc': 808.86747}
#
# Tool ids
# {'fastqc': 533, 'rna_star': 213}
# ======================================

# %%
list_cls_wt = list()
list_usage_wt = list()
list_pred_wt = list()
division_pt = int(len(pred_tools) / 2)

for tool in pred_tools:
    list_pred_wt.append(pred_tools[tool])
    try:
        list_cls_wt.append(class_wt[tool])
    except:
        list_cls_wt.append(1)

def plot_scatter(y_val, title, xlabel, ylabel):
    x_val = range(1, len(y_val) + 1)
    plt.figure(figsize=(8, 8))
    plt.plot(x_val[:division_pt], y_val[:division_pt], 'ro')
    plt.plot(x_val[division_pt:], y_val[division_pt:], 'b^')
    plt.xlabel(xlabel, size=size_label)
    plt.ylabel(ylabel, size=size_label)
    plt.legend([("First top-%s" % str(division_pt)), ("Next top-%s" % str(division_pt))])
    plt.title(title, size=size_title)
    plt.grid(True)
    plt.show()

plot_scatter(list_cls_wt, "Usage weights for tools", "Number of tools", "Class weights")
#plot_scatter(ave_prediction_weights, ave_usage_weights, "Prediction vs usage weights", "Prediction scores", "Usage weights")
#plot_scatter(ave_prediction_weights, ave_inverted_weights, "Prediction vs inverted weights", "Prediction scores", "Inverted weights")
