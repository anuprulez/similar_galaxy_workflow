# %%
import numpy as np
import json
import warnings
import operator

import h5py
from keras.models import model_from_json
from keras import backend as K

from matplotlib import pyplot as plt

warnings.filterwarnings("ignore")

size_title = 18
size_label = 14
n_pred = 2 

base_path = "data/evaluate_usage_sigmoid_22_03/" # cluster path: 2_similar_galaxy_workflow

path_data_dict = base_path + "data_dict.txt"
path_usage_wt = base_path + "usage_prediction.txt"
path_class_wt = base_path + "class_weights.txt"
path_test_data = base_path + "test_paths_dict.txt"
model_path = base_path + "trained_model.hdf5"

def read_file(file_path):
    with open(file_path, 'r') as data_file:
        data = json.loads(data_file.read())
    return data

class_weights = read_file(path_class_wt)
usage_weights = read_file(path_usage_wt)
data_dict = read_file(path_data_dict)

def create_model(model_path):
    trained_model = h5py.File(model_path, 'r')
    model_config = json.loads(trained_model.get('model_config').value)
    loaded_model = model_from_json(model_config)
    dictionary = json.loads(trained_model.get('data_dictionary').value)
    compatibile_tools = json.loads(trained_model.get('compatible_tools').value)
    reverse_dictionary = dict((str(v), k) for k, v in dictionary.items())
    model_weights = list()
    weight_ctr = 0
    while True:
        try:
            d_key = "weight_" + str(weight_ctr)
            weights = trained_model.get(d_key).value
            model_weights.append(weights)
            weight_ctr += 1
        except Exception as exception:
            break
    # set the model weights
    loaded_model.set_weights(model_weights)
    return loaded_model, dictionary, reverse_dictionary, compatibile_tools

model, dictionary, reverse_dictionary, compatibile_tools = create_model(model_path)
# Out:
# Using TensorFlow backend.

# %%
reverse_dictionary
# Out:
# {'1': 'Convert characters1',
#  '2': 'bedtools_subtractbed',
#  '3': 'mycrobiota-krona-mothur',
#  '4': 'allele_counts_1',
#  '5': 'stacks_refmap',
#  '6': 'subtract_query1',
#  '7': 'samtools_stats',
#  '8': 'ggplot_histogram',
#  '9': 'picard_AddOrReplaceReadGroups',
#  '10': 'glimmer_knowlegde-based',
#  '11': 'bcftools_norm',
#  '12': 'pilon',
#  '13': 'pureclip',
#  '14': 'cshl_easyjoin',
#  '15': 'sed_stream_editor',
#  '16': 'idpassemble',
#  '17': 'hmmer_hmmsearch',
#  '18': 'sam_to_bam',
#  '19': 'viz_overlay_moving_and_fixed_image',
#  '20': 'hgv_david',
#  '21': 'viennarna_rnaalifold',
#  '22': 'bedtools_complementbed',
#  '23': 'sklearn_searchcv',
#  '24': 'lfq_protein_quant',
#  '25': 'gtftobed12',
#  '26': 'react_cal_pipeline',
#  '27': 'ChangeCase',
#  '28': 'deeptools_heatmapper',
#  '29': 'mycrobiota-split-multi-otutable',
#  '30': 'ncbi_makeblastdb',
#  '31': 'ncbi_blastp_wrapper',
#  '32': 'je_markdupes',
#  '33': 'bedtools_shufflebed',
#  '34': 'w4mclassfilter',
#  '35': 'raceid_clustering',
#  '36': 'nspdk_sparse',
#  '37': 'pynast',
#  '38': 'CONVERTER_fasta_to_tabular',
#  '39': 'mothur_get_seqs',
#  '40': 't_coffee',
#  '41': 'FileMerger',
#  '42': 'tp_awk_tool',
#  '43': 'mothur_summary_single',
#  '44': 'vcffilter',
#  '45': 'uchime',
#  '46': 'bowtie_wrapper',
#  '47': '__MERGE_COLLECTION__',
#  '48': 'datamash_transpose',
#  '49': 'egsea',
#  '50': 'vt_normalize',
#  '51': 'RNAlien',
#  '52': 'bam2wig',
#  '53': 'hicexplorer_hicplottads',
#  '54': 'TrimPrimer',
#  '55': 'snpsift_vartype',
#  '56': 'Cut1',
#  '57': 'gops_intersect_1',
#  '58': 'gff2bed1',
#  '59': 'gffread',
#  '60': 'hgv_snpFreq',
#  '61': 'edger',
#  '62': 'deeptools_bamCorrelate',
#  '63': 'gatk2_variant_apply_recalibration',
#  '64': 'gops_subtract_1',
#  '65': 'minfi_getM',
#  '66': 'infernal_cmstat',
#  '67': 'gatk2_variant_annotator',
#  '68': 'Batch_correction',
#  '69': 'gatk2_variant_filtration',
#  '70': 'deeptools_bamFingerprint',
#  '71': 'nanoplot',
#  '72': 'cuffnorm',
#  '73': 'mothur_unique_seqs',
#  '74': 'structure_to_gspan',
#  '75': 'prokaryotic_ncbi_submission',
#  '76': 'hisat',
#  '77': 'picard_ReorderSam',
#  '78': 'smf_utils_fix-fasta-headers',
#  '79': 'mothur_rarefaction_single',
#  '80': 'gtf_filter_by_attribute_values_list',
#  '81': 'metilene',
#  '82': 'vcf2tsv',
#  '83': 'tp_sort_header_tool',
#  '84': 'convert_bc_to_binary_RY.py',
#  '85': 'IsobaricAnalyzer',
#  '86': 'fastq_paired_end_joiner',
#  '87': 'openms_id_mapper',
#  '88': 'FROGS_clustering',
#  '89': 'cshl_find_and_replace',
#  '90': 'bedtools_multicovtbed',
#  '91': 'gemini_windower',
#  '92': 'mothur_taxonomy_to_krona',
#  '93': 'graphlan_annotate',
#  '94': 'shovill',
#  '95': 'vcfcombine',
#  '96': 'gops_coverage_1',
#  '97': 'mothur_classify_rf',
#  '98': 'fasta_filter_by_length',
#  '99': 'mothur_tree_shared',
#  '100': 'flye',
#  '101': 'iReport',
#  '102': 'rmcontamination',
#  '103': 'tp_sed_tool',
#  '104': 'vcfgenotypes',
#  '105': 'venn_list',
#  '106': 'mass_spectrometry_imaging_preprocessing',
#  '107': 'bcftools_consensus',
#  '108': 'graphlan',
#  '109': 'fasplit',
#  '110': 'pileometh',
#  '111': 'hicexplorer_hicbuildmatrix',
#  '112': 'deeptools_plot_correlation',
#  '113': 'metaphlan_hclust_heatmap',
#  '114': 'minfi_ppfun',
#  '115': 'mothur_chimera_vsearch',
#  '116': 'fasta2tab',
#  '117': 'find_in_reference',
#  '118': 'ggplot2_point',
#  '119': 'vcfselectsamples',
#  '120': 'mergeCols1',
#  '121': 'mothur_phylotype',
#  '122': 'IDMassAccuracy',
#  '123': 'methtools_plot',
#  '124': 'deeptools_plot_enrichment',
#  '125': 'vcf2pgSnp',
#  '126': 'tophat_fusion_post',
#  '127': 'rbc_mafft',
#  '128': 'snpeff_to_peptides',
#  '129': 'bwa_mem',
#  '130': 'proteomics_moff',
#  '131': 'Extract_RNA_seq_Evidence',
#  '132': 'mimodd_varcall',
#  '133': 'je_clip',
#  '134': 'Psortb',
#  '135': 'ctb_simsearch',
#  '136': 'gemini_load',
#  '137': 'proteomics_search_protein_prophet_1',
#  '138': 'sample_seqs',
#  '139': 'spades',
#  '140': 'signalp3',
#  '141': 'seq_filter_by_mapping',
#  '142': 'deeptools_bam_coverage',
#  '143': 'mothur_cluster',
#  '144': 'modencode_peakcalling_macs2',
#  '145': 'gmx_md',
#  '146': 'lca1',
#  '147': 'locarna_multiple',
#  '148': 'get_sequences',
#  '149': 'bctools_remove_spurious_events',
#  '150': 'PeakPickerHiRes',
#  '151': 'metams_runGC',
#  '152': 'minfi_maptogenome',
#  '153': 'addName',
#  '154': 'velvet',
#  '155': 'mass_spectrometry_imaging_ion_images',
#  '156': 'graphicsmagick_image_convert',
#  '157': 'dt_profiler',
#  '158': 'bedtools_coveragebed_counts',
#  '159': 'samtools_calmd',
#  '160': 'ExtractFASTAfromFASTQ',
#  '161': 'bg_sortmerna',
#  '162': 'w4mcorcov',
#  '163': 'aragorn_trna',
#  '164': 'samtools_rmdup',
#  '165': 'tsne',
#  '166': 'graphclust_aggregate_alignments',
#  '167': 'samtools_mpileup',
#  '168': 'picard_NormalizeFasta',
#  '169': 'rbc_mirdeep2',
#  '170': 'humann2_genefamilies_genus_level',
#  '171': 'deeptools_profiler',
#  '172': 'mothur_metastats',
#  '173': 'featurecounts',
#  '174': 'sqlite_to_tabular',
#  '175': 'gatk_realigner_target_creator',
#  '176': 'bg_column_arrange_by_header',
#  '177': 'qiime_make_phylogeny',
#  '178': 'NSPDK_candidateClust',
#  '179': 'XTandemAdapter',
#  '180': 'vcfflatten2',
#  '181': 'cshl_princeton_fastx_barcode_splitter',
#  '182': 'length_and_gc_content',
#  '183': 'deeptools_computeGCBias',
#  '184': 'mothur_screen_seqs',
#  '185': 'cshl_sed_tool',
#  '186': 'ruvseq',
#  '187': 'flexbar_no_split',
#  '188': 'gatk2_reduce_reads',
#  '189': 'bedtools_intersectBed',
#  '190': 'sam_pileup',
#  '191': 'picard_CleanSam',
#  '192': 'bedtools_sortbed',
#  '193': 'chipsequtil_maptoknowngenes',
#  '194': 'w4mclstrpeakpics',
#  '195': 'vcfsort',
#  '196': 'infernal_cmbuild',
#  '197': 'tp_sort_rows',
#  '198': 'mothur_venn',
#  '199': 'minfi_dmp',
#  '200': 'mothur_sub_sample',
#  '201': 'fasta_merge_files_and_filter_unique_sequences',
#  '202': 'fastq_paired_end_deinterlacer',
#  '203': 'CONVERTER_bed_to_bgzip_0',
#  '204': 'term_id_vs_term_name',
#  '205': 'FidoAdapter',
#  '206': 'mycrobiota-otutable_add_blast',
#  '207': 'fasta-stats',
#  '208': 'Nucleosome',
#  '209': 'megablast_wrapper',
#  '210': 'umi_tools_group',
#  '211': 'multiqc',
#  '212': 'fastq_paired_end_splitter',
#  '213': 'deeptools_correctGCBias',
#  '214': 'sort1',
#  '215': 'EMBOSS: tranalign100',
#  '216': 'hicexplorer_hicsummatrices',
#  '217': 'replace_column_with_key_value_file',
#  '218': 'cuffcompare',
#  '219': 'samtools_bedcov',
#  '220': 'gemini_pathways',
#  '221': 'gops_basecoverage_1',
#  '222': 'hicexplorer_hiccorrectmatrix',
#  '223': 'Datamash',
#  '224': 'make_families',
#  '225': 'fasta_compute_length',
#  '226': 'vcfallelicprimitives',
#  '227': 'MapStatistics',
#  '228': '__APPLY_RULES__',
#  '229': 'FeatureFinderCentroided',
#  '230': 'biosigner',
#  '231': 'freebayes',
#  '232': 'taxonomy_krona_chart',
#  '233': 'gatk2_haplotype_caller',
#  '234': 'umi_tools_count',
#  '235': 'picard_ValidateSamFile',
#  '236': 'tophat2',
#  '237': 'cshl_fastq_to_fasta',
#  '238': 'velvetg_jgi',
#  '239': 'gemini_de_novo',
#  '240': 'wiggle2simple1',
#  '241': 'FalseDiscoveryRate',
#  '242': 'MapRTTransformer',
#  '243': 'group_humann2_uniref_abundances_to_go',
#  '244': 'Multivariate',
#  '245': 'prokka',
#  '246': 'valet',
#  '247': 'gtf2bedgraph',
#  '248': 'extract_bcs.py',
#  '249': 'uniprot',
#  '250': 'deeptools_correct_gc_bias',
#  '251': 'ctb_compound_convert',
#  '252': 'rseqc_bam_stat',
#  '253': 'blast_parser',
#  '254': 'FileConverter',
#  '255': 'regex_replace',
#  '256': 'align_families',
#  '257': 'gd_raxml',
#  '258': 'meme_meme',
#  '259': 'annotatemyids',
#  '260': 'ssake',
#  '261': 'mass_spectrometry_imaging_mzplots',
#  '262': 'gatk_unified_genotyper',
#  '263': 'mcClust',
#  '264': 'extract_element_from_collection',
#  '265': 'FROGS_affiliation_OTU',
#  '266': 'sam_bw_filter',
#  '267': 'peptide_shaker',
#  '268': 'IDConflictResolver',
#  '269': 'mimodd_map',
#  '270': 'megablast_xml_parser',
#  '271': 'pieplots_macs',
#  '272': 'FeatureLinkerUnlabeledQT',
#  '273': 'flexbar_split_RYYR_bcs',
#  '274': 'tophat',
#  '275': 'sklearn_numeric_clustering',
#  '276': 'htseq_count',
#  '277': 'stacks_denovomap',
#  '278': 'smf_utils_estimate-energy',
#  '279': 'snippy',
#  '280': 'cardinal_combine',
#  '281': 'mothur_filter_seqs',
#  '282': 'qiime_pick_rep_set',
#  '283': 'flexbar',
#  '284': 'export2graphlan',
#  '285': 'raceid_filtnormconf',
#  '286': 'mothur_summary_seqs',
#  '287': 'stringtie',
#  '288': 'r_correlation_matrix',
#  '289': 'htseq-count',
#  '290': 'column_remove_by_header',
#  '291': 'QCCalculator',
#  '292': 'hcluster_sg_parser',
#  '293': 'picard_ARRG',
#  '294': 'viennarna_rnaplot',
#  '295': 'bcftools_view',
#  '296': 'mothur_parsimony',
#  '297': 'preproc',
#  '298': 'gemini_annotate',
#  '299': 'ia_coordinates_of_roi',
#  '300': 'cuffdiff',
#  '301': 'CONVERTER_bed_gff_or_vcf_to_bigwig_0',
#  '302': 'PicardASMetrics',
#  '303': 'fastq_join',
#  '304': 'wolf_psort',
#  '305': 'pileup_parser',
#  '306': 'mimodd_vcf_filter',
#  '307': '__ZIP_COLLECTION__',
#  '308': 'minfi_getbeta',
#  '309': 'tp_grep_tool',
#  '310': 'bamCoverage_deepTools',
#  '311': 'mothur_merge_files',
#  '312': 'samtools_flagstat',
#  '313': 'snpSift_dbnsfp_generic',
#  '314': 'EMBOSS: wordcount109',
#  '315': 'nonpareil',
#  '316': 'paralyzer',
#  '317': 'sequence_content_trimmer',
#  '318': 'scaffold2fasta',
#  '319': 'picard_CollectInsertSizeMetrics',
#  '320': 'get_feature_info',
#  '321': 'salmon',
#  '322': 'sklearn_feature_selection',
#  '323': 'diffbind-embl',
#  '324': 'bed_to_bigBed',
#  '325': 'mothur_pre_cluster',
#  '326': 'deeptools_bigwig_compare',
#  '327': 'rcas',
#  '328': 'bedtools_intersectbed',
#  '329': 'abims_xcms_fillPeaks',
#  '330': 'minfi_dropsnp',
#  '331': 'bedtools_intersectbed_bam',
#  '332': 'fasttree',
#  '333': 'cshl_grep_tool',
#  '334': 'Grep1',
#  '335': 'samtools_flag_filter',
#  '336': 'get_child_terms',
#  '337': 'CONVERTER_Bam_Bai_0',
#  '338': 'macs2_bdgcmp',
#  '339': 'blastxml_to_tabular',
#  '340': 'vcfbedintersect',
#  '341': 'mimodd_varextract',
#  '342': 'tp_cat',
#  '343': 'bctools_extract_alignment_ends',
#  '344': 'rm_spurious_events.py',
#  '345': 'mothur_homova',
#  '346': 'deeptools_compute_matrix',
#  '347': 'ngsutils_bam_filter',
#  '348': 'FastTree',
#  '349': 'deeptools_multi_bam_summary',
#  '350': 't2t_report',
#  '351': 'antismash',
#  '352': 'deseq2',
#  '353': 'lastz_wrapper_2',
#  '354': 'MassCalculator',
#  '355': 'Show beginning1',
#  '356': 'heatmapper',
#  '357': 'FROGS_filters',
#  '358': 'cshl_awk_tool',
#  '359': 'sam2interval',
#  '360': 'meme_psp_gen',
#  '361': 'enhanced_bowtie_wrapper',
#  '362': 'tp_tail_tool',
#  '363': 'tp_sorted_uniq',
#  '364': 'fastq_combiner',
#  '365': 'join_files_on_column_fuzzy',
#  '366': 'bg_uniq',
#  '367': 'porechop',
#  '368': 'gmx_nvt',
#  '369': 'cshl_fastx_clipper',
#  '370': 'mass_spectrometry_imaging_combine',
#  '371': 'cshl_fastx_trimmer',
#  '372': 'minfi_qc',
#  '373': 'tp_uniq_tool',
#  '374': 'augustus',
#  '375': 'ctb_online_data_fetch',
#  '376': 'numeric_clustering',
#  '377': 'bedtools_windowbed',
#  '378': 'wc_gnu',
#  '379': 'cummerbund_to_cuffdiff',
#  '380': 'deg_annotate',
#  '381': 'disco',
#  '382': 'tp_find_and_replace',
#  '383': 'bedtools_bamtofastq',
#  '384': 'vcftools_isec',
#  '385': 'secretbt2test',
#  '386': 'rgPicFixMate',
#  '387': 'bedtools_annotatebed',
#  '388': 'smooth_running_window',
#  '389': 'FeatureFinderMultiplex',
#  '390': 'heinz_visualization',
#  '391': 'tag_stat2',
#  '392': 'rgweblogo3',
#  '393': 'tp_replace_in_column',
#  '394': 'hicexplorer_hicfindtads',
#  '395': 'bamleftalign',
#  '396': 'column_order_header_sort',
#  '397': 'mycrobiota-qc-report',
#  '398': 'bedtools_coveragebed',
#  '399': 'mycrobiota-correct-replicates',
#  '400': 'bandage_image',
#  '401': 'cardinal_data_exporter',
#  '402': 'heinz_bum',
#  '403': 'blockclust',
#  '404': 'bedtools_genomecoveragebed_bedgraph',
#  '405': '__RELABEL_FROM_FILE__',
#  '406': 'mothur_count_seqs',
#  '407': 'abims_CAMERA_annotateDiffreport',
#  '408': 'deeptools_bam_compare',
#  '409': 'mass_spectrometry_imaging_filtering',
#  '410': 'mothur_nmds',
#  '411': 'IDFilter',
#  '412': 'FeatureLinkerUnlabeled',
#  '413': 'minimap2',
#  '414': 'gemini_comp_hets',
#  '415': 'EMBOSS: extractseq35',
#  '416': 'snpfinder',
#  '417': 'snippy_core',
#  '418': 'samtools_split',
#  '419': 'NFS_transfer',
#  '420': 'nn_classifier',
#  '421': 'scale_image',
#  '422': 'picard_EstimateLibraryComplexity',
#  '423': 'bcftools_call',
#  '424': 'thermo_raw_file_converter',
#  '425': 'interproscan',
#  '426': 'gatk2_print_reads',
#  '427': 'gemini_interactions',
#  '428': 'picard_MarkDuplicatesWithMateCigar',
#  '429': 'samtools_idxstats',
#  '430': 'selectsequencesfrommsa',
#  '431': 'EMBOSS: newseq59',
#  '432': 'tp_split_on_column',
#  '433': 'gops_concat_1',
#  '434': 'abims_xcms_group',
#  '435': 'mlocarna',
#  '436': 'fastq_groomer',
#  '437': 'tp_tac',
#  '438': 'varscan_copynumber',
#  '439': 'vcf_filter',
#  '440': 'mothur_chimera_uchime',
#  '441': 'fastq collapser',
#  '442': 'Show tail1',
#  '443': 'ete_homology_classifier',
#  '444': 'fastq_to_fasta_python',
#  '445': 'ggplot2_heatmap2',
#  '446': 'picard_FilterSamReads',
#  '447': 'flanking_features_1',
#  '448': '__FILTER_FAILED_DATASETS__',
#  '449': 'gmx_setup',
#  '450': 'rseqc_inner_distance',
#  '451': 'hisat2',
#  '452': 'extract_aln_ends.py',
#  '453': 'macs2_callpeak',
#  '454': 'get_subontology_from',
#  '455': 'mothur_trim_seqs',
#  '456': 'cshl_fastx_barcode_splitter',
#  '457': 'goseq',
#  '458': 'varscan_mpileup',
#  '459': 'bowtie2',
#  '460': 'PicardInsertSize',
#  '461': 'mothur_remove_lineage',
#  '462': 'fastq_manipulation',
#  '463': 'FROGS_remove_chimera',
#  '464': 'mothur_align_seqs',
#  '465': 'mothur_classify_seqs',
#  '466': 'humann2_renorm_table',
#  '467': 'msgfplus',
#  '468': 'bctools_extract_crosslinked_nucleotides',
#  '469': '__UNZIP_COLLECTION__',
#  '470': 'seurat',
#  '471': 'fastq_paired_end_interlacer',
#  '472': 'samtools_sort',
#  '473': 'tab2fasta',
#  '474': 'stacks_populations',
#  '475': 'metaspades',
#  '476': 'plotly_ml_performance_plots',
#  '477': 'format_metaphlan2_output',
#  '478': 'p_clip_peaks',
#  '479': 'fastq_filter',
#  '480': 'Paste1',
#  '481': 'MSGFPlusAdapter',
#  '482': 'table_annovar',
#  '483': 'charts',
#  '484': 'addValue',
#  '485': 'bedtools_mergebed',
#  '486': 'circgraph',
#  '487': 'Determine_BC',
#  '488': 'gemini_actionable_mutations',
#  '489': 'raceid_inspectclusters',
#  '490': 'FeatureLinkerUnlabeledKD',
#  '491': 'Count1',
#  '492': 'aggregate_scores_in_intervals2',
#  '493': 'gmx_solvate',
#  '494': 'query_tabular',
#  '495': 'mothur_get_oturep',
#  '496': 'cardinal_quality_report',
#  '497': 'EMBOSS: fuzztran39',
#  '498': 'EMBOSS: textsearch98',
#  '499': 'CONVERTER_fastqgz_to_fastq',
#  '500': 'nanopolish_variants',
#  '501': 'regex1',
#  '502': 'IDScoreSwitcher',
#  '503': 'mothur_dist_shared',
#  '504': 'modencode_peakcalling_spp',
#  '505': 'predict_pipeline',
#  '506': 'mothur_heatmap_sim',
#  '507': 'cshl_word_list_grep',
#  '508': 'hicexplorer_hictransform',
#  '509': 'samtools_filter',
#  '510': 'kraken-report',
#  '511': 'svm_classifier',
#  '512': 'rgPicardMarkDups',
#  '513': 'trim_reads',
#  '514': 'cshl_sort_header',
#  '515': 'ggplot2_heatmap',
#  '516': 'cast',
#  '517': 'sklearn_nn_classifier',
#  '518': 'rseqc_read_duplication',
#  '519': 'heinz',
#  '520': 'piranha',
#  '521': 'metaphlan2krona',
#  '522': 'msconvert_nix',
#  '523': 'locarna_best_subtree',
#  '524': 'createInterval',
#  '525': 'TextExporter',
#  '526': 'quast',
#  '527': 'FileFilter',
#  '528': 'silac_analyzer',
#  '529': 'smf_utils_filter-by-energy',
#  '530': 'fastq_dump',
#  '531': 'glimmer_not-knowlegde-based',
#  '532': 'minfi_dmr',
#  '533': 'minfi_read450k',
#  '534': 'rseqc_geneBody_coverage',
#  '535': 'tp_easyjoin_tool',
#  '536': 'gemini_db_info',
#  '537': 'viennarna_rnafold',
#  '538': 'ip_projective_transformation_points',
#  '539': 'Btrim64',
#  '540': 'gemini_burden',
#  '541': 'bedtools_bamtobed',
#  '542': 'snpEff_download',
#  '543': 'raceid_trajectory',
#  '544': 'openms_id_file_converter',
#  '545': 'mothur_cluster_split',
#  '546': 'minfi_getanno',
#  '547': 'xpath',
#  '548': 'eden_vectorizer',
#  '549': 'seq_composition',
#  '550': 'gops_join_1',
#  '551': 'dunovo',
#  '552': 'fraggenescan',
#  '553': 'flexbardsc',
#  '554': 'gmx_npt',
#  '555': 'rbc_rnacode',
#  '556': 'vegan_diversity',
#  '557': 'bamtools',
#  '558': 'GeneModelMapper',
#  '559': 'qiime_assign_taxonomy',
#  '560': 'DatamashTranspose',
#  '561': 'mass_spectrometry_imaging_qc',
#  '562': 'cshl_fastx_collapser',
#  '563': 'rseqc_bam2wig',
#  '564': 'blockbuster',
#  '565': 'kallisto_quant',
#  '566': 'bedtools_unionbedgraph',
#  '567': 'umi_tools_dedup',
#  '568': 'cardinal_segmentations',
#  '569': 'bedtools_multiintersectbed',
#  '570': 'mothur_seq_error',
#  '571': 'mothur_count_groups',
#  '572': 'seq_filter_by_id',
#  '573': 'tp_head_tool',
#  '574': 'cardinal_preprocessing',
#  '575': 'mz_to_sqlite',
#  '576': 'mycrobiota-make-multi-otutable',
#  '577': 'samtool_filter2',
#  '578': 'CONVERTER_gff_to_bed_0',
#  '579': 'gops_cluster_1',
#  '580': 'cardinal_filtering',
#  '581': 'metaphlan2',
#  '582': 'bedtools_bedtobam',
#  '583': 'ete_genetree_splitter',
#  '584': 'rbc_mirdeep2_quantifier',
#  '585': 'goenrichment',
#  '586': 'cutadapt',
#  '587': 'trimmomatic',
#  '588': 'fastqc',
#  '589': 'rna_star',
#  '590': 'je_demultiplex',
#  '591': 'ctb_ob_genProp',
#  '592': 'velvetoptimiser',
#  '593': '__SORTLIST__',
#  '594': 'methtools_destrand',
#  '595': 'cmFinder',
#  '596': 'bg_statistical_hypothesis_testing',
#  '597': 'msconvert3_raw',
#  '598': 'blastxml_to_tabular_selectable',
#  '599': 'mothur_get_communitytype',
#  '600': 'ProteinInference',
#  '601': 'FileInfo',
#  '602': 'treebest_best',
#  '603': 'blast2go',
#  '604': 'bam_to_bigwig',
#  '605': 'dexseq',
#  '606': 'cmv',
#  '607': 'minfi_mset',
#  '608': 'varscan_somatic',
#  '609': 'sailfish',
#  '610': 'IDFileConverter',
#  '611': 'methtools_calling',
#  '612': 'remove_tail.py',
#  '613': 'deeptools_multi_bigwig_summary',
#  '614': 'mothur_get_groups',
#  '615': 'cshl_cut_tool',
#  '616': 'Extract_features1',
#  '617': 'samtools_slice_bam',
#  '618': 'ncbi_tblastn_wrapper',
#  '619': 'mothur_make_biom',
#  '620': 'IDMapper',
#  '621': 'Extractor',
#  '622': 'segemehl',
#  '623': 'EMBOSS: getorf42',
#  '624': 'scpipe',
#  '625': 'ucsc-twobittofa',
#  '626': 'heatmap2',
#  '627': 'deeptools_bamCompare',
#  '628': 'meme_chip',
#  '629': 'hcluster_sg',
#  '630': 'bams2ratio',
#  '631': 'gatk2_unified_genotyper',
#  '632': 'dbbuilder',
#  '633': 'minfi_rset',
#  '634': 'rnafold',
#  '635': 'rseqc_junction_saturation',
#  '636': 'Extract genomic DNA 1',
#  '637': 'secure_hash_message_digest',
#  '638': 'mass_spectrometry_imaging_segmentations',
#  '639': 'bismark_bowtie',
#  '640': 'cat1',
#  '641': 'mothur_remove_seqs',
#  '642': 'roary',
#  '643': 'qiime_validate_mapping_file',
#  '644': 'glimmer_build-icm',
#  '645': 'fastq_to_tabular',
#  '646': 'ip_projective_transformation',
#  '647': 'idr-embl',
#  '648': 'genbank_to_gff',
#  '649': 'tp_cut_tool',
#  '650': 'ChooseTag',
#  '651': 'rnbeads',
#  '652': 'SequenceCoverageCalculator',
#  '653': 'fastq_trimmer',
#  '654': 'cardinal_spectra_plots',
#  '655': 'qiime_pick_closed_reference_otus',
#  '656': 'vcffilter2',
#  '657': 'proteomics_search_tandem_1',
#  '658': 'get_flanks1',
#  '659': 'merge_pcr_duplicates.py',
#  '660': '__FILTER_FROM_FILE__',
#  '661': 'filter_bed_on_splice_junctions',
#  '662': 'chipseeker',
#  '663': 'ConsensusID',
#  '664': 'umi_tools_whitelist',
#  '665': 'maldi_quant_peak_detection',
#  '666': 'FeatureFinderMetabo',
#  '667': 'humann2',
#  '668': 'gemini_query',
#  '669': 'Digestor',
#  '670': 'racon',
#  '671': 'ctb_remIons',
#  '672': 'tmhmm2',
#  '673': 'CONVERTER_interval_to_bgzip_0',
#  '674': 'resistome_analyzer',
#  '675': 'sklearn_svm_classifier',
#  '676': 'CONVERTER_interval_to_bedstrict_0',
#  '677': 'raceid_inspecttrajectory',
#  '678': 'computeMatrix',
#  '679': 'CONVERTER_sam_to_unsorted_bam',
#  '680': 'ncbi_blastx_wrapper',
#  '681': 'snpSift_geneSets',
#  '682': 'datamash_ops',
#  '683': 'EMBOSS: transeq101',
#  '684': 'histogram_rpy',
#  '685': 'bg_protein_properties',
#  '686': 'bedtools_getfastabed',
#  '687': 'mass_spectrometry_imaging_classification',
#  '688': 'combine_metaphlan2_humann2',
#  '689': 'sam_merge2',
#  '690': 'cshl_fasta_formatter',
#  '691': '16Saligner',
#  '692': 'XY_Plot_1',
#  '693': 'GeMoMa_Annotation_Filter',
#  '694': 'deeptools_plot_heatmap',
#  '695': 'stringtie_merge',
#  '696': 'checkFormat',
#  '697': 'vcffixup',
#  '698': 'humann2_regroup_table',
#  '699': 'vsearch_dereplication',
#  '700': 'fragmenter',
#  '701': 'bed_to_bigwig',
#  '702': 'barchart_gnuplot',
#  '703': 'picard_SortSam',
#  '704': 'Remove_ending',
#  '705': 'correct_barcodes',
#  '706': 'MultiplexResolver',
#  '707': 'trimmer',
#  '708': 'cor2',
#  '709': 'abricate',
#  '710': 'qiime_core_diversity',
#  '711': 'CometAdapter',
#  '712': 'bed2gff1',
#  '713': 'melt',
#  '714': 'ctb_remSmall',
#  '715': 'cshl_fastx_reverse_complement',
#  '716': 'rbc_mirdeep2_mapper',
#  '717': 'idpquery',
#  '718': 'bundle_collection',
#  '719': 'naive_variant_caller',
#  '720': 'CONVERTER_bed_to_gff_0',
#  '721': 'cd_hit_dup',
#  '722': 'bismark_bowtie2',
#  '723': 'krona-text',
#  '724': 'gmx_em',
#  '725': 'snpSift_annotate',
#  '726': 'tp_unfold_column_tool',
#  '727': 'wsdl_hmdb',
#  '728': 'cshl_awk_replace_in_column',
#  '729': 'picard_MarkDuplicates',
#  '730': 'deeptools_plot_pca',
#  '731': 'preMloc',
#  '732': 'rsem_calculate_expression',
#  '733': 'eden_sequence_converter',
#  '734': 'picard_FixMateInformation',
#  '735': 'hicexplorer_hicmergematrixbins',
#  '736': 'mimodd_varreport',
#  '737': 'deeptools_plot_profile',
#  '738': 'picard_CASM',
#  '739': 'coords2clnt.py',
#  '740': 'deeptools_compute_matrix_operations',
#  '741': 'snpSift_filter',
#  '742': 'peakcalling_macs14',
#  '743': 'macs2_predictd',
#  '744': 'rseqc_read_distribution',
#  '745': 'Univariate',
#  '746': 'dexseq_annotate',
#  '747': 'Add_a_column1',
#  '748': 'meme_dreme',
#  '749': 'picard_SamToFastq',
#  '750': 'plotly_regression_performance_plots',
#  '751': 'Draw_phylogram',
#  '752': 'mothur_make_group',
#  '753': 'MapAlignerPoseClustering',
#  '754': 'ctb_change_title',
#  '755': 'tabular_to_fastq',
#  '756': 'gatk2_base_recalibrator',
#  '757': 'cuffmerge',
#  '758': 'Fetch Taxonomic Ranks',
#  '759': 'bgchem_fragment_merger',
#  '760': 'megahit',
#  '761': 'umi_tools_extract',
#  '762': 're_he_maldi_image_registration',
#  '763': 'EMBOSS: revseq82',
#  '764': 'varscan',
#  '765': 'mothur_corr_axes',
#  '766': 'mothur_lefse',
#  '767': 'kraken-filter',
#  '768': 'qiime_make_otu_heatmap',
#  '769': 'bamFilter',
#  '770': 'vcfvcfintersect',
#  '771': 'Interval_Maf_Merged_Fasta2',
#  '772': 'sklear_numeric_clustering',
#  '773': 'IDMerger',
#  '774': 'clustalw',
#  '775': 'TrimByN',
#  '776': 'bedtools_slopbed',
#  '777': 'sklearn_build_pipeline',
#  '778': 'cshl_fastx_artifacts_filter',
#  '779': 'glob_report',
#  '780': 'filter_by_fasta_ids',
#  '781': 'bedtools_genomecoveragebed_histogram',
#  '782': 'unipept',
#  '783': 'bctools_remove_tail',
#  '784': 'bwa',
#  '785': 'CONVERTER_interval_to_bed_0',
#  '786': 'ctb_filter',
#  '787': 'iuc_pear',
#  '788': 'MAF_To_Fasta1',
#  '789': 'myrimatch',
#  '790': '__FLATTEN__',
#  '791': 'vcftools_merge',
#  '792': 'EMBOSS: seqret84',
#  '793': 'decoyfasta',
#  '794': 'picard_CollectRnaSeqMetrics',
#  '795': 'sickle',
#  '796': 'bwa_wrapper',
#  '797': 'fgsea',
#  '798': 'unicycler',
#  '799': 'ProteinResolver',
#  '800': 'rarefaction',
#  '801': 'rbc_splitfasta',
#  '802': 'bwameth',
#  '803': 'cshl_multijoin',
#  '804': 'snpEff',
#  '805': 'vcftools_annotate',
#  '806': 'dexseq_count',
#  '807': 'gatk2_indel_realigner',
#  '808': 'deeptools_compute_gc_bias',
#  '809': 'join1',
#  '810': 'collapse_dataset',
#  '811': 'CONVERTER_gz_to_uncompressed',
#  '812': 'qiime_pick_otus',
#  '813': 'ConsensusMapNormalizer',
#  '814': 'bg_find_subsequences',
#  '815': 'EMBOSS: fuzzpro38',
#  '816': 'cshl_fasta_nucleotides_changer',
#  '817': 'graphclust_align_cluster',
#  '818': 'ncbi_blastn_wrapper',
#  '819': 'tp_multijoin_tool',
#  '820': 'openms_protein_quantifier',
#  '821': 'ctb_silicos_qed',
#  '822': 'CONVERTER_gff_to_interval_index_0',
#  '823': 'qiime_align_seqs',
#  '824': 'limma_voom',
#  '825': 'mothur_make_contigs',
#  '826': 'mothur_dist_seqs',
#  '827': 'hicexplorer_hicplotmatrix',
#  '828': 'FROGS_preprocess',
#  '829': 'abims_xcms_xcmsSet',
#  '830': 'wig_to_bigWig',
#  '831': 'get_read_pipeline',
#  '832': 'ggplot_point',
#  '833': 'uparse',
#  '834': 'cufflinks',
#  '835': 'minfi_methcpg',
#  '836': 'cummeRbund',
#  '837': 'msconvert2_raw',
#  '838': 'igvtools_count',
#  '839': 'cshl_fastx_nucleotides_distribution',
#  '840': 'raceid_main',
#  '841': 'kraken-translate',
#  '842': 'gatk_indel_realigner',
#  '843': 'qiime_split_libraries_fastq',
#  '844': 'cshl_uniq_tool',
#  '845': 'ProteinQuantifier',
#  '846': 'plotly_parallel_coordinates_plot',
#  '847': 'gffcompare',
#  '848': 'picard_MergeSamFiles',
#  '849': 'idpqonvert',
#  '850': 'deeptools_computeMatrix',
#  '851': 'smf_utils_find-boxes',
#  '852': 'IDPosteriorErrorProbability',
#  '853': 'annotateMyIDs',
#  '854': 'methtools_dmr',
#  '855': 'smf_utils_extract-boxed-sequences',
#  '856': '16Sclassifier',
#  '857': 'mothur_classify_otu',
#  '858': 'tp_replace_in_line',
#  '859': 'mothur_heatmap_bin',
#  '860': 'gff_filter_by_attribute',
#  '861': 'ncbi_rpsblast_wrapper',
#  '862': 'ctb_chemfp_mol2fps',
#  '863': 'collection_column_join',
#  '864': 'flexbar_split_RR_bcs',
#  '865': 'qiime_pick_open_reference_otus',
#  '866': 'proteomics_search_peptide_prophet_1',
#  '867': 'kraken',
#  '868': 'trinity',
#  '869': 'trim_galore',
#  '870': 'hgv_linkToGProfile',
#  '871': 'w4mjoinpn',
#  '872': 'MzTabExporter',
#  '873': 'CONVERTER_fasta_to_fai',
#  '874': 'ggplot2_histogram',
#  '875': 'EMBOSS: geecee41',
#  '876': 'EMBOSS: water107',
#  '877': 'random_lines1',
#  '878': 'heinz_scoring',
#  '879': 'xcms_merge',
#  '880': 'cshl_fastx_quality_statistics',
#  '881': 'bam_to_sam',
#  '882': 'gemini_recessive_and_dominant',
#  '883': 'FROGS_affiliations_stat',
#  '884': 'mothur_amova',
#  '885': 'transpose',
#  '886': 'filtlong',
#  '887': 'gops_merge_1',
#  '888': 'cardinal_mz_images',
#  '889': 'gspan',
#  '890': 'cshl_fastx_renamer',
#  '891': 'deeptools_plot_coverage',
#  '892': 'CONVERTER_bedgraph_to_bigwig',
#  '893': 'tp_text_file_with_recurring_lines',
#  '894': 'translate_bed_sequences',
#  '895': 'gatk_depth_of_coverage',
#  '896': 'muscle',
#  '897': 'DecoyDatabase',
#  '898': 'rsem_prepare_reference',
#  '899': 'transdecoder',
#  '900': 'vcfannotate',
#  '901': 'gatk2_variant_recalibrator',
#  '902': 'cshl_fastq_quality_filter',
#  '903': 'bigwig_to_bedgraph',
#  '904': 'gatk2_realigner_target_creator',
#  '905': 'bedtools_map',
#  '906': 'gene2exon1',
#  '907': 'vegan_rarefaction',
#  '908': 'peakcalling_macs',
#  '909': 'methtools_tiling',
#  '910': 'mothur_remove_groups',
#  '911': 'gatk2_variant_select',
#  '912': 'heatmapper_deepTools',
#  '913': 'rarefaction_analyzer',
#  '914': 'search_gui',
#  '915': 'goslimmer',
#  '916': 'bg_diamond',
#  '917': 'velveth_jgi',
#  '918': 'methtools_filter',
#  '919': 'meme_fimo',
#  '920': 'deseq2_single',
#  '921': 'sklearn_ensemble',
#  '922': 'EMBOSS: shuffleseq87',
#  '923': 'gatk2_depth_of_coverage',
#  '924': 'correctGCBias',
#  '925': 'hmmer_hmmbuild',
#  '926': 'eukaryotic_ncbi_submission',
#  '927': 'pileup_interval',
#  '928': 'Grouping1',
#  '929': 'bam-filter',
#  '930': 'TrimByLength',
#  '931': 'qiime_count_seqs',
#  '932': 'hicexplorer_hicpca',
#  '933': 'Flash',
#  '934': 'maldi_quant_preprocessing',
#  '935': 'gafa',
#  '936': 'graphclust_glob_report_no_align',
#  '937': 'gff_to_sequence',
#  '938': 'rseqc_infer_experiment',
#  '939': 'newick_display',
#  '940': 'picard_BamIndexStats',
#  '941': 'picard_CollectWgsMetrics',
#  '942': 'HighResPrecursorMassCorrector',
#  '943': 'PeptideIndexer',
#  '944': 'Summary_Statistics1',
#  '945': 'fastq_quality_trimmer',
#  '946': 'rnaz',
#  '947': 'bedtools_genomecoveragebed',
#  '948': 'peakachu',
#  '949': 'deeptools_bamCoverage',
#  '950': 'abims_xcms_summary',
#  '951': 'gbk_to_orf',
#  '952': 'stacks_genotypes',
#  '953': 'deeptools_plot_fingerprint',
#  '954': 'comp1',
#  '955': 'mothur_make_shared',
#  '956': 'cshl_fastq_quality_boxplot',
#  '957': 'stacks_procrad',
#  '958': 'Remove beginning1',
#  '959': 'infernal_cmsearch',
#  '960': 'Heatmap',
#  '961': 'blastxml_to_top_descr',
#  '962': 'cufflinks_prok',
#  '963': 'DatamashOps',
#  '964': 'term_id_vs_term_def',
#  '965': 'map_peptides_to_bed',
#  '966': 'bamCompare_deepTools',
#  '967': 'jbrowse',
#  '968': 'cuffquant',
#  '969': 'Filter1',
#  '970': 'mothur_pcoa',
#  '971': 'deeptools_bigwigCompare'}

# %%
def verify_model(model, tool_sequence, labels, dictionary, reverse_dictionary, compatible_tools, topk=20, max_seq_len=25):
    tl_seq = tool_sequence.split(",")
    last_tool_name = reverse_dictionary[str(tl_seq[-1])]
    last_compatible_tools = compatible_tools[last_tool_name]
    sample = np.zeros(max_seq_len)
    for idx, tool_id in enumerate(tl_seq):
        sample[idx] = int(tool_id)
    sample_reshaped = np.reshape(sample, (1, max_seq_len))

    tool_sequence_names = [reverse_dictionary[str(tool_pos)] for tool_pos in tool_sequence.split(",")]
    print("Tool seq: %s" % ",".join(tool_sequence_names))

    # predict next tools for a test path
    prediction = model.predict(sample_reshaped, verbose=0)
    prediction = np.reshape(prediction, (prediction.shape[1],))
    prediction_pos = np.argsort(prediction, axis=-1)

    # get topk prediction
    topk_prediction_pos = prediction_pos[-topk:]
    topk_prediction_val = [np.round(prediction[pos] * 100, 2) for pos in topk_prediction_pos]

    # read tool names using reverse dictionary
    pred_tool_ids = [reverse_dictionary[str(tool_pos)] for tool_pos in topk_prediction_pos]
    actual_next_tool_ids = list(set(pred_tool_ids).intersection(set(last_compatible_tools.split(","))))      

    print()
    pred_tool_ids_sorted = dict()
    for (tool_pos, tool_pred_val) in zip(topk_prediction_pos, topk_prediction_val):
        tool_name = reverse_dictionary[str(tool_pos)]
        if tool_name in actual_next_tool_ids:
            pred_tool_ids_sorted[tool_name] = tool_pred_val
    pred_tool_ids_sorted = dict(sorted(pred_tool_ids_sorted.items(), key=lambda kv: kv[1], reverse=True))
    
    cls_wt = dict()
    usg_wt = dict()
    inv_wt = dict()
    ids_tools = dict()
    keys = list(pred_tool_ids_sorted.keys())
    for k in keys:
        try:
            cls_wt[k] = np.round(class_weights[str(data_dict[k])], 2)
            usg_wt[k] = np.round(usage_weights[k], 2)
            inv_wt[k] = np.round(inverted_weights[str(data_dict[k])], 2)
        except:
            continue
    print("Predicted tools: \n")
    print(pred_tool_ids_sorted)
    print()
    print("Class weights: \n")
    cls_wt = dict(sorted(cls_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(cls_wt)
    print()
    print("Usage weights: \n")
    usg_wt = dict(sorted(usg_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(usg_wt)
    print()
    total_usage_wt = np.mean(list(usg_wt.values()))
    print("Mean usage wt: %0.4f" % (total_usage_wt))
    print()
    print("Inverted weights: \n")
    inv_wt = dict(sorted(inv_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(inv_wt)
    for key in pred_tool_ids_sorted:
        ids_tools[key] = dictionary[key]
    print()
    print("Tool ids")
    print(ids_tools)
    print("======================================")
    return cls_wt, usg_wt, inv_wt, pred_tool_ids_sorted

topk = 20
tool_seq = "389,620"
class_wt, usage_wt, inverse_wt, pred_tools = verify_model(model, tool_seq, "", dictionary, reverse_dictionary, compatibile_tools, topk)
# Out:
# Tool seq: FeatureFinderMultiplex,IDMapper
#
# Predicted tools:
#
# {'FileInfo': 77.24, 'FileFilter': 61.38, 'IDConflictResolver': 56.19, 'FileMerger': 53.66, 'MzTabExporter': 32.99, 'ProteinQuantifier': 21.78, 'TextExporter': 16.88, 'FeatureLinkerUnlabeledQT': 12.42, 'MapRTTransformer': 10.58, 'MapAlignerPoseClustering': 3.06}
#
# Class weights:
#
# {'MzTabExporter': 23.78, 'FileInfo': 21.39, 'IDConflictResolver': 15.9, 'ProteinQuantifier': 4.66, 'FileFilter': 4.44, 'FileMerger': 1.42, 'TextExporter': 1.0, 'FeatureLinkerUnlabeledQT': 1.0, 'MapRTTransformer': 1.0, 'MapAlignerPoseClustering': 1.0}
#
# Usage weights:
#
# {'MzTabExporter': 23.78, 'FileInfo': 21.39, 'IDConflictResolver': 15.9, 'ProteinQuantifier': 4.66, 'FileFilter': 4.44, 'FileMerger': 1.42, 'TextExporter': 1.0, 'FeatureLinkerUnlabeledQT': 1.0, 'MapRTTransformer': 1.0, 'MapAlignerPoseClustering': 1.0}
#
# Mean usage wt: 7.5590
#
# Inverted weights:
#
# {}
#
# Tool ids
# {'FileInfo': 601, 'FileFilter': 527, 'IDConflictResolver': 268, 'FileMerger': 41, 'MzTabExporter': 872, 'ProteinQuantifier': 845, 'TextExporter': 525, 'FeatureLinkerUnlabeledQT': 272, 'MapRTTransformer': 242, 'MapAlignerPoseClustering': 753}
# ======================================

# %%
list_cls_wt = list()
list_usage_wt = list()
list_pred_wt = list()
list_inv_wt = list()
division_pt = int(len(pred_tools) / 2)

for tool in pred_tools:
    list_pred_wt.append(pred_tools[tool])
    #try:
    list_inv_wt.append(inverse_wt[tool])
    list_usage_wt.append(usage_wt[tool])
    #except:
    #list_inv_wt.append(1)

def plot_scatter(y_val, title, xlabel, ylabel):
    x_val = range(1, len(y_val) + 1)
    plt.figure(figsize=(8, 8))
    plt.plot(x_val[:division_pt], y_val[:division_pt], 'ro')
    plt.plot(x_val[division_pt:], y_val[division_pt:], 'b^')
    plt.xlabel(xlabel, size=size_label)
    plt.ylabel(ylabel, size=size_label)
    plt.legend([("First top-%s" % str(division_pt)), ("Next top-%s" % str(division_pt))])
    plt.title(title, size=size_title)
    plt.grid(True)
    plt.show()

plot_scatter(list_usage_wt, "Usage weights for tools", "Number of tools", "Class weights")
#plot_scatter(ave_prediction_weights, ave_usage_weights, "Prediction vs usage weights", "Prediction scores", "Usage weights")
#plot_scatter(ave_prediction_weights, ave_inverted_weights, "Prediction vs inverted weights", "Prediction scores", "Inverted weights")
