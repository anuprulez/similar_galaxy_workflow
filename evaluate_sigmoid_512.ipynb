# %%
import numpy as np
import json
import warnings
import operator

import h5py
from keras.models import model_from_json
from keras import backend as K

from matplotlib import pyplot as plt

warnings.filterwarnings("ignore")

size_title = 18
size_label = 14
n_pred = 2 

base_path = "data/evaluate_sigmoid_512/" # cluster path: 4_similar_galaxy_workflow

path_data_dict = base_path + "data_dict.txt"
path_usage_wt = base_path + "usage_prediction.txt"
path_class_wt = base_path + "class_weights.txt"
path_test_data = base_path + "test_paths_dict.txt"
model_path = base_path + "trained_model.hdf5"

def read_file(file_path):
    with open(file_path, 'r') as data_file:
        data = json.loads(data_file.read())
    return data

class_weights = read_file(path_class_wt)
usage_weights = read_file(path_usage_wt)
data_dict = read_file(path_data_dict)

def create_model(model_path):
    trained_model = h5py.File(model_path, 'r')
    model_config = json.loads(trained_model.get('model_config').value)
    loaded_model = model_from_json(model_config)
    dictionary = json.loads(trained_model.get('data_dictionary').value)
    compatibile_tools = json.loads(trained_model.get('compatible_tools').value)
    reverse_dictionary = dict((str(v), k) for k, v in dictionary.items())
    model_weights = list()
    weight_ctr = 0
    while True:
        try:
            d_key = "weight_" + str(weight_ctr)
            weights = trained_model.get(d_key).value
            model_weights.append(weights)
            weight_ctr += 1
        except Exception as exception:
            break
    # set the model weights
    loaded_model.set_weights(model_weights)
    return loaded_model, dictionary, reverse_dictionary, compatibile_tools

model, dictionary, reverse_dictionary, compatibile_tools = create_model(model_path)
# Out:
# Using TensorFlow backend.

# %%
reverse_dictionary
# Out:
# {'1': 'sed_stream_editor',
#  '2': 'FileFilter',
#  '3': 'sklearn_ensemble',
#  '4': 'cshl_fastq_to_fasta',
#  '5': 'ete_homology_classifier',
#  '6': 'ctb_online_data_fetch',
#  '7': 'nanoplot',
#  '8': 'fastq_to_tabular',
#  '9': 't_coffee',
#  '10': '__FILTER_FAILED_DATASETS__',
#  '11': 'bam2wig',
#  '12': '16Saligner',
#  '13': 'gatk2_haplotype_caller',
#  '14': 'cshl_fastq_quality_boxplot',
#  '15': 'w4mjoinpn',
#  '16': 'term_id_vs_term_def',
#  '17': 'blastxml_to_top_descr',
#  '18': 'unipept',
#  '19': 'goseq',
#  '20': 'graphclust_glob_report_no_align',
#  '21': 'chipsequtil_maptoknowngenes',
#  '22': 'picard_CASM',
#  '23': 'GeMoMa_Annotation_Filter',
#  '24': 'cshl_grep_tool',
#  '25': 'bctools_remove_spurious_events',
#  '26': 'Show tail1',
#  '27': 'combine_metaphlan2_humann2',
#  '28': 'picard_CollectWgsMetrics',
#  '29': 'umi_tools_whitelist',
#  '30': 'heinz_visualization',
#  '31': 'circgraph',
#  '32': 'seq_filter_by_mapping',
#  '33': 'mycrobiota-split-multi-otutable',
#  '34': 'bedtools_unionbedgraph',
#  '35': 'tab2fasta',
#  '36': 'interproscan',
#  '37': 'IDMerger',
#  '38': 'gemini_comp_hets',
#  '39': 'seq_composition',
#  '40': 'chipseeker',
#  '41': 'IDMapper',
#  '42': 'hicexplorer_hicmergematrixbins',
#  '43': 'mothur_taxonomy_to_krona',
#  '44': 'deeptools_bam_coverage',
#  '45': 'rbc_splitfasta',
#  '46': 'fasta2tab',
#  '47': 'CONVERTER_gz_to_uncompressed',
#  '48': 'snpSift_geneSets',
#  '49': 'cshl_easyjoin',
#  '50': 'TrimByLength',
#  '51': 'deeptools_computeGCBias',
#  '52': 'metaphlan_hclust_heatmap',
#  '53': 'fastq_paired_end_splitter',
#  '54': 'prokka',
#  '55': 'fastq_trimmer',
#  '56': 'eukaryotic_ncbi_submission',
#  '57': 'qiime_count_seqs',
#  '58': 'Convert characters1',
#  '59': 'qiime_pick_open_reference_otus',
#  '60': 'methtools_plot',
#  '61': 'picard_ValidateSamFile',
#  '62': 'smf_utils_find-boxes',
#  '63': 'mothur_tree_shared',
#  '64': 'cor2',
#  '65': 'deeptools_bigwig_compare',
#  '66': 'viz_overlay_moving_and_fixed_image',
#  '67': 'tp_cut_tool',
#  '68': 'get_sequences',
#  '69': 'meme_chip',
#  '70': 'rseqc_bam_stat',
#  '71': 'segemehl',
#  '72': 'column_remove_by_header',
#  '73': 'bam-filter',
#  '74': 'ete_genetree_splitter',
#  '75': 'rsem_calculate_expression',
#  '76': 'preproc',
#  '77': 'Btrim64',
#  '78': 'cufflinks_prok',
#  '79': 'vegan_diversity',
#  '80': 'ChooseTag',
#  '81': 'viennarna_rnafold',
#  '82': 'ctb_chemfp_mol2fps',
#  '83': 'IDFileConverter',
#  '84': 'subtract_query1',
#  '85': 'ctb_filter',
#  '86': 'bgchem_fragment_merger',
#  '87': 'w4mcorcov',
#  '88': 'picard_ARRG',
#  '89': 'melt',
#  '90': 'tophat',
#  '91': 'vcftools_merge',
#  '92': 'bedtools_annotatebed',
#  '93': 'rbc_mirdeep2',
#  '94': 'CONVERTER_fasta_to_fai',
#  '95': 'krona-text',
#  '96': 'ssake',
#  '97': 'structure_to_gspan',
#  '98': 'proteomics_search_peptide_prophet_1',
#  '99': 'ruvseq',
#  '100': 'sklear_numeric_clustering',
#  '101': 'hisat2',
#  '102': 'varscan_somatic',
#  '103': 'datamash_ops',
#  '104': 'pileometh',
#  '105': 'Nucleosome',
#  '106': 'gatk2_depth_of_coverage',
#  '107': 'methtools_filter',
#  '108': 'deeptools_bamCompare',
#  '109': 'tp_unfold_column_tool',
#  '110': 'Heatmap',
#  '111': 'column_order_header_sort',
#  '112': 'coords2clnt.py',
#  '113': 'bedtools_subtractbed',
#  '114': 'qiime_pick_closed_reference_otus',
#  '115': 'samtool_filter2',
#  '116': 'mimodd_varcall',
#  '117': 'PeptideIndexer',
#  '118': 'velveth_jgi',
#  '119': 'mothur_heatmap_bin',
#  '120': 'bedtools_genomecoveragebed_histogram',
#  '121': 'minfi_read450k',
#  '122': 'Datamash',
#  '123': 'tabular_to_fastq',
#  '124': 'fastqc',
#  '125': 'gmx_md',
#  '126': 'mothur_remove_lineage',
#  '127': 'get_subontology_from',
#  '128': 'tp_multijoin_tool',
#  '129': 'addValue',
#  '130': 'picard_BamIndexStats',
#  '131': 'openms_id_mapper',
#  '132': 'treebest_best',
#  '133': 'samtools_calmd',
#  '134': 'bcftools_call',
#  '135': 'qiime_split_libraries_fastq',
#  '136': 'mothur_seq_error',
#  '137': 'mass_spectrometry_imaging_mzplots',
#  '138': 'map_peptides_to_bed',
#  '139': 'rnaz',
#  '140': 'velvet',
#  '141': 'flye',
#  '142': 'Summary_Statistics1',
#  '143': 'filter_bed_on_splice_junctions',
#  '144': 'EMBOSS: water107',
#  '145': 'EMBOSS: geecee41',
#  '146': 'raceid_filtnormconf',
#  '147': 'bowtie2',
#  '148': 'rarefaction',
#  '149': 'fastq collapser',
#  '150': 'createInterval',
#  '151': 'EMBOSS: getorf42',
#  '152': 'table_annovar',
#  '153': 'bedtools_slopbed',
#  '154': 'blast_parser',
#  '155': 'gbk_to_orf',
#  '156': 't2t_report',
#  '157': 'trim_galore',
#  '158': 'PicardInsertSize',
#  '159': 'EMBOSS: transeq101',
#  '160': 'bam_to_bigwig',
#  '161': 'stacks_refmap',
#  '162': 'get_child_terms',
#  '163': 'MapAlignerPoseClustering',
#  '164': 'FROGS_affiliation_OTU',
#  '165': 'CONVERTER_gff_to_bed_0',
#  '166': 'Univariate',
#  '167': 'hicexplorer_hicpca',
#  '168': 'megahit',
#  '169': 'snpEff_download',
#  '170': 'stacks_denovomap',
#  '171': 'qiime_make_otu_heatmap',
#  '172': 'valet',
#  '173': 'fraggenescan',
#  '174': 'varscan',
#  '175': 'mothur_cluster_split',
#  '176': 'snpEff',
#  '177': 'cummeRbund',
#  '178': 'infernal_cmbuild',
#  '179': 'scaffold2fasta',
#  '180': 'bg_column_arrange_by_header',
#  '181': 'mycrobiota-make-multi-otutable',
#  '182': 'vcffilter2',
#  '183': 'MassCalculator',
#  '184': 'samtools_split',
#  '185': 'bedtools_intersectbed',
#  '186': 'snippy_core',
#  '187': 'bamCompare_deepTools',
#  '188': 'tp_sort_rows',
#  '189': 'gff2bed1',
#  '190': 'rna_star',
#  '191': 'mothur_summary_single',
#  '192': 'peptide_shaker',
#  '193': 'gspan',
#  '194': 'picard_SortSam',
#  '195': 'CONVERTER_interval_to_bedstrict_0',
#  '196': 'deeptools_heatmapper',
#  '197': 'cuffdiff',
#  '198': 'je_markdupes',
#  '199': 'mothur_trim_seqs',
#  '200': 'bg_statistical_hypothesis_testing',
#  '201': 'allele_counts_1',
#  '202': 'abims_xcms_summary',
#  '203': 'gtf_filter_by_attribute_values_list',
#  '204': 're_he_maldi_image_registration',
#  '205': 'FROGS_filters',
#  '206': 'locarna_best_subtree',
#  '207': 'ucsc-twobittofa',
#  '208': 'deeptools_plot_profile',
#  '209': '__SORTLIST__',
#  '210': 'lfq_protein_quant',
#  '211': 'hcluster_sg',
#  '212': 'msconvert3_raw',
#  '213': 'vcf2tsv',
#  '214': 'velvetoptimiser',
#  '215': 'gops_coverage_1',
#  '216': '__ZIP_COLLECTION__',
#  '217': 'hgv_linkToGProfile',
#  '218': 'tophat2',
#  '219': 'idpassemble',
#  '220': 'blockclust',
#  '221': 'rgPicardMarkDups',
#  '222': 'kallisto_quant',
#  '223': 'mz_to_sqlite',
#  '224': 'hmmer_hmmsearch',
#  '225': 'umi_tools_group',
#  '226': 'je_clip',
#  '227': 'varscan_copynumber',
#  '228': 'p_clip_peaks',
#  '229': 'cshl_fastx_barcode_splitter',
#  '230': 'jbrowse',
#  '231': 'CONVERTER_bedgraph_to_bigwig',
#  '232': 'bwa_mem',
#  '233': 'raceid_inspectclusters',
#  '234': 'vcfflatten2',
#  '235': 'glimmer_knowlegde-based',
#  '236': 'minfi_ppfun',
#  '237': 'deeptools_plot_correlation',
#  '238': 'rnafold',
#  '239': 'cat1',
#  '240': 'mothur_get_seqs',
#  '241': 'bedtools_map',
#  '242': 'umi_tools_extract',
#  '243': 'fasta_merge_files_and_filter_unique_sequences',
#  '244': 'glimmer_not-knowlegde-based',
#  '245': 'bedtools_shufflebed',
#  '246': 'random_lines1',
#  '247': 'picard_MergeSamFiles',
#  '248': 'rbc_mirdeep2_quantifier',
#  '249': 'bg_find_subsequences',
#  '250': 'deeptools_profiler',
#  '251': 'modencode_peakcalling_macs2',
#  '252': 'mycrobiota-krona-mothur',
#  '253': 'gemini_pathways',
#  '254': 'proteomics_search_protein_prophet_1',
#  '255': 'rm_spurious_events.py',
#  '256': 'tsne',
#  '257': 'nn_classifier',
#  '258': 'piranha',
#  '259': 'ExtractFASTAfromFASTQ',
#  '260': 'tp_sort_header_tool',
#  '261': 'gmx_setup',
#  '262': 'kraken-report',
#  '263': 'gemini_annotate',
#  '264': 'heinz_scoring',
#  '265': 'bed2gff1',
#  '266': 'Add_a_column1',
#  '267': 'FROGS_affiliations_stat',
#  '268': 'tp_grep_tool',
#  '269': 'dbbuilder',
#  '270': 'bandage_image',
#  '271': 'gff_filter_by_attribute',
#  '272': 'EMBOSS: textsearch98',
#  '273': 'hicexplorer_hictransform',
#  '274': 'FeatureLinkerUnlabeledKD',
#  '275': 'bedtools_genomecoveragebed_bedgraph',
#  '276': 'peakachu',
#  '277': 'bamtools',
#  '278': 'rseqc_inner_distance',
#  '279': 'minfi_dmp',
#  '280': 'wolf_psort',
#  '281': 'tp_find_and_replace',
#  '282': 'samtools_sort',
#  '283': 'IDFilter',
#  '284': 'iuc_pear',
#  '285': 'mothur_cluster',
#  '286': 'ProteinQuantifier',
#  '287': 'rseqc_read_distribution',
#  '288': 'hisat',
#  '289': 'cshl_fastx_reverse_complement',
#  '290': 'bctools_extract_crosslinked_nucleotides',
#  '291': 'heatmapper_deepTools',
#  '292': 'lastz_wrapper_2',
#  '293': 'ip_projective_transformation_points',
#  '294': 'gatk2_variant_filtration',
#  '295': 'decoyfasta',
#  '296': 'bed_to_bigwig',
#  '297': 'seurat',
#  '298': 'deeptools_compute_matrix',
#  '299': 'checkFormat',
#  '300': 'MapRTTransformer',
#  '301': 'dt_profiler',
#  '302': 'correct_barcodes',
#  '303': 'extract_bcs.py',
#  '304': 'cd_hit_dup',
#  '305': 'picard_EstimateLibraryComplexity',
#  '306': 'salmon',
#  '307': 'FeatureLinkerUnlabeled',
#  '308': 'regex_replace',
#  '309': 'snpsift_vartype',
#  '310': 'vcfsort',
#  '311': 'mothur_remove_groups',
#  '312': 'mass_spectrometry_imaging_preprocessing',
#  '313': 'cshl_fastx_trimmer',
#  '314': 'Paste1',
#  '315': '__FILTER_FROM_FILE__',
#  '316': 'picard_AddOrReplaceReadGroups',
#  '317': 'samtools_flagstat',
#  '318': 'TextExporter',
#  '319': 'deeptools_bamCorrelate',
#  '320': 'cshl_fastx_renamer',
#  '321': 'vcf_filter',
#  '322': 'metaspades',
#  '323': 'FeatureFinderMultiplex',
#  '324': 'gops_join_1',
#  '325': 'EMBOSS: wordcount109',
#  '326': 'cshl_fasta_formatter',
#  '327': '__APPLY_RULES__',
#  '328': 'fastq_dump',
#  '329': 'FeatureFinderMetabo',
#  '330': 'deeptools_compute_matrix_operations',
#  '331': 'bg_protein_properties',
#  '332': 'bedtools_mergebed',
#  '333': 'minfi_getanno',
#  '334': 'thermo_raw_file_converter',
#  '335': 'snpSift_annotate',
#  '336': 'fasta_compute_length',
#  '337': 'tp_sorted_uniq',
#  '338': 'snpfinder',
#  '339': 'picard_CollectRnaSeqMetrics',
#  '340': 'tp_head_tool',
#  '341': 'bamFilter',
#  '342': 'racon',
#  '343': 'samtools_flag_filter',
#  '344': 'snpSift_dbnsfp_generic',
#  '345': 'glob_report',
#  '346': 'macs2_callpeak',
#  '347': 'meme_psp_gen',
#  '348': 'viennarna_rnaplot',
#  '349': 'cuffcompare',
#  '350': 'CONVERTER_gff_to_interval_index_0',
#  '351': 'TrimPrimer',
#  '352': 'tophat_fusion_post',
#  '353': 'naive_variant_caller',
#  '354': 'export2graphlan',
#  '355': 'gatk2_unified_genotyper',
#  '356': 'macs2_bdgcmp',
#  '357': 'samtools_idxstats',
#  '358': 'PeakPickerHiRes',
#  '359': 'gtftobed12',
#  '360': 'signalp3',
#  '361': 'mothur_heatmap_sim',
#  '362': 'blastxml_to_tabular',
#  '363': 'correctGCBias',
#  '364': 'mlocarna',
#  '365': 'mimodd_varextract',
#  '366': 'mothur_corr_axes',
#  '367': 'ngsutils_bam_filter',
#  '368': 'fragmenter',
#  '369': 'gatk_realigner_target_creator',
#  '370': 'tp_cat',
#  '371': 'deeptools_plot_enrichment',
#  '372': 'megablast_xml_parser',
#  '373': 'make_families',
#  '374': 'EMBOSS: shuffleseq87',
#  '375': 'sklearn_searchcv',
#  '376': 'htseq-count',
#  '377': 'predict_pipeline',
#  '378': 'flexbar_split_RR_bcs',
#  '379': 'blastxml_to_tabular_selectable',
#  '380': 'ncbi_blastx_wrapper',
#  '381': 'stringtie',
#  '382': 'CONVERTER_bed_gff_or_vcf_to_bigwig_0',
#  '383': 'bg_uniq',
#  '384': 'MapStatistics',
#  '385': 'cufflinks',
#  '386': 'picard_ReorderSam',
#  '387': 'cshl_awk_tool',
#  '388': 'vcffixup',
#  '389': 'ncbi_rpsblast_wrapper',
#  '390': 'FastTree',
#  '391': 'Cut1',
#  '392': 'QCCalculator',
#  '393': 'rmcontamination',
#  '394': 'graphclust_align_cluster',
#  '395': 'hicexplorer_hicplotmatrix',
#  '396': 'extract_element_from_collection',
#  '397': 'fasta_filter_by_length',
#  '398': 'mothur_pcoa',
#  '399': 'ConsensusMapNormalizer',
#  '400': 'heinz_bum',
#  '401': 'transdecoder',
#  '402': 'cardinal_quality_report',
#  '403': 'minimap2',
#  '404': 'cshl_fastx_clipper',
#  '405': '__UNZIP_COLLECTION__',
#  '406': 'gatk2_variant_recalibrator',
#  '407': 'mothur_make_contigs',
#  '408': 'mothur_make_shared',
#  '409': 'CONVERTER_bed_to_bgzip_0',
#  '410': 'samtools_slice_bam',
#  '411': 'bedtools_multiintersectbed',
#  '412': 'gatk2_print_reads',
#  '413': 'deeptools_correctGCBias',
#  '414': 'MSGFPlusAdapter',
#  '415': 'infernal_cmsearch',
#  '416': 'mothur_make_biom',
#  '417': 'mothur_venn',
#  '418': 'join1',
#  '419': 'convert_bc_to_binary_RY.py',
#  '420': 'rseqc_junction_saturation',
#  '421': 'MultiplexResolver',
#  '422': 'vcftools_annotate',
#  '423': 'mergeCols1',
#  '424': 'cardinal_preprocessing',
#  '425': 'FidoAdapter',
#  '426': 'mothur_filter_seqs',
#  '427': 'Grouping1',
#  '428': 'NSPDK_candidateClust',
#  '429': 'transpose',
#  '430': 'hgv_snpFreq',
#  '431': 'sklearn_svm_classifier',
#  '432': 'bedtools_bamtofastq',
#  '433': 'gffcompare',
#  '434': 'limma_voom',
#  '435': 'IDPosteriorErrorProbability',
#  '436': 'IDMassAccuracy',
#  '437': 'bamCoverage_deepTools',
#  '438': 'vcffilter',
#  '439': 'vcf2pgSnp',
#  '440': 'fastq_filter',
#  '441': 'bed_to_bigBed',
#  '442': 'xpath',
#  '443': 'sam_to_bam',
#  '444': 'ChangeCase',
#  '445': 'mcClust',
#  '446': 'mothur_get_communitytype',
#  '447': 'sam2interval',
#  '448': 'aragorn_trna',
#  '449': 'bcftools_view',
#  '450': 'dexseq_count',
#  '451': 'NFS_transfer',
#  '452': 'deeptools_multi_bam_summary',
#  '453': 'secretbt2test',
#  '454': 'replace_column_with_key_value_file',
#  '455': 'ctb_change_title',
#  '456': 'Digestor',
#  '457': 'minfi_rset',
#  '458': 'deeptools_bigwigCompare',
#  '459': 'mothur_classify_rf',
#  '460': 'lca1',
#  '461': 'enhanced_bowtie_wrapper',
#  '462': 'cshl_sort_header',
#  '463': 'ncbi_blastn_wrapper',
#  '464': 'deeptools_bam_compare',
#  '465': 'Grep1',
#  '466': 'mothur_parsimony',
#  '467': 'sam_bw_filter',
#  '468': 'samtools_rmdup',
#  '469': 'graphclust_aggregate_alignments',
#  '470': 'msgfplus',
#  '471': 'humann2',
#  '472': 'mothur_get_groups',
#  '473': 'wiggle2simple1',
#  '474': 'cshl_uniq_tool',
#  '475': 'ggplot2_point',
#  '476': 'unicycler',
#  '477': 'search_gui',
#  '478': 'FROGS_remove_chimera',
#  '479': 'vcfannotate',
#  '480': 'HighResPrecursorMassCorrector',
#  '481': 'filter_by_fasta_ids',
#  '482': 'ctb_remIons',
#  '483': 'bctools_remove_tail',
#  '484': 'Extract_features1',
#  '485': 'barchart_gnuplot',
#  '486': 'gffread',
#  '487': 'bcftools_norm',
#  '488': 'bigwig_to_bedgraph',
#  '489': 'sailfish',
#  '490': 'FeatureFinderCentroided',
#  '491': 'gene2exon1',
#  '492': 'msconvert2_raw',
#  '493': 'vcfcombine',
#  '494': 'cshl_princeton_fastx_barcode_splitter',
#  '495': 'peakcalling_macs14',
#  '496': 'bwa_wrapper',
#  '497': 'mothur_chimera_uchime',
#  '498': 'gatk2_variant_apply_recalibration',
#  '499': 'fastq_groomer',
#  '500': 'clustalw',
#  '501': 'gatk2_indel_realigner',
#  '502': 'pilon',
#  '503': 'ctb_remSmall',
#  '504': 'bedtools_coveragebed_counts',
#  '505': 'newick_display',
#  '506': 'dunovo',
#  '507': 'mothur_align_seqs',
#  '508': 'ia_coordinates_of_roi',
#  '509': 'extract_aln_ends.py',
#  '510': 'gemini_db_info',
#  '511': 'ggplot_point',
#  '512': 'cshl_fasta_nucleotides_changer',
#  '513': 'bctools_extract_alignment_ends',
#  '514': 'bg_sortmerna',
#  '515': 'preMloc',
#  '516': 'bedtools_sortbed',
#  '517': 'picard_NormalizeFasta',
#  '518': 'prokaryotic_ncbi_submission',
#  '519': 'deeptools_compute_gc_bias',
#  '520': 'modencode_peakcalling_spp',
#  '521': 'cshl_word_list_grep',
#  '522': 'vcfgenotypes',
#  '523': 'join_files_on_column_fuzzy',
#  '524': 'secure_hash_message_digest',
#  '525': 'bamleftalign',
#  '526': 'sklearn_nn_classifier',
#  '527': 'proteomics_moff',
#  '528': 'sam_merge2',
#  '529': 'scpipe',
#  '530': 'pileup_parser',
#  '531': 'numeric_clustering',
#  '532': '__MERGE_COLLECTION__',
#  '533': 'mothur_nmds',
#  '534': 'spades',
#  '535': 'megablast_wrapper',
#  '536': 'Remove_ending',
#  '537': 'translate_bed_sequences',
#  '538': 'ProteinInference',
#  '539': 'gatk2_reduce_reads',
#  '540': 'computeMatrix',
#  '541': '__RELABEL_FROM_FILE__',
#  '542': 'deeptools_computeMatrix',
#  '543': 'bedtools_getfastabed',
#  '544': 'CONVERTER_sam_to_unsorted_bam',
#  '545': 'bedtools_intersectbed_bam',
#  '546': 'cuffmerge',
#  '547': 'Extractor',
#  '548': 'w4mclstrpeakpics',
#  '549': 'DatamashTranspose',
#  '550': 'Extract genomic DNA 1',
#  '551': 'gatk_indel_realigner',
#  '552': 'FileMerger',
#  '553': 'mothur_summary_seqs',
#  '554': 'plotly_regression_performance_plots',
#  '555': 'peakcalling_macs',
#  '556': 'ggplot_histogram',
#  '557': 'qiime_align_seqs',
#  '558': 'fastq_paired_end_interlacer',
#  '559': 'uchime',
#  '560': 'histogram_rpy',
#  '561': 'mothur_lefse',
#  '562': 'XY_Plot_1',
#  '563': 'myrimatch',
#  '564': 'proteomics_search_tandem_1',
#  '565': 'mothur_make_group',
#  '566': 'trinity',
#  '567': 'mothur_dist_seqs',
#  '568': 'tp_tail_tool',
#  '569': 'gatk_unified_genotyper',
#  '570': 'deeptools_bamFingerprint',
#  '571': 'gatk2_realigner_target_creator',
#  '572': 'sequence_content_trimmer',
#  '573': 'cardinal_mz_images',
#  '574': 'bedtools_bedtobam',
#  '575': 'fastq_to_fasta_python',
#  '576': 'infernal_cmstat',
#  '577': 'hcluster_sg_parser',
#  '578': 'qiime_assign_taxonomy',
#  '579': 'heatmap2',
#  '580': 'stacks_populations',
#  '581': 'pureclip',
#  '582': 'uparse',
#  '583': 'gemini_interactions',
#  '584': 'openms_id_file_converter',
#  '585': 'vcfallelicprimitives',
#  '586': 'ggplot2_heatmap2',
#  '587': 'pieplots_macs',
#  '588': 'fastq_combiner',
#  '589': 'samtools_stats',
#  '590': 'minfi_dropsnp',
#  '591': 'gmx_npt',
#  '592': 'Batch_correction',
#  '593': 'hgv_david',
#  '594': 'bams2ratio',
#  '595': 'featurecounts',
#  '596': 'vcfvcfintersect',
#  '597': 'mycrobiota-correct-replicates',
#  '598': 'hmmer_hmmbuild',
#  '599': 'abims_xcms_xcmsSet',
#  '600': 'cshl_multijoin',
#  '601': 'length_and_gc_content',
#  '602': 'PicardASMetrics',
#  '603': 'metaphlan2krona',
#  '604': 'bcftools_consensus',
#  '605': 'minfi_getM',
#  '606': 'ctb_ob_genProp',
#  '607': 'macs2_predictd',
#  '608': 'mothur_rarefaction_single',
#  '609': 'sklearn_build_pipeline',
#  '610': 'FeatureLinkerUnlabeledQT',
#  '611': 'augustus',
#  '612': 'gmx_solvate',
#  '613': 'smf_utils_filter-by-energy',
#  '614': 'qiime_core_diversity',
#  '615': 'MAF_To_Fasta1',
#  '616': 'snippy',
#  '617': 'hicexplorer_hicbuildmatrix',
#  '618': 'EMBOSS: fuzzpro38',
#  '619': 'FileConverter',
#  '620': 'deseq2',
#  '621': 'stringtie_merge',
#  '622': 'gd_raxml',
#  '623': 'SequenceCoverageCalculator',
#  '624': 'DatamashOps',
#  '625': 'stacks_genotypes',
#  '626': 'goenrichment',
#  '627': 'gemini_windower',
#  '628': 'FROGS_clustering',
#  '629': 'igvtools_count',
#  '630': 'je_demultiplex',
#  '631': 'tp_uniq_tool',
#  '632': 'mass_spectrometry_imaging_filtering',
#  '633': 'mothur_get_oturep',
#  '634': 'mass_spectrometry_imaging_combine',
#  '635': 'gops_cluster_1',
#  '636': 'bismark_bowtie2',
#  '637': 'fasttree',
#  '638': 'hicexplorer_hicplottads',
#  '639': 'mothur_remove_seqs',
#  '640': 'openms_protein_quantifier',
#  '641': 'ctb_simsearch',
#  '642': 'mass_spectrometry_imaging_ion_images',
#  '643': 'minfi_mset',
#  '644': 'idpquery',
#  '645': 'minfi_qc',
#  '646': 'gemini_recessive_and_dominant',
#  '647': 'mothur_count_groups',
#  '648': 'tp_text_file_with_recurring_lines',
#  '649': 'mothur_homova',
#  '650': 'vsearch_dereplication',
#  '651': 'trimmer',
#  '652': 'get_flanks1',
#  '653': 'annotateMyIDs',
#  '654': 'fastq_paired_end_joiner',
#  '655': 'gatk_depth_of_coverage',
#  '656': 'plotly_ml_performance_plots',
#  '657': 'IDConflictResolver',
#  '658': 'locarna_multiple',
#  '659': 'gemini_de_novo',
#  '660': 'CONVERTER_interval_to_bed_0',
#  '661': 'kraken-translate',
#  '662': 'EMBOSS: seqret84',
#  '663': 'format_metaphlan2_output',
#  '664': 'bam_to_sam',
#  '665': 'bedtools_genomecoveragebed',
#  '666': 'term_id_vs_term_name',
#  '667': 'muscle',
#  '668': 'meme_dreme',
#  '669': 'mothur_sub_sample',
#  '670': 'charts',
#  '671': 'cshl_fastx_quality_statistics',
#  '672': 'velvetg_jgi',
#  '673': 'sam_pileup',
#  '674': 'react_cal_pipeline',
#  '675': 'uniprot',
#  '676': 'graphlan',
#  '677': 'gatk2_variant_annotator',
#  '678': 'gemini_query',
#  '679': 'IDScoreSwitcher',
#  '680': 'dexseq',
#  '681': 'umi_tools_count',
#  '682': 'wc_gnu',
#  '683': 'freebayes',
#  '684': 'hicexplorer_hicfindtads',
#  '685': 'fastq_quality_trimmer',
#  '686': 'bg_diamond',
#  '687': 'gff_to_sequence',
#  '688': 'deeptools_plot_heatmap',
#  '689': 'Multivariate',
#  '690': 'bwameth',
#  '691': 'bedtools_multicovtbed',
#  '692': 'cshl_fastq_quality_filter',
#  '693': 'cardinal_combine',
#  '694': 'deg_annotate',
#  '695': 'goslimmer',
#  '696': 'mothur_phylotype',
#  '697': 'gatk2_variant_select',
#  '698': 'ncbi_tblastn_wrapper',
#  '699': 'smf_utils_fix-fasta-headers',
#  '700': 'annotatemyids',
#  '701': 'picard_MarkDuplicates',
#  '702': 'query_tabular',
#  '703': 'meme_meme',
#  '704': 'paralyzer',
#  '705': 'stacks_procrad',
#  '706': 'cast',
#  '707': 'CONVERTER_fasta_to_tabular',
#  '708': 'deeptools_plot_coverage',
#  '709': 'glimmer_build-icm',
#  '710': 'cshl_cut_tool',
#  '711': 'pileup_interval',
#  '712': 'xcms_merge',
#  '713': 'mothur_merge_files',
#  '714': 'gmx_em',
#  '715': 'mass_spectrometry_imaging_classification',
#  '716': 'seq_filter_by_id',
#  '717': 'sample_seqs',
#  '718': 'diffbind-embl',
#  '719': 'genbank_to_gff',
#  '720': 'cuffquant',
#  '721': 'raceid_clustering',
#  '722': 'ctb_compound_convert',
#  '723': 'cshl_fastx_collapser',
#  '724': 'bundle_collection',
#  '725': 'sklearn_feature_selection',
#  '726': 'bedtools_coveragebed',
#  '727': 'r_correlation_matrix',
#  '728': 'bedtools_complementbed',
#  '729': 'mothur_metastats',
#  '730': 'rgPicFixMate',
#  '731': 'selectsequencesfrommsa',
#  '732': 'viennarna_rnaalifold',
#  '733': 'vcfbedintersect',
#  '734': 'wsdl_hmdb',
#  '735': 'cardinal_segmentations',
#  '736': 'svm_classifier',
#  '737': 'cshl_find_and_replace',
#  '738': 'addName',
#  '739': 'graphicsmagick_image_convert',
#  '740': 'align_families',
#  '741': 'mass_spectrometry_imaging_qc',
#  '742': 'nspdk_sparse',
#  '743': 'kraken-filter',
#  '744': 'maldi_quant_peak_detection',
#  '745': 'minfi_dmr',
#  '746': 'samtools_filter',
#  '747': 'fastq_join',
#  '748': 'comp1',
#  '749': 'mothur_unique_seqs',
#  '750': 'CONVERTER_Bam_Bai_0',
#  '751': 'cardinal_data_exporter',
#  '752': 'minfi_getbeta',
#  '753': 'mimodd_map',
#  '754': 'tp_awk_tool',
#  '755': 'tp_tac',
#  '756': 'ProteinResolver',
#  '757': 'get_feature_info',
#  '758': 'ip_projective_transformation',
#  '759': 'trimmomatic',
#  '760': 'nanopolish_variants',
#  '761': 'humann2_genefamilies_genus_level',
#  '762': 'regex1',
#  '763': 'Remove beginning1',
#  '764': 'fastq_manipulation',
#  '765': 'gops_intersect_1',
#  '766': '__FLATTEN__',
#  '767': 'bedtools_intersectBed',
#  '768': 'samtools_mpileup',
#  '769': 'qiime_validate_mapping_file',
#  '770': 'MzTabExporter',
#  '771': '16Sclassifier',
#  '772': 'meme_fimo',
#  '773': 'Count1',
#  '774': 'collection_column_join',
#  '775': 'Extract_RNA_seq_Evidence',
#  '776': 'metaphlan2',
#  '777': 'XTandemAdapter',
#  '778': 'smf_utils_estimate-energy',
#  '779': 'tp_sed_tool',
#  '780': 'mothur_amova',
#  '781': 'mothur_classify_seqs',
#  '782': 'cshl_awk_replace_in_column',
#  '783': 'filtlong',
#  '784': 'raceid_inspecttrajectory',
#  '785': 'mycrobiota-qc-report',
#  '786': 'abims_CAMERA_annotateDiffreport',
#  '787': 'cshl_fastx_artifacts_filter',
#  '788': 'gops_basecoverage_1',
#  '789': 'bwa',
#  '790': 'tp_replace_in_column',
#  '791': 'cardinal_spectra_plots',
#  '792': 'cuffnorm',
#  '793': 'methtools_dmr',
#  '794': 'rarefaction_analyzer',
#  '795': 'minfi_maptogenome',
#  '796': 'vcftools_isec',
#  '797': 'disco',
#  '798': 'Psortb',
#  '799': 'umi_tools_dedup',
#  '800': 'smf_utils_extract-boxed-sequences',
#  '801': 'mycrobiota-otutable_add_blast',
#  '802': 'cmv',
#  '803': 'antismash',
#  '804': 'gafa',
#  '805': 'kraken',
#  '806': 'plotly_parallel_coordinates_plot',
#  '807': 'vcfselectsamples',
#  '808': 'CometAdapter',
#  '809': 'fasta-stats',
#  '810': 'gemini_actionable_mutations',
#  '811': 'fgsea',
#  '812': 'tag_stat2',
#  '813': 'ggplot2_histogram',
#  '814': 'gops_subtract_1',
#  '815': 'biosigner',
#  '816': 'pynast',
#  '817': 'blockbuster',
#  '818': 'rnbeads',
#  '819': 'TrimByN',
#  '820': 'flexbar_split_RYYR_bcs',
#  '821': 'CONVERTER_fastqgz_to_fastq',
#  '822': 'deeptools_plot_fingerprint',
#  '823': 'picard_FilterSamReads',
#  '824': 'ctb_silicos_qed',
#  '825': 'mothur_pre_cluster',
#  '826': 'roary',
#  '827': 'deeptools_bamCoverage',
#  '828': 'flexbardsc',
#  '829': 'mass_spectrometry_imaging_segmentations',
#  '830': 'flexbar',
#  '831': 'FileInfo',
#  '832': 'gops_concat_1',
#  '833': 'metilene',
#  '834': 'gemini_burden',
#  '835': 'mothur_dist_shared',
#  '836': 'snpeff_to_peptides',
#  '837': 'Draw_phylogram',
#  '838': 'raceid_main',
#  '839': 'humann2_renorm_table',
#  '840': 'CONVERTER_interval_to_bgzip_0',
#  '841': 'ncbi_makeblastdb',
#  '842': 'deseq2_single',
#  '843': 'EMBOSS: extractseq35',
#  '844': 'qiime_make_phylogeny',
#  '845': 'flexbar_no_split',
#  '846': 'picard_MarkDuplicatesWithMateCigar',
#  '847': 'rbc_mirdeep2_mapper',
#  '848': 'cshl_sed_tool',
#  '849': 'cutadapt',
#  '850': 'remove_tail.py',
#  '851': 'picard_SamToFastq',
#  '852': 'vegan_rarefaction',
#  '853': 'EMBOSS: tranalign100',
#  '854': 'graphlan_annotate',
#  '855': 'cardinal_filtering',
#  '856': 'qiime_pick_otus',
#  '857': 'ggplot2_heatmap',
#  '858': 'egsea',
#  '859': 'porechop',
#  '860': 'shovill',
#  '861': 'resistome_analyzer',
#  '862': 'idr-embl',
#  '863': 'taxonomy_krona_chart',
#  '864': 'htseq_count',
#  '865': 'cummerbund_to_cuffdiff',
#  '866': 'heinz',
#  '867': 'heatmapper',
#  '868': 'sqlite_to_tabular',
#  '869': 'dexseq_annotate',
#  '870': 'bismark_bowtie',
#  '871': 'bowtie_wrapper',
#  '872': 'EMBOSS: newseq59',
#  '873': 'silac_analyzer',
#  '874': 'msconvert_nix',
#  '875': 'mimodd_vcf_filter',
#  '876': 'rbc_rnacode',
#  '877': 'metams_runGC',
#  '878': 'qiime_pick_rep_set',
#  '879': 'quast',
#  '880': 'EMBOSS: revseq82',
#  '881': 'ConsensusID',
#  '882': 'edger',
#  '883': 'sklearn_numeric_clustering',
#  '884': 'FalseDiscoveryRate',
#  '885': 'w4mclassfilter',
#  '886': 'Flash',
#  '887': 'smooth_running_window',
#  '888': 'venn_list',
#  '889': 'methtools_destrand',
#  '890': 'picard_CollectInsertSizeMetrics',
#  '891': 'RNAlien',
#  '892': 'humann2_regroup_table',
#  '893': 'multiqc',
#  '894': 'wig_to_bigWig',
#  '895': 'vt_normalize',
#  '896': 'sickle',
#  '897': 'idpqonvert',
#  '898': 'GeneModelMapper',
#  '899': 'methtools_calling',
#  '900': 'cshl_fastx_nucleotides_distribution',
#  '901': 'CONVERTER_bed_to_gff_0',
#  '902': 'rbc_mafft',
#  '903': 'rsem_prepare_reference',
#  '904': 'mothur_chimera_vsearch',
#  '905': 'gemini_load',
#  '906': 'snpSift_filter',
#  '907': 'deeptools_correct_gc_bias',
#  '908': 'IsobaricAnalyzer',
#  '909': 'DecoyDatabase',
#  '910': 'datamash_transpose',
#  '911': 'find_in_reference',
#  '912': 'cmFinder',
#  '913': 'blast2go',
#  '914': 'maldi_quant_preprocessing',
#  '915': 'rgweblogo3',
#  '916': 'Show beginning1',
#  '917': 'rcas',
#  '918': 'sort1',
#  '919': 'Determine_BC',
#  '920': 'tmhmm2',
#  '921': 'trim_reads',
#  '922': 'deeptools_plot_pca',
#  '923': 'rseqc_read_duplication',
#  '924': 'FROGS_preprocess',
#  '925': 'fastq_paired_end_deinterlacer',
#  '926': 'abims_xcms_fillPeaks',
#  '927': 'abims_xcms_group',
#  '928': 'mimodd_varreport',
#  '929': 'group_humann2_uniref_abundances_to_go',
#  '930': 'Filter1',
#  '931': 'rseqc_geneBody_coverage',
#  '932': 'hicexplorer_hiccorrectmatrix',
#  '933': 'tp_replace_in_line',
#  '934': 'iReport',
#  '935': 'gmx_nvt',
#  '936': 'abricate',
#  '937': 'samtools_bedcov',
#  '938': 'methtools_tiling',
#  '939': 'gatk2_base_recalibrator',
#  '940': 'collapse_dataset',
#  '941': 'mothur_count_seqs',
#  '942': 'raceid_trajectory',
#  '943': 'mothur_screen_seqs',
#  '944': 'merge_pcr_duplicates.py',
#  '945': 'picard_CleanSam',
#  '946': 'gops_merge_1',
#  '947': 'scale_image',
#  '948': 'hicexplorer_hicsummatrices',
#  '949': 'tp_split_on_column',
#  '950': 'nonpareil',
#  '951': 'bedtools_bamtobed',
#  '952': 'minfi_methcpg',
#  '953': 'tp_easyjoin_tool',
#  '954': 'bedtools_windowbed',
#  '955': 'EMBOSS: fuzztran39',
#  '956': 'varscan_mpileup',
#  '957': 'aggregate_scores_in_intervals2',
#  '958': 'picard_FixMateInformation',
#  '959': 'Interval_Maf_Merged_Fasta2',
#  '960': 'flanking_features_1',
#  '961': 'ncbi_blastp_wrapper',
#  '962': 'gtf2bedgraph',
#  '963': 'rseqc_bam2wig',
#  '964': 'fasplit',
#  '965': 'mothur_classify_otu',
#  '966': 'eden_sequence_converter',
#  '967': 'get_read_pipeline',
#  '968': 'rseqc_infer_experiment',
#  '969': 'deeptools_multi_bigwig_summary',
#  '970': 'eden_vectorizer',
#  '971': 'Fetch Taxonomic Ranks'}

# %%
def verify_model(model, tool_sequence, labels, dictionary, reverse_dictionary, compatible_tools, topk=20, max_seq_len=25):
    tl_seq = tool_sequence.split(",")
    last_tool_name = reverse_dictionary[str(tl_seq[-1])]
    last_compatible_tools = compatible_tools[last_tool_name]
    sample = np.zeros(max_seq_len)
    for idx, tool_id in enumerate(tl_seq):
        sample[idx] = int(tool_id)
    sample_reshaped = np.reshape(sample, (1, max_seq_len))

    tool_sequence_names = [reverse_dictionary[str(tool_pos)] for tool_pos in tool_sequence.split(",")]
    print("Tool seq: %s" % ",".join(tool_sequence_names))

    # predict next tools for a test path
    prediction = model.predict(sample_reshaped, verbose=0)
    prediction = np.reshape(prediction, (prediction.shape[1],))
    prediction_pos = np.argsort(prediction, axis=-1)

    # get topk prediction
    topk_prediction_pos = prediction_pos[-topk:]
    topk_prediction_val = [np.round(prediction[pos] * 100, 2) for pos in topk_prediction_pos]

    # read tool names using reverse dictionary
    pred_tool_ids = [reverse_dictionary[str(tool_pos)] for tool_pos in topk_prediction_pos]
    actual_next_tool_ids = list(set(pred_tool_ids).intersection(set(last_compatible_tools.split(","))))      

    print()
    pred_tool_ids_sorted = dict()
    for (tool_pos, tool_pred_val) in zip(topk_prediction_pos, topk_prediction_val):
        tool_name = reverse_dictionary[str(tool_pos)]
        if tool_name in actual_next_tool_ids:
            pred_tool_ids_sorted[tool_name] = tool_pred_val
    pred_tool_ids_sorted = dict(sorted(pred_tool_ids_sorted.items(), key=lambda kv: kv[1], reverse=True))
    
    cls_wt = dict()
    usg_wt = dict()
    inv_wt = dict()
    ids_tools = dict()
    keys = list(pred_tool_ids_sorted.keys())
    for k in keys:
        try:
            cls_wt[k] = np.round(class_weights[str(data_dict[k])], 2)
            usg_wt[k] = np.round(usage_weights[k], 2)
            inv_wt[k] = np.round(inverted_weights[str(data_dict[k])], 2)
        except:
            continue
    print("Predicted tools: \n")
    print(pred_tool_ids_sorted)
    print()
    print("Class weights: \n")
    cls_wt = dict(sorted(cls_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(cls_wt)
    print()
    print("Usage weights: \n")
    usg_wt = dict(sorted(usg_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(usg_wt)
    print()
    total_usage_wt = np.mean(list(usg_wt.values()))
    print("Mean usage wt: %0.4f" % (total_usage_wt))
    print()
    print("Inverted weights: \n")
    inv_wt = dict(sorted(inv_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(inv_wt)
    for key in pred_tool_ids_sorted:
        ids_tools[key] = dictionary[key]
    print()
    print("Tool ids")
    print(ids_tools)
    print("======================================")
    return cls_wt, usg_wt, inv_wt, pred_tool_ids_sorted

topk = 20
tool_seq = "147"
class_wt, usage_wt, inverse_wt, pred_tools = verify_model(model, tool_seq, "", dictionary, reverse_dictionary, compatibile_tools, topk)
# Out:
# Tool seq: bowtie2
#
# Predicted tools:
#
# {'samtools_flagstat': 98.97, 'samtools_rmdup': 97.91, 'hicexplorer_hicbuildmatrix': 97.37, 'macs2_callpeak': 97.21, 'picard_MarkDuplicates': 97.15, 'ngsutils_bam_filter': 96.99, 'deeptools_bamCompare': 96.44, 'bam_to_sam': 95.94, 'deeptools_bam_compare': 95.71, 'deeptools_bamCorrelate': 95.65, 'deeptools_bamCoverage': 95.57, 'sam_merge2': 95.56, 'fastqc': 94.66, 'samtools_sort': 94.34, 'deeptools_bam_coverage': 94.2, 'deeptools_bamFingerprint': 93.96, 'bedtools_bamtobed': 93.91, 'samtool_filter2': 93.67, 'rgPicardMarkDups': 93.21, 'deeptools_plot_fingerprint': 92.48}
#
# Class weights:
#
# {'fastqc': 5879.0, 'deeptools_bam_coverage': 993.67, 'macs2_callpeak': 576.96, 'picard_MarkDuplicates': 392.84, 'samtools_flagstat': 295.48, 'samtools_rmdup': 253.4, 'samtool_filter2': 235.76, 'deeptools_bam_compare': 126.77, 'hicexplorer_hicbuildmatrix': 114.41, 'samtools_sort': 106.9, 'ngsutils_bam_filter': 80.09, 'deeptools_plot_fingerprint': 77.81, 'bam_to_sam': 68.97, 'sam_merge2': 54.12, 'bedtools_bamtobed': 37.24, 'rgPicardMarkDups': 10.6, 'deeptools_bamCompare': 1.0, 'deeptools_bamCorrelate': 1.0, 'deeptools_bamCoverage': 1.0, 'deeptools_bamFingerprint': 1.0}
#
# Usage weights:
#
# {'fastqc': 5879.0, 'deeptools_bam_coverage': 993.67, 'macs2_callpeak': 576.96, 'picard_MarkDuplicates': 392.84, 'samtools_flagstat': 295.48, 'samtools_rmdup': 253.4, 'samtool_filter2': 235.76, 'deeptools_bam_compare': 126.77, 'hicexplorer_hicbuildmatrix': 114.41, 'samtools_sort': 106.9, 'ngsutils_bam_filter': 80.09, 'deeptools_plot_fingerprint': 77.81, 'bam_to_sam': 68.97, 'sam_merge2': 54.12, 'bedtools_bamtobed': 37.24, 'rgPicardMarkDups': 10.6, 'deeptools_bamCompare': 1.0, 'deeptools_bamCorrelate': 1.0, 'deeptools_bamCoverage': 1.0}
#
# Mean usage wt: 489.8432
#
# Inverted weights:
#
# {}
#
# Tool ids
# {'samtools_flagstat': 317, 'samtools_rmdup': 468, 'hicexplorer_hicbuildmatrix': 617, 'macs2_callpeak': 346, 'picard_MarkDuplicates': 701, 'ngsutils_bam_filter': 367, 'deeptools_bamCompare': 108, 'bam_to_sam': 664, 'deeptools_bam_compare': 464, 'deeptools_bamCorrelate': 319, 'deeptools_bamCoverage': 827, 'sam_merge2': 528, 'fastqc': 124, 'samtools_sort': 282, 'deeptools_bam_coverage': 44, 'deeptools_bamFingerprint': 570, 'bedtools_bamtobed': 951, 'samtool_filter2': 115, 'rgPicardMarkDups': 221, 'deeptools_plot_fingerprint': 822}
# ======================================

# %%
list_cls_wt = list()
list_usage_wt = list()
list_pred_wt = list()
list_inv_wt = list()
division_pt = int(len(pred_tools) / 2)

for tool in pred_tools:
    list_pred_wt.append(pred_tools[tool])
    #try:
    list_inv_wt.append(inverse_wt[tool])
    list_usage_wt.append(usage_wt[tool])
    #except:
    #list_inv_wt.append(1)

def plot_scatter(y_val, title, xlabel, ylabel):
    x_val = range(1, len(y_val) + 1)
    plt.figure(figsize=(8, 8))
    plt.plot(x_val[:division_pt], y_val[:division_pt], 'ro')
    plt.plot(x_val[division_pt:], y_val[division_pt:], 'b^')
    plt.xlabel(xlabel, size=size_label)
    plt.ylabel(ylabel, size=size_label)
    plt.legend([("First top-%s" % str(division_pt)), ("Next top-%s" % str(division_pt))])
    plt.title(title, size=size_title)
    plt.grid(True)
    plt.show()

plot_scatter(list_usage_wt, "Usage weights for tools", "Number of tools", "Class weights")
#plot_scatter(ave_prediction_weights, ave_usage_weights, "Prediction vs usage weights", "Prediction scores", "Usage weights")
#plot_scatter(ave_prediction_weights, ave_inverted_weights, "Prediction vs inverted weights", "Prediction scores", "Inverted weights")
