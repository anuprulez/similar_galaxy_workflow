# %%
import numpy as np
import json
import warnings
import operator

import h5py
from keras.models import model_from_json
from keras import backend as K

from matplotlib import pyplot as plt

warnings.filterwarnings("ignore")

size_title = 18
size_label = 14
n_pred = 2 

base_path = "data/evaluate_softmax_512/" # cluster path: 1_similar_galaxy_workflow

path_data_dict = base_path + "data_dict.txt"
path_usage_wt = base_path + "usage_prediction.txt"
path_class_wt = base_path + "class_weights.txt"
path_test_data = base_path + "test_paths_dict.txt"
model_path = base_path + "trained_model.hdf5"

def read_file(file_path):
    with open(file_path, 'r') as data_file:
        data = json.loads(data_file.read())
    return data

class_weights = read_file(path_class_wt)
usage_weights = read_file(path_usage_wt)
data_dict = read_file(path_data_dict)

def create_model(model_path):
    trained_model = h5py.File(model_path, 'r')
    model_config = json.loads(trained_model.get('model_config').value)
    loaded_model = model_from_json(model_config)
    dictionary = json.loads(trained_model.get('data_dictionary').value)
    compatibile_tools = json.loads(trained_model.get('compatible_tools').value)
    reverse_dictionary = dict((str(v), k) for k, v in dictionary.items())
    model_weights = list()
    weight_ctr = 0
    while True:
        try:
            d_key = "weight_" + str(weight_ctr)
            weights = trained_model.get(d_key).value
            model_weights.append(weights)
            weight_ctr += 1
        except Exception as exception:
            break
    # set the model weights
    loaded_model.set_weights(model_weights)
    return loaded_model, dictionary, reverse_dictionary, compatibile_tools

model, dictionary, reverse_dictionary, compatibile_tools = create_model(model_path)
# Out:
# Using TensorFlow backend.

# %%
reverse_dictionary
# Out:
# {'1': 'MzTabExporter',
#  '2': 'locarna_best_subtree',
#  '3': 'Extract genomic DNA 1',
#  '4': 'eukaryotic_ncbi_submission',
#  '5': 'hicexplorer_hicplottads',
#  '6': 'FROGS_filters',
#  '7': 'FeatureLinkerUnlabeledQT',
#  '8': 'datamash_ops',
#  '9': 'rseqc_geneBody_coverage',
#  '10': 'qiime_split_libraries_fastq',
#  '11': 'maldi_quant_preprocessing',
#  '12': 'cshl_fastx_reverse_complement',
#  '13': 'deeptools_heatmapper',
#  '14': 'samtools_calmd',
#  '15': 'fasta2tab',
#  '16': 'CometAdapter',
#  '17': 'FastTree',
#  '18': 'antismash',
#  '19': 'picard_FilterSamReads',
#  '20': 'qiime_make_phylogeny',
#  '21': 'gatk_depth_of_coverage',
#  '22': 'megablast_xml_parser',
#  '23': 'GeneModelMapper',
#  '24': 'abims_xcms_xcmsSet',
#  '25': 'gatk2_indel_realigner',
#  '26': 'trimmer',
#  '27': 'pileometh',
#  '28': 'mass_spectrometry_imaging_filtering',
#  '29': 'FROGS_affiliation_OTU',
#  '30': 'bedtools_complementbed',
#  '31': 'bg_statistical_hypothesis_testing',
#  '32': 'mothur_screen_seqs',
#  '33': 'tag_stat2',
#  '34': 'ggplot2_point',
#  '35': 'checkFormat',
#  '36': 'Filter1',
#  '37': 'vt_normalize',
#  '38': 'qiime_pick_rep_set',
#  '39': 'mothur_classify_seqs',
#  '40': 'XTandemAdapter',
#  '41': 'vcftools_merge',
#  '42': 'plotly_parallel_coordinates_plot',
#  '43': 'cshl_princeton_fastx_barcode_splitter',
#  '44': 'cshl_uniq_tool',
#  '45': 'umi_tools_whitelist',
#  '46': 'raceid_inspecttrajectory',
#  '47': 'graphicsmagick_image_convert',
#  '48': 'term_id_vs_term_name',
#  '49': 'mothur_dist_seqs',
#  '50': 'vsearch_dereplication',
#  '51': 'goseq',
#  '52': 'gatk2_variant_recalibrator',
#  '53': 'interproscan',
#  '54': 'dexseq_annotate',
#  '55': 'TrimByLength',
#  '56': 'mothur_phylotype',
#  '57': 'fastq_paired_end_deinterlacer',
#  '58': 'humann2_regroup_table',
#  '59': 'cshl_fastx_collapser',
#  '60': 'cufflinks_prok',
#  '61': 'htseq_count',
#  '62': 'mycrobiota-krona-mothur',
#  '63': 'roary',
#  '64': 'bedtools_shufflebed',
#  '65': 'bedtools_coveragebed_counts',
#  '66': 'hisat',
#  '67': 'mothur_sub_sample',
#  '68': 'ggplot2_histogram',
#  '69': 'cshl_grep_tool',
#  '70': 'gmx_em',
#  '71': 'deeptools_correctGCBias',
#  '72': 'cshl_find_and_replace',
#  '73': 'scaffold2fasta',
#  '74': 'cmFinder',
#  '75': 'gffcompare',
#  '76': 'EMBOSS: water107',
#  '77': 'mothur_heatmap_bin',
#  '78': 'picard_MarkDuplicates',
#  '79': 'samtools_flag_filter',
#  '80': 'viennarna_rnaalifold',
#  '81': 'mothur_cluster_split',
#  '82': 'mothur_corr_axes',
#  '83': 'structure_to_gspan',
#  '84': 'bam2wig',
#  '85': 'gmx_md',
#  '86': 'hcluster_sg_parser',
#  '87': '__APPLY_RULES__',
#  '88': 'mothur_classify_rf',
#  '89': 'vcf2pgSnp',
#  '90': 'sam_bw_filter',
#  '91': 'flexbar_split_RYYR_bcs',
#  '92': 'Grep1',
#  '93': 'EMBOSS: transeq101',
#  '94': 'sklearn_numeric_clustering',
#  '95': 'hisat2',
#  '96': 'metaphlan2',
#  '97': 'mothur_rarefaction_single',
#  '98': 'glimmer_not-knowlegde-based',
#  '99': 'tp_sort_rows',
#  '100': 'heatmap2',
#  '101': 'fastq_trimmer',
#  '102': 'heinz_bum',
#  '103': 'cshl_fastq_quality_filter',
#  '104': 'bctools_remove_spurious_events',
#  '105': '__ZIP_COLLECTION__',
#  '106': 'mass_spectrometry_imaging_combine',
#  '107': 'bedtools_mergebed',
#  '108': 'cardinal_spectra_plots',
#  '109': 'mothur_get_communitytype',
#  '110': 'bg_diamond',
#  '111': 'bundle_collection',
#  '112': 'snpSift_filter',
#  '113': 'cuffdiff',
#  '114': 'deeptools_compute_gc_bias',
#  '115': 'rseqc_bam2wig',
#  '116': 'seq_filter_by_id',
#  '117': 'mothur_heatmap_sim',
#  '118': 'mlocarna',
#  '119': 'mimodd_varcall',
#  '120': 'picard_CASM',
#  '121': 'transpose',
#  '122': 'vcftools_annotate',
#  '123': 'dexseq',
#  '124': 'rseqc_bam_stat',
#  '125': 'metaphlan2krona',
#  '126': 'gops_concat_1',
#  '127': 'openms_id_mapper',
#  '128': 'bcftools_consensus',
#  '129': 'vegan_diversity',
#  '130': 'fasta_filter_by_length',
#  '131': 'translate_bed_sequences',
#  '132': 'picard_FixMateInformation',
#  '133': 'ncbi_blastn_wrapper',
#  '134': 'bctools_remove_tail',
#  '135': 'mothur_count_groups',
#  '136': 'rsem_calculate_expression',
#  '137': 'ruvseq',
#  '138': 'meme_meme',
#  '139': 'gtf2bedgraph',
#  '140': 'rarefaction',
#  '141': 'MassCalculator',
#  '142': 'gops_intersect_1',
#  '143': 'aragorn_trna',
#  '144': 'FalseDiscoveryRate',
#  '145': 'sklearn_feature_selection',
#  '146': 'Show tail1',
#  '147': 'minfi_mset',
#  '148': 'datamash_transpose',
#  '149': 'mimodd_varreport',
#  '150': 'picard_CleanSam',
#  '151': 'meme_dreme',
#  '152': 'bedtools_coveragebed',
#  '153': 'clustalw',
#  '154': 'IDMapper',
#  '155': 'cast',
#  '156': 'bedtools_intersectBed',
#  '157': 'velvet',
#  '158': 'fastq_paired_end_splitter',
#  '159': 'smf_utils_fix-fasta-headers',
#  '160': 'histogram_rpy',
#  '161': 'lfq_protein_quant',
#  '162': 'bedtools_intersectbed_bam',
#  '163': 'deeptools_bam_compare',
#  '164': 'mass_spectrometry_imaging_classification',
#  '165': 'bamCoverage_deepTools',
#  '166': 'gemini_windower',
#  '167': 'rbc_splitfasta',
#  '168': 'ggplot2_heatmap',
#  '169': 'rseqc_junction_saturation',
#  '170': 'sequence_content_trimmer',
#  '171': 'gd_raxml',
#  '172': 'cshl_fastx_barcode_splitter',
#  '173': 'bcftools_view',
#  '174': 'ctb_simsearch',
#  '175': 'RNAlien',
#  '176': 'stacks_procrad',
#  '177': 'openms_protein_quantifier',
#  '178': 'Datamash',
#  '179': 'chipseeker',
#  '180': 'naive_variant_caller',
#  '181': 'CONVERTER_bed_to_gff_0',
#  '182': 'search_gui',
#  '183': 'bed_to_bigwig',
#  '184': 'filtlong',
#  '185': 'MapStatistics',
#  '186': 'tmhmm2',
#  '187': 'minfi_read450k',
#  '188': 'diffbind-embl',
#  '189': 'minfi_ppfun',
#  '190': 'ctb_remSmall',
#  '191': 'deeptools_plot_heatmap',
#  '192': 'cshl_fastq_quality_boxplot',
#  '193': 'humann2_genefamilies_genus_level',
#  '194': 'fasplit',
#  '195': 'peptide_shaker',
#  '196': 'CONVERTER_gff_to_bed_0',
#  '197': 'blastxml_to_tabular',
#  '198': 'unipept',
#  '199': '__SORTLIST__',
#  '200': 'FeatureLinkerUnlabeled',
#  '201': 'barchart_gnuplot',
#  '202': 'quast',
#  '203': 'EMBOSS: shuffleseq87',
#  '204': 'Psortb',
#  '205': 'cshl_fastx_clipper',
#  '206': 'rseqc_read_distribution',
#  '207': 'bg_column_arrange_by_header',
#  '208': 'deeptools_compute_matrix_operations',
#  '209': 'CONVERTER_interval_to_bgzip_0',
#  '210': 'gspan',
#  '211': 'FROGS_affiliations_stat',
#  '212': 'minimap2',
#  '213': 'bwa',
#  '214': 'gatk_indel_realigner',
#  '215': 'bg_protein_properties',
#  '216': 'cshl_fastx_trimmer',
#  '217': 'annotatemyids',
#  '218': 'picard_ARRG',
#  '219': 'stringtie',
#  '220': 'vcfsort',
#  '221': 'nonpareil',
#  '222': 'gatk2_depth_of_coverage',
#  '223': 'tp_tac',
#  '224': 'length_and_gc_content',
#  '225': 'cshl_easyjoin',
#  '226': 'MAF_To_Fasta1',
#  '227': 'sklearn_svm_classifier',
#  '228': 'tophat2',
#  '229': 'cshl_multijoin',
#  '230': 'stacks_refmap',
#  '231': 'get_feature_info',
#  '232': 'Show beginning1',
#  '233': 'vcftools_isec',
#  '234': 'qiime_make_otu_heatmap',
#  '235': 'rgPicFixMate',
#  '236': 'kraken-report',
#  '237': 'fastq_paired_end_joiner',
#  '238': 'bigwig_to_bedgraph',
#  '239': 'newick_display',
#  '240': 'mass_spectrometry_imaging_ion_images',
#  '241': 'tp_text_file_with_recurring_lines',
#  '242': 'abricate',
#  '243': 'annotateMyIDs',
#  '244': 'fasttree',
#  '245': 'EMBOSS: fuzzpro38',
#  '246': 'hicexplorer_hiccorrectmatrix',
#  '247': 'ggplot2_heatmap2',
#  '248': 'bowtie_wrapper',
#  '249': 'uchime',
#  '250': '__FILTER_FAILED_DATASETS__',
#  '251': 'thermo_raw_file_converter',
#  '252': 'cummeRbund',
#  '253': 'eden_vectorizer',
#  '254': 'mimodd_vcf_filter',
#  '255': 'hicexplorer_hicbuildmatrix',
#  '256': 'deeptools_plot_pca',
#  '257': 'mothur_count_seqs',
#  '258': 'heatmapper',
#  '259': 'gops_subtract_1',
#  '260': 'gemini_comp_hets',
#  '261': 'TrimByN',
#  '262': 'bedtools_bamtofastq',
#  '263': 'salmon',
#  '264': 'mothur_chimera_uchime',
#  '265': 'mothur_merge_files',
#  '266': 'mothur_pcoa',
#  '267': 'w4mclassfilter',
#  '268': 'bedtools_genomecoveragebed_histogram',
#  '269': 'trimmomatic',
#  '270': 'segemehl',
#  '271': 'deeptools_plot_correlation',
#  '272': 'ConsensusID',
#  '273': 'bamCompare_deepTools',
#  '274': 'convert_bc_to_binary_RY.py',
#  '275': 'allele_counts_1',
#  '276': 'correctGCBias',
#  '277': 'hgv_snpFreq',
#  '278': 'deeptools_bamCorrelate',
#  '279': 'mothur_remove_lineage',
#  '280': 'tp_find_and_replace',
#  '281': 'picard_CollectRnaSeqMetrics',
#  '282': 'proteomics_search_peptide_prophet_1',
#  '283': 'blockclust',
#  '284': 'bedtools_unionbedgraph',
#  '285': 'computeMatrix',
#  '286': 'seq_filter_by_mapping',
#  '287': 'dexseq_count',
#  '288': 'tp_replace_in_line',
#  '289': 'prokka',
#  '290': 'msconvert2_raw',
#  '291': 'venn_list',
#  '292': 'ncbi_blastp_wrapper',
#  '293': 'IDFilter',
#  '294': 'sam2interval',
#  '295': 'egsea',
#  '296': 'extract_aln_ends.py',
#  '297': 'column_order_header_sort',
#  '298': 'raceid_trajectory',
#  '299': 'jbrowse',
#  '300': 'metams_runGC',
#  '301': 'goslimmer',
#  '302': 'limma_voom',
#  '303': 'peakachu',
#  '304': 'format_metaphlan2_output',
#  '305': 'rnbeads',
#  '306': 'vegan_rarefaction',
#  '307': 'glob_report',
#  '308': 'picard_MarkDuplicatesWithMateCigar',
#  '309': 'fastq_combiner',
#  '310': 'EMBOSS: extractseq35',
#  '311': 'sort1',
#  '312': 'samtools_filter',
#  '313': 'secure_hash_message_digest',
#  '314': 'bismark_bowtie2',
#  '315': 'rbc_mirdeep2',
#  '316': 'pieplots_macs',
#  '317': 'NSPDK_candidateClust',
#  '318': 'mothur_get_groups',
#  '319': 'FeatureFinderCentroided',
#  '320': 'bam-filter',
#  '321': 'mothur_nmds',
#  '322': 'mergeCols1',
#  '323': 'kallisto_quant',
#  '324': 'raceid_filtnormconf',
#  '325': '__MERGE_COLLECTION__',
#  '326': 'deseq2',
#  '327': 'deeptools_bamCompare',
#  '328': 'query_tabular',
#  '329': 'FROGS_clustering',
#  '330': 'meme_fimo',
#  '331': 'graphclust_glob_report_no_align',
#  '332': 'hgv_linkToGProfile',
#  '333': 'varscan_somatic',
#  '334': 'flexbar',
#  '335': 'addValue',
#  '336': 'fastq collapser',
#  '337': 'pileup_interval',
#  '338': 'bcftools_call',
#  '339': 'bg_uniq',
#  '340': 'qiime_core_diversity',
#  '341': 'raceid_clustering',
#  '342': 'qiime_count_seqs',
#  '343': 'EMBOSS: tranalign100',
#  '344': 'react_cal_pipeline',
#  '345': 'sickle',
#  '346': 'maldi_quant_peak_detection',
#  '347': 'mycrobiota-make-multi-otutable',
#  '348': 'FROGS_preprocess',
#  '349': 'get_flanks1',
#  '350': 'CONVERTER_bed_gff_or_vcf_to_bigwig_0',
#  '351': 'cshl_fastq_to_fasta',
#  '352': 'ChooseTag',
#  '353': 'idpqonvert',
#  '354': 'ProteinResolver',
#  '355': 'macs2_bdgcmp',
#  '356': 'filter_by_fasta_ids',
#  '357': 'gatk_unified_genotyper',
#  '358': 'megablast_wrapper',
#  '359': 'trim_galore',
#  '360': 'vcfallelicprimitives',
#  '361': 'sample_seqs',
#  '362': 'samtools_split',
#  '363': 'correct_barcodes',
#  '364': 'piranha',
#  '365': 'gtftobed12',
#  '366': 'mycrobiota-split-multi-otutable',
#  '367': 'bctools_extract_crosslinked_nucleotides',
#  '368': 'picard_SamToFastq',
#  '369': 'seq_composition',
#  '370': 'minfi_rset',
#  '371': 'smf_utils_estimate-energy',
#  '372': 'melt',
#  '373': 'gatk2_reduce_reads',
#  '374': 'sailfish',
#  '375': 'qiime_pick_otus',
#  '376': 'resistome_analyzer',
#  '377': 'make_families',
#  '378': 'smf_utils_filter-by-energy',
#  '379': 'je_markdupes',
#  '380': 'TextExporter',
#  '381': 'pureclip',
#  '382': 'lastz_wrapper_2',
#  '383': 'cutadapt',
#  '384': 'filter_bed_on_splice_junctions',
#  '385': 'mothur_remove_seqs',
#  '386': 'FeatureFinderMetabo',
#  '387': 'snpEff',
#  '388': 'minfi_qc',
#  '389': 'DatamashOps',
#  '390': 'mothur_get_oturep',
#  '391': 'deeptools_multi_bam_summary',
#  '392': 'modencode_peakcalling_spp',
#  '393': 'multiqc',
#  '394': 'vcffilter2',
#  '395': 'get_child_terms',
#  '396': 'trim_reads',
#  '397': 'IDScoreSwitcher',
#  '398': 'IDPosteriorErrorProbability',
#  '399': 'get_read_pipeline',
#  '400': 'fraggenescan',
#  '401': 'join1',
#  '402': 'cshl_cut_tool',
#  '403': 'bedtools_sortbed',
#  '404': 'PeptideIndexer',
#  '405': 'regex1',
#  '406': 'wc_gnu',
#  '407': 'mycrobiota-otutable_add_blast',
#  '408': 'gff_to_sequence',
#  '409': 'gene2exon1',
#  '410': 'valet',
#  '411': 'cardinal_preprocessing',
#  '412': 'infernal_cmbuild',
#  '413': 'EMBOSS: revseq82',
#  '414': 'wsdl_hmdb',
#  '415': 'proteomics_moff',
#  '416': 'DatamashTranspose',
#  '417': 'mothur_pre_cluster',
#  '418': 'CONVERTER_Bam_Bai_0',
#  '419': '__FLATTEN__',
#  '420': 'aggregate_scores_in_intervals2',
#  '421': 'deeptools_bam_coverage',
#  '422': 'tp_sort_header_tool',
#  '423': 'hgv_david',
#  '424': 'w4mjoinpn',
#  '425': 'cd_hit_dup',
#  '426': 'silac_analyzer',
#  '427': 'freebayes',
#  '428': 'mothur_align_seqs',
#  '429': 'gmx_solvate',
#  '430': 'hicexplorer_hicpca',
#  '431': 'viennarna_rnafold',
#  '432': 'uparse',
#  '433': 'umi_tools_dedup',
#  '434': 'cuffquant',
#  '435': 'openms_id_file_converter',
#  '436': 'fastq_manipulation',
#  '437': 'combine_metaphlan2_humann2',
#  '438': 'circgraph',
#  '439': 'deeptools_bigwig_compare',
#  '440': 'mass_spectrometry_imaging_mzplots',
#  '441': 'MultiplexResolver',
#  '442': 'graphlan',
#  '443': 'mimodd_varextract',
#  '444': 'bedtools_map',
#  '445': 'bedtools_annotatebed',
#  '446': 'bam_to_bigwig',
#  '447': 'flexbar_split_RR_bcs',
#  '448': 'FROGS_remove_chimera',
#  '449': 'tp_grep_tool',
#  '450': 'mothur_seq_error',
#  '451': 'rm_spurious_events.py',
#  '452': 'dbbuilder',
#  '453': 'ssake',
#  '454': 'tsne',
#  '455': 'cshl_fastx_artifacts_filter',
#  '456': 'ctb_silicos_qed',
#  '457': 'dunovo',
#  '458': 'umi_tools_count',
#  '459': 'rbc_rnacode',
#  '460': 'CONVERTER_fasta_to_tabular',
#  '461': 'mothur_remove_groups',
#  '462': 'subtract_query1',
#  '463': 'tabular_to_fastq',
#  '464': 'fragmenter',
#  '465': 'cshl_sed_tool',
#  '466': 'gatk2_realigner_target_creator',
#  '467': 'picard_MergeSamFiles',
#  '468': 'porechop',
#  '469': 'deeptools_bigwigCompare',
#  '470': 'coords2clnt.py',
#  '471': 'methtools_destrand',
#  '472': 'bamFilter',
#  '473': 'rmcontamination',
#  '474': 'snpSift_dbnsfp_generic',
#  '475': 'samtools_stats',
#  '476': 'velveth_jgi',
#  '477': 'fastq_to_tabular',
#  '478': 'minfi_getanno',
#  '479': 'flye',
#  '480': 'raceid_main',
#  '481': 'bed_to_bigBed',
#  '482': 'mimodd_map',
#  '483': 'Batch_correction',
#  '484': 'stacks_genotypes',
#  '485': 'FileConverter',
#  '486': 'enhanced_bowtie_wrapper',
#  '487': 'gemini_recessive_and_dominant',
#  '488': 'ngsutils_bam_filter',
#  '489': 'cuffnorm',
#  '490': 'regex_replace',
#  '491': 'IDMerger',
#  '492': 'gatk2_base_recalibrator',
#  '493': 'peakcalling_macs',
#  '494': 'cardinal_quality_report',
#  '495': 'ete_homology_classifier',
#  '496': 'samtool_filter2',
#  '497': 'hicexplorer_hicfindtads',
#  '498': 'r_correlation_matrix',
#  '499': 'velvetoptimiser',
#  '500': 'bg_sortmerna',
#  '501': 'decoyfasta',
#  '502': 'tp_easyjoin_tool',
#  '503': 'deeptools_bamFingerprint',
#  '504': 'rbc_mirdeep2_mapper',
#  '505': 'bedtools_intersectbed',
#  '506': 'gemini_db_info',
#  '507': 'snpsift_vartype',
#  '508': 'kraken-translate',
#  '509': 'minfi_getM',
#  '510': 'vcfcombine',
#  '511': 'hicexplorer_hicmergematrixbins',
#  '512': 'DecoyDatabase',
#  '513': 'samtools_rmdup',
#  '514': 'blastxml_to_tabular_selectable',
#  '515': 'blastxml_to_top_descr',
#  '516': 'ctb_remIons',
#  '517': 'meme_psp_gen',
#  '518': 'Univariate',
#  '519': 'bedtools_multiintersectbed',
#  '520': 'gemini_load',
#  '521': 'fgsea',
#  '522': 'cardinal_mz_images',
#  '523': 'trinity',
#  '524': 'fastq_groomer',
#  '525': 'tp_replace_in_column',
#  '526': 'fastq_to_fasta_python',
#  '527': 'rseqc_read_duplication',
#  '528': 'gff_filter_by_attribute',
#  '529': 'tophat_fusion_post',
#  '530': 'cshl_word_list_grep',
#  '531': 'ia_coordinates_of_roi',
#  '532': 'stringtie_merge',
#  '533': 'mothur_get_seqs',
#  '534': 'Cut1',
#  '535': 'graphclust_aggregate_alignments',
#  '536': 'createInterval',
#  '537': 'iuc_pear',
#  '538': 'sed_stream_editor',
#  '539': 'samtools_slice_bam',
#  '540': 'ExtractFASTAfromFASTQ',
#  '541': 'bcftools_norm',
#  '542': 'tp_cut_tool',
#  '543': '__RELABEL_FROM_FILE__',
#  '544': 'SequenceCoverageCalculator',
#  '545': 'deg_annotate',
#  '546': 'picard_BamIndexStats',
#  '547': 'CONVERTER_gz_to_uncompressed',
#  '548': 'Remove_ending',
#  '549': 'minfi_dmp',
#  '550': 'biosigner',
#  '551': 'blast_parser',
#  '552': 'tophat',
#  '553': 'gops_coverage_1',
#  '554': 'ctb_compound_convert',
#  '555': 'umi_tools_group',
#  '556': 'tab2fasta',
#  '557': 'minfi_getbeta',
#  '558': 'mothur_chimera_vsearch',
#  '559': 'fastq_join',
#  '560': 'Draw_phylogram',
#  '561': 'samtools_sort',
#  '562': 'methtools_calling',
#  '563': 'sam_pileup',
#  '564': 'blockbuster',
#  '565': 'flanking_features_1',
#  '566': 'cardinal_combine',
#  '567': 'rsem_prepare_reference',
#  '568': 'sam_to_bam',
#  '569': 'join_files_on_column_fuzzy',
#  '570': 'bedtools_genomecoveragebed_bedgraph',
#  '571': 'pileup_parser',
#  '572': 'bedtools_multicovtbed',
#  '573': 'picard_AddOrReplaceReadGroups',
#  '574': 'hmmer_hmmsearch',
#  '575': 'snpEff_download',
#  '576': 'cardinal_data_exporter',
#  '577': 'igvtools_count',
#  '578': 'smooth_running_window',
#  '579': 'gff2bed1',
#  '580': 'fastq_dump',
#  '581': 'rna_star',
#  '582': 'cshl_fastx_quality_statistics',
#  '583': 'align_families',
#  '584': 'deeptools_plot_fingerprint',
#  '585': 'ggplot_histogram',
#  '586': 'methtools_dmr',
#  '587': 'gafa',
#  '588': 'muscle',
#  '589': 'FileFilter',
#  '590': 'gops_join_1',
#  '591': 'treebest_best',
#  '592': 'Digestor',
#  '593': 'hicexplorer_hictransform',
#  '594': 'mz_to_sqlite',
#  '595': 'smf_utils_extract-boxed-sequences',
#  '596': 'gatk2_variant_filtration',
#  '597': 'collection_column_join',
#  '598': 'cardinal_filtering',
#  '599': 'ncbi_tblastn_wrapper',
#  '600': 'rnaz',
#  '601': 'edger',
#  '602': 'bamleftalign',
#  '603': 'Heatmap',
#  '604': 'mothur_tree_shared',
#  '605': 'gmx_setup',
#  '606': 'FileInfo',
#  '607': 'rbc_mafft',
#  '608': 'deeptools_computeMatrix',
#  '609': 'mothur_lefse',
#  '610': 'bg_find_subsequences',
#  '611': 'cmv',
#  '612': 'bowtie2',
#  '613': 'mcClust',
#  '614': 'tp_unfold_column_tool',
#  '615': 'ctb_filter',
#  '616': 'chipsequtil_maptoknowngenes',
#  '617': 'ctb_ob_genProp',
#  '618': 'column_remove_by_header',
#  '619': 'gtf_filter_by_attribute_values_list',
#  '620': 'ProteinQuantifier',
#  '621': 'w4mcorcov',
#  '622': 'spades',
#  '623': 'bedtools_getfastabed',
#  '624': 'ctb_chemfp_mol2fps',
#  '625': 'cummerbund_to_cuffdiff',
#  '626': 'humann2',
#  '627': 'ip_projective_transformation_points',
#  '628': 'preMloc',
#  '629': 'featurecounts',
#  '630': 'rcas',
#  '631': 'snpSift_geneSets',
#  '632': 'msconvert_nix',
#  '633': 'gops_cluster_1',
#  '634': 'htseq-count',
#  '635': 'secretbt2test',
#  '636': 'mothur_amova',
#  '637': 'qiime_validate_mapping_file',
#  '638': 'comp1',
#  '639': 'minfi_dropsnp',
#  '640': 'gemini_annotate',
#  '641': 'msconvert3_raw',
#  '642': 'fastq_quality_trimmer',
#  '643': 'flexbardsc',
#  '644': 'p_clip_peaks',
#  '645': 'snpfinder',
#  '646': 'rseqc_inner_distance',
#  '647': 'wiggle2simple1',
#  '648': 'uniprot',
#  '649': 'FileMerger',
#  '650': 'cuffcompare',
#  '651': 'cardinal_segmentations',
#  '652': 'hmmer_hmmbuild',
#  '653': 'methtools_filter',
#  '654': 'picard_ReorderSam',
#  '655': 'w4mclstrpeakpics',
#  '656': 'find_in_reference',
#  '657': 'ProteinInference',
#  '658': 'scpipe',
#  '659': 'bctools_extract_alignment_ends',
#  '660': 'cshl_awk_tool',
#  '661': 'msgfplus',
#  '662': 'cufflinks',
#  '663': 'replace_column_with_key_value_file',
#  '664': 'GeMoMa_Annotation_Filter',
#  '665': 'qiime_pick_open_reference_otus',
#  '666': 'mothur_classify_otu',
#  '667': 'addName',
#  '668': 'abims_xcms_summary',
#  '669': 'cat1',
#  '670': 'vcf_filter',
#  '671': 'methtools_plot',
#  '672': 'mothur_trim_seqs',
#  '673': 'deeptools_compute_matrix',
#  '674': 'CONVERTER_fasta_to_fai',
#  '675': 'tp_uniq_tool',
#  '676': 'dt_profiler',
#  '677': 't2t_report',
#  '678': 'locarna_multiple',
#  '679': 'plotly_regression_performance_plots',
#  '680': 'metilene',
#  '681': 'mothur_make_contigs',
#  '682': 'meme_chip',
#  '683': 'glimmer_build-icm',
#  '684': 'gatk2_variant_apply_recalibration',
#  '685': 'vcfgenotypes',
#  '686': 'selectsequencesfrommsa',
#  '687': 'fastq_filter',
#  '688': 'sklear_numeric_clustering',
#  '689': 'tp_awk_tool',
#  '690': 'cshl_fasta_nucleotides_changer',
#  '691': 'vcfselectsamples',
#  '692': 'peakcalling_macs14',
#  '693': 'cshl_fasta_formatter',
#  '694': 'nanoplot',
#  '695': 'IDConflictResolver',
#  '696': 'mothur_parsimony',
#  '697': 'snippy',
#  '698': 'wig_to_bigWig',
#  '699': 'heinz_visualization',
#  '700': 'mothur_venn',
#  '701': 'bwa_wrapper',
#  '702': 'deeptools_plot_enrichment',
#  '703': 'MapAlignerPoseClustering',
#  '704': 'predict_pipeline',
#  '705': 'proteomics_search_protein_prophet_1',
#  '706': '16Saligner',
#  '707': 'picard_CollectWgsMetrics',
#  '708': 'ucsc-twobittofa',
#  '709': 'mothur_dist_shared',
#  '710': 'get_sequences',
#  '711': 'xpath',
#  '712': 'seurat',
#  '713': 'gops_merge_1',
#  '714': 'samtools_bedcov',
#  '715': 'deeptools_computeGCBias',
#  '716': 'tp_multijoin_tool',
#  '717': 'heinz',
#  '718': 'bedtools_bamtobed',
#  '719': 'preproc',
#  '720': 'idpquery',
#  '721': 'deeptools_multi_bigwig_summary',
#  '722': 'map_peptides_to_bed',
#  '723': 'deseq2_single',
#  '724': 'get_subontology_from',
#  '725': 'Nucleosome',
#  '726': 'graphlan_annotate',
#  '727': 'Count1',
#  '728': 'racon',
#  '729': 'EMBOSS: fuzztran39',
#  '730': 'viz_overlay_moving_and_fixed_image',
#  '731': 'ConsensusMapNormalizer',
#  '732': 'rbc_mirdeep2_quantifier',
#  '733': 'MSGFPlusAdapter',
#  '734': 'cshl_awk_replace_in_column',
#  '735': 'gops_basecoverage_1',
#  '736': 't_coffee',
#  '737': 'tp_head_tool',
#  '738': 'deeptools_plot_coverage',
#  '739': 'nanopolish_variants',
#  '740': 'genbank_to_gff',
#  '741': 'gmx_nvt',
#  '742': 'CONVERTER_fastqgz_to_fastq',
#  '743': 'sklearn_build_pipeline',
#  '744': 'snippy_core',
#  '745': 'methtools_tiling',
#  '746': 'infernal_cmsearch',
#  '747': 'augustus',
#  '748': 'rarefaction_analyzer',
#  '749': 'bandage_image',
#  '750': 'mothur_taxonomy_to_krona',
#  '751': 'picard_CollectInsertSizeMetrics',
#  '752': 'infernal_cmstat',
#  '753': 'bamtools',
#  '754': 'sklearn_nn_classifier',
#  '755': 'extract_bcs.py',
#  '756': 'CONVERTER_bedgraph_to_bigwig',
#  '757': 'mycrobiota-qc-report',
#  '758': 'modencode_peakcalling_macs2',
#  '759': 'ncbi_rpsblast_wrapper',
#  '760': 'minfi_methcpg',
#  '761': 'bgchem_fragment_merger',
#  '762': 'Summary_Statistics1',
#  '763': 'cshl_sort_header',
#  '764': 'gatk2_print_reads',
#  '765': 'umi_tools_extract',
#  '766': 'wolf_psort',
#  '767': 'IDFileConverter',
#  '768': 'PicardInsertSize',
#  '769': 'Paste1',
#  '770': 'cshl_fastx_nucleotides_distribution',
#  '771': 'CONVERTER_sam_to_unsorted_bam',
#  '772': 'rgweblogo3',
#  '773': 'EMBOSS: geecee41',
#  '774': 'idpassemble',
#  '775': 'PicardASMetrics',
#  '776': 'vcf2tsv',
#  '777': 'je_demultiplex',
#  '778': 'rnafold',
#  '779': 'fastqc',
#  '780': 'ncbi_makeblastdb',
#  '781': 'gffread',
#  '782': 'XY_Plot_1',
#  '783': 'abims_xcms_group',
#  '784': 'stacks_denovomap',
#  '785': 'samtools_flagstat',
#  '786': 'TrimPrimer',
#  '787': 'mass_spectrometry_imaging_qc',
#  '788': 'picard_NormalizeFasta',
#  '789': 'glimmer_knowlegde-based',
#  '790': 'heinz_scoring',
#  '791': 'mothur_filter_seqs',
#  '792': 'sklearn_searchcv',
#  '793': 'fasta_merge_files_and_filter_unique_sequences',
#  '794': 'prokaryotic_ncbi_submission',
#  '795': 'tp_tail_tool',
#  '796': 'stacks_populations',
#  '797': 'gatk2_haplotype_caller',
#  '798': 'ctb_online_data_fetch',
#  '799': 'deeptools_correct_gc_bias',
#  '800': 'xcms_merge',
#  '801': 'gemini_pathways',
#  '802': 'gemini_query',
#  '803': 'bedtools_bedtobam',
#  '804': 'iReport',
#  '805': 'mothur_summary_single',
#  '806': 'mothur_metastats',
#  '807': 'hicexplorer_hicsummatrices',
#  '808': 'Extract_features1',
#  '809': 'mothur_make_group',
#  '810': 'mass_spectrometry_imaging_preprocessing',
#  '811': 'Add_a_column1',
#  '812': 'QCCalculator',
#  '813': 'vcffixup',
#  '814': 'goenrichment',
#  '815': 'MapRTTransformer',
#  '816': 'FeatureFinderMultiplex',
#  '817': 'picard_SortSam',
#  '818': 'gemini_interactions',
#  '819': 'gemini_actionable_mutations',
#  '820': 'tp_split_on_column',
#  '821': 'ChangeCase',
#  '822': 'numeric_clustering',
#  '823': 'cuffmerge',
#  '824': 'CONVERTER_interval_to_bedstrict_0',
#  '825': 'vcfvcfintersect',
#  '826': 'snpeff_to_peptides',
#  '827': 'deeptools_bamCoverage',
#  '828': 'nspdk_sparse',
#  '829': 'sam_merge2',
#  '830': 'mycrobiota-correct-replicates',
#  '831': 'abims_xcms_fillPeaks',
#  '832': 'krona-text',
#  '833': 'heatmapper_deepTools',
#  '834': 'abims_CAMERA_annotateDiffreport',
#  '835': 'gemini_de_novo',
#  '836': 'FeatureLinkerUnlabeledKD',
#  '837': 'tp_sed_tool',
#  '838': 'picard_ValidateSamFile',
#  '839': 'vcfbedintersect',
#  '840': 'EMBOSS: wordcount109',
#  '841': 'EMBOSS: seqret84',
#  '842': 'mass_spectrometry_imaging_segmentations',
#  '843': 'CONVERTER_gff_to_interval_index_0',
#  '844': 'bwameth',
#  '845': 'Fetch Taxonomic Ranks',
#  '846': 'minfi_maptogenome',
#  '847': 'fastq_paired_end_interlacer',
#  '848': 'macs2_predictd',
#  '849': 'collapse_dataset',
#  '850': 'gatk_realigner_target_creator',
#  '851': 'bam_to_sam',
#  '852': 'smf_utils_find-boxes',
#  '853': 'Interval_Maf_Merged_Fasta2',
#  '854': 'HighResPrecursorMassCorrector',
#  '855': 'macs2_callpeak',
#  '856': 'bwa_mem',
#  '857': 'disco',
#  '858': 'mothur_homova',
#  '859': 'tp_sorted_uniq',
#  '860': 'minfi_dmr',
#  '861': 'ggplot_point',
#  '862': 'kraken-filter',
#  '863': 'transdecoder',
#  '864': 'varscan_copynumber',
#  '865': 'mothur_make_shared',
#  '866': 'Btrim64',
#  '867': 'flexbar_no_split',
#  '868': 'gatk2_unified_genotyper',
#  '869': 'proteomics_search_tandem_1',
#  '870': 'scale_image',
#  '871': 'gmx_npt',
#  '872': 'kraken',
#  '873': 'unicycler',
#  '874': 'varscan',
#  '875': 'group_humann2_uniref_abundances_to_go',
#  '876': 'raceid_inspectclusters',
#  '877': 'ctb_change_title',
#  '878': 'signalp3',
#  '879': 'svm_classifier',
#  '880': 'Extract_RNA_seq_Evidence',
#  '881': 'Determine_BC',
#  '882': 'fasta-stats',
#  '883': 'Extractor',
#  '884': 'bedtools_subtractbed',
#  '885': 'samtools_idxstats',
#  '886': 'Flash',
#  '887': 'cor2',
#  '888': 'PeakPickerHiRes',
#  '889': 'sqlite_to_tabular',
#  '890': 'myrimatch',
#  '891': 'ip_projective_transformation',
#  '892': 'FidoAdapter',
#  '893': 'plotly_ml_performance_plots',
#  '894': 'random_lines1',
#  '895': 'idr-embl',
#  '896': 'bismark_bowtie',
#  '897': 'CONVERTER_interval_to_bed_0',
#  '898': 'bedtools_genomecoveragebed',
#  '899': 'pilon',
#  '900': 'Remove beginning1',
#  '901': 're_he_maldi_image_registration',
#  '902': 'qiime_pick_closed_reference_otus',
#  '903': 'vcfflatten2',
#  '904': 'merge_pcr_duplicates.py',
#  '905': '16Sclassifier',
#  '906': 'sklearn_ensemble',
#  '907': 'Multivariate',
#  '908': 'graphclust_align_cluster',
#  '909': 'bams2ratio',
#  '910': 'gatk2_variant_annotator',
#  '911': 'mothur_cluster',
#  '912': 'mothur_summary_seqs',
#  '913': 'Convert characters1',
#  '914': 'eden_sequence_converter',
#  '915': 'vcffilter',
#  '916': 'mothur_make_biom',
#  '917': 'deeptools_plot_profile',
#  '918': 'lca1',
#  '919': 'cshl_fastx_renamer',
#  '920': 'NFS_transfer',
#  '921': 'ncbi_blastx_wrapper',
#  '922': 'EMBOSS: textsearch98',
#  '923': 'taxonomy_krona_chart',
#  '924': 'varscan_mpileup',
#  '925': 'bedtools_windowbed',
#  '926': 'EMBOSS: getorf42',
#  '927': 'metaphlan_hclust_heatmap',
#  '928': 'humann2_renorm_table',
#  '929': 'blast2go',
#  '930': 'shovill',
#  '931': 'pynast',
#  '932': '__UNZIP_COLLECTION__',
#  '933': 'picard_EstimateLibraryComplexity',
#  '934': 'table_annovar',
#  '935': 'gbk_to_orf',
#  '936': 'EMBOSS: newseq59',
#  '937': 'bed2gff1',
#  '938': 'metaspades',
#  '939': 'deeptools_profiler',
#  '940': 'paralyzer',
#  '941': 'nn_classifier',
#  '942': 'megahit',
#  '943': 'samtools_mpileup',
#  '944': 'mothur_unique_seqs',
#  '945': 'remove_tail.py',
#  '946': 'hcluster_sg',
#  '947': 'velvetg_jgi',
#  '948': 'term_id_vs_term_def',
#  '949': 'vcfannotate',
#  '950': 'bedtools_slopbed',
#  '951': 'snpSift_annotate',
#  '952': 'ete_genetree_splitter',
#  '953': 'fasta_compute_length',
#  '954': 'IDMassAccuracy',
#  '955': 'charts',
#  '956': 'CONVERTER_bed_to_bgzip_0',
#  '957': 'IsobaricAnalyzer',
#  '958': 'je_clip',
#  '959': 'tp_cat',
#  '960': 'rgPicardMarkDups',
#  '961': 'Grouping1',
#  '962': 'extract_element_from_collection',
#  '963': 'export2graphlan',
#  '964': 'viennarna_rnaplot',
#  '965': 'qiime_assign_taxonomy',
#  '966': 'gemini_burden',
#  '967': 'qiime_align_seqs',
#  '968': '__FILTER_FROM_FILE__',
#  '969': 'gatk2_variant_select',
#  '970': 'rseqc_infer_experiment',
#  '971': 'hicexplorer_hicplotmatrix'}

# %%
def verify_model(model, tool_sequence, labels, dictionary, reverse_dictionary, compatible_tools, topk=20, max_seq_len=25):
    tl_seq = tool_sequence.split(",")
    last_tool_name = reverse_dictionary[str(tl_seq[-1])]
    last_compatible_tools = compatible_tools[last_tool_name]
    sample = np.zeros(max_seq_len)
    for idx, tool_id in enumerate(tl_seq):
        sample[idx] = int(tool_id)
    sample_reshaped = np.reshape(sample, (1, max_seq_len))

    tool_sequence_names = [reverse_dictionary[str(tool_pos)] for tool_pos in tool_sequence.split(",")]
    print("Tool seq: %s" % ",".join(tool_sequence_names))

    # predict next tools for a test path
    prediction = model.predict(sample_reshaped, verbose=0)
    prediction = np.reshape(prediction, (prediction.shape[1],))
    prediction_pos = np.argsort(prediction, axis=-1)

    # get topk prediction
    topk_prediction_pos = prediction_pos[-topk:]
    topk_prediction_val = [np.round(prediction[pos] * 100, 2) for pos in topk_prediction_pos]

    # read tool names using reverse dictionary
    pred_tool_ids = [reverse_dictionary[str(tool_pos)] for tool_pos in topk_prediction_pos]
    actual_next_tool_ids = list(set(pred_tool_ids).intersection(set(last_compatible_tools.split(","))))      

    print()
    pred_tool_ids_sorted = dict()
    for (tool_pos, tool_pred_val) in zip(topk_prediction_pos, topk_prediction_val):
        tool_name = reverse_dictionary[str(tool_pos)]
        if tool_name in actual_next_tool_ids:
            pred_tool_ids_sorted[tool_name] = tool_pred_val
    pred_tool_ids_sorted = dict(sorted(pred_tool_ids_sorted.items(), key=lambda kv: kv[1], reverse=True))
    
    cls_wt = dict()
    usg_wt = dict()
    inv_wt = dict()
    ids_tools = dict()
    keys = list(pred_tool_ids_sorted.keys())
    for k in keys:
        try:
            cls_wt[k] = np.round(class_weights[str(data_dict[k])], 2)
            usg_wt[k] = np.round(usage_weights[k], 2)
            inv_wt[k] = np.round(inverted_weights[str(data_dict[k])], 2)
        except:
            continue
    print("Predicted tools: \n")
    print(pred_tool_ids_sorted)
    print()
    print("Class weights: \n")
    cls_wt = dict(sorted(cls_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(cls_wt)
    print()
    print("Usage weights: \n")
    usg_wt = dict(sorted(usg_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(usg_wt)
    print()
    total_usage_wt = np.mean(list(usg_wt.values()))
    print("Mean usage wt: %0.4f" % (total_usage_wt))
    print()
    print("Inverted weights: \n")
    inv_wt = dict(sorted(inv_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(inv_wt)
    for key in pred_tool_ids_sorted:
        ids_tools[key] = dictionary[key]
    print()
    print("Tool ids")
    print(ids_tools)
    print("======================================")
    return cls_wt, usg_wt, inv_wt, pred_tool_ids_sorted

topk = 30
tool_seq = "612"
class_wt, usage_wt, inverse_wt, pred_tools = verify_model(model, tool_seq, "", dictionary, reverse_dictionary, compatibile_tools, topk)
# Out:
# Tool seq: bowtie2
#
# Predicted tools:
#
# {'deeptools_bamCoverage': 7.99, 'samtools_rmdup': 5.47, 'deeptools_bamCompare': 5.23, 'ngsutils_bam_filter': 4.8, 'samtools_flagstat': 4.05, 'multiqc': 3.99, 'deeptools_bamCorrelate': 2.81, 'picard_MarkDuplicates': 2.75, 'samtool_filter2': 2.58, 'bamFilter': 2.44, 'fastqc': 2.4, 'samtools_sort': 2.38, 'htseq_count': 2.16, 'fastq_to_fasta_python': 2.09, 'rseqc_bam2wig': 2.06, 'deeptools_bam_compare': 2.03, 'rgPicardMarkDups': 1.99, 'deeptools_plot_fingerprint': 1.87, 'bam_to_sam': 1.86, 'hicexplorer_hicbuildmatrix': 1.8, 'deeptools_multi_bam_summary': 1.7, 'freebayes': 1.65, 'macs2_callpeak': 1.61, 'deeptools_bamFingerprint': 1.49, 'deeptools_compute_gc_bias': 1.43, 'bedtools_bamtobed': 1.36, 'sam_merge2': 1.28, 'bamCoverage_deepTools': 1.28, 'gatk2_realigner_target_creator': 1.27, 'picard_CollectInsertSizeMetrics': 1.14}
#
# Class weights:
#
# {'fastqc': 5879.0, 'freebayes': 1726.37, 'macs2_callpeak': 576.96, 'htseq_count': 538.31, 'multiqc': 434.46, 'picard_MarkDuplicates': 392.84, 'samtools_flagstat': 295.48, 'samtools_rmdup': 253.4, 'bamFilter': 243.6, 'samtool_filter2': 235.76, 'deeptools_bam_compare': 126.77, 'hicexplorer_hicbuildmatrix': 114.41, 'samtools_sort': 106.9, 'ngsutils_bam_filter': 80.09, 'deeptools_multi_bam_summary': 79.9, 'deeptools_plot_fingerprint': 77.81, 'fastq_to_fasta_python': 76.94, 'bam_to_sam': 68.97, 'sam_merge2': 54.12, 'bedtools_bamtobed': 37.24, 'rseqc_bam2wig': 19.54, 'rgPicardMarkDups': 10.6, 'gatk2_realigner_target_creator': 9.17, 'deeptools_compute_gc_bias': 9.0, 'picard_CollectInsertSizeMetrics': 3.14, 'deeptools_bamCoverage': 1.0, 'deeptools_bamCompare': 1.0, 'deeptools_bamCorrelate': 1.0, 'deeptools_bamFingerprint': 1.0, 'bamCoverage_deepTools': 1.0}
#
# Usage weights:
#
# {'fastqc': 5879.0, 'freebayes': 1726.37, 'macs2_callpeak': 576.96, 'htseq_count': 538.31, 'multiqc': 434.46, 'picard_MarkDuplicates': 392.84, 'samtools_flagstat': 295.48, 'samtools_rmdup': 253.4, 'bamFilter': 243.6, 'samtool_filter2': 235.76, 'deeptools_bam_compare': 126.77, 'hicexplorer_hicbuildmatrix': 114.41, 'samtools_sort': 106.9, 'ngsutils_bam_filter': 80.09, 'deeptools_multi_bam_summary': 79.9, 'deeptools_plot_fingerprint': 77.81, 'fastq_to_fasta_python': 76.94, 'bam_to_sam': 68.97, 'sam_merge2': 54.12, 'bedtools_bamtobed': 37.24, 'rseqc_bam2wig': 19.54, 'rgPicardMarkDups': 10.6, 'gatk2_realigner_target_creator': 9.17, 'deeptools_compute_gc_bias': 9.0, 'picard_CollectInsertSizeMetrics': 3.14, 'deeptools_bamCoverage': 1.0, 'deeptools_bamCompare': 1.0, 'deeptools_bamCorrelate': 1.0}
#
# Mean usage wt: 409.0636
#
# Inverted weights:
#
# {}
#
# Tool ids
# {'deeptools_bamCoverage': 827, 'samtools_rmdup': 513, 'deeptools_bamCompare': 327, 'ngsutils_bam_filter': 488, 'samtools_flagstat': 785, 'multiqc': 393, 'deeptools_bamCorrelate': 278, 'picard_MarkDuplicates': 78, 'samtool_filter2': 496, 'bamFilter': 472, 'fastqc': 779, 'samtools_sort': 561, 'htseq_count': 61, 'fastq_to_fasta_python': 526, 'rseqc_bam2wig': 115, 'deeptools_bam_compare': 163, 'rgPicardMarkDups': 960, 'deeptools_plot_fingerprint': 584, 'bam_to_sam': 851, 'hicexplorer_hicbuildmatrix': 255, 'deeptools_multi_bam_summary': 391, 'freebayes': 427, 'macs2_callpeak': 855, 'deeptools_bamFingerprint': 503, 'deeptools_compute_gc_bias': 114, 'bedtools_bamtobed': 718, 'sam_merge2': 829, 'bamCoverage_deepTools': 165, 'gatk2_realigner_target_creator': 466, 'picard_CollectInsertSizeMetrics': 751}
# ======================================

# %%
list_cls_wt = list()
list_usage_wt = list()
list_pred_wt = list()
list_inv_wt = list()
division_pt = int(len(pred_tools) / 2)

for tool in pred_tools:
    list_pred_wt.append(pred_tools[tool])
    #try:
    list_inv_wt.append(inverse_wt[tool])
    list_usage_wt.append(usage_wt[tool])
    #except:
    #list_inv_wt.append(1)

def plot_scatter(y_val, title, xlabel, ylabel):
    x_val = range(1, len(y_val) + 1)
    plt.figure(figsize=(8, 8))
    plt.plot(x_val[:division_pt], y_val[:division_pt], 'ro')
    plt.plot(x_val[division_pt:], y_val[division_pt:], 'b^')
    plt.xlabel(xlabel, size=size_label)
    plt.ylabel(ylabel, size=size_label)
    plt.legend([("First top-%s" % str(division_pt)), ("Next top-%s" % str(division_pt))])
    plt.title(title, size=size_title)
    plt.grid(True)
    plt.show()

plot_scatter(list_usage_wt, "Usage weights for tools", "Number of tools", "Class weights")
#plot_scatter(ave_prediction_weights, ave_usage_weights, "Prediction vs usage weights", "Prediction scores", "Usage weights")
#plot_scatter(ave_prediction_weights, ave_inverted_weights, "Prediction vs inverted weights", "Prediction scores", "Inverted weights")
