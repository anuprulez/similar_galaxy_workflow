# %%
import numpy as np
import json
import warnings
import operator

import h5py
from keras.models import model_from_json
from keras import backend as K

from matplotlib import pyplot as plt

warnings.filterwarnings("ignore")

size_title = 18
size_label = 14
n_pred = 2

base_path = "data/evalute_softmax/"

path_data_dict = base_path + "data_dict.txt"
path_inverted_wt = base_path + "inverted_weights.txt"
path_usage_wt = base_path + "usage_prediction.txt"
path_class_wt = base_path + "class_weights.txt"
path_test_data = base_path + "test_paths_dict.txt"
model_path = base_path + "trained_model.hdf5"

def read_file(file_path):
    with open(file_path, 'r') as data_file:
        data = json.loads(data_file.read())
    return data

class_weights = read_file(path_class_wt)
usage_weights = read_file(path_usage_wt)
inverted_weights = read_file(path_inverted_wt)
data_dict = read_file(path_data_dict)

def create_model(model_path):
    trained_model = h5py.File(model_path, 'r')
    model_config = json.loads(trained_model.get('model_config').value)
    loaded_model = model_from_json(model_config)
    dictionary = json.loads(trained_model.get('data_dictionary').value)
    compatibile_tools = json.loads(trained_model.get('compatible_tools').value)
    reverse_dictionary = dict((str(v), k) for k, v in dictionary.items())
    model_weights = list()
    weight_ctr = 0
    while True:
        try:
            d_key = "weight_" + str(weight_ctr)
            weights = trained_model.get(d_key).value
            model_weights.append(weights)
            weight_ctr += 1
        except Exception as exception:
            break
    # set the model weights
    loaded_model.set_weights(model_weights)
    return loaded_model, dictionary, reverse_dictionary, compatibile_tools

model, dictionary, reverse_dictionary, compatibile_tools = create_model(model_path)
# Out:
# Using TensorFlow backend.

# %%
reverse_dictionary
# Out:
# {'1': 'mothur_tree_shared',
#  '2': 'flexbar',
#  '3': 'gff_filter_by_attribute',
#  '4': 'locarna_best_subtree',
#  '5': 'msconvert3_raw',
#  '6': 'Show beginning1',
#  '7': 'regex_replace',
#  '8': 'cshl_sort_header',
#  '9': 'bed_to_bigBed',
#  '10': 'scpipe',
#  '11': 'ruvseq',
#  '12': 'resistome_analyzer',
#  '13': 'humann2_regroup_table',
#  '14': 'methtools_calling',
#  '15': 'checkFormat',
#  '16': 'bedtools_bedtobam',
#  '17': 'ProteinQuantifier',
#  '18': 'cardinal_spectra_plots',
#  '19': 'pureclip',
#  '20': 'mothur_trim_seqs',
#  '21': 'fastq_paired_end_joiner',
#  '22': 'gffcompare',
#  '23': 'diffbind-embl',
#  '24': 'mass_spectrometry_imaging_combine',
#  '25': 'picard_FilterSamReads',
#  '26': 'Datamash',
#  '27': 'snpSift_filter',
#  '28': 'cshl_find_and_replace',
#  '29': 'PeptideIndexer',
#  '30': 'lfq_protein_quant',
#  '31': 'vcfallelicprimitives',
#  '32': 'EMBOSS: water107',
#  '33': 'abims_xcms_xcmsSet',
#  '34': '__UNZIP_COLLECTION__',
#  '35': 'get_child_terms',
#  '36': 'heinz',
#  '37': 'openms_id_mapper',
#  '38': 're_he_maldi_image_registration',
#  '39': 'dt_profiler',
#  '40': 'infernal_cmstat',
#  '41': 'cor2',
#  '42': 'ConsensusMapNormalizer',
#  '43': 'hmmer_hmmsearch',
#  '44': 'bam_to_bigwig',
#  '45': 'cd_hit_dup',
#  '46': 'augustus',
#  '47': 'Nucleosome',
#  '48': 'vcfselectsamples',
#  '49': 'gemini_de_novo',
#  '50': 'FROGS_clustering',
#  '51': 'nspdk_sparse',
#  '52': 'minfi_qc',
#  '53': 'samtools_slice_bam',
#  '54': 'pilon',
#  '55': 'blockbuster',
#  '56': 'gtf2bedgraph',
#  '57': 'picard_MarkDuplicatesWithMateCigar',
#  '58': 'minfi_methcpg',
#  '59': 'mycrobiota-krona-mothur',
#  '60': 'uniprot',
#  '61': 'plotly_regression_performance_plots',
#  '62': 'stringtie_merge',
#  '63': 'macs2_bdgcmp',
#  '64': 'bwa',
#  '65': 'sklearn_build_pipeline',
#  '66': 'Interval_Maf_Merged_Fasta2',
#  '67': 'kallisto_quant',
#  '68': 'mlocarna',
#  '69': 'gops_intersect_1',
#  '70': 'cardinal_mz_images',
#  '71': 'gmx_setup',
#  '72': 'IDMapper',
#  '73': 'picard_EstimateLibraryComplexity',
#  '74': 'smf_utils_extract-boxed-sequences',
#  '75': 'cutadapt',
#  '76': 'snpSift_geneSets',
#  '77': 'EMBOSS: fuzztran39',
#  '78': 'fastq_paired_end_splitter',
#  '79': 'mass_spectrometry_imaging_filtering',
#  '80': 'cshl_fastx_renamer',
#  '81': 'vcfvcfintersect',
#  '82': 'gatk2_unified_genotyper',
#  '83': 'cuffnorm',
#  '84': 'gffread',
#  '85': 'flexbar_split_RYYR_bcs',
#  '86': 'jbrowse',
#  '87': 'wolf_psort',
#  '88': 'CONVERTER_bed_to_bgzip_0',
#  '89': 'venn_list',
#  '90': 'deeptools_correctGCBias',
#  '91': 'samtools_sort',
#  '92': 'picard_CASM',
#  '93': 'CONVERTER_fasta_to_tabular',
#  '94': 'varscan_mpileup',
#  '95': 'sample_seqs',
#  '96': 'vcfbedintersect',
#  '97': 'glimmer_build-icm',
#  '98': 'goseq',
#  '99': 'Show tail1',
#  '100': 'deeptools_compute_gc_bias',
#  '101': 'ctb_ob_genProp',
#  '102': 'sort1',
#  '103': 'ConsensusID',
#  '104': 'hicexplorer_hicplotmatrix',
#  '105': 'ncbi_rpsblast_wrapper',
#  '106': 'ngsutils_bam_filter',
#  '107': 'stacks_denovomap',
#  '108': 'blastxml_to_top_descr',
#  '109': 'je_demultiplex',
#  '110': 'vcftools_isec',
#  '111': 'rbc_mirdeep2_quantifier',
#  '112': 'sickle',
#  '113': 'deeptools_multi_bam_summary',
#  '114': 'mimodd_map',
#  '115': 'picard_MarkDuplicates',
#  '116': 'picard_ARRG',
#  '117': 'locarna_multiple',
#  '118': 'glimmer_knowlegde-based',
#  '119': 'kraken-report',
#  '120': 'extract_aln_ends.py',
#  '121': 'gops_merge_1',
#  '122': 'idpassemble',
#  '123': 'bg_column_arrange_by_header',
#  '124': 'mothur_get_groups',
#  '125': 'smf_utils_fix-fasta-headers',
#  '126': 'nonpareil',
#  '127': 'samtools_filter',
#  '128': 'bwa_wrapper',
#  '129': 'viennarna_rnaplot',
#  '130': 'column_remove_by_header',
#  '131': 'rnaz',
#  '132': 'hgv_linkToGProfile',
#  '133': 'EMBOSS: extractseq35',
#  '134': 'Count1',
#  '135': 'MultiplexResolver',
#  '136': 'hicexplorer_hicmergematrixbins',
#  '137': 'idpquery',
#  '138': 'vcf_filter',
#  '139': 'shovill',
#  '140': 'racon',
#  '141': 'megahit',
#  '142': 'gemini_load',
#  '143': '__ZIP_COLLECTION__',
#  '144': 'eukaryotic_ncbi_submission',
#  '145': 'structure_to_gspan',
#  '146': 'gd_raxml',
#  '147': 'get_sequences',
#  '148': 'mothur_unique_seqs',
#  '149': 'ctb_simsearch',
#  '150': 'ip_projective_transformation_points',
#  '151': 'mothur_pre_cluster',
#  '152': 'mothur_lefse',
#  '153': 'blastxml_to_tabular_selectable',
#  '154': 'fastq_paired_end_deinterlacer',
#  '155': 'qiime_pick_open_reference_otus',
#  '156': 'collection_column_join',
#  '157': 'mothur_classify_otu',
#  '158': 'plotly_ml_performance_plots',
#  '159': 'fastq_paired_end_interlacer',
#  '160': 'get_read_pipeline',
#  '161': 'roary',
#  '162': 'table_annovar',
#  '163': 'methtools_plot',
#  '164': 'gatk2_variant_select',
#  '165': 'FeatureLinkerUnlabeledQT',
#  '166': 'cardinal_combine',
#  '167': 'dunovo',
#  '168': 'QCCalculator',
#  '169': 'graphclust_aggregate_alignments',
#  '170': 'cshl_fasta_formatter',
#  '171': 'bed_to_bigwig',
#  '172': 'velvet',
#  '173': 'gatk2_depth_of_coverage',
#  '174': 'sam_merge2',
#  '175': 'FROGS_preprocess',
#  '176': 'cshl_fastx_artifacts_filter',
#  '177': 'glimmer_not-knowlegde-based',
#  '178': 'qiime_make_phylogeny',
#  '179': 'qiime_pick_rep_set',
#  '180': 'tp_cat',
#  '181': 'tsne',
#  '182': 'tp_find_and_replace',
#  '183': 'picard_FixMateInformation',
#  '184': 'pileup_interval',
#  '185': 'picard_CollectInsertSizeMetrics',
#  '186': 'gtftobed12',
#  '187': 'CONVERTER_gff_to_bed_0',
#  '188': 'tp_multijoin_tool',
#  '189': 'ctb_compound_convert',
#  '190': 'fastq_dump',
#  '191': 'samtools_stats',
#  '192': 'minfi_dropsnp',
#  '193': 'bg_protein_properties',
#  '194': 'CometAdapter',
#  '195': 'qiime_validate_mapping_file',
#  '196': 'gene2exon1',
#  '197': 'vegan_diversity',
#  '198': 'bigwig_to_bedgraph',
#  '199': 'mothur_pcoa',
#  '200': 'IDMassAccuracy',
#  '201': 'FastTree',
#  '202': 'IDScoreSwitcher',
#  '203': 'preproc',
#  '204': 'msgfplus',
#  '205': 'tp_head_tool',
#  '206': 'Flash',
#  '207': 'filter_by_fasta_ids',
#  '208': 'openms_protein_quantifier',
#  '209': 'ete_genetree_splitter',
#  '210': 'Remove beginning1',
#  '211': 'hcluster_sg_parser',
#  '212': 'mothur_chimera_vsearch',
#  '213': 'picard_NormalizeFasta',
#  '214': 'trimmer',
#  '215': 'mothur_get_communitytype',
#  '216': 'tp_tac',
#  '217': 'eden_vectorizer',
#  '218': 'minfi_maptogenome',
#  '219': 'cufflinks_prok',
#  '220': 'cshl_fastx_trimmer',
#  '221': 'tp_text_file_with_recurring_lines',
#  '222': 'uparse',
#  '223': 'IDConflictResolver',
#  '224': 'random_lines1',
#  '225': 'aggregate_scores_in_intervals2',
#  '226': 'treebest_best',
#  '227': 'vegan_rarefaction',
#  '228': 'EMBOSS: geecee41',
#  '229': 'column_order_header_sort',
#  '230': 'annotatemyids',
#  '231': 'minfi_read450k',
#  '232': 'fraggenescan',
#  '233': 'mycrobiota-otutable_add_blast',
#  '234': 'datamash_transpose',
#  '235': 'stacks_refmap',
#  '236': 'MapRTTransformer',
#  '237': 'bedtools_bamtobed',
#  '238': 'humann2',
#  '239': 'hicexplorer_hictransform',
#  '240': 'sklearn_searchcv',
#  '241': 'deeptools_plot_correlation',
#  '242': 'picard_CollectWgsMetrics',
#  '243': 'graphclust_glob_report_no_align',
#  '244': 'htseq-count',
#  '245': 'FROGS_remove_chimera',
#  '246': 'nn_classifier',
#  '247': 'ctb_online_data_fetch',
#  '248': 'quast',
#  '249': 'iuc_pear',
#  '250': 'mothur_seq_error',
#  '251': 'cshl_fastq_quality_boxplot',
#  '252': 'r_correlation_matrix',
#  '253': 'transdecoder',
#  '254': 'valet',
#  '255': 'join_files_on_column_fuzzy',
#  '256': 'heatmapper_deepTools',
#  '257': 'viz_overlay_moving_and_fixed_image',
#  '258': 'minfi_getanno',
#  '259': 'hgv_snpFreq',
#  '260': 'graphclust_align_cluster',
#  '261': 'gatk2_indel_realigner',
#  '262': 'cardinal_quality_report',
#  '263': 'sailfish',
#  '264': 'bedtools_coveragebed',
#  '265': 'meme_chip',
#  '266': 'fastq_manipulation',
#  '267': 'FeatureLinkerUnlabeledKD',
#  '268': 'hisat2',
#  '269': 'Determine_BC',
#  '270': 'mothur_sub_sample',
#  '271': 'heinz_visualization',
#  '272': 'sklear_numeric_clustering',
#  '273': 'rarefaction',
#  '274': 'rseqc_bam_stat',
#  '275': 'deeptools_bam_compare',
#  '276': 'abricate',
#  '277': 'gatk2_variant_filtration',
#  '278': 'datamash_ops',
#  '279': 'Extractor',
#  '280': 'tp_sed_tool',
#  '281': 'hicexplorer_hicsummatrices',
#  '282': 'make_families',
#  '283': 'PicardInsertSize',
#  '284': 'deeptools_computeGCBias',
#  '285': 'bams2ratio',
#  '286': 'FidoAdapter',
#  '287': 'cshl_fastq_to_fasta',
#  '288': 'lastz_wrapper_2',
#  '289': 'tabular_to_fastq',
#  '290': 'TextExporter',
#  '291': 'EMBOSS: seqret84',
#  '292': 'cshl_easyjoin',
#  '293': 'collapse_dataset',
#  '294': 'mass_spectrometry_imaging_qc',
#  '295': 'EMBOSS: newseq59',
#  '296': 'tp_uniq_tool',
#  '297': 'sklearn_feature_selection',
#  '298': 'mimodd_varreport',
#  '299': 'proteomics_search_protein_prophet_1',
#  '300': 'fastq collapser',
#  '301': 'minfi_rset',
#  '302': 'deeptools_multi_bigwig_summary',
#  '303': 'pynast',
#  '304': '16Saligner',
#  '305': 'mothur_remove_groups',
#  '306': 'rseqc_infer_experiment',
#  '307': 'cufflinks',
#  '308': 'ExtractFASTAfromFASTQ',
#  '309': 'Cut1',
#  '310': 'fasttree',
#  '311': 'rseqc_geneBody_coverage',
#  '312': 'eden_sequence_converter',
#  '313': '__FILTER_FAILED_DATASETS__',
#  '314': 'xcms_merge',
#  '315': 'gemini_burden',
#  '316': 'Paste1',
#  '317': 'deeptools_heatmapper',
#  '318': 'smf_utils_find-boxes',
#  '319': 'CONVERTER_fastqgz_to_fastq',
#  '320': 'mycrobiota-correct-replicates',
#  '321': 'FROGS_affiliation_OTU',
#  '322': 'ggplot2_heatmap2',
#  '323': 'bwameth',
#  '324': 'minimap2',
#  '325': 'methtools_filter',
#  '326': 'bam-filter',
#  '327': 'cshl_fastx_barcode_splitter',
#  '328': 'deeptools_compute_matrix',
#  '329': 'abims_xcms_group',
#  '330': 'tophat2',
#  '331': 'PeakPickerHiRes',
#  '332': 'trim_reads',
#  '333': 'umi_tools_extract',
#  '334': 'ssake',
#  '335': 'rseqc_bam2wig',
#  '336': 'varscan_somatic',
#  '337': 'extract_bcs.py',
#  '338': 'deeptools_plot_pca',
#  '339': 'bismark_bowtie',
#  '340': 'salmon',
#  '341': 'je_clip',
#  '342': 'numeric_clustering',
#  '343': 'ggplot_histogram',
#  '344': 'ggplot2_point',
#  '345': 'viennarna_rnafold',
#  '346': 'MapStatistics',
#  '347': 'vcftools_annotate',
#  '348': 'scaffold2fasta',
#  '349': 'mothur_parsimony',
#  '350': 'metaspades',
#  '351': 'raceid_inspectclusters',
#  '352': 'rbc_mafft',
#  '353': 'deeptools_compute_matrix_operations',
#  '354': 'sam_bw_filter',
#  '355': 'vcf2tsv',
#  '356': 'trinity',
#  '357': 'smooth_running_window',
#  '358': 'FalseDiscoveryRate',
#  '359': 'bcftools_consensus',
#  '360': 'cardinal_preprocessing',
#  '361': 'gops_cluster_1',
#  '362': 'pileup_parser',
#  '363': 'XTandemAdapter',
#  '364': 'Summary_Statistics1',
#  '365': 'FeatureLinkerUnlabeled',
#  '366': '__FLATTEN__',
#  '367': 'gatk2_reduce_reads',
#  '368': 'svm_classifier',
#  '369': 'mothur_dist_seqs',
#  '370': 'ncbi_blastn_wrapper',
#  '371': 'bg_uniq',
#  '372': 'ctb_change_title',
#  '373': 'abims_xcms_summary',
#  '374': 'filter_bed_on_splice_junctions',
#  '375': 'wc_gnu',
#  '376': 'gemini_comp_hets',
#  '377': 'ip_projective_transformation',
#  '378': 'rsem_calculate_expression',
#  '379': 'sam_pileup',
#  '380': 'bedtools_map',
#  '381': 'umi_tools_group',
#  '382': 'bedtools_bamtofastq',
#  '383': 'mothur_filter_seqs',
#  '384': 'mothur_make_contigs',
#  '385': 'mergeCols1',
#  '386': 'spades',
#  '387': 'proteomics_search_peptide_prophet_1',
#  '388': 'Grep1',
#  '389': 'heinz_bum',
#  '390': 'heatmapper',
#  '391': 'deeptools_bamCoverage',
#  '392': 'pileometh',
#  '393': 'graphlan_annotate',
#  '394': 'tp_sort_header_tool',
#  '395': 'rbc_splitfasta',
#  '396': 'bamCoverage_deepTools',
#  '397': 'modencode_peakcalling_spp',
#  '398': 'cuffcompare',
#  '399': 'CONVERTER_fasta_to_fai',
#  '400': 'CONVERTER_Bam_Bai_0',
#  '401': 'chipseeker',
#  '402': 'fgsea',
#  '403': 'bundle_collection',
#  '404': 'raceid_trajectory',
#  '405': 'seq_composition',
#  '406': 'fastq_filter',
#  '407': 'Remove_ending',
#  '408': 'minfi_getM',
#  '409': 'remove_tail.py',
#  '410': 'flanking_features_1',
#  '411': 'naive_variant_caller',
#  '412': 'picard_ValidateSamFile',
#  '413': 'trimmomatic',
#  '414': 'qiime_align_seqs',
#  '415': 'deseq2_single',
#  '416': 'Add_a_column1',
#  '417': 'rna_star',
#  '418': 'gmx_npt',
#  '419': 'createInterval',
#  '420': 'tp_unfold_column_tool',
#  '421': 'mass_spectrometry_imaging_preprocessing',
#  '422': 'bowtie_wrapper',
#  '423': 'IDMerger',
#  '424': 'xpath',
#  '425': 'RNAlien',
#  '426': 'mycrobiota-qc-report',
#  '427': 'FeatureFinderMetabo',
#  '428': 'bedtools_windowbed',
#  '429': 'mothur_remove_lineage',
#  '430': 'selectsequencesfrommsa',
#  '431': 'wiggle2simple1',
#  '432': 'MapAlignerPoseClustering',
#  '433': 'picard_AddOrReplaceReadGroups',
#  '434': 'subtract_query1',
#  '435': 'ncbi_blastx_wrapper',
#  '436': 'gatk_depth_of_coverage',
#  '437': 'seq_filter_by_mapping',
#  '438': 'seurat',
#  '439': 'dexseq',
#  '440': 'gff_to_sequence',
#  '441': 'CONVERTER_interval_to_bedstrict_0',
#  '442': 'sam_to_bam',
#  '443': 'macs2_callpeak',
#  '444': 'deeptools_bam_coverage',
#  '445': 'vcftools_merge',
#  '446': 'fasta-stats',
#  '447': 'ete_homology_classifier',
#  '448': 'mothur_venn',
#  '449': 'ctb_filter',
#  '450': 'mz_to_sqlite',
#  '451': 'tp_sorted_uniq',
#  '452': 'deeptools_plot_enrichment',
#  '453': 'msconvert_nix',
#  '454': 'gemini_query',
#  '455': 'picard_SortSam',
#  '456': 'bctools_extract_crosslinked_nucleotides',
#  '457': 'gatk_realigner_target_creator',
#  '458': 'gemini_pathways',
#  '459': 'smf_utils_filter-by-energy',
#  '460': 'mothur_cluster',
#  '461': 'vcfflatten2',
#  '462': 'ncbi_makeblastdb',
#  '463': 'hcluster_sg',
#  '464': 'bowtie2',
#  '465': 'glob_report',
#  '466': 'cummerbund_to_cuffdiff',
#  '467': 'bam2wig',
#  '468': 'mothur_merge_files',
#  '469': 'cshl_princeton_fastx_barcode_splitter',
#  '470': 'qiime_split_libraries_fastq',
#  '471': 'flexbar_no_split',
#  '472': 'megablast_xml_parser',
#  '473': 'rseqc_read_distribution',
#  '474': 'kraken-filter',
#  '475': 'picard_SamToFastq',
#  '476': 'charts',
#  '477': 'mothur_dist_shared',
#  '478': 'rseqc_inner_distance',
#  '479': 'gspan',
#  '480': 'predict_pipeline',
#  '481': 'gemini_actionable_mutations',
#  '482': 'aragorn_trna',
#  '483': 'methtools_destrand',
#  '484': 'EMBOSS: revseq82',
#  '485': 'snpfinder',
#  '486': 'hisat',
#  '487': 'coords2clnt.py',
#  '488': 'freebayes',
#  '489': 'Heatmap',
#  '490': 'umi_tools_dedup',
#  '491': 'term_id_vs_term_name',
#  '492': 'TrimPrimer',
#  '493': 'idpqonvert',
#  '494': 'heinz_scoring',
#  '495': '16Sclassifier',
#  '496': 'ggplot2_histogram',
#  '497': 'length_and_gc_content',
#  '498': 'scale_image',
#  '499': 'prokaryotic_ncbi_submission',
#  '500': 'samtools_split',
#  '501': 'tag_stat2',
#  '502': 'minfi_dmp',
#  '503': 'GeneModelMapper',
#  '504': 'snpEff',
#  '505': 'EMBOSS: wordcount109',
#  '506': 'vcffilter',
#  '507': 'melt',
#  '508': 'MAF_To_Fasta1',
#  '509': 'mothur_remove_seqs',
#  '510': 'sqlite_to_tabular',
#  '511': 'rgPicFixMate',
#  '512': 'mass_spectrometry_imaging_segmentations',
#  '513': 'nanoplot',
#  '514': 'qiime_make_otu_heatmap',
#  '515': 'deeptools_bamCorrelate',
#  '516': 'myrimatch',
#  '517': 'goslimmer',
#  '518': 'convert_bc_to_binary_RY.py',
#  '519': 'minfi_ppfun',
#  '520': 'CONVERTER_sam_to_unsorted_bam',
#  '521': 'je_markdupes',
#  '522': 'sklearn_ensemble',
#  '523': 'segemehl',
#  '524': 'umi_tools_whitelist',
#  '525': 'rseqc_read_duplication',
#  '526': 'GeMoMa_Annotation_Filter',
#  '527': 'bg_find_subsequences',
#  '528': 'peptide_shaker',
#  '529': 'qiime_pick_otus',
#  '530': 'cuffmerge',
#  '531': 'thermo_raw_file_converter',
#  '532': 'rsem_prepare_reference',
#  '533': 'deeptools_bigwig_compare',
#  '534': 'w4mclstrpeakpics',
#  '535': 'tp_easyjoin_tool',
#  '536': 'SequenceCoverageCalculator',
#  '537': 'translate_bed_sequences',
#  '538': 'deseq2',
#  '539': 'hicexplorer_hicfindtads',
#  '540': 'cardinal_filtering',
#  '541': 'mothur_summary_single',
#  '542': 'bedtools_sortbed',
#  '543': 'secure_hash_message_digest',
#  '544': 'fastq_combiner',
#  '545': 'hicexplorer_hicbuildmatrix',
#  '546': 'bedtools_annotatebed',
#  '547': 'histogram_rpy',
#  '548': 'FileMerger',
#  '549': 'edger',
#  '550': 'merge_pcr_duplicates.py',
#  '551': 'export2graphlan',
#  '552': 'gmx_em',
#  '553': 'gops_join_1',
#  '554': 'gatk2_haplotype_caller',
#  '555': 'raceid_filtnormconf',
#  '556': 'enhanced_bowtie_wrapper',
#  '557': 'group_humann2_uniref_abundances_to_go',
#  '558': 'Btrim64',
#  '559': 'mothur_screen_seqs',
#  '560': 'rgweblogo3',
#  '561': 'meme_psp_gen',
#  '562': 'minfi_dmr',
#  '563': 'mothur_cluster_split',
#  '564': 'trim_galore',
#  '565': 'tp_awk_tool',
#  '566': 'umi_tools_count',
#  '567': 'w4mcorcov',
#  '568': 'snpSift_annotate',
#  '569': 'gops_basecoverage_1',
#  '570': 'infernal_cmsearch',
#  '571': 'proteomics_moff',
#  '572': 'bcftools_norm',
#  '573': 'dexseq_count',
#  '574': 'gemini_annotate',
#  '575': 'iReport',
#  '576': 'term_id_vs_term_def',
#  '577': 'deeptools_correct_gc_bias',
#  '578': 'MassCalculator',
#  '579': 'flexbar_split_RR_bcs',
#  '580': 'tophat',
#  '581': 'mimodd_vcf_filter',
#  '582': 'bcftools_call',
#  '583': 'align_families',
#  '584': 'mothur_make_shared',
#  '585': 'bctools_remove_spurious_events',
#  '586': 'rcas',
#  '587': 'gatk_indel_realigner',
#  '588': 'cshl_fasta_nucleotides_changer',
#  '589': 'FileConverter',
#  '590': 'regex1',
#  '591': 'mycrobiota-make-multi-otutable',
#  '592': 'samtools_rmdup',
#  '593': 'gatk2_variant_recalibrator',
#  '594': 'muscle',
#  '595': 'mass_spectrometry_imaging_ion_images',
#  '596': 'bg_statistical_hypothesis_testing',
#  '597': 'idr-embl',
#  '598': 'cshl_sed_tool',
#  '599': 'ia_coordinates_of_roi',
#  '600': 'get_subontology_from',
#  '601': '__FILTER_FROM_FILE__',
#  '602': 'vcfcombine',
#  '603': 'tmhmm2',
#  '604': 'gatk2_variant_apply_recalibration',
#  '605': 'FeatureFinderCentroided',
#  '606': 'picard_CollectRnaSeqMetrics',
#  '607': 'computeMatrix',
#  '608': 'query_tabular',
#  '609': 'smf_utils_estimate-energy',
#  '610': 'gatk_unified_genotyper',
#  '611': 'pieplots_macs',
#  '612': 'transpose',
#  '613': 'Convert characters1',
#  '614': 'mothur_count_seqs',
#  '615': 'uchime',
#  '616': 'cardinal_segmentations',
#  '617': 'bctools_extract_alignment_ends',
#  '618': 'bandage_image',
#  '619': 'EMBOSS: fuzzpro38',
#  '620': 'Filter1',
#  '621': 'macs2_predictd',
#  '622': 'tp_grep_tool',
#  '623': 'bamCompare_deepTools',
#  '624': 'porechop',
#  '625': 'ggplot2_heatmap',
#  '626': 'rbc_mirdeep2',
#  '627': 'mass_spectrometry_imaging_mzplots',
#  '628': 'NFS_transfer',
#  '629': 'gemini_windower',
#  '630': 'fastq_to_tabular',
#  '631': 'rarefaction_analyzer',
#  '632': 'gff2bed1',
#  '633': 'samtools_idxstats',
#  '634': 'kraken',
#  '635': 'interproscan',
#  '636': 'picard_ReorderSam',
#  '637': 'bed2gff1',
#  '638': 'cmv',
#  '639': 'proteomics_search_tandem_1',
#  '640': 'graphlan',
#  '641': 'cast',
#  '642': 'addName',
#  '643': 'cshl_awk_tool',
#  '644': 'fasta_compute_length',
#  '645': 'gops_subtract_1',
#  '646': 'blockclust',
#  '647': 'gops_coverage_1',
#  '648': 'meme_dreme',
#  '649': 'deeptools_bamFingerprint',
#  '650': 'seq_filter_by_id',
#  '651': 'fasta2tab',
#  '652': 'DecoyDatabase',
#  '653': 'EMBOSS: transeq101',
#  '654': 'cmFinder',
#  '655': 'bedtools_unionbedgraph',
#  '656': 'Fetch Taxonomic Ranks',
#  '657': 'sam2interval',
#  '658': 'mothur_classify_rf',
#  '659': 'barchart_gnuplot',
#  '660': 'raceid_main',
#  '661': 'metilene',
#  '662': 'Digestor',
#  '663': 'newick_display',
#  '664': 'samtools_mpileup',
#  '665': 'nanopolish_variants',
#  '666': 'Extract_features1',
#  '667': 'metaphlan2krona',
#  '668': 'cshl_fastx_quality_statistics',
#  '669': 'stacks_procrad',
#  '670': 'hgv_david',
#  '671': 'ctb_silicos_qed',
#  '672': 'snippy',
#  '673': 'sklearn_nn_classifier',
#  '674': 'search_gui',
#  '675': 'mimodd_varcall',
#  '676': 'qiime_core_diversity',
#  '677': 'Psortb',
#  '678': 'gafa',
#  '679': 'qiime_count_seqs',
#  '680': 'deeptools_plot_heatmap',
#  '681': 'tp_replace_in_line',
#  '682': 'limma_voom',
#  '683': 'mass_spectrometry_imaging_classification',
#  '684': 'bedtools_subtractbed',
#  '685': 'CONVERTER_interval_to_bgzip_0',
#  '686': 'cardinal_data_exporter',
#  '687': 'picard_MergeSamFiles',
#  '688': 'tophat_fusion_post',
#  '689': 'infernal_cmbuild',
#  '690': 'cshl_grep_tool',
#  '691': 'sklearn_svm_classifier',
#  '692': 'format_metaphlan2_output',
#  '693': 'gatk2_variant_annotator',
#  '694': 'mothur_corr_axes',
#  '695': 'tp_replace_in_column',
#  '696': 'fragmenter',
#  '697': 'htseq_count',
#  '698': 'bedtools_genomecoveragebed_bedgraph',
#  '699': 'gemini_db_info',
#  '700': '__SORTLIST__',
#  '701': 'bamleftalign',
#  '702': 'qiime_pick_closed_reference_otus',
#  '703': 'comp1',
#  '704': 'bismark_bowtie2',
#  '705': 'annotateMyIDs',
#  '706': 'piranha',
#  '707': 'correctGCBias',
#  '708': 'wsdl_hmdb',
#  '709': 'mothur_make_biom',
#  '710': 'bcftools_view',
#  '711': 'bctools_remove_tail',
#  '712': 'deeptools_plot_profile',
#  '713': 'rgPicardMarkDups',
#  '714': 'minfi_mset',
#  '715': 'sequence_content_trimmer',
#  '716': 'rmcontamination',
#  '717': 'w4mclassfilter',
#  '718': 'abims_xcms_fillPeaks',
#  '719': 'velvetoptimiser',
#  '720': 'DatamashTranspose',
#  '721': 'tp_sort_rows',
#  '722': 'gemini_interactions',
#  '723': 'bedtools_slopbed',
#  '724': 'humann2_genefamilies_genus_level',
#  '725': 'bedtools_intersectbed_bam',
#  '726': 'gtf_filter_by_attribute_values_list',
#  '727': 'bamFilter',
#  '728': 'bamtools',
#  '729': 'flexbardsc',
#  '730': 'picard_BamIndexStats',
#  '731': 't2t_report',
#  '732': 'fastq_quality_trimmer',
#  '733': 'dbbuilder',
#  '734': 'featurecounts',
#  '735': 'mothur_align_seqs',
#  '736': 'IsobaricAnalyzer',
#  '737': 'fastq_to_fasta_python',
#  '738': 'mothur_amova',
#  '739': 'IDFileConverter',
#  '740': 'cat1',
#  '741': 'deeptools_plot_coverage',
#  '742': 'dexseq_annotate',
#  '743': 'Batch_correction',
#  '744': 'ProteinResolver',
#  '745': 'rnbeads',
#  '746': '__MERGE_COLLECTION__',
#  '747': 'HighResPrecursorMassCorrector',
#  '748': 'stacks_populations',
#  '749': 'peakcalling_macs',
#  '750': 'clustalw',
#  '751': 'bedtools_genomecoveragebed',
#  '752': 'metaphlan_hclust_heatmap',
#  '753': 'EMBOSS: shuffleseq87',
#  '754': 'IDFilter',
#  '755': 'fasta_filter_by_length',
#  '756': 'CONVERTER_bed_to_gff_0',
#  '757': 'mothur_phylotype',
#  '758': 'CONVERTER_gz_to_uncompressed',
#  '759': 'MzTabExporter',
#  '760': 'combine_metaphlan2_humann2',
#  '761': 'vcffilter2',
#  '762': 'meme_meme',
#  '763': 'abims_CAMERA_annotateDiffreport',
#  '764': 'ncbi_blastp_wrapper',
#  '765': 'megablast_wrapper',
#  '766': 'mcClust',
#  '767': 'filtlong',
#  '768': 'cshl_fastx_collapser',
#  '769': 'gatk2_print_reads',
#  '770': 'snippy_core',
#  '771': 'EMBOSS: tranalign100',
#  '772': 'FROGS_affiliations_stat',
#  '773': 'varscan_copynumber',
#  '774': 'vcfgenotypes',
#  '775': 'fastqc',
#  '776': 'fasplit',
#  '777': 'mothur_heatmap_bin',
#  '778': 'bedtools_getfastabed',
#  '779': 'msconvert2_raw',
#  '780': 'Multivariate',
#  '781': 'samtools_flagstat',
#  '782': 'signalp3',
#  '783': 'mothur_make_group',
#  '784': 'graphicsmagick_image_convert',
#  '785': 'cuffdiff',
#  '786': 'samtools_flag_filter',
#  '787': '__APPLY_RULES__',
#  '788': 'ucsc-twobittofa',
#  '789': 'mothur_get_seqs',
#  '790': 'ncbi_tblastn_wrapper',
#  '791': 'igvtools_count',
#  '792': 'correct_barcodes',
#  '793': 'ProteinInference',
#  '794': 'XY_Plot_1',
#  '795': 'Univariate',
#  '796': 'mothur_nmds',
#  '797': 'bedtools_complementbed',
#  '798': 'addValue',
#  '799': 'CONVERTER_interval_to_bed_0',
#  '800': 'deg_annotate',
#  '801': 'stacks_genotypes',
#  '802': 'velvetg_jgi',
#  '803': 'viennarna_rnaalifold',
#  '804': 'plotly_parallel_coordinates_plot',
#  '805': 'bedtools_genomecoveragebed_histogram',
#  '806': 'hicexplorer_hicpca',
#  '807': 'MSGFPlusAdapter',
#  '808': 'raceid_clustering',
#  '809': 'stringtie',
#  '810': 'vsearch_dereplication',
#  '811': 'fasta_merge_files_and_filter_unique_sequences',
#  '812': 'mothur_count_groups',
#  '813': 'PicardASMetrics',
#  '814': 'methtools_dmr',
#  '815': 'p_clip_peaks',
#  '816': 'prokka',
#  '817': 'NSPDK_candidateClust',
#  '818': 'cshl_fastq_quality_filter',
#  '819': 'mothur_classify_seqs',
#  '820': 'Draw_phylogram',
#  '821': 'get_feature_info',
#  '822': 'preMloc',
#  '823': 'mothur_heatmap_sim',
#  '824': 'tp_tail_tool',
#  '825': 'metaphlan2',
#  '826': 'tp_cut_tool',
#  '827': 'fastq_groomer',
#  '828': 'cshl_fastx_reverse_complement',
#  '829': 'cuffquant',
#  '830': 'meme_fimo',
#  '831': 'ChangeCase',
#  '832': 'gatk2_realigner_target_creator',
#  '833': 'cshl_uniq_tool',
#  '834': 'goenrichment',
#  '835': 'maldi_quant_peak_detection',
#  '836': 'secretbt2test',
#  '837': 'rbc_mirdeep2_mapper',
#  '838': 'ggplot_point',
#  '839': 'TrimByN',
#  '840': 'CONVERTER_bedgraph_to_bigwig',
#  '841': 'IDPosteriorErrorProbability',
#  '842': 'Extract_RNA_seq_Evidence',
#  '843': 'ctb_remSmall',
#  '844': 'deeptools_plot_fingerprint',
#  '845': 'metams_runGC',
#  '846': 'samtool_filter2',
#  '847': 'openms_id_file_converter',
#  '848': 'gops_concat_1',
#  '849': 'fastq_trimmer',
#  '850': 'snpSift_dbnsfp_generic',
#  '851': 'circgraph',
#  '852': 'bedtools_multicovtbed',
#  '853': 'vcf2pgSnp',
#  '854': 'biosigner',
#  '855': 'deeptools_bamCompare',
#  '856': 'wig_to_bigWig',
#  '857': 'velveth_jgi',
#  '858': 'humann2_renorm_table',
#  '859': 'picard_CleanSam',
#  '860': 'antismash',
#  '861': 'mothur_metastats',
#  '862': 'snpsift_vartype',
#  '863': 'ChooseTag',
#  '864': 'hicexplorer_hiccorrectmatrix',
#  '865': 'rnafold',
#  '866': 'bedtools_intersectBed',
#  '867': 'bwa_mem',
#  '868': 'find_in_reference',
#  '869': 'vcfannotate',
#  '870': 'flye',
#  '871': 'cshl_fastx_nucleotides_distribution',
#  '872': 'gmx_md',
#  '873': 'gemini_recessive_and_dominant',
#  '874': 'vcfsort',
#  '875': 'FileFilter',
#  '876': 'CONVERTER_gff_to_interval_index_0',
#  '877': 'egsea',
#  '878': 'gatk2_base_recalibrator',
#  '879': 'sklearn_numeric_clustering',
#  '880': 'snpEff_download',
#  '881': 'peakachu',
#  '882': 'hicexplorer_hicplottads',
#  '883': 'ctb_chemfp_mol2fps',
#  '884': 'blastxml_to_tabular',
#  '885': 'varscan',
#  '886': 'samtools_calmd',
#  '887': 'mothur_summary_seqs',
#  '888': 'bedtools_coveragebed_counts',
#  '889': 'chipsequtil_maptoknowngenes',
#  '890': 'DatamashOps',
#  '891': 'cshl_multijoin',
#  '892': 'qiime_assign_taxonomy',
#  '893': 'EMBOSS: textsearch98',
#  '894': 'hmmer_hmmbuild',
#  '895': 'tab2fasta',
#  '896': 'paralyzer',
#  '897': 'get_flanks1',
#  '898': 'join1',
#  '899': 'disco',
#  '900': '__RELABEL_FROM_FILE__',
#  '901': 'unipept',
#  '902': 'rseqc_junction_saturation',
#  '903': 'mothur_chimera_uchime',
#  '904': 'fastq_join',
#  '905': 'unicycler',
#  '906': 'mimodd_varextract',
#  '907': 'FileInfo',
#  '908': 'vcffixup',
#  '909': 'CONVERTER_bed_gff_or_vcf_to_bigwig_0',
#  '910': 'decoyfasta',
#  '911': 'samtools_bedcov',
#  '912': 'allele_counts_1',
#  '913': 'taxonomy_krona_chart',
#  '914': 'rbc_rnacode',
#  '915': 'Extract genomic DNA 1',
#  '916': 'ctb_remIons',
#  '917': 'gmx_solvate',
#  '918': 'raceid_inspecttrajectory',
#  '919': 'map_peptides_to_bed',
#  '920': 'peakcalling_macs14',
#  '921': 'cshl_cut_tool',
#  '922': 'bam_to_sam',
#  '923': 'cshl_awk_replace_in_column',
#  '924': 'bedtools_intersectbed',
#  '925': 'FROGS_filters',
#  '926': 'sed_stream_editor',
#  '927': 'extract_element_from_collection',
#  '928': 'react_cal_pipeline',
#  '929': 'bedtools_multiintersectbed',
#  '930': 'blast_parser',
#  '931': 'minfi_getbeta',
#  '932': 'mothur_get_oturep',
#  '933': 'mycrobiota-split-multi-otutable',
#  '934': 'kraken-translate',
#  '935': 'krona-text',
#  '936': 'mothur_homova',
#  '937': 'gbk_to_orf',
#  '938': 'deeptools_bigwigCompare',
#  '939': 'maldi_quant_preprocessing',
#  '940': 'heatmap2',
#  '941': 'snpeff_to_peptides',
#  '942': 'deeptools_profiler',
#  '943': 'gmx_nvt',
#  '944': 'bedtools_mergebed',
#  '945': 'modencode_peakcalling_macs2',
#  '946': 'vt_normalize',
#  '947': 'mothur_taxonomy_to_krona',
#  '948': 'EMBOSS: getorf42',
#  '949': 'bg_sortmerna',
#  '950': 't_coffee',
#  '951': 'rm_spurious_events.py',
#  '952': 'deeptools_computeMatrix',
#  '953': 'methtools_tiling',
#  '954': 'bgchem_fragment_merger',
#  '955': 'Grouping1',
#  '956': 'cshl_word_list_grep',
#  '957': 'bedtools_shufflebed',
#  '958': 'multiqc',
#  '959': 'mothur_rarefaction_single',
#  '960': 'blast2go',
#  '961': 'w4mjoinpn',
#  '962': 'genbank_to_gff',
#  '963': 'cummeRbund',
#  '964': 'tp_split_on_column',
#  '965': 'cshl_fastx_clipper',
#  '966': 'FeatureFinderMultiplex',
#  '967': 'lca1',
#  '968': 'bg_diamond',
#  '969': 'TrimByLength',
#  '970': 'silac_analyzer',
#  '971': 'replace_column_with_key_value_file'}

# %%
def verify_model(model, tool_sequence, labels, dictionary, reverse_dictionary, compatible_tools, topk=20, max_seq_len=25):
    tl_seq = tool_sequence.split(",")
    last_tool_name = reverse_dictionary[str(tl_seq[-1])]
    last_compatible_tools = compatible_tools[last_tool_name]
    sample = np.zeros(max_seq_len)
    for idx, tool_id in enumerate(tl_seq):
        sample[idx] = int(tool_id)
    sample_reshaped = np.reshape(sample, (1, max_seq_len))
    
    tool_sequence_names = [reverse_dictionary[str(tool_pos)] for tool_pos in tool_sequence.split(",")]
    print("Tool seq: %s" % ",".join(tool_sequence_names))
    # predict next tools for a test path
    prediction = model.predict(sample_reshaped, verbose=0)
    prediction = np.reshape(prediction, (prediction.shape[1],))
    prediction_pos = np.argsort(prediction, axis=-1)

    # get topk prediction
    topk_prediction_pos = prediction_pos[-topk:]
    topk_prediction_val = [np.round(prediction[pos] * 100, 2) for pos in topk_prediction_pos]

    # read tool names using reverse dictionary
    pred_tool_ids = [reverse_dictionary[str(tool_pos)] for tool_pos in topk_prediction_pos]
    actual_next_tool_ids = list(set(pred_tool_ids).intersection(set(last_compatible_tools.split(","))))      
        
    #print("Predicted tools: %s" % ",".join(pred_tool_ids))
    print()
    pred_tool_ids_sorted = dict()
    for (tool_pos, tool_pred_val) in zip(topk_prediction_pos, topk_prediction_val):
        tool_name = reverse_dictionary[str(tool_pos)]
        if tool_name in actual_next_tool_ids:
            pred_tool_ids_sorted[tool_name] = tool_pred_val
    pred_tool_ids_sorted = dict(sorted(pred_tool_ids_sorted.items(), key=lambda kv: kv[1], reverse=True))
    
    cls_wt = dict()
    usg_wt = dict()
    inv_wt = dict()
    ids_tools = dict()
    keys = list(pred_tool_ids_sorted.keys())
    for k in keys:
        try:
            cls_wt[k] = np.round(class_weights[str(data_dict[k])], 2)
            usg_wt[k] = np.round(usage_weights[k], 2)
            inv_wt[k] = np.round(inverted_weights[str(data_dict[k])], 2)
        except:
            continue
    print("Predicted tools: \n")
    print(pred_tool_ids_sorted)
    print()
    print("Class weights: \n")
    cls_wt = dict(sorted(cls_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(cls_wt)
    print()
    print("Usage weights: \n")
    usg_wt = dict(sorted(usg_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(usg_wt)
    print()
    total_usage_wt = np.mean(list(usg_wt.values()))
    print("Mean usage wt: %0.4f" % (total_usage_wt))
    print()
    print("Inverted weights: \n")
    inv_wt = dict(sorted(inv_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(inv_wt)
    for key in pred_tool_ids_sorted:
        ids_tools[key] = dictionary[key]
    print()
    print("Tool ids")
    print(ids_tools)
    print("======================================")
    return cls_wt, usg_wt, inv_wt, pred_tool_ids_sorted

topk = 10
tool_seq = "966" # ,875,223,17
class_wt, usage_wt, inverse_wt, pred_tools = verify_model(model, tool_seq, "", dictionary, reverse_dictionary, compatibile_tools, topk)
# Out:
# Tool seq: FeatureFinderMultiplex
#
# Predicted tools:
#
# {'FileInfo': 15.87}
#
# Class weights:
#
# {'FileInfo': 9.34}
#
# Usage weights:
#
# {'FileInfo': 21.39}
#
# Mean usage wt: 21.3900
#
# Inverted weights:
#
# {'FileInfo': 534.54}
#
# Tool ids
# {'FileInfo': 907}
# ======================================

# %%
list_cls_wt = list()
list_usage_wt = list()
list_pred_wt = list()
list_inv_wt = list()
division_pt = int(len(pred_tools) / 2)

for tool in pred_tools:
    list_pred_wt.append(pred_tools[tool])
    #try:
    list_inv_wt.append(inverse_wt[tool])
    list_usage_wt.append(usage_wt[tool])
    #except:
    #list_inv_wt.append(1)

def plot_scatter(y_val, title, xlabel, ylabel):
    x_val = range(1, len(y_val) + 1)
    plt.figure(figsize=(8, 8))
    plt.plot(x_val[:division_pt], y_val[:division_pt], 'ro')
    plt.plot(x_val[division_pt:], y_val[division_pt:], 'b^')
    plt.xlabel(xlabel, size=size_label)
    plt.ylabel(ylabel, size=size_label)
    plt.legend([("First top-%s" % str(division_pt)), ("Next top-%s" % str(division_pt))])
    plt.title(title, size=size_title)
    plt.grid(True)
    plt.show()

plot_scatter(list_usage_wt, "Usage weights for tools", "Number of tools", "Class weights")
#plot_scatter(ave_prediction_weights, ave_usage_weights, "Prediction vs usage weights", "Prediction scores", "Usage weights")
#plot_scatter(ave_prediction_weights, ave_inverted_weights, "Prediction vs inverted weights", "Prediction scores", "Inverted weights")
