# %%
import numpy as np
import json
import warnings
import operator

import h5py
from keras.models import model_from_json
from keras import backend as K

from matplotlib import pyplot as plt

warnings.filterwarnings("ignore")

size_title = 18
size_label = 14
n_pred = 2 

base_path = "data/evaluate_usage_normalized/" # cluster path: 8_similar_galaxy_workflow

path_data_dict = base_path + "data_dict.txt"
path_inverted_wt = base_path + "inverted_weights.txt"
path_usage_wt = base_path + "usage_prediction.txt"
path_class_wt = base_path + "class_weights.txt"
path_test_data = base_path + "test_paths_dict.txt"
model_path = base_path + "trained_model.hdf5"

def read_file(file_path):
    with open(file_path, 'r') as data_file:
        data = json.loads(data_file.read())
    return data

class_weights = read_file(path_class_wt)
usage_weights = read_file(path_usage_wt)
inverted_weights = read_file(path_inverted_wt)
data_dict = read_file(path_data_dict)

def create_model(model_path):
    trained_model = h5py.File(model_path, 'r')
    model_config = json.loads(trained_model.get('model_config').value)
    loaded_model = model_from_json(model_config)
    dictionary = json.loads(trained_model.get('data_dictionary').value)
    compatibile_tools = json.loads(trained_model.get('compatible_tools').value)
    reverse_dictionary = dict((str(v), k) for k, v in dictionary.items())
    model_weights = list()
    weight_ctr = 0
    while True:
        try:
            d_key = "weight_" + str(weight_ctr)
            weights = trained_model.get(d_key).value
            model_weights.append(weights)
            weight_ctr += 1
        except Exception as exception:
            break
    # set the model weights
    loaded_model.set_weights(model_weights)
    return loaded_model, dictionary, reverse_dictionary, compatibile_tools

model, dictionary, reverse_dictionary, compatibile_tools = create_model(model_path)
# Out:
# Using TensorFlow backend.

# %%
reverse_dictionary
# Out:
# {'1': 'FeatureFinderMetabo',
#  '2': 'minfi_mset',
#  '3': 'rbc_mirdeep2_quantifier',
#  '4': 'w4mclstrpeakpics',
#  '5': 'mothur_chimera_uchime',
#  '6': 'seq_filter_by_mapping',
#  '7': 'mothur_venn',
#  '8': 'GeneModelMapper',
#  '9': 'vcfcombine',
#  '10': 'FeatureLinkerUnlabeled',
#  '11': 'scaffold2fasta',
#  '12': 'vt_normalize',
#  '13': 'smf_utils_filter-by-energy',
#  '14': 'segemehl',
#  '15': 'CONVERTER_fastqgz_to_fastq',
#  '16': 'ctb_remSmall',
#  '17': 'sailfish',
#  '18': 'cshl_cut_tool',
#  '19': 'column_order_header_sort',
#  '20': 'mothur_remove_seqs',
#  '21': 'snpfinder',
#  '22': 'ConsensusID',
#  '23': 'mothur_rarefaction_single',
#  '24': 'mothur_remove_lineage',
#  '25': 'ncbi_makeblastdb',
#  '26': 'w4mclassfilter',
#  '27': 'deseq2_single',
#  '28': 'EMBOSS: fuzzpro38',
#  '29': 'mothur_get_seqs',
#  '30': 'heatmapper_deepTools',
#  '31': 'mothur_classify_seqs',
#  '32': 'mothur_cluster',
#  '33': 'bed_to_bigwig',
#  '34': 'vcftools_merge',
#  '35': 'gatk2_variant_select',
#  '36': 'EMBOSS: geecee41',
#  '37': 'graphlan_annotate',
#  '38': 'ggplot2_heatmap2',
#  '39': 'ggplot_point',
#  '40': 'tophat',
#  '41': 'htseq-count',
#  '42': 'stacks_genotypes',
#  '43': 'goslimmer',
#  '44': 'Show tail1',
#  '45': 'cshl_find_and_replace',
#  '46': 'gemini_recessive_and_dominant',
#  '47': 'rseqc_bam2wig',
#  '48': 'iuc_pear',
#  '49': 'w4mcorcov',
#  '50': 'meme_chip',
#  '51': 'FeatureFinderCentroided',
#  '52': 'tsne',
#  '53': 'mothur_cluster_split',
#  '54': 'tag_stat2',
#  '55': 'r_correlation_matrix',
#  '56': 'cor2',
#  '57': 'resistome_analyzer',
#  '58': 'Batch_correction',
#  '59': 'mlocarna',
#  '60': 'IsobaricAnalyzer',
#  '61': 'gops_intersect_1',
#  '62': 'graphclust_aggregate_alignments',
#  '63': 'cshl_grep_tool',
#  '64': 'SequenceCoverageCalculator',
#  '65': 'dbbuilder',
#  '66': 'metilene',
#  '67': 'igvtools_count',
#  '68': 'CONVERTER_sam_to_unsorted_bam',
#  '69': 'EMBOSS: water107',
#  '70': 'ctb_ob_genProp',
#  '71': 'hgv_snpFreq',
#  '72': 'rnaz',
#  '73': 'cshl_sed_tool',
#  '74': 'deeptools_bam_compare',
#  '75': 'vcffilter2',
#  '76': 'raceid_clustering',
#  '77': 'deeptools_correct_gc_bias',
#  '78': 'MapAlignerPoseClustering',
#  '79': 'raceid_inspectclusters',
#  '80': 'react_cal_pipeline',
#  '81': 'rmcontamination',
#  '82': 'macs2_callpeak',
#  '83': 'bedtools_shufflebed',
#  '84': 'nonpareil',
#  '85': 'tp_awk_tool',
#  '86': 'egsea',
#  '87': 'bedtools_mergebed',
#  '88': 'Paste1',
#  '89': 'samtools_slice_bam',
#  '90': 'rbc_mirdeep2_mapper',
#  '91': 'barchart_gnuplot',
#  '92': 'lca1',
#  '93': 'bedtools_complementbed',
#  '94': 'vcffixup',
#  '95': 'eukaryotic_ncbi_submission',
#  '96': 'mothur_chimera_vsearch',
#  '97': 'modencode_peakcalling_macs2',
#  '98': 'bg_statistical_hypothesis_testing',
#  '99': 'cshl_fastq_to_fasta',
#  '100': 'msconvert2_raw',
#  '101': 'smooth_running_window',
#  '102': 'qiime_make_phylogeny',
#  '103': 'heinz_scoring',
#  '104': 'clustalw',
#  '105': 'gmx_em',
#  '106': 'hicexplorer_hiccorrectmatrix',
#  '107': 'bg_find_subsequences',
#  '108': 'viz_overlay_moving_and_fixed_image',
#  '109': 'deeptools_plot_coverage',
#  '110': 'dexseq_count',
#  '111': 'bctools_extract_crosslinked_nucleotides',
#  '112': 'ncbi_tblastn_wrapper',
#  '113': 'minfi_getanno',
#  '114': 'mass_spectrometry_imaging_preprocessing',
#  '115': 'picard_CollectWgsMetrics',
#  '116': 'EMBOSS: fuzztran39',
#  '117': 'tabular_to_fastq',
#  '118': 'bedtools_bamtobed',
#  '119': 'ggplot_histogram',
#  '120': 'mothur_make_group',
#  '121': 'CONVERTER_bed_to_bgzip_0',
#  '122': 'methtools_filter',
#  '123': 'fastq_quality_trimmer',
#  '124': 'bedtools_subtractbed',
#  '125': 'qiime_validate_mapping_file',
#  '126': 'CONVERTER_Bam_Bai_0',
#  '127': 'lastz_wrapper_2',
#  '128': 'deeptools_multi_bam_summary',
#  '129': 'raceid_filtnormconf',
#  '130': 'rna_star',
#  '131': 'fastq_manipulation',
#  '132': 'vcffilter',
#  '133': 'heatmapper',
#  '134': 'bedtools_map',
#  '135': 'EMBOSS: transeq101',
#  '136': 'mothur_make_contigs',
#  '137': 'picard_CleanSam',
#  '138': 'snippy_core',
#  '139': 'samtools_mpileup',
#  '140': 'graphclust_glob_report_no_align',
#  '141': 'peakachu',
#  '142': 'racon',
#  '143': 'bg_uniq',
#  '144': 'circgraph',
#  '145': 'collapse_dataset',
#  '146': 'MultiplexResolver',
#  '147': 'bg_protein_properties',
#  '148': 'minfi_getbeta',
#  '149': 'tp_sort_header_tool',
#  '150': 'dt_profiler',
#  '151': 'abims_CAMERA_annotateDiffreport',
#  '152': 'trinity',
#  '153': 'picard_ReorderSam',
#  '154': 'stringtie',
#  '155': 'glob_report',
#  '156': 'Extract_RNA_seq_Evidence',
#  '157': 'extract_bcs.py',
#  '158': 'secure_hash_message_digest',
#  '159': 'NFS_transfer',
#  '160': 'ip_projective_transformation_points',
#  '161': 'pileup_interval',
#  '162': 'velvetg_jgi',
#  '163': 'rseqc_read_duplication',
#  '164': 'flanking_features_1',
#  '165': 'trimmomatic',
#  '166': 'snpsift_vartype',
#  '167': 'roary',
#  '168': 'cshl_fastx_trimmer',
#  '169': 'salmon',
#  '170': 'column_remove_by_header',
#  '171': 'pynast',
#  '172': 'augustus',
#  '173': 'bedtools_intersectBed',
#  '174': 'mothur_make_shared',
#  '175': 'snpSift_geneSets',
#  '176': 'term_id_vs_term_def',
#  '177': 'tp_tail_tool',
#  '178': 'transdecoder',
#  '179': 'fastq_join',
#  '180': 'mothur_amova',
#  '181': 'cd_hit_dup',
#  '182': 'hmmer_hmmsearch',
#  '183': 'bedtools_multicovtbed',
#  '184': 'gemini_db_info',
#  '185': 'wc_gnu',
#  '186': 'silac_analyzer',
#  '187': 'ucsc-twobittofa',
#  '188': 'tp_sed_tool',
#  '189': 'abims_xcms_fillPeaks',
#  '190': 'hmmer_hmmbuild',
#  '191': 'gemini_comp_hets',
#  '192': 'vcfsort',
#  '193': 'qiime_pick_otus',
#  '194': 'mothur_pre_cluster',
#  '195': 'deeptools_profiler',
#  '196': 'ip_projective_transformation',
#  '197': 'Extract_features1',
#  '198': 'TrimByN',
#  '199': 'deeptools_compute_matrix_operations',
#  '200': 'IDConflictResolver',
#  '201': 'bismark_bowtie2',
#  '202': 'gffcompare',
#  '203': 'EMBOSS: tranalign100',
#  '204': 'minfi_dmp',
#  '205': 'gbk_to_orf',
#  '206': 'gemini_query',
#  '207': 'mothur_parsimony',
#  '208': 'NSPDK_candidateClust',
#  '209': 'uchime',
#  '210': 'picard_FilterSamReads',
#  '211': 'cmFinder',
#  '212': 'ctb_change_title',
#  '213': 'vcf2pgSnp',
#  '214': 'bedtools_unionbedgraph',
#  '215': 'join_files_on_column_fuzzy',
#  '216': 'TrimPrimer',
#  '217': 'gtftobed12',
#  '218': 'deeptools_correctGCBias',
#  '219': 'piranha',
#  '220': 'humann2_renorm_table',
#  '221': 'IDFilter',
#  '222': 'DatamashOps',
#  '223': 'deeptools_plot_heatmap',
#  '224': 'heinz',
#  '225': 'bam_to_sam',
#  '226': 'gatk2_depth_of_coverage',
#  '227': 'tp_uniq_tool',
#  '228': 'hisat2',
#  '229': 'bcftools_consensus',
#  '230': 'Psortb',
#  '231': 'ChooseTag',
#  '232': 'gmx_npt',
#  '233': 'cummerbund_to_cuffdiff',
#  '234': 'htseq_count',
#  '235': 'metaspades',
#  '236': 'seq_composition',
#  '237': 'proteomics_search_protein_prophet_1',
#  '238': 'tp_tac',
#  '239': 'cshl_fastx_nucleotides_distribution',
#  '240': 'gops_concat_1',
#  '241': 'combine_metaphlan2_humann2',
#  '242': 'samtools_calmd',
#  '243': 'EMBOSS: revseq82',
#  '244': 'deeptools_plot_fingerprint',
#  '245': 'minfi_dropsnp',
#  '246': 'jbrowse',
#  '247': 'vegan_diversity',
#  '248': 'gtf_filter_by_attribute_values_list',
#  '249': 'varscan_copynumber',
#  '250': 'mothur_trim_seqs',
#  '251': 'samtools_flag_filter',
#  '252': 'mothur_screen_seqs',
#  '253': 'mothur_count_seqs',
#  '254': 'sqlite_to_tabular',
#  '255': 'smf_utils_estimate-energy',
#  '256': 'flexbar_no_split',
#  '257': 'qiime_align_seqs',
#  '258': 'cardinal_filtering',
#  '259': 'xcms_merge',
#  '260': 'deeptools_computeGCBias',
#  '261': 'Determine_BC',
#  '262': 'DatamashTranspose',
#  '263': 'hicexplorer_hicmergematrixbins',
#  '264': 'openms_protein_quantifier',
#  '265': 'disco',
#  '266': 'Show beginning1',
#  '267': 'ctb_compound_convert',
#  '268': 'kraken-filter',
#  '269': 'gatk2_indel_realigner',
#  '270': 'smf_utils_find-boxes',
#  '271': 'gatk_depth_of_coverage',
#  '272': 'tp_find_and_replace',
#  '273': 'FileFilter',
#  '274': 'tp_head_tool',
#  '275': 'Convert characters1',
#  '276': 'bedtools_genomecoveragebed_bedgraph',
#  '277': '__UNZIP_COLLECTION__',
#  '278': 'subtract_query1',
#  '279': 'idr-embl',
#  '280': 'rgPicFixMate',
#  '281': 'bwa_wrapper',
#  '282': 'annotateMyIDs',
#  '283': 'gatk2_variant_filtration',
#  '284': 'smf_utils_extract-boxed-sequences',
#  '285': 'fastq_paired_end_splitter',
#  '286': 'bowtie2',
#  '287': 'sample_seqs',
#  '288': 'picard_CollectInsertSizeMetrics',
#  '289': 'dexseq',
#  '290': 'Multivariate',
#  '291': 'raceid_inspecttrajectory',
#  '292': 'Extractor',
#  '293': 'gff2bed1',
#  '294': 'abims_xcms_xcmsSet',
#  '295': 'hicexplorer_hicfindtads',
#  '296': 'stringtie_merge',
#  '297': 'picard_CollectRnaSeqMetrics',
#  '298': 'mothur_taxonomy_to_krona',
#  '299': '__RELABEL_FROM_FILE__',
#  '300': 'tp_text_file_with_recurring_lines',
#  '301': 'gatk2_print_reads',
#  '302': 'snpSift_annotate',
#  '303': 'rbc_mirdeep2',
#  '304': 'genbank_to_gff',
#  '305': 'MzTabExporter',
#  '306': 'mothur_homova',
#  '307': 'meme_psp_gen',
#  '308': 'deeptools_bigwig_compare',
#  '309': 'sklearn_build_pipeline',
#  '310': 'mycrobiota-krona-mothur',
#  '311': 'ggplot2_heatmap',
#  '312': 'cardinal_segmentations',
#  '313': 'Grep1',
#  '314': 'picard_EstimateLibraryComplexity',
#  '315': 'snpSift_filter',
#  '316': 'Flash',
#  '317': 'FROGS_affiliations_stat',
#  '318': 'CONVERTER_gz_to_uncompressed',
#  '319': 'stacks_procrad',
#  '320': 'mass_spectrometry_imaging_qc',
#  '321': 'megablast_xml_parser',
#  '322': 'rarefaction',
#  '323': 'mothur_dist_seqs',
#  '324': 'taxonomy_krona_chart',
#  '325': 'mothur_phylotype',
#  '326': 'ProteinInference',
#  '327': 'sickle',
#  '328': 'bams2ratio',
#  '329': 'ete_genetree_splitter',
#  '330': 'gatk2_realigner_target_creator',
#  '331': 'gmx_setup',
#  '332': 'bam_to_bigwig',
#  '333': 'merge_pcr_duplicates.py',
#  '334': 'cshl_awk_tool',
#  '335': 'msconvert3_raw',
#  '336': 'deg_annotate',
#  '337': 'cshl_fastx_quality_statistics',
#  '338': 'cuffnorm',
#  '339': 'CONVERTER_interval_to_bed_0',
#  '340': 'myrimatch',
#  '341': 'cshl_uniq_tool',
#  '342': 'sklearn_svm_classifier',
#  '343': 'plotly_parallel_coordinates_plot',
#  '344': 'EMBOSS: wordcount109',
#  '345': 'sort1',
#  '346': 'picard_ValidateSamFile',
#  '347': 'graphlan',
#  '348': 'get_child_terms',
#  '349': 'bwa_mem',
#  '350': 'coords2clnt.py',
#  '351': 'bcftools_norm',
#  '352': 'sklearn_numeric_clustering',
#  '353': 'regex_replace',
#  '354': 'remove_tail.py',
#  '355': 'EMBOSS: shuffleseq87',
#  '356': 'fastq_filter',
#  '357': 'mycrobiota-split-multi-otutable',
#  '358': 'EMBOSS: extractseq35',
#  '359': 'fasttree',
#  '360': 'mothur_filter_seqs',
#  '361': 'addName',
#  '362': 'deeptools_multi_bigwig_summary',
#  '363': 'nanoplot',
#  '364': 'tmhmm2',
#  '365': 'samtools_flagstat',
#  '366': 'bctools_extract_alignment_ends',
#  '367': 'mass_spectrometry_imaging_classification',
#  '368': 'ctb_online_data_fetch',
#  '369': 'deeptools_bam_coverage',
#  '370': 'Add_a_column1',
#  '371': 'mass_spectrometry_imaging_combine',
#  '372': 'cummeRbund',
#  '373': 'hicexplorer_hicpca',
#  '374': 'chipsequtil_maptoknowngenes',
#  '375': 'bedtools_sortbed',
#  '376': 'sed_stream_editor',
#  '377': 'gatk_indel_realigner',
#  '378': 'filter_bed_on_splice_junctions',
#  '379': 'bigwig_to_bedgraph',
#  '380': 'bgchem_fragment_merger',
#  '381': 'abricate',
#  '382': 'IDMerger',
#  '383': 'ConsensusMapNormalizer',
#  '384': 'nn_classifier',
#  '385': 'EMBOSS: newseq59',
#  '386': 'selectsequencesfrommsa',
#  '387': 'w4mjoinpn',
#  '388': 'sklear_numeric_clustering',
#  '389': 'fraggenescan',
#  '390': 'fasta2tab',
#  '391': 'fastq_dump',
#  '392': 'picard_NormalizeFasta',
#  '393': 'mothur_summary_seqs',
#  '394': 'ggplot2_point',
#  '395': 'gops_basecoverage_1',
#  '396': 'fgsea',
#  '397': 'gemini_annotate',
#  '398': 'ExtractFASTAfromFASTQ',
#  '399': 'picard_FixMateInformation',
#  '400': 'bcftools_call',
#  '401': 'find_in_reference',
#  '402': 'methtools_calling',
#  '403': 'mimodd_vcf_filter',
#  '404': 'cuffquant',
#  '405': 'Univariate',
#  '406': 'macs2_bdgcmp',
#  '407': 'ncbi_blastn_wrapper',
#  '408': 'humann2',
#  '409': 'cutadapt',
#  '410': 'bg_diamond',
#  '411': 'hicexplorer_hicsummatrices',
#  '412': 'Fetch Taxonomic Ranks',
#  '413': 'locarna_best_subtree',
#  '414': 'hicexplorer_hicplotmatrix',
#  '415': 'fastq_to_tabular',
#  '416': 'cufflinks',
#  '417': 'mothur_classify_rf',
#  '418': 'rsem_prepare_reference',
#  '419': 'velvet',
#  '420': 'preproc',
#  '421': 'picard_SortSam',
#  '422': 'gatk2_base_recalibrator',
#  '423': 'methtools_tiling',
#  '424': 'mycrobiota-otutable_add_blast',
#  '425': 'trimmer',
#  '426': 'trim_galore',
#  '427': 'rbc_rnacode',
#  '428': 't2t_report',
#  '429': 'gatk_unified_genotyper',
#  '430': 'hisat',
#  '431': 'varscan',
#  '432': 'cardinal_mz_images',
#  '433': 'EMBOSS: seqret84',
#  '434': 'addValue',
#  '435': 'correct_barcodes',
#  '436': 'rseqc_read_distribution',
#  '437': 'random_lines1',
#  '438': 'mothur_metastats',
#  '439': 'FalseDiscoveryRate',
#  '440': 'minfi_ppfun',
#  '441': 'antismash',
#  '442': 'mothur_pcoa',
#  '443': 'mothur_summary_single',
#  '444': 'rm_spurious_events.py',
#  '445': 'sklearn_nn_classifier',
#  '446': 'mimodd_varcall',
#  '447': 'deeptools_compute_gc_bias',
#  '448': 'group_humann2_uniref_abundances_to_go',
#  '449': 'velvetoptimiser',
#  '450': 'gene2exon1',
#  '451': 'get_feature_info',
#  '452': 'histogram_rpy',
#  '453': 'computeMatrix',
#  '454': 'mass_spectrometry_imaging_ion_images',
#  '455': 'charts',
#  '456': 'uniprot',
#  '457': 'correctGCBias',
#  '458': 'smf_utils_fix-fasta-headers',
#  '459': 'rbc_mafft',
#  '460': 'ctb_filter',
#  '461': 'mass_spectrometry_imaging_segmentations',
#  '462': 'FROGS_clustering',
#  '463': 'cshl_awk_replace_in_column',
#  '464': 'bedtools_multiintersectbed',
#  '465': 'mycrobiota-correct-replicates',
#  '466': 'deeptools_bamCoverage',
#  '467': 'varscan_mpileup',
#  '468': 'pieplots_macs',
#  '469': 'je_clip',
#  '470': 'hcluster_sg',
#  '471': 'goenrichment',
#  '472': 'gatk_realigner_target_creator',
#  '473': 'openms_id_mapper',
#  '474': 'ssake',
#  '475': 'tp_multijoin_tool',
#  '476': 'gops_merge_1',
#  '477': 'transpose',
#  '478': 'ProteinResolver',
#  '479': 'rsem_calculate_expression',
#  '480': 'hicexplorer_hicbuildmatrix',
#  '481': 'maldi_quant_peak_detection',
#  '482': 'deeptools_bamCorrelate',
#  '483': 'format_metaphlan2_output',
#  '484': 'proteomics_search_peptide_prophet_1',
#  '485': 'glimmer_knowlegde-based',
#  '486': 'viennarna_rnaplot',
#  '487': 'bedtools_coveragebed',
#  '488': 'vcfflatten2',
#  '489': 'uparse',
#  '490': 'shovill',
#  '491': 'cast',
#  '492': 'tp_replace_in_column',
#  '493': 'mothur_dist_shared',
#  '494': 'Extract genomic DNA 1',
#  '495': '16Sclassifier',
#  '496': 'heatmap2',
#  '497': 'fasta_filter_by_length',
#  '498': 'tab2fasta',
#  '499': 'mimodd_varreport',
#  '500': 'bedtools_intersectbed',
#  '501': 'translate_bed_sequences',
#  '502': 'samtools_rmdup',
#  '503': 'mothur_heatmap_sim',
#  '504': '__SORTLIST__',
#  '505': 'bamleftalign',
#  '506': 'umi_tools_dedup',
#  '507': 'cshl_word_list_grep',
#  '508': 'flye',
#  '509': 'ncbi_blastx_wrapper',
#  '510': 'export2graphlan',
#  '511': 'cshl_multijoin',
#  '512': 'get_sequences',
#  '513': 'rnbeads',
#  '514': 'query_tabular',
#  '515': '__FILTER_FROM_FILE__',
#  '516': 'ctb_silicos_qed',
#  '517': 'gatk2_reduce_reads',
#  '518': 'mothur_unique_seqs',
#  '519': 'blastxml_to_tabular_selectable',
#  '520': 'checkFormat',
#  '521': 'sklearn_ensemble',
#  '522': 'qiime_count_seqs',
#  '523': 'mass_spectrometry_imaging_mzplots',
#  '524': 'blockclust',
#  '525': 'cmv',
#  '526': 'vcf2tsv',
#  '527': 'umi_tools_extract',
#  '528': 'mothur_get_oturep',
#  '529': 'snpeff_to_peptides',
#  '530': 'vsearch_dereplication',
#  '531': 'bamtools',
#  '532': 'fastq collapser',
#  '533': 'mothur_sub_sample',
#  '534': 'minfi_qc',
#  '535': 'stacks_refmap',
#  '536': 'datamash_ops',
#  '537': 'mothur_lefse',
#  '538': 'meme_dreme',
#  '539': 'filter_by_fasta_ids',
#  '540': 'abims_xcms_group',
#  '541': 'rcas',
#  '542': 'mimodd_map',
#  '543': 'kraken-translate',
#  '544': 'Interval_Maf_Merged_Fasta2',
#  '545': 'deeptools_computeMatrix',
#  '546': 'msconvert_nix',
#  '547': 'bedtools_slopbed',
#  '548': 'tp_cut_tool',
#  '549': 'CONVERTER_fasta_to_fai',
#  '550': 'fastq_groomer',
#  '551': 'picard_BamIndexStats',
#  '552': 'unipept',
#  '553': 'convert_bc_to_binary_RY.py',
#  '554': 'sklearn_searchcv',
#  '555': 'wsdl_hmdb',
#  '556': 'mimodd_varextract',
#  '557': 'vcfallelicprimitives',
#  '558': 'blastxml_to_top_descr',
#  '559': 'bam-filter',
#  '560': 'wolf_psort',
#  '561': 'sam2interval',
#  '562': 'FastTree',
#  '563': 'humann2_genefamilies_genus_level',
#  '564': 'qiime_split_libraries_fastq',
#  '565': 'tp_unfold_column_tool',
#  '566': 'pilon',
#  '567': 'minfi_methcpg',
#  '568': 'porechop',
#  '569': 'tp_split_on_column',
#  '570': 'multiqc',
#  '571': 'raceid_trajectory',
#  '572': 'structure_to_gspan',
#  '573': '__APPLY_RULES__',
#  '574': 'gops_cluster_1',
#  '575': 'gemini_windower',
#  '576': 'deseq2',
#  '577': 'locarna_multiple',
#  '578': 'FROGS_preprocess',
#  '579': 'IDMassAccuracy',
#  '580': 'vcf_filter',
#  '581': 'deeptools_bigwigCompare',
#  '582': 'MassCalculator',
#  '583': 'hgv_david',
#  '584': 'TextExporter',
#  '585': 'gspan',
#  '586': 'bedtools_windowbed',
#  '587': 'qiime_pick_open_reference_otus',
#  '588': 'EMBOSS: getorf42',
#  '589': 'FileMerger',
#  '590': 'sequence_content_trimmer',
#  '591': 'snpSift_dbnsfp_generic',
#  '592': 'methtools_destrand',
#  '593': 'gmx_solvate',
#  '594': 'gafa',
#  '595': 'stacks_denovomap',
#  '596': 'fastq_combiner',
#  '597': 'extract_element_from_collection',
#  '598': 'kallisto_quant',
#  '599': 'mcClust',
#  '600': 'signalp3',
#  '601': 'picard_CASM',
#  '602': 'cshl_fastx_renamer',
#  '603': 'ChangeCase',
#  '604': 'megahit',
#  '605': 'sklearn_feature_selection',
#  '606': 'preMloc',
#  '607': 'cardinal_spectra_plots',
#  '608': 'tp_easyjoin_tool',
#  '609': 'chipseeker',
#  '610': 'QCCalculator',
#  '611': 'hcluster_sg_parser',
#  '612': 'snpEff_download',
#  '613': 'rseqc_bam_stat',
#  '614': 'deeptools_plot_pca',
#  '615': 'maldi_quant_preprocessing',
#  '616': 'Btrim64',
#  '617': 'treebest_best',
#  '618': 'samtools_idxstats',
#  '619': 'viennarna_rnaalifold',
#  '620': 'cuffcompare',
#  '621': 'qiime_assign_taxonomy',
#  '622': 'rnafold',
#  '623': 'tophat2',
#  '624': 'rseqc_infer_experiment',
#  '625': 'cshl_fastx_collapser',
#  '626': 'gemini_pathways',
#  '627': 'vcftools_annotate',
#  '628': 'Grouping1',
#  '629': 'mothur_align_seqs',
#  '630': 'MapRTTransformer',
#  '631': 'allele_counts_1',
#  '632': 'cshl_fastx_reverse_complement',
#  '633': 'bedtools_intersectbed_bam',
#  '634': 'goseq',
#  '635': 'gffread',
#  '636': 'unicycler',
#  '637': 'limma_voom',
#  '638': 'bg_sortmerna',
#  '639': 'samtools_filter',
#  '640': 'numeric_clustering',
#  '641': 'idpassemble',
#  '642': 'bg_column_arrange_by_header',
#  '643': 'MSGFPlusAdapter',
#  '644': 'qiime_make_otu_heatmap',
#  '645': 'plotly_regression_performance_plots',
#  '646': 'peptide_shaker',
#  '647': 'vcfvcfintersect',
#  '648': 'collection_column_join',
#  '649': 'cardinal_quality_report',
#  '650': 'cat1',
#  '651': 'wiggle2simple1',
#  '652': 'infernal_cmstat',
#  '653': 'bamFilter',
#  '654': 'picard_AddOrReplaceReadGroups',
#  '655': 'umi_tools_whitelist',
#  '656': 'rbc_splitfasta',
#  '657': 'mothur_count_groups',
#  '658': 'tp_sorted_uniq',
#  '659': 'mothur_make_biom',
#  '660': 'valet',
#  '661': 'MAF_To_Fasta1',
#  '662': 'Remove_ending',
#  '663': 'TrimByLength',
#  '664': 'proteomics_moff',
#  '665': 'graphicsmagick_image_convert',
#  '666': 'XY_Plot_1',
#  '667': 'vcfannotate',
#  '668': 'get_read_pipeline',
#  '669': 'vcftools_isec',
#  '670': 'picard_MarkDuplicatesWithMateCigar',
#  '671': 'fastq_to_fasta_python',
#  '672': 'mz_to_sqlite',
#  '673': 'fasta_compute_length',
#  '674': 'deeptools_plot_enrichment',
#  '675': 'gops_coverage_1',
#  '676': 'XTandemAdapter',
#  '677': 'deeptools_plot_profile',
#  '678': 'cshl_fastq_quality_boxplot',
#  '679': 'gops_join_1',
#  '680': 'varscan_somatic',
#  '681': 'CometAdapter',
#  '682': 'FROGS_filters',
#  '683': 'gops_subtract_1',
#  '684': 'umi_tools_count',
#  '685': '__FLATTEN__',
#  '686': 'metams_runGC',
#  '687': 'hicexplorer_hicplottads',
#  '688': 'Filter1',
#  '689': 'fastq_paired_end_deinterlacer',
#  '690': '__ZIP_COLLECTION__',
#  '691': 'blast_parser',
#  '692': 'blastxml_to_tabular',
#  '693': 'glimmer_not-knowlegde-based',
#  '694': 'Summary_Statistics1',
#  '695': 'DecoyDatabase',
#  '696': 'rseqc_inner_distance',
#  '697': 'map_peptides_to_bed',
#  '698': 'minfi_rset',
#  '699': 'peakcalling_macs',
#  '700': 'samtools_split',
#  '701': 'tp_cat',
#  '702': 'biosigner',
#  '703': 'bctools_remove_spurious_events',
#  '704': 'ia_coordinates_of_roi',
#  '705': 'mergeCols1',
#  '706': 'gatk2_haplotype_caller',
#  '707': 'table_annovar',
#  '708': 'infernal_cmsearch',
#  '709': 'bwa',
#  '710': 'velveth_jgi',
#  '711': 'deeptools_compute_matrix',
#  '712': 'mothur_classify_otu',
#  '713': 'mothur_corr_axes',
#  '714': 'wig_to_bigWig',
#  '715': 'bam2wig',
#  '716': 'gtf2bedgraph',
#  '717': 'cshl_princeton_fastx_barcode_splitter',
#  '718': 'cshl_fastq_quality_filter',
#  '719': 'EMBOSS: textsearch98',
#  '720': 'gemini_actionable_mutations',
#  '721': 'cshl_fastx_clipper',
#  '722': 'Count1',
#  '723': 'metaphlan2',
#  '724': 'kraken-report',
#  '725': 'Digestor',
#  '726': 'vegan_rarefaction',
#  '727': 'bandage_image',
#  '728': 'mothur_seq_error',
#  '729': 'mass_spectrometry_imaging_filtering',
#  '730': 'metaphlan2krona',
#  '731': 'align_families',
#  '732': 'annotatemyids',
#  '733': 'CONVERTER_bedgraph_to_bigwig',
#  '734': 'samtools_sort',
#  '735': 'glimmer_build-icm',
#  '736': 'bamCompare_deepTools',
#  '737': 'IDPosteriorErrorProbability',
#  '738': 'snpEff',
#  '739': 'idpquery',
#  '740': 'idpqonvert',
#  '741': 'hicexplorer_hictransform',
#  '742': 'Datamash',
#  '743': 'viennarna_rnafold',
#  '744': 're_he_maldi_image_registration',
#  '745': 'sam_pileup',
#  '746': 'flexbar',
#  '747': 'cuffmerge',
#  '748': 'PicardASMetrics',
#  '749': 'muscle',
#  '750': 'abims_xcms_summary',
#  '751': 'ctb_chemfp_mol2fps',
#  '752': 'dexseq_annotate',
#  '753': 'eden_sequence_converter',
#  '754': 't_coffee',
#  '755': 'cardinal_preprocessing',
#  '756': 'IDScoreSwitcher',
#  '757': 'mothur_merge_files',
#  '758': 'CONVERTER_interval_to_bedstrict_0',
#  '759': 'term_id_vs_term_name',
#  '760': 'Heatmap',
#  '761': 'ruvseq',
#  '762': 'bedtools_bedtobam',
#  '763': 'mycrobiota-qc-report',
#  '764': 'qiime_pick_rep_set',
#  '765': 'flexbardsc',
#  '766': 'fastqc',
#  '767': 'paralyzer',
#  '768': 'raceid_main',
#  '769': 'rseqc_junction_saturation',
#  '770': 'mothur_heatmap_bin',
#  '771': 'rseqc_geneBody_coverage',
#  '772': 'CONVERTER_gff_to_bed_0',
#  '773': 'thermo_raw_file_converter',
#  '774': 'PicardInsertSize',
#  '775': 'GeMoMa_Annotation_Filter',
#  '776': 'gatk2_variant_recalibrator',
#  '777': 'datamash_transpose',
#  '778': 'FileConverter',
#  '779': 'comp1',
#  '780': 'cardinal_data_exporter',
#  '781': 'bwameth',
#  '782': 'cardinal_combine',
#  '783': 'modencode_peakcalling_spp',
#  '784': 'picard_MergeSamFiles',
#  '785': 'blockbuster',
#  '786': 'gemini_burden',
#  '787': 'mycrobiota-make-multi-otutable',
#  '788': 'bed2gff1',
#  '789': 'melt',
#  '790': 'picard_MarkDuplicates',
#  '791': 'gmx_nvt',
#  '792': 'gmx_md',
#  '793': 'p_clip_peaks',
#  '794': 'FeatureFinderMultiplex',
#  '795': 'length_and_gc_content',
#  '796': 'qiime_pick_closed_reference_otus',
#  '797': 'lfq_protein_quant',
#  '798': 'seq_filter_by_id',
#  '799': 'FROGS_affiliation_OTU',
#  '800': 'umi_tools_group',
#  '801': 'minfi_getM',
#  '802': 'predict_pipeline',
#  '803': 'bctools_remove_tail',
#  '804': 'minfi_read450k',
#  '805': 'cshl_fastx_artifacts_filter',
#  '806': 'mothur_remove_groups',
#  '807': 'naive_variant_caller',
#  '808': 'methtools_plot',
#  '809': 'fastq_paired_end_joiner',
#  '810': 'CONVERTER_fasta_to_tabular',
#  '811': 'CONVERTER_bed_gff_or_vcf_to_bigwig_0',
#  '812': 'HighResPrecursorMassCorrector',
#  '813': 'bed_to_bigBed',
#  '814': 'bedtools_genomecoveragebed_histogram',
#  '815': 'Remove beginning1',
#  '816': 'PeptideIndexer',
#  '817': 'extract_aln_ends.py',
#  '818': 'gatk2_variant_apply_recalibration',
#  '819': 'je_markdupes',
#  '820': 'deeptools_plot_correlation',
#  '821': 'deeptools_bamFingerprint',
#  '822': 'sam_merge2',
#  '823': 'nanopolish_variants',
#  '824': 'filtlong',
#  '825': 'bismark_bowtie',
#  '826': 'gatk2_variant_annotator',
#  '827': 'nspdk_sparse',
#  '828': 'kraken',
#  '829': 'replace_column_with_key_value_file',
#  '830': 'venn_list',
#  '831': 'minfi_maptogenome',
#  '832': 'tp_sort_rows',
#  '833': 'snippy',
#  '834': 'decoyfasta',
#  '835': 'spades',
#  '836': 'graphclust_align_cluster',
#  '837': 'get_subontology_from',
#  '838': 'seurat',
#  '839': 'infernal_cmbuild',
#  '840': 'qiime_core_diversity',
#  '841': 'edger',
#  '842': 'createInterval',
#  '843': 'flexbar_split_RYYR_bcs',
#  '844': 'heinz_visualization',
#  '845': 'mothur_get_communitytype',
#  '846': 'enhanced_bowtie_wrapper',
#  '847': 'gemini_load',
#  '848': 'pileup_parser',
#  '849': 'dunovo',
#  '850': 'trim_reads',
#  '851': 'FROGS_remove_chimera',
#  '852': 'ncbi_blastp_wrapper',
#  '853': 'scpipe',
#  '854': 'gff_to_sequence',
#  '855': 'vcfgenotypes',
#  '856': 'mothur_tree_shared',
#  '857': 'interproscan',
#  '858': 'mothur_nmds',
#  '859': 'tp_replace_in_line',
#  '860': 'join1',
#  '861': 'RNAlien',
#  '862': 'metaphlan_hclust_heatmap',
#  '863': 'gff_filter_by_attribute',
#  '864': 'FileInfo',
#  '865': 'gemini_interactions',
#  '866': 'MapStatistics',
#  '867': 'ProteinQuantifier',
#  '868': 'meme_meme',
#  '869': 'methtools_dmr',
#  '870': 'samtool_filter2',
#  '871': 'deeptools_heatmapper',
#  '872': 'CONVERTER_gff_to_interval_index_0',
#  '873': 'secretbt2test',
#  '874': 'PeakPickerHiRes',
#  '875': 'cuffdiff',
#  '876': 'pileometh',
#  '877': 'deeptools_bamCompare',
#  '878': 'proteomics_search_tandem_1',
#  '879': 'aggregate_scores_in_intervals2',
#  '880': 'bedtools_annotatebed',
#  '881': 'peakcalling_macs14',
#  '882': 'aragorn_trna',
#  '883': 'cshl_fasta_formatter',
#  '884': 'xpath',
#  '885': 'vcfselectsamples',
#  '886': 'minfi_dmr',
#  '887': 'plotly_ml_performance_plots',
#  '888': 'cshl_fastx_barcode_splitter',
#  '889': 'gd_raxml',
#  '890': 'ete_homology_classifier',
#  '891': 'rgweblogo3',
#  '892': 'Cut1',
#  '893': 'samtools_stats',
#  '894': 'bcftools_view',
#  '895': 'flexbar_split_RR_bcs',
#  '896': 'gatk2_unified_genotyper',
#  '897': 'regex1',
#  '898': 'ggplot2_histogram',
#  '899': 'rgPicardMarkDups',
#  '900': 'minimap2',
#  '901': 'FeatureLinkerUnlabeledKD',
#  '902': 'bedtools_bamtofastq',
#  '903': 'Draw_phylogram',
#  '904': 'bundle_collection',
#  '905': 'msgfplus',
#  '906': 'ctb_simsearch',
#  '907': 'macs2_predictd',
#  '908': 'openms_id_file_converter',
#  '909': 'Nucleosome',
#  '910': 'fasta_merge_files_and_filter_unique_sequences',
#  '911': 'cufflinks_prok',
#  '912': 'fastq_paired_end_interlacer',
#  '913': 'megablast_wrapper',
#  '914': 'make_families',
#  '915': 'ncbi_rpsblast_wrapper',
#  '916': 'prokaryotic_ncbi_submission',
#  '917': 'bedtools_getfastabed',
#  '918': 'stacks_populations',
#  '919': 'krona-text',
#  '920': 'eden_vectorizer',
#  '921': 'tp_grep_tool',
#  '922': 'fasplit',
#  '923': 'cshl_sort_header',
#  '924': 'FidoAdapter',
#  '925': 'fasta-stats',
#  '926': 'rarefaction_analyzer',
#  '927': 'fragmenter',
#  '928': 'humann2_regroup_table',
#  '929': 'bowtie_wrapper',
#  '930': 'quast',
#  '931': 'cshl_easyjoin',
#  '932': '16Saligner',
#  '933': 'tophat_fusion_post',
#  '934': 'sam_bw_filter',
#  '935': 'meme_fimo',
#  '936': 'search_gui',
#  '937': 'picard_SamToFastq',
#  '938': 'mothur_get_groups',
#  '939': 'je_demultiplex',
#  '940': 'CONVERTER_bed_to_gff_0',
#  '941': 'ctb_remIons',
#  '942': 'vcfbedintersect',
#  '943': 'newick_display',
#  '944': 'diffbind-embl',
#  '945': 'heinz_bum',
#  '946': 'hgv_linkToGProfile',
#  '947': 'prokka',
#  '948': 'fastq_trimmer',
#  '949': 'pureclip',
#  '950': 'featurecounts',
#  '951': 'ngsutils_bam_filter',
#  '952': 'IDMapper',
#  '953': 'FeatureLinkerUnlabeledQT',
#  '954': 'cshl_fasta_nucleotides_changer',
#  '955': 'blast2go',
#  '956': 'iReport',
#  '957': '__FILTER_FAILED_DATASETS__',
#  '958': 'svm_classifier',
#  '959': 'get_flanks1',
#  '960': 'bedtools_genomecoveragebed',
#  '961': 'sam_to_bam',
#  '962': 'CONVERTER_interval_to_bgzip_0',
#  '963': 'picard_ARRG',
#  '964': '__MERGE_COLLECTION__',
#  '965': 'freebayes',
#  '966': 'gemini_de_novo',
#  '967': 'IDFileConverter',
#  '968': 'bedtools_coveragebed_counts',
#  '969': 'scale_image',
#  '970': 'samtools_bedcov',
#  '971': 'bamCoverage_deepTools'}

# %%
def verify_model(model, tool_sequence, labels, dictionary, reverse_dictionary, compatible_tools, topk=20, max_seq_len=25):
    tl_seq = tool_sequence.split(",")
    last_tool_name = reverse_dictionary[str(tl_seq[-1])]
    last_compatible_tools = compatible_tools[last_tool_name]
    sample = np.zeros(max_seq_len)
    for idx, tool_id in enumerate(tl_seq):
        sample[idx] = int(tool_id)
    sample_reshaped = np.reshape(sample, (1, max_seq_len))

    tool_sequence_names = [reverse_dictionary[str(tool_pos)] for tool_pos in tool_sequence.split(",")]
    print("Tool seq: %s" % ",".join(tool_sequence_names))

    # predict next tools for a test path
    prediction = model.predict(sample_reshaped, verbose=0)
    prediction = np.reshape(prediction, (prediction.shape[1],))
    prediction_pos = np.argsort(prediction, axis=-1)

    # get topk prediction
    topk_prediction_pos = prediction_pos[-topk:]
    topk_prediction_val = [np.round(prediction[pos] * 100, 2) for pos in topk_prediction_pos]

    # read tool names using reverse dictionary
    pred_tool_ids = [reverse_dictionary[str(tool_pos)] for tool_pos in topk_prediction_pos]
    actual_next_tool_ids = list(set(pred_tool_ids).intersection(set(last_compatible_tools.split(","))))      

    print()
    pred_tool_ids_sorted = dict()
    for (tool_pos, tool_pred_val) in zip(topk_prediction_pos, topk_prediction_val):
        tool_name = reverse_dictionary[str(tool_pos)]
        if tool_name in actual_next_tool_ids:
            pred_tool_ids_sorted[tool_name] = tool_pred_val
    pred_tool_ids_sorted = dict(sorted(pred_tool_ids_sorted.items(), key=lambda kv: kv[1], reverse=True))
    
    cls_wt = dict()
    usg_wt = dict()
    inv_wt = dict()
    ids_tools = dict()
    keys = list(pred_tool_ids_sorted.keys())
    for k in keys:
        try:
            cls_wt[k] = np.round(class_weights[str(data_dict[k])], 2)
            usg_wt[k] = np.round(usage_weights[k], 2)
            inv_wt[k] = np.round(inverted_weights[str(data_dict[k])], 2)
        except:
            continue
    print("Predicted tools: \n")
    print(pred_tool_ids_sorted)
    print()
    print("Class weights: \n")
    cls_wt = dict(sorted(cls_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(cls_wt)
    print()
    print("Usage weights: \n")
    usg_wt = dict(sorted(usg_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(usg_wt)
    print()
    total_usage_wt = np.mean(list(usg_wt.values()))
    print("Mean usage wt: %0.4f" % (total_usage_wt))
    print()
    print("Inverted weights: \n")
    inv_wt = dict(sorted(inv_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(inv_wt)
    for key in pred_tool_ids_sorted:
        ids_tools[key] = dictionary[key]
    print()
    print("Tool ids")
    print(ids_tools)
    print("======================================")
    return cls_wt, usg_wt, inv_wt, pred_tool_ids_sorted

topk = 10
tool_seq = "420"
class_wt, usage_wt, inverse_wt, pred_tools = verify_model(model, tool_seq, "", dictionary, reverse_dictionary, compatibile_tools, topk)
# Out:
# Tool seq: preproc
#
# Predicted tools:
#
# {'preMloc': 3.32}
#
# Class weights:
#
# {'preMloc': 6.62}
#
# Usage weights:
#
# {'preMloc': 6.62}
#
# Mean usage wt: 6.6200
#
# Inverted weights:
#
# {'preMloc': 8766.5}
#
# Tool ids
# {'preMloc': 606}
# ======================================

# %%
list_cls_wt = list()
list_usage_wt = list()
list_pred_wt = list()
list_inv_wt = list()
division_pt = int(len(pred_tools) / 2)

for tool in pred_tools:
    list_pred_wt.append(pred_tools[tool])
    #try:
    list_inv_wt.append(inverse_wt[tool])
    list_usage_wt.append(usage_wt[tool])
    #except:
    #list_inv_wt.append(1)

def plot_scatter(y_val, title, xlabel, ylabel):
    x_val = range(1, len(y_val) + 1)
    plt.figure(figsize=(8, 8))
    plt.plot(x_val[:division_pt], y_val[:division_pt], 'ro')
    plt.plot(x_val[division_pt:], y_val[division_pt:], 'b^')
    plt.xlabel(xlabel, size=size_label)
    plt.ylabel(ylabel, size=size_label)
    plt.legend([("First top-%s" % str(division_pt)), ("Next top-%s" % str(division_pt))])
    plt.title(title, size=size_title)
    plt.grid(True)
    plt.show()

plot_scatter(list_usage_wt, "Usage weights for tools", "Number of tools", "Class weights")
#plot_scatter(ave_prediction_weights, ave_usage_weights, "Prediction vs usage weights", "Prediction scores", "Usage weights")
#plot_scatter(ave_prediction_weights, ave_inverted_weights, "Prediction vs inverted weights", "Prediction scores", "Inverted weights")
