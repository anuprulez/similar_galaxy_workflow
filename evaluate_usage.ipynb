# %%
import numpy as np
import json
import warnings
import operator

import h5py
from keras.models import model_from_json
from keras import backend as K

from matplotlib import pyplot as plt

warnings.filterwarnings("ignore")

size_title = 18
size_label = 14
n_pred = 2 

base_path = "data/evaluate_usage/" # cluster path: 7_similar_galaxy_workflow

path_data_dict = base_path + "data_dict.txt"
path_inverted_wt = base_path + "inverted_weights.txt"
path_usage_wt = base_path + "usage_prediction.txt"
path_class_wt = base_path + "class_weights.txt"
path_test_data = base_path + "test_paths_dict.txt"
model_path = base_path + "trained_model.hdf5"

def read_file(file_path):
    with open(file_path, 'r') as data_file:
        data = json.loads(data_file.read())
    return data

class_weights = read_file(path_class_wt)
usage_weights = read_file(path_usage_wt)
inverted_weights = read_file(path_inverted_wt)
data_dict = read_file(path_data_dict)

def create_model(model_path):
    trained_model = h5py.File(model_path, 'r')
    model_config = json.loads(trained_model.get('model_config').value)
    loaded_model = model_from_json(model_config)
    dictionary = json.loads(trained_model.get('data_dictionary').value)
    compatibile_tools = json.loads(trained_model.get('compatible_tools').value)
    reverse_dictionary = dict((str(v), k) for k, v in dictionary.items())
    model_weights = list()
    weight_ctr = 0
    while True:
        try:
            d_key = "weight_" + str(weight_ctr)
            weights = trained_model.get(d_key).value
            model_weights.append(weights)
            weight_ctr += 1
        except Exception as exception:
            break
    # set the model weights
    loaded_model.set_weights(model_weights)
    return loaded_model, dictionary, reverse_dictionary, compatibile_tools

model, dictionary, reverse_dictionary, compatibile_tools = create_model(model_path)
# Out:
# Using TensorFlow backend.

# %%
reverse_dictionary
# Out:
# {'1': 'hgv_snpFreq',
#  '2': 'CONVERTER_interval_to_bgzip_0',
#  '3': 'FROGS_remove_chimera',
#  '4': 'gatk2_variant_select',
#  '5': 'Cut1',
#  '6': 'gops_subtract_1',
#  '7': 'react_cal_pipeline',
#  '8': 'tp_cut_tool',
#  '9': 'mothur_dist_seqs',
#  '10': 'Extractor',
#  '11': 'bed_to_bigBed',
#  '12': 'mass_spectrometry_imaging_mzplots',
#  '13': 'umi_tools_whitelist',
#  '14': 'meme_chip',
#  '15': 'dunovo',
#  '16': 'deeptools_bamCorrelate',
#  '17': 'table_annovar',
#  '18': 'lca1',
#  '19': 'w4mjoinpn',
#  '20': 'bedtools_intersectbed_bam',
#  '21': 'fraggenescan',
#  '22': 'unipept',
#  '23': 'ncbi_tblastn_wrapper',
#  '24': 'deeptools_bamFingerprint',
#  '25': 'bamtools',
#  '26': 'sklearn_nn_classifier',
#  '27': 'tabular_to_fastq',
#  '28': 'snpsift_vartype',
#  '29': 'convert_bc_to_binary_RY.py',
#  '30': 'FeatureFinderCentroided',
#  '31': 'trimmer',
#  '32': 'gops_basecoverage_1',
#  '33': 'addName',
#  '34': 'sklearn_build_pipeline',
#  '35': 'extract_aln_ends.py',
#  '36': 'bgchem_fragment_merger',
#  '37': 'seq_filter_by_id',
#  '38': 'Show beginning1',
#  '39': 'mothur_homova',
#  '40': 'nn_classifier',
#  '41': 'vcf2tsv',
#  '42': 'picard_MarkDuplicatesWithMateCigar',
#  '43': 'mothur_chimera_vsearch',
#  '44': 'piranha',
#  '45': 'raceid_filtnormconf',
#  '46': 'metaspades',
#  '47': 'gtftobed12',
#  '48': 'EMBOSS: seqret84',
#  '49': 'bg_column_arrange_by_header',
#  '50': 'rseqc_read_duplication',
#  '51': 'TextExporter',
#  '52': 'w4mcorcov',
#  '53': 'gemini_db_info',
#  '54': 'align_families',
#  '55': 'qiime_pick_rep_set',
#  '56': 'correctGCBias',
#  '57': 'tp_cat',
#  '58': 'deeptools_multi_bam_summary',
#  '59': 'deeptools_plot_fingerprint',
#  '60': 'sklearn_feature_selection',
#  '61': 'cshl_find_and_replace',
#  '62': 'cshl_fastx_barcode_splitter',
#  '63': 'Filter1',
#  '64': 'preMloc',
#  '65': 'gspan',
#  '66': 'bedtools_bamtobed',
#  '67': 'gemini_load',
#  '68': 'rbc_mirdeep2_quantifier',
#  '69': 'rcas',
#  '70': 'bctools_extract_alignment_ends',
#  '71': 'column_order_header_sort',
#  '72': 'charts',
#  '73': 'gatk2_variant_filtration',
#  '74': 'gops_merge_1',
#  '75': 'gff_filter_by_attribute',
#  '76': 'cshl_awk_replace_in_column',
#  '77': 'GeneModelMapper',
#  '78': 'tp_sort_header_tool',
#  '79': 'fastq_paired_end_joiner',
#  '80': 'PeakPickerHiRes',
#  '81': 'bcftools_view',
#  '82': 'minfi_getbeta',
#  '83': 'varscan_copynumber',
#  '84': 'GeMoMa_Annotation_Filter',
#  '85': 'CONVERTER_gff_to_interval_index_0',
#  '86': 'gemini_pathways',
#  '87': 'methtools_destrand',
#  '88': 'subtract_query1',
#  '89': 'Digestor',
#  '90': 'ctb_simsearch',
#  '91': 'mothur_unique_seqs',
#  '92': 'group_humann2_uniref_abundances_to_go',
#  '93': 'heatmapper',
#  '94': 'deeptools_plot_heatmap',
#  '95': 'vsearch_dereplication',
#  '96': 'IDConflictResolver',
#  '97': 'smooth_running_window',
#  '98': 'porechop',
#  '99': 'ete_genetree_splitter',
#  '100': 'fragmenter',
#  '101': 'MapRTTransformer',
#  '102': 'hicexplorer_hicsummatrices',
#  '103': 'gatk2_variant_annotator',
#  '104': 'meme_psp_gen',
#  '105': 'hmmer_hmmsearch',
#  '106': 'stacks_refmap',
#  '107': 'gatk2_depth_of_coverage',
#  '108': 'Interval_Maf_Merged_Fasta2',
#  '109': 'goseq',
#  '110': 'bedtools_sortbed',
#  '111': 'rbc_splitfasta',
#  '112': 'CONVERTER_fasta_to_fai',
#  '113': 'fasta2tab',
#  '114': '__UNZIP_COLLECTION__',
#  '115': 'heatmapper_deepTools',
#  '116': 'limma_voom',
#  '117': 'XTandemAdapter',
#  '118': 'vcfselectsamples',
#  '119': 'cshl_princeton_fastx_barcode_splitter',
#  '120': 'bismark_bowtie2',
#  '121': 'nspdk_sparse',
#  '122': 'heinz_scoring',
#  '123': 'regex1',
#  '124': 'gemini_annotate',
#  '125': 'Heatmap',
#  '126': 'heinz_bum',
#  '127': 'aragorn_trna',
#  '128': 'EMBOSS: shuffleseq87',
#  '129': 'xpath',
#  '130': 'picard_ValidateSamFile',
#  '131': 'gatk_realigner_target_creator',
#  '132': 'vcftools_merge',
#  '133': 'get_sequences',
#  '134': 'mothur_phylotype',
#  '135': 'bwameth',
#  '136': 'tmhmm2',
#  '137': 'seq_filter_by_mapping',
#  '138': 'Remove_ending',
#  '139': 'pynast',
#  '140': 'picard_EstimateLibraryComplexity',
#  '141': 'tp_replace_in_line',
#  '142': 'picard_CleanSam',
#  '143': 'mothur_cluster_split',
#  '144': 'maldi_quant_preprocessing',
#  '145': 'combine_metaphlan2_humann2',
#  '146': 'sqlite_to_tabular',
#  '147': 'vcftools_isec',
#  '148': 'glimmer_not-knowlegde-based',
#  '149': 'createInterval',
#  '150': 'gatk2_variant_apply_recalibration',
#  '151': 'regex_replace',
#  '152': 'stringtie',
#  '153': 'picard_FixMateInformation',
#  '154': 'mothur_make_biom',
#  '155': 'clustalw',
#  '156': 'dbbuilder',
#  '157': 'minfi_getM',
#  '158': 'IDMapper',
#  '159': 'cshl_word_list_grep',
#  '160': 't_coffee',
#  '161': 'bedtools_intersectBed',
#  '162': 'minfi_maptogenome',
#  '163': 'pileometh',
#  '164': 'mothur_heatmap_bin',
#  '165': 'rnafold',
#  '166': 'mothur_taxonomy_to_krona',
#  '167': 'deeptools_bam_coverage',
#  '168': 'graphclust_glob_report_no_align',
#  '169': 'mass_spectrometry_imaging_segmentations',
#  '170': 'predict_pipeline',
#  '171': 'comp1',
#  '172': 'format_metaphlan2_output',
#  '173': 'histogram_rpy',
#  '174': 'methtools_calling',
#  '175': 'structure_to_gspan',
#  '176': 'gatk2_unified_genotyper',
#  '177': 'gmx_solvate',
#  '178': 'bedtools_complementbed',
#  '179': '__FLATTEN__',
#  '180': 'cshl_fasta_nucleotides_changer',
#  '181': 'picard_ARRG',
#  '182': 'mimodd_varreport',
#  '183': 'tophat_fusion_post',
#  '184': 'mycrobiota-krona-mothur',
#  '185': 'plotly_regression_performance_plots',
#  '186': 'hisat2',
#  '187': 'join1',
#  '188': 'blastxml_to_tabular_selectable',
#  '189': 'sam2interval',
#  '190': 'mothur_dist_shared',
#  '191': 'collection_column_join',
#  '192': 'FastTree',
#  '193': 'flexbar_no_split',
#  '194': 'meme_meme',
#  '195': 'fasta_merge_files_and_filter_unique_sequences',
#  '196': 'get_child_terms',
#  '197': 'bctools_remove_tail',
#  '198': 'bam2wig',
#  '199': 'snippy_core',
#  '200': 'vegan_diversity',
#  '201': 'interproscan',
#  '202': 'r_correlation_matrix',
#  '203': 'seurat',
#  '204': 'CONVERTER_Bam_Bai_0',
#  '205': 'mothur_corr_axes',
#  '206': 'rarefaction',
#  '207': 'mothur_classify_otu',
#  '208': 'picard_CollectInsertSizeMetrics',
#  '209': 'mimodd_varcall',
#  '210': 're_he_maldi_image_registration',
#  '211': 'bedtools_shufflebed',
#  '212': 'proteomics_search_tandem_1',
#  '213': 'vegan_rarefaction',
#  '214': 'gene2exon1',
#  '215': 'fasta_filter_by_length',
#  '216': 'seq_composition',
#  '217': 'cuffdiff',
#  '218': 'ncbi_blastn_wrapper',
#  '219': 'cardinal_filtering',
#  '220': 'cshl_fastq_quality_boxplot',
#  '221': 'blastxml_to_top_descr',
#  '222': 'CONVERTER_interval_to_bedstrict_0',
#  '223': 'picard_MarkDuplicates',
#  '224': 'cshl_fastx_quality_statistics',
#  '225': 'bowtie2',
#  '226': 'cuffmerge',
#  '227': 'gmx_em',
#  '228': 'deeptools_bigwigCompare',
#  '229': 'picard_SamToFastq',
#  '230': 'mothur_amova',
#  '231': 'peptide_shaker',
#  '232': 'hicexplorer_hicpca',
#  '233': 'hicexplorer_hicplottads',
#  '234': 'term_id_vs_term_name',
#  '235': 'w4mclstrpeakpics',
#  '236': 'random_lines1',
#  '237': 'valet',
#  '238': 'deeptools_plot_correlation',
#  '239': 'Univariate',
#  '240': 'kallisto_quant',
#  '241': 'hicexplorer_hictransform',
#  '242': 'muscle',
#  '243': 'mothur_cluster',
#  '244': 'graphlan_annotate',
#  '245': 'locarna_multiple',
#  '246': 'resistome_analyzer',
#  '247': 'macs2_predictd',
#  '248': 'flexbar_split_RR_bcs',
#  '249': 'Grouping1',
#  '250': 'cardinal_quality_report',
#  '251': 'EMBOSS: revseq82',
#  '252': 'TrimByLength',
#  '253': 'pileup_interval',
#  '254': 'deeptools_plot_enrichment',
#  '255': 'rseqc_bam2wig',
#  '256': 'ngsutils_bam_filter',
#  '257': 'rgPicFixMate',
#  '258': 'roary',
#  '259': 'Datamash',
#  '260': 'mothur_filter_seqs',
#  '261': 'RNAlien',
#  '262': 'methtools_tiling',
#  '263': 'bamleftalign',
#  '264': 'raceid_inspectclusters',
#  '265': 'smf_utils_filter-by-energy',
#  '266': 'hicexplorer_hicfindtads',
#  '267': 'vcffilter2',
#  '268': 'cardinal_combine',
#  '269': 'flexbar',
#  '270': 'cmFinder',
#  '271': 'addValue',
#  '272': 'Grep1',
#  '273': 'ctb_filter',
#  '274': 'bedtools_intersectbed',
#  '275': 'Btrim64',
#  '276': 'DatamashTranspose',
#  '277': 'ctb_ob_genProp',
#  '278': '__FILTER_FROM_FILE__',
#  '279': 'fastq_join',
#  '280': 'Fetch Taxonomic Ranks',
#  '281': 'blast2go',
#  '282': 'ConsensusID',
#  '283': 'gff2bed1',
#  '284': 'FeatureLinkerUnlabeledKD',
#  '285': 'samtools_stats',
#  '286': 'samtools_calmd',
#  '287': 'prokaryotic_ncbi_submission',
#  '288': 'igvtools_count',
#  '289': 'get_feature_info',
#  '290': 'gops_concat_1',
#  '291': 'idpquery',
#  '292': 'bedtools_multicovtbed',
#  '293': 'mothur_lefse',
#  '294': 'raceid_clustering',
#  '295': 'wsdl_hmdb',
#  '296': 'EMBOSS: geecee41',
#  '297': 'FROGS_filters',
#  '298': 'datamash_ops',
#  '299': 'get_subontology_from',
#  '300': 'ctb_change_title',
#  '301': 'EMBOSS: tranalign100',
#  '302': 'pilon',
#  '303': 'minfi_methcpg',
#  '304': 'bam_to_sam',
#  '305': 'snpeff_to_peptides',
#  '306': 'mass_spectrometry_imaging_filtering',
#  '307': 'peakcalling_macs14',
#  '308': 'glimmer_knowlegde-based',
#  '309': 'trinity',
#  '310': 'hisat',
#  '311': 'bctools_remove_spurious_events',
#  '312': 'trim_galore',
#  '313': 'get_flanks1',
#  '314': 'stacks_genotypes',
#  '315': 'trimmomatic',
#  '316': 'meme_dreme',
#  '317': 'FROGS_affiliation_OTU',
#  '318': 'mothur_trim_seqs',
#  '319': 'DecoyDatabase',
#  '320': 'mimodd_map',
#  '321': 'aggregate_scores_in_intervals2',
#  '322': 'sickle',
#  '323': 'CONVERTER_fasta_to_tabular',
#  '324': 'vcfsort',
#  '325': 'mothur_merge_files',
#  '326': 'barchart_gnuplot',
#  '327': 'mothur_venn',
#  '328': 'bctools_extract_crosslinked_nucleotides',
#  '329': 'Batch_correction',
#  '330': 'bamFilter',
#  '331': 'rsem_calculate_expression',
#  '332': 'newick_display',
#  '333': 'fastq_paired_end_splitter',
#  '334': 'ProteinQuantifier',
#  '335': 'cshl_fastx_trimmer',
#  '336': 'taxonomy_krona_chart',
#  '337': 'rseqc_inner_distance',
#  '338': 'deeptools_computeGCBias',
#  '339': 'cshl_fastx_reverse_complement',
#  '340': 'cshl_multijoin',
#  '341': 'mothur_seq_error',
#  '342': 'silac_analyzer',
#  '343': 'fastq_quality_trimmer',
#  '344': 'minfi_getanno',
#  '345': 'gatk2_variant_recalibrator',
#  '346': 'sklearn_numeric_clustering',
#  '347': 'HighResPrecursorMassCorrector',
#  '348': 'vcfvcfintersect',
#  '349': 'htseq_count',
#  '350': 'cat1',
#  '351': 'translate_bed_sequences',
#  '352': 'qiime_pick_otus',
#  '353': 'rm_spurious_events.py',
#  '354': 'cardinal_data_exporter',
#  '355': 'mothur_get_oturep',
#  '356': 'EMBOSS: fuzzpro38',
#  '357': 'make_families',
#  '358': 'smf_utils_fix-fasta-headers',
#  '359': 'Extract_RNA_seq_Evidence',
#  '360': 'bg_protein_properties',
#  '361': 'samtools_filter',
#  '362': 'CONVERTER_interval_to_bed_0',
#  '363': 'get_read_pipeline',
#  '364': 'eden_sequence_converter',
#  '365': 'mycrobiota-otutable_add_blast',
#  '366': 'ncbi_blastp_wrapper',
#  '367': 'cast',
#  '368': 'hmmer_hmmbuild',
#  '369': 'locarna_best_subtree',
#  '370': 'velvetoptimiser',
#  '371': 'gops_coverage_1',
#  '372': 'sort1',
#  '373': 'goslimmer',
#  '374': 'ia_coordinates_of_roi',
#  '375': 'mothur_pre_cluster',
#  '376': 'peakachu',
#  '377': 'viennarna_rnaplot',
#  '378': 'MzTabExporter',
#  '379': 'venn_list',
#  '380': 'Draw_phylogram',
#  '381': 'fastq collapser',
#  '382': 'query_tabular',
#  '383': 'samtools_split',
#  '384': 'XY_Plot_1',
#  '385': 'ggplot_histogram',
#  '386': 'FROGS_clustering',
#  '387': 'rna_star',
#  '388': 'cummeRbund',
#  '389': 'picard_CASM',
#  '390': 'bismark_bowtie',
#  '391': 'mass_spectrometry_imaging_qc',
#  '392': 'replace_column_with_key_value_file',
#  '393': 'sklearn_ensemble',
#  '394': 'bg_statistical_hypothesis_testing',
#  '395': 'mass_spectrometry_imaging_classification',
#  '396': 'samtools_flag_filter',
#  '397': 'umi_tools_dedup',
#  '398': 'EMBOSS: fuzztran39',
#  '399': 'cummerbund_to_cuffdiff',
#  '400': 'ggplot2_heatmap2',
#  '401': 'abims_xcms_summary',
#  '402': 'ctb_chemfp_mol2fps',
#  '403': 'hgv_linkToGProfile',
#  '404': 'rarefaction_analyzer',
#  '405': 'plotly_parallel_coordinates_plot',
#  '406': 'MassCalculator',
#  '407': 'gffread',
#  '408': '__RELABEL_FROM_FILE__',
#  '409': 'mothur_get_groups',
#  '410': 'heatmap2',
#  '411': 'MapAlignerPoseClustering',
#  '412': '__SORTLIST__',
#  '413': 'qiime_validate_mapping_file',
#  '414': 'blockclust',
#  '415': 'QCCalculator',
#  '416': 'annotateMyIDs',
#  '417': 'abims_CAMERA_annotateDiffreport',
#  '418': 'deseq2_single',
#  '419': 'tp_text_file_with_recurring_lines',
#  '420': 'sailfish',
#  '421': 'tp_tac',
#  '422': 'trim_reads',
#  '423': 'cd_hit_dup',
#  '424': 'rseqc_bam_stat',
#  '425': 'minfi_read450k',
#  '426': 'egsea',
#  '427': 'EMBOSS: newseq59',
#  '428': 'mothur_nmds',
#  '429': 'IsobaricAnalyzer',
#  '430': 'stringtie_merge',
#  '431': 'pileup_parser',
#  '432': 'EMBOSS: wordcount109',
#  '433': 'wig_to_bigWig',
#  '434': 'scpipe',
#  '435': 'EMBOSS: getorf42',
#  '436': 'tp_multijoin_tool',
#  '437': 'mothur_remove_lineage',
#  '438': 'find_in_reference',
#  '439': 'FROGS_preprocess',
#  '440': 'tp_replace_in_column',
#  '441': 'hgv_david',
#  '442': 'mothur_parsimony',
#  '443': 'FeatureFinderMultiplex',
#  '444': 'edger',
#  '445': 'sed_stream_editor',
#  '446': 'rbc_mafft',
#  '447': 'gatk2_reduce_reads',
#  '448': 'wolf_psort',
#  '449': 'rnaz',
#  '450': 'uchime',
#  '451': 'ctb_silicos_qed',
#  '452': 'chipseeker',
#  '453': 'deeptools_plot_profile',
#  '454': 'vcfbedintersect',
#  '455': 'DatamashOps',
#  '456': 'CONVERTER_bed_gff_or_vcf_to_bigwig_0',
#  '457': 'collapse_dataset',
#  '458': 'picard_MergeSamFiles',
#  '459': 'NFS_transfer',
#  '460': 'mothur_metastats',
#  '461': 'cshl_fastq_to_fasta',
#  '462': 'infernal_cmbuild',
#  '463': 'bcftools_norm',
#  '464': 'preproc',
#  '465': 'tab2fasta',
#  '466': 'w4mclassfilter',
#  '467': 'fastq_paired_end_interlacer',
#  '468': 'rmcontamination',
#  '469': 'mergeCols1',
#  '470': 'picard_BamIndexStats',
#  '471': 'extract_bcs.py',
#  '472': 'mothur_make_contigs',
#  '473': 'tp_easyjoin_tool',
#  '474': 'fastq_combiner',
#  '475': 'flexbar_split_RYYR_bcs',
#  '476': 'Count1',
#  '477': 'qiime_assign_taxonomy',
#  '478': 'smf_utils_extract-boxed-sequences',
#  '479': 'bedtools_unionbedgraph',
#  '480': 'rbc_rnacode',
#  '481': 'mothur_get_communitytype',
#  '482': 'prokka',
#  '483': 'mothur_align_seqs',
#  '484': 'biosigner',
#  '485': 'ip_projective_transformation',
#  '486': 'Flash',
#  '487': 'modencode_peakcalling_macs2',
#  '488': 'uparse',
#  '489': 'viennarna_rnafold',
#  '490': 'mothur_screen_seqs',
#  '491': 'deeptools_compute_matrix_operations',
#  '492': 'rbc_mirdeep2_mapper',
#  '493': 'gatk_depth_of_coverage',
#  '494': 'fastq_to_tabular',
#  '495': 'bedtools_genomecoveragebed',
#  '496': 'gmx_md',
#  '497': 'picard_ReorderSam',
#  '498': 'filter_by_fasta_ids',
#  '499': 'msconvert_nix',
#  '500': 'bcftools_call',
#  '501': 'vcfgenotypes',
#  '502': 'tp_tail_tool',
#  '503': 'Multivariate',
#  '504': 'cardinal_segmentations',
#  '505': 'ChooseTag',
#  '506': 'CONVERTER_gff_to_bed_0',
#  '507': 'gemini_windower',
#  '508': 'shovill',
#  '509': 'dexseq_count',
#  '510': 'gatk2_realigner_target_creator',
#  '511': 'humann2',
#  '512': 'mothur_count_seqs',
#  '513': 'length_and_gc_content',
#  '514': 'IDFileConverter',
#  '515': 'glimmer_build-icm',
#  '516': 'PicardASMetrics',
#  '517': 'CONVERTER_gz_to_uncompressed',
#  '518': 'iReport',
#  '519': 'Show tail1',
#  '520': 'minfi_dmp',
#  '521': 'mothur_chimera_uchime',
#  '522': 'picard_AddOrReplaceReadGroups',
#  '523': 'deeptools_bamCompare',
#  '524': 'graphlan',
#  '525': 'hcluster_sg',
#  '526': 'fastq_groomer',
#  '527': 'gmx_nvt',
#  '528': 'fgsea',
#  '529': 'enhanced_bowtie_wrapper',
#  '530': 'dexseq',
#  '531': 'unicycler',
#  '532': 'hicexplorer_hicmergematrixbins',
#  '533': 'FROGS_affiliations_stat',
#  '534': 'deeptools_plot_pca',
#  '535': 'infernal_cmsearch',
#  '536': 'glob_report',
#  '537': 'minfi_rset',
#  '538': 'idpassemble',
#  '539': 'ggplot_point',
#  '540': 'Determine_BC',
#  '541': 'cshl_fasta_formatter',
#  '542': 'deeptools_profiler',
#  '543': 'jbrowse',
#  '544': 'raceid_main',
#  '545': '__ZIP_COLLECTION__',
#  '546': 'stacks_populations',
#  '547': 'je_clip',
#  '548': 'EMBOSS: transeq101',
#  '549': 'samtools_idxstats',
#  '550': 'cardinal_preprocessing',
#  '551': 'cshl_fastx_artifacts_filter',
#  '552': 'flexbardsc',
#  '553': 'cshl_grep_tool',
#  '554': 'qiime_pick_open_reference_otus',
#  '555': 'tp_sorted_uniq',
#  '556': 'gtf2bedgraph',
#  '557': 'velvet',
#  '558': 'cshl_easyjoin',
#  '559': 'deseq2',
#  '560': 'abims_xcms_xcmsSet',
#  '561': 'tp_split_on_column',
#  '562': 'minfi_qc',
#  '563': 'CONVERTER_fastqgz_to_fastq',
#  '564': 'bundle_collection',
#  '565': 'search_gui',
#  '566': 'proteomics_moff',
#  '567': 'cshl_fastq_quality_filter',
#  '568': 'Psortb',
#  '569': 'gops_join_1',
#  '570': 'cutadapt',
#  '571': 'deeptools_computeMatrix',
#  '572': 'bed_to_bigwig',
#  '573': 'hicexplorer_hiccorrectmatrix',
#  '574': 'openms_id_file_converter',
#  '575': 'mass_spectrometry_imaging_preprocessing',
#  '576': 'computeMatrix',
#  '577': 'FidoAdapter',
#  '578': 'ctb_compound_convert',
#  '579': 'gtf_filter_by_attribute_values_list',
#  '580': 'gatk2_indel_realigner',
#  '581': 'vcfannotate',
#  '582': 'gemini_de_novo',
#  '583': 'openms_protein_quantifier',
#  '584': 'humann2_regroup_table',
#  '585': 'IDScoreSwitcher',
#  '586': 'augustus',
#  '587': 'smf_utils_estimate-energy',
#  '588': 'spades',
#  '589': 'rseqc_infer_experiment',
#  '590': 'meme_fimo',
#  '591': 'nanopolish_variants',
#  '592': 'gops_cluster_1',
#  '593': 'fasta_compute_length',
#  '594': 'proteomics_search_peptide_prophet_1',
#  '595': 'fasta-stats',
#  '596': 'tp_uniq_tool',
#  '597': 'bowtie_wrapper',
#  '598': 'fastq_paired_end_deinterlacer',
#  '599': 'bg_diamond',
#  '600': 'svm_classifier',
#  '601': 'tsne',
#  '602': 'treebest_best',
#  '603': 'bams2ratio',
#  '604': 'iuc_pear',
#  '605': 'tag_stat2',
#  '606': 'uniprot',
#  '607': 'samtools_sort',
#  '608': 'nanoplot',
#  '609': 'gemini_interactions',
#  '610': 'ip_projective_transformation_points',
#  '611': 'varscan_somatic',
#  '612': 'ExtractFASTAfromFASTQ',
#  '613': 'cufflinks_prok',
#  '614': 'plotly_ml_performance_plots',
#  '615': 'scaffold2fasta',
#  '616': 'qiime_pick_closed_reference_otus',
#  '617': 'snpSift_filter',
#  '618': 'msconvert3_raw',
#  '619': 'qiime_make_otu_heatmap',
#  '620': 'Extract genomic DNA 1',
#  '621': 'bg_find_subsequences',
#  '622': 'CONVERTER_sam_to_unsorted_bam',
#  '623': 'FeatureFinderMetabo',
#  '624': 'bam_to_bigwig',
#  '625': 'bedtools_annotatebed',
#  '626': 'deeptools_plot_coverage',
#  '627': 'chipsequtil_maptoknowngenes',
#  '628': 'tp_find_and_replace',
#  '629': 'bed2gff1',
#  '630': 'sam_pileup',
#  '631': 'transdecoder',
#  '632': 'gemini_burden',
#  '633': 'bedtools_multiintersectbed',
#  '634': 'vcffilter',
#  '635': 'graphclust_align_cluster',
#  '636': 'deg_annotate',
#  '637': '__MERGE_COLLECTION__',
#  '638': 'mothur_pcoa',
#  '639': 't2t_report',
#  '640': 'CONVERTER_bed_to_gff_0',
#  '641': 'graphclust_aggregate_alignments',
#  '642': 'merge_pcr_duplicates.py',
#  '643': 'ctb_online_data_fetch',
#  '644': 'minfi_dropsnp',
#  '645': 'snpSift_dbnsfp_generic',
#  '646': 'vcfallelicprimitives',
#  '647': 'vcf_filter',
#  '648': 'velveth_jgi',
#  '649': 'msconvert2_raw',
#  '650': 'blastxml_to_tabular',
#  '651': 'picard_SortSam',
#  '652': 'snippy',
#  '653': 'cshl_sed_tool',
#  '654': 'bwa_mem',
#  '655': 'Convert characters1',
#  '656': 'racon',
#  '657': 'antismash',
#  '658': 'bedtools_windowbed',
#  '659': 'deeptools_bamCoverage',
#  '660': 'viz_overlay_moving_and_fixed_image',
#  '661': 'deeptools_bigwig_compare',
#  '662': 'graphicsmagick_image_convert',
#  '663': 'krona-text',
#  '664': 'sklear_numeric_clustering',
#  '665': 'cshl_awk_tool',
#  '666': 'macs2_bdgcmp',
#  '667': 'map_peptides_to_bed',
#  '668': 'abims_xcms_group',
#  '669': 'idr-embl',
#  '670': 'picard_CollectWgsMetrics',
#  '671': 'column_remove_by_header',
#  '672': 'flanking_features_1',
#  '673': 'bedtools_bedtobam',
#  '674': 'je_markdupes',
#  '675': 'minfi_ppfun',
#  '676': 'transpose',
#  '677': 'methtools_filter',
#  '678': 'disco',
#  '679': 'metilene',
#  '680': 'mothur_classify_rf',
#  '681': 'bwa',
#  '682': 'mycrobiota-make-multi-otutable',
#  '683': 'FileMerger',
#  '684': 'remove_tail.py',
#  '685': 'CONVERTER_bedgraph_to_bigwig',
#  '686': 'mass_spectrometry_imaging_combine',
#  '687': 'snpEff_download',
#  '688': 'rseqc_junction_saturation',
#  '689': 'mothur_heatmap_sim',
#  '690': 'snpSift_annotate',
#  '691': 'FileConverter',
#  '692': 'rseqc_geneBody_coverage',
#  '693': 'correct_barcodes',
#  '694': 'genbank_to_gff',
#  '695': 'ctb_remSmall',
#  '696': 'myrimatch',
#  '697': 'qiime_core_diversity',
#  '698': 'thermo_raw_file_converter',
#  '699': 'ncbi_rpsblast_wrapper',
#  '700': 'vcftools_annotate',
#  '701': 'samtools_rmdup',
#  '702': 'tp_grep_tool',
#  '703': 'deeptools_heatmapper',
#  '704': 'term_id_vs_term_def',
#  '705': 'paralyzer',
#  '706': 'fastq_dump',
#  '707': 'cardinal_mz_images',
#  '708': 'goenrichment',
#  '709': 'EMBOSS: water107',
#  '710': 'mothur_summary_seqs',
#  '711': 'featurecounts',
#  '712': 'scale_image',
#  '713': 'samtools_flagstat',
#  '714': 'varscan',
#  '715': 'gmx_setup',
#  '716': 'eden_vectorizer',
#  '717': 'deeptools_correctGCBias',
#  '718': 'diffbind-embl',
#  '719': 'sam_bw_filter',
#  '720': 'Nucleosome',
#  '721': 'pureclip',
#  '722': 'Add_a_column1',
#  '723': 'tp_unfold_column_tool',
#  '724': 'EMBOSS: extractseq35',
#  '725': 'rseqc_read_distribution',
#  '726': 'viennarna_rnaalifold',
#  '727': 'mycrobiota-split-multi-otutable',
#  '728': 'cmv',
#  '729': 'join_files_on_column_fuzzy',
#  '730': 'sklearn_searchcv',
#  '731': 'IDFilter',
#  '732': 'bedtools_map',
#  '733': 'bamCompare_deepTools',
#  '734': 'tophat2',
#  '735': 'bcftools_consensus',
#  '736': 'cuffnorm',
#  '737': 'bamCoverage_deepTools',
#  '738': 'htseq-count',
#  '739': 'allele_counts_1',
#  '740': 'gd_raxml',
#  '741': 'Extract_features1',
#  '742': 'NSPDK_candidateClust',
#  '743': 'sam_to_bam',
#  '744': 'mothur_classify_seqs',
#  '745': 'mothur_count_groups',
#  '746': 'raceid_trajectory',
#  '747': 'rsem_prepare_reference',
#  '748': 'vcf2pgSnp',
#  '749': '16Saligner',
#  '750': 'peakcalling_macs',
#  '751': 'MapStatistics',
#  '752': 'mz_to_sqlite',
#  '753': 'idpqonvert',
#  '754': 'bigwig_to_bedgraph',
#  '755': 'abims_xcms_fillPeaks',
#  '756': 'lastz_wrapper_2',
#  '757': 'MSGFPlusAdapter',
#  '758': 'mothur_tree_shared',
#  '759': 'annotatemyids',
#  '760': 'bedtools_mergebed',
#  '761': 'mcClust',
#  '762': 'humann2_genefamilies_genus_level',
#  '763': 'secure_hash_message_digest',
#  '764': 'bandage_image',
#  '765': 'mothur_rarefaction_single',
#  '766': 'bedtools_genomecoveragebed_bedgraph',
#  '767': 'cuffcompare',
#  '768': 'mycrobiota-qc-report',
#  '769': 'metaphlan2',
#  '770': 'kraken-report',
#  '771': 'xcms_merge',
#  '772': 'bwa_wrapper',
#  '773': 'coords2clnt.py',
#  '774': 'Paste1',
#  '775': 'ucsc-twobittofa',
#  '776': 'gatk2_haplotype_caller',
#  '777': '__APPLY_RULES__',
#  '778': 'multiqc',
#  '779': 'ncbi_makeblastdb',
#  '780': 'gemini_comp_hets',
#  '781': 'minfi_dmr',
#  '782': 'fasttree',
#  '783': 'bg_sortmerna',
#  '784': 'msgfplus',
#  '785': 'rnbeads',
#  '786': 'mimodd_vcf_filter',
#  '787': 'umi_tools_extract',
#  '788': 'mlocarna',
#  '789': 'fastq_filter',
#  '790': 'cshl_fastx_collapser',
#  '791': 'MAF_To_Fasta1',
#  '792': 'ggplot2_histogram',
#  '793': '16Sclassifier',
#  '794': 'Remove beginning1',
#  '795': 'mass_spectrometry_imaging_ion_images',
#  '796': 'humann2_renorm_table',
#  '797': 'numeric_clustering',
#  '798': 'segemehl',
#  '799': 'mothur_get_seqs',
#  '800': '__FILTER_FAILED_DATASETS__',
#  '801': 'gatk2_base_recalibrator',
#  '802': 'selectsequencesfrommsa',
#  '803': 'gemini_actionable_mutations',
#  '804': 'IDPosteriorErrorProbability',
#  '805': 'umi_tools_group',
#  '806': 'lfq_protein_quant',
#  '807': 'bedtools_subtractbed',
#  '808': 'picard_NormalizeFasta',
#  '809': 'salmon',
#  '810': 'hicexplorer_hicbuildmatrix',
#  '811': 'melt',
#  '812': 'minimap2',
#  '813': 'stacks_procrad',
#  '814': 'cshl_sort_header',
#  '815': 'fastq_trimmer',
#  '816': 'snpfinder',
#  '817': 'IDMerger',
#  '818': 'heinz_visualization',
#  '819': 'bedtools_slopbed',
#  '820': 'sam_merge2',
#  '821': 'TrimByN',
#  '822': 'deeptools_compute_matrix',
#  '823': 'samtools_bedcov',
#  '824': 'cufflinks',
#  '825': 'proteomics_search_protein_prophet_1',
#  '826': 'secretbt2test',
#  '827': 'rgPicardMarkDups',
#  '828': 'metaphlan2krona',
#  '829': 'blockbuster',
#  '830': 'eukaryotic_ncbi_submission',
#  '831': 'megablast_wrapper',
#  '832': 'bedtools_bamtofastq',
#  '833': 'infernal_cmstat',
#  '834': 'cshl_uniq_tool',
#  '835': 'snpEff',
#  '836': 'FalseDiscoveryRate',
#  '837': 'PicardInsertSize',
#  '838': 'FeatureLinkerUnlabeled',
#  '839': 'naive_variant_caller',
#  '840': 'cardinal_spectra_plots',
#  '841': 'snpSift_geneSets',
#  '842': 'ggplot2_heatmap',
#  '843': 'IDMassAccuracy',
#  '844': 'FileInfo',
#  '845': 'ssake',
#  '846': 'velvetg_jgi',
#  '847': 'fastqc',
#  '848': 'datamash_transpose',
#  '849': 'export2graphlan',
#  '850': 'tp_sed_tool',
#  '851': 'bg_uniq',
#  '852': 'filtlong',
#  '853': 'gff_to_sequence',
#  '854': 'qiime_align_seqs',
#  '855': 'circgraph',
#  '856': 'kraken-filter',
#  '857': 'cuffquant',
#  '858': 'vcfflatten2',
#  '859': 'flye',
#  '860': 'deeptools_correct_gc_bias',
#  '861': 'mothur_sub_sample',
#  '862': 'blast_parser',
#  '863': 'fasplit',
#  '864': 'checkFormat',
#  '865': 'cshl_fastx_renamer',
#  '866': 'gffcompare',
#  '867': 'gmx_npt',
#  '868': 'MultiplexResolver',
#  '869': 'tp_head_tool',
#  '870': 'deeptools_bam_compare',
#  '871': 'varscan_mpileup',
#  '872': 'ggplot2_point',
#  '873': 'umi_tools_count',
#  '874': 'heinz',
#  '875': 'mothur_remove_seqs',
#  '876': 'fastq_manipulation',
#  '877': 'SequenceCoverageCalculator',
#  '878': 'CONVERTER_bed_to_bgzip_0',
#  '879': 'nonpareil',
#  '880': 'smf_utils_find-boxes',
#  '881': 'tp_awk_tool',
#  '882': 'methtools_plot',
#  '883': 'mothur_remove_groups',
#  '884': 'minfi_mset',
#  '885': 'decoyfasta',
#  '886': 'gemini_query',
#  '887': 'kraken',
#  '888': 'FeatureLinkerUnlabeledQT',
#  '889': 'rbc_mirdeep2',
#  '890': 'gafa',
#  '891': 'maldi_quant_peak_detection',
#  '892': 'samtools_slice_bam',
#  '893': 'ProteinResolver',
#  '894': 'bedtools_getfastabed',
#  '895': 'mothur_make_shared',
#  '896': 'quast',
#  '897': 'samtools_mpileup',
#  '898': 'modencode_peakcalling_spp',
#  '899': 'sklearn_svm_classifier',
#  '900': 'bedtools_coveragebed_counts',
#  '901': 'rgweblogo3',
#  '902': 'je_demultiplex',
#  '903': 'signalp3',
#  '904': 'tophat',
#  '905': 'cshl_fastx_nucleotides_distribution',
#  '906': 'kraken-translate',
#  '907': 'mimodd_varextract',
#  '908': 'ete_homology_classifier',
#  '909': 'raceid_inspecttrajectory',
#  '910': 'ProteinInference',
#  '911': 'TrimPrimer',
#  '912': 'gbk_to_orf',
#  '913': 'gemini_recessive_and_dominant',
#  '914': 'sequence_content_trimmer',
#  '915': 'hcluster_sg_parser',
#  '916': 'cshl_fastx_clipper',
#  '917': 'ChangeCase',
#  '918': 'pieplots_macs',
#  '919': 'picard_FilterSamReads',
#  '920': 'bedtools_coveragebed',
#  '921': 'ctb_remIons',
#  '922': 'sample_seqs',
#  '923': 'tp_sort_rows',
#  '924': 'FileFilter',
#  '925': 'Summary_Statistics1',
#  '926': 'megablast_xml_parser',
#  '927': 'p_clip_peaks',
#  '928': 'bam-filter',
#  '929': 'filter_bed_on_splice_junctions',
#  '930': 'metams_runGC',
#  '931': 'wiggle2simple1',
#  '932': 'EMBOSS: textsearch98',
#  '933': 'deeptools_compute_gc_bias',
#  '934': 'ncbi_blastx_wrapper',
#  '935': 'wc_gnu',
#  '936': 'dexseq_annotate',
#  '937': 'extract_element_from_collection',
#  '938': 'hicexplorer_hicplotmatrix',
#  '939': 'qiime_split_libraries_fastq',
#  '940': 'gatk_unified_genotyper',
#  '941': 'freebayes',
#  '942': 'gatk_indel_realigner',
#  '943': 'vcffixup',
#  '944': 'mothur_summary_single',
#  '945': 'qiime_count_seqs',
#  '946': 'openms_id_mapper',
#  '947': 'megahit',
#  '948': 'fastq_to_fasta_python',
#  '949': 'vcfcombine',
#  '950': 'methtools_dmr',
#  '951': 'mothur_make_group',
#  '952': 'samtool_filter2',
#  '953': 'vt_normalize',
#  '954': 'bedtools_genomecoveragebed_histogram',
#  '955': 'gatk2_print_reads',
#  '956': 'cor2',
#  '957': 'picard_CollectRnaSeqMetrics',
#  '958': 'qiime_make_phylogeny',
#  '959': 'cshl_cut_tool',
#  '960': 'mycrobiota-correct-replicates',
#  '961': 'macs2_callpeak',
#  '962': 'gops_intersect_1',
#  '963': 'dt_profiler',
#  '964': 'abricate',
#  '965': 'ruvseq',
#  '966': 'PeptideIndexer',
#  '967': 'metaphlan_hclust_heatmap',
#  '968': 'CometAdapter',
#  '969': 'ConsensusMapNormalizer',
#  '970': 'stacks_denovomap',
#  '971': 'deeptools_multi_bigwig_summary'}

# %%
def verify_model(model, tool_sequence, labels, dictionary, reverse_dictionary, compatible_tools, topk=20, max_seq_len=25):
    tl_seq = tool_sequence.split(",")
    last_tool_name = reverse_dictionary[str(tl_seq[-1])]
    last_compatible_tools = compatible_tools[last_tool_name]
    sample = np.zeros(max_seq_len)
    for idx, tool_id in enumerate(tl_seq):
        sample[idx] = int(tool_id)
    sample_reshaped = np.reshape(sample, (1, max_seq_len))

    tool_sequence_names = [reverse_dictionary[str(tool_pos)] for tool_pos in tool_sequence.split(",")]
    print("Tool seq: %s" % ",".join(tool_sequence_names))

    # predict next tools for a test path
    prediction = model.predict(sample_reshaped, verbose=0)
    prediction = np.reshape(prediction, (prediction.shape[1],))
    prediction_pos = np.argsort(prediction, axis=-1)

    # get topk prediction
    topk_prediction_pos = prediction_pos[-topk:]
    topk_prediction_val = [np.round(prediction[pos] * 100, 2) for pos in topk_prediction_pos]

    # read tool names using reverse dictionary
    pred_tool_ids = [reverse_dictionary[str(tool_pos)] for tool_pos in topk_prediction_pos]
    actual_next_tool_ids = list(set(pred_tool_ids).intersection(set(last_compatible_tools.split(","))))      

    print()
    pred_tool_ids_sorted = dict()
    for (tool_pos, tool_pred_val) in zip(topk_prediction_pos, topk_prediction_val):
        tool_name = reverse_dictionary[str(tool_pos)]
        if tool_name in actual_next_tool_ids:
            pred_tool_ids_sorted[tool_name] = tool_pred_val
    pred_tool_ids_sorted = dict(sorted(pred_tool_ids_sorted.items(), key=lambda kv: kv[1], reverse=True))
    
    cls_wt = dict()
    usg_wt = dict()
    inv_wt = dict()
    ids_tools = dict()
    keys = list(pred_tool_ids_sorted.keys())
    for k in keys:
        try:
            cls_wt[k] = np.round(class_weights[str(data_dict[k])], 2)
            usg_wt[k] = np.round(usage_weights[k], 2)
            inv_wt[k] = np.round(inverted_weights[str(data_dict[k])], 2)
        except:
            continue
    print("Predicted tools: \n")
    print(pred_tool_ids_sorted)
    print()
    print("Class weights: \n")
    cls_wt = dict(sorted(cls_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(cls_wt)
    print()
    print("Usage weights: \n")
    usg_wt = dict(sorted(usg_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(usg_wt)
    print()
    total_usage_wt = np.mean(list(usg_wt.values()))
    print("Mean usage wt: %0.4f" % (total_usage_wt))
    print()
    print("Inverted weights: \n")
    inv_wt = dict(sorted(inv_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(inv_wt)
    for key in pred_tool_ids_sorted:
        ids_tools[key] = dictionary[key]
    print()
    print("Tool ids")
    print(ids_tools)
    print("======================================")
    return cls_wt, usg_wt, inv_wt, pred_tool_ids_sorted

topk = 10
tool_seq = "654,810,532"
class_wt, usage_wt, inverse_wt, pred_tools = verify_model(model, tool_seq, "", dictionary, reverse_dictionary, compatibile_tools, topk)
# Out:
# Tool seq: bwa_mem,hicexplorer_hicbuildmatrix,hicexplorer_hicmergematrixbins
#
# Predicted tools:
#
# {'hicexplorer_hicplotmatrix': 41.81, 'hicexplorer_hicplottads': 26.37, 'hicexplorer_hiccorrectmatrix': 1.36}
#
# Class weights:
#
# {'hicexplorer_hicplotmatrix': 126.04, 'hicexplorer_hiccorrectmatrix': 114.36, 'hicexplorer_hicplottads': 109.85}
#
# Usage weights:
#
# {'hicexplorer_hicplotmatrix': 126.04, 'hicexplorer_hiccorrectmatrix': 114.36, 'hicexplorer_hicplottads': 109.85}
#
# Mean usage wt: 116.7500
#
# Inverted weights:
#
# {'hicexplorer_hiccorrectmatrix': 9740.56, 'hicexplorer_hicplotmatrix': 6261.79, 'hicexplorer_hicplottads': 5479.06}
#
# Tool ids
# {'hicexplorer_hicplotmatrix': 938, 'hicexplorer_hicplottads': 233, 'hicexplorer_hiccorrectmatrix': 573}
# ======================================

# %%
list_cls_wt = list()
list_usage_wt = list()
list_pred_wt = list()
list_inv_wt = list()
division_pt = int(len(pred_tools) / 2)

for tool in pred_tools:
    list_pred_wt.append(pred_tools[tool])
    #try:
    list_inv_wt.append(inverse_wt[tool])
    list_usage_wt.append(usage_wt[tool])
    #except:
    #list_inv_wt.append(1)

def plot_scatter(y_val, title, xlabel, ylabel):
    x_val = range(1, len(y_val) + 1)
    plt.figure(figsize=(8, 8))
    plt.plot(x_val[:division_pt], y_val[:division_pt], 'ro')
    plt.plot(x_val[division_pt:], y_val[division_pt:], 'b^')
    plt.xlabel(xlabel, size=size_label)
    plt.ylabel(ylabel, size=size_label)
    plt.legend([("First top-%s" % str(division_pt)), ("Next top-%s" % str(division_pt))])
    plt.title(title, size=size_title)
    plt.grid(True)
    plt.show()

plot_scatter(list_usage_wt, "Usage weights for tools", "Number of tools", "Class weights")
#plot_scatter(ave_prediction_weights, ave_usage_weights, "Prediction vs usage weights", "Prediction scores", "Usage weights")
#plot_scatter(ave_prediction_weights, ave_inverted_weights, "Prediction vs inverted weights", "Prediction scores", "Inverted weights")
