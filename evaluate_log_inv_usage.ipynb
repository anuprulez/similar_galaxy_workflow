# %%
import numpy as np
import json
import warnings
import operator

import h5py
from keras.models import model_from_json
from keras import backend as K

from matplotlib import pyplot as plt

warnings.filterwarnings("ignore")

size_title = 18
size_label = 14
n_pred = 2

base_path = "data/evaluate_log_inv_usage/" # 5_similar_galaxy_workflow

path_data_dict = base_path + "data_dict.txt"
path_inverted_wt = base_path + "inverted_weights.txt"
path_usage_wt = base_path + "usage_prediction.txt"
path_class_wt = base_path + "class_weights.txt"
path_test_data = base_path + "test_paths_dict.txt"
model_path = base_path + "trained_model.hdf5"

def read_file(file_path):
    with open(file_path, 'r') as data_file:
        data = json.loads(data_file.read())
    return data

class_weights = read_file(path_class_wt)
usage_weights = read_file(path_usage_wt)
inverted_weights = read_file(path_inverted_wt)
data_dict = read_file(path_data_dict)

def create_model(model_path):
    trained_model = h5py.File(model_path, 'r')
    model_config = json.loads(trained_model.get('model_config').value)
    loaded_model = model_from_json(model_config)
    dictionary = json.loads(trained_model.get('data_dictionary').value)
    compatibile_tools = json.loads(trained_model.get('compatible_tools').value)
    reverse_dictionary = dict((str(v), k) for k, v in dictionary.items())
    model_weights = list()
    weight_ctr = 0
    while True:
        try:
            d_key = "weight_" + str(weight_ctr)
            weights = trained_model.get(d_key).value
            model_weights.append(weights)
            weight_ctr += 1
        except Exception as exception:
            break
    # set the model weights
    loaded_model.set_weights(model_weights)
    return loaded_model, dictionary, reverse_dictionary, compatibile_tools

model, dictionary, reverse_dictionary, compatibile_tools = create_model(model_path)
# Out:
# Using TensorFlow backend.

# %%
reverse_dictionary
# Out:
# {'1': 'blastxml_to_top_descr',
#  '2': 'mothur_heatmap_bin',
#  '3': 'rseqc_read_distribution',
#  '4': 'scpipe',
#  '5': 'correctGCBias',
#  '6': 'cshl_fastq_to_fasta',
#  '7': 'cshl_grep_tool',
#  '8': 'TrimByN',
#  '9': 'uparse',
#  '10': 'PeptideIndexer',
#  '11': 'gtftobed12',
#  '12': 'cummeRbund',
#  '13': 'picard_NormalizeFasta',
#  '14': 'filtlong',
#  '15': 'mycrobiota-make-multi-otutable',
#  '16': 'FileConverter',
#  '17': 'rbc_mafft',
#  '18': 'ggplot_histogram',
#  '19': 'mothur_cluster',
#  '20': 'cshl_sort_header',
#  '21': 'bedtools_genomecoveragebed_bedgraph',
#  '22': 'gffcompare',
#  '23': 'rbc_mirdeep2',
#  '24': 'snpfinder',
#  '25': 'metams_runGC',
#  '26': 'sam_merge2',
#  '27': 'gmx_em',
#  '28': 'fastq_paired_end_interlacer',
#  '29': 'regex_replace',
#  '30': 'ConsensusID',
#  '31': 'deeptools_profiler',
#  '32': 'infernal_cmsearch',
#  '33': 'random_lines1',
#  '34': 'picard_EstimateLibraryComplexity',
#  '35': 'IDMapper',
#  '36': 'cd_hit_dup',
#  '37': 'graphclust_align_cluster',
#  '38': 'antismash',
#  '39': 'peptide_shaker',
#  '40': 'RNAlien',
#  '41': 'fastq_paired_end_splitter',
#  '42': 'SequenceCoverageCalculator',
#  '43': 'pileup_parser',
#  '44': 'idpqonvert',
#  '45': 'seq_filter_by_id',
#  '46': 'FROGS_filters',
#  '47': 'edger',
#  '48': 'samtools_sort',
#  '49': 'aragorn_trna',
#  '50': 'enhanced_bowtie_wrapper',
#  '51': 'qiime_pick_rep_set',
#  '52': 'quast',
#  '53': 'FalseDiscoveryRate',
#  '54': 'term_id_vs_term_name',
#  '55': 'cshl_fastq_quality_boxplot',
#  '56': 'FROGS_remove_chimera',
#  '57': 'rbc_rnacode',
#  '58': 'gatk_unified_genotyper',
#  '59': 'raceid_clustering',
#  '60': 'tp_tac',
#  '61': 'bg_sortmerna',
#  '62': 'tp_text_file_with_recurring_lines',
#  '63': 'sklearn_svm_classifier',
#  '64': 'gemini_comp_hets',
#  '65': '16Sclassifier',
#  '66': 'secure_hash_message_digest',
#  '67': 'vcfselectsamples',
#  '68': '__RELABEL_FROM_FILE__',
#  '69': 'Nucleosome',
#  '70': 'heinz_visualization',
#  '71': 'bamleftalign',
#  '72': 'rseqc_bam2wig',
#  '73': 'gtf2bedgraph',
#  '74': 't2t_report',
#  '75': 'idr-embl',
#  '76': 'humann2_renorm_table',
#  '77': 'samtools_filter',
#  '78': 'sailfish',
#  '79': 'metilene',
#  '80': 'raceid_main',
#  '81': 'bedtools_intersectbed',
#  '82': 'blast2go',
#  '83': 'velveth_jgi',
#  '84': 'fastq_to_tabular',
#  '85': 'sklearn_build_pipeline',
#  '86': 'smf_utils_fix-fasta-headers',
#  '87': 'tp_multijoin_tool',
#  '88': 'graphlan_annotate',
#  '89': 'ggplot2_heatmap2',
#  '90': 'blockclust',
#  '91': 'kraken-translate',
#  '92': 'MassCalculator',
#  '93': 'samtools_bedcov',
#  '94': 'CONVERTER_interval_to_bgzip_0',
#  '95': 'bedtools_intersectBed',
#  '96': 'mothur_rarefaction_single',
#  '97': 'mothur_get_groups',
#  '98': 'extract_element_from_collection',
#  '99': 'pureclip',
#  '100': 'vcffilter2',
#  '101': 'raceid_filtnormconf',
#  '102': 'MAF_To_Fasta1',
#  '103': 'mothur_summary_single',
#  '104': 'datamash_ops',
#  '105': 'snpsift_vartype',
#  '106': 'mothur_amova',
#  '107': 'gemini_recessive_and_dominant',
#  '108': 'abricate',
#  '109': 'ExtractFASTAfromFASTQ',
#  '110': 'vcfvcfintersect',
#  '111': 'mothur_lefse',
#  '112': 'bctools_extract_alignment_ends',
#  '113': 'mothur_merge_files',
#  '114': 'fastq_join',
#  '115': 'translate_bed_sequences',
#  '116': 'w4mjoinpn',
#  '117': 'picard_FixMateInformation',
#  '118': 'kallisto_quant',
#  '119': 'EMBOSS: geecee41',
#  '120': 'tp_head_tool',
#  '121': 'proteomics_search_protein_prophet_1',
#  '122': 'mothur_cluster_split',
#  '123': 'mass_spectrometry_imaging_ion_images',
#  '124': 'ggplot_point',
#  '125': 'bowtie2',
#  '126': 'mothur_summary_seqs',
#  '127': 'fastq_dump',
#  '128': 'bwa',
#  '129': 'openms_id_mapper',
#  '130': 'Batch_correction',
#  '131': 'stacks_refmap',
#  '132': 'search_gui',
#  '133': 'shovill',
#  '134': 'gmx_solvate',
#  '135': 'ggplot2_heatmap',
#  '136': 'Interval_Maf_Merged_Fasta2',
#  '137': 'humann2_genefamilies_genus_level',
#  '138': 'smf_utils_estimate-energy',
#  '139': 'fgsea',
#  '140': 'gemini_actionable_mutations',
#  '141': 'racon',
#  '142': 'gbk_to_orf',
#  '143': 'extract_bcs.py',
#  '144': 'mimodd_varcall',
#  '145': 'gops_merge_1',
#  '146': 'pilon',
#  '147': 'ete_homology_classifier',
#  '148': 'unicycler',
#  '149': 'metaspades',
#  '150': 'fastq_to_fasta_python',
#  '151': 'cshl_fastq_quality_filter',
#  '152': 'mothur_heatmap_sim',
#  '153': 'EMBOSS: seqret84',
#  '154': 'mass_spectrometry_imaging_mzplots',
#  '155': 'qiime_pick_open_reference_otus',
#  '156': 'mlocarna',
#  '157': 'vcfallelicprimitives',
#  '158': 'ctb_remIons',
#  '159': 'mothur_align_seqs',
#  '160': 'eukaryotic_ncbi_submission',
#  '161': 'FastTree',
#  '162': 'megahit',
#  '163': 'tp_easyjoin_tool',
#  '164': 'cshl_uniq_tool',
#  '165': 'mothur_chimera_uchime',
#  '166': 'clustalw',
#  '167': 'tp_replace_in_column',
#  '168': 'varscan_mpileup',
#  '169': 'deeptools_bamCoverage',
#  '170': 'dt_profiler',
#  '171': 'get_flanks1',
#  '172': 'bcftools_call',
#  '173': 'mothur_metastats',
#  '174': 'Univariate',
#  '175': 'aggregate_scores_in_intervals2',
#  '176': 'htseq_count',
#  '177': 'rseqc_inner_distance',
#  '178': 'salmon',
#  '179': 'tabular_to_fastq',
#  '180': 'MzTabExporter',
#  '181': 'bamFilter',
#  '182': 'vcftools_annotate',
#  '183': 'tp_grep_tool',
#  '184': 'sam_bw_filter',
#  '185': 'deeptools_plot_fingerprint',
#  '186': 'eden_vectorizer',
#  '187': 'bam-filter',
#  '188': 'fasplit',
#  '189': 'methtools_tiling',
#  '190': 'bedtools_getfastabed',
#  '191': 'fasttree',
#  '192': 'EMBOSS: textsearch98',
#  '193': 'heinz',
#  '194': 'smooth_running_window',
#  '195': 'samtools_rmdup',
#  '196': 'w4mclassfilter',
#  '197': 'FROGS_affiliations_stat',
#  '198': 'augustus',
#  '199': 'wiggle2simple1',
#  '200': 'mothur_corr_axes',
#  '201': 'mothur_seq_error',
#  '202': 'deeptools_computeMatrix',
#  '203': 'bcftools_norm',
#  '204': 'get_feature_info',
#  '205': 'mothur_screen_seqs',
#  '206': 'piranha',
#  '207': 'metaphlan_hclust_heatmap',
#  '208': 'fastq_manipulation',
#  '209': 'ctb_simsearch',
#  '210': 'cshl_fastx_quality_statistics',
#  '211': 'gatk2_reduce_reads',
#  '212': 'Remove beginning1',
#  '213': 'length_and_gc_content',
#  '214': 'fastq_filter',
#  '215': 'ncbi_tblastn_wrapper',
#  '216': 'chipseeker',
#  '217': 'ctb_compound_convert',
#  '218': 'maldi_quant_preprocessing',
#  '219': 'cardinal_combine',
#  '220': 'naive_variant_caller',
#  '221': 'mothur_count_seqs',
#  '222': 'bedtools_coveragebed_counts',
#  '223': 'sam_pileup',
#  '224': 'heatmapper_deepTools',
#  '225': 'gemini_pathways',
#  '226': 'gspan',
#  '227': 'EMBOSS: wordcount109',
#  '228': 'varscan_copynumber',
#  '229': 'egsea',
#  '230': 'rarefaction',
#  '231': 'GeMoMa_Annotation_Filter',
#  '232': 'gatk_depth_of_coverage',
#  '233': 'iReport',
#  '234': 'MapAlignerPoseClustering',
#  '235': 'htseq-count',
#  '236': 'bam_to_bigwig',
#  '237': 'abims_xcms_xcmsSet',
#  '238': 'structure_to_gspan',
#  '239': 'modencode_peakcalling_spp',
#  '240': 'bwameth',
#  '241': 'gops_coverage_1',
#  '242': 'charts',
#  '243': 'proteomics_search_peptide_prophet_1',
#  '244': 'valet',
#  '245': 'gops_intersect_1',
#  '246': 'lca1',
#  '247': 'coords2clnt.py',
#  '248': 'collection_column_join',
#  '249': 'checkFormat',
#  '250': 'methtools_calling',
#  '251': 'nanoplot',
#  '252': 'align_families',
#  '253': '__APPLY_RULES__',
#  '254': 'get_sequences',
#  '255': 'bg_find_subsequences',
#  '256': 'trim_galore',
#  '257': 'hicexplorer_hicplotmatrix',
#  '258': 'qiime_assign_taxonomy',
#  '259': 'stacks_denovomap',
#  '260': 'Flash',
#  '261': 'deeptools_multi_bam_summary',
#  '262': 'mimodd_map',
#  '263': 'picard_ReorderSam',
#  '264': 'viennarna_rnaplot',
#  '265': 'vcftools_merge',
#  '266': 'NSPDK_candidateClust',
#  '267': 'cshl_sed_tool',
#  '268': 'cast',
#  '269': 'minfi_dmp',
#  '270': 'mothur_trim_seqs',
#  '271': 'gemini_annotate',
#  '272': 'CONVERTER_bed_to_bgzip_0',
#  '273': 'mothur_get_communitytype',
#  '274': 'correct_barcodes',
#  '275': 'modencode_peakcalling_macs2',
#  '276': 'deeptools_correct_gc_bias',
#  '277': 'stacks_populations',
#  '278': 'EMBOSS: extractseq35',
#  '279': 'QCCalculator',
#  '280': 'flexbardsc',
#  '281': 'plotly_ml_performance_plots',
#  '282': 'ConsensusMapNormalizer',
#  '283': 'ggplot2_point',
#  '284': 'samtools_split',
#  '285': 'minfi_maptogenome',
#  '286': 'deeptools_correctGCBias',
#  '287': 'Paste1',
#  '288': 'mothur_get_oturep',
#  '289': 'bg_statistical_hypothesis_testing',
#  '290': 'ncbi_blastn_wrapper',
#  '291': 'Btrim64',
#  '292': 'get_read_pipeline',
#  '293': 'picard_CASM',
#  '294': 'Determine_BC',
#  '295': 'glimmer_build-icm',
#  '296': 'xcms_merge',
#  '297': 'myrimatch',
#  '298': 'picard_BamIndexStats',
#  '299': 'mothur_classify_seqs',
#  '300': 'deeptools_bamCompare',
#  '301': 'fragmenter',
#  '302': 'seurat',
#  '303': 'mothur_pre_cluster',
#  '304': 'TrimByLength',
#  '305': 'fasta_compute_length',
#  '306': 'proteomics_moff',
#  '307': 'Summary_Statistics1',
#  '308': 'FeatureFinderMultiplex',
#  '309': 'peakcalling_macs',
#  '310': 'cor2',
#  '311': 'hmmer_hmmbuild',
#  '312': 'cshl_awk_replace_in_column',
#  '313': 'rbc_mirdeep2_quantifier',
#  '314': 'vcffilter',
#  '315': 'bedtools_genomecoveragebed',
#  '316': 'circgraph',
#  '317': 'ucsc-twobittofa',
#  '318': 'bedtools_multiintersectbed',
#  '319': 'trimmomatic',
#  '320': 'gemini_burden',
#  '321': 'hgv_linkToGProfile',
#  '322': 'cshl_fasta_formatter',
#  '323': 'picard_SamToFastq',
#  '324': 'openms_protein_quantifier',
#  '325': 'HighResPrecursorMassCorrector',
#  '326': 'gmx_nvt',
#  '327': 'nonpareil',
#  '328': 'bcftools_consensus',
#  '329': 'sklearn_ensemble',
#  '330': 'fastq_combiner',
#  '331': 'Grep1',
#  '332': 'stringtie_merge',
#  '333': 'glimmer_knowlegde-based',
#  '334': 'FeatureLinkerUnlabeledKD',
#  '335': 'CONVERTER_bed_to_gff_0',
#  '336': 'bedtools_bamtofastq',
#  '337': 'PicardInsertSize',
#  '338': 'mimodd_vcf_filter',
#  '339': 'fastq collapser',
#  '340': 'gatk_indel_realigner',
#  '341': 'IDScoreSwitcher',
#  '342': 'mothur_classify_otu',
#  '343': 'sklearn_nn_classifier',
#  '344': 'methtools_filter',
#  '345': 'paralyzer',
#  '346': 'ngsutils_bam_filter',
#  '347': 'mothur_pcoa',
#  '348': 'gff2bed1',
#  '349': 'meme_dreme',
#  '350': 'ChangeCase',
#  '351': 'IDFilter',
#  '352': 'ctb_silicos_qed',
#  '353': 'je_demultiplex',
#  '354': 'nanopolish_variants',
#  '355': 'CONVERTER_bed_gff_or_vcf_to_bigwig_0',
#  '356': 'mothur_tree_shared',
#  '357': 'sickle',
#  '358': 'qiime_make_otu_heatmap',
#  '359': 'createInterval',
#  '360': 'mothur_make_contigs',
#  '361': 'rseqc_infer_experiment',
#  '362': 'dexseq',
#  '363': 'tophat2',
#  '364': 'abims_CAMERA_annotateDiffreport',
#  '365': 'macs2_callpeak',
#  '366': 'fastq_trimmer',
#  '367': 'bams2ratio',
#  '368': 'cmFinder',
#  '369': 'deeptools_plot_heatmap',
#  '370': 'rnaz',
#  '371': 'cardinal_filtering',
#  '372': 'secretbt2test',
#  '373': 'lastz_wrapper_2',
#  '374': 'EMBOSS: fuzzpro38',
#  '375': 'bgchem_fragment_merger',
#  '376': 'mothur_dist_seqs',
#  '377': 'thermo_raw_file_converter',
#  '378': 'minfi_methcpg',
#  '379': 'qiime_count_seqs',
#  '380': 'NFS_transfer',
#  '381': 'histogram_rpy',
#  '382': 'ia_coordinates_of_roi',
#  '383': 'rgweblogo3',
#  '384': 'picard_ARRG',
#  '385': 'rgPicFixMate',
#  '386': 'samtools_flag_filter',
#  '387': 'bedtools_unionbedgraph',
#  '388': 'decoyfasta',
#  '389': 'cmv',
#  '390': 'rsem_calculate_expression',
#  '391': 'cshl_find_and_replace',
#  '392': 'gemini_interactions',
#  '393': 'gatk2_variant_annotator',
#  '394': 'Add_a_column1',
#  '395': 'interproscan',
#  '396': 'fasta2tab',
#  '397': 'msgfplus',
#  '398': 'mycrobiota-krona-mothur',
#  '399': 'metaphlan2',
#  '400': 'venn_list',
#  '401': 'gtf_filter_by_attribute_values_list',
#  '402': 'stacks_genotypes',
#  '403': 'bedtools_bamtobed',
#  '404': 'bwa_wrapper',
#  '405': 'signalp3',
#  '406': 'replace_column_with_key_value_file',
#  '407': 'mycrobiota-correct-replicates',
#  '408': 'collapse_dataset',
#  '409': 'trinity',
#  '410': 'vcfflatten2',
#  '411': 'cutadapt',
#  '412': 'bamtools',
#  '413': 'umi_tools_count',
#  '414': 'minfi_ppfun',
#  '415': 'cardinal_spectra_plots',
#  '416': 'tp_cut_tool',
#  '417': 'je_clip',
#  '418': 'mothur_phylotype',
#  '419': 'cuffcompare',
#  '420': 'transdecoder',
#  '421': 'minfi_mset',
#  '422': 'addName',
#  '423': 'deeptools_plot_profile',
#  '424': 'umi_tools_extract',
#  '425': 'bedtools_genomecoveragebed_histogram',
#  '426': 'vcffixup',
#  '427': 'msconvert3_raw',
#  '428': 'CONVERTER_fastqgz_to_fastq',
#  '429': 'plotly_parallel_coordinates_plot',
#  '430': 'XTandemAdapter',
#  '431': 'EMBOSS: newseq59',
#  '432': 'snpSift_filter',
#  '433': 'cuffnorm',
#  '434': 'mimodd_varextract',
#  '435': 'bedtools_mergebed',
#  '436': 'preMloc',
#  '437': 'hcluster_sg_parser',
#  '438': 'newick_display',
#  '439': 'PeakPickerHiRes',
#  '440': 'Extract_features1',
#  '441': 'IsobaricAnalyzer',
#  '442': 'prokka',
#  '443': 'CONVERTER_fasta_to_tabular',
#  '444': 'pileup_interval',
#  '445': 'vt_normalize',
#  '446': 'mass_spectrometry_imaging_combine',
#  '447': 'bg_uniq',
#  '448': 'group_humann2_uniref_abundances_to_go',
#  '449': 'pileometh',
#  '450': 'bedtools_multicovtbed',
#  '451': 'tag_stat2',
#  '452': 'snpeff_to_peptides',
#  '453': 'featurecounts',
#  '454': 'gatk2_haplotype_caller',
#  '455': 'wsdl_hmdb',
#  '456': 'bedtools_sortbed',
#  '457': 'snpSift_annotate',
#  '458': 'ip_projective_transformation_points',
#  '459': 'picard_MergeSamFiles',
#  '460': 'pieplots_macs',
#  '461': 'abims_xcms_group',
#  '462': 'blast_parser',
#  '463': 'minimap2',
#  '464': 'stringtie',
#  '465': 'CONVERTER_bedgraph_to_bigwig',
#  '466': 'fastq_paired_end_deinterlacer',
#  '467': 'glimmer_not-knowlegde-based',
#  '468': 'graphclust_glob_report_no_align',
#  '469': 'MultiplexResolver',
#  '470': 'rseqc_geneBody_coverage',
#  '471': 'Filter1',
#  '472': 'diffbind-embl',
#  '473': 'sqlite_to_tabular',
#  '474': 'vegan_rarefaction',
#  '475': 'datamash_transpose',
#  '476': 'krona-text',
#  '477': 'gemini_query',
#  '478': 'gd_raxml',
#  '479': 'mothur_filter_seqs',
#  '480': 'cshl_fasta_nucleotides_changer',
#  '481': 'cat1',
#  '482': 'tsne',
#  '483': 'fasta_merge_files_and_filter_unique_sequences',
#  '484': 'blockbuster',
#  '485': 'rseqc_junction_saturation',
#  '486': 'Show tail1',
#  '487': 'prokaryotic_ncbi_submission',
#  '488': 'rbc_mirdeep2_mapper',
#  '489': 'samtools_idxstats',
#  '490': 'mothur_taxonomy_to_krona',
#  '491': 'gops_basecoverage_1',
#  '492': 'gff_to_sequence',
#  '493': 'mass_spectrometry_imaging_filtering',
#  '494': 'ete_genetree_splitter',
#  '495': 'deeptools_compute_matrix_operations',
#  '496': '16Saligner',
#  '497': 'bam_to_sam',
#  '498': 'gatk2_variant_apply_recalibration',
#  '499': 'gmx_setup',
#  '500': 'kraken-filter',
#  '501': 'abims_xcms_fillPeaks',
#  '502': 'vegan_diversity',
#  '503': 'gemini_windower',
#  '504': 'methtools_destrand',
#  '505': 'bctools_remove_spurious_events',
#  '506': 'multiqc',
#  '507': 'Convert characters1',
#  '508': 'heinz_bum',
#  '509': 'pynast',
#  '510': 'join1',
#  '511': 'ruvseq',
#  '512': 'gatk2_base_recalibrator',
#  '513': 'samtools_stats',
#  '514': 'deeptools_bam_coverage',
#  '515': 'ncbi_rpsblast_wrapper',
#  '516': 'bctools_extract_crosslinked_nucleotides',
#  '517': 'Datamash',
#  '518': 'bedtools_shufflebed',
#  '519': 'segemehl',
#  '520': 'cuffmerge',
#  '521': 'mothur_dist_shared',
#  '522': 'qiime_make_phylogeny',
#  '523': 'qiime_pick_closed_reference_otus',
#  '524': 'blastxml_to_tabular_selectable',
#  '525': 'tp_tail_tool',
#  '526': 'extract_aln_ends.py',
#  '527': 'w4mclstrpeakpics',
#  '528': 'mothur_classify_rf',
#  '529': 'fastq_quality_trimmer',
#  '530': 'muscle',
#  '531': 'vcf2pgSnp',
#  '532': 'tp_unfold_column_tool',
#  '533': 'ctb_filter',
#  '534': 'ncbi_makeblastdb',
#  '535': 'FileInfo',
#  '536': 'lfq_protein_quant',
#  '537': 'tp_cat',
#  '538': 'mothur_get_seqs',
#  '539': 'mothur_remove_lineage',
#  '540': 'flexbar',
#  '541': 'mothur_count_groups',
#  '542': 're_he_maldi_image_registration',
#  '543': 'tp_replace_in_line',
#  '544': 'cshl_easyjoin',
#  '545': 'cufflinks',
#  '546': 'vcfcombine',
#  '547': 'rsem_prepare_reference',
#  '548': 'umi_tools_whitelist',
#  '549': 'mycrobiota-split-multi-otutable',
#  '550': 'gemini_de_novo',
#  '551': 'ip_projective_transformation',
#  '552': 'minfi_getbeta',
#  '553': 'gatk2_depth_of_coverage',
#  '554': 'mcClust',
#  '555': 'FeatureFinderMetabo',
#  '556': 'kraken',
#  '557': 'bed2gff1',
#  '558': 'gops_cluster_1',
#  '559': 'vcfgenotypes',
#  '560': 'gatk2_variant_select',
#  '561': 'CONVERTER_Bam_Bai_0',
#  '562': 'vcftools_isec',
#  '563': 'bamCoverage_deepTools',
#  '564': 'deg_annotate',
#  '565': 'bg_diamond',
#  '566': 'glob_report',
#  '567': 'ctb_online_data_fetch',
#  '568': 'ssake',
#  '569': 'mothur_remove_seqs',
#  '570': 'bowtie_wrapper',
#  '571': 'merge_pcr_duplicates.py',
#  '572': 'Psortb',
#  '573': 'deeptools_heatmapper',
#  '574': 'Grouping1',
#  '575': 'qiime_core_diversity',
#  '576': 'graphclust_aggregate_alignments',
#  '577': 'hicexplorer_hicsummatrices',
#  '578': 'Heatmap',
#  '579': 'resistome_analyzer',
#  '580': 'convert_bc_to_binary_RY.py',
#  '581': 'hicexplorer_hictransform',
#  '582': 'gatk2_indel_realigner',
#  '583': 'eden_sequence_converter',
#  '584': 'rcas',
#  '585': 'EMBOSS: transeq101',
#  '586': 'addValue',
#  '587': 'DecoyDatabase',
#  '588': 'flexbar_split_RYYR_bcs',
#  '589': 'hicexplorer_hicbuildmatrix',
#  '590': 'bedtools_complementbed',
#  '591': 'picard_CollectRnaSeqMetrics',
#  '592': 'deeptools_plot_enrichment',
#  '593': 'annotatemyids',
#  '594': 'gmx_md',
#  '595': 'cshl_fastx_artifacts_filter',
#  '596': 'bg_column_arrange_by_header',
#  '597': 'sequence_content_trimmer',
#  '598': 'rseqc_read_duplication',
#  '599': 'deseq2_single',
#  '600': 'bundle_collection',
#  '601': 'qiime_split_libraries_fastq',
#  '602': 'goslimmer',
#  '603': 'Extractor',
#  '604': 'ProteinResolver',
#  '605': 'taxonomy_krona_chart',
#  '606': 'tophat',
#  '607': 'bigwig_to_bedgraph',
#  '608': 'cshl_princeton_fastx_barcode_splitter',
#  '609': 'igvtools_count',
#  '610': 'ncbi_blastx_wrapper',
#  '611': 'filter_bed_on_splice_junctions',
#  '612': 'subtract_query1',
#  '613': 'infernal_cmstat',
#  '614': 'minfi_getM',
#  '615': 'r_correlation_matrix',
#  '616': 'vcf_filter',
#  '617': 'bismark_bowtie2',
#  '618': 'CONVERTER_fasta_to_fai',
#  '619': 'cuffquant',
#  '620': 'PicardASMetrics',
#  '621': 'TrimPrimer',
#  '622': 'dexseq_annotate',
#  '623': 'mothur_make_group',
#  '624': 'FROGS_clustering',
#  '625': 'cshl_fastx_clipper',
#  '626': 'treebest_best',
#  '627': 'Digestor',
#  '628': 'gmx_npt',
#  '629': 'numeric_clustering',
#  '630': 'qiime_align_seqs',
#  '631': 'uniprot',
#  '632': 'goseq',
#  '633': 'tp_sorted_uniq',
#  '634': 'deeptools_compute_matrix',
#  '635': 'gffread',
#  '636': 'mycrobiota-otutable_add_blast',
#  '637': 'methtools_dmr',
#  '638': 'hmmer_hmmsearch',
#  '639': 'cshl_word_list_grep',
#  '640': 'blastxml_to_tabular',
#  '641': 'sklear_numeric_clustering',
#  '642': 'mass_spectrometry_imaging_qc',
#  '643': 'gatk2_variant_recalibrator',
#  '644': 'picard_CollectWgsMetrics',
#  '645': 'vcfbedintersect',
#  '646': 'dunovo',
#  '647': 'macs2_predictd',
#  '648': 'hgv_snpFreq',
#  '649': 'peakcalling_macs14',
#  '650': 'mothur_nmds',
#  '651': 'bedtools_map',
#  '652': 'query_tabular',
#  '653': 'tp_sort_rows',
#  '654': 'idpassemble',
#  '655': 'meme_fimo',
#  '656': 'tp_sort_header_tool',
#  '657': 'gene2exon1',
#  '658': 'IDPosteriorErrorProbability',
#  '659': 'get_subontology_from',
#  '660': 'msconvert2_raw',
#  '661': 'Remove_ending',
#  '662': 'CONVERTER_interval_to_bed_0',
#  '663': 'stacks_procrad',
#  '664': 'IDConflictResolver',
#  '665': 'bed_to_bigBed',
#  '666': 'rgPicardMarkDups',
#  '667': 'cummerbund_to_cuffdiff',
#  '668': 'p_clip_peaks',
#  '669': 'minfi_read450k',
#  '670': 'bedtools_intersectbed_bam',
#  '671': 'bcftools_view',
#  '672': 'cardinal_preprocessing',
#  '673': 'MapStatistics',
#  '674': 'column_order_header_sort',
#  '675': 'mothur_homova',
#  '676': 'plotly_regression_performance_plots',
#  '677': 'bedtools_coveragebed',
#  '678': 'uchime',
#  '679': 'umi_tools_group',
#  '680': 'gatk2_variant_filtration',
#  '681': 'CONVERTER_sam_to_unsorted_bam',
#  '682': 'unipept',
#  '683': 'Show beginning1',
#  '684': 'scaffold2fasta',
#  '685': 'hicexplorer_hiccorrectmatrix',
#  '686': 'combine_metaphlan2_humann2',
#  '687': 'deeptools_plot_correlation',
#  '688': 'mothur_unique_seqs',
#  '689': 'locarna_best_subtree',
#  '690': 'raceid_inspectclusters',
#  '691': 'flanking_features_1',
#  '692': 'bedtools_subtractbed',
#  '693': 'bedtools_bedtobam',
#  '694': 'EMBOSS: tranalign100',
#  '695': 'fraggenescan',
#  '696': 'snpEff_download',
#  '697': 'EMBOSS: fuzztran39',
#  '698': 'minfi_getanno',
#  '699': 'make_families',
#  '700': 'mass_spectrometry_imaging_classification',
#  '701': 'idpquery',
#  '702': 'IDFileConverter',
#  '703': 'deeptools_bigwig_compare',
#  '704': 'EMBOSS: revseq82',
#  '705': 'spades',
#  '706': '__MERGE_COLLECTION__',
#  '707': 'tp_find_and_replace',
#  '708': 'ctb_remSmall',
#  '709': 'minfi_qc',
#  '710': 'hcluster_sg',
#  '711': 'viennarna_rnaalifold',
#  '712': 'mothur_parsimony',
#  '713': 'bismark_bowtie',
#  '714': 'metaphlan2krona',
#  '715': 'dexseq_count',
#  '716': 'comp1',
#  '717': 'rna_star',
#  '718': 'sort1',
#  '719': 'tp_split_on_column',
#  '720': 'samtools_flagstat',
#  '721': 'gops_concat_1',
#  '722': 'w4mcorcov',
#  '723': 'rnbeads',
#  '724': 'FeatureFinderCentroided',
#  '725': 'infernal_cmbuild',
#  '726': 'varscan',
#  '727': 'nn_classifier',
#  '728': 'cardinal_mz_images',
#  '729': 'picard_MarkDuplicates',
#  '730': 'hisat',
#  '731': 'minfi_dmr',
#  '732': 'mothur_make_shared',
#  '733': 'format_metaphlan2_output',
#  '734': 'ggplot2_histogram',
#  '735': 'silac_analyzer',
#  '736': 'cuffdiff',
#  '737': 'samtools_calmd',
#  '738': 'mothur_remove_groups',
#  '739': 'nspdk_sparse',
#  '740': 'snippy',
#  '741': 'cshl_fastx_renamer',
#  '742': 'qiime_pick_otus',
#  '743': 'term_id_vs_term_def',
#  '744': 'bedtools_annotatebed',
#  '745': 'freebayes',
#  '746': 'deeptools_computeGCBias',
#  '747': 'varscan_somatic',
#  '748': 'tp_awk_tool',
#  '749': 'hicexplorer_hicpca',
#  '750': 'graphlan',
#  '751': 'methtools_plot',
#  '752': 'cshl_fastx_trimmer',
#  '753': 'vcf2tsv',
#  '754': 'megablast_wrapper',
#  '755': 'sample_seqs',
#  '756': 'join_files_on_column_fuzzy',
#  '757': 'allele_counts_1',
#  '758': 'smf_utils_find-boxes',
#  '759': 'gemini_db_info',
#  '760': 'gatk2_unified_genotyper',
#  '761': 'Multivariate',
#  '762': 'ctb_chemfp_mol2fps',
#  '763': 'deeptools_bigwigCompare',
#  '764': 'gatk2_print_reads',
#  '765': 'find_in_reference',
#  '766': 'Fetch Taxonomic Ranks',
#  '767': 'heatmap2',
#  '768': '__FLATTEN__',
#  '769': 'wolf_psort',
#  '770': '__FILTER_FAILED_DATASETS__',
#  '771': 'bamCompare_deepTools',
#  '772': 'picard_CollectInsertSizeMetrics',
#  '773': 'sam2interval',
#  '774': 'heinz_scoring',
#  '775': 'mothur_make_biom',
#  '776': 'snpSift_dbnsfp_generic',
#  '777': 'trim_reads',
#  '778': 'Count1',
#  '779': 'ncbi_blastp_wrapper',
#  '780': 'scale_image',
#  '781': 'proteomics_search_tandem_1',
#  '782': 'gatk2_realigner_target_creator',
#  '783': 'seq_filter_by_mapping',
#  '784': 'deeptools_multi_bigwig_summary',
#  '785': 'samtool_filter2',
#  '786': 'ctb_ob_genProp',
#  '787': 'flexbar_no_split',
#  '788': 'table_annovar',
#  '789': 'ChooseTag',
#  '790': 'picard_ValidateSamFile',
#  '791': 'sklearn_feature_selection',
#  '792': 'smf_utils_extract-boxed-sequences',
#  '793': 'cufflinks_prok',
#  '794': 'xpath',
#  '795': 'mass_spectrometry_imaging_segmentations',
#  '796': 'fastq_paired_end_joiner',
#  '797': 'cardinal_data_exporter',
#  '798': 'jbrowse',
#  '799': 'ProteinInference',
#  '800': 'picard_FilterSamReads',
#  '801': 'hicexplorer_hicmergematrixbins',
#  '802': 'snpSift_geneSets',
#  '803': 'meme_meme',
#  '804': 'openms_id_file_converter',
#  '805': 'IDMassAccuracy',
#  '806': 'minfi_dropsnp',
#  '807': 'ProteinQuantifier',
#  '808': 'computeMatrix',
#  '809': '__UNZIP_COLLECTION__',
#  '810': 'tab2fasta',
#  '811': 'raceid_trajectory',
#  '812': 'filter_by_fasta_ids',
#  '813': 'transpose',
#  '814': 'melt',
#  '815': 'MapRTTransformer',
#  '816': 'raceid_inspecttrajectory',
#  '817': 'rarefaction_analyzer',
#  '818': 'rbc_splitfasta',
#  '819': 'chipsequtil_maptoknowngenes',
#  '820': 'heatmapper',
#  '821': 'rnafold',
#  '822': 'bam2wig',
#  '823': 'mergeCols1',
#  '824': 'samtools_slice_bam',
#  '825': 'cshl_fastx_barcode_splitter',
#  '826': 'Extract genomic DNA 1',
#  '827': 'regex1',
#  '828': 'rseqc_bam_stat',
#  '829': 'cshl_fastx_nucleotides_distribution',
#  '830': 'gff_filter_by_attribute',
#  '831': 'deeptools_bam_compare',
#  '832': 't_coffee',
#  '833': 'deeptools_bamCorrelate',
#  '834': 'CONVERTER_gff_to_bed_0',
#  '835': 'kraken-report',
#  '836': 'column_remove_by_header',
#  '837': 'bg_protein_properties',
#  '838': 'cshl_awk_tool',
#  '839': 'dbbuilder',
#  '840': 'Extract_RNA_seq_Evidence',
#  '841': 'tophat_fusion_post',
#  '842': 'iuc_pear',
#  '843': 'bctools_remove_tail',
#  '844': 'tp_uniq_tool',
#  '845': 'MSGFPlusAdapter',
#  '846': 'genbank_to_gff',
#  '847': 'hisat2',
#  '848': 'predict_pipeline',
#  '849': 'rm_spurious_events.py',
#  '850': 'mass_spectrometry_imaging_preprocessing',
#  '851': 'disco',
#  '852': 'bed_to_bigwig',
#  '853': 'maldi_quant_peak_detection',
#  '854': 'TextExporter',
#  '855': 'deeptools_bamFingerprint',
#  '856': 'picard_MarkDuplicatesWithMateCigar',
#  '857': 'CONVERTER_gz_to_uncompressed',
#  '858': 'CometAdapter',
#  '859': 'velvet',
#  '860': 'sam_to_bam',
#  '861': 'goenrichment',
#  '862': 'humann2',
#  '863': 'cshl_fastx_collapser',
#  '864': 'mothur_sub_sample',
#  '865': 'tp_sed_tool',
#  '866': 'cardinal_quality_report',
#  '867': 'gatk_realigner_target_creator',
#  '868': '__ZIP_COLLECTION__',
#  '869': 'FeatureLinkerUnlabeled',
#  '870': 'picard_CleanSam',
#  '871': 'Cut1',
#  '872': 'snpEff',
#  '873': 'cshl_cut_tool',
#  '874': 'EMBOSS: water107',
#  '875': 'porechop',
#  '876': 'vcfsort',
#  '877': 'locarna_multiple',
#  '878': 'abims_xcms_summary',
#  '879': 'mz_to_sqlite',
#  '880': 'ctb_change_title',
#  '881': 'gafa',
#  '882': 'bedtools_windowbed',
#  '883': 'GeneModelMapper',
#  '884': 'hicexplorer_hicfindtads',
#  '885': 'wc_gnu',
#  '886': 'megablast_xml_parser',
#  '887': '__FILTER_FROM_FILE__',
#  '888': 'mimodd_varreport',
#  '889': 'FileMerger',
#  '890': 'remove_tail.py',
#  '891': 'FileFilter',
#  '892': 'minfi_rset',
#  '893': 'mothur_venn',
#  '894': 'hgv_david',
#  '895': 'msconvert_nix',
#  '896': 'flye',
#  '897': 'humann2_regroup_table',
#  '898': 'bedtools_slopbed',
#  '899': 'cardinal_segmentations',
#  '900': 'velvetoptimiser',
#  '901': 'sed_stream_editor',
#  '902': 'cshl_multijoin',
#  '903': 'snippy_core',
#  '904': 'selectsequencesfrommsa',
#  '905': 'meme_chip',
#  '906': 'preproc',
#  '907': 'sklearn_numeric_clustering',
#  '908': 'FidoAdapter',
#  '909': 'fasta_filter_by_length',
#  '910': 'fastq_groomer',
#  '911': 'mycrobiota-qc-report',
#  '912': 'CONVERTER_interval_to_bedstrict_0',
#  '913': 'deeptools_plot_coverage',
#  '914': 'CONVERTER_gff_to_interval_index_0',
#  '915': 'EMBOSS: shuffleseq87',
#  '916': '__SORTLIST__',
#  '917': 'cshl_fastx_reverse_complement',
#  '918': 'peakachu',
#  '919': 'sklearn_searchcv',
#  '920': 'je_markdupes',
#  '921': 'bwa_mem',
#  '922': 'viennarna_rnafold',
#  '923': 'fasta-stats',
#  '924': 'bandage_image',
#  '925': 'vcfannotate',
#  '926': 'export2graphlan',
#  '927': 'tmhmm2',
#  '928': 'XY_Plot_1',
#  '929': 'svm_classifier',
#  '930': 'annotateMyIDs',
#  '931': 'Draw_phylogram',
#  '932': 'mothur_chimera_vsearch',
#  '933': 'deeptools_compute_gc_bias',
#  '934': 'flexbar_split_RR_bcs',
#  '935': 'barchart_gnuplot',
#  '936': 'umi_tools_dedup',
#  '937': 'DatamashOps',
#  '938': 'rmcontamination',
#  '939': 'qiime_validate_mapping_file',
#  '940': 'velvetg_jgi',
#  '941': 'react_cal_pipeline',
#  '942': 'gops_subtract_1',
#  '943': 'vsearch_dereplication',
#  '944': 'picard_AddOrReplaceReadGroups',
#  '945': 'limma_voom',
#  '946': 'macs2_bdgcmp',
#  '947': 'FROGS_preprocess',
#  '948': 'biosigner',
#  '949': 'gemini_load',
#  '950': 'deeptools_plot_pca',
#  '951': 'viz_overlay_moving_and_fixed_image',
#  '952': 'wig_to_bigWig',
#  '953': 'meme_psp_gen',
#  '954': 'get_child_terms',
#  '955': 'hicexplorer_hicplottads',
#  '956': 'EMBOSS: getorf42',
#  '957': 'FROGS_affiliation_OTU',
#  '958': 'graphicsmagick_image_convert',
#  '959': 'trimmer',
#  '960': 'samtools_mpileup',
#  '961': 'DatamashTranspose',
#  '962': 'IDMerger',
#  '963': 'picard_SortSam',
#  '964': 'fastqc',
#  '965': 'seq_composition',
#  '966': 'roary',
#  '967': 'FeatureLinkerUnlabeledQT',
#  '968': 'smf_utils_filter-by-energy',
#  '969': 'gops_join_1',
#  '970': 'deseq2',
#  '971': 'map_peptides_to_bed'}

# %%
def verify_model(model, tool_sequence, labels, dictionary, reverse_dictionary, compatible_tools, topk=20, max_seq_len=25):
    tl_seq = tool_sequence.split(",")
    last_tool_name = reverse_dictionary[str(tl_seq[-1])]
    last_compatible_tools = compatible_tools[last_tool_name]
    sample = np.zeros(max_seq_len)
    for idx, tool_id in enumerate(tl_seq):
        sample[idx] = int(tool_id)
    sample_reshaped = np.reshape(sample, (1, max_seq_len))
    
    tool_sequence_names = [reverse_dictionary[str(tool_pos)] for tool_pos in tool_sequence.split(",")]
    print("Tool seq: %s" % ",".join(tool_sequence_names))
    # predict next tools for a test path
    prediction = model.predict(sample_reshaped, verbose=0)
    prediction = np.reshape(prediction, (prediction.shape[1],))
    prediction_pos = np.argsort(prediction, axis=-1)

    # get topk prediction
    topk_prediction_pos = prediction_pos[-topk:]
    topk_prediction_val = [np.round(prediction[pos] * 100, 2) for pos in topk_prediction_pos]

    # read tool names using reverse dictionary
    pred_tool_ids = [reverse_dictionary[str(tool_pos)] for tool_pos in topk_prediction_pos]
    actual_next_tool_ids = list(set(pred_tool_ids).intersection(set(last_compatible_tools.split(","))))      

    print()
    pred_tool_ids_sorted = dict()
    for (tool_pos, tool_pred_val) in zip(topk_prediction_pos, topk_prediction_val):
        tool_name = reverse_dictionary[str(tool_pos)]
        if tool_name in actual_next_tool_ids:
            pred_tool_ids_sorted[tool_name] = tool_pred_val
    pred_tool_ids_sorted = dict(sorted(pred_tool_ids_sorted.items(), key=lambda kv: kv[1], reverse=True))
    
    cls_wt = dict()
    usg_wt = dict()
    inv_wt = dict()
    ids_tools = dict()
    keys = list(pred_tool_ids_sorted.keys())
    for k in keys:
        try:
            cls_wt[k] = np.round(class_weights[str(data_dict[k])], 2)
            usg_wt[k] = np.round(usage_weights[k], 2)
            inv_wt[k] = np.round(inverted_weights[str(data_dict[k])], 2)
        except:
            continue
    print("Predicted tools: \n")
    print(pred_tool_ids_sorted)
    print()
    print("Class weights: \n")
    cls_wt = dict(sorted(cls_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(cls_wt)
    print()
    print("Usage weights: \n")
    usg_wt = dict(sorted(usg_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(usg_wt)
    print()
    total_usage_wt = np.mean(list(usg_wt.values()))
    print("Mean usage wt: %0.4f" % (total_usage_wt))
    print()
    print("Inverted weights: \n")
    inv_wt = dict(sorted(inv_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(inv_wt)
    for key in pred_tool_ids_sorted:
        ids_tools[key] = dictionary[key]
    print()
    print("Tool ids")
    print(ids_tools)
    print("======================================")
    return cls_wt, usg_wt, inv_wt, pred_tool_ids_sorted

topk = 20
tool_seq = "787" # ,875,223,17
class_wt, usage_wt, inverse_wt, pred_tools = verify_model(model, tool_seq, "", dictionary, reverse_dictionary, compatibile_tools, topk)
# Out:
# Tool seq: flexbar_no_split
#
# Predicted tools:
#
# {'rna_star': 0.64}
#
# Class weights:
#
# {'rna_star': 649.64}
#
# Usage weights:
#
# {'rna_star': 642.15}
#
# Mean usage wt: 642.1500
#
# Inverted weights:
#
# {'rna_star': 1789.08}
#
# Tool ids
# {'rna_star': 717}
# ======================================

# %%
list_cls_wt = list()
list_usage_wt = list()
list_pred_wt = list()
list_inv_wt = list()
division_pt = int(len(pred_tools) / 2)

for tool in pred_tools:
    list_pred_wt.append(pred_tools[tool])
    #try:
    list_inv_wt.append(inverse_wt[tool])
    list_usage_wt.append(usage_wt[tool])
    #except:
    #list_inv_wt.append(1)

def plot_scatter(y_val, title, xlabel, ylabel):
    x_val = range(1, len(y_val) + 1)
    plt.figure(figsize=(8, 8))
    plt.plot(x_val[:division_pt], y_val[:division_pt], 'ro')
    plt.plot(x_val[division_pt:], y_val[division_pt:], 'b^')
    plt.xlabel(xlabel, size=size_label)
    plt.ylabel(ylabel, size=size_label)
    plt.legend([("First top-%s" % str(division_pt)), ("Next top-%s" % str(division_pt))])
    plt.title(title, size=size_title)
    plt.grid(True)
    plt.show()

plot_scatter(list_usage_wt, "Usage weights for tools", "Number of tools", "Class weights")
#plot_scatter(ave_prediction_weights, ave_usage_weights, "Prediction vs usage weights", "Prediction scores", "Usage weights")
#plot_scatter(ave_prediction_weights, ave_inverted_weights, "Prediction vs inverted weights", "Prediction scores", "Inverted weights")
