# %%
import numpy as np
import json
import warnings
import operator

import h5py
from keras.models import model_from_json
from keras import backend as K

from matplotlib import pyplot as plt

warnings.filterwarnings("ignore")

size_title = 18
size_label = 14
n_pred = 2

base_path = "data/remote_inverted_freq_normalized/"

path_data_dict = base_path + "data_dict.txt"
path_inverted_wt = base_path + "inverted_weights.txt"
path_usage_wt = base_path + "usage_prediction.txt"
path_class_wt = base_path + "class_weights.txt"
path_test_data = base_path + "test_paths_dict.txt"
model_path = base_path + "trained_model.hdf5"

def read_file(file_path):
    with open(file_path, 'r') as data_file:
        data = json.loads(data_file.read())
    return data

class_weights = read_file(path_class_wt)
usage_weights = read_file(path_usage_wt)
inverted_weights = read_file(path_inverted_wt)
data_dict = read_file(path_data_dict)

def create_model(model_path):
    trained_model = h5py.File(model_path, 'r')
    model_config = json.loads(trained_model.get('model_config').value)
    loaded_model = model_from_json(model_config)
    dictionary = json.loads(trained_model.get('data_dictionary').value)
    compatibile_tools = json.loads(trained_model.get('compatible_tools').value)
    reverse_dictionary = dict((str(v), k) for k, v in dictionary.items())
    model_weights = list()
    weight_ctr = 0
    while True:
        try:
            d_key = "weight_" + str(weight_ctr)
            weights = trained_model.get(d_key).value
            model_weights.append(weights)
            weight_ctr += 1
        except Exception as exception:
            break
    # set the model weights
    loaded_model.set_weights(model_weights)
    return loaded_model, dictionary, reverse_dictionary, compatibile_tools

model, dictionary, reverse_dictionary, compatibile_tools = create_model(model_path)
# Out:
# Using TensorFlow backend.

# %%
reverse_dictionary
# Out:
# {'1': 'stacks_populations',
#  '2': 'mimodd_varextract',
#  '3': 'gatk2_variant_apply_recalibration',
#  '4': 'seq_filter_by_mapping',
#  '5': 'trimmer',
#  '6': 'htseq-count',
#  '7': 'join1',
#  '8': 'fastq_manipulation',
#  '9': 'sklear_numeric_clustering',
#  '10': 'seurat',
#  '11': 'quast',
#  '12': 'wig_to_bigWig',
#  '13': 'ctb_remSmall',
#  '14': 'mothur_remove_groups',
#  '15': 'sequence_content_trimmer',
#  '16': 'bcftools_view',
#  '17': 'get_read_pipeline',
#  '18': 'mothur_remove_seqs',
#  '19': 'vcffixup',
#  '20': 'gd_raxml',
#  '21': 'meme_chip',
#  '22': 'vcf2tsv',
#  '23': 'mothur_classify_otu',
#  '24': '__APPLY_RULES__',
#  '25': 'sklearn_searchcv',
#  '26': 'ctb_chemfp_mol2fps',
#  '27': 'ChangeCase',
#  '28': 'deeptools_multi_bam_summary',
#  '29': 'secretbt2test',
#  '30': 'pieplots_macs',
#  '31': 'cardinal_mz_images',
#  '32': 'CONVERTER_fastqgz_to_fastq',
#  '33': 'lfq_protein_quant',
#  '34': 'smooth_running_window',
#  '35': 'column_remove_by_header',
#  '36': 'get_flanks1',
#  '37': 'comp1',
#  '38': 'mothur_pre_cluster',
#  '39': 'goslimmer',
#  '40': 'velvetoptimiser',
#  '41': 'picard_SamToFastq',
#  '42': 'prokaryotic_ncbi_submission',
#  '43': 'dexseq_annotate',
#  '44': 'tp_replace_in_line',
#  '45': 'join_files_on_column_fuzzy',
#  '46': 'mothur_phylotype',
#  '47': 'pileometh',
#  '48': 'tmhmm2',
#  '49': 'msgfplus',
#  '50': 'Count1',
#  '51': 'viz_overlay_moving_and_fixed_image',
#  '52': 'cardinal_data_exporter',
#  '53': 'CONVERTER_interval_to_bgzip_0',
#  '54': 'ncbi_blastp_wrapper',
#  '55': 'gops_concat_1',
#  '56': 't_coffee',
#  '57': 'gtf_filter_by_attribute_values_list',
#  '58': 'CONVERTER_fasta_to_tabular',
#  '59': 'cat1',
#  '60': 'HighResPrecursorMassCorrector',
#  '61': 'search_gui',
#  '62': 'hmmer_hmmbuild',
#  '63': 'gemini_comp_hets',
#  '64': 'minfi_getanno',
#  '65': 'ggplot2_heatmap',
#  '66': 'ctb_silicos_qed',
#  '67': 'proteomics_search_peptide_prophet_1',
#  '68': 'EMBOSS: fuzzpro38',
#  '69': 'IsobaricAnalyzer',
#  '70': 'mothur_taxonomy_to_krona',
#  '71': 'unipept',
#  '72': 'FalseDiscoveryRate',
#  '73': 'velvet',
#  '74': 'nanopolish_variants',
#  '75': 'mothur_pcoa',
#  '76': 'dbbuilder',
#  '77': 'macs2_bdgcmp',
#  '78': 'cshl_find_and_replace',
#  '79': 'SequenceCoverageCalculator',
#  '80': 'deeptools_correct_gc_bias',
#  '81': 'snpfinder',
#  '82': 'EMBOSS: water107',
#  '83': 'deeptools_bamFingerprint',
#  '84': 'correct_barcodes',
#  '85': 'gatk2_base_recalibrator',
#  '86': 'heinz',
#  '87': 'gemini_recessive_and_dominant',
#  '88': 'trimmomatic',
#  '89': 'TrimByN',
#  '90': 'vcftools_isec',
#  '91': 'qiime_align_seqs',
#  '92': 'umi_tools_count',
#  '93': 'cuffnorm',
#  '94': 'fastq_trimmer',
#  '95': 'qiime_split_libraries_fastq',
#  '96': 'sqlite_to_tabular',
#  '97': 'dt_profiler',
#  '98': 'fastq_to_fasta_python',
#  '99': 'vcfbedintersect',
#  '100': 'picard_MarkDuplicatesWithMateCigar',
#  '101': 'scpipe',
#  '102': 'htseq_count',
#  '103': 'ggplot_point',
#  '104': 'stringtie',
#  '105': 'mothur_count_groups',
#  '106': 'bedtools_intersectbed_bam',
#  '107': 'wolf_psort',
#  '108': 'mothur_dist_shared',
#  '109': 'snpSift_filter',
#  '110': 'openms_id_mapper',
#  '111': 'ete_homology_classifier',
#  '112': 'silac_analyzer',
#  '113': 'picard_SortSam',
#  '114': 'bcftools_call',
#  '115': 'Flash',
#  '116': 'ia_coordinates_of_roi',
#  '117': 'tp_head_tool',
#  '118': 'cshl_fastq_quality_boxplot',
#  '119': 'secure_hash_message_digest',
#  '120': 'deeptools_plot_profile',
#  '121': 'MapRTTransformer',
#  '122': 'mothur_filter_seqs',
#  '123': 'qiime_make_phylogeny',
#  '124': 'p_clip_peaks',
#  '125': 'samtools_stats',
#  '126': 'idpquery',
#  '127': 'filter_bed_on_splice_junctions',
#  '128': 'annotateMyIDs',
#  '129': 'mothur_make_group',
#  '130': 'plotly_regression_performance_plots',
#  '131': 'cshl_cut_tool',
#  '132': 'sailfish',
#  '133': 'hicexplorer_hicfindtads',
#  '134': 'blast2go',
#  '135': 'sklearn_feature_selection',
#  '136': 'tp_split_on_column',
#  '137': 'EMBOSS: fuzztran39',
#  '138': 'extract_bcs.py',
#  '139': 'hgv_snpFreq',
#  '140': 'Interval_Maf_Merged_Fasta2',
#  '141': 'rm_spurious_events.py',
#  '142': 'sample_seqs',
#  '143': 'plotly_parallel_coordinates_plot',
#  '144': 'allele_counts_1',
#  '145': 'minfi_dmr',
#  '146': 'idpassemble',
#  '147': 'mass_spectrometry_imaging_preprocessing',
#  '148': 'stacks_procrad',
#  '149': 'stringtie_merge',
#  '150': 'picard_ReorderSam',
#  '151': 'gatk_unified_genotyper',
#  '152': 'resistome_analyzer',
#  '153': 'cshl_awk_tool',
#  '154': 'regex_replace',
#  '155': 'cmFinder',
#  '156': 'sickle',
#  '157': 'mass_spectrometry_imaging_classification',
#  '158': 'pileup_interval',
#  '159': 'rbc_splitfasta',
#  '160': 'umi_tools_group',
#  '161': 'mothur_homova',
#  '162': 'ncbi_makeblastdb',
#  '163': 'filtlong',
#  '164': 'treebest_best',
#  '165': 'minfi_dmp',
#  '166': 'clustalw',
#  '167': 'Convert characters1',
#  '168': 'w4mjoinpn',
#  '169': 'picard_CASM',
#  '170': 'MAF_To_Fasta1',
#  '171': 'RNAlien',
#  '172': 'antismash',
#  '173': 'deeptools_computeMatrix',
#  '174': 'gspan',
#  '175': 'Draw_phylogram',
#  '176': 'CONVERTER_interval_to_bed_0',
#  '177': 'ctb_online_data_fetch',
#  '178': 'deeptools_profiler',
#  '179': 'gtftobed12',
#  '180': 'mothur_rarefaction_single',
#  '181': 'bedtools_bamtobed',
#  '182': 'cardinal_filtering',
#  '183': 'mothur_get_groups',
#  '184': 'maldi_quant_preprocessing',
#  '185': 'rbc_rnacode',
#  '186': 'raceid_filtnormconf',
#  '187': 'je_markdupes',
#  '188': 'ProteinInference',
#  '189': 'hicexplorer_hicsummatrices',
#  '190': 'cast',
#  '191': 'smf_utils_extract-boxed-sequences',
#  '192': 'createInterval',
#  '193': 'abims_xcms_xcmsSet',
#  '194': 'uniprot',
#  '195': 'hmmer_hmmsearch',
#  '196': 'Extract genomic DNA 1',
#  '197': 'peptide_shaker',
#  '198': 'tp_text_file_with_recurring_lines',
#  '199': 'bismark_bowtie2',
#  '200': 'abricate',
#  '201': 'mothur_summary_seqs',
#  '202': 'paralyzer',
#  '203': 'vcfselectsamples',
#  '204': 'MapStatistics',
#  '205': 'Psortb',
#  '206': 'picard_MarkDuplicates',
#  '207': 'heinz_bum',
#  '208': 'sam_pileup',
#  '209': 'cshl_sort_header',
#  '210': 'bed_to_bigBed',
#  '211': 'gff_filter_by_attribute',
#  '212': 'cuffquant',
#  '213': 'bedtools_bamtofastq',
#  '214': 'heatmapper_deepTools',
#  '215': 'gops_intersect_1',
#  '216': 'bamCoverage_deepTools',
#  '217': 'pilon',
#  '218': 'mass_spectrometry_imaging_ion_images',
#  '219': 'samtools_bedcov',
#  '220': 'format_metaphlan2_output',
#  '221': 'gatk2_depth_of_coverage',
#  '222': 'cshl_fastq_quality_filter',
#  '223': 'vcfgenotypes',
#  '224': 'signalp3',
#  '225': 'rseqc_bam_stat',
#  '226': 'FileMerger',
#  '227': 'DatamashTranspose',
#  '228': 'translate_bed_sequences',
#  '229': 'egsea',
#  '230': 'snpSift_annotate',
#  '231': 'tp_sorted_uniq',
#  '232': 'stacks_genotypes',
#  '233': 'mothur_unique_seqs',
#  '234': 'export2graphlan',
#  '235': 'megablast_xml_parser',
#  '236': 'roary',
#  '237': 'cshl_easyjoin',
#  '238': 'graphclust_align_cluster',
#  '239': 'hicexplorer_hicplotmatrix',
#  '240': 'fastq_dump',
#  '241': 'methtools_filter',
#  '242': 'eden_sequence_converter',
#  '243': 'trim_reads',
#  '244': 'peakcalling_macs14',
#  '245': 'deeptools_multi_bigwig_summary',
#  '246': 'peakachu',
#  '247': 'CONVERTER_sam_to_unsorted_bam',
#  '248': 'idr-embl',
#  '249': 'bam-filter',
#  '250': 'ggplot2_histogram',
#  '251': 'circgraph',
#  '252': 'picard_CleanSam',
#  '253': 'bctools_extract_alignment_ends',
#  '254': 'scaffold2fasta',
#  '255': 'aggregate_scores_in_intervals2',
#  '256': 'bg_diamond',
#  '257': 'snippy_core',
#  '258': 'bctools_remove_tail',
#  '259': 'samtools_idxstats',
#  '260': 'PeakPickerHiRes',
#  '261': 'CONVERTER_gz_to_uncompressed',
#  '262': 'rgPicFixMate',
#  '263': 'xpath',
#  '264': 'sam_bw_filter',
#  '265': 'deeptools_plot_pca',
#  '266': 'minfi_maptogenome',
#  '267': 'msconvert2_raw',
#  '268': 'mothur_trim_seqs',
#  '269': 'DatamashOps',
#  '270': 'eukaryotic_ncbi_submission',
#  '271': 'Determine_BC',
#  '272': 'rsem_prepare_reference',
#  '273': 'IDMapper',
#  '274': 'XY_Plot_1',
#  '275': 'Paste1',
#  '276': 'IDMerger',
#  '277': 'deeptools_plot_enrichment',
#  '278': 'Btrim64',
#  '279': 'cshl_fastx_barcode_splitter',
#  '280': 'ctb_simsearch',
#  '281': 'cufflinks_prok',
#  '282': 'cummeRbund',
#  '283': 'sort1',
#  '284': 'mothur_tree_shared',
#  '285': 'interproscan',
#  '286': 'flexbar_split_RYYR_bcs',
#  '287': 'bedtools_slopbed',
#  '288': 'mass_spectrometry_imaging_mzplots',
#  '289': 'rseqc_bam2wig',
#  '290': 'kraken-translate',
#  '291': 'gemini_pathways',
#  '292': 'Filter1',
#  '293': 'fasplit',
#  '294': '16Sclassifier',
#  '295': 'abims_xcms_summary',
#  '296': 'krona-text',
#  '297': 'seq_filter_by_id',
#  '298': 'addName',
#  '299': 'vt_normalize',
#  '300': 'gbk_to_orf',
#  '301': 'FROGS_clustering',
#  '302': 'picard_FixMateInformation',
#  '303': 'svm_classifier',
#  '304': 'deg_annotate',
#  '305': 'abims_xcms_group',
#  '306': 'mothur_amova',
#  '307': '16Saligner',
#  '308': 'vcftools_merge',
#  '309': 'vcfannotate',
#  '310': 'ucsc-twobittofa',
#  '311': 'samtools_calmd',
#  '312': 'gops_cluster_1',
#  '313': 'combine_metaphlan2_humann2',
#  '314': 'cshl_princeton_fastx_barcode_splitter',
#  '315': 'bedtools_shufflebed',
#  '316': 'gmx_md',
#  '317': 'numeric_clustering',
#  '318': 'fragmenter',
#  '319': 'gatk2_indel_realigner',
#  '320': 'gmx_setup',
#  '321': 'minfi_getbeta',
#  '322': 'vcfcombine',
#  '323': 'vcfflatten2',
#  '324': 'ProteinResolver',
#  '325': 'tophat',
#  '326': 'porechop',
#  '327': 'tp_sort_rows',
#  '328': 'samtools_slice_bam',
#  '329': 'featurecounts',
#  '330': 'charts',
#  '331': 'Multivariate',
#  '332': 'picard_EstimateLibraryComplexity',
#  '333': 'heatmap2',
#  '334': 'length_and_gc_content',
#  '335': 'fasta_filter_by_length',
#  '336': 'cshl_uniq_tool',
#  '337': 'openms_id_file_converter',
#  '338': 'muscle',
#  '339': 'CONVERTER_gff_to_interval_index_0',
#  '340': 'Show tail1',
#  '341': 'mothur_nmds',
#  '342': 'minfi_ppfun',
#  '343': 'PeptideIndexer',
#  '344': 'minfi_qc',
#  '345': 'fastq_join',
#  '346': 'deeptools_bigwigCompare',
#  '347': 'computeMatrix',
#  '348': 'hcluster_sg_parser',
#  '349': 'gafa',
#  '350': 'MassCalculator',
#  '351': 'cuffmerge',
#  '352': 'rarefaction',
#  '353': 'infernal_cmsearch',
#  '354': 'EMBOSS: textsearch98',
#  '355': 'deeptools_bam_coverage',
#  '356': 'eden_vectorizer',
#  '357': 'goenrichment',
#  '358': 'glimmer_build-icm',
#  '359': 'cummerbund_to_cuffdiff',
#  '360': 'hisat',
#  '361': 'get_child_terms',
#  '362': 'deeptools_compute_gc_bias',
#  '363': 'valet',
#  '364': 'mothur_cluster',
#  '365': 'mycrobiota-krona-mothur',
#  '366': 'minfi_rset',
#  '367': 'mothur_remove_lineage',
#  '368': 'hicexplorer_hicplottads',
#  '369': 'Extract_features1',
#  '370': 'rnafold',
#  '371': 'kraken-report',
#  '372': 'tp_cut_tool',
#  '373': 'EMBOSS: shuffleseq87',
#  '374': 'mothur_get_seqs',
#  '375': 'heatmapper',
#  '376': 'gemini_burden',
#  '377': 'vcfsort',
#  '378': 'taxonomy_krona_chart',
#  '379': 'gemini_interactions',
#  '380': 'FeatureLinkerUnlabeledQT',
#  '381': 'hicexplorer_hicpca',
#  '382': 'react_cal_pipeline',
#  '383': 'EMBOSS: seqret84',
#  '384': 'gatk2_variant_recalibrator',
#  '385': 'je_demultiplex',
#  '386': 'FidoAdapter',
#  '387': 'raceid_main',
#  '388': 'Summary_Statistics1',
#  '389': 'ssake',
#  '390': '__FILTER_FROM_FILE__',
#  '391': 'tp_find_and_replace',
#  '392': 'meme_psp_gen',
#  '393': 'fastq_to_tabular',
#  '394': 'prokka',
#  '395': 'picard_BamIndexStats',
#  '396': 'mlocarna',
#  '397': 'dunovo',
#  '398': 'varscan_somatic',
#  '399': 'stacks_denovomap',
#  '400': 'transpose',
#  '401': 'extract_aln_ends.py',
#  '402': 'bam_to_bigwig',
#  '403': 'Datamash',
#  '404': 'bcftools_norm',
#  '405': 'snpSift_dbnsfp_generic',
#  '406': 'sklearn_ensemble',
#  '407': 'FROGS_remove_chimera',
#  '408': 'jbrowse',
#  '409': 'multiqc',
#  '410': 'gatk2_variant_annotator',
#  '411': 'EMBOSS: transeq101',
#  '412': 'cshl_fasta_formatter',
#  '413': 'bismark_bowtie',
#  '414': 'bctools_remove_spurious_events',
#  '415': 'deeptools_correctGCBias',
#  '416': 'bedtools_genomecoveragebed',
#  '417': 'gatk_indel_realigner',
#  '418': 'tp_multijoin_tool',
#  '419': 'ConsensusID',
#  '420': 'mothur_make_shared',
#  '421': 'TextExporter',
#  '422': 'MapAlignerPoseClustering',
#  '423': 'mothur_merge_files',
#  '424': 'mothur_seq_error',
#  '425': 'TrimByLength',
#  '426': 'Extractor',
#  '427': 'bam_to_sam',
#  '428': 'Grep1',
#  '429': 'cuffdiff',
#  '430': 'vegan_diversity',
#  '431': 'random_lines1',
#  '432': 'bamtools',
#  '433': 'gmx_em',
#  '434': 'selectsequencesfrommsa',
#  '435': 'sklearn_svm_classifier',
#  '436': 'aragorn_trna',
#  '437': 'PicardInsertSize',
#  '438': 'modencode_peakcalling_spp',
#  '439': 'graphicsmagick_image_convert',
#  '440': 'query_tabular',
#  '441': 'samtools_flagstat',
#  '442': 'rna_star',
#  '443': 'convert_bc_to_binary_RY.py',
#  '444': 'gops_join_1',
#  '445': 'cd_hit_dup',
#  '446': 'XTandemAdapter',
#  '447': 'mothur_make_biom',
#  '448': 'ngsutils_bam_filter',
#  '449': 'cshl_fastq_to_fasta',
#  '450': 'openms_protein_quantifier',
#  '451': 'mothur_screen_seqs',
#  '452': 'bigwig_to_bedgraph',
#  '453': 'FileInfo',
#  '454': 'extract_element_from_collection',
#  '455': 'GeMoMa_Annotation_Filter',
#  '456': 'bedtools_mergebed',
#  '457': 'meme_fimo',
#  '458': 'bwa_wrapper',
#  '459': 'mothur_classify_rf',
#  '460': 'FastTree',
#  '461': 'fasta_compute_length',
#  '462': 'abims_CAMERA_annotateDiffreport',
#  '463': 'hcluster_sg',
#  '464': 'smf_utils_find-boxes',
#  '465': 'coords2clnt.py',
#  '466': 'qiime_pick_otus',
#  '467': 'methtools_tiling',
#  '468': 'tp_sed_tool',
#  '469': 'newick_display',
#  '470': 'igvtools_count',
#  '471': 'maldi_quant_peak_detection',
#  '472': 'deeptools_bam_compare',
#  '473': 'stacks_refmap',
#  '474': 'fastq_paired_end_joiner',
#  '475': 'heinz_visualization',
#  '476': 'gops_merge_1',
#  '477': 'wsdl_hmdb',
#  '478': 'fasta2tab',
#  '479': 'datamash_ops',
#  '480': 'kraken',
#  '481': 'bowtie_wrapper',
#  '482': 'cardinal_quality_report',
#  '483': 'picard_FilterSamReads',
#  '484': 'deeptools_bamCoverage',
#  '485': 'flanking_features_1',
#  '486': 'cshl_awk_replace_in_column',
#  '487': 'mass_spectrometry_imaging_filtering',
#  '488': 'fasta_merge_files_and_filter_unique_sequences',
#  '489': 'rgPicardMarkDups',
#  '490': 'pileup_parser',
#  '491': 'rsem_calculate_expression',
#  '492': 'metaphlan_hclust_heatmap',
#  '493': 'gemini_actionable_mutations',
#  '494': 'merge_pcr_duplicates.py',
#  '495': 'mass_spectrometry_imaging_segmentations',
#  '496': 'GeneModelMapper',
#  '497': 'blast_parser',
#  '498': 'ruvseq',
#  '499': 'tag_stat2',
#  '500': 'umi_tools_extract',
#  '501': 'gemini_query',
#  '502': 'mothur_heatmap_sim',
#  '503': 'QCCalculator',
#  '504': 'minfi_methcpg',
#  '505': 'bamleftalign',
#  '506': 'ncbi_blastx_wrapper',
#  '507': 'bundle_collection',
#  '508': 'graphlan_annotate',
#  '509': 'correctGCBias',
#  '510': 'bamFilter',
#  '511': 'fraggenescan',
#  '512': 'fastq collapser',
#  '513': 'vegan_rarefaction',
#  '514': 'nanoplot',
#  '515': 'qiime_validate_mapping_file',
#  '516': 'bedtools_annotatebed',
#  '517': 'snpEff',
#  '518': 'tp_sort_header_tool',
#  '519': 'picard_NormalizeFasta',
#  '520': 'mothur_get_communitytype',
#  '521': 'blastxml_to_tabular_selectable',
#  '522': 'augustus',
#  '523': 'sam_to_bam',
#  '524': 'NSPDK_candidateClust',
#  '525': 'deeptools_compute_matrix',
#  '526': 'w4mcorcov',
#  '527': 'predict_pipeline',
#  '528': 'ncbi_tblastn_wrapper',
#  '529': 'bgchem_fragment_merger',
#  '530': 'gatk2_unified_genotyper',
#  '531': 'Digestor',
#  '532': 'gatk2_haplotype_caller',
#  '533': 'collection_column_join',
#  '534': 'addValue',
#  '535': 'bandage_image',
#  '536': 'kraken-filter',
#  '537': 'nonpareil',
#  '538': 'sklearn_numeric_clustering',
#  '539': 'pureclip',
#  '540': 'cutadapt',
#  '541': 'meme_meme',
#  '542': 'picard_CollectInsertSizeMetrics',
#  '543': 'preproc',
#  '544': 'mothur_sub_sample',
#  '545': 'sam_merge2',
#  '546': 'fastq_paired_end_interlacer',
#  '547': 'cshl_fastx_quality_statistics',
#  '548': 'plotly_ml_performance_plots',
#  '549': 'bed_to_bigwig',
#  '550': 'wiggle2simple1',
#  '551': 'megablast_wrapper',
#  '552': 'Add_a_column1',
#  '553': 'mothur_venn',
#  '554': 'bedtools_multiintersectbed',
#  '555': 'mycrobiota-make-multi-otutable',
#  '556': 'myrimatch',
#  '557': 'tp_uniq_tool',
#  '558': 'snpEff_download',
#  '559': 'deeptools_plot_heatmap',
#  '560': 'hicexplorer_hictransform',
#  '561': 'EMBOSS: wordcount109',
#  '562': 'gops_basecoverage_1',
#  '563': 'qiime_pick_rep_set',
#  '564': 'limma_voom',
#  '565': 'gemini_windower',
#  '566': 'hicexplorer_hicmergematrixbins',
#  '567': 'minfi_getM',
#  '568': 'viennarna_rnaplot',
#  '569': 'Nucleosome',
#  '570': 'rseqc_geneBody_coverage',
#  '571': 're_he_maldi_image_registration',
#  '572': 'make_families',
#  '573': 'regex1',
#  '574': 'bedtools_bedtobam',
#  '575': 'histogram_rpy',
#  '576': 'get_sequences',
#  '577': 'flexbar_no_split',
#  '578': 'varscan_mpileup',
#  '579': 'Fetch Taxonomic Ranks',
#  '580': 'rmcontamination',
#  '581': 'mycrobiota-correct-replicates',
#  '582': 'blastxml_to_tabular',
#  '583': 'glimmer_not-knowlegde-based',
#  '584': 'deeptools_plot_correlation',
#  '585': 'fasta-stats',
#  '586': 'rseqc_read_distribution',
#  '587': 'IDFileConverter',
#  '588': 'melt',
#  '589': 'FileFilter',
#  '590': 'Cut1',
#  '591': 'ggplot_histogram',
#  '592': 'gtf2bedgraph',
#  '593': 'IDMassAccuracy',
#  '594': 'MSGFPlusAdapter',
#  '595': 'snippy',
#  '596': 'samtools_flag_filter',
#  '597': 'smf_utils_fix-fasta-headers',
#  '598': 'snpeff_to_peptides',
#  '599': 'cardinal_segmentations',
#  '600': 'bg_column_arrange_by_header',
#  '601': 'FeatureLinkerUnlabeled',
#  '602': 'DecoyDatabase',
#  '603': '__FILTER_FAILED_DATASETS__',
#  '604': 'cuffcompare',
#  '605': 'TrimPrimer',
#  '606': 'deeptools_computeGCBias',
#  '607': 'tp_tail_tool',
#  '608': 'deeptools_heatmapper',
#  '609': 'ConsensusMapNormalizer',
#  '610': 'thermo_raw_file_converter',
#  '611': 'hicexplorer_hicbuildmatrix',
#  '612': 'spades',
#  '613': 'bg_find_subsequences',
#  '614': 'EMBOSS: revseq82',
#  '615': 'humann2_regroup_table',
#  '616': 'replace_column_with_key_value_file',
#  '617': 'vsearch_dereplication',
#  '618': 'flye',
#  '619': 'mimodd_map',
#  '620': 'term_id_vs_term_name',
#  '621': 'bamCompare_deepTools',
#  '622': 'ctb_compound_convert',
#  '623': 'Show beginning1',
#  '624': 'gatk2_reduce_reads',
#  '625': 'FeatureFinderCentroided',
#  '626': 'velveth_jgi',
#  '627': 'uparse',
#  '628': 'fastq_filter',
#  '629': 'picard_ValidateSamFile',
#  '630': 'CONVERTER_bed_gff_or_vcf_to_bigwig_0',
#  '631': 'bedtools_coveragebed_counts',
#  '632': 'tsne',
#  '633': 'deeptools_plot_fingerprint',
#  '634': 'varscan',
#  '635': 'gff_to_sequence',
#  '636': 'racon',
#  '637': 'mycrobiota-split-multi-otutable',
#  '638': 'ip_projective_transformation_points',
#  '639': 'transdecoder',
#  '640': 'bedtools_getfastabed',
#  '641': 'vcffilter2',
#  '642': 'dexseq',
#  '643': 'ncbi_rpsblast_wrapper',
#  '644': 'vcftools_annotate',
#  '645': 'tp_grep_tool',
#  '646': 'minimap2',
#  '647': 'hisat2',
#  '648': 'FeatureFinderMetabo',
#  '649': 'w4mclassfilter',
#  '650': 'FROGS_affiliation_OTU',
#  '651': 'metaphlan2krona',
#  '652': 'blastxml_to_top_descr',
#  '653': 'rbc_mirdeep2',
#  '654': 'deeptools_bamCompare',
#  '655': 'Remove beginning1',
#  '656': 'rseqc_inner_distance',
#  '657': 'segemehl',
#  '658': 'checkFormat',
#  '659': 'locarna_best_subtree',
#  '660': 'viennarna_rnaalifold',
#  '661': 'gatk2_variant_filtration',
#  '662': 'samtools_filter',
#  '663': 'gmx_solvate',
#  '664': 'fastq_paired_end_deinterlacer',
#  '665': 'CONVERTER_Bam_Bai_0',
#  '666': 'Remove_ending',
#  '667': 'vcffilter',
#  '668': 'bedtools_windowbed',
#  '669': 'peakcalling_macs',
#  '670': 'edger',
#  '671': 'gene2exon1',
#  '672': 'meme_dreme',
#  '673': 'mass_spectrometry_imaging_qc',
#  '674': 'metaspades',
#  '675': 'hgv_david',
#  '676': 'gemini_load',
#  '677': 'bg_uniq',
#  '678': 'FROGS_preprocess',
#  '679': 'mothur_cluster_split',
#  '680': 'ctb_filter',
#  '681': 'CONVERTER_bed_to_bgzip_0',
#  '682': 'idpqonvert',
#  '683': 'gemini_de_novo',
#  '684': 'tp_awk_tool',
#  '685': 'methtools_dmr',
#  '686': 'FileConverter',
#  '687': '__UNZIP_COLLECTION__',
#  '688': 'minfi_dropsnp',
#  '689': 'seq_composition',
#  '690': 'Univariate',
#  '691': 'iuc_pear',
#  '692': 'unicycler',
#  '693': 'bg_statistical_hypothesis_testing',
#  '694': 'CONVERTER_gff_to_bed_0',
#  '695': 'mothur_chimera_vsearch',
#  '696': 'pynast',
#  '697': 'group_humann2_uniref_abundances_to_go',
#  '698': 'xcms_merge',
#  '699': 'ncbi_blastn_wrapper',
#  '700': 'mothur_get_oturep',
#  '701': 'humann2',
#  '702': 'iReport',
#  '703': 'filter_by_fasta_ids',
#  '704': '__MERGE_COLLECTION__',
#  '705': 'picard_CollectRnaSeqMetrics',
#  '706': 'fasttree',
#  '707': 'bg_protein_properties',
#  '708': 'CONVERTER_bedgraph_to_bigwig',
#  '709': 'graphclust_aggregate_alignments',
#  '710': 'qiime_core_diversity',
#  '711': 'mothur_classify_seqs',
#  '712': 'FROGS_filters',
#  '713': 'gmx_npt',
#  '714': 'tp_easyjoin_tool',
#  '715': 'Heatmap',
#  '716': 'raceid_clustering',
#  '717': 'w4mclstrpeakpics',
#  '718': 'subtract_query1',
#  '719': 'picard_MergeSamFiles',
#  '720': 'uchime',
#  '721': 'IDScoreSwitcher',
#  '722': 'bctools_extract_crosslinked_nucleotides',
#  '723': 'mass_spectrometry_imaging_combine',
#  '724': 'methtools_plot',
#  '725': 'goseq',
#  '726': 'samtools_split',
#  '727': 'bedtools_complementbed',
#  '728': 'lastz_wrapper_2',
#  '729': 'mothur_align_seqs',
#  '730': 'tab2fasta',
#  '731': 'mothur_parsimony',
#  '732': 'qiime_count_seqs',
#  '733': 'rbc_mirdeep2_quantifier',
#  '734': 'FeatureLinkerUnlabeledKD',
#  '735': 'gff2bed1',
#  '736': 'IDPosteriorErrorProbability',
#  '737': 'mergeCols1',
#  '738': 'rseqc_read_duplication',
#  '739': 'MultiplexResolver',
#  '740': 'glob_report',
#  '741': 'cshl_fastx_collapser',
#  '742': 'modencode_peakcalling_macs2',
#  '743': 'ete_genetree_splitter',
#  '744': 'msconvert_nix',
#  '745': 'diffbind-embl',
#  '746': 'raceid_inspectclusters',
#  '747': 'methtools_destrand',
#  '748': 'cufflinks',
#  '749': 'term_id_vs_term_def',
#  '750': 'column_order_header_sort',
#  '751': 'r_correlation_matrix',
#  '752': 'locarna_multiple',
#  '753': 'minfi_read450k',
#  '754': 'rbc_mirdeep2_mapper',
#  '755': 'EMBOSS: tranalign100',
#  '756': 'scale_image',
#  '757': 'varscan_copynumber',
#  '758': 'bedtools_subtractbed',
#  '759': 'ip_projective_transformation',
#  '760': 'vcf2pgSnp',
#  '761': 'samtool_filter2',
#  '762': 'proteomics_moff',
#  '763': 'disco',
#  '764': 'mycrobiota-otutable_add_blast',
#  '765': 'sed_stream_editor',
#  '766': 'sam2interval',
#  '767': 'blockbuster',
#  '768': 'qiime_pick_closed_reference_otus',
#  '769': 'mimodd_varcall',
#  '770': 'deseq2_single',
#  '771': 'Grouping1',
#  '772': 'cor2',
#  '773': 'gops_subtract_1',
#  '774': 'nspdk_sparse',
#  '775': 'mothur_count_seqs',
#  '776': 'decoyfasta',
#  '777': 'mothur_lefse',
#  '778': 'rbc_mafft',
#  '779': 'rarefaction_analyzer',
#  '780': 'velvetg_jgi',
#  '781': 'viennarna_rnafold',
#  '782': 'cshl_grep_tool',
#  '783': 'piranha',
#  '784': 'mothur_summary_single',
#  '785': 'flexbar',
#  '786': 'picard_AddOrReplaceReadGroups',
#  '787': 'smf_utils_filter-by-energy',
#  '788': 'structure_to_gspan',
#  '789': 'align_families',
#  '790': 'shovill',
#  '791': 'bam2wig',
#  '792': 'barchart_gnuplot',
#  '793': 't2t_report',
#  '794': 'flexbar_split_RR_bcs',
#  '795': 'nn_classifier',
#  '796': 'gops_coverage_1',
#  '797': 'fgsea',
#  '798': 'chipsequtil_maptoknowngenes',
#  '799': 'ExtractFASTAfromFASTQ',
#  '800': 'MzTabExporter',
#  '801': 'gatk_depth_of_coverage',
#  '802': 'ctb_change_title',
#  '803': 'mz_to_sqlite',
#  '804': 'mothur_corr_axes',
#  '805': 'ggplot2_heatmap2',
#  '806': 'gatk2_realigner_target_creator',
#  '807': 'fastq_groomer',
#  '808': 'table_annovar',
#  '809': 'bwa_mem',
#  '810': 'picard_CollectWgsMetrics',
#  '811': 'bwameth',
#  '812': 'tp_cat',
#  '813': 'gffread',
#  '814': 'umi_tools_dedup',
#  '815': 'smf_utils_estimate-energy',
#  '816': 'samtools_sort',
#  '817': 'infernal_cmstat',
#  '818': 'mothur_dist_seqs',
#  '819': 'graphlan',
#  '820': 'IDFilter',
#  '821': 'cshl_fastx_nucleotides_distribution',
#  '822': 'CONVERTER_interval_to_bedstrict_0',
#  '823': 'cshl_sed_tool',
#  '824': 'tophat_fusion_post',
#  '825': 'bedtools_genomecoveragebed_bedgraph',
#  '826': 'rgweblogo3',
#  '827': 'mothur_chimera_uchime',
#  '828': 'samtools_rmdup',
#  '829': 'freebayes',
#  '830': 'CometAdapter',
#  '831': 'mothur_metastats',
#  '832': 'mycrobiota-qc-report',
#  '833': 'Extract_RNA_seq_Evidence',
#  '834': 'bedtools_multicovtbed',
#  '835': 'glimmer_knowlegde-based',
#  '836': 'tp_tac',
#  '837': 'map_peptides_to_bed',
#  '838': 'get_subontology_from',
#  '839': 'datamash_transpose',
#  '840': 'qiime_assign_taxonomy',
#  '841': 'PicardASMetrics',
#  '842': 'mimodd_vcf_filter',
#  '843': 'lca1',
#  '844': 'metams_runGC',
#  '845': 'gmx_nvt',
#  '846': 'tophat2',
#  '847': 'ggplot2_point',
#  '848': 'samtools_mpileup',
#  '849': 'gatk_realigner_target_creator',
#  '850': 'cshl_fastx_reverse_complement',
#  '851': 'rcas',
#  '852': 'bcftools_consensus',
#  '853': 'gemini_db_info',
#  '854': 'FeatureFinderMultiplex',
#  '855': 'graphclust_glob_report_no_align',
#  '856': 'hgv_linkToGProfile',
#  '857': 'rnbeads',
#  '858': 'cardinal_preprocessing',
#  '859': 'gffcompare',
#  '860': 'wc_gnu',
#  '861': 'vcfallelicprimitives',
#  '862': 'je_clip',
#  '863': 'remove_tail.py',
#  '864': 'cshl_fastx_clipper',
#  '865': 'genbank_to_gff',
#  '866': 'tabular_to_fastq',
#  '867': 'bedtools_genomecoveragebed_histogram',
#  '868': 'annotatemyids',
#  '869': 'rseqc_infer_experiment',
#  '870': 'CONVERTER_bed_to_gff_0',
#  '871': 'cardinal_spectra_plots',
#  '872': 'macs2_callpeak',
#  '873': 'ctb_remIons',
#  '874': 'gemini_annotate',
#  '875': 'EMBOSS: newseq59',
#  '876': 'dexseq_count',
#  '877': 'NFS_transfer',
#  '878': 'deeptools_bigwig_compare',
#  '879': 'bowtie2',
#  '880': 'cshl_fasta_nucleotides_changer',
#  '881': 'trinity',
#  '882': 'cshl_multijoin',
#  '883': 'infernal_cmbuild',
#  '884': 'blockclust',
#  '885': 'methtools_calling',
#  '886': 'hicexplorer_hiccorrectmatrix',
#  '887': 'picard_ARRG',
#  '888': 'deeptools_bamCorrelate',
#  '889': 'fastq_combiner',
#  '890': 'kallisto_quant',
#  '891': 'ChooseTag',
#  '892': '__SORTLIST__',
#  '893': 'humann2_genefamilies_genus_level',
#  '894': 'CONVERTER_fasta_to_fai',
#  '895': 'EMBOSS: extractseq35',
#  '896': 'get_feature_info',
#  '897': 'collapse_dataset',
#  '898': 'bedtools_coveragebed',
#  '899': 'rseqc_junction_saturation',
#  '900': 'fastq_quality_trimmer',
#  '901': 'tp_replace_in_column',
#  '902': 'qiime_pick_open_reference_otus',
#  '903': 'Batch_correction',
#  '904': 'FROGS_affiliations_stat',
#  '905': 'qiime_make_otu_heatmap',
#  '906': 'msconvert3_raw',
#  '907': 'proteomics_search_tandem_1',
#  '908': 'EMBOSS: geecee41',
#  '909': 'bedtools_intersectbed',
#  '910': '__RELABEL_FROM_FILE__',
#  '911': 'gatk2_variant_select',
#  '912': 'deeptools_compute_matrix_operations',
#  '913': 'ctb_ob_genProp',
#  '914': 'ProteinQuantifier',
#  '915': 'deeptools_plot_coverage',
#  '916': 'bwa',
#  '917': 'megahit',
#  '918': 'bedtools_intersectBed',
#  '919': 'mcClust',
#  '920': '__FLATTEN__',
#  '921': 'venn_list',
#  '922': 'sklearn_nn_classifier',
#  '923': 'macs2_predictd',
#  '924': 'metilene',
#  '925': 'sklearn_build_pipeline',
#  '926': 'bed2gff1',
#  '927': 'cardinal_combine',
#  '928': 'naive_variant_caller',
#  '929': 'salmon',
#  '930': 'EMBOSS: getorf42',
#  '931': 'biosigner',
#  '932': 'bedtools_map',
#  '933': 'heinz_scoring',
#  '934': 'snpSift_geneSets',
#  '935': 'mothur_make_contigs',
#  '936': 'deseq2',
#  '937': 'vcf_filter',
#  '938': 'tp_unfold_column_tool',
#  '939': 'cshl_fastx_trimmer',
#  '940': 'snpsift_vartype',
#  '941': 'proteomics_search_protein_prophet_1',
#  '942': 'mimodd_varreport',
#  '943': 'cshl_fastx_renamer',
#  '944': 'bg_sortmerna',
#  '945': 'bams2ratio',
#  '946': 'fastqc',
#  '947': 'cmv',
#  '948': 'bedtools_unionbedgraph',
#  '949': '__ZIP_COLLECTION__',
#  '950': 'chipseeker',
#  '951': 'abims_xcms_fillPeaks',
#  '952': 'mothur_heatmap_bin',
#  '953': 'find_in_reference',
#  '954': 'raceid_inspecttrajectory',
#  '955': 'umi_tools_whitelist',
#  '956': 'raceid_trajectory',
#  '957': 'rnaz',
#  '958': 'cshl_word_list_grep',
#  '959': 'flexbardsc',
#  '960': 'gatk2_print_reads',
#  '961': 'humann2_renorm_table',
#  '962': 'vcfvcfintersect',
#  '963': 'enhanced_bowtie_wrapper',
#  '964': 'minfi_mset',
#  '965': 'IDConflictResolver',
#  '966': 'metaphlan2',
#  '967': 'cshl_fastx_artifacts_filter',
#  '968': 'fastq_paired_end_splitter',
#  '969': 'bedtools_sortbed',
#  '970': 'preMloc',
#  '971': 'trim_galore'}

# %%
def verify_model(model, tool_sequence, labels, dictionary, reverse_dictionary, compatible_tools, topk=30, max_seq_len=25):
    tl_seq = tool_sequence.split(",")
    last_tool_name = reverse_dictionary[str(tl_seq[-1])]
    last_compatible_tools = compatible_tools[last_tool_name]
    sample = np.zeros(max_seq_len)
    for idx, tool_id in enumerate(tl_seq):
        sample[idx] = int(tool_id)
    sample_reshaped = np.reshape(sample, (1, max_seq_len))
    
    tool_sequence_names = [reverse_dictionary[str(tool_pos)] for tool_pos in tool_sequence.split(",")]
    print("Tool seq: %s" % ",".join(tool_sequence_names))
    # predict next tools for a test path
    prediction = model.predict(sample_reshaped, verbose=0)
    prediction = np.reshape(prediction, (prediction.shape[1],))
    prediction_pos = np.argsort(prediction, axis=-1)

    # get topk prediction
    topk_prediction_pos = prediction_pos[-topk:]
    topk_prediction_val = [np.round(prediction[pos] * 100, 2) for pos in topk_prediction_pos]

    # read tool names using reverse dictionary
    pred_tool_ids = [reverse_dictionary[str(tool_pos)] for tool_pos in topk_prediction_pos]
    actual_next_tool_ids = list(set(pred_tool_ids).intersection(set(last_compatible_tools.split(","))))      
        
    #print("Predicted tools: %s" % ",".join(pred_tool_ids))
    print()
    pred_tool_ids_sorted = dict()
    for (tool_pos, tool_pred_val) in zip(topk_prediction_pos, topk_prediction_val):
        tool_name = reverse_dictionary[str(tool_pos)]
        if tool_name in actual_next_tool_ids:
            pred_tool_ids_sorted[tool_name] = tool_pred_val
    pred_tool_ids_sorted = dict(sorted(pred_tool_ids_sorted.items(), key=lambda kv: kv[1], reverse=True))
    
    cls_wt = dict()
    usg_wt = dict()
    inv_wt = dict()
    ids_tools = dict()
    keys = list(pred_tool_ids_sorted.keys())
    for k in keys:
        try:
            cls_wt[k] = np.round(class_weights[str(data_dict[k])], 6)
            usg_wt[k] = np.round(usage_weights[k], 6)
            inv_wt[k] = np.round(inverted_weights[str(data_dict[k])], 6)
        except:
            continue
    print("Predicted tools: \n")
    print(pred_tool_ids_sorted)
    print()
    print("Class weights: \n")
    cls_wt = dict(sorted(cls_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(cls_wt)
    print()
    print("Usage weights: \n")
    usg_wt = dict(sorted(usg_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(usg_wt)
    print()
    total_usage_wt = np.mean(list(usg_wt.values()))
    total_pred_score = np.mean(list(pred_tool_ids_sorted.values()))
    print("Mean usage wt: %0.4f, Mean prediction score: %0.4f, Sum: %0.4f" % (total_usage_wt, total_pred_score, (total_usage_wt + total_pred_score)))
    print()
    print("Inverted weights: \n")
    inv_wt = dict(sorted(inv_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(inv_wt)
    for key in pred_tool_ids_sorted:
        ids_tools[key] = dictionary[key]
    print()
    print("Tool ids")
    print(ids_tools)
    print("======================================")
    return cls_wt, usg_wt, inv_wt, pred_tool_ids_sorted

topk = 10
# 895,533,260,894,596,114,297,896,387,626,486,720,361,283,943
tool_seq = "687,442" #879,102,936,292,7,590
class_wt, usage_wt, inverse_wt, pred_tools = verify_model(model, tool_seq, "", dictionary, reverse_dictionary, compatibile_tools, topk)
# Out:
# Tool seq: __UNZIP_COLLECTION__
#
# Predicted tools:
#
# {'multiqc': 36.53, 'rna_star': 10.87, 'bowtie2': 5.45}
#
# Class weights:
#
# {'bowtie2': 43.864787, 'rna_star': 19.459202, 'multiqc': 5.951446}
#
# Usage weights:
#
# {'bowtie2': 877.295737, 'rna_star': 642.153657, 'multiqc': 434.455556}
#
# Mean usage wt: 651.3016, Mean prediction score: 17.6167, Sum: 668.9183
#
# Inverted weights:
#
# {'bowtie2': 0.05, 'rna_star': 0.030303, 'multiqc': 0.013699}
#
# Tool ids
# {'multiqc': 409, 'rna_star': 442, 'bowtie2': 879}
# ======================================

# %%
list_cls_wt = list()
list_usage_wt = list()
list_pred_wt = list()
division_pt = int(len(pred_tools) / 2)

for tool in pred_tools:
    list_pred_wt.append(pred_tools[tool])
    try:
        list_cls_wt.append(class_wt[tool])
    except:
        list_cls_wt.append(1)

def plot_scatter(y_val, title, xlabel, ylabel):
    x_val = range(1, len(y_val) + 1)
    plt.figure(figsize=(8, 8))
    plt.plot(x_val[:division_pt], y_val[:division_pt], 'ro')
    plt.plot(x_val[division_pt:], y_val[division_pt:], 'b^')
    plt.xlabel(xlabel, size=size_label)
    plt.ylabel(ylabel, size=size_label)
    plt.legend([("First top-%s" % str(division_pt)), ("Next top-%s" % str(division_pt))])
    plt.title(title, size=size_title)
    plt.grid(True)
    plt.show()

plot_scatter(list_cls_wt, "Usage weights for tools", "Number of tools", "Class weights")
#plot_scatter(ave_prediction_weights, ave_usage_weights, "Prediction vs usage weights", "Prediction scores", "Usage weights")
#plot_scatter(ave_prediction_weights, ave_inverted_weights, "Prediction vs inverted weights", "Prediction scores", "Inverted weights")
