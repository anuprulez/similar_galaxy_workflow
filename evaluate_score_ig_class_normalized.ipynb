# %%
import numpy as np
import json
import warnings
import operator

import h5py
from keras.models import model_from_json
from keras import backend as K

from matplotlib import pyplot as plt

warnings.filterwarnings("ignore")

size_title = 18
size_label = 14
n_pred = 2

base_path = "data/remote_cls_normalized/"

path_data_dict = base_path + "data_dict.txt"
path_inverted_wt = base_path + "inverted_weights.txt"
path_usage_wt = base_path + "usage_prediction.txt"
path_class_wt = base_path + "class_weights.txt"
path_test_data = base_path + "test_paths_dict.txt"
model_path = base_path + "trained_model.hdf5"

def read_file(file_path):
    with open(file_path, 'r') as data_file:
        data = json.loads(data_file.read())
    return data

class_weights = read_file(path_class_wt)
usage_weights = read_file(path_usage_wt)
inverted_weights = read_file(path_inverted_wt)
data_dict = read_file(path_data_dict)

def create_model(model_path):
    trained_model = h5py.File(model_path, 'r')
    model_config = json.loads(trained_model.get('model_config').value)
    loaded_model = model_from_json(model_config)
    dictionary = json.loads(trained_model.get('data_dictionary').value)
    compatibile_tools = json.loads(trained_model.get('compatible_tools').value)
    reverse_dictionary = dict((str(v), k) for k, v in dictionary.items())
    model_weights = list()
    weight_ctr = 0
    while True:
        try:
            d_key = "weight_" + str(weight_ctr)
            weights = trained_model.get(d_key).value
            model_weights.append(weights)
            weight_ctr += 1
        except Exception as exception:
            break
    # set the model weights
    loaded_model.set_weights(model_weights)
    return loaded_model, dictionary, reverse_dictionary, compatibile_tools

model, dictionary, reverse_dictionary, compatibile_tools = create_model(model_path)

# %%
reverse_dictionary
# Out:
# {'1': 'stacks_refmap',
#  '2': 'clustalw',
#  '3': 'vcfvcfintersect',
#  '4': 'mothur_classify_seqs',
#  '5': 'bams2ratio',
#  '6': 'ia_coordinates_of_roi',
#  '7': 'EMBOSS: extractseq35',
#  '8': 'msconvert3_raw',
#  '9': 'get_sequences',
#  '10': 'gops_coverage_1',
#  '11': 'mothur_remove_groups',
#  '12': 'bismark_bowtie',
#  '13': '__FLATTEN__',
#  '14': 'raceid_main',
#  '15': 'prokaryotic_ncbi_submission',
#  '16': 'bismark_bowtie2',
#  '17': 'prokka',
#  '18': 'fastq_dump',
#  '19': 'gemini_db_info',
#  '20': 'mothur_make_shared',
#  '21': 'gd_raxml',
#  '22': 'trinity',
#  '23': 'mothur_homova',
#  '24': 'snpEff_download',
#  '25': 'sailfish',
#  '26': 'bed2gff1',
#  '27': 'tp_split_on_column',
#  '28': 'deeptools_plot_profile',
#  '29': 'sam_bw_filter',
#  '30': 'Interval_Maf_Merged_Fasta2',
#  '31': 'rnbeads',
#  '32': 'FileFilter',
#  '33': 'tag_stat2',
#  '34': 'rarefaction',
#  '35': 'hcluster_sg',
#  '36': 'mothur_nmds',
#  '37': 'mothur_cluster',
#  '38': 'gemini_query',
#  '39': 'kraken-filter',
#  '40': 'metaphlan2krona',
#  '41': 'vcfselectsamples',
#  '42': 'fasta-stats',
#  '43': 'bamleftalign',
#  '44': 'react_cal_pipeline',
#  '45': 'mothur_count_seqs',
#  '46': 'gatk_unified_genotyper',
#  '47': 'methtools_dmr',
#  '48': 'cshl_find_and_replace',
#  '49': 'find_in_reference',
#  '50': 'tp_awk_tool',
#  '51': 'salmon',
#  '52': 'openms_id_mapper',
#  '53': 't_coffee',
#  '54': 'fasta_merge_files_and_filter_unique_sequences',
#  '55': 'je_markdupes',
#  '56': 'Paste1',
#  '57': 'mothur_remove_lineage',
#  '58': 'silac_analyzer',
#  '59': 'PicardASMetrics',
#  '60': 'join1',
#  '61': 'samtool_filter2',
#  '62': 'tmhmm2',
#  '63': 'cshl_sort_header',
#  '64': 'Univariate',
#  '65': 'hicexplorer_hicsummatrices',
#  '66': 'vegan_rarefaction',
#  '67': 'blastxml_to_tabular',
#  '68': 'plotly_ml_performance_plots',
#  '69': 'ProteinInference',
#  '70': 'disco',
#  '71': '__APPLY_RULES__',
#  '72': 'EMBOSS: newseq59',
#  '73': 'macs2_predictd',
#  '74': 'rnaz',
#  '75': 'ctb_compound_convert',
#  '76': 'ctb_silicos_qed',
#  '77': 'replace_column_with_key_value_file',
#  '78': 'thermo_raw_file_converter',
#  '79': 'vegan_diversity',
#  '80': 'fastq_join',
#  '81': 'gops_intersect_1',
#  '82': 'blast2go',
#  '83': 'gtftobed12',
#  '84': 'fasta_filter_by_length',
#  '85': 'locarna_best_subtree',
#  '86': 'bwa_mem',
#  '87': 'qiime_make_otu_heatmap',
#  '88': 'glob_report',
#  '89': 'mothur_metastats',
#  '90': 'deeptools_compute_matrix_operations',
#  '91': 'vsearch_dereplication',
#  '92': 'nanopolish_variants',
#  '93': 'qiime_core_diversity',
#  '94': 'deeptools_multi_bam_summary',
#  '95': 'pynast',
#  '96': 'diffbind-embl',
#  '97': 'mothur_merge_files',
#  '98': 'deeptools_bamCoverage',
#  '99': 'bctools_remove_tail',
#  '100': 'fastq_quality_trimmer',
#  '101': 'muscle',
#  '102': 'gene2exon1',
#  '103': 'CONVERTER_interval_to_bed_0',
#  '104': 'datamash_transpose',
#  '105': 'bedtools_multicovtbed',
#  '106': 'snpfinder',
#  '107': 'rseqc_read_distribution',
#  '108': 'interproscan',
#  '109': 'bg_statistical_hypothesis_testing',
#  '110': 'nn_classifier',
#  '111': 'samtools_filter',
#  '112': 'umi_tools_count',
#  '113': 'mothur_summary_single',
#  '114': 'RNAlien',
#  '115': 'shovill',
#  '116': 'regex1',
#  '117': 'vcfflatten2',
#  '118': 'mergeCols1',
#  '119': 'mass_spectrometry_imaging_classification',
#  '120': 'Psortb',
#  '121': 'dexseq_count',
#  '122': 'idr-embl',
#  '123': 'mycrobiota-krona-mothur',
#  '124': 'transpose',
#  '125': 'seq_composition',
#  '126': 'get_child_terms',
#  '127': 'Extractor',
#  '128': 'mothur_unique_seqs',
#  '129': 'FileConverter',
#  '130': 'kraken-translate',
#  '131': 'gff_filter_by_attribute',
#  '132': 'bedtools_intersectbed_bam',
#  '133': 'cardinal_preprocessing',
#  '134': 'rseqc_geneBody_coverage',
#  '135': 'bedtools_intersectBed',
#  '136': 'gatk2_variant_annotator',
#  '137': '__RELABEL_FROM_FILE__',
#  '138': 'mothur_dist_shared',
#  '139': 'bedtools_unionbedgraph',
#  '140': 'vcfgenotypes',
#  '141': 'tophat',
#  '142': 'EMBOSS: seqret84',
#  '143': 'datamash_ops',
#  '144': 'gatk2_reduce_reads',
#  '145': 'gatk2_unified_genotyper',
#  '146': 'picard_CleanSam',
#  '147': 'CONVERTER_interval_to_bgzip_0',
#  '148': 'rbc_mirdeep2_quantifier',
#  '149': 'minfi_getM',
#  '150': 'EMBOSS: tranalign100',
#  '151': 'velvet',
#  '152': 'cmFinder',
#  '153': 'smf_utils_fix-fasta-headers',
#  '154': 'smf_utils_extract-boxed-sequences',
#  '155': 'gatk2_variant_apply_recalibration',
#  '156': 'minfi_read450k',
#  '157': 'ctb_change_title',
#  '158': 'rna_star',
#  '159': 'glimmer_build-icm',
#  '160': 'EMBOSS: textsearch98',
#  '161': 'metaphlan_hclust_heatmap',
#  '162': 'samtools_sort',
#  '163': 'roary',
#  '164': 'Filter1',
#  '165': 'heatmapper_deepTools',
#  '166': 'Grouping1',
#  '167': 'wiggle2simple1',
#  '168': 'FastTree',
#  '169': 'pileometh',
#  '170': 'picard_MarkDuplicates',
#  '171': 'snpSift_dbnsfp_generic',
#  '172': 'gatk2_base_recalibrator',
#  '173': 'qiime_count_seqs',
#  '174': 'gatk2_haplotype_caller',
#  '175': 'cshl_uniq_tool',
#  '176': 'gops_merge_1',
#  '177': 'cshl_cut_tool',
#  '178': 'scpipe',
#  '179': 'deeptools_profiler',
#  '180': 'antismash',
#  '181': 'deeptools_bigwigCompare',
#  '182': 'mothur_trim_seqs',
#  '183': 'glimmer_not-knowlegde-based',
#  '184': 'vcf2tsv',
#  '185': 'eden_vectorizer',
#  '186': 'hicexplorer_hicfindtads',
#  '187': 'bedtools_bedtobam',
#  '188': 'stacks_denovomap',
#  '189': 'piranha',
#  '190': 'bam_to_sam',
#  '191': 'graphlan',
#  '192': 'EMBOSS: fuzztran39',
#  '193': 'mothur_get_oturep',
#  '194': 'mothur_filter_seqs',
#  '195': 'velvetg_jgi',
#  '196': 'convert_bc_to_binary_RY.py',
#  '197': 'deeptools_correctGCBias',
#  '198': 'paralyzer',
#  '199': 'ctb_remSmall',
#  '200': 'search_gui',
#  '201': 'picard_CollectWgsMetrics',
#  '202': 'tp_sort_rows',
#  '203': 'bg_column_arrange_by_header',
#  '204': 'mlocarna',
#  '205': 'bamCoverage_deepTools',
#  '206': 'mycrobiota-correct-replicates',
#  '207': 'bedtools_map',
#  '208': 'snippy',
#  '209': 'get_feature_info',
#  '210': 'snpSift_geneSets',
#  '211': 'IDMerger',
#  '212': 'infernal_cmstat',
#  '213': 'IsobaricAnalyzer',
#  '214': 'xcms_merge',
#  '215': 'deeptools_plot_heatmap',
#  '216': 'qiime_assign_taxonomy',
#  '217': 'goenrichment',
#  '218': 'fgsea',
#  '219': 'modencode_peakcalling_spp',
#  '220': 'goseq',
#  '221': 'meme_meme',
#  '222': 'cast',
#  '223': 'bandage_image',
#  '224': 'varscan',
#  '225': 'proteomics_moff',
#  '226': '__UNZIP_COLLECTION__',
#  '227': 'pieplots_macs',
#  '228': 'krona-text',
#  '229': 'bedtools_getfastabed',
#  '230': 'deeptools_bamCompare',
#  '231': 'bctools_extract_alignment_ends',
#  '232': 'preMloc',
#  '233': 'plotly_regression_performance_plots',
#  '234': 'chipseeker',
#  '235': 'cuffcompare',
#  '236': 'velveth_jgi',
#  '237': 'umi_tools_whitelist',
#  '238': 'Cut1',
#  '239': 'subtract_query1',
#  '240': 'deseq2_single',
#  '241': 'term_id_vs_term_name',
#  '242': 'mothur_sub_sample',
#  '243': 'hicexplorer_hicplotmatrix',
#  '244': 'msgfplus',
#  '245': 'deeptools_plot_correlation',
#  '246': 'vt_normalize',
#  '247': 'rsem_prepare_reference',
#  '248': 'bedtools_subtractbed',
#  '249': 'deeptools_heatmapper',
#  '250': 'mothur_heatmap_bin',
#  '251': 'pileup_interval',
#  '252': 'sort1',
#  '253': 'MultiplexResolver',
#  '254': 'smf_utils_filter-by-energy',
#  '255': 'w4mclstrpeakpics',
#  '256': 'cardinal_filtering',
#  '257': 'CONVERTER_interval_to_bedstrict_0',
#  '258': 'bcftools_norm',
#  '259': 'kraken-report',
#  '260': 'bctools_remove_spurious_events',
#  '261': 'stringtie',
#  '262': 'ProteinQuantifier',
#  '263': 'numeric_clustering',
#  '264': 'bcftools_consensus',
#  '265': 'bedtools_intersectbed',
#  '266': 'gatk2_realigner_target_creator',
#  '267': 'checkFormat',
#  '268': 'bedtools_windowbed',
#  '269': 'proteomics_search_protein_prophet_1',
#  '270': 'bg_find_subsequences',
#  '271': 'mothur_cluster_split',
#  '272': 'mothur_lefse',
#  '273': 'tp_easyjoin_tool',
#  '274': 'mothur_classify_rf',
#  '275': 'samtools_bedcov',
#  '276': 'fastqc',
#  '277': 'cardinal_quality_report',
#  '278': 'collection_column_join',
#  '279': 'biosigner',
#  '280': 'CONVERTER_gff_to_interval_index_0',
#  '281': 'deeptools_plot_pca',
#  '282': 'blockbuster',
#  '283': 'mothur_remove_seqs',
#  '284': 'DatamashTranspose',
#  '285': 'gemini_windower',
#  '286': 'IDFileConverter',
#  '287': 'rcas',
#  '288': 'NFS_transfer',
#  '289': 'cshl_fasta_nucleotides_changer',
#  '290': 'flexbardsc',
#  '291': 'MapRTTransformer',
#  '292': 'cshl_fastx_renamer',
#  '293': 'rarefaction_analyzer',
#  '294': 'mass_spectrometry_imaging_qc',
#  '295': 'w4mcorcov',
#  '296': 'multiqc',
#  '297': 'cshl_fastx_collapser',
#  '298': 'hicexplorer_hicmergematrixbins',
#  '299': 'MSGFPlusAdapter',
#  '300': 'vcfannotate',
#  '301': '16Sclassifier',
#  '302': 'picard_SortSam',
#  '303': 'enhanced_bowtie_wrapper',
#  '304': 'CONVERTER_bed_to_gff_0',
#  '305': 'bedtools_genomecoveragebed',
#  '306': 'mothur_amova',
#  '307': 'macs2_callpeak',
#  '308': 'ncbi_rpsblast_wrapper',
#  '309': 'cummerbund_to_cuffdiff',
#  '310': 'extract_aln_ends.py',
#  '311': 'vcfsort',
#  '312': 'Extract genomic DNA 1',
#  '313': 'rbc_splitfasta',
#  '314': 'graphlan_annotate',
#  '315': 'CometAdapter',
#  '316': 'cardinal_combine',
#  '317': 'heinz_visualization',
#  '318': 'vcfbedintersect',
#  '319': 'trim_galore',
#  '320': 'NSPDK_candidateClust',
#  '321': 'snpeff_to_peptides',
#  '322': 'humann2',
#  '323': 'FeatureLinkerUnlabeledQT',
#  '324': 'htseq_count',
#  '325': 'ucsc-twobittofa',
#  '326': 'deeptools_bamFingerprint',
#  '327': 't2t_report',
#  '328': 'Convert characters1',
#  '329': 'rseqc_infer_experiment',
#  '330': 'proteomics_search_tandem_1',
#  '331': 'msconvert2_raw',
#  '332': 'EMBOSS: wordcount109',
#  '333': 'seurat',
#  '334': 'resistome_analyzer',
#  '335': 'gafa',
#  '336': 'annotatemyids',
#  '337': 'ncbi_makeblastdb',
#  '338': 'metilene',
#  '339': 'megahit',
#  '340': 'IDMapper',
#  '341': 'maldi_quant_preprocessing',
#  '342': 'heatmap2',
#  '343': 'sam_pileup',
#  '344': 'hicexplorer_hicplottads',
#  '345': 'mothur_make_group',
#  '346': 'cshl_fastq_quality_filter',
#  '347': 'CONVERTER_fasta_to_fai',
#  '348': 'join_files_on_column_fuzzy',
#  '349': 'gmx_npt',
#  '350': 'Multivariate',
#  '351': 'deeptools_bam_compare',
#  '352': 'mothur_rarefaction_single',
#  '353': 'tp_cut_tool',
#  '354': 'gemini_comp_hets',
#  '355': 'freebayes',
#  '356': 'bedtools_sortbed',
#  '357': 'tabular_to_fastq',
#  '358': 'wig_to_bigWig',
#  '359': 'EMBOSS: getorf42',
#  '360': 'ggplot_histogram',
#  '361': 'decoyfasta',
#  '362': 'DatamashOps',
#  '363': 'Extract_features1',
#  '364': 'flanking_features_1',
#  '365': 'meme_psp_gen',
#  '366': 'tp_cat',
#  '367': 'random_lines1',
#  '368': 'mothur_summary_seqs',
#  '369': 'openms_id_file_converter',
#  '370': 'charts',
#  '371': 'cmv',
#  '372': 'snpEff',
#  '373': 'term_id_vs_term_def',
#  '374': 'PeptideIndexer',
#  '375': 'cshl_easyjoin',
#  '376': 'minfi_maptogenome',
#  '377': 'FROGS_affiliation_OTU',
#  '378': 'raceid_clustering',
#  '379': 'macs2_bdgcmp',
#  '380': 'fastq_paired_end_interlacer',
#  '381': 'picard_MarkDuplicatesWithMateCigar',
#  '382': 'combine_metaphlan2_humann2',
#  '383': 'mothur_parsimony',
#  '384': 'mimodd_varextract',
#  '385': 'deseq2',
#  '386': 'mimodd_map',
#  '387': 'bamtools',
#  '388': 'blockclust',
#  '389': 'cshl_multijoin',
#  '390': 'barchart_gnuplot',
#  '391': 'stacks_procrad',
#  '392': 'signalp3',
#  '393': 'umi_tools_dedup',
#  '394': 'cufflinks_prok',
#  '395': '__MERGE_COLLECTION__',
#  '396': 'cshl_fastx_artifacts_filter',
#  '397': 'minfi_dmr',
#  '398': 'mothur_make_biom',
#  '399': 'uniprot',
#  '400': 'circgraph',
#  '401': 'bedtools_genomecoveragebed_histogram',
#  '402': 'w4mclassfilter',
#  '403': 'ctb_simsearch',
#  '404': 'FidoAdapter',
#  '405': 'align_families',
#  '406': 'filter_by_fasta_ids',
#  '407': 'samtools_rmdup',
#  '408': 'varscan_copynumber',
#  '409': 'modencode_peakcalling_macs2',
#  '410': 'peptide_shaker',
#  '411': 'qiime_pick_open_reference_otus',
#  '412': 'gops_join_1',
#  '413': 'ctb_filter',
#  '414': 'CONVERTER_bed_to_bgzip_0',
#  '415': 'gtf_filter_by_attribute_values_list',
#  '416': 'varscan_mpileup',
#  '417': 'cardinal_spectra_plots',
#  '418': 'gff2bed1',
#  '419': 'maldi_quant_peak_detection',
#  '420': 'bwa',
#  '421': 'translate_bed_sequences',
#  '422': 'tp_unfold_column_tool',
#  '423': 'hgv_snpFreq',
#  '424': 'dunovo',
#  '425': 'CONVERTER_sam_to_unsorted_bam',
#  '426': 'deeptools_bamCorrelate',
#  '427': 'mimodd_varcall',
#  '428': 'regex_replace',
#  '429': 'gatk2_print_reads',
#  '430': 'qiime_pick_closed_reference_otus',
#  '431': 'mimodd_vcf_filter',
#  '432': 'trim_reads',
#  '433': 'bedtools_mergebed',
#  '434': 'seq_filter_by_mapping',
#  '435': 'bowtie_wrapper',
#  '436': 'mothur_dist_seqs',
#  '437': 'fastq_filter',
#  '438': 'FalseDiscoveryRate',
#  '439': 'mothur_pre_cluster',
#  '440': 'goslimmer',
#  '441': 'unipept',
#  '442': 'gemini_de_novo',
#  '443': 'smooth_running_window',
#  '444': 'xpath',
#  '445': 'idpassemble',
#  '446': 'rsem_calculate_expression',
#  '447': 'bed_to_bigwig',
#  '448': 'pureclip',
#  '449': 'cuffmerge',
#  '450': 'infernal_cmbuild',
#  '451': 'nonpareil',
#  '452': 'computeMatrix',
#  '453': 'rseqc_inner_distance',
#  '454': 'tp_text_file_with_recurring_lines',
#  '455': 'qiime_align_seqs',
#  '456': 'gemini_annotate',
#  '457': 'selectsequencesfrommsa',
#  '458': 'Draw_phylogram',
#  '459': 'rseqc_junction_saturation',
#  '460': 'metaphlan2',
#  '461': 'w4mjoinpn',
#  '462': 'EMBOSS: shuffleseq87',
#  '463': 'picard_NormalizeFasta',
#  '464': 'flexbar',
#  '465': 'deeptools_plot_coverage',
#  '466': 'aragorn_trna',
#  '467': 'mothur_align_seqs',
#  '468': 'gmx_setup',
#  '469': 'gatk2_variant_filtration',
#  '470': 'Btrim64',
#  '471': 'abricate',
#  '472': 'fasta2tab',
#  '473': 'heinz',
#  '474': 'PicardInsertSize',
#  '475': 'viennarna_rnaplot',
#  '476': 'deeptools_computeGCBias',
#  '477': 'kallisto_quant',
#  '478': 'mothur_heatmap_sim',
#  '479': 'infernal_cmsearch',
#  '480': 'rgweblogo3',
#  '481': 'ctb_chemfp_mol2fps',
#  '482': 'mycrobiota-qc-report',
#  '483': 'Extract_RNA_seq_Evidence',
#  '484': 'htseq-count',
#  '485': 'iReport',
#  '486': 'raceid_inspecttrajectory',
#  '487': '16Saligner',
#  '488': 'qiime_pick_otus',
#  '489': 'bedtools_slopbed',
#  '490': 'hgv_linkToGProfile',
#  '491': 'hgv_david',
#  '492': 'EMBOSS: water107',
#  '493': 'fragmenter',
#  '494': 'CONVERTER_fastqgz_to_fastq',
#  '495': 'sklear_numeric_clustering',
#  '496': 'flexbar_split_RYYR_bcs',
#  '497': 'cshl_fastq_to_fasta',
#  '498': 'wsdl_hmdb',
#  '499': 'EMBOSS: revseq82',
#  '500': 'augustus',
#  '501': 'metams_runGC',
#  '502': 'deeptools_multi_bigwig_summary',
#  '503': 'cshl_fasta_formatter',
#  '504': 'gops_basecoverage_1',
#  '505': 'extract_bcs.py',
#  '506': 'dexseq',
#  '507': 'map_peptides_to_bed',
#  '508': 'export2graphlan',
#  '509': 'idpqonvert',
#  '510': 'bedtools_multiintersectbed',
#  '511': 'mass_spectrometry_imaging_combine',
#  '512': 'bcftools_call',
#  '513': 'ProteinResolver',
#  '514': 'tp_uniq_tool',
#  '515': 'mz_to_sqlite',
#  '516': 'fastq_to_fasta_python',
#  '517': 'IDMassAccuracy',
#  '518': 'minfi_dropsnp',
#  '519': 'sklearn_build_pipeline',
#  '520': 'CONVERTER_gz_to_uncompressed',
#  '521': 'methtools_calling',
#  '522': 'CONVERTER_bedgraph_to_bigwig',
#  '523': 'gffcompare',
#  '524': 'DecoyDatabase',
#  '525': 'wolf_psort',
#  '526': 'mothur_make_contigs',
#  '527': 'blastxml_to_top_descr',
#  '528': 'Batch_correction',
#  '529': 'FROGS_affiliations_stat',
#  '530': 'structure_to_gspan',
#  '531': 'ggplot_point',
#  '532': 'heinz_scoring',
#  '533': 'comp1',
#  '534': 'lfq_protein_quant',
#  '535': 'gemini_pathways',
#  '536': 'spades',
#  '537': 'unicycler',
#  '538': 'minfi_getanno',
#  '539': 'TrimByN',
#  '540': 'mothur_screen_seqs',
#  '541': 'Show beginning1',
#  '542': 'TrimByLength',
#  '543': 'length_and_gc_content',
#  '544': 'rgPicardMarkDups',
#  '545': 'myrimatch',
#  '546': 'tophat2',
#  '547': 'hicexplorer_hicpca',
#  '548': 'cutadapt',
#  '549': 'get_subontology_from',
#  '550': 'bg_diamond',
#  '551': 'fastq_paired_end_splitter',
#  '552': 'Determine_BC',
#  '553': 'flexbar_no_split',
#  '554': 'graphclust_aggregate_alignments',
#  '555': 'snippy_core',
#  '556': 'wc_gnu',
#  '557': 'CONVERTER_fasta_to_tabular',
#  '558': 'Digestor',
#  '559': 'samtools_idxstats',
#  '560': 'picard_CollectInsertSizeMetrics',
#  '561': 'vcffilter2',
#  '562': 'je_clip',
#  '563': 'metaspades',
#  '564': 'smf_utils_find-boxes',
#  '565': 'blastxml_to_tabular_selectable',
#  '566': 'remove_tail.py',
#  '567': 'samtools_calmd',
#  '568': 'chipsequtil_maptoknowngenes',
#  '569': 'p_clip_peaks',
#  '570': 'deeptools_plot_enrichment',
#  '571': 'XTandemAdapter',
#  '572': 'cd_hit_dup',
#  '573': 'mimodd_varreport',
#  '574': 'proteomics_search_peptide_prophet_1',
#  '575': 'picard_ARRG',
#  '576': 'sklearn_numeric_clustering',
#  '577': 'rgPicFixMate',
#  '578': 'deeptools_correct_gc_bias',
#  '579': 'get_read_pipeline',
#  '580': 'gatk_indel_realigner',
#  '581': 'tophat_fusion_post',
#  '582': 'MapAlignerPoseClustering',
#  '583': 'limma_voom',
#  '584': 'hmmer_hmmbuild',
#  '585': 'naive_variant_caller',
#  '586': 'egsea',
#  '587': 'ngsutils_bam_filter',
#  '588': 'cor2',
#  '589': 'bam-filter',
#  '590': 'bedtools_annotatebed',
#  '591': 'FROGS_preprocess',
#  '592': 'abims_xcms_fillPeaks',
#  '593': 'Remove beginning1',
#  '594': 'vcftools_merge',
#  '595': 'bg_sortmerna',
#  '596': 'annotateMyIDs',
#  '597': 'picard_FixMateInformation',
#  '598': 'scale_image',
#  '599': 'sample_seqs',
#  '600': 'tp_sort_header_tool',
#  '601': 'gbk_to_orf',
#  '602': 'gmx_em',
#  '603': 'mass_spectrometry_imaging_preprocessing',
#  '604': 'histogram_rpy',
#  '605': 'picard_MergeSamFiles',
#  '606': 'flye',
#  '607': 'abims_CAMERA_annotateDiffreport',
#  '608': 'secure_hash_message_digest',
#  '609': 'dt_profiler',
#  '610': 'MassCalculator',
#  '611': 'bigwig_to_bedgraph',
#  '612': 'transdecoder',
#  '613': 'rbc_rnacode',
#  '614': 'correctGCBias',
#  '615': 'peakachu',
#  '616': 'cshl_fastx_barcode_splitter',
#  '617': 'ctb_ob_genProp',
#  '618': 'ctb_online_data_fetch',
#  '619': 'Show tail1',
#  '620': 'filtlong',
#  '621': 'fastq_combiner',
#  '622': 'vcffixup',
#  '623': 'minfi_methcpg',
#  '624': 'FeatureFinderMultiplex',
#  '625': 'samtools_slice_bam',
#  '626': 'bedtools_genomecoveragebed_bedgraph',
#  '627': 'graphclust_align_cluster',
#  '628': 'humann2_renorm_table',
#  '629': 'EMBOSS: geecee41',
#  '630': 'gemini_interactions',
#  '631': 'cshl_fastx_quality_statistics',
#  '632': 'MzTabExporter',
#  '633': 'sam_to_bam',
#  '634': 'group_humann2_uniref_abundances_to_go',
#  '635': 'FileMerger',
#  '636': 'viz_overlay_moving_and_fixed_image',
#  '637': 'ConsensusMapNormalizer',
#  '638': 'samtools_stats',
#  '639': 'meme_chip',
#  '640': 'rbc_mirdeep2',
#  '641': 'Nucleosome',
#  '642': 'samtools_flag_filter',
#  '643': 'cshl_princeton_fastx_barcode_splitter',
#  '644': 'deeptools_compute_gc_bias',
#  '645': 'hisat',
#  '646': 'ChooseTag',
#  '647': 'uchime',
#  '648': 'umi_tools_group',
#  '649': 'abims_xcms_summary',
#  '650': 'smf_utils_estimate-energy',
#  '651': 'mothur_get_seqs',
#  '652': 'ncbi_blastx_wrapper',
#  '653': 'ExtractFASTAfromFASTQ',
#  '654': 'fastq_paired_end_joiner',
#  '655': 'filter_bed_on_splice_junctions',
#  '656': 'megablast_xml_parser',
#  '657': 'stringtie_merge',
#  '658': 'deeptools_bam_coverage',
#  '659': 'plotly_parallel_coordinates_plot',
#  '660': 'gtf2bedgraph',
#  '661': 'ggplot2_heatmap2',
#  '662': 'mothur_venn',
#  '663': 'cshl_fastx_trimmer',
#  '664': 'SequenceCoverageCalculator',
#  '665': 'gemini_load',
#  '666': 'deg_annotate',
#  '667': 'hcluster_sg_parser',
#  '668': 'kraken',
#  '669': 'ggplot2_heatmap',
#  '670': 'cshl_sed_tool',
#  '671': 'fasttree',
#  '672': 'query_tabular',
#  '673': 'eden_sequence_converter',
#  '674': 'stacks_genotypes',
#  '675': 'Flash',
#  '676': 'tp_tail_tool',
#  '677': 'tp_replace_in_column',
#  '678': 'hicexplorer_hictransform',
#  '679': 'minfi_getbeta',
#  '680': 'trimmomatic',
#  '681': 'mycrobiota-otutable_add_blast',
#  '682': 'methtools_plot',
#  '683': 'ggplot2_point',
#  '684': 'igvtools_count',
#  '685': 'cshl_awk_replace_in_column',
#  '686': 'table_annovar',
#  '687': 'get_flanks1',
#  '688': 'fraggenescan',
#  '689': 'ChangeCase',
#  '690': 'Datamash',
#  '691': 'FROGS_clustering',
#  '692': 'bwameth',
#  '693': 'deeptools_bigwig_compare',
#  '694': 'mothur_taxonomy_to_krona',
#  '695': 'cshl_fastx_reverse_complement',
#  '696': 'cuffnorm',
#  '697': 'cshl_fastq_quality_boxplot',
#  '698': 'bed_to_bigBed',
#  '699': 'vcfcombine',
#  '700': 'preproc',
#  '701': 'extract_element_from_collection',
#  '702': 'pileup_parser',
#  '703': 'minfi_rset',
#  '704': 'QCCalculator',
#  '705': 'aggregate_scores_in_intervals2',
#  '706': 'je_demultiplex',
#  '707': 'gatk2_indel_realigner',
#  '708': 'velvetoptimiser',
#  '709': 'minfi_ppfun',
#  '710': 'trimmer',
#  '711': 'varscan_somatic',
#  '712': 'picard_CollectRnaSeqMetrics',
#  '713': 'gops_cluster_1',
#  '714': 'cuffdiff',
#  '715': 'cshl_fastx_nucleotides_distribution',
#  '716': 'Grep1',
#  '717': 'ip_projective_transformation_points',
#  '718': 'picard_BamIndexStats',
#  '719': '__SORTLIST__',
#  '720': '__ZIP_COLLECTION__',
#  '721': 'hisat2',
#  '722': 'MAF_To_Fasta1',
#  '723': 'format_metaphlan2_output',
#  '724': 'sed_stream_editor',
#  '725': 'mothur_chimera_vsearch',
#  '726': 'cshl_grep_tool',
#  '727': 'mothur_phylotype',
#  '728': 'mothur_tree_shared',
#  '729': 'vcf2pgSnp',
#  '730': 'FROGS_remove_chimera',
#  '731': 'uparse',
#  '732': 'cat1',
#  '733': 'mothur_corr_axes',
#  '734': 'gmx_md',
#  '735': 'IDFilter',
#  '736': 'Remove_ending',
#  '737': 'bctools_extract_crosslinked_nucleotides',
#  '738': 'newick_display',
#  '739': 'bcftools_view',
#  '740': '__FILTER_FROM_FILE__',
#  '741': 'minfi_mset',
#  '742': 'addName',
#  '743': 'tp_sed_tool',
#  '744': 'bedtools_bamtobed',
#  '745': 'cardinal_mz_images',
#  '746': 'picard_EstimateLibraryComplexity',
#  '747': 'picard_ReorderSam',
#  '748': 'Add_a_column1',
#  '749': 'msconvert_nix',
#  '750': 'ip_projective_transformation',
#  '751': 'glimmer_knowlegde-based',
#  '752': 'graphclust_glob_report_no_align',
#  '753': 'humann2_regroup_table',
#  '754': 'ete_genetree_splitter',
#  '755': 'picard_AddOrReplaceReadGroups',
#  '756': 'heinz_bum',
#  '757': 'gatk2_variant_recalibrator',
#  '758': 'gops_subtract_1',
#  '759': 'racon',
#  '760': 'bedtools_shufflebed',
#  '761': 'correct_barcodes',
#  '762': 'mothur_count_groups',
#  '763': 'mass_spectrometry_imaging_segmentations',
#  '764': 'nspdk_sparse',
#  '765': 'sklearn_searchcv',
#  '766': 'ncbi_blastn_wrapper',
#  '767': 'sklearn_nn_classifier',
#  '768': 'tsne',
#  '769': 'cummeRbund',
#  '770': 'mothur_get_communitytype',
#  '771': 'hicexplorer_hicbuildmatrix',
#  '772': 'viennarna_rnaalifold',
#  '773': 'sam2interval',
#  '774': 'picard_CASM',
#  '775': 'sklearn_svm_classifier',
#  '776': 'sequence_content_trimmer',
#  '777': 'cuffquant',
#  '778': 'r_correlation_matrix',
#  '779': 'tp_sorted_uniq',
#  '780': 'gatk2_variant_select',
#  '781': 'secretbt2test',
#  '782': 'gmx_nvt',
#  '783': 'rbc_mafft',
#  '784': 'vcffilter',
#  '785': 'featurecounts',
#  '786': 'sam_merge2',
#  '787': 'CONVERTER_Bam_Bai_0',
#  '788': 'fastq_manipulation',
#  '789': 'cardinal_segmentations',
#  '790': 'GeMoMa_Annotation_Filter',
#  '791': 'openms_protein_quantifier',
#  '792': 'fastq_paired_end_deinterlacer',
#  '793': 'bgchem_fragment_merger',
#  '794': 'fasplit',
#  '795': 'GeneModelMapper',
#  '796': 'collapse_dataset',
#  '797': 'blast_parser',
#  '798': 'ssake',
#  '799': 'stacks_populations',
#  '800': 'umi_tools_extract',
#  '801': 'mothur_seq_error',
#  '802': 'gemini_burden',
#  '803': 'abims_xcms_group',
#  '804': 'gff_to_sequence',
#  '805': 'treebest_best',
#  '806': 'bg_protein_properties',
#  '807': 'segemehl',
#  '808': 'rseqc_bam_stat',
#  '809': 'peakcalling_macs',
#  '810': 'svm_classifier',
#  '811': 'ncbi_blastp_wrapper',
#  '812': 'coords2clnt.py',
#  '813': 'Heatmap',
#  '814': 'fasta_compute_length',
#  '815': 'lca1',
#  '816': 'MapStatistics',
#  '817': 'idpquery',
#  '818': 'fastq_trimmer',
#  '819': 'hmmer_hmmsearch',
#  '820': 'qiime_pick_rep_set',
#  '821': 'cshl_fastx_clipper',
#  '822': 'ruvseq',
#  '823': 'make_families',
#  '824': 'mcClust',
#  '825': 'fastq_groomer',
#  '826': 'samtools_mpileup',
#  '827': 'tp_grep_tool',
#  '828': 'heatmapper',
#  '829': 'deeptools_compute_matrix',
#  '830': 'gatk_realigner_target_creator',
#  '831': 'raceid_inspectclusters',
#  '832': 'cshl_word_list_grep',
#  '833': 'fastq collapser',
#  '834': 'FileInfo',
#  '835': 'ConsensusID',
#  '836': 'deeptools_computeMatrix',
#  '837': 'abims_xcms_xcmsSet',
#  '838': 'rmcontamination',
#  '839': 'gops_concat_1',
#  '840': 'EMBOSS: fuzzpro38',
#  '841': 'lastz_wrapper_2',
#  '842': 'bam_to_bigwig',
#  '843': 'mothur_get_groups',
#  '844': 'dexseq_annotate',
#  '845': 'FeatureLinkerUnlabeledKD',
#  '846': 'humann2_genefamilies_genus_level',
#  '847': 'venn_list',
#  '848': 'bedtools_coveragebed_counts',
#  '849': 'CONVERTER_bed_gff_or_vcf_to_bigwig_0',
#  '850': 'gffread',
#  '851': 'PeakPickerHiRes',
#  '852': 'bundle_collection',
#  '853': 'column_remove_by_header',
#  '854': 'snpsift_vartype',
#  '855': 'snpSift_filter',
#  '856': 'mycrobiota-make-multi-otutable',
#  '857': 'porechop',
#  '858': 'qiime_validate_mapping_file',
#  '859': 'XY_Plot_1',
#  '860': 'tp_find_and_replace',
#  '861': 'FeatureFinderMetabo',
#  '862': 'gemini_actionable_mutations',
#  '863': 'tp_replace_in_line',
#  '864': 'vcfallelicprimitives',
#  '865': 'methtools_filter',
#  '866': 'bowtie2',
#  '867': 'vcftools_isec',
#  '868': 'IDPosteriorErrorProbability',
#  '869': 'cshl_awk_tool',
#  '870': 'tp_tac',
#  '871': 'ncbi_tblastn_wrapper',
#  '872': 'ete_homology_classifier',
#  '873': 'peakcalling_macs14',
#  '874': 'rseqc_read_duplication',
#  '875': 'valet',
#  '876': 'bwa_wrapper',
#  '877': 'fastq_to_tabular',
#  '878': 'graphicsmagick_image_convert',
#  '879': 'sklearn_feature_selection',
#  '880': 'taxonomy_krona_chart',
#  '881': 'HighResPrecursorMassCorrector',
#  '882': 'gemini_recessive_and_dominant',
#  '883': 'gatk2_depth_of_coverage',
#  '884': 'bamCompare_deepTools',
#  '885': 'mothur_chimera_uchime',
#  '886': 'qiime_make_phylogeny',
#  '887': 'gspan',
#  '888': 'mass_spectrometry_imaging_ion_images',
#  '889': 'raceid_trajectory',
#  '890': 'rm_spurious_events.py',
#  '891': 'cardinal_data_exporter',
#  '892': 'TrimPrimer',
#  '893': 'methtools_tiling',
#  '894': 'jbrowse',
#  '895': 'FROGS_filters',
#  '896': 'EMBOSS: transeq101',
#  '897': 'bedtools_coveragebed',
#  '898': 'bam2wig',
#  '899': 'bedtools_bamtofastq',
#  '900': 'CONVERTER_gff_to_bed_0',
#  '901': 'tab2fasta',
#  '902': 'hicexplorer_hiccorrectmatrix',
#  '903': '__FILTER_FAILED_DATASETS__',
#  '904': 'edger',
#  '905': 'FeatureLinkerUnlabeled',
#  '906': 'nanoplot',
#  '907': 'vcf_filter',
#  '908': 'pilon',
#  '909': 'flexbar_split_RR_bcs',
#  '910': 'melt',
#  '911': 'sickle',
#  '912': 'tp_multijoin_tool',
#  '913': 'FeatureFinderCentroided',
#  '914': 'Summary_Statistics1',
#  '915': 'tp_head_tool',
#  '916': 'quast',
#  '917': 'column_order_header_sort',
#  '918': 'qiime_split_libraries_fastq',
#  '919': 'minimap2',
#  '920': 'mothur_pcoa',
#  '921': 'megablast_wrapper',
#  '922': 'meme_fimo',
#  '923': 'sklearn_ensemble',
#  '924': 'genbank_to_gff',
#  '925': 'Count1',
#  '926': 'methtools_destrand',
#  '927': 'mass_spectrometry_imaging_mzplots',
#  '928': 'cufflinks',
#  '929': 'IDConflictResolver',
#  '930': 'picard_FilterSamReads',
#  '931': 'picard_SamToFastq',
#  '932': 'mothur_classify_otu',
#  '933': 're_he_maldi_image_registration',
#  '934': 'viennarna_rnafold',
#  '935': 'Fetch Taxonomic Ranks',
#  '936': 'picard_ValidateSamFile',
#  '937': 'gatk_depth_of_coverage',
#  '938': 'seq_filter_by_id',
#  '939': 'dbbuilder',
#  '940': 'predict_pipeline',
#  '941': 'gmx_solvate',
#  '942': 'samtools_split',
#  '943': 'bamFilter',
#  '944': 'ggplot2_histogram',
#  '945': 'ctb_remIons',
#  '946': 'vcftools_annotate',
#  '947': 'createInterval',
#  '948': 'mycrobiota-split-multi-otutable',
#  '949': 'TextExporter',
#  '950': 'scaffold2fasta',
#  '951': 'minfi_dmp',
#  '952': 'iuc_pear',
#  '953': 'raceid_filtnormconf',
#  '954': 'rnafold',
#  '955': 'rseqc_bam2wig',
#  '956': 'bedtools_complementbed',
#  '957': 'allele_counts_1',
#  '958': 'minfi_qc',
#  '959': 'deeptools_plot_fingerprint',
#  '960': 'mass_spectrometry_imaging_filtering',
#  '961': 'meme_dreme',
#  '962': 'rbc_mirdeep2_mapper',
#  '963': 'snpSift_annotate',
#  '964': 'locarna_multiple',
#  '965': 'eukaryotic_ncbi_submission',
#  '966': 'samtools_flagstat',
#  '967': 'bg_uniq',
#  '968': 'sqlite_to_tabular',
#  '969': 'IDScoreSwitcher',
#  '970': 'addValue',
#  '971': 'merge_pcr_duplicates.py'}

# %%
def verify_model(model, tool_sequence, labels, dictionary, reverse_dictionary, compatible_tools, topk=30, max_seq_len=25):
    tl_seq = tool_sequence.split(",")
    last_tool_name = reverse_dictionary[str(tl_seq[-1])]
    last_compatible_tools = compatible_tools[last_tool_name]
    sample = np.zeros(max_seq_len)
    for idx, tool_id in enumerate(tl_seq):
        sample[idx] = int(tool_id)
    sample_reshaped = np.reshape(sample, (1, max_seq_len))
    
    tool_sequence_names = [reverse_dictionary[str(tool_pos)] for tool_pos in tool_sequence.split(",")]
    print("Tool seq: %s" % ",".join(tool_sequence_names))
    # predict next tools for a test path
    prediction = model.predict(sample_reshaped, verbose=0)
    prediction = np.reshape(prediction, (prediction.shape[1],))
    prediction_pos = np.argsort(prediction, axis=-1)

    # get topk prediction
    topk_prediction_pos = prediction_pos[-topk:]
    topk_prediction_val = [np.round(prediction[pos] * 100, 2) for pos in topk_prediction_pos]

    # read tool names using reverse dictionary
    pred_tool_ids = [reverse_dictionary[str(tool_pos)] for tool_pos in topk_prediction_pos]
    actual_next_tool_ids = list(set(pred_tool_ids).intersection(set(last_compatible_tools.split(","))))      
        
    #print("Predicted tools: %s" % ",".join(pred_tool_ids))
    print()
    pred_tool_ids_sorted = dict()
    for (tool_pos, tool_pred_val) in zip(topk_prediction_pos, topk_prediction_val):
        tool_name = reverse_dictionary[str(tool_pos)]
        if tool_name in actual_next_tool_ids:
            pred_tool_ids_sorted[tool_name] = tool_pred_val
    pred_tool_ids_sorted = dict(sorted(pred_tool_ids_sorted.items(), key=lambda kv: kv[1], reverse=True))
    
    cls_wt = dict()
    usg_wt = dict()
    inv_wt = dict()
    ids_tools = dict()
    keys = list(pred_tool_ids_sorted.keys())
    for k in keys:
        try:
            cls_wt[k] = np.round(class_weights[str(data_dict[k])], 2)
            usg_wt[k] = np.round(usage_weights[k], 2)
            inv_wt[k] = np.round(inverted_weights[str(data_dict[k])], 2)
        except:
            continue
    print("Predicted tools: \n")
    print(pred_tool_ids_sorted)
    print()
    print("Class weights: \n")
    cls_wt = dict(sorted(cls_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(cls_wt)
    print()
    print("Usage weights: \n")
    usg_wt = dict(sorted(usg_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(usg_wt)
    print()
    print("Inverted weights: \n")
    inv_wt = dict(sorted(inv_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(inv_wt)
    for key in pred_tool_ids_sorted:
        ids_tools[key] = dictionary[key]
    print()
    print("Tool ids")
    print(ids_tools)
    print("======================================")
    return cls_wt, usg_wt, inv_wt, pred_tool_ids_sorted

topk = 10
tool_seq = "680,721,785,385"
class_wt, usage_wt, inverse_wt, pred_tools = verify_model(model, tool_seq, "", dictionary, reverse_dictionary, compatibile_tools, topk)
# Out:
# Tool seq: trimmomatic,hisat2,featurecounts,deseq2
#
# Predicted tools:
#
# {'Filter1': 96.72, 'deg_annotate': 4.28, 'Cut1': 2.04, 'Add_a_column1': 0.83, 'join1': 0.59}
#
# Class weights:
#
# {'deg_annotate': 0.43, 'Filter1': 0.19, 'Cut1': 0.14, 'join1': 0.08, 'Add_a_column1': 0.0}
#
# Usage weights:
#
# {'Cut1': 1425.46, 'Filter1': 1021.1, 'join1': 371.21, 'deg_annotate': 1.78, 'Add_a_column1': 0.0}
#
# Inverted weights:
#
# {'deg_annotate': 13410.4, 'Add_a_column1': 61.35, 'join1': 26.72, 'Filter1': 22.74, 'Cut1': 6.05}
#
# Tool ids
# {'Filter1': 164, 'deg_annotate': 666, 'Cut1': 238, 'Add_a_column1': 748, 'join1': 60}
# ======================================

# %%
list_cls_wt = list()
list_usage_wt = list()
list_pred_wt = list()
division_pt = int(len(pred_tools) / 2)

for tool in pred_tools:
    list_pred_wt.append(pred_tools[tool])
    try:
        list_cls_wt.append(class_wt[tool])
    except:
        list_cls_wt.append(1)

def plot_scatter(y_val, title, xlabel, ylabel):
    x_val = range(1, len(y_val) + 1)
    plt.figure(figsize=(8, 8))
    plt.plot(x_val[:division_pt], y_val[:division_pt], 'ro')
    plt.plot(x_val[division_pt:], y_val[division_pt:], 'b^')
    plt.xlabel(xlabel, size=size_label)
    plt.ylabel(ylabel, size=size_label)
    plt.legend([("First top-%s" % str(division_pt)), ("Next top-%s" % str(division_pt))])
    plt.title(title, size=size_title)
    plt.grid(True)
    plt.show()

plot_scatter(list_cls_wt, "Usage weights for tools", "Number of tools", "Class weights")
#plot_scatter(ave_prediction_weights, ave_usage_weights, "Prediction vs usage weights", "Prediction scores", "Usage weights")
#plot_scatter(ave_prediction_weights, ave_inverted_weights, "Prediction vs inverted weights", "Prediction scores", "Inverted weights")
