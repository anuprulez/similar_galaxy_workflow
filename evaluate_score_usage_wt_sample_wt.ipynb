# %%
import numpy as np
import json
import warnings
import operator

import h5py
from keras.models import model_from_json
from keras import backend as K

from matplotlib import pyplot as plt

warnings.filterwarnings("ignore")

size_title = 18
size_label = 14
n_pred = 2

base_path = "data/remote_usage_wt_sample_wt/"

path_data_dict = base_path + "data_dict.txt"
path_inverted_wt = base_path + "inverted_weights.txt"
path_usage_wt = base_path + "usage_prediction.txt"
path_class_wt = base_path + "class_weights.txt"
path_test_data = base_path + "test_paths_dict.txt"
model_path = base_path + "trained_model.hdf5"

def read_file(file_path):
    with open(file_path, 'r') as data_file:
        data = json.loads(data_file.read())
    return data

class_weights = read_file(path_class_wt)
usage_weights = read_file(path_usage_wt)
inverted_weights = read_file(path_inverted_wt)
data_dict = read_file(path_data_dict)

def create_model(model_path):
    trained_model = h5py.File(model_path, 'r')
    model_config = json.loads(trained_model.get('model_config').value)
    loaded_model = model_from_json(model_config)
    dictionary = json.loads(trained_model.get('data_dictionary').value)
    compatibile_tools = json.loads(trained_model.get('compatible_tools').value)
    reverse_dictionary = dict((str(v), k) for k, v in dictionary.items())
    model_weights = list()
    weight_ctr = 0
    while True:
        try:
            d_key = "weight_" + str(weight_ctr)
            weights = trained_model.get(d_key).value
            model_weights.append(weights)
            weight_ctr += 1
        except Exception as exception:
            break
    # set the model weights
    loaded_model.set_weights(model_weights)
    return loaded_model, dictionary, reverse_dictionary, compatibile_tools

model, dictionary, reverse_dictionary, compatibile_tools = create_model(model_path)
# Out:
# Using TensorFlow backend.

# %%
reverse_dictionary
# Out:
# {'1': 'shovill',
#  '2': 'limma_voom',
#  '3': 'FileInfo',
#  '4': 'vcfselectsamples',
#  '5': 'numeric_clustering',
#  '6': 'get_sequences',
#  '7': 'xcms_merge',
#  '8': 'MapRTTransformer',
#  '9': 'samtools_slice_bam',
#  '10': 'ctb_simsearch',
#  '11': 'bg_find_subsequences',
#  '12': 'gmx_nvt',
#  '13': 'addValue',
#  '14': 'qiime_pick_closed_reference_otus',
#  '15': 'cardinal_data_exporter',
#  '16': 'tab2fasta',
#  '17': 'tp_tac',
#  '18': 'gspan',
#  '19': 'cshl_awk_replace_in_column',
#  '20': 'mass_spectrometry_imaging_filtering',
#  '21': 'thermo_raw_file_converter',
#  '22': 'infernal_cmstat',
#  '23': 'mass_spectrometry_imaging_classification',
#  '24': 'cshl_fasta_nucleotides_changer',
#  '25': 'dbbuilder',
#  '26': 'Count1',
#  '27': 'msgfplus',
#  '28': 'mothur_make_group',
#  '29': 'bamFilter',
#  '30': 'MapStatistics',
#  '31': 'deeptools_plot_heatmap',
#  '32': 'gemini_interactions',
#  '33': 'deeptools_bigwigCompare',
#  '34': 'deeptools_bamFingerprint',
#  '35': 'flexbar_split_RR_bcs',
#  '36': 'infernal_cmbuild',
#  '37': 'picard_CollectInsertSizeMetrics',
#  '38': 'deeptools_plot_correlation',
#  '39': 'sort1',
#  '40': 'bg_column_arrange_by_header',
#  '41': 'spades',
#  '42': 'rnaz',
#  '43': 'sklearn_feature_selection',
#  '44': 'deeptools_compute_gc_bias',
#  '45': 'fragmenter',
#  '46': 'mothur_sub_sample',
#  '47': 'graphlan_annotate',
#  '48': 'chipseeker',
#  '49': 'dexseq_count',
#  '50': 'cutadapt',
#  '51': 'megablast_xml_parser',
#  '52': 'FalseDiscoveryRate',
#  '53': 'IDMerger',
#  '54': 'gemini_annotate',
#  '55': 'picard_FilterSamReads',
#  '56': 'GeMoMa_Annotation_Filter',
#  '57': 'cshl_sed_tool',
#  '58': 'seq_filter_by_mapping',
#  '59': 'dunovo',
#  '60': 'ip_projective_transformation',
#  '61': 'term_id_vs_term_def',
#  '62': 'mothur_metastats',
#  '63': 'hicexplorer_hicplotmatrix',
#  '64': 'bedtools_genomecoveragebed',
#  '65': 't_coffee',
#  '66': 'Extractor',
#  '67': 'checkFormat',
#  '68': 'sam2interval',
#  '69': 'tp_find_and_replace',
#  '70': 'gatk2_variant_annotator',
#  '71': 'collection_column_join',
#  '72': 'myrimatch',
#  '73': 'mycrobiota-qc-report',
#  '74': 'fastq_quality_trimmer',
#  '75': 'deeptools_computeGCBias',
#  '76': 'mothur_unique_seqs',
#  '77': 'mothur_get_oturep',
#  '78': 'umi_tools_whitelist',
#  '79': 'abims_xcms_summary',
#  '80': 'bams2ratio',
#  '81': 'bcftools_norm',
#  '82': 'MSGFPlusAdapter',
#  '83': 'metaphlan_hclust_heatmap',
#  '84': 'rgweblogo3',
#  '85': 'gemini_burden',
#  '86': 'clustalw',
#  '87': 'sailfish',
#  '88': 'rbc_splitfasta',
#  '89': 'cast',
#  '90': 'methtools_destrand',
#  '91': 'deg_annotate',
#  '92': 'ChooseTag',
#  '93': 'FROGS_clustering',
#  '94': 'eden_sequence_converter',
#  '95': 'aggregate_scores_in_intervals2',
#  '96': 'vcf_filter',
#  '97': 'bam_to_bigwig',
#  '98': 'cufflinks',
#  '99': 'FeatureFinderMetabo',
#  '100': 'htseq-count',
#  '101': 'bedtools_complementbed',
#  '102': 'gatk2_reduce_reads',
#  '103': 'tp_cat',
#  '104': 'Heatmap',
#  '105': 'fastqc',
#  '106': 'stringtie_merge',
#  '107': 'dt_profiler',
#  '108': 'FROGS_preprocess',
#  '109': 'mothur_remove_groups',
#  '110': 'pureclip',
#  '111': 'enhanced_bowtie_wrapper',
#  '112': 'w4mclassfilter',
#  '113': 'deeptools_correctGCBias',
#  '114': 'hcluster_sg',
#  '115': 'blast_parser',
#  '116': 'TrimPrimer',
#  '117': 'tp_replace_in_column',
#  '118': 'tp_text_file_with_recurring_lines',
#  '119': 'tp_head_tool',
#  '120': 'raceid_filtnormconf',
#  '121': 'TextExporter',
#  '122': 'gemini_actionable_mutations',
#  '123': 'mass_spectrometry_imaging_segmentations',
#  '124': 'bg_protein_properties',
#  '125': 'taxonomy_krona_chart',
#  '126': 'gmx_solvate',
#  '127': 'smf_utils_fix-fasta-headers',
#  '128': 'gtftobed12',
#  '129': 'CONVERTER_bed_gff_or_vcf_to_bigwig_0',
#  '130': 'EMBOSS: geecee41',
#  '131': '__RELABEL_FROM_FILE__',
#  '132': 'egsea',
#  '133': 'deeptools_plot_coverage',
#  '134': 'gtf2bedgraph',
#  '135': 'cuffquant',
#  '136': 'openms_id_mapper',
#  '137': 'react_cal_pipeline',
#  '138': 'tp_replace_in_line',
#  '139': 'ncbi_blastp_wrapper',
#  '140': 'MAF_To_Fasta1',
#  '141': 'melt',
#  '142': 'Show tail1',
#  '143': 'cshl_sort_header',
#  '144': 'deeptools_heatmapper',
#  '145': 'CONVERTER_interval_to_bedstrict_0',
#  '146': 'mothur_homova',
#  '147': 'cshl_multijoin',
#  '148': 'snpSift_annotate',
#  '149': 'random_lines1',
#  '150': 'cshl_fastq_quality_boxplot',
#  '151': 'mothur_dist_shared',
#  '152': 'samtool_filter2',
#  '153': 'openms_id_file_converter',
#  '154': 'mothur_chimera_vsearch',
#  '155': 'CONVERTER_interval_to_bgzip_0',
#  '156': 'format_metaphlan2_output',
#  '157': 'mycrobiota-otutable_add_blast',
#  '158': 'gmx_setup',
#  '159': 'ctb_silicos_qed',
#  '160': 'snpSift_dbnsfp_generic',
#  '161': 'FileFilter',
#  '162': 'EMBOSS: wordcount109',
#  '163': 'cor2',
#  '164': 'FeatureLinkerUnlabeledKD',
#  '165': 'lastz_wrapper_2',
#  '166': 'structure_to_gspan',
#  '167': 'column_order_header_sort',
#  '168': 'ggplot2_heatmap',
#  '169': 'cshl_find_and_replace',
#  '170': 'bedtools_bamtofastq',
#  '171': 'varscan_copynumber',
#  '172': 'openms_protein_quantifier',
#  '173': 'mothur_venn',
#  '174': 'samtools_bedcov',
#  '175': 'sam_to_bam',
#  '176': 'fasplit',
#  '177': 'minfi_maptogenome',
#  '178': 'abims_xcms_xcmsSet',
#  '179': 'deeptools_plot_profile',
#  '180': 'stacks_denovomap',
#  '181': 'mycrobiota-split-multi-otutable',
#  '182': 'vcffilter2',
#  '183': 'bam2wig',
#  '184': 'ChangeCase',
#  '185': 'mergeCols1',
#  '186': 'collapse_dataset',
#  '187': 'hicexplorer_hicmergematrixbins',
#  '188': 'picard_CollectWgsMetrics',
#  '189': 'mothur_cluster_split',
#  '190': 'jbrowse',
#  '191': 'bedtools_multiintersectbed',
#  '192': 'silac_analyzer',
#  '193': 'mothur_classify_otu',
#  '194': 'bedtools_genomecoveragebed_histogram',
#  '195': 'trinity',
#  '196': 'ggplot_histogram',
#  '197': 'snpEff',
#  '198': 'wsdl_hmdb',
#  '199': 'IDConflictResolver',
#  '200': 'length_and_gc_content',
#  '201': 'blastxml_to_tabular',
#  '202': 'bedtools_mergebed',
#  '203': 'gemini_db_info',
#  '204': 'Extract_features1',
#  '205': 'humann2_regroup_table',
#  '206': 'vcfvcfintersect',
#  '207': 'abims_xcms_fillPeaks',
#  '208': 'picard_ValidateSamFile',
#  '209': 'hgv_linkToGProfile',
#  '210': 'varscan_somatic',
#  '211': 'gemini_recessive_and_dominant',
#  '212': 'ncbi_blastx_wrapper',
#  '213': 'mothur_summary_seqs',
#  '214': 'modencode_peakcalling_macs2',
#  '215': 'rm_spurious_events.py',
#  '216': 'hmmer_hmmbuild',
#  '217': 'bg_diamond',
#  '218': 'ctb_remIons',
#  '219': 'PicardInsertSize',
#  '220': 'fastq_paired_end_joiner',
#  '221': 'ProteinInference',
#  '222': 'ExtractFASTAfromFASTQ',
#  '223': 'CONVERTER_fasta_to_fai',
#  '224': 'secure_hash_message_digest',
#  '225': 'bedtools_coveragebed_counts',
#  '226': 'igvtools_count',
#  '227': 'deseq2',
#  '228': 'aragorn_trna',
#  '229': 'mothur_pre_cluster',
#  '230': 'picard_EstimateLibraryComplexity',
#  '231': 'extract_aln_ends.py',
#  '232': 'disco',
#  '233': 'rbc_mafft',
#  '234': 'bamCompare_deepTools',
#  '235': 'viennarna_rnaalifold',
#  '236': 'ConsensusID',
#  '237': 'addName',
#  '238': 'gbk_to_orf',
#  '239': 'selectsequencesfrommsa',
#  '240': 'mothur_lefse',
#  '241': 'mothur_rarefaction_single',
#  '242': 'w4mclstrpeakpics',
#  '243': 'picard_CollectRnaSeqMetrics',
#  '244': '__APPLY_RULES__',
#  '245': 'deseq2_single',
#  '246': 'cshl_fasta_formatter',
#  '247': 'signalp3',
#  '248': 'heinz',
#  '249': 'vcfbedintersect',
#  '250': 'mothur_remove_seqs',
#  '251': 'bedtools_shufflebed',
#  '252': 'gmx_npt',
#  '253': 'minfi_qc',
#  '254': 'IDMapper',
#  '255': 'datamash_transpose',
#  '256': 'plotly_parallel_coordinates_plot',
#  '257': 'tp_tail_tool',
#  '258': 'gops_join_1',
#  '259': 'deeptools_bamCoverage',
#  '260': 'wolf_psort',
#  '261': 'join1',
#  '262': 'bedtools_bamtobed',
#  '263': 'kraken-report',
#  '264': 'krona-text',
#  '265': 'heatmapper',
#  '266': 'gops_merge_1',
#  '267': 'venn_list',
#  '268': 'Convert characters1',
#  '269': 'circgraph',
#  '270': 'samtools_split',
#  '271': 'ctb_change_title',
#  '272': 'cmv',
#  '273': 'mimodd_varreport',
#  '274': 'ip_projective_transformation_points',
#  '275': 'umi_tools_count',
#  '276': 'export2graphlan',
#  '277': 'samtools_sort',
#  '278': 'varscan',
#  '279': 'rnbeads',
#  '280': 'maldi_quant_preprocessing',
#  '281': 'subtract_query1',
#  '282': 'mothur_get_seqs',
#  '283': 'kraken-translate',
#  '284': 'heinz_scoring',
#  '285': 'get_child_terms',
#  '286': 'ete_homology_classifier',
#  '287': 'cuffcompare',
#  '288': 'gemini_windower',
#  '289': 'PeakPickerHiRes',
#  '290': 'stacks_genotypes',
#  '291': 'EMBOSS: shuffleseq87',
#  '292': 'eukaryotic_ncbi_submission',
#  '293': 'CONVERTER_bed_to_bgzip_0',
#  '294': 'IsobaricAnalyzer',
#  '295': 'ia_coordinates_of_roi',
#  '296': 'bctools_remove_spurious_events',
#  '297': 'mycrobiota-krona-mothur',
#  '298': 'raceid_main',
#  '299': 'peakcalling_macs14',
#  '300': 'roary',
#  '301': 'gff_to_sequence',
#  '302': 'Fetch Taxonomic Ranks',
#  '303': 'blast2go',
#  '304': 'histogram_rpy',
#  '305': 'viz_overlay_moving_and_fixed_image',
#  '306': 'picard_AddOrReplaceReadGroups',
#  '307': 'qiime_make_otu_heatmap',
#  '308': 'ruvseq',
#  '309': 'bctools_extract_alignment_ends',
#  '310': 'correctGCBias',
#  '311': 'mothur_trim_seqs',
#  '312': 'idr-embl',
#  '313': 'gffread',
#  '314': 'gemini_load',
#  '315': 'PicardASMetrics',
#  '316': 'mothur_parsimony',
#  '317': 'IDFilter',
#  '318': 'trimmer',
#  '319': 'gemini_query',
#  '320': 'newick_display',
#  '321': 'fasta_compute_length',
#  '322': 'glimmer_knowlegde-based',
#  '323': 'bg_uniq',
#  '324': 'transpose',
#  '325': 'velvetg_jgi',
#  '326': 'bwa',
#  '327': 'rseqc_infer_experiment',
#  '328': '__FILTER_FAILED_DATASETS__',
#  '329': 'deeptools_compute_matrix',
#  '330': 'gatk2_depth_of_coverage',
#  '331': 'bctools_remove_tail',
#  '332': 'peakcalling_macs',
#  '333': 'pileometh',
#  '334': 'cshl_awk_tool',
#  '335': 'gffcompare',
#  '336': 'Flash',
#  '337': 'minfi_dmp',
#  '338': 'deeptools_plot_enrichment',
#  '339': 'mlocarna',
#  '340': 'mothur_heatmap_sim',
#  '341': 'mothur_count_groups',
#  '342': 'hicexplorer_hicbuildmatrix',
#  '343': 'sklearn_svm_classifier',
#  '344': 'bundle_collection',
#  '345': 'rgPicardMarkDups',
#  '346': 'minfi_ppfun',
#  '347': 'mimodd_vcf_filter',
#  '348': 'blastxml_to_top_descr',
#  '349': 'CONVERTER_fastqgz_to_fastq',
#  '350': 'mothur_merge_files',
#  '351': 'CONVERTER_Bam_Bai_0',
#  '352': 'cshl_cut_tool',
#  '353': 'ctb_compound_convert',
#  '354': 'extract_bcs.py',
#  '355': 'cshl_fastx_reverse_complement',
#  '356': 'mass_spectrometry_imaging_qc',
#  '357': 'datamash_ops',
#  '358': 'bedtools_subtractbed',
#  '359': 'fasta2tab',
#  '360': 'minimap2',
#  '361': 'cardinal_combine',
#  '362': 'rnafold',
#  '363': 'gatk2_base_recalibrator',
#  '364': 'cardinal_mz_images',
#  '365': 'gatk2_haplotype_caller',
#  '366': 'gtf_filter_by_attribute_values_list',
#  '367': 'ggplot_point',
#  '368': 'tp_sorted_uniq',
#  '369': 'uparse',
#  '370': 'Multivariate',
#  '371': 'gatk2_print_reads',
#  '372': 'sklearn_numeric_clustering',
#  '373': 'Paste1',
#  '374': 'EMBOSS: fuzzpro38',
#  '375': 'CONVERTER_gff_to_interval_index_0',
#  '376': 'tophat_fusion_post',
#  '377': 'sam_merge2',
#  '378': 'Grouping1',
#  '379': 'mothur_seq_error',
#  '380': 'EMBOSS: textsearch98',
#  '381': 'FeatureFinderCentroided',
#  '382': 'find_in_reference',
#  '383': 'rcas',
#  '384': 'TrimByLength',
#  '385': 'kraken-filter',
#  '386': 'ncbi_rpsblast_wrapper',
#  '387': 'gops_coverage_1',
#  '388': 'metaspades',
#  '389': 'fgsea',
#  '390': 'RNAlien',
#  '391': 'make_families',
#  '392': 'minfi_rset',
#  '393': 'scale_image',
#  '394': 'mz_to_sqlite',
#  '395': 'mothur_pcoa',
#  '396': 'varscan_mpileup',
#  '397': 'minfi_mset',
#  '398': 'rseqc_bam_stat',
#  '399': 'bedtools_intersectbed_bam',
#  '400': 'qiime_pick_open_reference_otus',
#  '401': 'cardinal_quality_report',
#  '402': 'tp_multijoin_tool',
#  '403': 'picard_FixMateInformation',
#  '404': 'ete_genetree_splitter',
#  '405': 't2t_report',
#  '406': 'muscle',
#  '407': 'vegan_diversity',
#  '408': 'prokka',
#  '409': 'pynast',
#  '410': 'stacks_populations',
#  '411': 'qiime_pick_rep_set',
#  '412': 'hisat',
#  '413': 'vcf2pgSnp',
#  '414': 'fasta_merge_files_and_filter_unique_sequences',
#  '415': 'plotly_regression_performance_plots',
#  '416': 'vcffilter',
#  '417': 'meme_fimo',
#  '418': 'megablast_wrapper',
#  '419': 'picard_MarkDuplicates',
#  '420': 'gemini_comp_hets',
#  '421': 'hicexplorer_hictransform',
#  '422': '__FILTER_FROM_FILE__',
#  '423': 'vcftools_isec',
#  '424': 'sklearn_searchcv',
#  '425': 'cshl_fastx_trimmer',
#  '426': 'tp_easyjoin_tool',
#  '427': 'mothur_count_seqs',
#  '428': 'gff2bed1',
#  '429': 'picard_ARRG',
#  '430': 'raceid_trajectory',
#  '431': 'piranha',
#  '432': 'msconvert3_raw',
#  '433': 'uniprot',
#  '434': 'cardinal_segmentations',
#  '435': 'uchime',
#  '436': 'bcftools_call',
#  '437': 'glimmer_build-icm',
#  '438': 'tophat',
#  '439': 'CometAdapter',
#  '440': 'nonpareil',
#  '441': 'picard_MarkDuplicatesWithMateCigar',
#  '442': 'FastTree',
#  '443': 'je_markdupes',
#  '444': 'smf_utils_extract-boxed-sequences',
#  '445': 'trimmomatic',
#  '446': 'DatamashOps',
#  '447': 'SequenceCoverageCalculator',
#  '448': 'nspdk_sparse',
#  '449': 'nanoplot',
#  '450': 'interproscan',
#  '451': 'mycrobiota-correct-replicates',
#  '452': 'gatk2_realigner_target_creator',
#  '453': 'bedtools_bedtobam',
#  '454': 'translate_bed_sequences',
#  '455': 'rsem_prepare_reference',
#  '456': 'p_clip_peaks',
#  '457': 'cshl_fastx_nucleotides_distribution',
#  '458': 'bwameth',
#  '459': 'mass_spectrometry_imaging_ion_images',
#  '460': 'fasta_filter_by_length',
#  '461': 'Remove beginning1',
#  '462': 'bedtools_annotatebed',
#  '463': 'scpipe',
#  '464': 'qiime_make_phylogeny',
#  '465': 'bedtools_intersectBed',
#  '466': 'gops_basecoverage_1',
#  '467': 'gatk2_variant_recalibrator',
#  '468': 'bedtools_genomecoveragebed_bedgraph',
#  '469': 'EMBOSS: water107',
#  '470': 'MzTabExporter',
#  '471': 'Nucleosome',
#  '472': 'ctb_ob_genProp',
#  '473': 'MapAlignerPoseClustering',
#  '474': 'FROGS_affiliation_OTU',
#  '475': 'smf_utils_estimate-energy',
#  '476': 'picard_MergeSamFiles',
#  '477': 'locarna_multiple',
#  '478': 'cshl_fastx_artifacts_filter',
#  '479': 'vt_normalize',
#  '480': 'samtools_stats',
#  '481': 'allele_counts_1',
#  '482': 'column_remove_by_header',
#  '483': 'Remove_ending',
#  '484': 'EMBOSS: newseq59',
#  '485': 'Cut1',
#  '486': 'flexbar_split_RYYR_bcs',
#  '487': 'gatk_indel_realigner',
#  '488': 'tabular_to_fastq',
#  '489': 'mothur_taxonomy_to_krona',
#  '490': 'gatk2_variant_select',
#  '491': 'msconvert2_raw',
#  '492': 'Grep1',
#  '493': 'mothur_make_shared',
#  '494': 'vcfannotate',
#  '495': 'ggplot2_heatmap2',
#  '496': 'cshl_word_list_grep',
#  '497': 'CONVERTER_interval_to_bed_0',
#  '498': 'bam-filter',
#  '499': 'methtools_filter',
#  '500': 'velvet',
#  '501': 'join_files_on_column_fuzzy',
#  '502': 'cshl_grep_tool',
#  '503': 'scaffold2fasta',
#  '504': 'bg_sortmerna',
#  '505': 'ggplot2_histogram',
#  '506': 'nanopolish_variants',
#  '507': 'cuffdiff',
#  '508': 'graphclust_glob_report_no_align',
#  '509': 'rbc_mirdeep2_mapper',
#  '510': 'sequence_content_trimmer',
#  '511': 'heinz_visualization',
#  '512': 'heatmap2',
#  '513': 'multiqc',
#  '514': 'NFS_transfer',
#  '515': 'macs2_bdgcmp',
#  '516': 'mothur_remove_lineage',
#  '517': 'minfi_getM',
#  '518': 'hmmer_hmmsearch',
#  '519': 'gops_cluster_1',
#  '520': 'mothur_chimera_uchime',
#  '521': 'filtlong',
#  '522': 'rsem_calculate_expression',
#  '523': 'deeptools_correct_gc_bias',
#  '524': 'freebayes',
#  '525': 'ngsutils_bam_filter',
#  '526': 'bamleftalign',
#  '527': 'flye',
#  '528': 'wc_gnu',
#  '529': 'maldi_quant_peak_detection',
#  '530': 'CONVERTER_bed_to_gff_0',
#  '531': 'EMBOSS: fuzztran39',
#  '532': 'Filter1',
#  '533': 'bedtools_sortbed',
#  '534': 'samtools_idxstats',
#  '535': 'convert_bc_to_binary_RY.py',
#  '536': 'mothur_align_seqs',
#  '537': 'dexseq_annotate',
#  '538': 'table_annovar',
#  '539': 'bwa_mem',
#  '540': 'umi_tools_group',
#  '541': 'mothur_classify_rf',
#  '542': 'deeptools_plot_pca',
#  '543': 'peakachu',
#  '544': 'sklearn_nn_classifier',
#  '545': 'cummeRbund',
#  '546': 'proteomics_moff',
#  '547': 'cuffnorm',
#  '548': 'regex1',
#  '549': 'tp_awk_tool',
#  '550': 'nn_classifier',
#  '551': 'samtools_filter',
#  '552': 'qiime_count_seqs',
#  '553': 'proteomics_search_peptide_prophet_1',
#  '554': 'vcfallelicprimitives',
#  '555': 'Add_a_column1',
#  '556': 'iuc_pear',
#  '557': 'EMBOSS: getorf42',
#  '558': 'deeptools_plot_fingerprint',
#  '559': 'snippy_core',
#  '560': 'GeneModelMapper',
#  '561': 'sam_pileup',
#  '562': 'blastxml_to_tabular_selectable',
#  '563': 'trim_galore',
#  '564': 'bedtools_unionbedgraph',
#  '565': 'snpEff_download',
#  '566': 'antismash',
#  '567': 'je_clip',
#  '568': 'mothur_make_biom',
#  '569': 'get_read_pipeline',
#  '570': 'CONVERTER_sam_to_unsorted_bam',
#  '571': 'fastq_groomer',
#  '572': 'mimodd_map',
#  '573': 'sklearn_build_pipeline',
#  '574': 'deeptools_compute_matrix_operations',
#  '575': 'blockclust',
#  '576': 'msconvert_nix',
#  '577': 'hcluster_sg_parser',
#  '578': 'Batch_correction',
#  '579': 'flexbar',
#  '580': 'ConsensusMapNormalizer',
#  '581': '__MERGE_COLLECTION__',
#  '582': 'rseqc_read_distribution',
#  '583': 'biosigner',
#  '584': 'filter_by_fasta_ids',
#  '585': 'picard_ReorderSam',
#  '586': 'locarna_best_subtree',
#  '587': 'gops_subtract_1',
#  '588': 'vcftools_annotate',
#  '589': 'bedtools_map',
#  '590': 'Psortb',
#  '591': 'rbc_rnacode',
#  '592': 'smooth_running_window',
#  '593': 'TrimByN',
#  '594': 'tag_stat2',
#  '595': 'gops_intersect_1',
#  '596': 'mass_spectrometry_imaging_preprocessing',
#  '597': 'methtools_tiling',
#  '598': 'bowtie_wrapper',
#  '599': 'metilene',
#  '600': 'rseqc_geneBody_coverage',
#  '601': 'treebest_best',
#  '602': 'flexbar_no_split',
#  '603': 'graphclust_aggregate_alignments',
#  '604': 'FeatureLinkerUnlabeled',
#  '605': 'vcftools_merge',
#  '606': 'fastq_combiner',
#  '607': 'diffbind-embl',
#  '608': 'pileup_parser',
#  '609': 'gatk2_unified_genotyper',
#  '610': 'metaphlan2',
#  '611': 'minfi_dropsnp',
#  '612': 'valet',
#  '613': 'naive_variant_caller',
#  '614': 'computeMatrix',
#  '615': 'bedtools_slopbed',
#  '616': 'FileMerger',
#  '617': 'rseqc_bam2wig',
#  '618': 'methtools_plot',
#  '619': 'Extract genomic DNA 1',
#  '620': 'minfi_dmr',
#  '621': 'Univariate',
#  '622': 'cshl_fastx_clipper',
#  '623': 'preproc',
#  '624': 'align_families',
#  '625': '__ZIP_COLLECTION__',
#  '626': 'proteomics_search_tandem_1',
#  '627': 'bandage_image',
#  '628': 'prokaryotic_ncbi_submission',
#  '629': 'ggplot2_point',
#  '630': 'mothur_cluster',
#  '631': 'remove_tail.py',
#  '632': 'PeptideIndexer',
#  '633': 'mothur_make_contigs',
#  '634': '__FLATTEN__',
#  '635': 'smf_utils_find-boxes',
#  '636': 'extract_element_from_collection',
#  '637': 'ncbi_tblastn_wrapper',
#  '638': 'plotly_ml_performance_plots',
#  '639': 'rmcontamination',
#  '640': 'fastq_filter',
#  '641': 'map_peptides_to_bed',
#  '642': 'snpsift_vartype',
#  '643': 'minfi_getbeta',
#  '644': 'ctb_chemfp_mol2fps',
#  '645': 'Btrim64',
#  '646': 'tp_split_on_column',
#  '647': 'bowtie2',
#  '648': 'FROGS_remove_chimera',
#  '649': 'tp_unfold_column_tool',
#  '650': 'get_feature_info',
#  '651': 'tp_sort_header_tool',
#  '652': 'gafa',
#  '653': 'bismark_bowtie2',
#  '654': 'IDPosteriorErrorProbability',
#  '655': 'mothur_tree_shared',
#  '656': 'comp1',
#  '657': 'samtools_rmdup',
#  '658': 'ProteinQuantifier',
#  '659': 'tsne',
#  '660': 'bctools_extract_crosslinked_nucleotides',
#  '661': 'humann2',
#  '662': 'rarefaction_analyzer',
#  '663': 'mothur_screen_seqs',
#  '664': 'XTandemAdapter',
#  '665': 'deeptools_multi_bam_summary',
#  '666': 'meme_meme',
#  '667': 'r_correlation_matrix',
#  '668': 'vcfsort',
#  '669': 'bamCoverage_deepTools',
#  '670': 'fastq_paired_end_splitter',
#  '671': 'bedtools_coveragebed',
#  '672': 'qiime_split_libraries_fastq',
#  '673': 'megahit',
#  '674': 'picard_SamToFastq',
#  '675': 'svm_classifier',
#  '676': 'minfi_read450k',
#  '677': 'seq_filter_by_id',
#  '678': 'unicycler',
#  '679': 'bwa_wrapper',
#  '680': '__SORTLIST__',
#  '681': 'IDFileConverter',
#  '682': 'hicexplorer_hicsummatrices',
#  '683': 'Draw_phylogram',
#  '684': 'heatmapper_deepTools',
#  '685': 'ncbi_blastn_wrapper',
#  '686': 'metams_runGC',
#  '687': 'cshl_uniq_tool',
#  '688': 'vcfflatten2',
#  '689': 'fastq_dump',
#  '690': 'ProteinResolver',
#  '691': 'qiime_core_diversity',
#  '692': 'hicexplorer_hicfindtads',
#  '693': 'hicexplorer_hicpca',
#  '694': 'deeptools_bamCompare',
#  '695': 'ncbi_makeblastdb',
#  '696': 'chipsequtil_maptoknowngenes',
#  '697': 'cummerbund_to_cuffdiff',
#  '698': 'Datamash',
#  '699': 'abricate',
#  '700': 'gmx_md',
#  '701': 'goseq',
#  '702': 'bam_to_sam',
#  '703': 'FeatureFinderMultiplex',
#  '704': 'QCCalculator',
#  '705': 'transdecoder',
#  '706': 'viennarna_rnaplot',
#  '707': 'idpqonvert',
#  '708': 'idpquery',
#  '709': 'rseqc_inner_distance',
#  '710': 'CONVERTER_gff_to_bed_0',
#  '711': 'picard_CASM',
#  '712': 'filter_bed_on_splice_junctions',
#  '713': 'raceid_inspectclusters',
#  '714': 'hgv_snpFreq',
#  '715': 'rgPicFixMate',
#  '716': 'tp_cut_tool',
#  '717': 'seurat',
#  '718': 'gd_raxml',
#  '719': 'stacks_procrad',
#  '720': '16Sclassifier',
#  '721': 'gatk2_indel_realigner',
#  '722': 'graphclust_align_cluster',
#  '723': 'gatk2_variant_filtration',
#  '724': 'lfq_protein_quant',
#  '725': 'w4mjoinpn',
#  '726': 'fastq_trimmer',
#  '727': 'cshl_fastx_collapser',
#  '728': 'Summary_Statistics1',
#  '729': '16Saligner',
#  '730': 'mass_spectrometry_imaging_combine',
#  '731': 'gatk2_variant_apply_recalibration',
#  '732': 'mycrobiota-make-multi-otutable',
#  '733': 'samtools_flagstat',
#  '734': 'EMBOSS: seqret84',
#  '735': 'get_subontology_from',
#  '736': 'dexseq',
#  '737': 'mcClust',
#  '738': 'abims_xcms_group',
#  '739': 'deeptools_bam_compare',
#  '740': 'wiggle2simple1',
#  '741': 'racon',
#  '742': 'qiime_assign_taxonomy',
#  '743': 'umi_tools_dedup',
#  '744': 'vcfgenotypes',
#  '745': 'sample_seqs',
#  '746': 'raceid_clustering',
#  '747': 'resistome_analyzer',
#  '748': 'hicexplorer_hiccorrectmatrix',
#  '749': 'trim_reads',
#  '750': 'snpSift_geneSets',
#  '751': 'sklearn_ensemble',
#  '752': 'iReport',
#  '753': 'blockbuster',
#  '754': 'annotatemyids',
#  '755': 'idpassemble',
#  '756': 'tophat2',
#  '757': 'Determine_BC',
#  '758': 'rbc_mirdeep2',
#  '759': 'edger',
#  '760': 'IDMassAccuracy',
#  '761': 'MultiplexResolver',
#  '762': 'cmFinder',
#  '763': 'snippy',
#  '764': 'porechop',
#  '765': 'hgv_david',
#  '766': 'bedtools_getfastabed',
#  '767': 'Interval_Maf_Merged_Fasta2',
#  '768': 'CONVERTER_fasta_to_tabular',
#  '769': 'Extract_RNA_seq_Evidence',
#  '770': 'regex_replace',
#  '771': 'graphicsmagick_image_convert',
#  '772': 'metaphlan2krona',
#  '773': 'picard_CleanSam',
#  '774': 'quast',
#  '775': 'deeptools_multi_bigwig_summary',
#  '776': 'smf_utils_filter-by-energy',
#  '777': 'gatk_depth_of_coverage',
#  '778': 'qiime_align_seqs',
#  '779': 'eden_vectorizer',
#  '780': 'sam_bw_filter',
#  '781': 'vcfcombine',
#  '782': 'ctb_remSmall',
#  '783': 'mothur_get_communitytype',
#  '784': 'ctb_filter',
#  '785': 'salmon',
#  '786': 'fastq_to_tabular',
#  '787': 'EMBOSS: transeq101',
#  '788': 'XY_Plot_1',
#  '789': 'pilon',
#  '790': 'DecoyDatabase',
#  '791': 'tp_grep_tool',
#  '792': 'pileup_interval',
#  '793': 'segemehl',
#  '794': 'picard_NormalizeFasta',
#  '795': 'bcftools_consensus',
#  '796': 'deeptools_bamCorrelate',
#  '797': 'fastq collapser',
#  '798': 'mothur_heatmap_bin',
#  '799': 'cat1',
#  '800': 'augustus',
#  '801': 'Digestor',
#  '802': 'pieplots_macs',
#  '803': 'FROGS_filters',
#  '804': 'minfi_getanno',
#  '805': 'FeatureLinkerUnlabeledQT',
#  '806': 'vegan_rarefaction',
#  '807': 'NSPDK_candidateClust',
#  '808': 'fastq_paired_end_interlacer',
#  '809': 'macs2_callpeak',
#  '810': 'gemini_de_novo',
#  '811': 'bamtools',
#  '812': '__UNZIP_COLLECTION__',
#  '813': 'flanking_features_1',
#  '814': 'merge_pcr_duplicates.py',
#  '815': 'mimodd_varcall',
#  '816': 'DatamashTranspose',
#  '817': 'barchart_gnuplot',
#  '818': 'cardinal_filtering',
#  '819': 'raceid_inspecttrajectory',
#  '820': 'cshl_fastx_barcode_splitter',
#  '821': 'cuffmerge',
#  '822': 'deeptools_bigwig_compare',
#  '823': 'xpath',
#  '824': 'cshl_princeton_fastx_barcode_splitter',
#  '825': 'charts',
#  '826': 'viennarna_rnafold',
#  '827': 'CONVERTER_bedgraph_to_bigwig',
#  '828': 'IDScoreSwitcher',
#  '829': 'proteomics_search_protein_prophet_1',
#  '830': 'bedtools_multicovtbed',
#  '831': 'bcftools_view',
#  '832': 'w4mcorcov',
#  '833': 'get_flanks1',
#  '834': 'paralyzer',
#  '835': 'gemini_pathways',
#  '836': 'preMloc',
#  '837': 'deeptools_profiler',
#  '838': 'gmx_em',
#  '839': 'EMBOSS: revseq82',
#  '840': 'decoyfasta',
#  '841': 'tp_sed_tool',
#  '842': 'CONVERTER_gz_to_uncompressed',
#  '843': 'wig_to_bigWig',
#  '844': 'createInterval',
#  '845': 'cardinal_preprocessing',
#  '846': 'stringtie',
#  '847': 'mothur_dist_seqs',
#  '848': 'flexbardsc',
#  '849': 'bismark_bowtie',
#  '850': 'snpSift_filter',
#  '851': 'ctb_online_data_fetch',
#  '852': 'gene2exon1',
#  '853': 'gatk_realigner_target_creator',
#  '854': 'modencode_peakcalling_spp',
#  '855': 'annotateMyIDs',
#  '856': 'samtools_mpileup',
#  '857': 'mothur_amova',
#  '858': 'mothur_summary_single',
#  '859': 're_he_maldi_image_registration',
#  '860': 'sqlite_to_tabular',
#  '861': 'humann2_renorm_table',
#  '862': 'macs2_predictd',
#  '863': 'glimmer_not-knowlegde-based',
#  '864': 'goenrichment',
#  '865': 'picard_SortSam',
#  '866': 'lca1',
#  '867': 'correct_barcodes',
#  '868': 'cshl_fastx_renamer',
#  '869': 'bed2gff1',
#  '870': 'cshl_fastx_quality_statistics',
#  '871': 'bed_to_bigwig',
#  '872': 'picard_BamIndexStats',
#  '873': 'bgchem_fragment_merger',
#  '874': 'rarefaction',
#  '875': 'bedtools_intersectbed',
#  '876': 'glob_report',
#  '877': 'qiime_pick_otus',
#  '878': 'cardinal_spectra_plots',
#  '879': 'mimodd_varextract',
#  '880': 'mothur_phylotype',
#  '881': 'bedtools_windowbed',
#  '882': 'MassCalculator',
#  '883': 'bed_to_bigBed',
#  '884': 'group_humann2_uniref_abundances_to_go',
#  '885': 'graphlan',
#  '886': 'kallisto_quant',
#  '887': 'sickle',
#  '888': 'fraggenescan',
#  '889': 'tp_sort_rows',
#  '890': 'methtools_calling',
#  '891': 'je_demultiplex',
#  '892': 'tp_uniq_tool',
#  '893': 'secretbt2test',
#  '894': 'fastq_paired_end_deinterlacer',
#  '895': 'mothur_nmds',
#  '896': 'hicexplorer_hicplottads',
#  '897': 'term_id_vs_term_name',
#  '898': 'mass_spectrometry_imaging_mzplots',
#  '899': 'bg_statistical_hypothesis_testing',
#  '900': 'combine_metaphlan2_humann2',
#  '901': 'fasttree',
#  '902': 'sklear_numeric_clustering',
#  '903': 'search_gui',
#  '904': 'ssake',
#  '905': 'heinz_bum',
#  '906': 'samtools_calmd',
#  '907': 'stacks_refmap',
#  '908': 'replace_column_with_key_value_file',
#  '909': 'gatk_unified_genotyper',
#  '910': 'qiime_validate_mapping_file',
#  '911': 'meme_psp_gen',
#  '912': 'genbank_to_gff',
#  '913': 'unipept',
#  '914': 'infernal_cmsearch',
#  '915': 'query_tabular',
#  '916': 'cd_hit_dup',
#  '917': 'EMBOSS: tranalign100',
#  '918': 'vsearch_dereplication',
#  '919': 'fastq_manipulation',
#  '920': 'EMBOSS: extractseq35',
#  '921': 'umi_tools_extract',
#  '922': 'gff_filter_by_attribute',
#  '923': 'rna_star',
#  '924': 'deeptools_bam_coverage',
#  '925': 'coords2clnt.py',
#  '926': 'fastq_to_fasta_python',
#  '927': 'cshl_fastq_to_fasta',
#  '928': 'fasta-stats',
#  '929': 'snpeff_to_peptides',
#  '930': 'goslimmer',
#  '931': 'htseq_count',
#  '932': 'sed_stream_editor',
#  '933': 'HighResPrecursorMassCorrector',
#  '934': 'rseqc_read_duplication',
#  '935': 'rseqc_junction_saturation',
#  '936': 'rbc_mirdeep2_quantifier',
#  '937': 'FileConverter',
#  '938': 'FROGS_affiliations_stat',
#  '939': 'cufflinks_prok',
#  '940': 'velveth_jgi',
#  '941': 'peptide_shaker',
#  '942': 'hisat2',
#  '943': 'deeptools_computeMatrix',
#  '944': 'snpfinder',
#  '945': 'gops_concat_1',
#  '946': 'featurecounts',
#  '947': 'abims_CAMERA_annotateDiffreport',
#  '948': 'minfi_methcpg',
#  '949': 'FidoAdapter',
#  '950': 'vcf2tsv',
#  '951': 'velvetoptimiser',
#  '952': 'tmhmm2',
#  '953': 'meme_dreme',
#  '954': 'meme_chip',
#  '955': 'mothur_classify_seqs',
#  '956': 'ucsc-twobittofa',
#  '957': 'cshl_easyjoin',
#  '958': 'humann2_genefamilies_genus_level',
#  '959': 'mothur_get_groups',
#  '960': 'Show beginning1',
#  '961': 'predict_pipeline',
#  '962': 'kraken',
#  '963': 'cshl_fastq_quality_filter',
#  '964': 'mothur_filter_seqs',
#  '965': 'methtools_dmr',
#  '966': 'samtools_flag_filter',
#  '967': 'bigwig_to_bedgraph',
#  '968': 'vcffixup',
#  '969': 'seq_composition',
#  '970': 'fastq_join',
#  '971': 'mothur_corr_axes'}

# %%
def verify_model(model, tool_sequence, labels, dictionary, reverse_dictionary, compatible_tools, topk=30, max_seq_len=25):
    tl_seq = tool_sequence.split(",")
    last_tool_name = reverse_dictionary[str(tl_seq[-1])]
    last_compatible_tools = compatible_tools[last_tool_name]
    sample = np.zeros(max_seq_len)
    for idx, tool_id in enumerate(tl_seq):
        sample[idx] = int(tool_id)
    sample_reshaped = np.reshape(sample, (1, max_seq_len))
    
    tool_sequence_names = [reverse_dictionary[str(tool_pos)] for tool_pos in tool_sequence.split(",")]
    print("Tool seq: %s" % ",".join(tool_sequence_names))
    # predict next tools for a test path
    prediction = model.predict(sample_reshaped, verbose=0)
    prediction = np.reshape(prediction, (prediction.shape[1],))
    prediction_pos = np.argsort(prediction, axis=-1)

    # get topk prediction
    topk_prediction_pos = prediction_pos[-topk:]
    topk_prediction_val = [np.round(prediction[pos] * 100, 2) for pos in topk_prediction_pos]

    # read tool names using reverse dictionary
    pred_tool_ids = [reverse_dictionary[str(tool_pos)] for tool_pos in topk_prediction_pos]
    actual_next_tool_ids = list(set(pred_tool_ids).intersection(set(last_compatible_tools.split(","))))      
        
    #print("Predicted tools: %s" % ",".join(pred_tool_ids))
    print()
    pred_tool_ids_sorted = dict()
    for (tool_pos, tool_pred_val) in zip(topk_prediction_pos, topk_prediction_val):
        tool_name = reverse_dictionary[str(tool_pos)]
        if tool_name in actual_next_tool_ids:
            pred_tool_ids_sorted[tool_name] = tool_pred_val
    pred_tool_ids_sorted = dict(sorted(pred_tool_ids_sorted.items(), key=lambda kv: kv[1], reverse=True))
    
    cls_wt = dict()
    usg_wt = dict()
    inv_wt = dict()
    ids_tools = dict()
    keys = list(pred_tool_ids_sorted.keys())
    for k in keys:
        try:
            cls_wt[k] = np.round(class_weights[str(data_dict[k])], 6)
            usg_wt[k] = np.round(usage_weights[k], 6)
            inv_wt[k] = np.round(inverted_weights[str(data_dict[k])], 6)
        except:
            continue
    print("Predicted tools: \n")
    print(pred_tool_ids_sorted)
    print()
    print("Class weights: \n")
    cls_wt = dict(sorted(cls_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(cls_wt)
    print()
    print("Usage weights: \n")
    usg_wt = dict(sorted(usg_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(usg_wt)
    print()
    total_usage_wt = np.mean(list(usg_wt.values()))
    total_pred_score = np.mean(list(pred_tool_ids_sorted.values()))
    print("Mean usage wt: %0.4f, Mean prediction score: %0.4f, Sum: %0.4f" % (total_usage_wt, total_pred_score, (total_usage_wt + total_pred_score)))
    print()
    print("Inverted weights: \n")
    inv_wt = dict(sorted(inv_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(inv_wt)
    for key in pred_tool_ids_sorted:
        ids_tools[key] = dictionary[key]
    print()
    print("Tool ids")
    print(ids_tools)
    print("======================================")
    return cls_wt, usg_wt, inv_wt, pred_tool_ids_sorted

topk = 10
# 895,533,260,894,596,114,297,896,387,626,486,720,361,283,943
tool_seq = "647,342" #,647,931,227,532,261,485
class_wt, usage_wt, inverse_wt, pred_tools = verify_model(model, tool_seq, "", dictionary, reverse_dictionary, compatibile_tools, topk)
# Out:
# Tool seq: bowtie2,hicexplorer_hicbuildmatrix
#
# Predicted tools:
#
# {'hicexplorer_hicplotmatrix': 0.68}
#
# Class weights:
#
# {'hicexplorer_hicplotmatrix': 126.036026}
#
# Usage weights:
#
# {'hicexplorer_hicplotmatrix': 126.036026}
#
# Mean usage wt: 126.0360, Mean prediction score: 0.6800, Sum: 126.7160
#
# Inverted weights:
#
# {'hicexplorer_hicplotmatrix': 4781.857143}
#
# Tool ids
# {'hicexplorer_hicplotmatrix': 63}
# ======================================

# %%
list_cls_wt = list()
list_usage_wt = list()
list_pred_wt = list()
division_pt = int(len(pred_tools) / 2)

for tool in pred_tools:
    list_pred_wt.append(pred_tools[tool])
    try:
        list_cls_wt.append(class_wt[tool])
    except:
        list_cls_wt.append(1)

def plot_scatter(y_val, title, xlabel, ylabel):
    x_val = range(1, len(y_val) + 1)
    plt.figure(figsize=(8, 8))
    plt.plot(x_val[:division_pt], y_val[:division_pt], 'ro')
    plt.plot(x_val[division_pt:], y_val[division_pt:], 'b^')
    plt.xlabel(xlabel, size=size_label)
    plt.ylabel(ylabel, size=size_label)
    plt.legend([("First top-%s" % str(division_pt)), ("Next top-%s" % str(division_pt))])
    plt.title(title, size=size_title)
    plt.grid(True)
    plt.show()

plot_scatter(list_cls_wt, "Usage weights for tools", "Number of tools", "Class weights")
#plot_scatter(ave_prediction_weights, ave_usage_weights, "Prediction vs usage weights", "Prediction scores", "Usage weights")
#plot_scatter(ave_prediction_weights, ave_inverted_weights, "Prediction vs inverted weights", "Prediction scores", "Inverted weights")
