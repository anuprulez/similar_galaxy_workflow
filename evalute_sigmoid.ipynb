# %%
import numpy as np
import json
import warnings
import operator

import h5py
from keras.models import model_from_json
from keras import backend as K

from matplotlib import pyplot as plt

warnings.filterwarnings("ignore")

size_title = 18
size_label = 14
n_pred = 2

base_path = "data/evalute_sigmoid/"

path_data_dict = base_path + "data_dict.txt"
path_inverted_wt = base_path + "inverted_weights.txt"
path_usage_wt = base_path + "usage_prediction.txt"
path_class_wt = base_path + "class_weights.txt"
path_test_data = base_path + "test_paths_dict.txt"
model_path = base_path + "trained_model.hdf5"

def read_file(file_path):
    with open(file_path, 'r') as data_file:
        data = json.loads(data_file.read())
    return data

class_weights = read_file(path_class_wt)
usage_weights = read_file(path_usage_wt)
inverted_weights = read_file(path_inverted_wt)
data_dict = read_file(path_data_dict)

def create_model(model_path):
    trained_model = h5py.File(model_path, 'r')
    model_config = json.loads(trained_model.get('model_config').value)
    loaded_model = model_from_json(model_config)
    dictionary = json.loads(trained_model.get('data_dictionary').value)
    compatibile_tools = json.loads(trained_model.get('compatible_tools').value)
    reverse_dictionary = dict((str(v), k) for k, v in dictionary.items())
    model_weights = list()
    weight_ctr = 0
    while True:
        try:
            d_key = "weight_" + str(weight_ctr)
            weights = trained_model.get(d_key).value
            model_weights.append(weights)
            weight_ctr += 1
        except Exception as exception:
            break
    # set the model weights
    loaded_model.set_weights(model_weights)
    return loaded_model, dictionary, reverse_dictionary, compatibile_tools

model, dictionary, reverse_dictionary, compatibile_tools = create_model(model_path)
# Out:
# Using TensorFlow backend.

# %%
reverse_dictionary
# Out:
# {'1': 'heinz_visualization',
#  '2': 'hicexplorer_hicpca',
#  '3': 'get_read_pipeline',
#  '4': 'ExtractFASTAfromFASTQ',
#  '5': 'NSPDK_candidateClust',
#  '6': 'transpose',
#  '7': 'bctools_remove_tail',
#  '8': 'methtools_plot',
#  '9': 'heinz',
#  '10': 'table_annovar',
#  '11': 'lfq_protein_quant',
#  '12': 'minfi_rset',
#  '13': 'comp1',
#  '14': 'wc_gnu',
#  '15': 'mothur_classify_rf',
#  '16': 'deeptools_bamCompare',
#  '17': 'lca1',
#  '18': 'bg_protein_properties',
#  '19': 'rnbeads',
#  '20': 'edger',
#  '21': 'PicardASMetrics',
#  '22': 'fastq_paired_end_interlacer',
#  '23': 'EMBOSS: wordcount109',
#  '24': 'sklearn_ensemble',
#  '25': 'Batch_correction',
#  '26': 'rseqc_read_duplication',
#  '27': 'Paste1',
#  '28': 'viennarna_rnaplot',
#  '29': 'MAF_To_Fasta1',
#  '30': 'heatmap2',
#  '31': 'CONVERTER_bed_gff_or_vcf_to_bigwig_0',
#  '32': 'gd_raxml',
#  '33': 'deeptools_plot_enrichment',
#  '34': 'Grouping1',
#  '35': 'cshl_fastx_renamer',
#  '36': 'eden_vectorizer',
#  '37': 'melt',
#  '38': 'velvetg_jgi',
#  '39': 'abims_xcms_summary',
#  '40': 'deeptools_heatmapper',
#  '41': 'methtools_calling',
#  '42': 'vcfcombine',
#  '43': 'sklearn_build_pipeline',
#  '44': 'rm_spurious_events.py',
#  '45': 'blastxml_to_top_descr',
#  '46': '__SORTLIST__',
#  '47': 'tp_replace_in_column',
#  '48': 'qiime_make_otu_heatmap',
#  '49': 'hicexplorer_hicbuildmatrix',
#  '50': 'macs2_predictd',
#  '51': 'dexseq',
#  '52': 'maldi_quant_preprocessing',
#  '53': 'ncbi_rpsblast_wrapper',
#  '54': 'blockclust',
#  '55': 'vcfvcfintersect',
#  '56': 'kraken-report',
#  '57': 'clustalw',
#  '58': 'Cut1',
#  '59': 'fastq_trimmer',
#  '60': 'ncbi_makeblastdb',
#  '61': 'picard_AddOrReplaceReadGroups',
#  '62': 'convert_bc_to_binary_RY.py',
#  '63': 'ete_homology_classifier',
#  '64': 'bamCompare_deepTools',
#  '65': 'egsea',
#  '66': 'align_families',
#  '67': 'mothur_pre_cluster',
#  '68': 'vcfbedintersect',
#  '69': 'seurat',
#  '70': 'bctools_extract_crosslinked_nucleotides',
#  '71': 'svm_classifier',
#  '72': 'decoyfasta',
#  '73': 'mothur_count_seqs',
#  '74': 'circgraph',
#  '75': 'hicexplorer_hicplottads',
#  '76': 'stacks_populations',
#  '77': 'raceid_trajectory',
#  '78': 'mothur_align_seqs',
#  '79': 'ChooseTag',
#  '80': 'addName',
#  '81': 'PicardInsertSize',
#  '82': 'metaphlan2',
#  '83': 'naive_variant_caller',
#  '84': 'samtools_split',
#  '85': 'meme_meme',
#  '86': 'cshl_find_and_replace',
#  '87': 'gmx_nvt',
#  '88': 'cardinal_combine',
#  '89': 'bwa_wrapper',
#  '90': 'minfi_dropsnp',
#  '91': 'metaspades',
#  '92': 'meme_fimo',
#  '93': 'prokaryotic_ncbi_submission',
#  '94': 'flanking_features_1',
#  '95': 'gemini_de_novo',
#  '96': 'EMBOSS: newseq59',
#  '97': 'gemini_recessive_and_dominant',
#  '98': 'barchart_gnuplot',
#  '99': 'hicexplorer_hicfindtads',
#  '100': 'MassCalculator',
#  '101': 'dexseq_count',
#  '102': 'gops_concat_1',
#  '103': 'rbc_mirdeep2',
#  '104': 'cshl_cut_tool',
#  '105': 'rbc_mirdeep2_quantifier',
#  '106': 'mothur_trim_seqs',
#  '107': 'term_id_vs_term_name',
#  '108': 'fragmenter',
#  '109': 'kraken',
#  '110': 'CONVERTER_interval_to_bgzip_0',
#  '111': 'bundle_collection',
#  '112': 'bedtools_bamtobed',
#  '113': 'seq_filter_by_id',
#  '114': 'smooth_running_window',
#  '115': 'gatk2_unified_genotyper',
#  '116': 'cshl_multijoin',
#  '117': 'collection_column_join',
#  '118': 'bismark_bowtie2',
#  '119': 'bamtools',
#  '120': '__FLATTEN__',
#  '121': 'MapStatistics',
#  '122': 'samtools_filter',
#  '123': 'ctb_chemfp_mol2fps',
#  '124': 'heinz_scoring',
#  '125': 'hcluster_sg_parser',
#  '126': 'peakcalling_macs14',
#  '127': 'goslimmer',
#  '128': 'mass_spectrometry_imaging_combine',
#  '129': 'qiime_make_phylogeny',
#  '130': 'sed_stream_editor',
#  '131': 'gmx_md',
#  '132': 'trimmer',
#  '133': 'samtools_stats',
#  '134': 'CONVERTER_gff_to_interval_index_0',
#  '135': 'gff_to_sequence',
#  '136': 'CONVERTER_interval_to_bed_0',
#  '137': 'openms_id_mapper',
#  '138': 'Datamash',
#  '139': 'raceid_clustering',
#  '140': 'FidoAdapter',
#  '141': 'export2graphlan',
#  '142': 'ip_projective_transformation_points',
#  '143': 'sam_pileup',
#  '144': 'megablast_wrapper',
#  '145': 'hicexplorer_hiccorrectmatrix',
#  '146': 'unicycler',
#  '147': 'mass_spectrometry_imaging_ion_images',
#  '148': 'bedtools_subtractbed',
#  '149': 'bedtools_shufflebed',
#  '150': 'Show beginning1',
#  '151': 'sklear_numeric_clustering',
#  '152': '__UNZIP_COLLECTION__',
#  '153': 'mycrobiota-split-multi-otutable',
#  '154': 'mothur_make_contigs',
#  '155': 'picard_NormalizeFasta',
#  '156': 'Show tail1',
#  '157': 'fasplit',
#  '158': 'methtools_destrand',
#  '159': 'gemini_comp_hets',
#  '160': 'gene2exon1',
#  '161': 'EMBOSS: textsearch98',
#  '162': 'mothur_amova',
#  '163': 'mycrobiota-correct-replicates',
#  '164': 'nspdk_sparse',
#  '165': 'qiime_pick_open_reference_otus',
#  '166': 'rna_star',
#  '167': 'multiqc',
#  '168': 'column_remove_by_header',
#  '169': 'mimodd_varreport',
#  '170': 'gatk_unified_genotyper',
#  '171': 'cshl_awk_replace_in_column',
#  '172': 'MapRTTransformer',
#  '173': 'bam_to_bigwig',
#  '174': 'TextExporter',
#  '175': 'seq_filter_by_mapping',
#  '176': 'sklearn_numeric_clustering',
#  '177': 'ctb_filter',
#  '178': 'rseqc_bam_stat',
#  '179': 'mothur_get_groups',
#  '180': 'bedtools_complementbed',
#  '181': 'FileMerger',
#  '182': 'gatk2_realigner_target_creator',
#  '183': 'dt_profiler',
#  '184': 'minfi_getbeta',
#  '185': 'CONVERTER_sam_to_unsorted_bam',
#  '186': 'mass_spectrometry_imaging_classification',
#  '187': 'FileInfo',
#  '188': 'tp_sort_header_tool',
#  '189': 'featurecounts',
#  '190': 'mass_spectrometry_imaging_filtering',
#  '191': 'CONVERTER_Bam_Bai_0',
#  '192': 'gff_filter_by_attribute',
#  '193': 'deeptools_computeMatrix',
#  '194': 'scpipe',
#  '195': 'idr-embl',
#  '196': 'FeatureLinkerUnlabeled',
#  '197': 'mothur_seq_error',
#  '198': 'annotateMyIDs',
#  '199': 'tp_cat',
#  '200': 'mimodd_varextract',
#  '201': 'rseqc_junction_saturation',
#  '202': 'plotly_ml_performance_plots',
#  '203': 'correct_barcodes',
#  '204': 'pileup_interval',
#  '205': 'cshl_fastx_quality_statistics',
#  '206': 'gatk2_variant_filtration',
#  '207': 'rmcontamination',
#  '208': 'mass_spectrometry_imaging_mzplots',
#  '209': 'predict_pipeline',
#  '210': 'vsearch_dereplication',
#  '211': 'fastq_dump',
#  '212': 'biosigner',
#  '213': 'FileFilter',
#  '214': 'smf_utils_estimate-energy',
#  '215': 'mothur_summary_seqs',
#  '216': 'mothur_cluster',
#  '217': 'mothur_cluster_split',
#  '218': 'glimmer_knowlegde-based',
#  '219': 'velvet',
#  '220': 'minimap2',
#  '221': 'mothur_phylotype',
#  '222': 'subtract_query1',
#  '223': 'paralyzer',
#  '224': 'locarna_best_subtree',
#  '225': 'picard_CASM',
#  '226': 'mothur_heatmap_bin',
#  '227': 'ChangeCase',
#  '228': 'mothur_heatmap_sim',
#  '229': 'velvetoptimiser',
#  '230': 'mothur_chimera_uchime',
#  '231': 'dbbuilder',
#  '232': 'smf_utils_extract-boxed-sequences',
#  '233': 'tophat_fusion_post',
#  '234': 'GeneModelMapper',
#  '235': 'bedtools_multiintersectbed',
#  '236': 'flexbar_no_split',
#  '237': 'EMBOSS: fuzztran39',
#  '238': 'flexbar_split_RR_bcs',
#  '239': '__ZIP_COLLECTION__',
#  '240': 'rbc_mafft',
#  '241': 'gspan',
#  '242': 'blockbuster',
#  '243': 'ctb_online_data_fetch',
#  '244': 'CONVERTER_fasta_to_tabular',
#  '245': 'samtools_calmd',
#  '246': 'tag_stat2',
#  '247': 'sailfish',
#  '248': 'qiime_split_libraries_fastq',
#  '249': 'CONVERTER_bedgraph_to_bigwig',
#  '250': 'Interval_Maf_Merged_Fasta2',
#  '251': 'quast',
#  '252': 'qiime_core_diversity',
#  '253': 'mothur_summary_single',
#  '254': 'deeptools_multi_bigwig_summary',
#  '255': 'scale_image',
#  '256': 'datamash_transpose',
#  '257': 'EMBOSS: transeq101',
#  '258': 'preproc',
#  '259': 'get_subontology_from',
#  '260': 'plotly_parallel_coordinates_plot',
#  '261': 'bam2wig',
#  '262': 'salmon',
#  '263': 'EMBOSS: tranalign100',
#  '264': 'flexbar',
#  '265': 'mothur_nmds',
#  '266': 'PeptideIndexer',
#  '267': 'sequence_content_trimmer',
#  '268': 'cuffnorm',
#  '269': 'bedtools_coveragebed',
#  '270': 'picard_ValidateSamFile',
#  '271': 'wsdl_hmdb',
#  '272': 'EMBOSS: extractseq35',
#  '273': 'pileometh',
#  '274': 'metilene',
#  '275': 'gffcompare',
#  '276': 'IDFilter',
#  '277': 'thermo_raw_file_converter',
#  '278': 'cshl_fastq_quality_filter',
#  '279': 'IDConflictResolver',
#  '280': 'igvtools_count',
#  '281': 'qiime_pick_otus',
#  '282': 'picard_EstimateLibraryComplexity',
#  '283': 'sickle',
#  '284': 'silac_analyzer',
#  '285': 'cshl_word_list_grep',
#  '286': 'tp_split_on_column',
#  '287': 'minfi_getM',
#  '288': 'samtools_flagstat',
#  '289': 'trim_galore',
#  '290': 'gatk2_variant_annotator',
#  '291': 'Extract_features1',
#  '292': 'random_lines1',
#  '293': 'qiime_align_seqs',
#  '294': 'bctools_extract_alignment_ends',
#  '295': 'chipseeker',
#  '296': 'graphlan',
#  '297': 'tophat',
#  '298': 'tabular_to_fastq',
#  '299': 'bedtools_annotatebed',
#  '300': 'glimmer_build-icm',
#  '301': 'gemini_pathways',
#  '302': 'vcfgenotypes',
#  '303': 'bwa',
#  '304': 'sklearn_nn_classifier',
#  '305': 'w4mclstrpeakpics',
#  '306': 'filter_by_fasta_ids',
#  '307': 'bams2ratio',
#  '308': 'secure_hash_message_digest',
#  '309': 'stringtie',
#  '310': 'deseq2_single',
#  '311': 'blast_parser',
#  '312': 'fastq_paired_end_joiner',
#  '313': 'PeakPickerHiRes',
#  '314': 'picard_ARRG',
#  '315': 'bcftools_call',
#  '316': 't2t_report',
#  '317': 'picard_MarkDuplicates',
#  '318': 'join1',
#  '319': 'FROGS_affiliation_OTU',
#  '320': 'myrimatch',
#  '321': 'ctb_silicos_qed',
#  '322': 'macs2_bdgcmp',
#  '323': 'coords2clnt.py',
#  '324': 'gemini_load',
#  '325': 'bedtools_windowbed',
#  '326': 'mothur_filter_seqs',
#  '327': 'methtools_filter',
#  '328': 'hisat2',
#  '329': 'snpEff',
#  '330': 'stacks_genotypes',
#  '331': 'cardinal_mz_images',
#  '332': 'minfi_methcpg',
#  '333': 'MSGFPlusAdapter',
#  '334': 'jbrowse',
#  '335': 'meme_dreme',
#  '336': 'vt_normalize',
#  '337': 'graphclust_glob_report_no_align',
#  '338': 'msconvert_nix',
#  '339': 'FeatureFinderMetabo',
#  '340': 'ConsensusID',
#  '341': 'mothur_make_group',
#  '342': 'bcftools_view',
#  '343': 'bedtools_mergebed',
#  '344': 'bg_diamond',
#  '345': 'trim_reads',
#  '346': '__FILTER_FROM_FILE__',
#  '347': 'chipsequtil_maptoknowngenes',
#  '348': 'wiggle2simple1',
#  '349': 'FileConverter',
#  '350': 'wig_to_bigWig',
#  '351': 'cshl_princeton_fastx_barcode_splitter',
#  '352': 'Summary_Statistics1',
#  '353': 'rseqc_infer_experiment',
#  '354': 'cshl_grep_tool',
#  '355': 'deeptools_plot_pca',
#  '356': 'gatk2_depth_of_coverage',
#  '357': 'vcf2pgSnp',
#  '358': 'bedtools_unionbedgraph',
#  '359': 'je_demultiplex',
#  '360': 'Digestor',
#  '361': 'htseq_count',
#  '362': 'bowtie2',
#  '363': 'mothur_get_oturep',
#  '364': 'vcf2tsv',
#  '365': 'rnafold',
#  '366': 'heatmapper',
#  '367': 'vcftools_isec',
#  '368': 'picard_CollectWgsMetrics',
#  '369': 'extract_aln_ends.py',
#  '370': 'mlocarna',
#  '371': 'addValue',
#  '372': 'ucsc-twobittofa',
#  '373': 'IDMerger',
#  '374': 'deeptools_plot_coverage',
#  '375': 'Extract genomic DNA 1',
#  '376': 'charts',
#  '377': 'cufflinks',
#  '378': 'CONVERTER_fasta_to_fai',
#  '379': 'cshl_easyjoin',
#  '380': 'Count1',
#  '381': 'hicexplorer_hictransform',
#  '382': 'interproscan',
#  '383': 'meme_psp_gen',
#  '384': 'vcftools_annotate',
#  '385': 'gemini_burden',
#  '386': 'vcfsort',
#  '387': 'gemini_interactions',
#  '388': 'xcms_merge',
#  '389': 'proteomics_search_peptide_prophet_1',
#  '390': 'gops_subtract_1',
#  '391': 'cutadapt',
#  '392': 'CONVERTER_gz_to_uncompressed',
#  '393': 'cshl_awk_tool',
#  '394': 'gmx_em',
#  '395': 'mothur_pcoa',
#  '396': 'hicexplorer_hicsummatrices',
#  '397': 'column_order_header_sort',
#  '398': 'cmv',
#  '399': 'genbank_to_gff',
#  '400': 'bedtools_map',
#  '401': 'bam-filter',
#  '402': 'checkFormat',
#  '403': 'Flash',
#  '404': 'pieplots_macs',
#  '405': 'Nucleosome',
#  '406': 'wolf_psort',
#  '407': 'rbc_rnacode',
#  '408': 'raceid_filtnormconf',
#  '409': 'vcf_filter',
#  '410': 'ncbi_blastn_wrapper',
#  '411': 'roary',
#  '412': 'EMBOSS: getorf42',
#  '413': 'freebayes',
#  '414': 'tp_grep_tool',
#  '415': 'rsem_calculate_expression',
#  '416': 'Convert characters1',
#  '417': 'IsobaricAnalyzer',
#  '418': 'cshl_fastx_trimmer',
#  '419': 'openms_protein_quantifier',
#  '420': 'mycrobiota-qc-report',
#  '421': 'samtools_sort',
#  '422': 'FeatureFinderCentroided',
#  '423': 'ctb_change_title',
#  '424': 'bed2gff1',
#  '425': 'picard_FixMateInformation',
#  '426': 'eden_sequence_converter',
#  '427': 'humann2',
#  '428': 'newick_display',
#  '429': 'humann2_genefamilies_genus_level',
#  '430': 'r_correlation_matrix',
#  '431': 'gmx_solvate',
#  '432': 'bedtools_multicovtbed',
#  '433': 'ssake',
#  '434': 'deeptools_profiler',
#  '435': 'infernal_cmsearch',
#  '436': 'modencode_peakcalling_spp',
#  '437': 'tp_text_file_with_recurring_lines',
#  '438': 'gops_merge_1',
#  '439': 'unipept',
#  '440': 'extract_bcs.py',
#  '441': 'bedtools_bedtobam',
#  '442': 'deeptools_plot_profile',
#  '443': 'gatk2_variant_recalibrator',
#  '444': 'mothur_corr_axes',
#  '445': 'cardinal_segmentations',
#  '446': 'mothur_rarefaction_single',
#  '447': 'cardinal_spectra_plots',
#  '448': 'valet',
#  '449': 'rbc_mirdeep2_mapper',
#  '450': 'rgPicardMarkDups',
#  '451': 'abricate',
#  '452': 'raceid_main',
#  '453': 'augustus',
#  '454': 'megahit',
#  '455': 'nonpareil',
#  '456': 'bedtools_slopbed',
#  '457': 'je_markdupes',
#  '458': 'cardinal_preprocessing',
#  '459': 'sort1',
#  '460': 'varscan_somatic',
#  '461': 'TrimByLength',
#  '462': 'deseq2',
#  '463': 'graphicsmagick_image_convert',
#  '464': 'gatk_indel_realigner',
#  '465': 'react_cal_pipeline',
#  '466': 't_coffee',
#  '467': 'query_tabular',
#  '468': 'hisat',
#  '469': 'deeptools_computeGCBias',
#  '470': 'deeptools_compute_gc_bias',
#  '471': 'mass_spectrometry_imaging_preprocessing',
#  '472': 'flexbar_split_RYYR_bcs',
#  '473': 'cummerbund_to_cuffdiff',
#  '474': 'bedtools_intersectbed_bam',
#  '475': 'tp_sorted_uniq',
#  '476': 'samtools_bedcov',
#  '477': 'FROGS_remove_chimera',
#  '478': 'SequenceCoverageCalculator',
#  '479': 'rgPicFixMate',
#  '480': 'ProteinQuantifier',
#  '481': 'gtftobed12',
#  '482': 'qiime_validate_mapping_file',
#  '483': 'merge_pcr_duplicates.py',
#  '484': 'tab2fasta',
#  '485': 'proteomics_search_protein_prophet_1',
#  '486': 'numeric_clustering',
#  '487': 'preMloc',
#  '488': 'cshl_fastx_artifacts_filter',
#  '489': 'ia_coordinates_of_roi',
#  '490': 'mycrobiota-make-multi-otutable',
#  '491': 'rcas',
#  '492': 'bedtools_genomecoveragebed',
#  '493': 'htseq-count',
#  '494': 'deeptools_correct_gc_bias',
#  '495': 'cshl_fastx_reverse_complement',
#  '496': 'search_gui',
#  '497': 'vcfflatten2',
#  '498': 'fastq_join',
#  '499': 'qiime_assign_taxonomy',
#  '500': 'regex1',
#  '501': 'gops_join_1',
#  '502': 'rbc_splitfasta',
#  '503': '__FILTER_FAILED_DATASETS__',
#  '504': 'vcffixup',
#  '505': 'bed_to_bigwig',
#  '506': 'replace_column_with_key_value_file',
#  '507': 'Multivariate',
#  '508': 'fastq_paired_end_deinterlacer',
#  '509': 'nn_classifier',
#  '510': 'porechop',
#  '511': 'tp_easyjoin_tool',
#  '512': 'hicexplorer_hicmergematrixbins',
#  '513': 'fastq_groomer',
#  '514': 'ruvseq',
#  '515': 'vcftools_merge',
#  '516': 'translate_bed_sequences',
#  '517': 'blast2go',
#  '518': 'CONVERTER_gff_to_bed_0',
#  '519': 'EMBOSS: fuzzpro38',
#  '520': 'NFS_transfer',
#  '521': 'ncbi_blastp_wrapper',
#  '522': 'mz_to_sqlite',
#  '523': 'bedtools_intersectbed',
#  '524': 'signalp3',
#  '525': 'fastq collapser',
#  '526': 'qiime_pick_rep_set',
#  '527': 'structure_to_gspan',
#  '528': 'bgchem_fragment_merger',
#  '529': 'tp_sort_rows',
#  '530': 'piranha',
#  '531': 'cuffcompare',
#  '532': 'bcftools_norm',
#  '533': 'get_sequences',
#  '534': 'Determine_BC',
#  '535': 'shovill',
#  '536': 'mothur_count_groups',
#  '537': 'vcfselectsamples',
#  '538': 'mothur_unique_seqs',
#  '539': 'selectsequencesfrommsa',
#  '540': 'tp_tac',
#  '541': 'deeptools_bamFingerprint',
#  '542': 'snpsift_vartype',
#  '543': 'scaffold2fasta',
#  '544': 'bedtools_intersectBed',
#  '545': 'fastq_quality_trimmer',
#  '546': 'bedtools_coveragebed_counts',
#  '547': 'ctb_simsearch',
#  '548': 'mergeCols1',
#  '549': 'gatk_realigner_target_creator',
#  '550': 'viennarna_rnafold',
#  '551': 'fastq_combiner',
#  '552': 'bedtools_sortbed',
#  '553': 'sqlite_to_tabular',
#  '554': 'MzTabExporter',
#  '555': 'deeptools_bamCorrelate',
#  '556': 'QCCalculator',
#  '557': 'CometAdapter',
#  '558': 'Draw_phylogram',
#  '559': 'XY_Plot_1',
#  '560': 'bwa_mem',
#  '561': 'picard_MarkDuplicatesWithMateCigar',
#  '562': 'disco',
#  '563': 'peakcalling_macs',
#  '564': 'picard_FilterSamReads',
#  '565': 'mothur_merge_files',
#  '566': 'rseqc_bam2wig',
#  '567': 'pynast',
#  '568': 'blastxml_to_tabular_selectable',
#  '569': 'picard_SortSam',
#  '570': 'filtlong',
#  '571': 'gmx_setup',
#  '572': 'gemini_db_info',
#  '573': 'msgfplus',
#  '574': 'bismark_bowtie',
#  '575': 'peakachu',
#  '576': 'deeptools_bamCoverage',
#  '577': 'antismash',
#  '578': 'mothur_homova',
#  '579': 'cuffmerge',
#  '580': 'snpSift_annotate',
#  '581': 'blastxml_to_tabular',
#  '582': 'smf_utils_filter-by-energy',
#  '583': 'graphclust_align_cluster',
#  '584': 'smf_utils_fix-fasta-headers',
#  '585': 'rseqc_geneBody_coverage',
#  '586': 'deeptools_multi_bam_summary',
#  '587': 'MapAlignerPoseClustering',
#  '588': 'mycrobiota-krona-mothur',
#  '589': 'vcfallelicprimitives',
#  '590': 'tp_uniq_tool',
#  '591': 'IDMassAccuracy',
#  '592': 'minfi_read450k',
#  '593': 'cshl_fastq_to_fasta',
#  '594': 'find_in_reference',
#  '595': 'mimodd_varcall',
#  '596': 'umi_tools_count',
#  '597': 'samtools_idxstats',
#  '598': 'EMBOSS: seqret84',
#  '599': 'deg_annotate',
#  '600': 'aragorn_trna',
#  '601': 'EMBOSS: revseq82',
#  '602': 'cufflinks_prok',
#  '603': 'gatk2_reduce_reads',
#  '604': 'ggplot_histogram',
#  '605': 'snippy_core',
#  '606': 'seq_composition',
#  '607': 'graphclust_aggregate_alignments',
#  '608': 'hmmer_hmmbuild',
#  '609': 'qiime_count_seqs',
#  '610': 'ncbi_tblastn_wrapper',
#  '611': 'MultiplexResolver',
#  '612': 'goenrichment',
#  '613': 'umi_tools_extract',
#  '614': 'rgweblogo3',
#  '615': 'cmFinder',
#  '616': 'IDFileConverter',
#  '617': 'format_metaphlan2_output',
#  '618': 'cshl_fastx_nucleotides_distribution',
#  '619': 'sam2interval',
#  '620': 'IDScoreSwitcher',
#  '621': 'peptide_shaker',
#  '622': 'fastqc',
#  '623': 'fastq_filter',
#  '624': 'trinity',
#  '625': 'mothur_lefse',
#  '626': 'methtools_tiling',
#  '627': 'trimmomatic',
#  '628': 'abims_CAMERA_annotateDiffreport',
#  '629': 'snpSift_dbnsfp_generic',
#  '630': 'regex_replace',
#  '631': 'group_humann2_uniref_abundances_to_go',
#  '632': 'map_peptides_to_bed',
#  '633': 'mothur_get_communitytype',
#  '634': 'cardinal_data_exporter',
#  '635': 'Remove_ending',
#  '636': 'metams_runGC',
#  '637': 'CONVERTER_interval_to_bedstrict_0',
#  '638': 'ncbi_blastx_wrapper',
#  '639': 'gatk2_indel_realigner',
#  '640': 'samtool_filter2',
#  '641': 'tp_sed_tool',
#  '642': 'heinz_bum',
#  '643': 'stacks_denovomap',
#  '644': 'aggregate_scores_in_intervals2',
#  '645': '16Saligner',
#  '646': 'kraken-filter',
#  '647': 'sklearn_svm_classifier',
#  '648': 'fraggenescan',
#  '649': 'eukaryotic_ncbi_submission',
#  '650': 'snpSift_filter',
#  '651': 'pureclip',
#  '652': '__APPLY_RULES__',
#  '653': 'mothur_screen_seqs',
#  '654': 'raceid_inspecttrajectory',
#  '655': 'vegan_rarefaction',
#  '656': 'XTandemAdapter',
#  '657': 'stringtie_merge',
#  '658': 'hicexplorer_hicplotmatrix',
#  '659': 'varscan',
#  '660': 'mothur_chimera_vsearch',
#  '661': 'fasta_compute_length',
#  '662': 'cuffdiff',
#  '663': 'bedtools_getfastabed',
#  '664': 'viz_overlay_moving_and_fixed_image',
#  '665': 'prokka',
#  '666': 'nanopolish_variants',
#  '667': 'pilon',
#  '668': 'ProteinResolver',
#  '669': 'idpqonvert',
#  '670': 'hmmer_hmmsearch',
#  '671': 'metaphlan_hclust_heatmap',
#  '672': 'picard_BamIndexStats',
#  '673': 'GeMoMa_Annotation_Filter',
#  '674': 'modencode_peakcalling_macs2',
#  '675': 'qiime_pick_closed_reference_otus',
#  '676': 'join_files_on_column_fuzzy',
#  '677': 'mothur_remove_seqs',
#  '678': 'cshl_fasta_formatter',
#  '679': 'sam_to_bam',
#  '680': 'rseqc_read_distribution',
#  '681': 'proteomics_search_tandem_1',
#  '682': 'ggplot2_heatmap2',
#  '683': 'sklearn_searchcv',
#  '684': 'meme_chip',
#  '685': 'deeptools_bam_compare',
#  '686': 'mothur_classify_otu',
#  '687': 'cardinal_quality_report',
#  '688': 'ctb_remIons',
#  '689': 'gffread',
#  '690': 'segemehl',
#  '691': 'DecoyDatabase',
#  '692': 'gatk2_base_recalibrator',
#  '693': 'minfi_qc',
#  '694': 'enhanced_bowtie_wrapper',
#  '695': 'minfi_dmp',
#  '696': 'lastz_wrapper_2',
#  '697': '__MERGE_COLLECTION__',
#  '698': 'abims_xcms_xcmsSet',
#  '699': 'DatamashTranspose',
#  '700': 'picard_ReorderSam',
#  '701': 'bwameth',
#  '702': 'iReport',
#  '703': 'bedtools_bamtofastq',
#  '704': 'tp_tail_tool',
#  '705': 'nanoplot',
#  '706': 'gemini_windower',
#  '707': 'mothur_metastats',
#  '708': 'Add_a_column1',
#  '709': 'xpath',
#  '710': 'krona-text',
#  '711': 'mimodd_map',
#  '712': 'msconvert3_raw',
#  '713': 'minfi_getanno',
#  '714': 'EMBOSS: shuffleseq87',
#  '715': 'FROGS_preprocess',
#  '716': 'minfi_maptogenome',
#  '717': 'bg_column_arrange_by_header',
#  '718': 'snpSift_geneSets',
#  '719': 'tp_head_tool',
#  '720': 'fastq_paired_end_splitter',
#  '721': 'cshl_sort_header',
#  '722': 'gtf2bedgraph',
#  '723': 'infernal_cmbuild',
#  '724': 'bigwig_to_bedgraph',
#  '725': 'sam_merge2',
#  '726': 'EMBOSS: geecee41',
#  '727': 'FROGS_affiliations_stat',
#  '728': 'bg_find_subsequences',
#  '729': 'iuc_pear',
#  '730': 'gbk_to_orf',
#  '731': 'gatk2_print_reads',
#  '732': 'pileup_parser',
#  '733': 'tsne',
#  '734': 'bamCoverage_deepTools',
#  '735': 'mothur_remove_groups',
#  '736': 'ctb_ob_genProp',
#  '737': 'je_clip',
#  '738': 'Extractor',
#  '739': 'hgv_david',
#  '740': 'picard_CollectInsertSizeMetrics',
#  '741': 'correctGCBias',
#  '742': 'mothur_classify_seqs',
#  '743': 'ngsutils_bam_filter',
#  '744': 'samtools_mpileup',
#  '745': 'vegan_diversity',
#  '746': 'cardinal_filtering',
#  '747': 'Heatmap',
#  '748': 'gafa',
#  '749': 'dunovo',
#  '750': 'CONVERTER_bed_to_bgzip_0',
#  '751': 'infernal_cmstat',
#  '752': 'cast',
#  '753': 'cummeRbund',
#  '754': 'macs2_callpeak',
#  '755': 'FROGS_clustering',
#  '756': 'goseq',
#  '757': 'ctb_compound_convert',
#  '758': 'tp_multijoin_tool',
#  '759': 'Psortb',
#  '760': 'minfi_ppfun',
#  '761': 'picard_MergeSamFiles',
#  '762': 'deeptools_plot_fingerprint',
#  '763': 'sklearn_feature_selection',
#  '764': 'velveth_jgi',
#  '765': '16Sclassifier',
#  '766': 'tophat2',
#  '767': 'megablast_xml_parser',
#  '768': 'bamFilter',
#  '769': 'datamash_ops',
#  '770': 'maldi_quant_peak_detection',
#  '771': 'snpfinder',
#  '772': 'humann2_renorm_table',
#  '773': 'mothur_venn',
#  '774': 're_he_maldi_image_registration',
#  '775': 'ctb_remSmall',
#  '776': 'gff2bed1',
#  '777': 'deeptools_plot_heatmap',
#  '778': 'bowtie_wrapper',
#  '779': 'cshl_sed_tool',
#  '780': 'fasta2tab',
#  '781': 'rseqc_inner_distance',
#  '782': 'bedtools_genomecoveragebed_histogram',
#  '783': 'HighResPrecursorMassCorrector',
#  '784': 'snpEff_download',
#  '785': 'computeMatrix',
#  '786': 'glob_report',
#  '787': 'sample_seqs',
#  '788': 'Filter1',
#  '789': 'mothur_parsimony',
#  '790': 'deeptools_plot_correlation',
#  '791': 'abims_xcms_group',
#  '792': 'FeatureFinderMultiplex',
#  '793': 'Extract_RNA_seq_Evidence',
#  '794': 'fgsea',
#  '795': 'vcffilter',
#  '796': 'uchime',
#  '797': 'tp_cut_tool',
#  '798': 'FeatureLinkerUnlabeledQT',
#  '799': 'mimodd_vcf_filter',
#  '800': 'get_child_terms',
#  '801': 'metaphlan2krona',
#  '802': 'picard_CleanSam',
#  '803': 'deeptools_bigwig_compare',
#  '804': 'cat1',
#  '805': 'viennarna_rnaalifold',
#  '806': 'make_families',
#  '807': 'bctools_remove_spurious_events',
#  '808': 'raceid_inspectclusters',
#  '809': 'mcClust',
#  '810': 'cshl_fastx_collapser',
#  '811': 'extract_element_from_collection',
#  '812': 'gemini_annotate',
#  '813': 'flexbardsc',
#  '814': 'ete_genetree_splitter',
#  '815': 'bamleftalign',
#  '816': 'cshl_fastx_clipper',
#  '817': 'bandage_image',
#  '818': 'mothur_remove_lineage',
#  '819': 'smf_utils_find-boxes',
#  '820': 'rsem_prepare_reference',
#  '821': 'bedtools_genomecoveragebed_bedgraph',
#  '822': 'rarefaction_analyzer',
#  '823': 'gmx_npt',
#  '824': 'tp_unfold_column_tool',
#  '825': 'samtools_rmdup',
#  '826': 'Grep1',
#  '827': 'secretbt2test',
#  '828': 'ggplot_point',
#  '829': 'spades',
#  '830': 'dexseq_annotate',
#  '831': 'ip_projective_transformation',
#  '832': 'TrimByN',
#  '833': 'combine_metaphlan2_humann2',
#  '834': 'proteomics_moff',
#  '835': 'ggplot2_heatmap',
#  '836': 'term_id_vs_term_def',
#  '837': 'fasta_merge_files_and_filter_unique_sequences',
#  '838': 'FeatureLinkerUnlabeledKD',
#  '839': 'DatamashOps',
#  '840': 'annotatemyids',
#  '841': 'gtf_filter_by_attribute_values_list',
#  '842': 'mothur_make_biom',
#  '843': 'hcluster_sg',
#  '844': 'ProteinInference',
#  '845': 'filter_bed_on_splice_junctions',
#  '846': 'gemini_actionable_mutations',
#  '847': 'uniprot',
#  '848': 'umi_tools_whitelist',
#  '849': 'locarna_multiple',
#  '850': 'mothur_tree_shared',
#  '851': 'treebest_best',
#  '852': 'cshl_fastx_barcode_splitter',
#  '853': 'mycrobiota-otutable_add_blast',
#  '854': '__RELABEL_FROM_FILE__',
#  '855': 'gops_cluster_1',
#  '856': 'idpquery',
#  '857': 'hgv_snpFreq',
#  '858': 'ggplot2_point',
#  '859': 'stacks_refmap',
#  '860': 'tmhmm2',
#  '861': 'IDMapper',
#  '862': 'graphlan_annotate',
#  '863': 'snpeff_to_peptides',
#  '864': 'mothur_dist_shared',
#  '865': 'collapse_dataset',
#  '866': 'snippy',
#  '867': 'glimmer_not-knowlegde-based',
#  '868': 'openms_id_file_converter',
#  '869': 'fastq_to_fasta_python',
#  '870': 'minfi_mset',
#  '871': 'tp_replace_in_line',
#  '872': 'ggplot2_histogram',
#  '873': 'FROGS_filters',
#  '874': 'tp_find_and_replace',
#  '875': 'fastq_to_tabular',
#  '876': 'idpassemble',
#  '877': 'deeptools_correctGCBias',
#  '878': 'mass_spectrometry_imaging_qc',
#  '879': 'samtools_slice_bam',
#  '880': 'gemini_query',
#  '881': 'hgv_linkToGProfile',
#  '882': 'bed_to_bigBed',
#  '883': 'w4mcorcov',
#  '884': 'deeptools_compute_matrix',
#  '885': 'sam_bw_filter',
#  '886': 'ConsensusMapNormalizer',
#  '887': 'p_clip_peaks',
#  '888': 'vcffilter2',
#  '889': 'taxonomy_krona_chart',
#  '890': 'bg_uniq',
#  '891': 'histogram_rpy',
#  '892': 'gatk_depth_of_coverage',
#  '893': 'stacks_procrad',
#  '894': 'rnaz',
#  '895': 'picard_SamToFastq',
#  '896': 'kallisto_quant',
#  '897': 'cshl_fasta_nucleotides_changer',
#  '898': 'FastTree',
#  '899': 'tp_awk_tool',
#  '900': 'CONVERTER_fastqgz_to_fastq',
#  '901': 'cuffquant',
#  '902': 'length_and_gc_content',
#  '903': 'humann2_regroup_table',
#  '904': 'msconvert2_raw',
#  '905': 'createInterval',
#  '906': 'deeptools_compute_matrix_operations',
#  '907': 'muscle',
#  '908': 'gops_coverage_1',
#  '909': 'mothur_sub_sample',
#  '910': 'Fetch Taxonomic Ranks',
#  '911': 'mothur_get_seqs',
#  '912': 'cshl_uniq_tool',
#  '913': 'fasta-stats',
#  '914': 'varscan_copynumber',
#  '915': 'cor2',
#  '916': 'FalseDiscoveryRate',
#  '917': 'vcfannotate',
#  '918': 'mothur_make_shared',
#  '919': 'venn_list',
#  '920': 'kraken-translate',
#  '921': 'racon',
#  '922': 'diffbind-embl',
#  '923': 'bcftools_consensus',
#  '924': 'EMBOSS: water107',
#  '925': 'remove_tail.py',
#  '926': 'IDPosteriorErrorProbability',
#  '927': 'limma_voom',
#  '928': 'plotly_regression_performance_plots',
#  '929': 'flye',
#  '930': 'gops_intersect_1',
#  '931': 'gatk2_variant_select',
#  '932': 'fasttree',
#  '933': 'resistome_analyzer',
#  '934': 'get_feature_info',
#  '935': 'bam_to_sam',
#  '936': 'gatk2_haplotype_caller',
#  '937': 'transdecoder',
#  '938': 'rarefaction',
#  '939': 'mothur_dist_seqs',
#  '940': 'abims_xcms_fillPeaks',
#  '941': 'w4mclassfilter',
#  '942': 'minfi_dmr',
#  '943': 'mothur_taxonomy_to_krona',
#  '944': 'deeptools_bigwigCompare',
#  '945': 'bg_statistical_hypothesis_testing',
#  '946': 'bg_sortmerna',
#  '947': 'cd_hit_dup',
#  '948': 'Univariate',
#  '949': 'CONVERTER_bed_to_gff_0',
#  '950': 'umi_tools_group',
#  '951': 'Btrim64',
#  '952': 'picard_CollectRnaSeqMetrics',
#  '953': 'heatmapper_deepTools',
#  '954': 'fasta_filter_by_length',
#  '955': 'gops_basecoverage_1',
#  '956': 'uparse',
#  '957': 'varscan_mpileup',
#  '958': 'umi_tools_dedup',
#  '959': 'TrimPrimer',
#  '960': 'Remove beginning1',
#  '961': 'fastq_manipulation',
#  '962': 'w4mjoinpn',
#  '963': 'get_flanks1',
#  '964': 'samtools_flag_filter',
#  '965': 'gatk2_variant_apply_recalibration',
#  '966': 'RNAlien',
#  '967': 'allele_counts_1',
#  '968': 'deeptools_bam_coverage',
#  '969': 'methtools_dmr',
#  '970': 'mass_spectrometry_imaging_segmentations',
#  '971': 'cshl_fastq_quality_boxplot'}

# %%
def verify_model(model, tool_sequence, labels, dictionary, reverse_dictionary, compatible_tools, topk=20, max_seq_len=25):
    tl_seq = tool_sequence.split(",")
    last_tool_name = reverse_dictionary[str(tl_seq[-1])]
    last_compatible_tools = compatible_tools[last_tool_name]
    sample = np.zeros(max_seq_len)
    for idx, tool_id in enumerate(tl_seq):
        sample[idx] = int(tool_id)
    sample_reshaped = np.reshape(sample, (1, max_seq_len))
    
    tool_sequence_names = [reverse_dictionary[str(tool_pos)] for tool_pos in tool_sequence.split(",")]
    print("Tool seq: %s" % ",".join(tool_sequence_names))
    # predict next tools for a test path
    prediction = model.predict(sample_reshaped, verbose=0)
    prediction = np.reshape(prediction, (prediction.shape[1],))
    prediction_pos = np.argsort(prediction, axis=-1)

    # get topk prediction
    topk_prediction_pos = prediction_pos[-topk:]
    topk_prediction_val = [np.round(prediction[pos] * 100, 2) for pos in topk_prediction_pos]

    # read tool names using reverse dictionary
    pred_tool_ids = [reverse_dictionary[str(tool_pos)] for tool_pos in topk_prediction_pos]
    actual_next_tool_ids = list(set(pred_tool_ids).intersection(set(last_compatible_tools.split(","))))      
        
    #print("Predicted tools: %s" % ",".join(pred_tool_ids))
    print()
    pred_tool_ids_sorted = dict()
    for (tool_pos, tool_pred_val) in zip(topk_prediction_pos, topk_prediction_val):
        tool_name = reverse_dictionary[str(tool_pos)]
        if tool_name in actual_next_tool_ids:
            pred_tool_ids_sorted[tool_name] = tool_pred_val
    pred_tool_ids_sorted = dict(sorted(pred_tool_ids_sorted.items(), key=lambda kv: kv[1], reverse=True))
    
    cls_wt = dict()
    usg_wt = dict()
    inv_wt = dict()
    ids_tools = dict()
    keys = list(pred_tool_ids_sorted.keys())
    for k in keys:
        try:
            cls_wt[k] = np.round(class_weights[str(data_dict[k])], 2)
            usg_wt[k] = np.round(usage_weights[k], 2)
            inv_wt[k] = np.round(inverted_weights[str(data_dict[k])], 2)
        except:
            continue
    print("Predicted tools: \n")
    print(pred_tool_ids_sorted)
    print()
    print("Class weights: \n")
    cls_wt = dict(sorted(cls_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(cls_wt)
    print()
    print("Usage weights: \n")
    usg_wt = dict(sorted(usg_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(usg_wt)
    print()
    total_usage_wt = np.mean(list(usg_wt.values()))
    total_pred_score = np.mean(list(pred_tool_ids_sorted.values()))
    print("Mean usage wt: %0.4f, Mean prediction score: %0.4f, Sum: %0.4f" % (total_usage_wt, total_pred_score, (total_usage_wt + total_pred_score)))
    print()
    print("Inverted weights: \n")
    inv_wt = dict(sorted(inv_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(inv_wt)
    for key in pred_tool_ids_sorted:
        ids_tools[key] = dictionary[key]
    print()
    print("Tool ids")
    print(ids_tools)
    print("======================================")
    return cls_wt, usg_wt, inv_wt, pred_tool_ids_sorted

topk = 10
tool_seq = "792" #
class_wt, usage_wt, inverse_wt, pred_tools = verify_model(model, tool_seq, "", dictionary, reverse_dictionary, compatibile_tools, topk)
# Out:
# Tool seq: FeatureFinderMultiplex
#
# Predicted tools:
#
# {'FileInfo': 47.0, 'IDMapper': 4.41}
#
# Class weights:
#
# {'IDMapper': 7.88, 'FileInfo': 6.28}
#
# Usage weights:
#
# {'FileInfo': 21.39, 'IDMapper': 0.0}
#
# Mean usage wt: 10.6950, Mean prediction score: 25.7050, Sum: 36.4000
#
# Inverted weights:
#
# {'IDMapper': 2656.52, 'FileInfo': 534.54}
#
# Tool ids
# {'FileInfo': 187, 'IDMapper': 861}
# ======================================

# %%
list_cls_wt = list()
list_usage_wt = list()
list_pred_wt = list()
list_inv_wt = list()
division_pt = int(len(pred_tools) / 2)

for tool in pred_tools:
    list_pred_wt.append(pred_tools[tool])
    #try:
    list_inv_wt.append(inverse_wt[tool])
    list_usage_wt.append(usage_wt[tool])
    #except:
    #list_inv_wt.append(1)

def plot_scatter(y_val, title, xlabel, ylabel):
    x_val = range(1, len(y_val) + 1)
    plt.figure(figsize=(8, 8))
    plt.plot(x_val[:division_pt], y_val[:division_pt], 'ro')
    plt.plot(x_val[division_pt:], y_val[division_pt:], 'b^')
    plt.xlabel(xlabel, size=size_label)
    plt.ylabel(ylabel, size=size_label)
    plt.legend([("First top-%s" % str(division_pt)), ("Next top-%s" % str(division_pt))])
    plt.title(title, size=size_title)
    plt.grid(True)
    plt.show()

plot_scatter(list_usage_wt, "Usage weights for tools", "Number of tools", "Class weights")
#plot_scatter(ave_prediction_weights, ave_usage_weights, "Prediction vs usage weights", "Prediction scores", "Usage weights")
#plot_scatter(ave_prediction_weights, ave_inverted_weights, "Prediction vs inverted weights", "Prediction scores", "Inverted weights")
