# %%
import numpy as np
import json
import warnings
import operator

import h5py
from keras.models import model_from_json
from keras import backend as K

from matplotlib import pyplot as plt

warnings.filterwarnings("ignore")

size_title = 18
size_label = 14
n_pred = 2

base_path = "data/evaluate_log_usage_sample_normalized/"

path_data_dict = base_path + "data_dict.txt"
path_inverted_wt = base_path + "inverted_weights.txt"
path_usage_wt = base_path + "usage_prediction.txt"
path_class_wt = base_path + "class_weights.txt"
path_test_data = base_path + "test_paths_dict.txt"
model_path = base_path + "trained_model.hdf5"

def read_file(file_path):
    with open(file_path, 'r') as data_file:
        data = json.loads(data_file.read())
    return data

class_weights = read_file(path_class_wt)
usage_weights = read_file(path_usage_wt)
inverted_weights = read_file(path_inverted_wt)
data_dict = read_file(path_data_dict)

def create_model(model_path):
    trained_model = h5py.File(model_path, 'r')
    model_config = json.loads(trained_model.get('model_config').value)
    loaded_model = model_from_json(model_config)
    dictionary = json.loads(trained_model.get('data_dictionary').value)
    compatibile_tools = json.loads(trained_model.get('compatible_tools').value)
    reverse_dictionary = dict((str(v), k) for k, v in dictionary.items())
    model_weights = list()
    weight_ctr = 0
    while True:
        try:
            d_key = "weight_" + str(weight_ctr)
            weights = trained_model.get(d_key).value
            model_weights.append(weights)
            weight_ctr += 1
        except Exception as exception:
            break
    # set the model weights
    loaded_model.set_weights(model_weights)
    return loaded_model, dictionary, reverse_dictionary, compatibile_tools

model, dictionary, reverse_dictionary, compatibile_tools = create_model(model_path)
# Out:
# Using TensorFlow backend.

# %%
reverse_dictionary
# Out:
# {'1': 'bwa_mem',
#  '2': 'Interval_Maf_Merged_Fasta2',
#  '3': 'macs2_predictd',
#  '4': 'ssake',
#  '5': 'deeptools_computeGCBias',
#  '6': 'mothur_summary_single',
#  '7': 'ggplot2_heatmap',
#  '8': 'vcftools_isec',
#  '9': 'correct_barcodes',
#  '10': 'bed_to_bigwig',
#  '11': 'cshl_find_and_replace',
#  '12': 'gff_filter_by_attribute',
#  '13': 'picard_ReorderSam',
#  '14': 'cuffmerge',
#  '15': 'RNAlien',
#  '16': 'seq_composition',
#  '17': 'idr-embl',
#  '18': 'ctb_remIons',
#  '19': 'gatk2_print_reads',
#  '20': 'deeptools_plot_fingerprint',
#  '21': 'cuffquant',
#  '22': 'scpipe',
#  '23': 'mimodd_varextract',
#  '24': 'stringtie',
#  '25': 'fasttree',
#  '26': 'flexbardsc',
#  '27': 'gatk2_variant_recalibrator',
#  '28': 'EMBOSS: shuffleseq87',
#  '29': 'map_peptides_to_bed',
#  '30': 'fastq_manipulation',
#  '31': 'cuffnorm',
#  '32': 'mothur_amova',
#  '33': 'random_lines1',
#  '34': 'raceid_clustering',
#  '35': 'comp1',
#  '36': 'sam_pileup',
#  '37': 'kraken-report',
#  '38': 'cshl_fastx_renamer',
#  '39': 'uniprot',
#  '40': 'mycrobiota-split-multi-otutable',
#  '41': 'mothur_dist_seqs',
#  '42': 'seq_filter_by_id',
#  '43': 'sample_seqs',
#  '44': 'proteomics_search_peptide_prophet_1',
#  '45': 'bamCoverage_deepTools',
#  '46': 'bedtools_complementbed',
#  '47': 'nn_classifier',
#  '48': 'cuffcompare',
#  '49': 'mothur_parsimony',
#  '50': 'eden_vectorizer',
#  '51': 'trinity',
#  '52': 'Digestor',
#  '53': 'filter_bed_on_splice_junctions',
#  '54': 'dbbuilder',
#  '55': 'melt',
#  '56': 'infernal_cmstat',
#  '57': 'fastq_to_tabular',
#  '58': 'dt_profiler',
#  '59': 'raceid_inspecttrajectory',
#  '60': 'tp_replace_in_line',
#  '61': 'hicexplorer_hicsummatrices',
#  '62': 'cardinal_spectra_plots',
#  '63': 'ChooseTag',
#  '64': 'htseq-count',
#  '65': 'w4mjoinpn',
#  '66': 'tp_multijoin_tool',
#  '67': 'CONVERTER_interval_to_bgzip_0',
#  '68': 'stacks_denovomap',
#  '69': 'deeptools_multi_bam_summary',
#  '70': 'heatmapper_deepTools',
#  '71': 'Psortb',
#  '72': 'export2graphlan',
#  '73': 'methtools_filter',
#  '74': 'allele_counts_1',
#  '75': 'IDScoreSwitcher',
#  '76': 'krona-text',
#  '77': 'varscan_copynumber',
#  '78': 'rarefaction',
#  '79': 'collapse_dataset',
#  '80': 'gemini_de_novo',
#  '81': 'sklear_numeric_clustering',
#  '82': 'trimmer',
#  '83': 'cshl_fastx_reverse_complement',
#  '84': 'samtools_filter',
#  '85': 'ncbi_rpsblast_wrapper',
#  '86': 'CONVERTER_gz_to_uncompressed',
#  '87': 'samtools_calmd',
#  '88': 'snpEff',
#  '89': 'mycrobiota-otutable_add_blast',
#  '90': 'gops_intersect_1',
#  '91': 'Datamash',
#  '92': 'velveth_jgi',
#  '93': 'mothur_dist_shared',
#  '94': 'Extract_features1',
#  '95': 'blast2go',
#  '96': 'smf_utils_filter-by-energy',
#  '97': 'MapStatistics',
#  '98': 'secure_hash_message_digest',
#  '99': 'glimmer_build-icm',
#  '100': 'racon',
#  '101': 'flexbar_split_RYYR_bcs',
#  '102': 'wc_gnu',
#  '103': 'extract_bcs.py',
#  '104': 'EMBOSS: extractseq35',
#  '105': 'deeptools_computeMatrix',
#  '106': 'bedtools_coveragebed',
#  '107': 'fgsea',
#  '108': 'bam-filter',
#  '109': 'gemini_annotate',
#  '110': 'react_cal_pipeline',
#  '111': 'IsobaricAnalyzer',
#  '112': 'rmcontamination',
#  '113': 'bedtools_genomecoveragebed_bedgraph',
#  '114': 'deeptools_compute_matrix_operations',
#  '115': 'sam_bw_filter',
#  '116': 'bedtools_annotatebed',
#  '117': 'cufflinks',
#  '118': 'eden_sequence_converter',
#  '119': 'smf_utils_fix-fasta-headers',
#  '120': 'rnaz',
#  '121': 'regex_replace',
#  '122': 'ctb_chemfp_mol2fps',
#  '123': 'rseqc_infer_experiment',
#  '124': 'FROGS_filters',
#  '125': 'mothur_sub_sample',
#  '126': 'tp_sed_tool',
#  '127': 'tp_replace_in_column',
#  '128': 'metaphlan2krona',
#  '129': 'tp_cut_tool',
#  '130': 'deeptools_bamFingerprint',
#  '131': 'tp_text_file_with_recurring_lines',
#  '132': 'cast',
#  '133': 'samtool_filter2',
#  '134': 'histogram_rpy',
#  '135': 'XTandemAdapter',
#  '136': 'cshl_grep_tool',
#  '137': 'cshl_easyjoin',
#  '138': 'nonpareil',
#  '139': 'glimmer_knowlegde-based',
#  '140': 'IDMerger',
#  '141': 'hicexplorer_hicmergematrixbins',
#  '142': 'get_flanks1',
#  '143': 'gops_cluster_1',
#  '144': 'salmon',
#  '145': 'FROGS_clustering',
#  '146': 'taxonomy_krona_chart',
#  '147': 'join_files_on_column_fuzzy',
#  '148': 'viennarna_rnaalifold',
#  '149': 'gatk2_haplotype_caller',
#  '150': 'IDFilter',
#  '151': 'ChangeCase',
#  '152': 'mothur_nmds',
#  '153': 'sam_merge2',
#  '154': 'qiime_assign_taxonomy',
#  '155': 'numeric_clustering',
#  '156': 'pieplots_macs',
#  '157': 'gops_basecoverage_1',
#  '158': 'fasta_compute_length',
#  '159': 'combine_metaphlan2_humann2',
#  '160': 'rgPicFixMate',
#  '161': 'CONVERTER_gff_to_interval_index_0',
#  '162': 'segemehl',
#  '163': 'gops_join_1',
#  '164': 'bam2wig',
#  '165': 'glob_report',
#  '166': 'Extract genomic DNA 1',
#  '167': '__SORTLIST__',
#  '168': 'sam_to_bam',
#  '169': 'pynast',
#  '170': 'MultiplexResolver',
#  '171': 'snippy',
#  '172': 'FeatureFinderCentroided',
#  '173': 'blastxml_to_tabular',
#  '174': 'DatamashOps',
#  '175': 'qiime_pick_closed_reference_otus',
#  '176': 'bedtools_sortbed',
#  '177': 'bed2gff1',
#  '178': 'deeptools_bamCompare',
#  '179': 'vcf2tsv',
#  '180': 'rbc_splitfasta',
#  '181': 'paralyzer',
#  '182': 'bcftools_norm',
#  '183': 'deeptools_bigwigCompare',
#  '184': 'datamash_ops',
#  '185': 'gatk2_unified_genotyper',
#  '186': 'megahit',
#  '187': 'samtools_flagstat',
#  '188': 'picard_MarkDuplicatesWithMateCigar',
#  '189': 'qiime_pick_rep_set',
#  '190': 'umi_tools_dedup',
#  '191': 'sort1',
#  '192': 'mycrobiota-correct-replicates',
#  '193': 'gffread',
#  '194': 'flexbar_no_split',
#  '195': 'seq_filter_by_mapping',
#  '196': 'hisat',
#  '197': 'minfi_qc',
#  '198': 'mothur_corr_axes',
#  '199': 'picard_CollectRnaSeqMetrics',
#  '200': 'pileup_interval',
#  '201': 'hisat2',
#  '202': 'GeMoMa_Annotation_Filter',
#  '203': 'scaffold2fasta',
#  '204': 'bismark_bowtie',
#  '205': 'Grep1',
#  '206': 'bctools_remove_tail',
#  '207': 'PicardInsertSize',
#  '208': 'DecoyDatabase',
#  '209': 'mothur_get_seqs',
#  '210': 'bowtie2',
#  '211': 'gatk2_variant_annotator',
#  '212': 'hmmer_hmmbuild',
#  '213': 'MSGFPlusAdapter',
#  '214': 'vcfallelicprimitives',
#  '215': 'PeptideIndexer',
#  '216': 'gemini_windower',
#  '217': 'shovill',
#  '218': 'gemini_comp_hets',
#  '219': 'graphlan',
#  '220': 'collection_column_join',
#  '221': 'annotatemyids',
#  '222': 'mothur_make_contigs',
#  '223': 'filter_by_fasta_ids',
#  '224': 'resistome_analyzer',
#  '225': 'vcffixup',
#  '226': 'maldi_quant_preprocessing',
#  '227': 'samtools_sort',
#  '228': 'humann2',
#  '229': 'bam_to_sam',
#  '230': 'hcluster_sg',
#  '231': 'samtools_flag_filter',
#  '232': 'prokka',
#  '233': 'mothur_filter_seqs',
#  '234': 'minfi_maptogenome',
#  '235': 'gtf_filter_by_attribute_values_list',
#  '236': 'get_sequences',
#  '237': 'coords2clnt.py',
#  '238': 'minfi_dmr',
#  '239': 'IDPosteriorErrorProbability',
#  '240': 'viz_overlay_moving_and_fixed_image',
#  '241': 'bedtools_bamtobed',
#  '242': 'megablast_xml_parser',
#  '243': 'bctools_extract_alignment_ends',
#  '244': 'bedtools_genomecoveragebed',
#  '245': 'rseqc_bam_stat',
#  '246': 'rsem_prepare_reference',
#  '247': 'term_id_vs_term_def',
#  '248': 'minimap2',
#  '249': 'ete_genetree_splitter',
#  '250': 'deeptools_plot_correlation',
#  '251': 'deeptools_bam_coverage',
#  '252': 'mothur_rarefaction_single',
#  '253': 'snpSift_filter',
#  '254': 'bedtools_multicovtbed',
#  '255': 'bamCompare_deepTools',
#  '256': 'cmv',
#  '257': 'bedtools_shufflebed',
#  '258': 'bedtools_multiintersectbed',
#  '259': 'je_markdupes',
#  '260': 'trim_galore',
#  '261': 'velvetoptimiser',
#  '262': 'muscle',
#  '263': 'CONVERTER_bed_gff_or_vcf_to_bigwig_0',
#  '264': 'gtftobed12',
#  '265': 'gatk_unified_genotyper',
#  '266': 'annotateMyIDs',
#  '267': '16Sclassifier',
#  '268': 'cshl_awk_tool',
#  '269': 'CONVERTER_fastqgz_to_fastq',
#  '270': 'filtlong',
#  '271': 'samtools_split',
#  '272': 'meme_fimo',
#  '273': 'bedtools_intersectBed',
#  '274': 'CONVERTER_gff_to_bed_0',
#  '275': '__ZIP_COLLECTION__',
#  '276': 'bandage_image',
#  '277': 'gatk2_realigner_target_creator',
#  '278': 'flanking_features_1',
#  '279': 'mass_spectrometry_imaging_combine',
#  '280': 'length_and_gc_content',
#  '281': 'wig_to_bigWig',
#  '282': '__APPLY_RULES__',
#  '283': 'pileup_parser',
#  '284': 'deg_annotate',
#  '285': 'cshl_princeton_fastx_barcode_splitter',
#  '286': 'mothur_cluster_split',
#  '287': 'Paste1',
#  '288': 'methtools_dmr',
#  '289': 'ete_homology_classifier',
#  '290': 'rseqc_geneBody_coverage',
#  '291': 'ncbi_blastp_wrapper',
#  '292': 'p_clip_peaks',
#  '293': 'bcftools_view',
#  '294': 'ggplot2_point',
#  '295': 'deeptools_bam_compare',
#  '296': 'gff_to_sequence',
#  '297': 'charts',
#  '298': 'velvetg_jgi',
#  '299': 'gemini_actionable_mutations',
#  '300': 'idpassemble',
#  '301': 'PeakPickerHiRes',
#  '302': 'openms_protein_quantifier',
#  '303': 'mothur_taxonomy_to_krona',
#  '304': 'jbrowse',
#  '305': 'CONVERTER_bed_to_bgzip_0',
#  '306': 'tp_split_on_column',
#  '307': 'Univariate',
#  '308': '__RELABEL_FROM_FILE__',
#  '309': 'picard_ARRG',
#  '310': 'MAF_To_Fasta1',
#  '311': 'glimmer_not-knowlegde-based',
#  '312': 'bwa',
#  '313': 'dunovo',
#  '314': 'get_subontology_from',
#  '315': 'hicexplorer_hicbuildmatrix',
#  '316': 'deeptools_heatmapper',
#  '317': 'deeptools_plot_heatmap',
#  '318': 'diffbind-embl',
#  '319': 'Draw_phylogram',
#  '320': 'rgweblogo3',
#  '321': 'disco',
#  '322': 'ctb_silicos_qed',
#  '323': 'iReport',
#  '324': 'mothur_cluster',
#  '325': 'bedtools_getfastabed',
#  '326': 'mothur_remove_seqs',
#  '327': 'varscan',
#  '328': 'snpSift_dbnsfp_generic',
#  '329': 'ctb_online_data_fetch',
#  '330': 'FeatureFinderMetabo',
#  '331': 'rbc_rnacode',
#  '332': 'Show beginning1',
#  '333': 'iuc_pear',
#  '334': 'snippy_core',
#  '335': 'bams2ratio',
#  '336': 'Batch_correction',
#  '337': 'sklearn_ensemble',
#  '338': 'w4mclassfilter',
#  '339': 'graphclust_align_cluster',
#  '340': 'mothur_trim_seqs',
#  '341': 'nanopolish_variants',
#  '342': 'picard_MergeSamFiles',
#  '343': 'idpqonvert',
#  '344': 'vcfgenotypes',
#  '345': 'IDFileConverter',
#  '346': 'tp_sort_rows',
#  '347': 'mimodd_map',
#  '348': 'rsem_calculate_expression',
#  '349': 'gspan',
#  '350': 'CONVERTER_interval_to_bed_0',
#  '351': 'augustus',
#  '352': 'cd_hit_dup',
#  '353': 'bedtools_intersectbed_bam',
#  '354': 'qiime_count_seqs',
#  '355': 'gffcompare',
#  '356': 're_he_maldi_image_registration',
#  '357': 'msconvert3_raw',
#  '358': 'w4mcorcov',
#  '359': 'table_annovar',
#  '360': 'wolf_psort',
#  '361': 'gmx_em',
#  '362': '16Saligner',
#  '363': 'Remove_ending',
#  '364': 'Extractor',
#  '365': 'interproscan',
#  '366': 'vcf2pgSnp',
#  '367': 'minfi_ppfun',
#  '368': 'goenrichment',
#  '369': 'wiggle2simple1',
#  '370': 'fraggenescan',
#  '371': 'vcffilter2',
#  '372': 'abims_CAMERA_annotateDiffreport',
#  '373': 'minfi_methcpg',
#  '374': 'vcf_filter',
#  '375': 'mycrobiota-krona-mothur',
#  '376': 'je_demultiplex',
#  '377': 'cshl_awk_replace_in_column',
#  '378': 'hicexplorer_hicplottads',
#  '379': 'tophat2',
#  '380': 'snpeff_to_peptides',
#  '381': 'methtools_tiling',
#  '382': 'ggplot2_heatmap2',
#  '383': 'lfq_protein_quant',
#  '384': 'abims_xcms_xcmsSet',
#  '385': 'gops_concat_1',
#  '386': 'samtools_rmdup',
#  '387': 'picard_CleanSam',
#  '388': 'heatmapper',
#  '389': 'vcfflatten2',
#  '390': '__FILTER_FROM_FILE__',
#  '391': 'samtools_bedcov',
#  '392': 'preproc',
#  '393': 'maldi_quant_peak_detection',
#  '394': 'tmhmm2',
#  '395': 'ip_projective_transformation_points',
#  '396': 'gatk_realigner_target_creator',
#  '397': 'bcftools_consensus',
#  '398': 'graphclust_aggregate_alignments',
#  '399': 'Fetch Taxonomic Ranks',
#  '400': 'EMBOSS: getorf42',
#  '401': 'modencode_peakcalling_macs2',
#  '402': 'bamtools',
#  '403': '__UNZIP_COLLECTION__',
#  '404': 'picard_CollectInsertSizeMetrics',
#  '405': 'msgfplus',
#  '406': 'picard_CollectWgsMetrics',
#  '407': 'gemini_load',
#  '408': 'idpquery',
#  '409': 'preMloc',
#  '410': 'extract_aln_ends.py',
#  '411': 'remove_tail.py',
#  '412': 'velvet',
#  '413': 'enhanced_bowtie_wrapper',
#  '414': 'htseq_count',
#  '415': 'FROGS_affiliation_OTU',
#  '416': 'naive_variant_caller',
#  '417': 'abims_xcms_group',
#  '418': 'blastxml_to_tabular_selectable',
#  '419': 'vcftools_merge',
#  '420': 'get_feature_info',
#  '421': 'mothur_make_shared',
#  '422': 'tp_find_and_replace',
#  '423': 'vcffilter',
#  '424': 'cshl_fasta_formatter',
#  '425': 'vsearch_dereplication',
#  '426': 'gatk_depth_of_coverage',
#  '427': 'cshl_fastx_artifacts_filter',
#  '428': 'qiime_pick_open_reference_otus',
#  '429': 'gatk2_variant_filtration',
#  '430': 'search_gui',
#  '431': 'meme_meme',
#  '432': 'antismash',
#  '433': 'chipseeker',
#  '434': 'ctb_compound_convert',
#  '435': 'cufflinks_prok',
#  '436': 'cardinal_quality_report',
#  '437': 'umi_tools_extract',
#  '438': 'fastq_groomer',
#  '439': 'raceid_trajectory',
#  '440': 'treebest_best',
#  '441': 'mothur_remove_lineage',
#  '442': 'EMBOSS: tranalign100',
#  '443': 'je_clip',
#  '444': 'gafa',
#  '445': 'kraken-filter',
#  '446': 'flye',
#  '447': 'mothur_seq_error',
#  '448': 'minfi_mset',
#  '449': 'CONVERTER_fasta_to_fai',
#  '450': 'eukaryotic_ncbi_submission',
#  '451': 'ProteinResolver',
#  '452': 'dexseq_count',
#  '453': 'gatk2_variant_apply_recalibration',
#  '454': 'fastq_paired_end_deinterlacer',
#  '455': 'Filter1',
#  '456': 'aragorn_trna',
#  '457': 'cardinal_combine',
#  '458': 'meme_dreme',
#  '459': 'hicexplorer_hicplotmatrix',
#  '460': 'graphclust_glob_report_no_align',
#  '461': 'ggplot_histogram',
#  '462': 'xcms_merge',
#  '463': 'gmx_solvate',
#  '464': 'sklearn_build_pipeline',
#  '465': 'cummerbund_to_cuffdiff',
#  '466': 'addValue',
#  '467': 'smf_utils_estimate-energy',
#  '468': 'fastq collapser',
#  '469': 'rseqc_junction_saturation',
#  '470': 'NSPDK_candidateClust',
#  '471': 'gemini_recessive_and_dominant',
#  '472': 'plotly_ml_performance_plots',
#  '473': 'FalseDiscoveryRate',
#  '474': 'kraken-translate',
#  '475': 'tp_head_tool',
#  '476': 'QCCalculator',
#  '477': 'qiime_make_otu_heatmap',
#  '478': 'umi_tools_count',
#  '479': 'blast_parser',
#  '480': 'ncbi_makeblastdb',
#  '481': 'fastq_dump',
#  '482': 'get_child_terms',
#  '483': 'CONVERTER_bedgraph_to_bigwig',
#  '484': 'rm_spurious_events.py',
#  '485': 'cardinal_segmentations',
#  '486': 'find_in_reference',
#  '487': 'cardinal_preprocessing',
#  '488': 'picard_AddOrReplaceReadGroups',
#  '489': 'goslimmer',
#  '490': 'svm_classifier',
#  '491': 'vcfannotate',
#  '492': 'vcfselectsamples',
#  '493': 'cshl_word_list_grep',
#  '494': 'make_families',
#  '495': 'minfi_getanno',
#  '496': 'rcas',
#  '497': 'mothur_classify_rf',
#  '498': 'nspdk_sparse',
#  '499': 'ia_coordinates_of_roi',
#  '500': 'createInterval',
#  '501': 'mycrobiota-make-multi-otutable',
#  '502': 'cutadapt',
#  '503': 'MapRTTransformer',
#  '504': 'sklearn_svm_classifier',
#  '505': 'rseqc_bam2wig',
#  '506': 'tp_sort_header_tool',
#  '507': 'group_humann2_uniref_abundances_to_go',
#  '508': 'cshl_fastq_quality_filter',
#  '509': 'gmx_nvt',
#  '510': 'bismark_bowtie2',
#  '511': 'snpSift_geneSets',
#  '512': 'snpsift_vartype',
#  '513': 'ncbi_blastn_wrapper',
#  '514': 'gd_raxml',
#  '515': 'ProteinQuantifier',
#  '516': 'deeptools_plot_coverage',
#  '517': 'ConsensusID',
#  '518': 'bg_statistical_hypothesis_testing',
#  '519': 'tp_uniq_tool',
#  '520': 'mothur_count_groups',
#  '521': 'PicardASMetrics',
#  '522': 'mothur_unique_seqs',
#  '523': 'qiime_make_phylogeny',
#  '524': 'gemini_db_info',
#  '525': 'mothur_count_seqs',
#  '526': 'checkFormat',
#  '527': 'vcftools_annotate',
#  '528': 'scale_image',
#  '529': 'msconvert2_raw',
#  '530': 'gbk_to_orf',
#  '531': 'XY_Plot_1',
#  '532': 'FastTree',
#  '533': 'deseq2',
#  '534': 'gtf2bedgraph',
#  '535': 'structure_to_gspan',
#  '536': 'porechop',
#  '537': 'hicexplorer_hicfindtads',
#  '538': 'sklearn_numeric_clustering',
#  '539': 'genbank_to_gff',
#  '540': 'qiime_pick_otus',
#  '541': 'picard_FilterSamReads',
#  '542': 'mothur_heatmap_bin',
#  '543': 'ncbi_blastx_wrapper',
#  '544': 'Cut1',
#  '545': 'cshl_fastx_trimmer',
#  '546': 'locarna_multiple',
#  '547': 'CONVERTER_bed_to_gff_0',
#  '548': 'heinz_bum',
#  '549': 'fastqc',
#  '550': 'deeptools_plot_pca',
#  '551': 'FROGS_preprocess',
#  '552': 'SequenceCoverageCalculator',
#  '553': 'viennarna_rnafold',
#  '554': 'infernal_cmbuild',
#  '555': 'bedtools_slopbed',
#  '556': 'biosigner',
#  '557': 'gops_subtract_1',
#  '558': 'valet',
#  '559': 'decoyfasta',
#  '560': 'mz_to_sqlite',
#  '561': 'mimodd_vcf_filter',
#  '562': 'Extract_RNA_seq_Evidence',
#  '563': 'Remove beginning1',
#  '564': 'vt_normalize',
#  '565': 'qiime_validate_mapping_file',
#  '566': 'deeptools_bamCoverage',
#  '567': 'tp_cat',
#  '568': 'picard_SamToFastq',
#  '569': 'rbc_mirdeep2',
#  '570': 'picard_SortSam',
#  '571': 'methtools_calling',
#  '572': 'methtools_plot',
#  '573': 'silac_analyzer',
#  '574': 'stacks_refmap',
#  '575': 'gops_coverage_1',
#  '576': 'minfi_dropsnp',
#  '577': 'ggplot2_histogram',
#  '578': 'stacks_procrad',
#  '579': 'query_tabular',
#  '580': 'gops_merge_1',
#  '581': 'cat1',
#  '582': 'openms_id_file_converter',
#  '583': 'bg_uniq',
#  '584': 'deeptools_correctGCBias',
#  '585': 'bedtools_map',
#  '586': 'HighResPrecursorMassCorrector',
#  '587': 'venn_list',
#  '588': 'convert_bc_to_binary_RY.py',
#  '589': 'trim_reads',
#  '590': 'kallisto_quant',
#  '591': '__FLATTEN__',
#  '592': 'r_correlation_matrix',
#  '593': 'FeatureLinkerUnlabeledKD',
#  '594': 'metaphlan2',
#  '595': 'Btrim64',
#  '596': 'spades',
#  '597': 'viennarna_rnaplot',
#  '598': 'FileMerger',
#  '599': 'heinz_scoring',
#  '600': 'mergeCols1',
#  '601': 'proteomics_moff',
#  '602': 'uchime',
#  '603': 'mothur_pcoa',
#  '604': 'mothur_align_seqs',
#  '605': 'bcftools_call',
#  '606': 'fastq_paired_end_joiner',
#  '607': 'humann2_renorm_table',
#  '608': 'mass_spectrometry_imaging_segmentations',
#  '609': 'gemini_burden',
#  '610': 'sed_stream_editor',
#  '611': 'bowtie_wrapper',
#  '612': 'infernal_cmsearch',
#  '613': 'Grouping1',
#  '614': 'flexbar_split_RR_bcs',
#  '615': 'kraken',
#  '616': 'Flash',
#  '617': 'ip_projective_transformation',
#  '618': 'Nucleosome',
#  '619': 'smooth_running_window',
#  '620': 'bigwig_to_bedgraph',
#  '621': 'ConsensusMapNormalizer',
#  '622': 'deeptools_plot_enrichment',
#  '623': 'raceid_main',
#  '624': 'cshl_sort_header',
#  '625': 'tp_awk_tool',
#  '626': 'peakcalling_macs',
#  '627': 'replace_column_with_key_value_file',
#  '628': 'pileometh',
#  '629': 'w4mclstrpeakpics',
#  '630': 'mothur_make_biom',
#  '631': 'tophat_fusion_post',
#  '632': 'gff2bed1',
#  '633': 'deeptools_compute_gc_bias',
#  '634': 'cshl_fastq_to_fasta',
#  '635': 'EMBOSS: fuzzpro38',
#  '636': 'gatk2_base_recalibrator',
#  '637': 'prokaryotic_ncbi_submission',
#  '638': 'pureclip',
#  '639': 'correctGCBias',
#  '640': 'tsne',
#  '641': 'egsea',
#  '642': 'MzTabExporter',
#  '643': 'hicexplorer_hicpca',
#  '644': 't2t_report',
#  '645': 'cummeRbund',
#  '646': 'tabular_to_fastq',
#  '647': 'tp_easyjoin_tool',
#  '648': 'goseq',
#  '649': 'mycrobiota-qc-report',
#  '650': 'modencode_peakcalling_spp',
#  '651': 'picard_EstimateLibraryComplexity',
#  '652': 'heatmap2',
#  '653': 'deseq2_single',
#  '654': 'unipept',
#  '655': 'FeatureLinkerUnlabeled',
#  '656': 'rnafold',
#  '657': 'rbc_mirdeep2_quantifier',
#  '658': 'stacks_genotypes',
#  '659': 'predict_pipeline',
#  '660': 'bundle_collection',
#  '661': 'minfi_getbeta',
#  '662': 'varscan_somatic',
#  '663': 'mass_spectrometry_imaging_filtering',
#  '664': 'bg_column_arrange_by_header',
#  '665': 'DatamashTranspose',
#  '666': 'mothur_summary_seqs',
#  '667': 'bedtools_bamtofastq',
#  '668': 'mothur_lefse',
#  '669': 'column_order_header_sort',
#  '670': 'selectsequencesfrommsa',
#  '671': 'cshl_fasta_nucleotides_changer',
#  '672': 'cshl_fastq_quality_boxplot',
#  '673': 'cshl_fastx_barcode_splitter',
#  '674': 'mothur_merge_files',
#  '675': 'deeptools_bamCorrelate',
#  '676': 'peakcalling_macs14',
#  '677': 'mothur_make_group',
#  '678': 'samtools_slice_bam',
#  '679': 'TrimByN',
#  '680': 'ProteinInference',
#  '681': 'gatk2_indel_realigner',
#  '682': 'ExtractFASTAfromFASTQ',
#  '683': 'meme_chip',
#  '684': 'CONVERTER_Bam_Bai_0',
#  '685': 'deeptools_compute_matrix',
#  '686': 'vegan_rarefaction',
#  '687': 'mothur_get_groups',
#  '688': 'stringtie_merge',
#  '689': 'fastq_paired_end_splitter',
#  '690': 'ctb_change_title',
#  '691': 'picard_FixMateInformation',
#  '692': 'bedtools_intersectbed',
#  '693': 'snpfinder',
#  '694': 'gemini_query',
#  '695': 'vcfvcfintersect',
#  '696': 'MapAlignerPoseClustering',
#  '697': 'cshl_fastx_nucleotides_distribution',
#  '698': 'cshl_uniq_tool',
#  '699': 'smf_utils_extract-boxed-sequences',
#  '700': 'xpath',
#  '701': 'sam2interval',
#  '702': 'metaphlan_hclust_heatmap',
#  '703': 'mothur_classify_otu',
#  '704': 'gmx_md',
#  '705': 'bg_find_subsequences',
#  '706': 'get_read_pipeline',
#  '707': 'fastq_to_fasta_python',
#  '708': 'gatk2_depth_of_coverage',
#  '709': 'hgv_snpFreq',
#  '710': 'fasta2tab',
#  '711': 'EMBOSS: transeq101',
#  '712': 'bwameth',
#  '713': 'gmx_setup',
#  '714': 'locarna_best_subtree',
#  '715': 'heinz',
#  '716': 'picard_CASM',
#  '717': 'bedtools_coveragebed_counts',
#  '718': 'tab2fasta',
#  '719': 'mothur_get_oturep',
#  '720': 'proteomics_search_tandem_1',
#  '721': 'EMBOSS: geecee41',
#  '722': 'fasta-stats',
#  '723': 'samtools_idxstats',
#  '724': 'cardinal_filtering',
#  '725': 'blockbuster',
#  '726': 'fasta_merge_files_and_filter_unique_sequences',
#  '727': 'newick_display',
#  '728': 'umi_tools_whitelist',
#  '729': 'limma_voom',
#  '730': 'cshl_fastx_clipper',
#  '731': 'deeptools_multi_bigwig_summary',
#  '732': 'fastq_filter',
#  '733': 'CONVERTER_sam_to_unsorted_bam',
#  '734': 'metaspades',
#  '735': 'translate_bed_sequences',
#  '736': 'chipsequtil_maptoknowngenes',
#  '737': 'snpEff_download',
#  '738': 'bg_sortmerna',
#  '739': 'plotly_parallel_coordinates_plot',
#  '740': 'picard_MarkDuplicates',
#  '741': 'mothur_pre_cluster',
#  '742': 'subtract_query1',
#  '743': 'secretbt2test',
#  '744': 'cuffdiff',
#  '745': 'barchart_gnuplot',
#  '746': 'hgv_david',
#  '747': 'join1',
#  '748': 'megablast_wrapper',
#  '749': 'CONVERTER_interval_to_bedstrict_0',
#  '750': 'FileInfo',
#  '751': 'graphlan_annotate',
#  '752': 'sklearn_searchcv',
#  '753': 'EMBOSS: seqret84',
#  '754': 'vegan_diversity',
#  '755': 'fasplit',
#  '756': 'FROGS_remove_chimera',
#  '757': 'gmx_npt',
#  '758': 'mothur_phylotype',
#  '759': 'Summary_Statistics1',
#  '760': 'ctb_ob_genProp',
#  '761': 'ucsc-twobittofa',
#  '762': 'trimmomatic',
#  '763': 'mimodd_varreport',
#  '764': 'TrimByLength',
#  '765': 'macs2_bdgcmp',
#  '766': 'sklearn_feature_selection',
#  '767': 'fastq_trimmer',
#  '768': 'circgraph',
#  '769': 'mass_spectrometry_imaging_classification',
#  '770': 'computeMatrix',
#  '771': 'FeatureFinderMultiplex',
#  '772': 'ctb_filter',
#  '773': 'samtools_mpileup',
#  '774': 'NFS_transfer',
#  '775': 'metams_runGC',
#  '776': 'mothur_screen_seqs',
#  '777': 'picard_NormalizeFasta',
#  '778': 'sqlite_to_tabular',
#  '779': 'roary',
#  '780': 'Heatmap',
#  '781': 'dexseq_annotate',
#  '782': 'Add_a_column1',
#  '783': 'hicexplorer_hiccorrectmatrix',
#  '784': 'samtools_stats',
#  '785': 'align_families',
#  '786': 'tp_sorted_uniq',
#  '787': 'gatk2_reduce_reads',
#  '788': 'EMBOSS: newseq59',
#  '789': 'cardinal_data_exporter',
#  '790': 'rseqc_read_distribution',
#  '791': 'hgv_linkToGProfile',
#  '792': 'mothur_remove_groups',
#  '793': 'unicycler',
#  '794': 'bedtools_unionbedgraph',
#  '795': 'bedtools_mergebed',
#  '796': 'IDMassAccuracy',
#  '797': 'merge_pcr_duplicates.py',
#  '798': 'tophat',
#  '799': 't_coffee',
#  '800': 'bwa_wrapper',
#  '801': 'fastq_combiner',
#  '802': 'mothur_chimera_uchime',
#  '803': 'bgchem_fragment_merger',
#  '804': 'bedtools_genomecoveragebed_histogram',
#  '805': 'cshl_cut_tool',
#  '806': 'rseqc_read_duplication',
#  '807': 'graphicsmagick_image_convert',
#  '808': 'multiqc',
#  '809': 'ctb_simsearch',
#  '810': 'mothur_venn',
#  '811': 'mothur_metastats',
#  '812': '__MERGE_COLLECTION__',
#  '813': 'meme_psp_gen',
#  '814': 'pilon',
#  '815': 'cshl_fastx_collapser',
#  '816': 'addName',
#  '817': 'CometAdapter',
#  '818': 'qiime_align_seqs',
#  '819': 'bedtools_subtractbed',
#  '820': 'sailfish',
#  '821': 'deeptools_correct_gc_bias',
#  '822': 'piranha',
#  '823': 'mothur_tree_shared',
#  '824': 'mlocarna',
#  '825': 'umi_tools_group',
#  '826': 'ncbi_tblastn_wrapper',
#  '827': 'EMBOSS: fuzztran39',
#  '828': 'rarefaction_analyzer',
#  '829': 'deeptools_bigwig_compare',
#  '830': 'abims_xcms_fillPeaks',
#  '831': 'bg_protein_properties',
#  '832': 'deeptools_plot_profile',
#  '833': 'transdecoder',
#  '834': 'bamFilter',
#  '835': 'qiime_split_libraries_fastq',
#  '836': 'bg_diamond',
#  '837': 'FileFilter',
#  '838': 'FeatureLinkerUnlabeledQT',
#  '839': 'rgPicardMarkDups',
#  '840': 'rseqc_inner_distance',
#  '841': 'signalp3',
#  '842': 'minfi_getM',
#  '843': 'ggplot_point',
#  '844': 'ctb_remSmall',
#  '845': 'blockclust',
#  '846': 'mass_spectrometry_imaging_preprocessing',
#  '847': 'varscan_mpileup',
#  '848': 'tp_tail_tool',
#  '849': 'proteomics_search_protein_prophet_1',
#  '850': 'blastxml_to_top_descr',
#  '851': 'nanoplot',
#  '852': 'raceid_filtnormconf',
#  '853': 'Convert characters1',
#  '854': 'stacks_populations',
#  '855': 'Show tail1',
#  '856': 'ngsutils_bam_filter',
#  '857': 'mothur_homova',
#  '858': 'msconvert_nix',
#  '859': 'FileConverter',
#  '860': 'flexbar',
#  '861': 'Determine_BC',
#  '862': 'EMBOSS: revseq82',
#  '863': 'bctools_extract_crosslinked_nucleotides',
#  '864': 'seurat',
#  '865': 'fastq_join',
#  '866': 'tp_unfold_column_tool',
#  '867': 'extract_element_from_collection',
#  '868': 'wsdl_hmdb',
#  '869': 'hmmer_hmmsearch',
#  '870': 'fastq_quality_trimmer',
#  '871': 'sickle',
#  '872': 'mothur_classify_seqs',
#  '873': 'snpSift_annotate',
#  '874': 'lastz_wrapper_2',
#  '875': 'clustalw',
#  '876': 'heinz_visualization',
#  '877': 'sequence_content_trimmer',
#  '878': 'cor2',
#  '879': 'cardinal_mz_images',
#  '880': 'cshl_fastx_quality_statistics',
#  '881': 'cshl_sed_tool',
#  '882': 'metilene',
#  '883': 'picard_BamIndexStats',
#  '884': 'mass_spectrometry_imaging_qc',
#  '885': 'rbc_mirdeep2_mapper',
#  '886': 'rna_star',
#  '887': '__FILTER_FAILED_DATASETS__',
#  '888': 'format_metaphlan2_output',
#  '889': 'FidoAdapter',
#  '890': 'rnbeads',
#  '891': 'igvtools_count',
#  '892': 'macs2_callpeak',
#  '893': 'thermo_raw_file_converter',
#  '894': 'mimodd_varcall',
#  '895': 'minfi_read450k',
#  '896': 'mothur_heatmap_sim',
#  '897': 'openms_id_mapper',
#  '898': 'cshl_multijoin',
#  '899': 'gemini_pathways',
#  '900': 'cmFinder',
#  '901': 'ruvseq',
#  '902': 'bctools_remove_spurious_events',
#  '903': 'myrimatch',
#  '904': 'vcfbedintersect',
#  '905': 'bam_to_bigwig',
#  '906': 'uparse',
#  '907': 'TextExporter',
#  '908': 'peptide_shaker',
#  '909': 'Multivariate',
#  '910': 'bamleftalign',
#  '911': 'GeneModelMapper',
#  '912': 'vcfsort',
#  '913': 'column_remove_by_header',
#  '914': 'fastq_paired_end_interlacer',
#  '915': 'datamash_transpose',
#  '916': 'humann2_genefamilies_genus_level',
#  '917': 'sklearn_nn_classifier',
#  '918': 'gatk2_variant_select',
#  '919': 'tag_stat2',
#  '920': 'bedtools_bedtobam',
#  '921': 'aggregate_scores_in_intervals2',
#  '922': 'minfi_dmp',
#  '923': 'regex1',
#  '924': 'EMBOSS: wordcount109',
#  '925': 'EMBOSS: textsearch98',
#  '926': 'CONVERTER_fasta_to_tabular',
#  '927': 'freebayes',
#  '928': 'EMBOSS: water107',
#  '929': 'transpose',
#  '930': 'smf_utils_find-boxes',
#  '931': 'vcfcombine',
#  '932': 'bedtools_windowbed',
#  '933': 'hcluster_sg_parser',
#  '934': 'gatk_indel_realigner',
#  '935': 'bed_to_bigBed',
#  '936': 'tp_tac',
#  '937': 'mass_spectrometry_imaging_ion_images',
#  '938': 'gemini_interactions',
#  '939': 'plotly_regression_performance_plots',
#  '940': 'fasta_filter_by_length',
#  '941': 'rbc_mafft',
#  '942': 'dexseq',
#  '943': 'peakachu',
#  '944': 'gene2exon1',
#  '945': 'FROGS_affiliations_stat',
#  '946': 'raceid_inspectclusters',
#  '947': 'TrimPrimer',
#  '948': 'tp_grep_tool',
#  '949': 'fragmenter',
#  '950': 'deeptools_profiler',
#  '951': 'quast',
#  '952': 'mcClust',
#  '953': 'MassCalculator',
#  '954': 'edger',
#  '955': 'methtools_destrand',
#  '956': 'picard_ValidateSamFile',
#  '957': 'featurecounts',
#  '958': 'IDConflictResolver',
#  '959': 'term_id_vs_term_name',
#  '960': 'lca1',
#  '961': 'abricate',
#  '962': 'Count1',
#  '963': 'IDMapper',
#  '964': 'qiime_core_diversity',
#  '965': 'abims_xcms_summary',
#  '966': 'humann2_regroup_table',
#  '967': 'mothur_get_communitytype',
#  '968': 'hicexplorer_hictransform',
#  '969': 'mass_spectrometry_imaging_mzplots',
#  '970': 'mothur_chimera_vsearch',
#  '971': 'minfi_rset'}

# %%
def verify_model(model, tool_sequence, labels, dictionary, reverse_dictionary, compatible_tools, topk=20, max_seq_len=25):
    tl_seq = tool_sequence.split(",")
    last_tool_name = reverse_dictionary[str(tl_seq[-1])]
    last_compatible_tools = compatible_tools[last_tool_name]
    sample = np.zeros(max_seq_len)
    for idx, tool_id in enumerate(tl_seq):
        sample[idx] = int(tool_id)
    sample_reshaped = np.reshape(sample, (1, max_seq_len))
    
    tool_sequence_names = [reverse_dictionary[str(tool_pos)] for tool_pos in tool_sequence.split(",")]
    print("Tool seq: %s" % ",".join(tool_sequence_names))
    # predict next tools for a test path
    prediction = model.predict(sample_reshaped, verbose=0)
    prediction = np.reshape(prediction, (prediction.shape[1],))
    prediction_pos = np.argsort(prediction, axis=-1)

    # get topk prediction
    topk_prediction_pos = prediction_pos[-topk:]
    topk_prediction_val = [np.round(prediction[pos] * 100, 2) for pos in topk_prediction_pos]

    # read tool names using reverse dictionary
    pred_tool_ids = [reverse_dictionary[str(tool_pos)] for tool_pos in topk_prediction_pos]
    actual_next_tool_ids = list(set(pred_tool_ids).intersection(set(last_compatible_tools.split(","))))      
        
    #print("Predicted tools: %s" % ",".join(pred_tool_ids))
    print()
    pred_tool_ids_sorted = dict()
    for (tool_pos, tool_pred_val) in zip(topk_prediction_pos, topk_prediction_val):
        tool_name = reverse_dictionary[str(tool_pos)]
        if tool_name in actual_next_tool_ids:
            pred_tool_ids_sorted[tool_name] = tool_pred_val
    pred_tool_ids_sorted = dict(sorted(pred_tool_ids_sorted.items(), key=lambda kv: kv[1], reverse=True))
    
    cls_wt = dict()
    usg_wt = dict()
    inv_wt = dict()
    ids_tools = dict()
    keys = list(pred_tool_ids_sorted.keys())
    for k in keys:
        try:
            cls_wt[k] = np.round(class_weights[str(data_dict[k])], 2)
            usg_wt[k] = np.round(usage_weights[k], 2)
            inv_wt[k] = np.round(inverted_weights[str(data_dict[k])], 2)
        except:
            continue
    print("Predicted tools: \n")
    print(pred_tool_ids_sorted)
    print()
    print("Class weights: \n")
    cls_wt = dict(sorted(cls_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(cls_wt)
    print()
    print("Usage weights: \n")
    usg_wt = dict(sorted(usg_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(usg_wt)
    print()
    total_usage_wt = np.sum(list(usg_wt.values()))
    print("Sum usage wt: %0.4f" % (total_usage_wt))
    print()
    print("Inverted weights: \n")
    inv_wt = dict(sorted(inv_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(inv_wt)
    for key in pred_tool_ids_sorted:
        ids_tools[key] = dictionary[key]
    print()
    print("Tool ids")
    print(ids_tools)
    print("======================================")
    return cls_wt, usg_wt, inv_wt, pred_tool_ids_sorted

topk = 10
tool_seq = "201" # ,875,223,17
class_wt, usage_wt, inverse_wt, pred_tools = verify_model(model, tool_seq, "", dictionary, reverse_dictionary, compatibile_tools, topk)
# Out:
# Tool seq: hisat2
#
# Predicted tools:
#
# {'htseq_count': 1.64}
#
# Class weights:
#
# {'htseq_count': 0.0}
#
# Usage weights:
#
# {'htseq_count': 538.31}
#
# Sum usage wt: 538.3100
#
# Inverted weights:
#
# {'htseq_count': 1314.71}
#
# Tool ids
# {'htseq_count': 414}
# ======================================

# %%
list_cls_wt = list()
list_usage_wt = list()
list_pred_wt = list()
list_inv_wt = list()
division_pt = int(len(pred_tools) / 2)

for tool in pred_tools:
    list_pred_wt.append(pred_tools[tool])
    #try:
    list_inv_wt.append(inverse_wt[tool])
    list_usage_wt.append(usage_wt[tool])
    #except:
    #list_inv_wt.append(1)

def plot_scatter(y_val, title, xlabel, ylabel):
    x_val = range(1, len(y_val) + 1)
    plt.figure(figsize=(8, 8))
    plt.plot(x_val[:division_pt], y_val[:division_pt], 'ro')
    plt.plot(x_val[division_pt:], y_val[division_pt:], 'b^')
    plt.xlabel(xlabel, size=size_label)
    plt.ylabel(ylabel, size=size_label)
    plt.legend([("First top-%s" % str(division_pt)), ("Next top-%s" % str(division_pt))])
    plt.title(title, size=size_title)
    plt.grid(True)
    plt.show()

plot_scatter(list_usage_wt, "Usage weights for tools", "Number of tools", "Class weights")
#plot_scatter(ave_prediction_weights, ave_usage_weights, "Prediction vs usage weights", "Prediction scores", "Usage weights")
#plot_scatter(ave_prediction_weights, ave_inverted_weights, "Prediction vs inverted weights", "Prediction scores", "Inverted weights")
