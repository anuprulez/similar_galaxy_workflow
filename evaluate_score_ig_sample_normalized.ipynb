# %%
import numpy as np
import json
import warnings
import operator

import h5py
from keras.models import model_from_json
from keras import backend as K

from matplotlib import pyplot as plt

warnings.filterwarnings("ignore")

size_title = 18
size_label = 14
n_pred = 2

base_path = "data/remote_sample_normalized/"

path_data_dict = base_path + "data_dict.txt"
path_inverted_wt = base_path + "inverted_weights.txt"
path_usage_wt = base_path + "usage_prediction.txt"
path_class_wt = base_path + "class_weights.txt"
path_test_data = base_path + "test_paths_dict.txt"
model_path = base_path + "trained_model.hdf5"

def read_file(file_path):
    with open(file_path, 'r') as data_file:
        data = json.loads(data_file.read())
    return data

class_weights = read_file(path_class_wt)
usage_weights = read_file(path_usage_wt)
inverted_weights = read_file(path_inverted_wt)
data_dict = read_file(path_data_dict)

def create_model(model_path):
    trained_model = h5py.File(model_path, 'r')
    model_config = json.loads(trained_model.get('model_config').value)
    loaded_model = model_from_json(model_config)
    dictionary = json.loads(trained_model.get('data_dictionary').value)
    compatibile_tools = json.loads(trained_model.get('compatible_tools').value)
    reverse_dictionary = dict((str(v), k) for k, v in dictionary.items())
    model_weights = list()
    weight_ctr = 0
    while True:
        try:
            d_key = "weight_" + str(weight_ctr)
            weights = trained_model.get(d_key).value
            model_weights.append(weights)
            weight_ctr += 1
        except Exception as exception:
            break
    # set the model weights
    loaded_model.set_weights(model_weights)
    return loaded_model, dictionary, reverse_dictionary, compatibile_tools

model, dictionary, reverse_dictionary, compatibile_tools = create_model(model_path)
# Out:
# Using TensorFlow backend.

# %%
reverse_dictionary
# Out:
# {'1': 'ncbi_blastx_wrapper',
#  '2': 'bedtools_annotatebed',
#  '3': 'QCCalculator',
#  '4': 'mimodd_varcall',
#  '5': 'collapse_dataset',
#  '6': 'hicexplorer_hicplotmatrix',
#  '7': 'cshl_fasta_nucleotides_changer',
#  '8': 'w4mjoinpn',
#  '9': 'deeptools_plot_heatmap',
#  '10': 'cuffmerge',
#  '11': 'gatk2_depth_of_coverage',
#  '12': 'metaphlan_hclust_heatmap',
#  '13': 'mothur_nmds',
#  '14': 'tp_find_and_replace',
#  '15': 'hicexplorer_hicmergematrixbins',
#  '16': 'blockbuster',
#  '17': 'cardinal_combine',
#  '18': 'snpSift_filter',
#  '19': 'cshl_fastx_trimmer',
#  '20': 'ruvseq',
#  '21': 'mothur_classify_seqs',
#  '22': 'computeMatrix',
#  '23': '__UNZIP_COLLECTION__',
#  '24': 'qiime_count_seqs',
#  '25': 'fastqc',
#  '26': 'IsobaricAnalyzer',
#  '27': 'mothur_filter_seqs',
#  '28': 'cshl_fastx_reverse_complement',
#  '29': 'disco',
#  '30': 'gmx_npt',
#  '31': 'mimodd_varextract',
#  '32': 'fastq collapser',
#  '33': 'rseqc_bam2wig',
#  '34': 'bg_diamond',
#  '35': 'tp_sort_rows',
#  '36': 'scale_image',
#  '37': 'Draw_phylogram',
#  '38': 'kraken-translate',
#  '39': 'unipept',
#  '40': 'qiime_pick_open_reference_otus',
#  '41': 'minfi_mset',
#  '42': 'metaspades',
#  '43': 'rbc_mirdeep2',
#  '44': 'taxonomy_krona_chart',
#  '45': 'regex_replace',
#  '46': 'fastq_quality_trimmer',
#  '47': 'deeptools_bigwigCompare',
#  '48': 'wig_to_bigWig',
#  '49': 'stacks_refmap',
#  '50': 'Remove_ending',
#  '51': 'bg_column_arrange_by_header',
#  '52': '__APPLY_RULES__',
#  '53': 'quast',
#  '54': 'blastxml_to_tabular',
#  '55': 'mothur_tree_shared',
#  '56': 'hicexplorer_hicplottads',
#  '57': 'ete_genetree_splitter',
#  '58': 'FastTree',
#  '59': 'infernal_cmbuild',
#  '60': 'dbbuilder',
#  '61': 'ip_projective_transformation_points',
#  '62': 'fastq_groomer',
#  '63': 'tp_head_tool',
#  '64': 'gemini_load',
#  '65': 'sam_to_bam',
#  '66': 'qiime_pick_rep_set',
#  '67': 'r_correlation_matrix',
#  '68': 'lfq_protein_quant',
#  '69': 'velvetoptimiser',
#  '70': 'openms_protein_quantifier',
#  '71': 'bgchem_fragment_merger',
#  '72': 'extract_aln_ends.py',
#  '73': 'picard_FixMateInformation',
#  '74': 'heinz_scoring',
#  '75': 'format_metaphlan2_output',
#  '76': 'mothur_parsimony',
#  '77': 'uparse',
#  '78': 'Count1',
#  '79': 'cummeRbund',
#  '80': 'bedtools_unionbedgraph',
#  '81': '16Saligner',
#  '82': 'flexbardsc',
#  '83': 'correctGCBias',
#  '84': 'meme_meme',
#  '85': 'IDMassAccuracy',
#  '86': 'mothur_remove_seqs',
#  '87': 'search_gui',
#  '88': 'minfi_getanno',
#  '89': 'react_cal_pipeline',
#  '90': 'hicexplorer_hiccorrectmatrix',
#  '91': 'ProteinInference',
#  '92': 'Filter1',
#  '93': 'bg_sortmerna',
#  '94': 'FROGS_filters',
#  '95': 'Fetch Taxonomic Ranks',
#  '96': 'blockclust',
#  '97': 'gff_filter_by_attribute',
#  '98': 'diffbind-embl',
#  '99': 'term_id_vs_term_def',
#  '100': 'raceid_main',
#  '101': 'rarefaction',
#  '102': 'fastq_combiner',
#  '103': 'rbc_mafft',
#  '104': 'mothur_get_groups',
#  '105': 'tp_cut_tool',
#  '106': 'deseq2_single',
#  '107': 'raceid_trajectory',
#  '108': 'nanoplot',
#  '109': 'meme_psp_gen',
#  '110': 'IDMapper',
#  '111': 'muscle',
#  '112': 'salmon',
#  '113': 'bowtie2',
#  '114': 'bam-filter',
#  '115': 'cshl_fastq_quality_boxplot',
#  '116': 'dt_profiler',
#  '117': 'fastq_manipulation',
#  '118': 'je_clip',
#  '119': 'tag_stat2',
#  '120': 'bed_to_bigwig',
#  '121': 'plotly_ml_performance_plots',
#  '122': 'cshl_fastx_quality_statistics',
#  '123': 'query_tabular',
#  '124': 'mothur_screen_seqs',
#  '125': 'seq_composition',
#  '126': 'vegan_diversity',
#  '127': 'peptide_shaker',
#  '128': 'EMBOSS: seqret84',
#  '129': 'hicexplorer_hictransform',
#  '130': 'ChangeCase',
#  '131': 'msgfplus',
#  '132': 'msconvert3_raw',
#  '133': 'mass_spectrometry_imaging_ion_images',
#  '134': 'gmx_setup',
#  '135': 'bedtools_bedtobam',
#  '136': 'fasta_filter_by_length',
#  '137': 'samtools_sort',
#  '138': 'samtools_bedcov',
#  '139': 'rbc_mirdeep2_quantifier',
#  '140': 'rcas',
#  '141': 'HighResPrecursorMassCorrector',
#  '142': 'FROGS_affiliations_stat',
#  '143': 'chipseeker',
#  '144': 'samtools_split',
#  '145': 'umi_tools_count',
#  '146': 'samtool_filter2',
#  '147': 'meme_fimo',
#  '148': 'rmcontamination',
#  '149': 'rbc_mirdeep2_mapper',
#  '150': 'deeptools_plot_correlation',
#  '151': 'viennarna_rnaplot',
#  '152': 'mothur_remove_groups',
#  '153': 'snpSift_geneSets',
#  '154': 'methtools_filter',
#  '155': 'blast_parser',
#  '156': 'minfi_rset',
#  '157': 'newick_display',
#  '158': 'Cut1',
#  '159': 'abims_xcms_group',
#  '160': 'rseqc_read_duplication',
#  '161': 'sam_bw_filter',
#  '162': 'bamtools',
#  '163': 'Paste1',
#  '164': 'EMBOSS: newseq59',
#  '165': 'picard_CollectRnaSeqMetrics',
#  '166': 'picard_ValidateSamFile',
#  '167': 'umi_tools_dedup',
#  '168': 'vcffixup',
#  '169': 'thermo_raw_file_converter',
#  '170': 'idpqonvert',
#  '171': 'venn_list',
#  '172': 'gatk2_variant_filtration',
#  '173': 'Univariate',
#  '174': 'qiime_align_seqs',
#  '175': 'CONVERTER_interval_to_bgzip_0',
#  '176': 'deeptools_bamCoverage',
#  '177': 'mothur_dist_shared',
#  '178': 'mothur_rarefaction_single',
#  '179': 'GeMoMa_Annotation_Filter',
#  '180': 'viz_overlay_moving_and_fixed_image',
#  '181': 'minfi_qc',
#  '182': 'eden_vectorizer',
#  '183': 'mz_to_sqlite',
#  '184': 'graphlan',
#  '185': 'mass_spectrometry_imaging_segmentations',
#  '186': 'stringtie',
#  '187': 'vegan_rarefaction',
#  '188': 'macs2_predictd',
#  '189': 'vcf2pgSnp',
#  '190': 'barchart_gnuplot',
#  '191': 'sklearn_searchcv',
#  '192': 'lca1',
#  '193': 'structure_to_gspan',
#  '194': 'IDConflictResolver',
#  '195': 'IDFileConverter',
#  '196': 'bed2gff1',
#  '197': 'pilon',
#  '198': 'graphicsmagick_image_convert',
#  '199': 'ia_coordinates_of_roi',
#  '200': 'viennarna_rnaalifold',
#  '201': 'signalp3',
#  '202': 'random_lines1',
#  '203': 'fastq_paired_end_deinterlacer',
#  '204': 'FileFilter',
#  '205': 'collection_column_join',
#  '206': 'ncbi_blastn_wrapper',
#  '207': 'dunovo',
#  '208': 'bedtools_bamtofastq',
#  '209': 'ctb_remSmall',
#  '210': 'vcfflatten2',
#  '211': 'trinity',
#  '212': 'multiqc',
#  '213': 'group_humann2_uniref_abundances_to_go',
#  '214': 'bam2wig',
#  '215': 'cmv',
#  '216': 'deeptools_computeMatrix',
#  '217': 'minfi_getbeta',
#  '218': 'mothur_lefse',
#  '219': 'picard_CollectWgsMetrics',
#  '220': 'deeptools_heatmapper',
#  '221': 'tsne',
#  '222': 'FROGS_clustering',
#  '223': 'methtools_tiling',
#  '224': 'gops_cluster_1',
#  '225': 'cshl_fastx_artifacts_filter',
#  '226': 'ConsensusID',
#  '227': 'vcfannotate',
#  '228': 'metilene',
#  '229': 'filter_bed_on_splice_junctions',
#  '230': 'sklearn_nn_classifier',
#  '231': 'plotly_regression_performance_plots',
#  '232': 'bedtools_bamtobed',
#  '233': 'maldi_quant_peak_detection',
#  '234': 'uchime',
#  '235': 't2t_report',
#  '236': 'segemehl',
#  '237': 'bedtools_shufflebed',
#  '238': 'pynast',
#  '239': 'Extract_features1',
#  '240': 'datamash_ops',
#  '241': 'cufflinks_prok',
#  '242': 'megahit',
#  '243': 'cshl_fastx_renamer',
#  '244': 'allele_counts_1',
#  '245': 'w4mcorcov',
#  '246': 'shovill',
#  '247': 'gtf_filter_by_attribute_values_list',
#  '248': 'tp_grep_tool',
#  '249': 'cshl_fastq_to_fasta',
#  '250': 'ctb_chemfp_mol2fps',
#  '251': 'mothur_classify_otu',
#  '252': 'vsearch_dereplication',
#  '253': 'mothur_merge_files',
#  '254': 'velveth_jgi',
#  '255': 'vcfbedintersect',
#  '256': 'deeptools_bamCorrelate',
#  '257': 'Flash',
#  '258': 'preMloc',
#  '259': 'megablast_wrapper',
#  '260': 'bedtools_multicovtbed',
#  '261': 'umi_tools_group',
#  '262': 'gops_coverage_1',
#  '263': 'gemini_recessive_and_dominant',
#  '264': 'metaphlan2krona',
#  '265': 'mothur_corr_axes',
#  '266': 'ctb_remIons',
#  '267': 'bctools_extract_crosslinked_nucleotides',
#  '268': 'MSGFPlusAdapter',
#  '269': 'extract_bcs.py',
#  '270': 'vcf2tsv',
#  '271': 'vcfallelicprimitives',
#  '272': 'Add_a_column1',
#  '273': 'egsea',
#  '274': 'mothur_homova',
#  '275': 'hicexplorer_hicfindtads',
#  '276': 'Show tail1',
#  '277': 'gops_merge_1',
#  '278': 'bismark_bowtie2',
#  '279': 'bwa_wrapper',
#  '280': 'Heatmap',
#  '281': 'abims_xcms_fillPeaks',
#  '282': 'abims_xcms_summary',
#  '283': 'regex1',
#  '284': 'annotatemyids',
#  '285': 'bctools_remove_spurious_events',
#  '286': 'w4mclstrpeakpics',
#  '287': 'qiime_pick_closed_reference_otus',
#  '288': 'dexseq_count',
#  '289': 'deg_annotate',
#  '290': 'gff_to_sequence',
#  '291': 'deeptools_computeGCBias',
#  '292': 'mothur_venn',
#  '293': 'w4mclassfilter',
#  '294': 'limma_voom',
#  '295': 'deeptools_plot_coverage',
#  '296': 'pureclip',
#  '297': 'spades',
#  '298': 'augustus',
#  '299': 'hicexplorer_hicpca',
#  '300': 'picard_EstimateLibraryComplexity',
#  '301': 'bcftools_view',
#  '302': 'DatamashOps',
#  '303': 'FeatureFinderMetabo',
#  '304': 'bedtools_mergebed',
#  '305': 'Btrim64',
#  '306': 'addName',
#  '307': 'picard_ReorderSam',
#  '308': 'IDScoreSwitcher',
#  '309': 'mothur_trim_seqs',
#  '310': 'join1',
#  '311': 'nspdk_sparse',
#  '312': 'cmFinder',
#  '313': 'FROGS_remove_chimera',
#  '314': 'ggplot_point',
#  '315': 'cshl_find_and_replace',
#  '316': 'MapAlignerPoseClustering',
#  '317': 'mimodd_map',
#  '318': 'ctb_ob_genProp',
#  '319': 'trim_galore',
#  '320': 'mothur_count_seqs',
#  '321': '__MERGE_COLLECTION__',
#  '322': 'ctb_change_title',
#  '323': 'bandage_image',
#  '324': 'stacks_denovomap',
#  '325': 'nanopolish_variants',
#  '326': 'krona-text',
#  '327': 'cshl_word_list_grep',
#  '328': 'picard_AddOrReplaceReadGroups',
#  '329': 'CONVERTER_bed_to_bgzip_0',
#  '330': 'replace_column_with_key_value_file',
#  '331': 'gatk2_unified_genotyper',
#  '332': 'msconvert_nix',
#  '333': 'maldi_quant_preprocessing',
#  '334': 'term_id_vs_term_name',
#  '335': 'bctools_extract_alignment_ends',
#  '336': 'hmmer_hmmsearch',
#  '337': 'EMBOSS: transeq101',
#  '338': 'mothur_make_group',
#  '339': 'createInterval',
#  '340': 'picard_MarkDuplicatesWithMateCigar',
#  '341': 'gmx_em',
#  '342': 'vcffilter2',
#  '343': 'gops_join_1',
#  '344': 'hgv_david',
#  '345': 'msconvert2_raw',
#  '346': 'mothur_chimera_uchime',
#  '347': 'samtools_flag_filter',
#  '348': 'smf_utils_fix-fasta-headers',
#  '349': 'picard_CleanSam',
#  '350': 'samtools_rmdup',
#  '351': 'trim_reads',
#  '352': 'mycrobiota-qc-report',
#  '353': 'subtract_query1',
#  '354': 'Extractor',
#  '355': 'gene2exon1',
#  '356': 'find_in_reference',
#  '357': 'aggregate_scores_in_intervals2',
#  '358': 'cufflinks',
#  '359': 'goseq',
#  '360': 'ncbi_makeblastdb',
#  '361': 'bedtools_genomecoveragebed_histogram',
#  '362': 'bedtools_intersectbed_bam',
#  '363': 'MzTabExporter',
#  '364': 'DecoyDatabase',
#  '365': 'myrimatch',
#  '366': 'Determine_BC',
#  '367': 'sqlite_to_tabular',
#  '368': 'gemini_burden',
#  '369': 'cardinal_spectra_plots',
#  '370': 'hicexplorer_hicsummatrices',
#  '371': 'mothur_make_shared',
#  '372': 'bedtools_intersectBed',
#  '373': 'ExtractFASTAfromFASTQ',
#  '374': 'picard_ARRG',
#  '375': 'humann2_genefamilies_genus_level',
#  '376': 'cshl_cut_tool',
#  '377': 'bg_uniq',
#  '378': 'velvet',
#  '379': 'gemini_windower',
#  '380': 'cshl_awk_tool',
#  '381': 'openms_id_mapper',
#  '382': 'sequence_content_trimmer',
#  '383': 'bcftools_call',
#  '384': 'bams2ratio',
#  '385': 'ncbi_rpsblast_wrapper',
#  '386': 'bwameth',
#  '387': 'blastxml_to_tabular_selectable',
#  '388': 'column_order_header_sort',
#  '389': 'bedtools_multiintersectbed',
#  '390': 'modencode_peakcalling_spp',
#  '391': 'qiime_validate_mapping_file',
#  '392': 'pileup_interval',
#  '393': 'vcfsort',
#  '394': 'sailfish',
#  '395': 'vcf_filter',
#  '396': 'gops_concat_1',
#  '397': 'sklearn_feature_selection',
#  '398': 'minfi_dropsnp',
#  '399': 'infernal_cmstat',
#  '400': 'peakcalling_macs14',
#  '401': 'merge_pcr_duplicates.py',
#  '402': 'megablast_xml_parser',
#  '403': 'mothur_heatmap_sim',
#  '404': 'mothur_cluster_split',
#  '405': 'hicexplorer_hicbuildmatrix',
#  '406': 'vcffilter',
#  '407': 'picard_MergeSamFiles',
#  '408': 'PeptideIndexer',
#  '409': '__SORTLIST__',
#  '410': 'raceid_inspecttrajectory',
#  '411': 'lastz_wrapper_2',
#  '412': 'cutadapt',
#  '413': 'cat1',
#  '414': 'minfi_maptogenome',
#  '415': 'ucsc-twobittofa',
#  '416': 'snpfinder',
#  '417': 'ncbi_blastp_wrapper',
#  '418': 'snpSift_dbnsfp_generic',
#  '419': 'deeptools_multi_bam_summary',
#  '420': 'mothur_get_communitytype',
#  '421': 'Grep1',
#  '422': 'bedtools_subtractbed',
#  '423': 'picard_CASM',
#  '424': 'rgweblogo3',
#  '425': 'mothur_pcoa',
#  '426': 'numeric_clustering',
#  '427': 'MultiplexResolver',
#  '428': 'bedtools_complementbed',
#  '429': 'cshl_awk_replace_in_column',
#  '430': 'mothur_taxonomy_to_krona',
#  '431': 'addValue',
#  '432': 'pileometh',
#  '433': 'treebest_best',
#  '434': 'CONVERTER_interval_to_bedstrict_0',
#  '435': 'minfi_dmp',
#  '436': 'mlocarna',
#  '437': 'flanking_features_1',
#  '438': 'fasta_compute_length',
#  '439': 'deeptools_bigwig_compare',
#  '440': 'FileMerger',
#  '441': 'smf_utils_estimate-energy',
#  '442': 'varscan_mpileup',
#  '443': 'glimmer_build-icm',
#  '444': 'blastxml_to_top_descr',
#  '445': 'je_markdupes',
#  '446': 'gffcompare',
#  '447': 'sam2interval',
#  '448': 'fastq_paired_end_joiner',
#  '449': 'FeatureFinderCentroided',
#  '450': 'IDMerger',
#  '451': 'bismark_bowtie',
#  '452': 'vcfgenotypes',
#  '453': 'CONVERTER_fastqgz_to_fastq',
#  '454': 'pieplots_macs',
#  '455': 'FidoAdapter',
#  '456': 'mcClust',
#  '457': 'deeptools_bam_compare',
#  '458': 'samtools_calmd',
#  '459': 'gd_raxml',
#  '460': 'circgraph',
#  '461': 'snippy_core',
#  '462': 'roary',
#  '463': '__RELABEL_FROM_FILE__',
#  '464': 'picard_NormalizeFasta',
#  '465': 'rseqc_bam_stat',
#  '466': 'get_read_pipeline',
#  '467': 'gemini_actionable_mutations',
#  '468': 'sickle',
#  '469': 'gff2bed1',
#  '470': 'cshl_fastx_barcode_splitter',
#  '471': 'raceid_clustering',
#  '472': 'aragorn_trna',
#  '473': 'gatk2_print_reads',
#  '474': 'CONVERTER_interval_to_bed_0',
#  '475': 'freebayes',
#  '476': 'graphclust_align_cluster',
#  '477': 'EMBOSS: fuzzpro38',
#  '478': 'transpose',
#  '479': 'hmmer_hmmbuild',
#  '480': 'IDPosteriorErrorProbability',
#  '481': 'qiime_assign_taxonomy',
#  '482': 'snippy',
#  '483': 'varscan',
#  '484': 'rseqc_read_distribution',
#  '485': 'bg_statistical_hypothesis_testing',
#  '486': 'deeptools_plot_enrichment',
#  '487': 'Batch_correction',
#  '488': 'cshl_princeton_fastx_barcode_splitter',
#  '489': 'EMBOSS: revseq82',
#  '490': 'tp_multijoin_tool',
#  '491': 'bedtools_genomecoveragebed_bedgraph',
#  '492': 'biosigner',
#  '493': 'cshl_uniq_tool',
#  '494': 'mothur_count_groups',
#  '495': 'preproc',
#  '496': 'minfi_methcpg',
#  '497': 'Remove beginning1',
#  '498': 'sam_pileup',
#  '499': 'smf_utils_find-boxes',
#  '500': 'sklearn_build_pipeline',
#  '501': 'idr-embl',
#  '502': 'mothur_make_biom',
#  '503': 'Nucleosome',
#  '504': 'glob_report',
#  '505': 'Extract_RNA_seq_Evidence',
#  '506': 'varscan_copynumber',
#  '507': 'cshl_fastx_collapser',
#  '508': 'IDFilter',
#  '509': 'gatk2_indel_realigner',
#  '510': 'sklear_numeric_clustering',
#  '511': 'tp_easyjoin_tool',
#  '512': 'bedtools_windowbed',
#  '513': 'sample_seqs',
#  '514': '16Sclassifier',
#  '515': 'je_demultiplex',
#  '516': 'deeptools_multi_bigwig_summary',
#  '517': 'goenrichment',
#  '518': 'glimmer_knowlegde-based',
#  '519': 'EMBOSS: wordcount109',
#  '520': 'picard_MarkDuplicates',
#  '521': 'kraken-report',
#  '522': 'deeptools_bamFingerprint',
#  '523': 'Multivariate',
#  '524': 'tophat2',
#  '525': 'heinz',
#  '526': 'samtools_mpileup',
#  '527': 'XTandemAdapter',
#  '528': 'umi_tools_whitelist',
#  '529': 'coords2clnt.py',
#  '530': 'tp_text_file_with_recurring_lines',
#  '531': 'minfi_dmr',
#  '532': 'meme_dreme',
#  '533': 'remove_tail.py',
#  '534': 'trimmer',
#  '535': 'xpath',
#  '536': 'stacks_populations',
#  '537': 'deeptools_correct_gc_bias',
#  '538': 'openms_id_file_converter',
#  '539': 'ggplot_histogram',
#  '540': 'get_feature_info',
#  '541': 'gemini_comp_hets',
#  '542': 'featurecounts',
#  '543': 'Digestor',
#  '544': '__FILTER_FROM_FILE__',
#  '545': 'qiime_make_otu_heatmap',
#  '546': 'tp_tac',
#  '547': 'gatk2_base_recalibrator',
#  '548': 'deeptools_plot_fingerprint',
#  '549': 'bamleftalign',
#  '550': 'mass_spectrometry_imaging_filtering',
#  '551': 'XY_Plot_1',
#  '552': 'rnaz',
#  '553': 'glimmer_not-knowlegde-based',
#  '554': 'sort1',
#  '555': 'mothur_classify_rf',
#  '556': 'kraken-filter',
#  '557': 'mothur_get_oturep',
#  '558': 'bedtools_coveragebed',
#  '559': 'translate_bed_sequences',
#  '560': 'tp_tail_tool',
#  '561': 'mothur_remove_lineage',
#  '562': 'mothur_summary_seqs',
#  '563': 'qiime_make_phylogeny',
#  '564': 'sklearn_numeric_clustering',
#  '565': 'vcftools_merge',
#  '566': 'get_flanks1',
#  '567': 'MassCalculator',
#  '568': 'fasta-stats',
#  '569': 'tp_split_on_column',
#  '570': 'ete_homology_classifier',
#  '571': 'EMBOSS: getorf42',
#  '572': 'deeptools_plot_pca',
#  '573': 'fasta_merge_files_and_filter_unique_sequences',
#  '574': 'EMBOSS: extractseq35',
#  '575': 'prokaryotic_ncbi_submission',
#  '576': 'hisat2',
#  '577': 'PeakPickerHiRes',
#  '578': 'mass_spectrometry_imaging_mzplots',
#  '579': 'uniprot',
#  '580': 'FeatureFinderMultiplex',
#  '581': 'CONVERTER_gff_to_bed_0',
#  '582': 'ip_projective_transformation',
#  '583': 'MapStatistics',
#  '584': 'bedtools_map',
#  '585': 'cshl_easyjoin',
#  '586': 'rarefaction_analyzer',
#  '587': 'graphlan_annotate',
#  '588': 'wc_gnu',
#  '589': 'SequenceCoverageCalculator',
#  '590': 'jbrowse',
#  '591': 'qiime_split_libraries_fastq',
#  '592': 'ctb_silicos_qed',
#  '593': 'tophat',
#  '594': 'hgv_snpFreq',
#  '595': 'fastq_to_fasta_python',
#  '596': 'cardinal_quality_report',
#  '597': 'proteomics_search_protein_prophet_1',
#  '598': 'cshl_sort_header',
#  '599': 'deeptools_bamCompare',
#  '600': 'clustalw',
#  '601': 'gemini_db_info',
#  '602': '__FLATTEN__',
#  '603': 'get_subontology_from',
#  '604': 'mothur_cluster',
#  '605': 'gatk_indel_realigner',
#  '606': 'hisat',
#  '607': 'bwa_mem',
#  '608': 'velvetg_jgi',
#  '609': 'make_families',
#  '610': 'cardinal_segmentations',
#  '611': 'fastq_join',
#  '612': 'iReport',
#  '613': 'sklearn_ensemble',
#  '614': 'fgsea',
#  '615': 'TextExporter',
#  '616': 'join_files_on_column_fuzzy',
#  '617': 'TrimByLength',
#  '618': 'humann2_renorm_table',
#  '619': 'FeatureLinkerUnlabeledQT',
#  '620': 'bg_find_subsequences',
#  '621': 'deeptools_compute_matrix_operations',
#  '622': 'metams_runGC',
#  '623': 'GeneModelMapper',
#  '624': 'locarna_best_subtree',
#  '625': 'naive_variant_caller',
#  '626': 'mothur_pre_cluster',
#  '627': 'minfi_read450k',
#  '628': 'EMBOSS: geecee41',
#  '629': 'smf_utils_extract-boxed-sequences',
#  '630': 'picard_BamIndexStats',
#  '631': 'NFS_transfer',
#  '632': 'correct_barcodes',
#  '633': 'gatk_unified_genotyper',
#  '634': 'selectsequencesfrommsa',
#  '635': 'deeptools_correctGCBias',
#  '636': 't_coffee',
#  '637': 'bamCompare_deepTools',
#  '638': 'transdecoder',
#  '639': 'bamFilter',
#  '640': 'gops_subtract_1',
#  '641': 'gspan',
#  '642': 'CONVERTER_gz_to_uncompressed',
#  '643': 'prokka',
#  '644': 'minfi_getM',
#  '645': 'CONVERTER_sam_to_unsorted_bam',
#  '646': 'interproscan',
#  '647': 'wiggle2simple1',
#  '648': 'cardinal_mz_images',
#  '649': 'chipsequtil_maptoknowngenes',
#  '650': 'Grouping1',
#  '651': 'tabular_to_fastq',
#  '652': 'heinz_visualization',
#  '653': 'extract_element_from_collection',
#  '654': 'nn_classifier',
#  '655': 'rna_star',
#  '656': 'filtlong',
#  '657': 'mycrobiota-otutable_add_blast',
#  '658': 'deeptools_profiler',
#  '659': 'deeptools_plot_profile',
#  '660': 'gatk2_variant_recalibrator',
#  '661': 'vcftools_isec',
#  '662': 'proteomics_moff',
#  '663': 'FileConverter',
#  '664': 'tp_sed_tool',
#  '665': 'rseqc_infer_experiment',
#  '666': 'stringtie_merge',
#  '667': 'ncbi_tblastn_wrapper',
#  '668': 'melt',
#  '669': 'graphclust_glob_report_no_align',
#  '670': 'mothur_heatmap_bin',
#  '671': 'Datamash',
#  '672': 'CONVERTER_fasta_to_tabular',
#  '673': 'mothur_chimera_vsearch',
#  '674': 'fasttree',
#  '675': 'deeptools_compute_matrix',
#  '676': 'tp_cat',
#  '677': 'snpSift_annotate',
#  '678': 'hgv_linkToGProfile',
#  '679': 'cuffnorm',
#  '680': 'samtools_filter',
#  '681': 'igvtools_count',
#  '682': 'bedtools_slopbed',
#  '683': 'rnafold',
#  '684': 'CometAdapter',
#  '685': 'rm_spurious_events.py',
#  '686': 'CONVERTER_Bam_Bai_0',
#  '687': 'cshl_sed_tool',
#  '688': 'gatk2_variant_apply_recalibration',
#  '689': 'gatk2_realigner_target_creator',
#  '690': 'piranha',
#  '691': 'valet',
#  '692': 'qiime_core_diversity',
#  '693': 'gtf2bedgraph',
#  '694': 'gemini_interactions',
#  '695': 'align_families',
#  '696': 'idpassemble',
#  '697': 'tp_unfold_column_tool',
#  '698': 'mass_spectrometry_imaging_combine',
#  '699': 'raceid_filtnormconf',
#  '700': 'kraken',
#  '701': 'smf_utils_filter-by-energy',
#  '702': 'cshl_fastq_quality_filter',
#  '703': 'FeatureLinkerUnlabeledKD',
#  '704': 'idpquery',
#  '705': 'unicycler',
#  '706': 'eukaryotic_ncbi_submission',
#  '707': 'datamash_transpose',
#  '708': 'CONVERTER_bed_gff_or_vcf_to_bigwig_0',
#  '709': 'abims_CAMERA_annotateDiffreport',
#  '710': 'picard_SortSam',
#  '711': 'mothur_phylotype',
#  '712': 'vt_normalize',
#  '713': 'tophat_fusion_post',
#  '714': 'EMBOSS: water107',
#  '715': 'vcfselectsamples',
#  '716': 'ggplot2_heatmap2',
#  '717': 'TrimPrimer',
#  '718': 'charts',
#  '719': 'blast2go',
#  '720': 'rgPicardMarkDups',
#  '721': 'peakachu',
#  '722': 'htseq_count',
#  '723': 'seq_filter_by_mapping',
#  '724': 'bedtools_intersectbed',
#  '725': 'gmx_solvate',
#  '726': 'proteomics_search_tandem_1',
#  '727': 'PicardInsertSize',
#  '728': 'cuffquant',
#  '729': 'bigwig_to_bedgraph',
#  '730': 'predict_pipeline',
#  '731': 'heatmapper',
#  '732': 'rsem_prepare_reference',
#  '733': 'tp_replace_in_line',
#  '734': 'length_and_gc_content',
#  '735': 'CONVERTER_gff_to_interval_index_0',
#  '736': 'gatk2_variant_select',
#  '737': 'humann2_regroup_table',
#  '738': 'dexseq',
#  '739': 'cardinal_preprocessing',
#  '740': 'mycrobiota-split-multi-otutable',
#  '741': 'pileup_parser',
#  '742': 'mothur_summary_single',
#  '743': 'wolf_psort',
#  '744': 'eden_sequence_converter',
#  '745': 'mycrobiota-correct-replicates',
#  '746': 'fastq_to_tabular',
#  '747': 'tab2fasta',
#  '748': 'seq_filter_by_id',
#  '749': 'ctb_filter',
#  '750': 'ggplot2_heatmap',
#  '751': 'snpeff_to_peptides',
#  '752': 'svm_classifier',
#  '753': 'edger',
#  '754': 'Summary_Statistics1',
#  '755': 'Extract genomic DNA 1',
#  '756': 'cummerbund_to_cuffdiff',
#  '757': 'stacks_procrad',
#  '758': 'flexbar',
#  '759': 'CONVERTER_bedgraph_to_bigwig',
#  '760': 'antismash',
#  '761': 'gemini_query',
#  '762': 'ProteinQuantifier',
#  '763': 'EMBOSS: shuffleseq87',
#  '764': 'mimodd_varreport',
#  '765': 'fastq_trimmer',
#  '766': 'resistome_analyzer',
#  '767': 'mycrobiota-make-multi-otutable',
#  '768': 'fasta2tab',
#  '769': 'heatmap2',
#  '770': 're_he_maldi_image_registration',
#  '771': 'secure_hash_message_digest',
#  '772': 'methtools_calling',
#  '773': 'TrimByN',
#  '774': 'paralyzer',
#  '775': 'mergeCols1',
#  '776': 'tp_sort_header_tool',
#  '777': 'scaffold2fasta',
#  '778': 'methtools_destrand',
#  '779': 'gemini_annotate',
#  '780': 'samtools_idxstats',
#  '781': 'ChooseTag',
#  '782': 'fastq_dump',
#  '783': 'ssake',
#  '784': 'FalseDiscoveryRate',
#  '785': 'ProteinResolver',
#  '786': 'ctb_compound_convert',
#  '787': 'bamCoverage_deepTools',
#  '788': 'stacks_genotypes',
#  '789': 'picard_FilterSamReads',
#  '790': 'Convert characters1',
#  '791': 'snpEff',
#  '792': 'macs2_bdgcmp',
#  '793': 'picard_SamToFastq',
#  '794': 'cast',
#  '795': 'CONVERTER_fasta_to_fai',
#  '796': 'plotly_parallel_coordinates_plot',
#  '797': 'comp1',
#  '798': 'flexbar_split_RYYR_bcs',
#  '799': 'NSPDK_candidateClust',
#  '800': 'FileInfo',
#  '801': 'export2graphlan',
#  '802': 'get_sequences',
#  '803': 'FROGS_affiliation_OTU',
#  '804': 'kallisto_quant',
#  '805': 'tp_replace_in_column',
#  '806': 'secretbt2test',
#  '807': 'locarna_multiple',
#  '808': 'rseqc_junction_saturation',
#  '809': 'gatk2_reduce_reads',
#  '810': 'bwa',
#  '811': 'flye',
#  '812': 'Psortb',
#  '813': 'mass_spectrometry_imaging_preprocessing',
#  '814': 'hcluster_sg_parser',
#  '815': 'cuffdiff',
#  '816': 'ngsutils_bam_filter',
#  '817': 'tp_sorted_uniq',
#  '818': 'mimodd_vcf_filter',
#  '819': 'mothur_sub_sample',
#  '820': '__FILTER_FAILED_DATASETS__',
#  '821': 'bedtools_genomecoveragebed',
#  '822': 'ConsensusMapNormalizer',
#  '823': 'mass_spectrometry_imaging_classification',
#  '824': 'modencode_peakcalling_macs2',
#  '825': 'fastq_paired_end_interlacer',
#  '826': 'FROGS_preprocess',
#  '827': 'cd_hit_dup',
#  '828': 'xcms_merge',
#  '829': 'deeptools_compute_gc_bias',
#  '830': '__ZIP_COLLECTION__',
#  '831': 'bowtie_wrapper',
#  '832': 'checkFormat',
#  '833': 'mothur_dist_seqs',
#  '834': 'proteomics_search_peptide_prophet_1',
#  '835': 'mothur_unique_seqs',
#  '836': 'umi_tools_extract',
#  '837': 'mothur_seq_error',
#  '838': 'cshl_fastx_clipper',
#  '839': 'bundle_collection',
#  '840': 'flexbar_no_split',
#  '841': 'varscan_somatic',
#  '842': 'nonpareil',
#  '843': 'dexseq_annotate',
#  '844': 'gbk_to_orf',
#  '845': 'samtools_flagstat',
#  '846': 'PicardASMetrics',
#  '847': 'picard_CollectInsertSizeMetrics',
#  '848': 'gtftobed12',
#  '849': 'Show beginning1',
#  '850': 'htseq-count',
#  '851': 'samtools_slice_bam',
#  '852': 'racon',
#  '853': 'gemini_pathways',
#  '854': 'get_child_terms',
#  '855': 'heinz_bum',
#  '856': 'genbank_to_gff',
#  '857': 'bctools_remove_tail',
#  '858': 'convert_bc_to_binary_RY.py',
#  '859': 'p_clip_peaks',
#  '860': 'rnbeads',
#  '861': 'fasplit',
#  '862': 'CONVERTER_bed_to_gff_0',
#  '863': 'fastq_paired_end_splitter',
#  '864': 'abricate',
#  '865': 'vcftools_annotate',
#  '866': 'gops_basecoverage_1',
#  '867': 'tmhmm2',
#  '868': 'mothur_align_seqs',
#  '869': 'cuffcompare',
#  '870': 'cardinal_filtering',
#  '871': 'deseq2',
#  '872': 'silac_analyzer',
#  '873': 'gatk_depth_of_coverage',
#  '874': 'tp_awk_tool',
#  '875': 'EMBOSS: textsearch98',
#  '876': 'enhanced_bowtie_wrapper',
#  '877': 'MapRTTransformer',
#  '878': 'deeptools_bam_coverage',
#  '879': 'bedtools_getfastabed',
#  '880': 'bedtools_coveragebed_counts',
#  '881': 'gatk_realigner_target_creator',
#  '882': 'rbc_splitfasta',
#  '883': 'wsdl_hmdb',
#  '884': 'minimap2',
#  '885': 'heatmapper_deepTools',
#  '886': 'cshl_fastx_nucleotides_distribution',
#  '887': 'bam_to_bigwig',
#  '888': 'fraggenescan',
#  '889': 'abims_xcms_xcmsSet',
#  '890': 'filter_by_fasta_ids',
#  '891': 'fastq_filter',
#  '892': 'map_peptides_to_bed',
#  '893': 'decoyfasta',
#  '894': 'raceid_inspectclusters',
#  '895': 'infernal_cmsearch',
#  '896': 'sed_stream_editor',
#  '897': 'mass_spectrometry_imaging_qc',
#  '898': 'cshl_fasta_formatter',
#  '899': 'gatk2_variant_annotator',
#  '900': 'RNAlien',
#  '901': 'rseqc_geneBody_coverage',
#  '902': 'gatk2_haplotype_caller',
#  '903': 'bam_to_sam',
#  '904': 'bcftools_consensus',
#  '905': 'trimmomatic',
#  '906': 'FeatureLinkerUnlabeled',
#  '907': 'samtools_stats',
#  '908': 'EMBOSS: fuzztran39',
#  '909': 'gops_intersect_1',
#  '910': 'flexbar_split_RR_bcs',
#  '911': 'macs2_callpeak',
#  '912': 'tp_uniq_tool',
#  '913': 'ggplot2_histogram',
#  '914': 'snpEff_download',
#  '915': 'smooth_running_window',
#  '916': 'rgPicFixMate',
#  '917': 'table_annovar',
#  '918': 'cshl_grep_tool',
#  '919': 'peakcalling_macs',
#  '920': 'column_remove_by_header',
#  '921': 'seurat',
#  '922': 'hcluster_sg',
#  '923': 'rsem_calculate_expression',
#  '924': 'bedtools_sortbed',
#  '925': 'bed_to_bigBed',
#  '926': 'bg_protein_properties',
#  '927': 'porechop',
#  '928': 'gmx_nvt',
#  '929': 'mothur_get_seqs',
#  '930': 'cshl_multijoin',
#  '931': 'gffread',
#  '932': 'combine_metaphlan2_humann2',
#  '933': 'bcftools_norm',
#  '934': 'rseqc_inner_distance',
#  '935': 'fragmenter',
#  '936': 'ctb_online_data_fetch',
#  '937': 'methtools_dmr',
#  '938': 'goslimmer',
#  '939': 'scpipe',
#  '940': 'DatamashTranspose',
#  '941': 'minfi_ppfun',
#  '942': 'mothur_metastats',
#  '943': 'gmx_md',
#  '944': 'snpsift_vartype',
#  '945': 'humann2',
#  '946': 'rbc_rnacode',
#  '947': 'cor2',
#  '948': 'graphclust_aggregate_alignments',
#  '949': 'histogram_rpy',
#  '950': 'qiime_pick_otus',
#  '951': 'mothur_make_contigs',
#  '952': 'mothur_amova',
#  '953': 'sklearn_svm_classifier',
#  '954': 'viennarna_rnafold',
#  '955': 'vcfcombine',
#  '956': 'cardinal_data_exporter',
#  '957': 'EMBOSS: tranalign100',
#  '958': 'metaphlan2',
#  '959': 'Interval_Maf_Merged_Fasta2',
#  '960': 'sam_merge2',
#  '961': 'gafa',
#  '962': 'MAF_To_Fasta1',
#  '963': 'annotateMyIDs',
#  '964': 'vcfvcfintersect',
#  '965': 'mycrobiota-krona-mothur',
#  '966': 'ctb_simsearch',
#  '967': 'ggplot2_point',
#  '968': 'methtools_plot',
#  '969': 'gemini_de_novo',
#  '970': 'iuc_pear',
#  '971': 'meme_chip'}

# %%
def verify_model(model, tool_sequence, labels, dictionary, reverse_dictionary, compatible_tools, topk=30, max_seq_len=25):
    tl_seq = tool_sequence.split(",")
    last_tool_name = reverse_dictionary[str(tl_seq[-1])]
    last_compatible_tools = compatible_tools[last_tool_name]
    sample = np.zeros(max_seq_len)
    for idx, tool_id in enumerate(tl_seq):
        sample[idx] = int(tool_id)
    sample_reshaped = np.reshape(sample, (1, max_seq_len))
    
    tool_sequence_names = [reverse_dictionary[str(tool_pos)] for tool_pos in tool_sequence.split(",")]
    print("Tool seq: %s" % ",".join(tool_sequence_names))
    # predict next tools for a test path
    prediction = model.predict(sample_reshaped, verbose=0)
    prediction = np.reshape(prediction, (prediction.shape[1],))
    prediction_pos = np.argsort(prediction, axis=-1)

    # get topk prediction
    topk_prediction_pos = prediction_pos[-topk:]
    topk_prediction_val = [np.round(prediction[pos] * 100, 2) for pos in topk_prediction_pos]

    # read tool names using reverse dictionary
    pred_tool_ids = [reverse_dictionary[str(tool_pos)] for tool_pos in topk_prediction_pos]
    actual_next_tool_ids = list(set(pred_tool_ids).intersection(set(last_compatible_tools.split(","))))      
        
    #print("Predicted tools: %s" % ",".join(pred_tool_ids))
    print()
    pred_tool_ids_sorted = dict()
    for (tool_pos, tool_pred_val) in zip(topk_prediction_pos, topk_prediction_val):
        tool_name = reverse_dictionary[str(tool_pos)]
        if tool_name in actual_next_tool_ids:
            pred_tool_ids_sorted[tool_name] = tool_pred_val
    pred_tool_ids_sorted = dict(sorted(pred_tool_ids_sorted.items(), key=lambda kv: kv[1], reverse=True))
    
    cls_wt = dict()
    usg_wt = dict()
    inv_wt = dict()
    ids_tools = dict()
    keys = list(pred_tool_ids_sorted.keys())
    for k in keys:
        try:
            cls_wt[k] = np.round(class_weights[str(data_dict[k])], 2)
            usg_wt[k] = np.round(usage_weights[k], 2)
            inv_wt[k] = np.round(inverted_weights[str(data_dict[k])], 2)
        except:
            continue
    print("Predicted tools: \n")
    print(pred_tool_ids_sorted)
    print()
    print("Class weights: \n")
    cls_wt = dict(sorted(cls_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(cls_wt)
    print()
    print("Usage weights: \n")
    usg_wt = dict(sorted(usg_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(usg_wt)
    print()
    print("Inverted weights: \n")
    inv_wt = dict(sorted(inv_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(inv_wt)
    for key in pred_tool_ids_sorted:
        ids_tools[key] = dictionary[key]
    print()
    print("Tool ids")
    print(ids_tools)
    print("======================================")
    return cls_wt, usg_wt, inv_wt, pred_tool_ids_sorted

topk = 10
tool_seq = "905"
class_wt, usage_wt, inverse_wt, pred_tools = verify_model(model, tool_seq, "", dictionary, reverse_dictionary, compatibile_tools, topk)
# Out:
# Tool seq: trimmomatic
#
# Predicted tools:
#
# {'fastqc': 24.93}
#
# Class weights:
#
# {'fastqc': 46842.03}
#
# Usage weights:
#
# {'fastqc': 5879.0}
#
# Inverted weights:
#
# {'fastqc': 837.82}
#
# Tool ids
# {'fastqc': 25}
# ======================================

# %%
list_cls_wt = list()
list_usage_wt = list()
list_pred_wt = list()
division_pt = int(len(pred_tools) / 2)

for tool in pred_tools:
    list_pred_wt.append(pred_tools[tool])
    try:
        list_cls_wt.append(class_wt[tool])
    except:
        list_cls_wt.append(1)

def plot_scatter(y_val, title, xlabel, ylabel):
    x_val = range(1, len(y_val) + 1)
    plt.figure(figsize=(8, 8))
    plt.plot(x_val[:division_pt], y_val[:division_pt], 'ro')
    plt.plot(x_val[division_pt:], y_val[division_pt:], 'b^')
    plt.xlabel(xlabel, size=size_label)
    plt.ylabel(ylabel, size=size_label)
    plt.legend([("First top-%s" % str(division_pt)), ("Next top-%s" % str(division_pt))])
    plt.title(title, size=size_title)
    plt.grid(True)
    plt.show()

plot_scatter(list_cls_wt, "Usage weights for tools", "Number of tools", "Class weights")
#plot_scatter(ave_prediction_weights, ave_usage_weights, "Prediction vs usage weights", "Prediction scores", "Usage weights")
#plot_scatter(ave_prediction_weights, ave_inverted_weights, "Prediction vs inverted weights", "Prediction scores", "Inverted weights")
