# %%
import numpy as np
import json
import warnings
import operator

import h5py
from keras.models import model_from_json
from keras import backend as K

from matplotlib import pyplot as plt

warnings.filterwarnings("ignore")

size_title = 18
size_label = 14
n_pred = 2

base_path = "data/evaluate_log_sum_sample/"

path_data_dict = base_path + "data_dict.txt"
path_inverted_wt = base_path + "inverted_weights.txt"
path_usage_wt = base_path + "usage_prediction.txt"
path_class_wt = base_path + "class_weights.txt"
path_test_data = base_path + "test_paths_dict.txt"
model_path = base_path + "trained_model.hdf5"

def read_file(file_path):
    with open(file_path, 'r') as data_file:
        data = json.loads(data_file.read())
    return data

class_weights = read_file(path_class_wt)
usage_weights = read_file(path_usage_wt)
inverted_weights = read_file(path_inverted_wt)
data_dict = read_file(path_data_dict)

def create_model(model_path):
    trained_model = h5py.File(model_path, 'r')
    model_config = json.loads(trained_model.get('model_config').value)
    loaded_model = model_from_json(model_config)
    dictionary = json.loads(trained_model.get('data_dictionary').value)
    compatibile_tools = json.loads(trained_model.get('compatible_tools').value)
    reverse_dictionary = dict((str(v), k) for k, v in dictionary.items())
    model_weights = list()
    weight_ctr = 0
    while True:
        try:
            d_key = "weight_" + str(weight_ctr)
            weights = trained_model.get(d_key).value
            model_weights.append(weights)
            weight_ctr += 1
        except Exception as exception:
            break
    # set the model weights
    loaded_model.set_weights(model_weights)
    return loaded_model, dictionary, reverse_dictionary, compatibile_tools

model, dictionary, reverse_dictionary, compatibile_tools = create_model(model_path)
# Out:
# Using TensorFlow backend.

# %%
reverse_dictionary
# Out:
# {'1': 'annotateMyIDs',
#  '2': 'unicycler',
#  '3': 'gatk_unified_genotyper',
#  '4': 'qiime_core_diversity',
#  '5': 'IDFilter',
#  '6': 'deg_annotate',
#  '7': 'mass_spectrometry_imaging_mzplots',
#  '8': 'pileup_interval',
#  '9': 'ncbi_blastx_wrapper',
#  '10': 'heinz_scoring',
#  '11': 'megahit',
#  '12': 'FileConverter',
#  '13': 'abims_xcms_fillPeaks',
#  '14': 'Flash',
#  '15': '16Saligner',
#  '16': 'hisat2',
#  '17': 'deeptools_compute_matrix',
#  '18': 'mothur_summary_single',
#  '19': 'meme_psp_gen',
#  '20': 'jbrowse',
#  '21': 'deeptools_compute_gc_bias',
#  '22': 'gatk_depth_of_coverage',
#  '23': 'gemini_db_info',
#  '24': 'rbc_mirdeep2_mapper',
#  '25': 'deeptools_plot_fingerprint',
#  '26': 'DecoyDatabase',
#  '27': 'abims_xcms_group',
#  '28': 'TextExporter',
#  '29': 'bedtools_slopbed',
#  '30': 'porechop',
#  '31': 'EMBOSS: getorf42',
#  '32': 'gemini_interactions',
#  '33': 'fastq_groomer',
#  '34': 'mimodd_vcf_filter',
#  '35': 'CONVERTER_fastqgz_to_fastq',
#  '36': 'metilene',
#  '37': 'enhanced_bowtie_wrapper',
#  '38': 'bedtools_intersectbed_bam',
#  '39': 'ctb_filter',
#  '40': 'hmmer_hmmsearch',
#  '41': 'deeptools_profiler',
#  '42': '__FILTER_FROM_FILE__',
#  '43': 'cmFinder',
#  '44': 'hcluster_sg',
#  '45': 'seq_filter_by_mapping',
#  '46': 'fastq_quality_trimmer',
#  '47': 'picard_ReorderSam',
#  '48': 'mothur_dist_seqs',
#  '49': 'deeptools_plot_pca',
#  '50': 'rseqc_junction_saturation',
#  '51': 'gatk2_base_recalibrator',
#  '52': 'snpSift_dbnsfp_generic',
#  '53': 'pileup_parser',
#  '54': 'samtools_filter',
#  '55': 'deeptools_bigwigCompare',
#  '56': 'proteomics_search_protein_prophet_1',
#  '57': 'tp_awk_tool',
#  '58': '__RELABEL_FROM_FILE__',
#  '59': 'picard_ValidateSamFile',
#  '60': 'bowtie2',
#  '61': 'bedtools_bedtobam',
#  '62': 'CONVERTER_interval_to_bed_0',
#  '63': 'tp_tail_tool',
#  '64': 'tp_cat',
#  '65': 'cardinal_data_exporter',
#  '66': 'cutadapt',
#  '67': 'r_correlation_matrix',
#  '68': 'ncbi_blastn_wrapper',
#  '69': 'mimodd_varreport',
#  '70': 'macs2_predictd',
#  '71': 'qiime_split_libraries_fastq',
#  '72': 'resistome_analyzer',
#  '73': 'fasttree',
#  '74': 'mothur_cluster',
#  '75': 'pilon',
#  '76': 'picard_CollectInsertSizeMetrics',
#  '77': 'export2graphlan',
#  '78': 'minfi_getanno',
#  '79': 'fastq_paired_end_splitter',
#  '80': 'meme_fimo',
#  '81': 'qiime_validate_mapping_file',
#  '82': 'fasta_merge_files_and_filter_unique_sequences',
#  '83': 'eukaryotic_ncbi_submission',
#  '84': 'make_families',
#  '85': 'extract_bcs.py',
#  '86': 'velvetg_jgi',
#  '87': 'bg_statistical_hypothesis_testing',
#  '88': 'wc_gnu',
#  '89': 'tp_split_on_column',
#  '90': 'qiime_pick_open_reference_otus',
#  '91': 'umi_tools_count',
#  '92': 'tp_cut_tool',
#  '93': 'blast_parser',
#  '94': 'picard_FixMateInformation',
#  '95': 'mothur_pcoa',
#  '96': 'sklearn_feature_selection',
#  '97': 'gatk_realigner_target_creator',
#  '98': 'minfi_ppfun',
#  '99': 'bwa_mem',
#  '100': 'gops_concat_1',
#  '101': '__SORTLIST__',
#  '102': 'w4mclassfilter',
#  '103': 'glimmer_knowlegde-based',
#  '104': 'proteomics_search_peptide_prophet_1',
#  '105': 'vcfbedintersect',
#  '106': 'IDConflictResolver',
#  '107': 'cardinal_quality_report',
#  '108': 'w4mcorcov',
#  '109': 'bedtools_genomecoveragebed_histogram',
#  '110': 'ncbi_tblastn_wrapper',
#  '111': 'methtools_plot',
#  '112': 'nspdk_sparse',
#  '113': 'uparse',
#  '114': 'FeatureLinkerUnlabeled',
#  '115': 'gemini_de_novo',
#  '116': 'sklear_numeric_clustering',
#  '117': 'varscan_somatic',
#  '118': 'aggregate_scores_in_intervals2',
#  '119': 'ggplot2_histogram',
#  '120': 'filter_bed_on_splice_junctions',
#  '121': 'gops_subtract_1',
#  '122': 'picard_CASM',
#  '123': 'qiime_make_otu_heatmap',
#  '124': 'gatk2_unified_genotyper',
#  '125': 'gene2exon1',
#  '126': 'hgv_david',
#  '127': 'fastq_paired_end_interlacer',
#  '128': 'igvtools_count',
#  '129': 'abims_xcms_xcmsSet',
#  '130': 'rm_spurious_events.py',
#  '131': 'tp_sort_header_tool',
#  '132': 'infernal_cmsearch',
#  '133': 'graphclust_align_cluster',
#  '134': 'pynast',
#  '135': 'sklearn_build_pipeline',
#  '136': 'ete_homology_classifier',
#  '137': 'snpEff',
#  '138': 'qiime_pick_closed_reference_otus',
#  '139': 'column_order_header_sort',
#  '140': 'mass_spectrometry_imaging_preprocessing',
#  '141': 'Batch_correction',
#  '142': 'bam2wig',
#  '143': 'mothur_chimera_vsearch',
#  '144': 'methtools_filter',
#  '145': 'snippy',
#  '146': 'rseqc_geneBody_coverage',
#  '147': 'translate_bed_sequences',
#  '148': 'rbc_splitfasta',
#  '149': 'hicexplorer_hictransform',
#  '150': 'je_clip',
#  '151': 'tp_find_and_replace',
#  '152': 'velvetoptimiser',
#  '153': 'sailfish',
#  '154': '__ZIP_COLLECTION__',
#  '155': 'bwa',
#  '156': 'velveth_jgi',
#  '157': 'eden_sequence_converter',
#  '158': 'FROGS_filters',
#  '159': 'gemini_windower',
#  '160': 'raceid_main',
#  '161': 'regex1',
#  '162': 'bedtools_mergebed',
#  '163': 'modencode_peakcalling_macs2',
#  '164': 'ssake',
#  '165': 'collapse_dataset',
#  '166': 'gatk2_realigner_target_creator',
#  '167': 'group_humann2_uniref_abundances_to_go',
#  '168': 'minfi_methcpg',
#  '169': 'Draw_phylogram',
#  '170': 'Summary_Statistics1',
#  '171': 'stacks_populations',
#  '172': 'numeric_clustering',
#  '173': 'signalp3',
#  '174': 'kallisto_quant',
#  '175': 'MapRTTransformer',
#  '176': 'gff2bed1',
#  '177': 'gemini_recessive_and_dominant',
#  '178': 'bamtools',
#  '179': 'MAF_To_Fasta1',
#  '180': 'picard_MarkDuplicatesWithMateCigar',
#  '181': 'maldi_quant_preprocessing',
#  '182': 'vcfannotate',
#  '183': 'flexbar_split_RYYR_bcs',
#  '184': 'gops_cluster_1',
#  '185': 'viennarna_rnaalifold',
#  '186': 'interproscan',
#  '187': 'samtools_sort',
#  '188': 'get_read_pipeline',
#  '189': 'uchime',
#  '190': 'join1',
#  '191': 'bundle_collection',
#  '192': 'hgv_linkToGProfile',
#  '193': 'deeptools_heatmapper',
#  '194': 'locarna_multiple',
#  '195': 'cardinal_mz_images',
#  '196': 'infernal_cmbuild',
#  '197': 'MSGFPlusAdapter',
#  '198': 'replace_column_with_key_value_file',
#  '199': 'fastq_to_tabular',
#  '200': 'smf_utils_filter-by-energy',
#  '201': 'circgraph',
#  '202': 'gemini_comp_hets',
#  '203': 'flye',
#  '204': 'plotly_parallel_coordinates_plot',
#  '205': 'mass_spectrometry_imaging_combine',
#  '206': 'get_sequences',
#  '207': 'flexbardsc',
#  '208': 'mothur_metastats',
#  '209': 'plotly_ml_performance_plots',
#  '210': 'vcffilter',
#  '211': 'CONVERTER_gz_to_uncompressed',
#  '212': 'stringtie',
#  '213': 'flexbar',
#  '214': 'mothur_filter_seqs',
#  '215': 'bedtools_bamtobed',
#  '216': 'Remove_ending',
#  '217': 'mothur_heatmap_sim',
#  '218': 'deeptools_correctGCBias',
#  '219': 'gatk2_print_reads',
#  '220': 'fasplit',
#  '221': 'mothur_lefse',
#  '222': 'EMBOSS: transeq101',
#  '223': 'gff_to_sequence',
#  '224': 'gmx_npt',
#  '225': 'idpquery',
#  '226': 'kraken-translate',
#  '227': 'tophat',
#  '228': 'featurecounts',
#  '229': 'cardinal_segmentations',
#  '230': 'selectsequencesfrommsa',
#  '231': 'rcas',
#  '232': 'ProteinResolver',
#  '233': 'openms_id_file_converter',
#  '234': 'vcffixup',
#  '235': 'mothur_parsimony',
#  '236': 'p_clip_peaks',
#  '237': 'MultiplexResolver',
#  '238': 'cshl_fastx_trimmer',
#  '239': 'merge_pcr_duplicates.py',
#  '240': 'bedtools_sortbed',
#  '241': 'bwameth',
#  '242': 'bed_to_bigBed',
#  '243': 'bedtools_getfastabed',
#  '244': 'abricate',
#  '245': 'bcftools_consensus',
#  '246': 'deeptools_plot_heatmap',
#  '247': 'aragorn_trna',
#  '248': 'bgchem_fragment_merger',
#  '249': 'CONVERTER_fasta_to_tabular',
#  '250': 'Btrim64',
#  '251': 'bedtools_annotatebed',
#  '252': 'blastxml_to_top_descr',
#  '253': 'bg_sortmerna',
#  '254': 'myrimatch',
#  '255': 'modencode_peakcalling_spp',
#  '256': 'rgweblogo3',
#  '257': 'hicexplorer_hicbuildmatrix',
#  '258': 'raceid_inspectclusters',
#  '259': 'mothur_nmds',
#  '260': 'rbc_mirdeep2_quantifier',
#  '261': 'ggplot2_heatmap2',
#  '262': 'seq_composition',
#  '263': 'PeptideIndexer',
#  '264': 'blockbuster',
#  '265': 'goslimmer',
#  '266': 'vcftools_isec',
#  '267': 'idpqonvert',
#  '268': 'sklearn_nn_classifier',
#  '269': 'meme_dreme',
#  '270': 'umi_tools_whitelist',
#  '271': 'mass_spectrometry_imaging_classification',
#  '272': 'picard_BamIndexStats',
#  '273': 'peakachu',
#  '274': 'gatk2_indel_realigner',
#  '275': 'macs2_callpeak',
#  '276': 'vcfflatten2',
#  '277': 'XTandemAdapter',
#  '278': 'hicexplorer_hiccorrectmatrix',
#  '279': 'varscan_mpileup',
#  '280': 'PicardASMetrics',
#  '281': 'bg_diamond',
#  '282': 'cufflinks_prok',
#  '283': 'vcfsort',
#  '284': 'abims_CAMERA_annotateDiffreport',
#  '285': 'mothur_get_seqs',
#  '286': 'Paste1',
#  '287': 'augustus',
#  '288': 'graphlan_annotate',
#  '289': 'qiime_assign_taxonomy',
#  '290': '__MERGE_COLLECTION__',
#  '291': 'minfi_dmr',
#  '292': 'lastz_wrapper_2',
#  '293': 'methtools_destrand',
#  '294': 'deeptools_bam_compare',
#  '295': 'PicardInsertSize',
#  '296': 'histogram_rpy',
#  '297': 'ProteinInference',
#  '298': 'bctools_extract_crosslinked_nucleotides',
#  '299': 'metaspades',
#  '300': 'cummeRbund',
#  '301': 'minimap2',
#  '302': 'hicexplorer_hicsummatrices',
#  '303': 'gtftobed12',
#  '304': 'sam_merge2',
#  '305': 'shovill',
#  '306': 'EMBOSS: fuzztran39',
#  '307': 'TrimByN',
#  '308': 'ctb_chemfp_mol2fps',
#  '309': 'dt_profiler',
#  '310': 'umi_tools_group',
#  '311': 'Extract_RNA_seq_Evidence',
#  '312': 'mothur_chimera_uchime',
#  '313': 'mothur_tree_shared',
#  '314': 'cufflinks',
#  '315': 'scale_image',
#  '316': 'bam_to_sam',
#  '317': 'bam_to_bigwig',
#  '318': 'kraken-report',
#  '319': 'mothur_remove_seqs',
#  '320': 'bam-filter',
#  '321': 'locarna_best_subtree',
#  '322': 'cshl_multijoin',
#  '323': 'sklearn_svm_classifier',
#  '324': 'bg_find_subsequences',
#  '325': 'IDFileConverter',
#  '326': 'mothur_get_communitytype',
#  '327': 'picard_SamToFastq',
#  '328': 'tp_head_tool',
#  '329': 'krona-text',
#  '330': 'IDPosteriorErrorProbability',
#  '331': 'je_demultiplex',
#  '332': 'mothur_phylotype',
#  '333': 'FeatureFinderMetabo',
#  '334': 'mycrobiota-correct-replicates',
#  '335': 'disco',
#  '336': 'find_in_reference',
#  '337': 'preproc',
#  '338': 'deeptools_bamFingerprint',
#  '339': 'deeptools_multi_bigwig_summary',
#  '340': 'dexseq',
#  '341': 'mothur_get_groups',
#  '342': 'samtools_bedcov',
#  '343': 'vt_normalize',
#  '344': 'term_id_vs_term_def',
#  '345': 'rsem_prepare_reference',
#  '346': 'xpath',
#  '347': 'ChangeCase',
#  '348': 'maldi_quant_peak_detection',
#  '349': 'CONVERTER_interval_to_bedstrict_0',
#  '350': 'cardinal_spectra_plots',
#  '351': 'ggplot_point',
#  '352': 'EMBOSS: geecee41',
#  '353': 'diffbind-embl',
#  '354': 'deeptools_plot_enrichment',
#  '355': 'tab2fasta',
#  '356': 'samtools_split',
#  '357': 'SequenceCoverageCalculator',
#  '358': 'extract_element_from_collection',
#  '359': 'blast2go',
#  '360': 'unipept',
#  '361': 'snpSift_annotate',
#  '362': 'flexbar_no_split',
#  '363': 'CONVERTER_bed_gff_or_vcf_to_bigwig_0',
#  '364': 'graphlan',
#  '365': 'transdecoder',
#  '366': 'samtools_rmdup',
#  '367': 'silac_analyzer',
#  '368': 'snpsift_vartype',
#  '369': 'smf_utils_fix-fasta-headers',
#  '370': 'picard_EstimateLibraryComplexity',
#  '371': 'ggplot_histogram',
#  '372': 'segemehl',
#  '373': 'react_cal_pipeline',
#  '374': 'qiime_count_seqs',
#  '375': 'smf_utils_estimate-energy',
#  '376': 'cshl_fastx_reverse_complement',
#  '377': 'tmhmm2',
#  '378': 'deeptools_correct_gc_bias',
#  '379': 'predict_pipeline',
#  '380': 'mothur_heatmap_bin',
#  '381': 'gatk2_variant_filtration',
#  '382': 'coords2clnt.py',
#  '383': 'methtools_tiling',
#  '384': 'collection_column_join',
#  '385': 'mothur_cluster_split',
#  '386': 'tp_replace_in_column',
#  '387': 'correctGCBias',
#  '388': 'gemini_pathways',
#  '389': 'genbank_to_gff',
#  '390': 'qiime_align_seqs',
#  '391': 'gatk_indel_realigner',
#  '392': 'htseq-count',
#  '393': 'computeMatrix',
#  '394': 'rnaz',
#  '395': 'column_remove_by_header',
#  '396': 'CONVERTER_fasta_to_fai',
#  '397': 'trinity',
#  '398': 'fastq_combiner',
#  '399': 'smf_utils_extract-boxed-sequences',
#  '400': 'cshl_fastq_quality_filter',
#  '401': 'EMBOSS: fuzzpro38',
#  '402': 'join_files_on_column_fuzzy',
#  '403': 'cshl_princeton_fastx_barcode_splitter',
#  '404': 'qiime_pick_otus',
#  '405': 'EMBOSS: water107',
#  '406': 'ProteinQuantifier',
#  '407': 'bamFilter',
#  '408': 'ncbi_blastp_wrapper',
#  '409': 'fraggenescan',
#  '410': 'bedtools_multiintersectbed',
#  '411': 'cardinal_combine',
#  '412': 'gmx_setup',
#  '413': 'gemini_actionable_mutations',
#  '414': 'picard_FilterSamReads',
#  '415': 'vcfgenotypes',
#  '416': 'ExtractFASTAfromFASTQ',
#  '417': 'heatmapper_deepTools',
#  '418': 'hcluster_sg_parser',
#  '419': 'FROGS_preprocess',
#  '420': 'table_annovar',
#  '421': 'samtools_slice_bam',
#  '422': 'prokka',
#  '423': 'deeptools_bamCorrelate',
#  '424': 'gmx_em',
#  '425': '__FILTER_FAILED_DATASETS__',
#  '426': 'rseqc_read_duplication',
#  '427': 'cshl_find_and_replace',
#  '428': 'fasta_compute_length',
#  '429': 'scpipe',
#  '430': 'proteomics_moff',
#  '431': 'Convert characters1',
#  '432': 'gatk2_reduce_reads',
#  '433': 'bcftools_view',
#  '434': 'methtools_dmr',
#  '435': 'vegan_rarefaction',
#  '436': 'mycrobiota-otutable_add_blast',
#  '437': 'FeatureFinderCentroided',
#  '438': 'cshl_word_list_grep',
#  '439': 'humann2',
#  '440': 'abims_xcms_summary',
#  '441': 'peakcalling_macs',
#  '442': 'get_feature_info',
#  '443': 'bismark_bowtie',
#  '444': '16Sclassifier',
#  '445': 'cast',
#  '446': 'mothur_seq_error',
#  '447': 'random_lines1',
#  '448': 'stacks_procrad',
#  '449': 'mothur_unique_seqs',
#  '450': 'CONVERTER_gff_to_bed_0',
#  '451': 'minfi_dmp',
#  '452': 'allele_counts_1',
#  '453': 'FidoAdapter',
#  '454': 'tp_uniq_tool',
#  '455': 'openms_protein_quantifier',
#  '456': 'mass_spectrometry_imaging_qc',
#  '457': 'rseqc_infer_experiment',
#  '458': 'minfi_maptogenome',
#  '459': 'barchart_gnuplot',
#  '460': 'biosigner',
#  '461': 'rna_star',
#  '462': 'FeatureFinderMultiplex',
#  '463': 'mimodd_map',
#  '464': 'goseq',
#  '465': 'MassCalculator',
#  '466': 'preMloc',
#  '467': 'mothur_corr_axes',
#  '468': 'tp_text_file_with_recurring_lines',
#  '469': 'metaphlan_hclust_heatmap',
#  '470': 'get_child_terms',
#  '471': 'Extract genomic DNA 1',
#  '472': 'iuc_pear',
#  '473': 'remove_tail.py',
#  '474': 'cshl_fasta_nucleotides_changer',
#  '475': 'CONVERTER_gff_to_interval_index_0',
#  '476': 'cshl_fastx_artifacts_filter',
#  '477': 'deeptools_bamCoverage',
#  '478': 'ctb_silicos_qed',
#  '479': 'bams2ratio',
#  '480': 'rseqc_bam_stat',
#  '481': 'bed2gff1',
#  '482': 'piranha',
#  '483': 'graphicsmagick_image_convert',
#  '484': 'addName',
#  '485': 'bwa_wrapper',
#  '486': 'cshl_fasta_formatter',
#  '487': 'gops_merge_1',
#  '488': 'mothur_classify_rf',
#  '489': 'CONVERTER_bed_to_gff_0',
#  '490': 'addValue',
#  '491': 'transpose',
#  '492': 'samtools_flag_filter',
#  '493': 'cshl_cut_tool',
#  '494': 'gops_coverage_1',
#  '495': 'gtf_filter_by_attribute_values_list',
#  '496': 'dexseq_annotate',
#  '497': 'cshl_fastx_renamer',
#  '498': 'Interval_Maf_Merged_Fasta2',
#  '499': 'mz_to_sqlite',
#  '500': 'newick_display',
#  '501': 'qiime_make_phylogeny',
#  '502': 'smf_utils_find-boxes',
#  '503': 'wiggle2simple1',
#  '504': 'ncbi_rpsblast_wrapper',
#  '505': 'sklearn_ensemble',
#  '506': 'stacks_genotypes',
#  '507': 'msgfplus',
#  '508': 'naive_variant_caller',
#  '509': 'Determine_BC',
#  '510': 'tophat_fusion_post',
#  '511': 'bamCompare_deepTools',
#  '512': 'melt',
#  '513': 'sort1',
#  '514': 'mycrobiota-krona-mothur',
#  '515': 'proteomics_search_tandem_1',
#  '516': 'mothur_classify_seqs',
#  '517': 'tp_unfold_column_tool',
#  '518': 'tp_tac',
#  '519': 'graphclust_glob_report_no_align',
#  '520': 'megablast_wrapper',
#  '521': 'gops_join_1',
#  '522': 'pileometh',
#  '523': 'deeptools_bam_coverage',
#  '524': 'wolf_psort',
#  '525': 'ctb_simsearch',
#  '526': 'FalseDiscoveryRate',
#  '527': 'mothur_count_groups',
#  '528': 'raceid_clustering',
#  '529': 'filter_by_fasta_ids',
#  '530': '__FLATTEN__',
#  '531': 'mothur_classify_otu',
#  '532': 'mothur_amova',
#  '533': 'bandage_image',
#  '534': 'fastq_to_fasta_python',
#  '535': 'viz_overlay_moving_and_fixed_image',
#  '536': 'deeptools_plot_coverage',
#  '537': 'ip_projective_transformation_points',
#  '538': 'bismark_bowtie2',
#  '539': 'CONVERTER_bedgraph_to_bigwig',
#  '540': 'IDScoreSwitcher',
#  '541': 'tsne',
#  '542': 'FastTree',
#  '543': 'infernal_cmstat',
#  '544': 'vcffilter2',
#  '545': 'tp_replace_in_line',
#  '546': 'glob_report',
#  '547': 'sam2interval',
#  '548': 'snpfinder',
#  '549': 'cshl_awk_replace_in_column',
#  '550': 'cshl_easyjoin',
#  '551': 'hicexplorer_hicmergematrixbins',
#  '552': 'ucsc-twobittofa',
#  '553': 'Fetch Taxonomic Ranks',
#  '554': 'PeakPickerHiRes',
#  '555': 'Remove beginning1',
#  '556': 'tophat2',
#  '557': 'deeptools_bamCompare',
#  '558': 'EMBOSS: tranalign100',
#  '559': 'bctools_extract_alignment_ends',
#  '560': 'fasta2tab',
#  '561': 'fastq_manipulation',
#  '562': 'mlocarna',
#  '563': 'mycrobiota-split-multi-otutable',
#  '564': 'paralyzer',
#  '565': 'mothur_align_seqs',
#  '566': 'mothur_homova',
#  '567': 'bedtools_genomecoveragebed',
#  '568': 'metaphlan2krona',
#  '569': 'bedtools_subtractbed',
#  '570': 'picard_CollectWgsMetrics',
#  '571': 'align_families',
#  '572': 'CONVERTER_sam_to_unsorted_bam',
#  '573': 'taxonomy_krona_chart',
#  '574': 'sample_seqs',
#  '575': 'smooth_running_window',
#  '576': 'mothur_rarefaction_single',
#  '577': 'Add_a_column1',
#  '578': 'chipseeker',
#  '579': 'openms_id_mapper',
#  '580': 'FileMerger',
#  '581': 'minfi_rset',
#  '582': 'DatamashOps',
#  '583': 'humann2_regroup_table',
#  '584': 're_he_maldi_image_registration',
#  '585': 'gtf2bedgraph',
#  '586': 'nanoplot',
#  '587': 'IDMerger',
#  '588': 'macs2_bdgcmp',
#  '589': 'MzTabExporter',
#  '590': 'gemini_burden',
#  '591': 'nanopolish_variants',
#  '592': 'svm_classifier',
#  '593': 'fastq_dump',
#  '594': 'tabular_to_fastq',
#  '595': 'seurat',
#  '596': 'hgv_snpFreq',
#  '597': 'minfi_getbeta',
#  '598': 'quast',
#  '599': 'varscan_copynumber',
#  '600': 'datamash_ops',
#  '601': 'mothur_venn',
#  '602': 'sqlite_to_tabular',
#  '603': 'Psortb',
#  '604': 'gatk2_variant_recalibrator',
#  '605': 'Extract_features1',
#  '606': 'mothur_dist_shared',
#  '607': 'Extractor',
#  '608': 'ggplot2_heatmap',
#  '609': 'seq_filter_by_id',
#  '610': 'GeneModelMapper',
#  '611': 'Grouping1',
#  '612': 'mimodd_varcall',
#  '613': 'rseqc_read_distribution',
#  '614': 'snpSift_filter',
#  '615': 'gops_basecoverage_1',
#  '616': 'QCCalculator',
#  '617': 'ctb_remIons',
#  '618': 'trim_galore',
#  '619': 'mass_spectrometry_imaging_ion_images',
#  '620': 'FROGS_clustering',
#  '621': 'EMBOSS: extractseq35',
#  '622': 'pieplots_macs',
#  '623': 'ruvseq',
#  '624': 'picard_AddOrReplaceReadGroups',
#  '625': 'idpassemble',
#  '626': 'raceid_filtnormconf',
#  '627': 'cshl_fastx_barcode_splitter',
#  '628': 'EMBOSS: seqret84',
#  '629': 'rmcontamination',
#  '630': 'bedtools_windowbed',
#  '631': 'EMBOSS: wordcount109',
#  '632': 'ConsensusID',
#  '633': 'cshl_fastx_collapser',
#  '634': 'samtool_filter2',
#  '635': 'rgPicFixMate',
#  '636': 'ConsensusMapNormalizer',
#  '637': 'tp_sort_rows',
#  '638': 'secretbt2test',
#  '639': 'msconvert3_raw',
#  '640': 'search_gui',
#  '641': 'Show tail1',
#  '642': 'rbc_rnacode',
#  '643': 'pureclip',
#  '644': 'peptide_shaker',
#  '645': 'cshl_fastx_quality_statistics',
#  '646': 'Nucleosome',
#  '647': 'umi_tools_dedup',
#  '648': 'tp_easyjoin_tool',
#  '649': 'Heatmap',
#  '650': 'antismash',
#  '651': 'vsearch_dereplication',
#  '652': 'heatmap2',
#  '653': 'mothur_remove_groups',
#  '654': 'metaphlan2',
#  '655': 'rgPicardMarkDups',
#  '656': 'cmv',
#  '657': 'humann2_genefamilies_genus_level',
#  '658': 'mothur_get_oturep',
#  '659': 'deeptools_plot_profile',
#  '660': 'muscle',
#  '661': 'cuffquant',
#  '662': 'FROGS_remove_chimera',
#  '663': 'cshl_sed_tool',
#  '664': 'clustalw',
#  '665': 'fastq_join',
#  '666': 'snpEff_download',
#  '667': 'lfq_protein_quant',
#  '668': 'picard_SortSam',
#  '669': 'FeatureLinkerUnlabeledQT',
#  '670': 'samtools_mpileup',
#  '671': 'rbc_mirdeep2',
#  '672': 'EMBOSS: revseq82',
#  '673': 'convert_bc_to_binary_RY.py',
#  '674': 'ggplot2_point',
#  '675': 'MapStatistics',
#  '676': 'Datamash',
#  '677': 'bed_to_bigwig',
#  '678': 'tag_stat2',
#  '679': 'cshl_uniq_tool',
#  '680': 'Filter1',
#  '681': 'rseqc_bam2wig',
#  '682': 'minfi_getM',
#  '683': 'mergeCols1',
#  '684': 'metams_runGC',
#  '685': 'fastq_trimmer',
#  '686': 'gemini_load',
#  '687': 'GeMoMa_Annotation_Filter',
#  '688': 'minfi_qc',
#  '689': 'tp_sorted_uniq',
#  '690': 'cuffnorm',
#  '691': 'secure_hash_message_digest',
#  '692': 'mothur_make_shared',
#  '693': 'hmmer_hmmbuild',
#  '694': 'picard_MergeSamFiles',
#  '695': 'heinz_bum',
#  '696': 'gspan',
#  '697': 'bamCoverage_deepTools',
#  '698': 'ia_coordinates_of_roi',
#  '699': 'cshl_fastx_nucleotides_distribution',
#  '700': 'plotly_regression_performance_plots',
#  '701': 'bg_column_arrange_by_header',
#  '702': 'hicexplorer_hicplottads',
#  '703': 'deeptools_computeMatrix',
#  '704': 'bamleftalign',
#  '705': 'NSPDK_candidateClust',
#  '706': 'idr-embl',
#  '707': 'dbbuilder',
#  '708': 'length_and_gc_content',
#  '709': 'sklearn_searchcv',
#  '710': 'vcf2pgSnp',
#  '711': 'meme_chip',
#  '712': 'checkFormat',
#  '713': 'minfi_dropsnp',
#  '714': 'deseq2',
#  '715': 'cshl_awk_tool',
#  '716': 'scaffold2fasta',
#  '717': 'gatk2_variant_select',
#  '718': 'vcfselectsamples',
#  '719': 'get_flanks1',
#  '720': 't2t_report',
#  '721': 'picard_CollectRnaSeqMetrics',
#  '722': 'ete_genetree_splitter',
#  '723': 'snpeff_to_peptides',
#  '724': 'Show beginning1',
#  '725': 'freebayes',
#  '726': 'MapAlignerPoseClustering',
#  '727': 'racon',
#  '728': 'mothur_summary_seqs',
#  '729': 'minfi_mset',
#  '730': 'nn_classifier',
#  '731': 'eden_vectorizer',
#  '732': 'vcftools_annotate',
#  '733': 'bigwig_to_bedgraph',
#  '734': 'picard_ARRG',
#  '735': 'wig_to_bigWig',
#  '736': 'hicexplorer_hicplotmatrix',
#  '737': 'extract_aln_ends.py',
#  '738': 'ChooseTag',
#  '739': 'flanking_features_1',
#  '740': 'thermo_raw_file_converter',
#  '741': 'bedtools_intersectbed',
#  '742': 'bedtools_coveragebed',
#  '743': 'fastq collapser',
#  '744': 'mothur_sub_sample',
#  '745': 'mothur_screen_seqs',
#  '746': 'wsdl_hmdb',
#  '747': 'glimmer_not-knowlegde-based',
#  '748': 'cummerbund_to_cuffdiff',
#  '749': 'ngsutils_bam_filter',
#  '750': 'picard_NormalizeFasta',
#  '751': 'spades',
#  '752': 'humann2_renorm_table',
#  '753': 'limma_voom',
#  '754': 'term_id_vs_term_name',
#  '755': 'sam_to_bam',
#  '756': 'mass_spectrometry_imaging_segmentations',
#  '757': 'picard_MarkDuplicates',
#  '758': 'Digestor',
#  '759': 'mothur_make_biom',
#  '760': 'EMBOSS: newseq59',
#  '761': 'cat1',
#  '762': 'je_markdupes',
#  '763': 'viennarna_rnafold',
#  '764': 'msconvert_nix',
#  '765': 'hicexplorer_hicpca',
#  '766': 'bedtools_multicovtbed',
#  '767': 'mass_spectrometry_imaging_filtering',
#  '768': 'mothur_count_seqs',
#  '769': 'ctb_online_data_fetch',
#  '770': 'multiqc',
#  '771': 'gemini_annotate',
#  '772': 'fragmenter',
#  '773': 'cd_hit_dup',
#  '774': 'fasta-stats',
#  '775': 'raceid_inspecttrajectory',
#  '776': 'bedtools_genomecoveragebed_bedgraph',
#  '777': 'TrimByLength',
#  '778': 'regex_replace',
#  '779': 'cardinal_preprocessing',
#  '780': 'blastxml_to_tabular_selectable',
#  '781': 'stacks_denovomap',
#  '782': 'FileInfo',
#  '783': 'gemini_query',
#  '784': 'annotatemyids',
#  '785': 'ncbi_makeblastdb',
#  '786': 'mimodd_varextract',
#  '787': 'gatk2_variant_apply_recalibration',
#  '788': 'xcms_merge',
#  '789': 'ctb_compound_convert',
#  '790': 'mcClust',
#  '791': 'venn_list',
#  '792': 'heinz',
#  '793': 'bedtools_coveragebed_counts',
#  '794': 'mothur_taxonomy_to_krona',
#  '795': 'trimmer',
#  '796': 'megablast_xml_parser',
#  '797': 'salmon',
#  '798': 'cor2',
#  '799': 'w4mjoinpn',
#  '800': 'filtlong',
#  '801': 'rbc_mafft',
#  '802': 'hicexplorer_hicfindtads',
#  '803': 'FeatureLinkerUnlabeledKD',
#  '804': 'bedtools_map',
#  '805': 'datamash_transpose',
#  '806': 'vcf_filter',
#  '807': 'cuffmerge',
#  '808': 'CometAdapter',
#  '809': 'gatk2_variant_annotator',
#  '810': 'gbk_to_orf',
#  '811': 'deeptools_multi_bam_summary',
#  '812': 'cshl_grep_tool',
#  '813': 'bctools_remove_spurious_events',
#  '814': 'cshl_fastx_clipper',
#  '815': 'tp_sed_tool',
#  '816': 'FROGS_affiliations_stat',
#  '817': 'ctb_ob_genProp',
#  '818': 'sklearn_numeric_clustering',
#  '819': 'fastqc',
#  '820': 'tp_multijoin_tool',
#  '821': 'fastq_paired_end_joiner',
#  '822': 'msconvert2_raw',
#  '823': 'deseq2_single',
#  '824': 'minfi_read450k',
#  '825': 'EMBOSS: shuffleseq87',
#  '826': 'TrimPrimer',
#  '827': 'nonpareil',
#  '828': 'comp1',
#  '829': 'graphclust_aggregate_alignments',
#  '830': 'correct_barcodes',
#  '831': 'gops_intersect_1',
#  '832': 'fastq_filter',
#  '833': 'trimmomatic',
#  '834': 'heinz_visualization',
#  '835': 'lca1',
#  '836': 'picard_CleanSam',
#  '837': 'sequence_content_trimmer',
#  '838': 'viennarna_rnaplot',
#  '839': 'vcfcombine',
#  '840': 'deeptools_compute_matrix_operations',
#  '841': 'combine_metaphlan2_humann2',
#  '842': 'heatmapper',
#  '843': 'bedtools_shufflebed',
#  '844': 'egsea',
#  '845': 'mycrobiota-make-multi-otutable',
#  '846': 'fastq_paired_end_deinterlacer',
#  '847': 't_coffee',
#  '848': 'vcftools_merge',
#  '849': 'mothur_trim_seqs',
#  '850': 'bg_uniq',
#  '851': 'mothur_make_contigs',
#  '852': 'sam_bw_filter',
#  '853': 'mothur_remove_lineage',
#  '854': 'format_metaphlan2_output',
#  '855': 'w4mclstrpeakpics',
#  '856': 'samtools_stats',
#  '857': '__UNZIP_COLLECTION__',
#  '858': 'IDMassAccuracy',
#  '859': 'uniprot',
#  '860': 'trim_reads',
#  '861': 'mycrobiota-qc-report',
#  '862': 'createInterval',
#  '863': 'gd_raxml',
#  '864': 'goenrichment',
#  '865': 'bowtie_wrapper',
#  '866': 'IDMapper',
#  '867': 'blastxml_to_tabular',
#  '868': 'rarefaction_analyzer',
#  '869': 'bedtools_complementbed',
#  '870': 'kraken',
#  '871': 'snippy_core',
#  '872': 'Count1',
#  '873': 'methtools_calling',
#  '874': 'tp_grep_tool',
#  '875': 'cuffcompare',
#  '876': 'cardinal_filtering',
#  '877': 'DatamashTranspose',
#  '878': 'sam_pileup',
#  '879': 'subtract_query1',
#  '880': 'bedtools_unionbedgraph',
#  '881': 'Univariate',
#  '882': 'hisat',
#  '883': 'query_tabular',
#  '884': 'snpSift_geneSets',
#  '885': 'bcftools_norm',
#  '886': 'FileFilter',
#  '887': 'velvet',
#  '888': 'structure_to_gspan',
#  '889': 'NFS_transfer',
#  '890': 'gatk2_depth_of_coverage',
#  '891': 'flexbar_split_RR_bcs',
#  '892': 'IsobaricAnalyzer',
#  '893': 'bctools_remove_tail',
#  '894': 'iReport',
#  '895': 'treebest_best',
#  '896': 'sickle',
#  '897': 'deeptools_plot_correlation',
#  '898': 'get_subontology_from',
#  '899': 'bcftools_call',
#  '900': 'vegan_diversity',
#  '901': 'Grep1',
#  '902': 'CONVERTER_Bam_Bai_0',
#  '903': 'mothur_make_group',
#  '904': 'vcfvcfintersect',
#  '905': 'kraken-filter',
#  '906': 'cshl_fastq_to_fasta',
#  '907': 'vcf2tsv',
#  '908': 'stacks_refmap',
#  '909': 'stringtie_merge',
#  '910': 'blockclust',
#  '911': 'mothur_merge_files',
#  '912': 'samtools_calmd',
#  '913': 'valet',
#  '914': 'map_peptides_to_bed',
#  '915': 'ip_projective_transformation',
#  '916': 'gatk2_haplotype_caller',
#  '917': 'glimmer_build-icm',
#  '918': 'rnafold',
#  '919': 'samtools_idxstats',
#  '920': 'meme_meme',
#  '921': 'gafa',
#  '922': 'rnbeads',
#  '923': 'mothur_pre_cluster',
#  '924': 'Cut1',
#  '925': 'RNAlien',
#  '926': 'gff_filter_by_attribute',
#  '927': 'decoyfasta',
#  '928': 'rarefaction',
#  '929': 'gffread',
#  '930': 'bg_protein_properties',
#  '931': 'gmx_nvt',
#  '932': 'XY_Plot_1',
#  '933': 'gmx_solvate',
#  '934': 'cshl_sort_header',
#  '935': 'rseqc_inner_distance',
#  '936': 'raceid_trajectory',
#  '937': 'ctb_change_title',
#  '938': 'umi_tools_extract',
#  '939': 'vcfallelicprimitives',
#  '940': 'EMBOSS: textsearch98',
#  '941': 'CONVERTER_interval_to_bgzip_0',
#  '942': 'bedtools_bamtofastq',
#  '943': 'deeptools_computeGCBias',
#  '944': 'sed_stream_editor',
#  '945': 'dexseq_count',
#  '946': 'qiime_pick_rep_set',
#  '947': 'ctb_remSmall',
#  '948': 'htseq_count',
#  '949': 'FROGS_affiliation_OTU',
#  '950': 'samtools_flagstat',
#  '951': 'HighResPrecursorMassCorrector',
#  '952': 'Multivariate',
#  '953': 'dunovo',
#  '954': 'CONVERTER_bed_to_bgzip_0',
#  '955': 'bedtools_intersectBed',
#  '956': 'gffcompare',
#  '957': 'fgsea',
#  '958': 'rsem_calculate_expression',
#  '959': 'fasta_filter_by_length',
#  '960': 'gmx_md',
#  '961': 'edger',
#  '962': 'cshl_fastq_quality_boxplot',
#  '963': 'roary',
#  '964': '__APPLY_RULES__',
#  '965': 'deeptools_bigwig_compare',
#  '966': 'charts',
#  '967': 'chipsequtil_maptoknowngenes',
#  '968': 'cuffdiff',
#  '969': 'prokaryotic_ncbi_submission',
#  '970': 'varscan',
#  '971': 'peakcalling_macs14'}

# %%
def verify_model(model, tool_sequence, labels, dictionary, reverse_dictionary, compatible_tools, topk=20, max_seq_len=25):
    tl_seq = tool_sequence.split(",")
    last_tool_name = reverse_dictionary[str(tl_seq[-1])]
    last_compatible_tools = compatible_tools[last_tool_name]
    sample = np.zeros(max_seq_len)
    for idx, tool_id in enumerate(tl_seq):
        sample[idx] = int(tool_id)
    sample_reshaped = np.reshape(sample, (1, max_seq_len))
    
    tool_sequence_names = [reverse_dictionary[str(tool_pos)] for tool_pos in tool_sequence.split(",")]
    print("Tool seq: %s" % ",".join(tool_sequence_names))
    # predict next tools for a test path
    prediction = model.predict(sample_reshaped, verbose=0)
    prediction = np.reshape(prediction, (prediction.shape[1],))
    prediction_pos = np.argsort(prediction, axis=-1)

    # get topk prediction
    topk_prediction_pos = prediction_pos[-topk:]
    topk_prediction_val = [np.round(prediction[pos] * 100, 2) for pos in topk_prediction_pos]

    # read tool names using reverse dictionary
    pred_tool_ids = [reverse_dictionary[str(tool_pos)] for tool_pos in topk_prediction_pos]
    actual_next_tool_ids = list(set(pred_tool_ids).intersection(set(last_compatible_tools.split(","))))      
        
    #print("Predicted tools: %s" % ",".join(pred_tool_ids))
    print()
    pred_tool_ids_sorted = dict()
    for (tool_pos, tool_pred_val) in zip(topk_prediction_pos, topk_prediction_val):
        tool_name = reverse_dictionary[str(tool_pos)]
        if tool_name in actual_next_tool_ids:
            pred_tool_ids_sorted[tool_name] = tool_pred_val
    pred_tool_ids_sorted = dict(sorted(pred_tool_ids_sorted.items(), key=lambda kv: kv[1], reverse=True))
    
    cls_wt = dict()
    usg_wt = dict()
    inv_wt = dict()
    ids_tools = dict()
    keys = list(pred_tool_ids_sorted.keys())
    for k in keys:
        try:
            cls_wt[k] = np.round(class_weights[str(data_dict[k])], 2)
            usg_wt[k] = np.round(usage_weights[k], 2)
            inv_wt[k] = np.round(inverted_weights[str(data_dict[k])], 2)
        except:
            continue
    print("Predicted tools: \n")
    print(pred_tool_ids_sorted)
    print()
    print("Class weights: \n")
    cls_wt = dict(sorted(cls_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(cls_wt)
    print()
    print("Usage weights: \n")
    usg_wt = dict(sorted(usg_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(usg_wt)
    print()
    total_usage_wt = np.mean(list(usg_wt.values()))
    print("Mean usage wt: %0.4f" % (total_usage_wt))
    print()
    print("Inverted weights: \n")
    inv_wt = dict(sorted(inv_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(inv_wt)
    for key in pred_tool_ids_sorted:
        ids_tools[key] = dictionary[key]
    print()
    print("Tool ids")
    print(ids_tools)
    print("======================================")
    return cls_wt, usg_wt, inv_wt, pred_tool_ids_sorted

topk = 10
tool_seq = "555" # ,875,223,17
class_wt, usage_wt, inverse_wt, pred_tools = verify_model(model, tool_seq, "", dictionary, reverse_dictionary, compatibile_tools, topk)
# Out:
# Tool seq: Remove beginning1
#
# Predicted tools:
#
# {'Grouping1': 7.59, 'addValue': 7.08, 'datamash_ops': 5.38, 'Cut1': 5.11, 'cat1': 3.45, 'wc_gnu': 3.1, 'Add_a_column1': 2.72, 'Filter1': 2.01, 'Show beginning1': 1.99, 'collection_column_join': 1.28}
#
# Class weights:
#
# {'datamash_ops': 5.06, 'Add_a_column1': 4.08, 'Filter1': 3.11, 'wc_gnu': 2.99, 'collection_column_join': 2.89, 'Grouping1': 2.36, 'addValue': 2.34, 'Cut1': 1.8, 'Show beginning1': 1.47, 'cat1': 1.15}
#
# Usage weights:
#
# {'Cut1': 1425.46, 'Filter1': 1021.1, 'addValue': 463.1, 'cat1': 428.07, 'Grouping1': 177.59, 'datamash_ops': 100.83, 'Show beginning1': 87.82, 'collection_column_join': 14.1, 'wc_gnu': 1.0, 'Add_a_column1': 1.0}
#
# Mean usage wt: 372.0070
#
# Inverted weights:
#
# {'datamash_ops': 157.06, 'Add_a_column1': 58.93, 'Filter1': 22.51, 'wc_gnu': 19.95, 'collection_column_join': 18.03, 'Grouping1': 10.63, 'addValue': 10.42, 'Cut1': 6.05, 'Show beginning1': 4.36, 'cat1': 3.15}
#
# Tool ids
# {'Grouping1': 611, 'addValue': 490, 'datamash_ops': 600, 'Cut1': 924, 'cat1': 761, 'wc_gnu': 88, 'Add_a_column1': 577, 'Filter1': 680, 'Show beginning1': 724, 'collection_column_join': 384}
# ======================================

# %%
list_cls_wt = list()
list_usage_wt = list()
list_pred_wt = list()
list_inv_wt = list()
division_pt = int(len(pred_tools) / 2)

for tool in pred_tools:
    list_pred_wt.append(pred_tools[tool])
    #try:
    list_inv_wt.append(inverse_wt[tool])
    list_usage_wt.append(usage_wt[tool])
    #except:
    #list_inv_wt.append(1)

def plot_scatter(y_val, title, xlabel, ylabel):
    x_val = range(1, len(y_val) + 1)
    plt.figure(figsize=(8, 8))
    plt.plot(x_val[:division_pt], y_val[:division_pt], 'ro')
    plt.plot(x_val[division_pt:], y_val[division_pt:], 'b^')
    plt.xlabel(xlabel, size=size_label)
    plt.ylabel(ylabel, size=size_label)
    plt.legend([("First top-%s" % str(division_pt)), ("Next top-%s" % str(division_pt))])
    plt.title(title, size=size_title)
    plt.grid(True)
    plt.show()

plot_scatter(list_usage_wt, "Usage weights for tools", "Number of tools", "Class weights")
#plot_scatter(ave_prediction_weights, ave_usage_weights, "Prediction vs usage weights", "Prediction scores", "Usage weights")
#plot_scatter(ave_prediction_weights, ave_inverted_weights, "Prediction vs inverted weights", "Prediction scores", "Inverted weights")
