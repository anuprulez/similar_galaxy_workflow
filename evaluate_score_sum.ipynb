# %%
import numpy as np
import json
import warnings
import operator

import h5py
from keras.models import model_from_json
from keras import backend as K

from matplotlib import pyplot as plt

warnings.filterwarnings("ignore")

size_title = 18
size_label = 14
n_pred = 2

base_path = "data/remote_sum/"

path_data_dict = base_path + "data_dict.txt"
path_inverted_wt = base_path + "inverted_weights.txt"
path_usage_wt = base_path + "usage_prediction.txt"
path_class_wt = base_path + "class_weights.txt"
path_test_data = base_path + "test_data.txt"
model_path = base_path + "trained_model.hdf5"

def read_file(file_path):
    with open(file_path, 'r') as data_file:
        data = json.loads(data_file.read())
    return data

class_weights = read_file(path_class_wt)
usage_weights = read_file(path_usage_wt)
inverted_weights = read_file(path_inverted_wt)
data_dict = read_file(path_data_dict)

def create_model(model_path):
    trained_model = h5py.File(model_path, 'r')
    model_config = json.loads(trained_model.get('model_config').value)
    loaded_model = model_from_json(model_config)
    dictionary = json.loads(trained_model.get('data_dictionary').value)
    compatibile_tools = json.loads(trained_model.get('compatible_tools').value)
    reverse_dictionary = dict((str(v), k) for k, v in dictionary.items())
    model_weights = list()
    weight_ctr = 0
    while True:
        try:
            d_key = "weight_" + str(weight_ctr)
            weights = trained_model.get(d_key).value
            model_weights.append(weights)
            weight_ctr += 1
        except Exception as exception:
            break
    # set the model weights
    loaded_model.set_weights(model_weights)
    return loaded_model, dictionary, reverse_dictionary, compatibile_tools

model, dictionary, reverse_dictionary, compatibile_tools = create_model(model_path)
# Out:
# Using TensorFlow backend.

# %%
reverse_dictionary
# Out:
# {'1': 'bedtools_coveragebed',
#  '2': 'IDMapper',
#  '3': 'heatmapper_deepTools',
#  '4': 'gatk2_indel_realigner',
#  '5': 'transpose',
#  '6': 'myrimatch',
#  '7': 'mothur_make_contigs',
#  '8': 'samtools_rmdup',
#  '9': 'qiime_pick_open_reference_otus',
#  '10': 'piranha',
#  '11': 'cshl_fastx_quality_statistics',
#  '12': 'ggplot2_histogram',
#  '13': 'FROGS_affiliations_stat',
#  '14': 'goslimmer',
#  '15': 'MassCalculator',
#  '16': 'deeptools_bamCorrelate',
#  '17': 'EMBOSS: water107',
#  '18': 'vcffilter',
#  '19': 'maldi_quant_peak_detection',
#  '20': 'hicexplorer_hicplottads',
#  '21': 'samtools_mpileup',
#  '22': 'deeptools_correct_gc_bias',
#  '23': 'rgPicFixMate',
#  '24': 'gmx_md',
#  '25': 'cardinal_filtering',
#  '26': 'Fetch Taxonomic Ranks',
#  '27': 'flexbar_split_RR_bcs',
#  '28': 'vcfannotate',
#  '29': 'idr-embl',
#  '30': 'MapAlignerPoseClustering',
#  '31': 'cshl_fastx_artifacts_filter',
#  '32': 'iReport',
#  '33': 'rseqc_infer_experiment',
#  '34': 'umi_tools_extract',
#  '35': 'ggplot2_heatmap',
#  '36': 'sickle',
#  '37': 'cuffnorm',
#  '38': 'featurecounts',
#  '39': 'decoyfasta',
#  '40': 'wig_to_bigWig',
#  '41': 'cshl_multijoin',
#  '42': 'CONVERTER_Bam_Bai_0',
#  '43': 'vcfgenotypes',
#  '44': 'gatk_depth_of_coverage',
#  '45': 'segemehl',
#  '46': 'lca1',
#  '47': 'mothur_classify_otu',
#  '48': 'cshl_cut_tool',
#  '49': 'join1',
#  '50': 'mothur_corr_axes',
#  '51': 'CONVERTER_interval_to_bed_0',
#  '52': 'tp_tac',
#  '53': 'transdecoder',
#  '54': 'FeatureFinderCentroided',
#  '55': 'rnafold',
#  '56': 'predict_pipeline',
#  '57': 'muscle',
#  '58': 'picard_CollectInsertSizeMetrics',
#  '59': 'wolf_psort',
#  '60': 'hicexplorer_hicfindtads',
#  '61': 'bwa_mem',
#  '62': 'tabular_to_fastq',
#  '63': 'w4mcorcov',
#  '64': 'correctGCBias',
#  '65': 'gatk2_realigner_target_creator',
#  '66': 'p_clip_peaks',
#  '67': 'TrimByN',
#  '68': 'gatk_realigner_target_creator',
#  '69': 'FROGS_affiliation_OTU',
#  '70': 'Multivariate',
#  '71': 'bg_statistical_hypothesis_testing',
#  '72': 'gemini_query',
#  '73': 'Show tail1',
#  '74': 'stacks_procrad',
#  '75': 'Extract_features1',
#  '76': 'EMBOSS: newseq59',
#  '77': 'CometAdapter',
#  '78': 'gatk_indel_realigner',
#  '79': 'Flash',
#  '80': 'roary',
#  '81': 'mothur_remove_groups',
#  '82': 'methtools_plot',
#  '83': 'fasta_merge_files_and_filter_unique_sequences',
#  '84': 'table_annovar',
#  '85': 'abims_xcms_group',
#  '86': 'velvetg_jgi',
#  '87': 'map_peptides_to_bed',
#  '88': 'prokaryotic_ncbi_submission',
#  '89': 'ChooseTag',
#  '90': 'macs2_predictd',
#  '91': 'filtlong',
#  '92': 'deeptools_bam_coverage',
#  '93': 'lfq_protein_quant',
#  '94': 'pileup_parser',
#  '95': 'wc_gnu',
#  '96': 'DatamashTranspose',
#  '97': 'snpSift_annotate',
#  '98': 'naive_variant_caller',
#  '99': 'preMloc',
#  '100': 'igvtools_count',
#  '101': 'abims_xcms_fillPeaks',
#  '102': 'mothur_make_biom',
#  '103': 'minfi_getbeta',
#  '104': 'heinz_bum',
#  '105': 'bedtools_coveragebed_counts',
#  '106': 'ncbi_blastp_wrapper',
#  '107': '__APPLY_RULES__',
#  '108': 'treebest_best',
#  '109': 'hcluster_sg',
#  '110': 'mimodd_map',
#  '111': 'ctb_simsearch',
#  '112': 'cshl_fastx_collapser',
#  '113': 'NFS_transfer',
#  '114': 'maldi_quant_preprocessing',
#  '115': 'CONVERTER_fasta_to_tabular',
#  '116': 'gmx_solvate',
#  '117': 'ete_homology_classifier',
#  '118': 'picard_MarkDuplicatesWithMateCigar',
#  '119': 'plotly_regression_performance_plots',
#  '120': 'export2graphlan',
#  '121': 'gemini_pathways',
#  '122': 'gemini_actionable_mutations',
#  '123': 'Nucleosome',
#  '124': 'dexseq',
#  '125': 'smf_utils_estimate-energy',
#  '126': 'smf_utils_filter-by-energy',
#  '127': 'graphicsmagick_image_convert',
#  '128': 'tp_grep_tool',
#  '129': 'deseq2_single',
#  '130': 'bed_to_bigwig',
#  '131': 'bed2gff1',
#  '132': 'FeatureFinderMultiplex',
#  '133': 'tp_sed_tool',
#  '134': 'mcClust',
#  '135': 'tsne',
#  '136': 'cshl_fastq_quality_boxplot',
#  '137': 'meme_psp_gen',
#  '138': 'extract_bcs.py',
#  '139': 'tab2fasta',
#  '140': 'picard_ValidateSamFile',
#  '141': 'metaphlan_hclust_heatmap',
#  '142': 'deeptools_plot_pca',
#  '143': 'metaspades',
#  '144': 'bg_protein_properties',
#  '145': 'disco',
#  '146': 'computeMatrix',
#  '147': 'nonpareil',
#  '148': 'tp_cut_tool',
#  '149': 'term_id_vs_term_def',
#  '150': 'tp_unfold_column_tool',
#  '151': 'mothur_summary_seqs',
#  '152': 'fastq_groomer',
#  '153': 'get_subontology_from',
#  '154': 'GeneModelMapper',
#  '155': 'fasta-stats',
#  '156': 'snpEff',
#  '157': 'rarefaction',
#  '158': 'ncbi_blastx_wrapper',
#  '159': 'Extract genomic DNA 1',
#  '160': 'mlocarna',
#  '161': 'unipept',
#  '162': 'metaphlan2krona',
#  '163': 'Remove beginning1',
#  '164': 'ggplot2_heatmap2',
#  '165': 'bg_diamond',
#  '166': 'Batch_correction',
#  '167': 'bowtie2',
#  '168': 'raceid_filtnormconf',
#  '169': 'coords2clnt.py',
#  '170': 'melt',
#  '171': 'gatk2_variant_annotator',
#  '172': 'msconvert_nix',
#  '173': 'gemini_interactions',
#  '174': 'eukaryotic_ncbi_submission',
#  '175': 'raceid_inspecttrajectory',
#  '176': 'bedtools_windowbed',
#  '177': 'mothur_get_seqs',
#  '178': 'tophat_fusion_post',
#  '179': 'bedtools_bamtofastq',
#  '180': 'minfi_rset',
#  '181': 'XY_Plot_1',
#  '182': 'racon',
#  '183': 'cufflinks',
#  '184': 'graphclust_aggregate_alignments',
#  '185': 'mothur_get_communitytype',
#  '186': 'cardinal_combine',
#  '187': 'minfi_dropsnp',
#  '188': 'fasplit',
#  '189': 'qiime_count_seqs',
#  '190': 'gd_raxml',
#  '191': 'QCCalculator',
#  '192': 'venn_list',
#  '193': 'Extract_RNA_seq_Evidence',
#  '194': 'stringtie',
#  '195': 'Heatmap',
#  '196': 'ctb_change_title',
#  '197': 'metams_runGC',
#  '198': 'CONVERTER_interval_to_bgzip_0',
#  '199': 'join_files_on_column_fuzzy',
#  '200': 'proteomics_search_peptide_prophet_1',
#  '201': 'vcftools_isec',
#  '202': 'cuffdiff',
#  '203': 'gops_intersect_1',
#  '204': 'blastxml_to_top_descr',
#  '205': 'deeptools_compute_gc_bias',
#  '206': 'gatk2_reduce_reads',
#  '207': 'IDMassAccuracy',
#  '208': 'plotly_parallel_coordinates_plot',
#  '209': 'sklearn_build_pipeline',
#  '210': 'snpSift_geneSets',
#  '211': 'peptide_shaker',
#  '212': 'deeptools_computeGCBias',
#  '213': 'metilene',
#  '214': 'seurat',
#  '215': 'gemini_annotate',
#  '216': 'CONVERTER_sam_to_unsorted_bam',
#  '217': 'make_families',
#  '218': 'Determine_BC',
#  '219': 'mz_to_sqlite',
#  '220': 'flexbar_no_split',
#  '221': 'cutadapt',
#  '222': 'viennarna_rnafold',
#  '223': 'prokka',
#  '224': 'shovill',
#  '225': 'samtool_filter2',
#  '226': 'Show beginning1',
#  '227': 'sklearn_feature_selection',
#  '228': 'rnaz',
#  '229': 'samtools_sort',
#  '230': 'dexseq_annotate',
#  '231': 'tp_cat',
#  '232': 'cshl_awk_tool',
#  '233': 'HighResPrecursorMassCorrector',
#  '234': 'EMBOSS: transeq101',
#  '235': 'extract_aln_ends.py',
#  '236': 'gff_filter_by_attribute',
#  '237': 'charts',
#  '238': 'ia_coordinates_of_roi',
#  '239': 'mothur_summary_single',
#  '240': 'htseq_count',
#  '241': 'deeptools_plot_profile',
#  '242': 'smooth_running_window',
#  '243': 'deeptools_bam_compare',
#  '244': 'mothur_phylotype',
#  '245': 'mass_spectrometry_imaging_classification',
#  '246': 'stacks_populations',
#  '247': 'Psortb',
#  '248': 'deseq2',
#  '249': 'blockclust',
#  '250': 'EMBOSS: getorf42',
#  '251': 'mothur_dist_shared',
#  '252': 'addValue',
#  '253': 'blastxml_to_tabular',
#  '254': '__UNZIP_COLLECTION__',
#  '255': 'hicexplorer_hicplotmatrix',
#  '256': 'NSPDK_candidateClust',
#  '257': 'graphlan_annotate',
#  '258': 'cshl_uniq_tool',
#  '259': 'kraken-report',
#  '260': 'vcffilter2',
#  '261': 'fastq_to_tabular',
#  '262': 'bedtools_genomecoveragebed',
#  '263': 'Datamash',
#  '264': 'bedtools_unionbedgraph',
#  '265': 'fastq_paired_end_interlacer',
#  '266': 'samtools_flagstat',
#  '267': 'raceid_trajectory',
#  '268': 'Paste1',
#  '269': 'samtools_flag_filter',
#  '270': 're_he_maldi_image_registration',
#  '271': 'picard_NormalizeFasta',
#  '272': 'locarna_multiple',
#  '273': 'salmon',
#  '274': 'methtools_calling',
#  '275': 'hisat2',
#  '276': 'freebayes',
#  '277': 'term_id_vs_term_name',
#  '278': 'DecoyDatabase',
#  '279': 'picard_SortSam',
#  '280': 'picard_CollectRnaSeqMetrics',
#  '281': 'r_correlation_matrix',
#  '282': 'rna_star',
#  '283': 'limma_voom',
#  '284': 'thermo_raw_file_converter',
#  '285': 'correct_barcodes',
#  '286': 'bcftools_consensus',
#  '287': 'mimodd_varcall',
#  '288': 'deeptools_compute_matrix_operations',
#  '289': 'CONVERTER_interval_to_bedstrict_0',
#  '290': 'humann2',
#  '291': 'Univariate',
#  '292': 'tp_uniq_tool',
#  '293': 'pileup_interval',
#  '294': 'tp_replace_in_column',
#  '295': 'MapRTTransformer',
#  '296': 'cshl_easyjoin',
#  '297': 'w4mclstrpeakpics',
#  '298': 'ctb_online_data_fetch',
#  '299': 'heinz',
#  '300': 'qiime_make_phylogeny',
#  '301': 'secretbt2test',
#  '302': 'trimmomatic',
#  '303': 'PeptideIndexer',
#  '304': 'minfi_mset',
#  '305': 'gops_join_1',
#  '306': 'deeptools_computeMatrix',
#  '307': 'rseqc_bam2wig',
#  '308': 'nanopolish_variants',
#  '309': 'cshl_fasta_nucleotides_changer',
#  '310': 'bctools_remove_spurious_events',
#  '311': 'rgPicardMarkDups',
#  '312': 'gtf2bedgraph',
#  '313': 'enhanced_bowtie_wrapper',
#  '314': 'cuffmerge',
#  '315': 'sqlite_to_tabular',
#  '316': 'graphlan',
#  '317': 'viz_overlay_moving_and_fixed_image',
#  '318': 'vcf2tsv',
#  '319': 'abims_CAMERA_annotateDiffreport',
#  '320': 'gmx_em',
#  '321': 'macs2_bdgcmp',
#  '322': 'sailfish',
#  '323': 'kraken-translate',
#  '324': 'idpquery',
#  '325': 'wsdl_hmdb',
#  '326': 'CONVERTER_gz_to_uncompressed',
#  '327': 'kraken',
#  '328': 'uchime',
#  '329': 'IDPosteriorErrorProbability',
#  '330': 'mothur_remove_lineage',
#  '331': 'mothur_metastats',
#  '332': 'scale_image',
#  '333': 'nanoplot',
#  '334': 'bam_to_sam',
#  '335': 'antismash',
#  '336': 'deeptools_bigwigCompare',
#  '337': 'kraken-filter',
#  '338': 'samtools_slice_bam',
#  '339': 'rbc_splitfasta',
#  '340': 'rcas',
#  '341': 'tp_awk_tool',
#  '342': 'raceid_clustering',
#  '343': 'mothur_amova',
#  '344': 'vsearch_dereplication',
#  '345': 'FidoAdapter',
#  '346': 'MapStatistics',
#  '347': 'dt_profiler',
#  '348': 'hicexplorer_hictransform',
#  '349': 'mothur_screen_seqs',
#  '350': 'mothur_pre_cluster',
#  '351': 'tp_sort_header_tool',
#  '352': 'rbc_mafft',
#  '353': 'minfi_dmr',
#  '354': 'get_flanks1',
#  '355': 'remove_tail.py',
#  '356': 'snpfinder',
#  '357': 'mass_spectrometry_imaging_combine',
#  '358': 'qiime_align_seqs',
#  '359': 'gmx_npt',
#  '360': 'snippy',
#  '361': 'cast',
#  '362': 'bctools_remove_tail',
#  '363': 'openms_id_mapper',
#  '364': 't_coffee',
#  '365': 'augustus',
#  '366': 'ucsc-twobittofa',
#  '367': 'scpipe',
#  '368': 'cuffcompare',
#  '369': 'openms_protein_quantifier',
#  '370': 'mothur_classify_seqs',
#  '371': 'annotateMyIDs',
#  '372': 'tag_stat2',
#  '373': 'EMBOSS: seqret84',
#  '374': 'ctb_silicos_qed',
#  '375': 'trim_galore',
#  '376': 'genbank_to_gff',
#  '377': 'picard_CleanSam',
#  '378': 'methtools_tiling',
#  '379': 'cshl_sort_header',
#  '380': 'gatk2_variant_select',
#  '381': 'sklearn_searchcv',
#  '382': 'circgraph',
#  '383': 'vcfselectsamples',
#  '384': 'cardinal_segmentations',
#  '385': 'cshl_fastq_to_fasta',
#  '386': 'nspdk_sparse',
#  '387': 'tp_easyjoin_tool',
#  '388': 'edger',
#  '389': 'tp_sort_rows',
#  '390': 'mothur_filter_seqs',
#  '391': 'FeatureLinkerUnlabeledKD',
#  '392': 'uniprot',
#  '393': 'eden_sequence_converter',
#  '394': 'Convert characters1',
#  '395': 'fasta_filter_by_length',
#  '396': 'snpeff_to_peptides',
#  '397': 'deeptools_bamFingerprint',
#  '398': 'picard_EstimateLibraryComplexity',
#  '399': 'structure_to_gspan',
#  '400': 'bedtools_slopbed',
#  '401': 'tophat',
#  '402': 'regex1',
#  '403': 'bedtools_multicovtbed',
#  '404': 'fasttree',
#  '405': 'RNAlien',
#  '406': 'heinz_visualization',
#  '407': 'bedtools_bedtobam',
#  '408': 'bg_sortmerna',
#  '409': 'quast',
#  '410': 'picard_SamToFastq',
#  '411': 'cor2',
#  '412': 'gatk2_depth_of_coverage',
#  '413': 'picard_MarkDuplicates',
#  '414': 'smf_utils_extract-boxed-sequences',
#  '415': 'Filter1',
#  '416': 'varscan_copynumber',
#  '417': 'Digestor',
#  '418': 'minfi_dmp',
#  '419': 'mothur_taxonomy_to_krona',
#  '420': 'rseqc_geneBody_coverage',
#  '421': 'fastq_join',
#  '422': 'meme_dreme',
#  '423': 'mothur_unique_seqs',
#  '424': 'FROGS_clustering',
#  '425': 'pieplots_macs',
#  '426': '16Saligner',
#  '427': 'mothur_nmds',
#  '428': 'bandage_image',
#  '429': 'cardinal_preprocessing',
#  '430': 'fastqc',
#  '431': 'samtools_stats',
#  '432': 'FileFilter',
#  '433': 'ngsutils_bam_filter',
#  '434': 'picard_FilterSamReads',
#  '435': 'w4mclassfilter',
#  '436': 'mothur_cluster_split',
#  '437': 'sklearn_numeric_clustering',
#  '438': 'cshl_fastx_trimmer',
#  '439': 'fastq_dump',
#  '440': 'blast_parser',
#  '441': 'bigwig_to_bedgraph',
#  '442': 'vcftools_annotate',
#  '443': 'regex_replace',
#  '444': 'biosigner',
#  '445': 'svm_classifier',
#  '446': 'ggplot_point',
#  '447': 'hisat',
#  '448': 'hcluster_sg_parser',
#  '449': 'bedtools_annotatebed',
#  '450': 'bctools_extract_alignment_ends',
#  '451': 'macs2_callpeak',
#  '452': 'tp_head_tool',
#  '453': 'vegan_rarefaction',
#  '454': 'dexseq_count',
#  '455': 'fasta2tab',
#  '456': 'bismark_bowtie',
#  '457': 'snpsift_vartype',
#  '458': 'hgv_snpFreq',
#  '459': 'sort1',
#  '460': 'vcfbedintersect',
#  '461': 'gops_subtract_1',
#  '462': 'minimap2',
#  '463': 'vcfallelicprimitives',
#  '464': 'deeptools_plot_fingerprint',
#  '465': 'heatmapper',
#  '466': 'extract_element_from_collection',
#  '467': 'fastq_filter',
#  '468': 'gemini_recessive_and_dominant',
#  '469': 'metaphlan2',
#  '470': 'mothur_chimera_vsearch',
#  '471': 'cshl_fastx_barcode_splitter',
#  '472': 'ctb_remSmall',
#  '473': 'sklearn_svm_classifier',
#  '474': 'smf_utils_fix-fasta-headers',
#  '475': 'valet',
#  '476': 'paralyzer',
#  '477': 'cshl_fastx_renamer',
#  '478': 'SequenceCoverageCalculator',
#  '479': 'velvetoptimiser',
#  '480': 'vcfsort',
#  '481': 'Btrim64',
#  '482': 'picard_FixMateInformation',
#  '483': 'datamash_transpose',
#  '484': 'deg_annotate',
#  '485': 'qiime_validate_mapping_file',
#  '486': 'FastTree',
#  '487': 'cufflinks_prok',
#  '488': 'ProteinInference',
#  '489': 'bed_to_bigBed',
#  '490': 'picard_CollectWgsMetrics',
#  '491': 'cd_hit_dup',
#  '492': 'aragorn_trna',
#  '493': 'get_feature_info',
#  '494': 'tp_split_on_column',
#  '495': 'cshl_grep_tool',
#  '496': 'umi_tools_whitelist',
#  '497': 'proteomics_search_tandem_1',
#  '498': 'filter_bed_on_splice_junctions',
#  '499': 'translate_bed_sequences',
#  '500': 'vegan_diversity',
#  '501': 'uparse',
#  '502': 'fastq_to_fasta_python',
#  '503': 'CONVERTER_gff_to_bed_0',
#  '504': 'gtf_filter_by_attribute_values_list',
#  '505': 'Extractor',
#  '506': 'trim_reads',
#  '507': 'bctools_extract_crosslinked_nucleotides',
#  '508': 'bam_to_bigwig',
#  '509': 'tp_sorted_uniq',
#  '510': 'htseq-count',
#  '511': 'XTandemAdapter',
#  '512': 'kallisto_quant',
#  '513': 'resistome_analyzer',
#  '514': 'mothur_pcoa',
#  '515': 'bedtools_genomecoveragebed_bedgraph',
#  '516': 'peakcalling_macs',
#  '517': 'bcftools_view',
#  '518': 'deeptools_bamCoverage',
#  '519': 'ncbi_rpsblast_wrapper',
#  '520': 'rnbeads',
#  '521': 'je_markdupes',
#  '522': 'newick_display',
#  '523': 'cmv',
#  '524': 'vcf2pgSnp',
#  '525': 'flexbardsc',
#  '526': 'checkFormat',
#  '527': 'methtools_destrand',
#  '528': 'stringtie_merge',
#  '529': 'meme_meme',
#  '530': 'DatamashOps',
#  '531': 'qiime_pick_rep_set',
#  '532': 'MAF_To_Fasta1',
#  '533': 'megahit',
#  '534': 'mothur_cluster',
#  '535': 'taxonomy_krona_chart',
#  '536': 'bwameth',
#  '537': 'gatk2_variant_apply_recalibration',
#  '538': 'mass_spectrometry_imaging_qc',
#  '539': 'ProteinResolver',
#  '540': 'bams2ratio',
#  '541': 'gemini_comp_hets',
#  '542': 'deeptools_plot_enrichment',
#  '543': 'peakcalling_macs14',
#  '544': 'glimmer_knowlegde-based',
#  '545': 'silac_analyzer',
#  '546': 'flanking_features_1',
#  '547': 'gatk_unified_genotyper',
#  '548': 'modencode_peakcalling_spp',
#  '549': 'hgv_linkToGProfile',
#  '550': 'collection_column_join',
#  '551': 'mycrobiota-qc-report',
#  '552': 'bg_column_arrange_by_header',
#  '553': 'trimmer',
#  '554': '__SORTLIST__',
#  '555': 'gops_concat_1',
#  '556': 'bedtools_mergebed',
#  '557': 'mothur_parsimony',
#  '558': 'cshl_sed_tool',
#  '559': 'tp_tail_tool',
#  '560': 'rseqc_read_duplication',
#  '561': 'createInterval',
#  '562': 'krona-text',
#  '563': 'clustalw',
#  '564': 'fasta_compute_length',
#  '565': 'tp_text_file_with_recurring_lines',
#  '566': 'Grouping1',
#  '567': 'bedtools_bamtobed',
#  '568': 'CONVERTER_bed_to_gff_0',
#  '569': 'fastq_paired_end_splitter',
#  '570': 'cshl_find_and_replace',
#  '571': 'cshl_princeton_fastx_barcode_splitter',
#  '572': 'stacks_refmap',
#  '573': 'aggregate_scores_in_intervals2',
#  '574': 'gtftobed12',
#  '575': 'random_lines1',
#  '576': 'histogram_rpy',
#  '577': 'bamCompare_deepTools',
#  '578': 'mass_spectrometry_imaging_segmentations',
#  '579': 'bcftools_norm',
#  '580': 'get_read_pipeline',
#  '581': 'mycrobiota-correct-replicates',
#  '582': 'bamCoverage_deepTools',
#  '583': 'EMBOSS: shuffleseq87',
#  '584': 'minfi_getM',
#  '585': 'heatmap2',
#  '586': 'allele_counts_1',
#  '587': 'combine_metaphlan2_humann2',
#  '588': 'filter_by_fasta_ids',
#  '589': 'idpassemble',
#  '590': 'get_sequences',
#  '591': 'ctb_filter',
#  '592': 'mothur_sub_sample',
#  '593': 'sam_merge2',
#  '594': 'length_and_gc_content',
#  '595': 'ExtractFASTAfromFASTQ',
#  '596': 'je_clip',
#  '597': 'multiqc',
#  '598': 'mothur_heatmap_sim',
#  '599': 'chipsequtil_maptoknowngenes',
#  '600': 'minfi_getanno',
#  '601': 'humann2_regroup_table',
#  '602': 'bedtools_intersectbed_bam',
#  '603': 'FROGS_remove_chimera',
#  '604': 'gops_basecoverage_1',
#  '605': 'picard_BamIndexStats',
#  '606': 'varscan',
#  '607': 'numeric_clustering',
#  '608': 'ctb_chemfp_mol2fps',
#  '609': 'cardinal_mz_images',
#  '610': 'mergeCols1',
#  '611': 'sklear_numeric_clustering',
#  '612': 'minfi_qc',
#  '613': 'datamash_ops',
#  '614': 'sample_seqs',
#  '615': 'bwa',
#  '616': 'blastxml_to_tabular_selectable',
#  '617': 'infernal_cmbuild',
#  '618': 'locarna_best_subtree',
#  '619': 'mycrobiota-make-multi-otutable',
#  '620': 'bowtie_wrapper',
#  '621': 'seq_composition',
#  '622': 'mothur_get_groups',
#  '623': 'CONVERTER_gff_to_interval_index_0',
#  '624': 'stacks_genotypes',
#  '625': 'umi_tools_group',
#  '626': 'mycrobiota-split-multi-otutable',
#  '627': 'mimodd_varreport',
#  '628': 'cardinal_data_exporter',
#  '629': 'Interval_Maf_Merged_Fasta2',
#  '630': 'FileMerger',
#  '631': 't2t_report',
#  '632': 'samtools_bedcov',
#  '633': 'plotly_ml_performance_plots',
#  '634': 'vcfvcfintersect',
#  '635': 'convert_bc_to_binary_RY.py',
#  '636': 'wiggle2simple1',
#  '637': 'FROGS_filters',
#  '638': 'rseqc_inner_distance',
#  '639': 'samtools_filter',
#  '640': 'modencode_peakcalling_macs2',
#  '641': 'mothur_venn',
#  '642': 'deeptools_plot_heatmap',
#  '643': 'graphclust_glob_report_no_align',
#  '644': 'IDScoreSwitcher',
#  '645': 'gatk2_variant_recalibrator',
#  '646': 'jbrowse',
#  '647': 'tp_replace_in_line',
#  '648': 'rmcontamination',
#  '649': 'bam-filter',
#  '650': 'sam_to_bam',
#  '651': '__FLATTEN__',
#  '652': 'vcftools_merge',
#  '653': 'CONVERTER_bed_gff_or_vcf_to_bigwig_0',
#  '654': 'CONVERTER_bed_to_bgzip_0',
#  '655': 'dbbuilder',
#  '656': 'flexbar_split_RYYR_bcs',
#  '657': 'IDConflictResolver',
#  '658': 'mycrobiota-otutable_add_blast',
#  '659': 'EMBOSS: revseq82',
#  '660': '__ZIP_COLLECTION__',
#  '661': 'cshl_fastx_clipper',
#  '662': 'scaffold2fasta',
#  '663': 'pynast',
#  '664': 'ConsensusID',
#  '665': 'mothur_remove_seqs',
#  '666': 'cardinal_quality_report',
#  '667': 'seq_filter_by_id',
#  '668': 'meme_fimo',
#  '669': 'hicexplorer_hiccorrectmatrix',
#  '670': 'CONVERTER_fasta_to_fai',
#  '671': 'mothur_chimera_uchime',
#  '672': 'cat1',
#  '673': 'infernal_cmsearch',
#  '674': 'picard_CASM',
#  '675': 'EMBOSS: fuzztran39',
#  '676': 'preproc',
#  '677': 'bg_find_subsequences',
#  '678': 'rm_spurious_events.py',
#  '679': 'seq_filter_by_mapping',
#  '680': 'je_demultiplex',
#  '681': 'fastq_manipulation',
#  '682': '__FILTER_FROM_FILE__',
#  '683': 'varscan_mpileup',
#  '684': 'bgchem_fragment_merger',
#  '685': 'bedtools_subtractbed',
#  '686': 'hgv_david',
#  '687': 'minfi_ppfun',
#  '688': 'w4mjoinpn',
#  '689': 'snpSift_dbnsfp_generic',
#  '690': 'mothur_tree_shared',
#  '691': 'mimodd_varextract',
#  '692': 'fragmenter',
#  '693': 'blast2go',
#  '694': 'group_humann2_uniref_abundances_to_go',
#  '695': 'mycrobiota-krona-mothur',
#  '696': 'methtools_dmr',
#  '697': 'hmmer_hmmbuild',
#  '698': 'ip_projective_transformation_points',
#  '699': 'egsea',
#  '700': 'mothur_heatmap_bin',
#  '701': 'gatk2_haplotype_caller',
#  '702': 'mothur_make_group',
#  '703': 'gene2exon1',
#  '704': 'sam_pileup',
#  '705': 'mothur_dist_seqs',
#  '706': 'mothur_get_oturep',
#  '707': 'minfi_read450k',
#  '708': 'cshl_word_list_grep',
#  '709': 'sed_stream_editor',
#  '710': 'ruvseq',
#  '711': 'samtools_idxstats',
#  '712': 'column_order_header_sort',
#  '713': 'MSGFPlusAdapter',
#  '714': 'graphclust_align_cluster',
#  '715': 'bam2wig',
#  '716': 'bedtools_getfastabed',
#  '717': 'qiime_core_diversity',
#  '718': 'glob_report',
#  '719': 'find_in_reference',
#  '720': 'bedtools_intersectBed',
#  '721': 'deeptools_multi_bigwig_summary',
#  '722': 'gops_merge_1',
#  '723': 'Count1',
#  '724': 'mothur_merge_files',
#  '725': 'sam_bw_filter',
#  '726': 'get_child_terms',
#  '727': 'deeptools_correctGCBias',
#  '728': 'idpqonvert',
#  '729': 'gops_coverage_1',
#  '730': 'rseqc_bam_stat',
#  '731': 'fastq_combiner',
#  '732': 'secure_hash_message_digest',
#  '733': 'sam2interval',
#  '734': 'picard_AddOrReplaceReadGroups',
#  '735': 'ip_projective_transformation',
#  '736': 'deeptools_bamCompare',
#  '737': 'cummeRbund',
#  '738': 'flye',
#  '739': 'bedtools_sortbed',
#  '740': 'Summary_Statistics1',
#  '741': 'msconvert3_raw',
#  '742': 'CONVERTER_bedgraph_to_bigwig',
#  '743': 'hicexplorer_hicpca',
#  '744': '__MERGE_COLLECTION__',
#  '745': 'ConsensusMapNormalizer',
#  '746': 'vcfflatten2',
#  '747': 'ncbi_tblastn_wrapper',
#  '748': 'qiime_pick_closed_reference_otus',
#  '749': 'bedtools_map',
#  '750': 'deeptools_plot_correlation',
#  '751': 'picard_ARRG',
#  '752': 'iuc_pear',
#  '753': 'minfi_methcpg',
#  '754': 'picard_ReorderSam',
#  '755': 'gffread',
#  '756': 'lastz_wrapper_2',
#  '757': 'comp1',
#  '758': 'bamleftalign',
#  '759': 'ctb_remIons',
#  '760': 'EMBOSS: wordcount109',
#  '761': 'viennarna_rnaalifold',
#  '762': 'cmFinder',
#  '763': 'gff_to_sequence',
#  '764': 'megablast_xml_parser',
#  '765': 'mothur_lefse',
#  '766': 'goseq',
#  '767': 'abims_xcms_xcmsSet',
#  '768': 'gatk2_unified_genotyper',
#  '769': 'PicardASMetrics',
#  '770': 'FeatureFinderMetabo',
#  '771': 'diffbind-embl',
#  '772': 'samtools_calmd',
#  '773': 'deeptools_profiler',
#  '774': 'cshl_fastx_reverse_complement',
#  '775': 'annotatemyids',
#  '776': 'PeakPickerHiRes',
#  '777': 'gemini_de_novo',
#  '778': 'raceid_inspectclusters',
#  '779': 'minfi_maptogenome',
#  '780': 'mass_spectrometry_imaging_mzplots',
#  '781': 'humann2_genefamilies_genus_level',
#  '782': 'Grep1',
#  '783': 'gmx_nvt',
#  '784': 'sklearn_nn_classifier',
#  '785': 'gmx_setup',
#  '786': 'deeptools_plot_coverage',
#  '787': 'IDFilter',
#  '788': 'tp_find_and_replace',
#  '789': 'gatk2_base_recalibrator',
#  '790': 'ncbi_blastn_wrapper',
#  '791': 'gspan',
#  '792': 'gemini_burden',
#  '793': 'varscan_somatic',
#  '794': 'snpEff_download',
#  '795': 'hmmer_hmmsearch',
#  '796': 'hicexplorer_hicsummatrices',
#  '797': 'vcf_filter',
#  '798': 'bedtools_complementbed',
#  '799': 'msconvert2_raw',
#  '800': 'mothur_classify_rf',
#  '801': 'chipseeker',
#  '802': 'samtools_split',
#  '803': 'Add_a_column1',
#  '804': 'IDFileConverter',
#  '805': 'react_cal_pipeline',
#  '806': 'PicardInsertSize',
#  '807': 'vt_normalize',
#  '808': 'tmhmm2',
#  '809': 'signalp3',
#  '810': 'hicexplorer_hicbuildmatrix',
#  '811': 'pilon',
#  '812': 'trinity',
#  '813': 'fastq collapser',
#  '814': 'gafa',
#  '815': 'gff2bed1',
#  '816': 'bedtools_genomecoveragebed_histogram',
#  '817': '__FILTER_FAILED_DATASETS__',
#  '818': 'cummerbund_to_cuffdiff',
#  '819': 'rgweblogo3',
#  '820': 'mothur_count_seqs',
#  '821': 'openms_id_file_converter',
#  '822': 'mothur_seq_error',
#  '823': 'nn_classifier',
#  '824': 'CONVERTER_fastqgz_to_fastq',
#  '825': 'gffcompare',
#  '826': 'deeptools_bigwig_compare',
#  '827': 'dunovo',
#  '828': 'goenrichment',
#  '829': 'mimodd_vcf_filter',
#  '830': 'MultiplexResolver',
#  '831': 'snippy_core',
#  '832': 'align_families',
#  '833': 'raceid_main',
#  '834': 'rbc_mirdeep2',
#  '835': 'porechop',
#  '836': 'umi_tools_dedup',
#  '837': 'fastq_quality_trimmer',
#  '838': 'EMBOSS: fuzzpro38',
#  '839': 'velveth_jgi',
#  '840': 'cshl_fastx_nucleotides_distribution',
#  '841': 'EMBOSS: textsearch98',
#  '842': 'glimmer_not-knowlegde-based',
#  '843': 'bg_uniq',
#  '844': 'deeptools_multi_bam_summary',
#  '845': 'blockbuster',
#  '846': 'mass_spectrometry_imaging_preprocessing',
#  '847': 'FileInfo',
#  '848': 'bamtools',
#  '849': 'MzTabExporter',
#  '850': 'rseqc_junction_saturation',
#  '851': 'merge_pcr_duplicates.py',
#  '852': 'cshl_fastq_quality_filter',
#  '853': 'sklearn_ensemble',
#  '854': 'viennarna_rnaplot',
#  '855': 'snpSift_filter',
#  '856': 'FileConverter',
#  '857': 'ChangeCase',
#  '858': 'proteomics_search_protein_prophet_1',
#  '859': 'gatk2_variant_filtration',
#  '860': 'replace_column_with_key_value_file',
#  '861': 'GeMoMa_Annotation_Filter',
#  '862': '__RELABEL_FROM_FILE__',
#  '863': 'deeptools_compute_matrix',
#  '864': 'cshl_awk_replace_in_column',
#  '865': 'bedtools_intersectbed',
#  '866': 'humann2_renorm_table',
#  '867': 'qiime_assign_taxonomy',
#  '868': 'rarefaction_analyzer',
#  '869': 'IsobaricAnalyzer',
#  '870': 'bamFilter',
#  '871': 'tophat2',
#  '872': 'bcftools_call',
#  '873': 'abims_xcms_summary',
#  '874': 'Draw_phylogram',
#  '875': 'bundle_collection',
#  '876': 'pileometh',
#  '877': 'addName',
#  '878': 'interproscan',
#  '879': 'rbc_rnacode',
#  '880': 'infernal_cmstat',
#  '881': 'smf_utils_find-boxes',
#  '882': 'velvet',
#  '883': 'gemini_db_info',
#  '884': 'qiime_make_otu_heatmap',
#  '885': 'mothur_homova',
#  '886': 'EMBOSS: tranalign100',
#  '887': 'rsem_prepare_reference',
#  '888': 'sequence_content_trimmer',
#  '889': 'query_tabular',
#  '890': 'deeptools_heatmapper',
#  '891': 'cuffquant',
#  '892': 'mothur_make_shared',
#  '893': 'picard_MergeSamFiles',
#  '894': '16Sclassifier',
#  '895': 'gops_cluster_1',
#  '896': 'ete_genetree_splitter',
#  '897': 'format_metaphlan2_output',
#  '898': 'barchart_gnuplot',
#  '899': 'hicexplorer_hicmergematrixbins',
#  '900': 'methtools_filter',
#  '901': 'rbc_mirdeep2_quantifier',
#  '902': 'TextExporter',
#  '903': 'glimmer_build-icm',
#  '904': 'fastq_trimmer',
#  '905': 'rsem_calculate_expression',
#  '906': 'bwa_wrapper',
#  '907': 'Cut1',
#  '908': 'bismark_bowtie2',
#  '909': 'bedtools_multiintersectbed',
#  '910': 'gemini_load',
#  '911': 'cardinal_spectra_plots',
#  '912': 'rseqc_read_distribution',
#  '913': 'mothur_count_groups',
#  '914': 'column_remove_by_header',
#  '915': 'spades',
#  '916': 'stacks_denovomap',
#  '917': 'ncbi_makeblastdb',
#  '918': 'search_gui',
#  '919': 'FROGS_preprocess',
#  '920': 'qiime_pick_otus',
#  '921': 'mass_spectrometry_imaging_filtering',
#  '922': 'ProteinQuantifier',
#  '923': 'flexbar',
#  '924': 'gemini_windower',
#  '925': 'fgsea',
#  '926': 'FalseDiscoveryRate',
#  '927': 'subtract_query1',
#  '928': 'mothur_align_seqs',
#  '929': 'fastq_paired_end_joiner',
#  '930': 'FeatureLinkerUnlabeled',
#  '931': 'rbc_mirdeep2_mapper',
#  '932': 'TrimPrimer',
#  '933': 'selectsequencesfrommsa',
#  '934': 'gbk_to_orf',
#  '935': 'FeatureLinkerUnlabeledQT',
#  '936': 'fastq_paired_end_deinterlacer',
#  '937': 'peakachu',
#  '938': 'xcms_merge',
#  '939': 'msgfplus',
#  '940': 'abricate',
#  '941': 'cshl_fasta_formatter',
#  '942': 'EMBOSS: geecee41',
#  '943': 'mass_spectrometry_imaging_ion_images',
#  '944': 'IDMerger',
#  '945': 'vcfcombine',
#  '946': 'heinz_scoring',
#  '947': 'fraggenescan',
#  '948': 'ggplot_histogram',
#  '949': 'megablast_wrapper',
#  '950': 'umi_tools_count',
#  '951': 'mothur_rarefaction_single',
#  '952': 'qiime_split_libraries_fastq',
#  '953': 'Remove_ending',
#  '954': 'pureclip',
#  '955': 'ssake',
#  '956': 'tp_multijoin_tool',
#  '957': 'gatk2_print_reads',
#  '958': 'TrimByLength',
#  '959': 'bedtools_shufflebed',
#  '960': 'ctb_compound_convert',
#  '961': 'eden_vectorizer',
#  '962': 'meme_chip',
#  '963': 'proteomics_moff',
#  '964': 'mothur_trim_seqs',
#  '965': 'ggplot2_point',
#  '966': 'collapse_dataset',
#  '967': 'unicycler',
#  '968': 'EMBOSS: extractseq35',
#  '969': 'vcffixup',
#  '970': 'ctb_ob_genProp',
#  '971': 'xpath'}

# %%
def verify_model(model, tool_sequence, labels, dictionary, reverse_dictionary, compatible_tools, topk=10, max_seq_len=25):
    tl_seq = tool_sequence.split(",")
    last_tool_name = reverse_dictionary[str(tl_seq[-1])]
    #print(last_tool_name, tl_seq)
    try:
        last_compatible_tools = compatible_tools[last_tool_name]
    except:
        last_compatible_tools = []
    sample = np.zeros(max_seq_len)
    for idx, tool_id in enumerate(tl_seq):
        sample[idx] = int(tool_id)
    sample_reshaped = np.reshape(sample, (1, max_seq_len))
    tool_sequence_names = [reverse_dictionary[str(tool_pos)] for tool_pos in tool_sequence.split(",")]
    print(",".join(tool_sequence_names))
    #print(sample)
    # predict next tools for a test path
    prediction = model.predict(sample_reshaped, verbose=0)
    prediction = np.reshape(prediction, (prediction.shape[1],))
    prediction_pos = np.argsort(prediction, axis=-1)

    # get topk prediction
    topk_prediction_pos = prediction_pos[-topk:]
    topk_prediction_val = [np.round(prediction[pos] * 100, 2) for pos in topk_prediction_pos]

    # read tool names using reverse dictionary
    pred_tool_ids = [reverse_dictionary[str(tool_pos)] for tool_pos in topk_prediction_pos]
    try:
        actual_next_tool_ids = list(set(pred_tool_ids).intersection(set(last_compatible_tools.split(","))))
    except:
        actual_next_tool_ids = []
        
    #print("Predicted tools: %s" % ",".join(pred_tool_ids))
    #print()
    pred_tool_ids_sorted = dict()
    for (tool_pos, tool_pred_val) in zip(topk_prediction_pos, topk_prediction_val):
        tool_name = reverse_dictionary[str(tool_pos)]
        if tool_name in actual_next_tool_ids:
            pred_tool_ids_sorted[tool_name] = tool_pred_val
    pred_tool_ids_sorted = dict(sorted(pred_tool_ids_sorted.items(), key=lambda kv: kv[1], reverse=True))
    cls_wt = dict()
    usg_wt = dict()
    inv_wt = dict()
    ids_tools = dict()
    keys = list(pred_tool_ids_sorted.keys())
    for k in keys:
        try:
            cls_wt[k] = np.round(class_weights[str(data_dict[k])], 2)
            usg_wt[k] = np.round(usage_weights[k], 2)
            inv_wt[k] = np.round(inverted_weights[str(data_dict[k])], 2)
        except:
            continue
    print("Predicted tools: \n")
    print(pred_tool_ids_sorted)
    print()
    print("Class weights: \n")
    cls_wt = dict(sorted(cls_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(cls_wt)
    print()
    print("Usage weights: \n")
    usg_wt = dict(sorted(usg_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(usg_wt)
    print()
    print("Inverted weights: \n")
    inv_wt = dict(sorted(inv_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(inv_wt)
    for key in pred_tool_ids_sorted:
        ids_tools[key] = dictionary[key]
    print()
    print(ids_tools)
    print("======================================")
    ave_pred_wt = np.mean(list(pred_tool_ids_sorted.values()))
    ave_cls_wt = np.mean(list(cls_wt.values()))
    ave_usg_wt = np.mean(list(usg_wt.values()))
    ave_inv_wt = np.mean(list(inv_wt.values()))
    return ave_pred_wt, ave_cls_wt, ave_usg_wt, ave_inv_wt

ave_prediction_weights = list()
ave_class_weights = list()
ave_usage_weights = list()
ave_inverted_weights = list()

def get_predictions(model, dictionary, reverse_dictionary, compatibile_tools):
    t_data = read_file(path_test_data)
    ctr = 1
    for ph, cl in t_data.items():
        ave_pred_wt, ave_cls_wt, ave_usg_wt, ave_inv_wt = verify_model(model, ph, cl, dictionary, reverse_dictionary, compatibile_tools)
        ave_prediction_weights.append(ave_pred_wt)
        ave_class_weights.append(ave_cls_wt)
        ave_usage_weights.append(ave_usg_wt)
        ave_inverted_weights.append(ave_inv_wt)
        ctr += 1
        if ctr == 10000:
            break
tool_seq = "302,275" #
verify_model(model, tool_seq, "", dictionary, reverse_dictionary, compatibile_tools)
#get_predictions(model, dictionary, reverse_dictionary, compatibile_tools)
# Out:
# trimmomatic,hisat2
# Predicted tools:
#
# {'fastqc': 7.12, 'featurecounts': 6.87, 'multiqc': 4.51, 'htseq_count': 3.56, 'bam_to_sam': 1.54}
#
# Class weights:
#
# {'fastqc': 6666.35, 'featurecounts': 2646.14, 'htseq_count': 1993.2, 'bam_to_sam': 1523.86, 'multiqc': 1315.05}
#
# Usage weights:
#
# {'fastqc': 5879.0, 'featurecounts': 1191.25, 'htseq_count': 538.31, 'multiqc': 434.46, 'bam_to_sam': 68.97}
#
# Inverted weights:
#
# {'featurecounts': 1454.89, 'htseq_count': 1454.89, 'bam_to_sam': 1454.89, 'multiqc': 880.59, 'fastqc': 787.35}
#
# {'fastqc': 430, 'featurecounts': 38, 'multiqc': 597, 'htseq_count': 240, 'bam_to_sam': 334}
# ======================================
# (4.72, 2828.92, 1622.398, 1206.5220000000002)

# %%
def plot_scatter(x_val, y_val, title, xlabel, ylabel):
    plt.figure(figsize=(8, 8))
    plt.plot(x_val, y_val, 'ro')
    plt.xlabel(xlabel, size=size_label)
    plt.ylabel(ylabel, size=size_label)
    plt.title(title, size=size_title)
    plt.grid(True)
    plt.show()
    
plot_scatter(ave_prediction_weights, ave_class_weights, "Prediction vs class weights", "Prediction scores", "Class weights")
plot_scatter(ave_prediction_weights, ave_usage_weights, "Prediction vs usage weights", "Prediction scores", "Usage weights")
plot_scatter(ave_prediction_weights, ave_inverted_weights, "Prediction vs inverted weights", "Prediction scores", "Inverted weights")
