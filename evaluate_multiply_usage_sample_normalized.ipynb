# %%
import numpy as np
import json
import warnings
import operator

import h5py
from keras.models import model_from_json
from keras import backend as K

from matplotlib import pyplot as plt

warnings.filterwarnings("ignore")

size_title = 18
size_label = 14
n_pred = 2

base_path = "data/evaluate_multiply_usage_sample_normalized/"

path_data_dict = base_path + "data_dict.txt"
path_inverted_wt = base_path + "inverted_weights.txt"
path_usage_wt = base_path + "usage_prediction.txt"
path_class_wt = base_path + "class_weights.txt"
path_test_data = base_path + "test_paths_dict.txt"
model_path = base_path + "trained_model.hdf5"

def read_file(file_path):
    with open(file_path, 'r') as data_file:
        data = json.loads(data_file.read())
    return data

class_weights = read_file(path_class_wt)
usage_weights = read_file(path_usage_wt)
inverted_weights = read_file(path_inverted_wt)
data_dict = read_file(path_data_dict)

def create_model(model_path):
    trained_model = h5py.File(model_path, 'r')
    model_config = json.loads(trained_model.get('model_config').value)
    loaded_model = model_from_json(model_config)
    dictionary = json.loads(trained_model.get('data_dictionary').value)
    compatibile_tools = json.loads(trained_model.get('compatible_tools').value)
    reverse_dictionary = dict((str(v), k) for k, v in dictionary.items())
    model_weights = list()
    weight_ctr = 0
    while True:
        try:
            d_key = "weight_" + str(weight_ctr)
            weights = trained_model.get(d_key).value
            model_weights.append(weights)
            weight_ctr += 1
        except Exception as exception:
            break
    # set the model weights
    loaded_model.set_weights(model_weights)
    return loaded_model, dictionary, reverse_dictionary, compatibile_tools

model, dictionary, reverse_dictionary, compatibile_tools = create_model(model_path)
# Out:
# Using TensorFlow backend.

# %%
reverse_dictionary
# Out:
# {'1': 'gemini_query',
#  '2': 'methtools_calling',
#  '3': 'FastTree',
#  '4': 'get_flanks1',
#  '5': 'fastq_to_fasta_python',
#  '6': 'hcluster_sg',
#  '7': 'length_and_gc_content',
#  '8': 'tp_split_on_column',
#  '9': 'mothur_classify_seqs',
#  '10': 'CONVERTER_Bam_Bai_0',
#  '11': 'cuffnorm',
#  '12': 'tab2fasta',
#  '13': 'heatmap2',
#  '14': 'fastq_combiner',
#  '15': 'cshl_uniq_tool',
#  '16': '__UNZIP_COLLECTION__',
#  '17': 'cufflinks_prok',
#  '18': 'deeptools_compute_matrix_operations',
#  '19': 'CONVERTER_fasta_to_fai',
#  '20': 'addValue',
#  '21': 'find_in_reference',
#  '22': 'mothur_chimera_vsearch',
#  '23': 'bg_statistical_hypothesis_testing',
#  '24': 'gatk2_haplotype_caller',
#  '25': 'rseqc_infer_experiment',
#  '26': 'sample_seqs',
#  '27': 'tp_text_file_with_recurring_lines',
#  '28': 'metaspades',
#  '29': 'Remove_ending',
#  '30': 'rseqc_read_distribution',
#  '31': 'tp_tac',
#  '32': 'trim_reads',
#  '33': 'preMloc',
#  '34': 'r_correlation_matrix',
#  '35': 'tabular_to_fastq',
#  '36': 'samtools_idxstats',
#  '37': 'mothur_venn',
#  '38': 'mothur_remove_groups',
#  '39': 'ProteinQuantifier',
#  '40': 'salmon',
#  '41': 'CONVERTER_bed_gff_or_vcf_to_bigwig_0',
#  '42': 'tp_cat',
#  '43': 'pileometh',
#  '44': 'maldi_quant_preprocessing',
#  '45': 'ncbi_makeblastdb',
#  '46': 'cshl_fastx_collapser',
#  '47': 'kraken-translate',
#  '48': 'wig_to_bigWig',
#  '49': 'Cut1',
#  '50': 'GeMoMa_Annotation_Filter',
#  '51': 'blastxml_to_tabular',
#  '52': 'proteomics_search_protein_prophet_1',
#  '53': 'mothur_classify_otu',
#  '54': 'gmx_md',
#  '55': 'FileInfo',
#  '56': 'bwa_wrapper',
#  '57': 'sequence_content_trimmer',
#  '58': 'mothur_summary_single',
#  '59': 'methtools_destrand',
#  '60': 'hmmer_hmmsearch',
#  '61': 'collapse_dataset',
#  '62': 'muscle',
#  '63': 'CONVERTER_gz_to_uncompressed',
#  '64': 'plotly_parallel_coordinates_plot',
#  '65': 'hicexplorer_hicbuildmatrix',
#  '66': 'mothur_nmds',
#  '67': 'Univariate',
#  '68': 'cshl_fastx_quality_statistics',
#  '69': 'abims_xcms_xcmsSet',
#  '70': 'regex_replace',
#  '71': 'pureclip',
#  '72': 'mothur_align_seqs',
#  '73': 'ssake',
#  '74': 'snpsift_vartype',
#  '75': 'sklearn_feature_selection',
#  '76': 'fastq_paired_end_deinterlacer',
#  '77': 'gtftobed12',
#  '78': 'fasta_merge_files_and_filter_unique_sequences',
#  '79': 'nanopolish_variants',
#  '80': 'piranha',
#  '81': 'cardinal_mz_images',
#  '82': 'samtools_flag_filter',
#  '83': 'cshl_grep_tool',
#  '84': 'gffcompare',
#  '85': 'scaffold2fasta',
#  '86': 'pilon',
#  '87': 'flye',
#  '88': 'glob_report',
#  '89': 'gmx_em',
#  '90': 'PeptideIndexer',
#  '91': 'resistome_analyzer',
#  '92': 'bam_to_bigwig',
#  '93': 'msgfplus',
#  '94': 'numeric_clustering',
#  '95': 'Datamash',
#  '96': 'gffread',
#  '97': 'picard_ValidateSamFile',
#  '98': 'gtf_filter_by_attribute_values_list',
#  '99': 'bedtools_sortbed',
#  '100': 'valet',
#  '101': 'deeptools_plot_coverage',
#  '102': 'cutadapt',
#  '103': 'seurat',
#  '104': 'bcftools_norm',
#  '105': 'humann2_genefamilies_genus_level',
#  '106': 'hgv_david',
#  '107': 'cshl_fasta_nucleotides_changer',
#  '108': 'mothur_sub_sample',
#  '109': 'column_order_header_sort',
#  '110': 'collection_column_join',
#  '111': 'mothur_pre_cluster',
#  '112': '__FLATTEN__',
#  '113': 'bedtools_multicovtbed',
#  '114': 'gops_subtract_1',
#  '115': 'umi_tools_whitelist',
#  '116': 'mothur_chimera_uchime',
#  '117': 'seq_filter_by_id',
#  '118': 'deseq2',
#  '119': 'glimmer_knowlegde-based',
#  '120': 'chipsequtil_maptoknowngenes',
#  '121': 'bedtools_coveragebed',
#  '122': 'clustalw',
#  '123': 'MultiplexResolver',
#  '124': 'cardinal_data_exporter',
#  '125': 'uniprot',
#  '126': 'ncbi_tblastn_wrapper',
#  '127': 'bedtools_unionbedgraph',
#  '128': 'hisat',
#  '129': 'snippy_core',
#  '130': 'deeptools_bigwig_compare',
#  '131': 'cufflinks',
#  '132': 'sklearn_searchcv',
#  '133': 'bedtools_subtractbed',
#  '134': 'bctools_extract_crosslinked_nucleotides',
#  '135': 'join1',
#  '136': 'bedtools_bamtobed',
#  '137': 'je_clip',
#  '138': 'correct_barcodes',
#  '139': 'bedtools_genomecoveragebed_bedgraph',
#  '140': 'minfi_maptogenome',
#  '141': 'secretbt2test',
#  '142': 'mz_to_sqlite',
#  '143': 'edger',
#  '144': 'tophat_fusion_post',
#  '145': 'goseq',
#  '146': 'FROGS_filters',
#  '147': 'rbc_mafft',
#  '148': 'ggplot2_point',
#  '149': 'FROGS_preprocess',
#  '150': 'datamash_transpose',
#  '151': 'iuc_pear',
#  '152': 'NSPDK_candidateClust',
#  '153': 'minfi_dmr',
#  '154': 'mothur_make_contigs',
#  '155': 'structure_to_gspan',
#  '156': 'allele_counts_1',
#  '157': 'bcftools_view',
#  '158': 'seq_composition',
#  '159': 'jbrowse',
#  '160': 'FROGS_affiliation_OTU',
#  '161': 'genbank_to_gff',
#  '162': 'get_feature_info',
#  '163': 'bedtools_windowbed',
#  '164': 'silac_analyzer',
#  '165': 'Nucleosome',
#  '166': 'ctb_simsearch',
#  '167': 'picard_ReorderSam',
#  '168': 'cardinal_filtering',
#  '169': 'fasta_compute_length',
#  '170': 'fastq_to_tabular',
#  '171': 'enhanced_bowtie_wrapper',
#  '172': 'infernal_cmsearch',
#  '173': 'FeatureLinkerUnlabeledQT',
#  '174': 'preproc',
#  '175': 'mothur_corr_axes',
#  '176': 'fasta2tab',
#  '177': 'regex1',
#  '178': 'deeptools_computeMatrix',
#  '179': 'peptide_shaker',
#  '180': 'tag_stat2',
#  '181': 'ruvseq',
#  '182': 'lastz_wrapper_2',
#  '183': 'metaphlan2',
#  '184': 'CONVERTER_interval_to_bedstrict_0',
#  '185': 'column_remove_by_header',
#  '186': 'predict_pipeline',
#  '187': 'infernal_cmbuild',
#  '188': 'ExtractFASTAfromFASTQ',
#  '189': 'samtools_rmdup',
#  '190': 'fasta-stats',
#  '191': 'snpSift_dbnsfp_generic',
#  '192': 'rgweblogo3',
#  '193': 'mycrobiota-make-multi-otutable',
#  '194': 'picard_CleanSam',
#  '195': 'IDMassAccuracy',
#  '196': 'Convert characters1',
#  '197': 'mothur_count_seqs',
#  '198': 'CometAdapter',
#  '199': 'eukaryotic_ncbi_submission',
#  '200': 'bg_sortmerna',
#  '201': 'replace_column_with_key_value_file',
#  '202': 'idpqonvert',
#  '203': 'viennarna_rnafold',
#  '204': 'hicexplorer_hicsummatrices',
#  '205': 'rcas',
#  '206': 'raceid_filtnormconf',
#  '207': 'gemini_interactions',
#  '208': 'EMBOSS: fuzztran39',
#  '209': 'bedtools_intersectBed',
#  '210': 'sklearn_numeric_clustering',
#  '211': 'ctb_online_data_fetch',
#  '212': 'bundle_collection',
#  '213': 'glimmer_build-icm',
#  '214': 'mass_spectrometry_imaging_combine',
#  '215': 'mothur_cluster',
#  '216': 'stacks_refmap',
#  '217': 'tp_cut_tool',
#  '218': 'minfi_mset',
#  '219': 'nonpareil',
#  '220': 'rna_star',
#  '221': 'qiime_pick_rep_set',
#  '222': 'cshl_awk_tool',
#  '223': 'krona-text',
#  '224': 'mcClust',
#  '225': 'rgPicFixMate',
#  '226': 'IDMerger',
#  '227': '__MERGE_COLLECTION__',
#  '228': 'viz_overlay_moving_and_fixed_image',
#  '229': 'secure_hash_message_digest',
#  '230': 'gff2bed1',
#  '231': 'CONVERTER_gff_to_interval_index_0',
#  '232': 'aggregate_scores_in_intervals2',
#  '233': 'openms_id_mapper',
#  '234': 'ChangeCase',
#  '235': 'EMBOSS: extractseq35',
#  '236': 'deg_annotate',
#  '237': 'vcftools_isec',
#  '238': 'idr-embl',
#  '239': 'cshl_fasta_formatter',
#  '240': 'seq_filter_by_mapping',
#  '241': 'qiime_split_libraries_fastq',
#  '242': 'rbc_splitfasta',
#  '243': 'minfi_getM',
#  '244': 'mlocarna',
#  '245': 'RNAlien',
#  '246': 'bamCoverage_deepTools',
#  '247': 'hicexplorer_hicmergematrixbins',
#  '248': 'vcfannotate',
#  '249': 'cshl_sed_tool',
#  '250': 'signalp3',
#  '251': 'minfi_getbeta',
#  '252': 'get_read_pipeline',
#  '253': 'gatk2_variant_select',
#  '254': 'picard_CASM',
#  '255': 'gatk2_variant_recalibrator',
#  '256': 'ggplot_histogram',
#  '257': 'deeptools_bam_compare',
#  '258': 'picard_MarkDuplicates',
#  '259': 'minfi_ppfun',
#  '260': 'vcfallelicprimitives',
#  '261': 'fasplit',
#  '262': '16Sclassifier',
#  '263': 'blast2go',
#  '264': 'tophat2',
#  '265': 'spades',
#  '266': 'gops_concat_1',
#  '267': 'proteomics_search_tandem_1',
#  '268': 'sam_pileup',
#  '269': 'methtools_filter',
#  '270': 'transpose',
#  '271': 'mothur_remove_seqs',
#  '272': 'XTandemAdapter',
#  '273': 'sklearn_nn_classifier',
#  '274': 'macs2_bdgcmp',
#  '275': 'samtools_bedcov',
#  '276': 'methtools_tiling',
#  '277': 'w4mjoinpn',
#  '278': 'bedtools_intersectbed_bam',
#  '279': 'glimmer_not-knowlegde-based',
#  '280': 'mothur_phylotype',
#  '281': 'bwameth',
#  '282': 'megablast_xml_parser',
#  '283': 'mothur_amova',
#  '284': 'shovill',
#  '285': 'bgchem_fragment_merger',
#  '286': 'Paste1',
#  '287': 'tp_replace_in_column',
#  '288': 'Multivariate',
#  '289': 'query_tabular',
#  '290': 'Determine_BC',
#  '291': 'mycrobiota-correct-replicates',
#  '292': 'selectsequencesfrommsa',
#  '293': 'graphlan',
#  '294': 'picard_SamToFastq',
#  '295': 'deeptools_plot_fingerprint',
#  '296': 'tp_find_and_replace',
#  '297': 'bedtools_mergebed',
#  '298': 'extract_element_from_collection',
#  '299': 'peakachu',
#  '300': 'EMBOSS: newseq59',
#  '301': 'picard_MergeSamFiles',
#  '302': 'deeptools_bigwigCompare',
#  '303': '__FILTER_FROM_FILE__',
#  '304': 'vcf2pgSnp',
#  '305': 'gatk2_indel_realigner',
#  '306': 'gmx_nvt',
#  '307': 'bamCompare_deepTools',
#  '308': 'bg_column_arrange_by_header',
#  '309': 'snpSift_geneSets',
#  '310': 'snippy',
#  '311': 'minfi_qc',
#  '312': 'rm_spurious_events.py',
#  '313': 'umi_tools_group',
#  '314': 'modencode_peakcalling_macs2',
#  '315': 'snpEff',
#  '316': 'cshl_cut_tool',
#  '317': 'velvetg_jgi',
#  '318': 'MapStatistics',
#  '319': 'varscan_mpileup',
#  '320': 'mothur_dist_shared',
#  '321': 'mothur_parsimony',
#  '322': 'venn_list',
#  '323': 'svm_classifier',
#  '324': 'minimap2',
#  '325': 'fastq_paired_end_joiner',
#  '326': 'mothur_get_groups',
#  '327': 'subtract_query1',
#  '328': 'gops_intersect_1',
#  '329': 'cshl_fastx_renamer',
#  '330': 'ChooseTag',
#  '331': 'cshl_princeton_fastx_barcode_splitter',
#  '332': 'sailfish',
#  '333': 'mimodd_varcall',
#  '334': 'pileup_interval',
#  '335': 'gemini_de_novo',
#  '336': 'ip_projective_transformation',
#  '337': 'ggplot2_heatmap2',
#  '338': 'flanking_features_1',
#  '339': 'vcfflatten2',
#  '340': 'cardinal_combine',
#  '341': 'samtools_flagstat',
#  '342': 'bam_to_sam',
#  '343': 'cummeRbund',
#  '344': 'samtools_calmd',
#  '345': 'stacks_denovomap',
#  '346': 'createInterval',
#  '347': 'bed_to_bigwig',
#  '348': 'EMBOSS: geecee41',
#  '349': 'heinz_bum',
#  '350': 'tp_head_tool',
#  '351': 'IDScoreSwitcher',
#  '352': 'merge_pcr_duplicates.py',
#  '353': 'PeakPickerHiRes',
#  '354': 'mass_spectrometry_imaging_filtering',
#  '355': 'computeMatrix',
#  '356': 'get_child_terms',
#  '357': 'mothur_get_seqs',
#  '358': 'Batch_correction',
#  '359': 'rsem_prepare_reference',
#  '360': 'TrimByLength',
#  '361': 'cmFinder',
#  '362': 'msconvert3_raw',
#  '363': 'ngsutils_bam_filter',
#  '364': 'EMBOSS: seqret84',
#  '365': 'heatmapper_deepTools',
#  '366': 'gatk_unified_genotyper',
#  '367': 'samtools_stats',
#  '368': 'bowtie_wrapper',
#  '369': 'hicexplorer_hicpca',
#  '370': 'PicardASMetrics',
#  '371': 'tp_replace_in_line',
#  '372': 'Count1',
#  '373': 'wolf_psort',
#  '374': 'vcfgenotypes',
#  '375': 'MapRTTransformer',
#  '376': 'ConsensusID',
#  '377': 'minfi_read450k',
#  '378': 'smf_utils_find-boxes',
#  '379': 'rseqc_bam2wig',
#  '380': 'filter_by_fasta_ids',
#  '381': 'rgPicardMarkDups',
#  '382': 'vsearch_dereplication',
#  '383': 'qiime_pick_open_reference_otus',
#  '384': 'mothur_get_communitytype',
#  '385': 'freebayes',
#  '386': 'augustus',
#  '387': 'bowtie2',
#  '388': 'gatk2_variant_annotator',
#  '389': 'deeptools_computeGCBias',
#  '390': 'smf_utils_estimate-energy',
#  '391': 'Btrim64',
#  '392': 'umi_tools_count',
#  '393': 'rseqc_inner_distance',
#  '394': 'racon',
#  '395': 'macs2_callpeak',
#  '396': 'CONVERTER_sam_to_unsorted_bam',
#  '397': 'tp_sorted_uniq',
#  '398': 'pileup_parser',
#  '399': 'minfi_rset',
#  '400': '__ZIP_COLLECTION__',
#  '401': 'ProteinInference',
#  '402': 'plotly_regression_performance_plots',
#  '403': 'vcffilter2',
#  '404': 'filter_bed_on_splice_junctions',
#  '405': 'deeptools_multi_bigwig_summary',
#  '406': 'methtools_dmr',
#  '407': 'varscan',
#  '408': 'bedtools_coveragebed_counts',
#  '409': 'align_families',
#  '410': 'hicexplorer_hiccorrectmatrix',
#  '411': 'smf_utils_extract-boxed-sequences',
#  '412': 'vcftools_annotate',
#  '413': 'tsne',
#  '414': 'humann2',
#  '415': 'openms_protein_quantifier',
#  '416': 'comp1',
#  '417': 're_he_maldi_image_registration',
#  '418': 'eden_sequence_converter',
#  '419': 'mass_spectrometry_imaging_classification',
#  '420': 'metams_runGC',
#  '421': 'Flash',
#  '422': 'EMBOSS: revseq82',
#  '423': 'bams2ratio',
#  '424': 'proteomics_moff',
#  '425': 'cmv',
#  '426': 'raceid_inspectclusters',
#  '427': 'FeatureLinkerUnlabeled',
#  '428': 'filtlong',
#  '429': 'mothur_trim_seqs',
#  '430': 'picard_CollectWgsMetrics',
#  '431': 'extract_aln_ends.py',
#  '432': 'mothur_homova',
#  '433': 'igvtools_count',
#  '434': '__SORTLIST__',
#  '435': 'mothur_metastats',
#  '436': 'bedtools_genomecoveragebed',
#  '437': 'NFS_transfer',
#  '438': 'eden_vectorizer',
#  '439': 'cshl_fastq_to_fasta',
#  '440': 'rseqc_bam_stat',
#  '441': 'gemini_annotate',
#  '442': 'PicardInsertSize',
#  '443': 'hgv_snpFreq',
#  '444': 'bamtools',
#  '445': 'tp_grep_tool',
#  '446': 'bedtools_shufflebed',
#  '447': 'viennarna_rnaplot',
#  '448': 'deeptools_plot_pca',
#  '449': 'mothur_lefse',
#  '450': 'paralyzer',
#  '451': 'tp_tail_tool',
#  '452': 'featurecounts',
#  '453': 'cat1',
#  '454': 'maldi_quant_peak_detection',
#  '455': 'sklearn_build_pipeline',
#  '456': 'umi_tools_dedup',
#  '457': 'hcluster_sg_parser',
#  '458': 'CONVERTER_gff_to_bed_0',
#  '459': 'get_sequences',
#  '460': 'mothur_dist_seqs',
#  '461': 'CONVERTER_interval_to_bed_0',
#  '462': 'cummerbund_to_cuffdiff',
#  '463': 'TrimByN',
#  '464': 'deeptools_correct_gc_bias',
#  '465': 'tp_easyjoin_tool',
#  '466': 'SequenceCoverageCalculator',
#  '467': 'ProteinResolver',
#  '468': 'translate_bed_sequences',
#  '469': 'meme_dreme',
#  '470': 'transdecoder',
#  '471': 'qiime_make_phylogeny',
#  '472': 'roary',
#  '473': 'FileMerger',
#  '474': 'picard_EstimateLibraryComplexity',
#  '475': 'rarefaction_analyzer',
#  '476': 'vcffixup',
#  '477': 'bcftools_call',
#  '478': 'je_markdupes',
#  '479': 'mothur_make_shared',
#  '480': 'velvet',
#  '481': 'deeptools_bamFingerprint',
#  '482': 'gatk2_variant_apply_recalibration',
#  '483': 'hicexplorer_hicplotmatrix',
#  '484': 'Add_a_column1',
#  '485': 'FalseDiscoveryRate',
#  '486': 'meme_meme',
#  '487': 'ctb_remSmall',
#  '488': 'naive_variant_caller',
#  '489': 'gmx_setup',
#  '490': 'annotateMyIDs',
#  '491': 'raceid_inspecttrajectory',
#  '492': 'lca1',
#  '493': 'bg_uniq',
#  '494': 'hisat2',
#  '495': 'cshl_fastx_trimmer',
#  '496': 'cshl_easyjoin',
#  '497': 'CONVERTER_interval_to_bgzip_0',
#  '498': 'qiime_make_otu_heatmap',
#  '499': 'get_subontology_from',
#  '500': 'gatk_depth_of_coverage',
#  '501': 'aragorn_trna',
#  '502': 'fastq_join',
#  '503': 'picard_BamIndexStats',
#  '504': 'dexseq',
#  '505': 'mimodd_vcf_filter',
#  '506': 'deeptools_bamCoverage',
#  '507': 'IsobaricAnalyzer',
#  '508': 'rnafold',
#  '509': 'cshl_fastx_barcode_splitter',
#  '510': 'minfi_dropsnp',
#  '511': 'mothur_make_biom',
#  '512': 'dt_profiler',
#  '513': 'gops_merge_1',
#  '514': 'nanoplot',
#  '515': 'ncbi_blastn_wrapper',
#  '516': 'tp_sort_header_tool',
#  '517': 'raceid_clustering',
#  '518': 'blockbuster',
#  '519': 'rnaz',
#  '520': 'mothur_classify_rf',
#  '521': 'velvetoptimiser',
#  '522': 'ggplot2_heatmap',
#  '523': 'vt_normalize',
#  '524': 'picard_FilterSamReads',
#  '525': 'cshl_find_and_replace',
#  '526': 'gemini_actionable_mutations',
#  '527': 'sklearn_svm_classifier',
#  '528': 'remove_tail.py',
#  '529': 'dexseq_annotate',
#  '530': 'fastq collapser',
#  '531': 'sklearn_ensemble',
#  '532': 'wc_gnu',
#  '533': 'iReport',
#  '534': 'group_humann2_uniref_abundances_to_go',
#  '535': 'qiime_count_seqs',
#  '536': 'segemehl',
#  '537': 'varscan_somatic',
#  '538': 'bwa_mem',
#  '539': 'methtools_plot',
#  '540': 'gemini_load',
#  '541': 'picard_AddOrReplaceReadGroups',
#  '542': 'bamleftalign',
#  '543': 'mimodd_map',
#  '544': 'correctGCBias',
#  '545': 'hicexplorer_hicfindtads',
#  '546': 'mimodd_varextract',
#  '547': 'samtool_filter2',
#  '548': 'stacks_genotypes',
#  '549': 'gatk2_depth_of_coverage',
#  '550': 'vegan_rarefaction',
#  '551': 'gatk2_print_reads',
#  '552': 'hicexplorer_hicplottads',
#  '553': 'kallisto_quant',
#  '554': 'scpipe',
#  '555': 'qiime_pick_otus',
#  '556': 'Psortb',
#  '557': 'locarna_multiple',
#  '558': 'gatk2_realigner_target_creator',
#  '559': 'make_families',
#  '560': 'melt',
#  '561': 'interproscan',
#  '562': 'megahit',
#  '563': 'ncbi_blastp_wrapper',
#  '564': 'gd_raxml',
#  '565': 'tp_sort_rows',
#  '566': 'treebest_best',
#  '567': 'ctb_chemfp_mol2fps',
#  '568': 'infernal_cmstat',
#  '569': 'mothur_filter_seqs',
#  '570': 'mycrobiota-otutable_add_blast',
#  '571': 'DatamashTranspose',
#  '572': 'minfi_dmp',
#  '573': 'wiggle2simple1',
#  '574': 'multiqc',
#  '575': 'mothur_heatmap_bin',
#  '576': 'cshl_fastx_nucleotides_distribution',
#  '577': 'dunovo',
#  '578': 'Extract_RNA_seq_Evidence',
#  '579': 'mothur_unique_seqs',
#  '580': 'EMBOSS: fuzzpro38',
#  '581': 'mothur_rarefaction_single',
#  '582': 'convert_bc_to_binary_RY.py',
#  '583': 'raceid_trajectory',
#  '584': 'ctb_filter',
#  '585': 'antismash',
#  '586': 'search_gui',
#  '587': 'humann2_regroup_table',
#  '588': 'gff_to_sequence',
#  '589': 'graphclust_align_cluster',
#  '590': 'gemini_comp_hets',
#  '591': 'bctools_remove_spurious_events',
#  '592': 'dexseq_count',
#  '593': 'bedtools_genomecoveragebed_histogram',
#  '594': 'IDPosteriorErrorProbability',
#  '595': 'hgv_linkToGProfile',
#  '596': 'mass_spectrometry_imaging_preprocessing',
#  '597': 'mothur_taxonomy_to_krona',
#  '598': 'sickle',
#  '599': 'pieplots_macs',
#  '600': 'FeatureFinderMetabo',
#  '601': 'rarefaction',
#  '602': 'react_cal_pipeline',
#  '603': 'nn_classifier',
#  '604': 'sort1',
#  '605': 'uchime',
#  '606': 'Filter1',
#  '607': 'ucsc-twobittofa',
#  '608': 'GeneModelMapper',
#  '609': 'gemini_windower',
#  '610': 'qiime_pick_closed_reference_otus',
#  '611': 'heatmapper',
#  '612': 'TrimPrimer',
#  '613': 'deeptools_plot_correlation',
#  '614': 'deeptools_bamCompare',
#  '615': 'fastq_trimmer',
#  '616': 'metaphlan2krona',
#  '617': 'ncbi_blastx_wrapper',
#  '618': 'rseqc_read_duplication',
#  '619': 'decoyfasta',
#  '620': 'cardinal_quality_report',
#  '621': 'bandage_image',
#  '622': 'FeatureFinderMultiplex',
#  '623': 'locarna_best_subtree',
#  '624': 'mothur_pcoa',
#  '625': 'rseqc_junction_saturation',
#  '626': 'format_metaphlan2_output',
#  '627': 'bg_find_subsequences',
#  '628': 'fastq_paired_end_splitter',
#  '629': 'bedtools_intersectbed',
#  '630': 'cshl_fastx_clipper',
#  '631': 'ctb_compound_convert',
#  '632': 'MAF_To_Fasta1',
#  '633': 'deeptools_multi_bam_summary',
#  '634': 'random_lines1',
#  '635': 'gops_basecoverage_1',
#  '636': 'DecoyDatabase',
#  '637': 'picard_FixMateInformation',
#  '638': 'heinz',
#  '639': 'w4mclassfilter',
#  '640': 'term_id_vs_term_name',
#  '641': 'qiime_assign_taxonomy',
#  '642': 'plotly_ml_performance_plots',
#  '643': 'cardinal_preprocessing',
#  '644': 'tp_uniq_tool',
#  '645': 'humann2_renorm_table',
#  '646': 'goenrichment',
#  '647': 'mothur_merge_files',
#  '648': 'blockclust',
#  '649': 'tophat',
#  '650': 'gene2exon1',
#  '651': 'bedtools_multiintersectbed',
#  '652': 'ctb_ob_genProp',
#  '653': 'deeptools_plot_profile',
#  '654': 'CONVERTER_fasta_to_tabular',
#  '655': 'rbc_rnacode',
#  '656': 'cardinal_spectra_plots',
#  '657': 'deseq2_single',
#  '658': 'macs2_predictd',
#  '659': 'Draw_phylogram',
#  '660': 'fastq_manipulation',
#  '661': 'graphclust_glob_report_no_align',
#  '662': 'bismark_bowtie',
#  '663': 'picard_MarkDuplicatesWithMateCigar',
#  '664': 'fgsea',
#  '665': 'FileConverter',
#  '666': 'idpassemble',
#  '667': 'bam2wig',
#  '668': 'Show beginning1',
#  '669': 'egsea',
#  '670': 'flexbar_no_split',
#  '671': 'trimmomatic',
#  '672': '__FILTER_FAILED_DATASETS__',
#  '673': 'heinz_scoring',
#  '674': 'picard_CollectInsertSizeMetrics',
#  '675': 'FeatureFinderCentroided',
#  '676': 'blast_parser',
#  '677': 'proteomics_search_peptide_prophet_1',
#  '678': 'hicexplorer_hictransform',
#  '679': 'raceid_main',
#  '680': 'htseq_count',
#  '681': 'rbc_mirdeep2',
#  '682': 'vegan_diversity',
#  '683': 'cuffdiff',
#  '684': 'fasta_filter_by_length',
#  '685': 'flexbar_split_RR_bcs',
#  '686': 'mothur_tree_shared',
#  '687': 'newick_display',
#  '688': 'sed_stream_editor',
#  '689': 'abims_xcms_fillPeaks',
#  '690': '__APPLY_RULES__',
#  '691': 'join_files_on_column_fuzzy',
#  '692': 'checkFormat',
#  '693': 'xpath',
#  '694': 'uparse',
#  '695': 'bedtools_bamtofastq',
#  '696': 'abricate',
#  '697': 'mothur_screen_seqs',
#  '698': '16Saligner',
#  '699': 'bedtools_map',
#  '700': 'vcftools_merge',
#  '701': 'vcffilter',
#  '702': 'qiime_validate_mapping_file',
#  '703': 'lfq_protein_quant',
#  '704': 'stacks_procrad',
#  '705': 'bcftools_consensus',
#  '706': 'rnbeads',
#  '707': 'snpEff_download',
#  '708': 'goslimmer',
#  '709': 'ete_genetree_splitter',
#  '710': 'dbbuilder',
#  '711': 'MSGFPlusAdapter',
#  '712': 'trinity',
#  '713': 'combine_metaphlan2_humann2',
#  '714': 'ggplot2_histogram',
#  '715': 'htseq-count',
#  '716': 'cast',
#  '717': 'DatamashOps',
#  '718': 'mothur_summary_seqs',
#  '719': 'gops_join_1',
#  '720': 'cor2',
#  '721': 'kraken-report',
#  '722': 'viennarna_rnaalifold',
#  '723': 'gspan',
#  '724': 'sam_to_bam',
#  '725': 'bigwig_to_bedgraph',
#  '726': 'Extract_features1',
#  '727': 'CONVERTER_bed_to_gff_0',
#  '728': 'IDFilter',
#  '729': 'ctb_remIons',
#  '730': 't2t_report',
#  '731': 'limma_voom',
#  '732': 'meme_psp_gen',
#  '733': 'export2graphlan',
#  '734': 'datamash_ops',
#  '735': 'abims_CAMERA_annotateDiffreport',
#  '736': 'tp_multijoin_tool',
#  '737': 'Extractor',
#  '738': 'bedtools_annotatebed',
#  '739': 'ip_projective_transformation_points',
#  '740': 'MzTabExporter',
#  '741': 'extract_bcs.py',
#  '742': 'velveth_jgi',
#  '743': 'vcfsort',
#  '744': 'FileFilter',
#  '745': 'bismark_bowtie2',
#  '746': 'thermo_raw_file_converter',
#  '747': 'ggplot_point',
#  '748': 'mothur_seq_error',
#  '749': 'unicycler',
#  '750': 'charts',
#  '751': 'cshl_fastx_artifacts_filter',
#  '752': 'bed_to_bigBed',
#  '753': 'sam_bw_filter',
#  '754': 'gatk_realigner_target_creator',
#  '755': 'Show tail1',
#  '756': 'bedtools_getfastabed',
#  '757': 'flexbar_split_RYYR_bcs',
#  '758': 'mothur_cluster_split',
#  '759': 'smf_utils_filter-by-energy',
#  '760': 'EMBOSS: textsearch98',
#  '761': 'gops_coverage_1',
#  '762': 'idpquery',
#  '763': 'ctb_silicos_qed',
#  '764': 'mergeCols1',
#  '765': 'mothur_remove_lineage',
#  '766': 'fasttree',
#  '767': 'mothur_count_groups',
#  '768': 'vcf2tsv',
#  '769': 'chipseeker',
#  '770': 'varscan_copynumber',
#  '771': 'annotatemyids',
#  '772': 'smooth_running_window',
#  '773': 'gops_cluster_1',
#  '774': 'kraken',
#  '775': 'prokka',
#  '776': 'Fetch Taxonomic Ranks',
#  '777': 'disco',
#  '778': 'sam2interval',
#  '779': 'rbc_mirdeep2_quantifier',
#  '780': 'IDMapper',
#  '781': 'cuffquant',
#  '782': 'peakcalling_macs14',
#  '783': 'bwa',
#  '784': 'rbc_mirdeep2_mapper',
#  '785': 'gatk2_unified_genotyper',
#  '786': 'mass_spectrometry_imaging_mzplots',
#  '787': 'vcfvcfintersect',
#  '788': 'deeptools_plot_enrichment',
#  '789': 'megablast_wrapper',
#  '790': 'fragmenter',
#  '791': 'IDConflictResolver',
#  '792': 'trimmer',
#  '793': 'deeptools_heatmapper',
#  '794': 'sqlite_to_tabular',
#  '795': 'prokaryotic_ncbi_submission',
#  '796': 'cshl_fastq_quality_boxplot',
#  '797': 'bctools_remove_tail',
#  '798': 'nspdk_sparse',
#  '799': 'table_annovar',
#  '800': 'gmx_solvate',
#  '801': 'gatk2_reduce_reads',
#  '802': 'gatk2_variant_filtration',
#  '803': 'deeptools_correctGCBias',
#  '804': 'metilene',
#  '805': 'ConsensusMapNormalizer',
#  '806': 'rsem_calculate_expression',
#  '807': 'gmx_npt',
#  '808': 'deeptools_plot_heatmap',
#  '809': 'diffbind-embl',
#  '810': 'ctb_change_title',
#  '811': 'picard_CollectRnaSeqMetrics',
#  '812': 'deeptools_compute_gc_bias',
#  '813': 'smf_utils_fix-fasta-headers',
#  '814': 'gemini_pathways',
#  '815': 'peakcalling_macs',
#  '816': 'bam-filter',
#  '817': 'mass_spectrometry_imaging_ion_images',
#  '818': 'bctools_extract_alignment_ends',
#  '819': 'graphicsmagick_image_convert',
#  '820': 'fastq_quality_trimmer',
#  '821': 'EMBOSS: transeq101',
#  '822': 'openms_id_file_converter',
#  '823': 'Summary_Statistics1',
#  '824': 'picard_NormalizeFasta',
#  '825': 'cuffmerge',
#  '826': 'blastxml_to_top_descr',
#  '827': 'TextExporter',
#  '828': 'minfi_getanno',
#  '829': 'deeptools_compute_matrix',
#  '830': 'EMBOSS: tranalign100',
#  '831': 'vcfcombine',
#  '832': 'tp_awk_tool',
#  '833': 'IDFileConverter',
#  '834': 'je_demultiplex',
#  '835': 'barchart_gnuplot',
#  '836': 'gbk_to_orf',
#  '837': 'vcfbedintersect',
#  '838': 't_coffee',
#  '839': 'kraken-filter',
#  '840': 'abims_xcms_summary',
#  '841': 'graphclust_aggregate_alignments',
#  '842': 'fastqc',
#  '843': 'fastq_filter',
#  '844': 'gafa',
#  '845': 'rseqc_geneBody_coverage',
#  '846': 'Grouping1',
#  '847': 'pynast',
#  '848': 'cshl_multijoin',
#  '849': 'xcms_merge',
#  '850': 'mass_spectrometry_imaging_segmentations',
#  '851': 'metaphlan_hclust_heatmap',
#  '852': 'Grep1',
#  '853': 'snpSift_filter',
#  '854': 'msconvert_nix',
#  '855': 'vcf_filter',
#  '856': 'cshl_fastq_quality_filter',
#  '857': 'fraggenescan',
#  '858': 'Interval_Maf_Merged_Fasta2',
#  '859': 'samtools_sort',
#  '860': 'gatk_indel_realigner',
#  '861': 'mothur_make_group',
#  '862': 'bg_protein_properties',
#  '863': 'HighResPrecursorMassCorrector',
#  '864': 'cuffcompare',
#  '865': 'FeatureLinkerUnlabeledKD',
#  '866': 'rmcontamination',
#  '867': 'CONVERTER_bed_to_bgzip_0',
#  '868': 'tmhmm2',
#  '869': 'sklear_numeric_clustering',
#  '870': 'snpfinder',
#  '871': 'FROGS_clustering',
#  '872': 'addName',
#  '873': 'w4mcorcov',
#  '874': 'gemini_recessive_and_dominant',
#  '875': 'ete_homology_classifier',
#  '876': 'stacks_populations',
#  '877': 'mycrobiota-split-multi-otutable',
#  '878': 'taxonomy_krona_chart',
#  '879': 'samtools_mpileup',
#  '880': 'gff_filter_by_attribute',
#  '881': 'CONVERTER_bedgraph_to_bigwig',
#  '882': 'mothur_get_oturep',
#  '883': 'fastq_dump',
#  '884': 'EMBOSS: shuffleseq87',
#  '885': 'modencode_peakcalling_spp',
#  '886': 'w4mclstrpeakpics',
#  '887': 'gemini_db_info',
#  '888': 'cardinal_segmentations',
#  '889': 'snpeff_to_peptides',
#  '890': 'bed2gff1',
#  '891': 'flexbardsc',
#  '892': 'scale_image',
#  '893': 'MapAlignerPoseClustering',
#  '894': '__RELABEL_FROM_FILE__',
#  '895': 'qiime_align_seqs',
#  '896': 'gatk2_base_recalibrator',
#  '897': 'map_peptides_to_bed',
#  '898': 'porechop',
#  '899': 'cshl_sort_header',
#  '900': 'quast',
#  '901': 'unipept',
#  '902': 'bg_diamond',
#  '903': 'heinz_visualization',
#  '904': 'myrimatch',
#  '905': 'tp_sed_tool',
#  '906': 'biosigner',
#  '907': 'circgraph',
#  '908': 'bamFilter',
#  '909': 'mass_spectrometry_imaging_qc',
#  '910': 'samtools_split',
#  '911': 'Digestor',
#  '912': 'fastq_groomer',
#  '913': 'mycrobiota-qc-report',
#  '914': 'stringtie',
#  '915': 'term_id_vs_term_def',
#  '916': 'stringtie_merge',
#  '917': 'cshl_word_list_grep',
#  '918': 'cshl_awk_replace_in_column',
#  '919': 'samtools_slice_bam',
#  '920': 'blastxml_to_tabular_selectable',
#  '921': 'meme_fimo',
#  '922': 'trim_galore',
#  '923': 'XY_Plot_1',
#  '924': 'samtools_filter',
#  '925': 'p_clip_peaks',
#  '926': 'coords2clnt.py',
#  '927': 'EMBOSS: getorf42',
#  '928': 'ncbi_rpsblast_wrapper',
#  '929': 'mycrobiota-krona-mothur',
#  '930': 'deeptools_bamCorrelate',
#  '931': 'mothur_heatmap_sim',
#  '932': 'picard_ARRG',
#  '933': 'graphlan_annotate',
#  '934': 'umi_tools_extract',
#  '935': 'bedtools_complementbed',
#  '936': 'cshl_fastx_reverse_complement',
#  '937': 'QCCalculator',
#  '938': 'FidoAdapter',
#  '939': 'FROGS_remove_chimera',
#  '940': 'Extract genomic DNA 1',
#  '941': 'wsdl_hmdb',
#  '942': 'Remove beginning1',
#  '943': 'ia_coordinates_of_roi',
#  '944': 'sam_merge2',
#  '945': 'histogram_rpy',
#  '946': 'qiime_core_diversity',
#  '947': 'deeptools_profiler',
#  '948': 'bedtools_bedtobam',
#  '949': 'tp_unfold_column_tool',
#  '950': 'gemini_burden',
#  '951': 'EMBOSS: wordcount109',
#  '952': 'fastq_paired_end_interlacer',
#  '953': 'picard_SortSam',
#  '954': 'flexbar',
#  '955': 'minfi_methcpg',
#  '956': 'abims_xcms_group',
#  '957': 'gtf2bedgraph',
#  '958': 'msconvert2_raw',
#  '959': 'deeptools_bam_coverage',
#  '960': 'bedtools_slopbed',
#  '961': 'mimodd_varreport',
#  '962': 'Heatmap',
#  '963': 'hmmer_hmmbuild',
#  '964': 'FROGS_affiliations_stat',
#  '965': 'MassCalculator',
#  '966': 'cd_hit_dup',
#  '967': 'meme_chip',
#  '968': 'EMBOSS: water107',
#  '969': 'snpSift_annotate',
#  '970': 'CONVERTER_fastqgz_to_fastq',
#  '971': 'vcfselectsamples'}

# %%
def verify_model(model, tool_sequence, labels, dictionary, reverse_dictionary, compatible_tools, topk=20, max_seq_len=25):
    tl_seq = tool_sequence.split(",")
    last_tool_name = reverse_dictionary[str(tl_seq[-1])]
    last_compatible_tools = compatible_tools[last_tool_name]
    sample = np.zeros(max_seq_len)
    for idx, tool_id in enumerate(tl_seq):
        sample[idx] = int(tool_id)
    sample_reshaped = np.reshape(sample, (1, max_seq_len))
    
    tool_sequence_names = [reverse_dictionary[str(tool_pos)] for tool_pos in tool_sequence.split(",")]
    print("Tool seq: %s" % ",".join(tool_sequence_names))
    # predict next tools for a test path
    prediction = model.predict(sample_reshaped, verbose=0)
    prediction = np.reshape(prediction, (prediction.shape[1],))
    prediction_pos = np.argsort(prediction, axis=-1)

    # get topk prediction
    topk_prediction_pos = prediction_pos[-topk:]
    topk_prediction_val = [np.round(prediction[pos] * 100, 2) for pos in topk_prediction_pos]

    # read tool names using reverse dictionary
    pred_tool_ids = [reverse_dictionary[str(tool_pos)] for tool_pos in topk_prediction_pos]
    actual_next_tool_ids = list(set(pred_tool_ids).intersection(set(last_compatible_tools.split(","))))      
        
    #print("Predicted tools: %s" % ",".join(pred_tool_ids))
    print()
    pred_tool_ids_sorted = dict()
    for (tool_pos, tool_pred_val) in zip(topk_prediction_pos, topk_prediction_val):
        tool_name = reverse_dictionary[str(tool_pos)]
        if tool_name in actual_next_tool_ids:
            pred_tool_ids_sorted[tool_name] = tool_pred_val
    pred_tool_ids_sorted = dict(sorted(pred_tool_ids_sorted.items(), key=lambda kv: kv[1], reverse=True))
    
    cls_wt = dict()
    usg_wt = dict()
    inv_wt = dict()
    ids_tools = dict()
    keys = list(pred_tool_ids_sorted.keys())
    for k in keys:
        try:
            cls_wt[k] = np.round(class_weights[str(data_dict[k])], 2)
            usg_wt[k] = np.round(usage_weights[k], 2)
            inv_wt[k] = np.round(inverted_weights[str(data_dict[k])], 2)
        except:
            continue
    print("Predicted tools: \n")
    print(pred_tool_ids_sorted)
    print()
    print("Class weights: \n")
    cls_wt = dict(sorted(cls_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(cls_wt)
    print()
    print("Usage weights: \n")
    usg_wt = dict(sorted(usg_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(usg_wt)
    print()
    total_usage_wt = np.sum(list(usg_wt.values()))
    print("Sum usage wt: %0.4f" % (total_usage_wt))
    print()
    print("Inverted weights: \n")
    inv_wt = dict(sorted(inv_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(inv_wt)
    for key in pred_tool_ids_sorted:
        ids_tools[key] = dictionary[key]
    print()
    print("Tool ids")
    print(ids_tools)
    print("======================================")
    return cls_wt, usg_wt, inv_wt, pred_tool_ids_sorted

topk = 10
tool_seq = "942" # ,875,223,17
class_wt, usage_wt, inverse_wt, pred_tools = verify_model(model, tool_seq, "", dictionary, reverse_dictionary, compatibile_tools, topk)
# Out:
# Tool seq: Remove beginning1
#
# Predicted tools:
#
# {'Show beginning1': 7.63, 'addValue': 7.25, 'Add_a_column1': 5.01, 'cat1': 4.17, 'wc_gnu': 4.08, 'datamash_ops': 3.59, 'Filter1': 3.57, 'Cut1': 2.99, 'sort1': 2.77, 'join1': 1.77}
#
# Class weights:
#
# {'sort1': 548.84, 'datamash_ops': 160.19, 'Add_a_column1': 60.76, 'join1': 26.83, 'Filter1': 22.48, 'wc_gnu': 19.82, 'addValue': 10.38, 'Cut1': 6.05, 'Show beginning1': 4.38, 'cat1': 3.16}
#
# Usage weights:
#
# {'Cut1': 1425.46, 'Filter1': 1021.1, 'addValue': 463.1, 'cat1': 428.07, 'join1': 371.21, 'datamash_ops': 100.83, 'Show beginning1': 87.82, 'sort1': 68.5, 'Add_a_column1': 1.0, 'wc_gnu': 1.0}
#
# Sum usage wt: 3968.0900
#
# Inverted weights:
#
# {'sort1': 548.84, 'datamash_ops': 160.19, 'Add_a_column1': 60.76, 'join1': 26.83, 'Filter1': 22.48, 'wc_gnu': 19.82, 'addValue': 10.38, 'Cut1': 6.05, 'Show beginning1': 4.38, 'cat1': 3.16}
#
# Tool ids
# {'Show beginning1': 668, 'addValue': 20, 'Add_a_column1': 484, 'cat1': 453, 'wc_gnu': 532, 'datamash_ops': 734, 'Filter1': 606, 'Cut1': 49, 'sort1': 604, 'join1': 135}
# ======================================

# %%
list_cls_wt = list()
list_usage_wt = list()
list_pred_wt = list()
list_inv_wt = list()
division_pt = int(len(pred_tools) / 2)

for tool in pred_tools:
    list_pred_wt.append(pred_tools[tool])
    #try:
    list_inv_wt.append(inverse_wt[tool])
    list_usage_wt.append(usage_wt[tool])
    #except:
    #list_inv_wt.append(1)

def plot_scatter(y_val, title, xlabel, ylabel):
    x_val = range(1, len(y_val) + 1)
    plt.figure(figsize=(8, 8))
    plt.plot(x_val[:division_pt], y_val[:division_pt], 'ro')
    plt.plot(x_val[division_pt:], y_val[division_pt:], 'b^')
    plt.xlabel(xlabel, size=size_label)
    plt.ylabel(ylabel, size=size_label)
    plt.legend([("First top-%s" % str(division_pt)), ("Next top-%s" % str(division_pt))])
    plt.title(title, size=size_title)
    plt.grid(True)
    plt.show()

plot_scatter(list_usage_wt, "Usage weights for tools", "Number of tools", "Class weights")
#plot_scatter(ave_prediction_weights, ave_usage_weights, "Prediction vs usage weights", "Prediction scores", "Usage weights")
#plot_scatter(ave_prediction_weights, ave_inverted_weights, "Prediction vs inverted weights", "Prediction scores", "Inverted weights")
