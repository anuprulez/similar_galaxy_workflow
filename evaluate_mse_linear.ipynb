# %%
import numpy as np
import json
import warnings
import operator

import h5py
from keras.models import model_from_json
from keras import backend as K

from matplotlib import pyplot as plt

warnings.filterwarnings("ignore")

size_title = 18
size_label = 14
n_pred = 2 

base_path = "data/evaluate_mse_linear/" # cluster path: 7_similar_galaxy_workflow

path_data_dict = base_path + "data_dict.txt"
path_inverted_wt = base_path + "inverted_weights.txt"
path_usage_wt = base_path + "usage_prediction.txt"
path_class_wt = base_path + "class_weights.txt"
path_test_data = base_path + "test_paths_dict.txt"
model_path = base_path + "trained_model.hdf5"

def read_file(file_path):
    with open(file_path, 'r') as data_file:
        data = json.loads(data_file.read())
    return data

class_weights = read_file(path_class_wt)
usage_weights = read_file(path_usage_wt)
inverted_weights = read_file(path_inverted_wt)
data_dict = read_file(path_data_dict)

def create_model(model_path):
    trained_model = h5py.File(model_path, 'r')
    model_config = json.loads(trained_model.get('model_config').value)
    loaded_model = model_from_json(model_config)
    dictionary = json.loads(trained_model.get('data_dictionary').value)
    compatibile_tools = json.loads(trained_model.get('compatible_tools').value)
    reverse_dictionary = dict((str(v), k) for k, v in dictionary.items())
    model_weights = list()
    weight_ctr = 0
    while True:
        try:
            d_key = "weight_" + str(weight_ctr)
            weights = trained_model.get(d_key).value
            model_weights.append(weights)
            weight_ctr += 1
        except Exception as exception:
            break
    # set the model weights
    loaded_model.set_weights(model_weights)
    return loaded_model, dictionary, reverse_dictionary, compatibile_tools

model, dictionary, reverse_dictionary, compatibile_tools = create_model(model_path)
# Out:
# Using TensorFlow backend.

# %%
reverse_dictionary
# Out:
# {'1': 'bg_statistical_hypothesis_testing',
#  '2': 'fastq_paired_end_interlacer',
#  '3': 'ConsensusMapNormalizer',
#  '4': 'cufflinks_prok',
#  '5': 'correctGCBias',
#  '6': 'fasta-stats',
#  '7': 'chipsequtil_maptoknowngenes',
#  '8': 'deeptools_multi_bam_summary',
#  '9': 'mergeCols1',
#  '10': 'deeptools_correct_gc_bias',
#  '11': 'smooth_running_window',
#  '12': 'regex_replace',
#  '13': 'column_order_header_sort',
#  '14': 'EMBOSS: transeq101',
#  '15': 'iReport',
#  '16': 'pileup_interval',
#  '17': 'addName',
#  '18': 'abims_xcms_fillPeaks',
#  '19': 'hicexplorer_hiccorrectmatrix',
#  '20': 'fraggenescan',
#  '21': 'picard_FixMateInformation',
#  '22': 'rseqc_bam_stat',
#  '23': 'fragmenter',
#  '24': 'mycrobiota-make-multi-otutable',
#  '25': 'eden_sequence_converter',
#  '26': 'FeatureFinderMultiplex',
#  '27': 'ncbi_blastn_wrapper',
#  '28': 'rseqc_bam2wig',
#  '29': 'deeptools_multi_bigwig_summary',
#  '30': 'IDFilter',
#  '31': 'bedtools_coveragebed_counts',
#  '32': 'tab2fasta',
#  '33': 'vcffixup',
#  '34': 'myrimatch',
#  '35': 'scale_image',
#  '36': 'tp_easyjoin_tool',
#  '37': 'bg_find_subsequences',
#  '38': 'kraken-report',
#  '39': 'vcfallelicprimitives',
#  '40': 'methtools_filter',
#  '41': 'gd_raxml',
#  '42': 'vcfselectsamples',
#  '43': 'bedtools_genomecoveragebed_bedgraph',
#  '44': 'get_read_pipeline',
#  '45': 'Show beginning1',
#  '46': 'methtools_calling',
#  '47': 'fastq_to_fasta_python',
#  '48': 'samtools_flag_filter',
#  '49': 'ProteinQuantifier',
#  '50': 'stringtie_merge',
#  '51': 'ctb_ob_genProp',
#  '52': 'sklearn_numeric_clustering',
#  '53': 'scpipe',
#  '54': '__APPLY_RULES__',
#  '55': 'gtf_filter_by_attribute_values_list',
#  '56': 'meme_dreme',
#  '57': 'ctb_filter',
#  '58': '__FILTER_FROM_FILE__',
#  '59': 'wig_to_bigWig',
#  '60': 'gatk2_print_reads',
#  '61': 'ncbi_blastx_wrapper',
#  '62': 'minfi_ppfun',
#  '63': 'transdecoder',
#  '64': 'minfi_maptogenome',
#  '65': 'structure_to_gspan',
#  '66': 'flexbar_split_RYYR_bcs',
#  '67': 'vsearch_dereplication',
#  '68': 'porechop',
#  '69': 'Extract_features1',
#  '70': 'bed_to_bigwig',
#  '71': 'w4mjoinpn',
#  '72': 'PeakPickerHiRes',
#  '73': 'sickle',
#  '74': 'bam-filter',
#  '75': 'openms_protein_quantifier',
#  '76': 'segemehl',
#  '77': 'mothur_trim_seqs',
#  '78': 'ctb_chemfp_mol2fps',
#  '79': 'FeatureLinkerUnlabeledKD',
#  '80': 'rna_star',
#  '81': 'qiime_pick_otus',
#  '82': 'hgv_david',
#  '83': 'cshl_sort_header',
#  '84': 'mothur_corr_axes',
#  '85': 'filtlong',
#  '86': 'ncbi_rpsblast_wrapper',
#  '87': 'unipept',
#  '88': 'bctools_extract_crosslinked_nucleotides',
#  '89': 'je_clip',
#  '90': 'gmx_md',
#  '91': 'rnaz',
#  '92': 'extract_element_from_collection',
#  '93': 'idr-embl',
#  '94': 'Extract genomic DNA 1',
#  '95': 'gffcompare',
#  '96': 'Remove_ending',
#  '97': 'bams2ratio',
#  '98': 'bedtools_genomecoveragebed_histogram',
#  '99': 'predict_pipeline',
#  '100': 'rnbeads',
#  '101': 'pileup_parser',
#  '102': 'ProteinResolver',
#  '103': 'fasta_filter_by_length',
#  '104': 'mycrobiota-qc-report',
#  '105': 'vcftools_annotate',
#  '106': 'fastq_join',
#  '107': 'prokaryotic_ncbi_submission',
#  '108': 'bedtools_intersectbed_bam',
#  '109': 'glob_report',
#  '110': 'random_lines1',
#  '111': 'methtools_dmr',
#  '112': 'cshl_cut_tool',
#  '113': 'gatk2_variant_annotator',
#  '114': 'varscan_somatic',
#  '115': 'smf_utils_filter-by-energy',
#  '116': 'Determine_BC',
#  '117': 'mothur_cluster_split',
#  '118': 'mothur_classify_otu',
#  '119': 'vcftools_merge',
#  '120': 'vt_normalize',
#  '121': 'bamtools',
#  '122': 'bedtools_intersectbed',
#  '123': 'bismark_bowtie',
#  '124': 'heinz',
#  '125': 'gmx_nvt',
#  '126': 'heatmapper',
#  '127': 'vcfgenotypes',
#  '128': 'gatk2_variant_select',
#  '129': 'comp1',
#  '130': 'mothur_make_biom',
#  '131': 'gatk2_realigner_target_creator',
#  '132': 'fastq_dump',
#  '133': 'cshl_awk_replace_in_column',
#  '134': 'mothur_remove_lineage',
#  '135': 'je_demultiplex',
#  '136': 'samtools_calmd',
#  '137': 'FROGS_affiliation_OTU',
#  '138': 'krona-text',
#  '139': 'mcClust',
#  '140': 'deeptools_bamCorrelate',
#  '141': 'hicexplorer_hictransform',
#  '142': 'gatk_depth_of_coverage',
#  '143': 'kraken-translate',
#  '144': 'sam_to_bam',
#  '145': 'bedtools_mergebed',
#  '146': 'cmv',
#  '147': 'minfi_methcpg',
#  '148': 'idpquery',
#  '149': 'tp_grep_tool',
#  '150': 'cshl_easyjoin',
#  '151': 'gops_merge_1',
#  '152': 'heatmapper_deepTools',
#  '153': 'term_id_vs_term_def',
#  '154': 'vcfbedintersect',
#  '155': 'cardinal_data_exporter',
#  '156': 'samtools_slice_bam',
#  '157': 'minfi_dmr',
#  '158': 'metaspades',
#  '159': 'picard_CollectWgsMetrics',
#  '160': 'fasplit',
#  '161': 'egsea',
#  '162': 'gatk2_indel_realigner',
#  '163': 'bg_uniq',
#  '164': 'picard_CollectInsertSizeMetrics',
#  '165': 'length_and_gc_content',
#  '166': 'gene2exon1',
#  '167': 'gatk2_variant_filtration',
#  '168': 'get_child_terms',
#  '169': 'hgv_snpFreq',
#  '170': 'gafa',
#  '171': 'naive_variant_caller',
#  '172': 'gatk2_variant_apply_recalibration',
#  '173': 'bedtools_windowbed',
#  '174': 'cardinal_quality_report',
#  '175': 'samtools_mpileup',
#  '176': 'addValue',
#  '177': 'mothur_heatmap_bin',
#  '178': 'piranha',
#  '179': 'mothur_dist_seqs',
#  '180': 'bwa',
#  '181': 'snpeff_to_peptides',
#  '182': 'EMBOSS: fuzztran39',
#  '183': 'bedtools_map',
#  '184': 're_he_maldi_image_registration',
#  '185': 'hcluster_sg_parser',
#  '186': 'fasttree',
#  '187': 'fasta_merge_files_and_filter_unique_sequences',
#  '188': 'FROGS_clustering',
#  '189': 'Heatmap',
#  '190': 'FalseDiscoveryRate',
#  '191': 'salmon',
#  '192': 'fastq_manipulation',
#  '193': 'deeptools_bamCoverage',
#  '194': 'bamFilter',
#  '195': 'mothur_make_group',
#  '196': 'tophat_fusion_post',
#  '197': 'methtools_plot',
#  '198': 'preproc',
#  '199': 'samtools_rmdup',
#  '200': 'cshl_fasta_nucleotides_changer',
#  '201': 'Btrim64',
#  '202': 'hgv_linkToGProfile',
#  '203': 'hisat',
#  '204': 'mass_spectrometry_imaging_combine',
#  '205': 'mothur_seq_error',
#  '206': 'cshl_fastx_clipper',
#  '207': 'mlocarna',
#  '208': 'samtools_filter',
#  '209': 'CONVERTER_interval_to_bed_0',
#  '210': 'deeptools_bigwig_compare',
#  '211': 'cshl_fastx_reverse_complement',
#  '212': 'shovill',
#  '213': 'gff2bed1',
#  '214': 'mass_spectrometry_imaging_mzplots',
#  '215': 'metaphlan_hclust_heatmap',
#  '216': 'minfi_qc',
#  '217': 'bam_to_sam',
#  '218': 'TrimPrimer',
#  '219': 'picard_ValidateSamFile',
#  '220': 'Multivariate',
#  '221': 'rbc_mirdeep2_mapper',
#  '222': 'w4mclassfilter',
#  '223': 'umi_tools_dedup',
#  '224': 'trimmer',
#  '225': 'viennarna_rnaalifold',
#  '226': 'ncbi_blastp_wrapper',
#  '227': 'FastTree',
#  '228': 'infernal_cmsearch',
#  '229': 'gops_subtract_1',
#  '230': 'CONVERTER_fasta_to_tabular',
#  '231': 'circgraph',
#  '232': 'bigwig_to_bedgraph',
#  '233': 'cshl_fastq_quality_filter',
#  '234': 'qiime_core_diversity',
#  '235': 'annotatemyids',
#  '236': 'pureclip',
#  '237': 'mothur_count_seqs',
#  '238': 'tp_multijoin_tool',
#  '239': 'FeatureFinderCentroided',
#  '240': 'openms_id_mapper',
#  '241': 'mimodd_map',
#  '242': 'varscan',
#  '243': 'picard_MergeSamFiles',
#  '244': 'bedtools_bamtofastq',
#  '245': 'correct_barcodes',
#  '246': 'deeptools_bamCompare',
#  '247': 'ip_projective_transformation',
#  '248': 't2t_report',
#  '249': 'flexbar_split_RR_bcs',
#  '250': 'snpsift_vartype',
#  '251': 'idpassemble',
#  '252': 'tp_head_tool',
#  '253': 'EMBOSS: getorf42',
#  '254': 'gtf2bedgraph',
#  '255': 'deeptools_bam_coverage',
#  '256': 'qiime_make_otu_heatmap',
#  '257': 'bam2wig',
#  '258': 'lfq_protein_quant',
#  '259': 'deseq2',
#  '260': 'cardinal_mz_images',
#  '261': 'xpath',
#  '262': 'DatamashTranspose',
#  '263': 'bctools_remove_tail',
#  '264': 'hmmer_hmmsearch',
#  '265': 'bam_to_bigwig',
#  '266': 'goseq',
#  '267': 'DecoyDatabase',
#  '268': 'sailfish',
#  '269': 'gemini_windower',
#  '270': 'IDFileConverter',
#  '271': 'query_tabular',
#  '272': 'abims_CAMERA_annotateDiffreport',
#  '273': 'fastq_paired_end_joiner',
#  '274': 'thermo_raw_file_converter',
#  '275': 'roary',
#  '276': 'join_files_on_column_fuzzy',
#  '277': 'humann2',
#  '278': 'ete_homology_classifier',
#  '279': 'proteomics_search_peptide_prophet_1',
#  '280': 'bamCompare_deepTools',
#  '281': 'smf_utils_extract-boxed-sequences',
#  '282': 'cshl_fastx_barcode_splitter',
#  '283': 'qiime_pick_rep_set',
#  '284': 'tp_sorted_uniq',
#  '285': 'term_id_vs_term_name',
#  '286': 'antismash',
#  '287': 'cardinal_filtering',
#  '288': 'picard_MarkDuplicates',
#  '289': 'openms_id_file_converter',
#  '290': 'macs2_predictd',
#  '291': 'peptide_shaker',
#  '292': 'snippy',
#  '293': 'umi_tools_count',
#  '294': 'minfi_dropsnp',
#  '295': 'Grouping1',
#  '296': 'heatmap2',
#  '297': 'bwa_mem',
#  '298': 'EMBOSS: textsearch98',
#  '299': 'ctb_silicos_qed',
#  '300': 'pileometh',
#  '301': 'bedtools_multicovtbed',
#  '302': 'bowtie_wrapper',
#  '303': 'bedtools_getfastabed',
#  '304': 'FROGS_remove_chimera',
#  '305': 'snpEff_download',
#  '306': 'ete_genetree_splitter',
#  '307': 'flexbardsc',
#  '308': 'snpfinder',
#  '309': 'trim_reads',
#  '310': 'graphlan_annotate',
#  '311': 'aragorn_trna',
#  '312': 'diffbind-embl',
#  '313': 'allele_counts_1',
#  '314': 'bctools_remove_spurious_events',
#  '315': 'IDPosteriorErrorProbability',
#  '316': 'coords2clnt.py',
#  '317': 'hicexplorer_hicplottads',
#  '318': 'ggplot_point',
#  '319': 'CONVERTER_sam_to_unsorted_bam',
#  '320': 'smf_utils_fix-fasta-headers',
#  '321': 'IDMerger',
#  '322': 'dunovo',
#  '323': 'mothur_screen_seqs',
#  '324': 'gmx_npt',
#  '325': 'raceid_main',
#  '326': '__FILTER_FAILED_DATASETS__',
#  '327': 'freebayes',
#  '328': 'pynast',
#  '329': 'CometAdapter',
#  '330': 'CONVERTER_interval_to_bgzip_0',
#  '331': 'Datamash',
#  '332': 'picard_AddOrReplaceReadGroups',
#  '333': 'tp_replace_in_column',
#  '334': 'FileInfo',
#  '335': 'cummeRbund',
#  '336': 'htseq_count',
#  '337': 'ChooseTag',
#  '338': 'NFS_transfer',
#  '339': 'gemini_de_novo',
#  '340': 'seq_filter_by_id',
#  '341': 'mass_spectrometry_imaging_qc',
#  '342': 'PeptideIndexer',
#  '343': 'xcms_merge',
#  '344': 'cshl_fastx_collapser',
#  '345': 'rbc_mirdeep2_quantifier',
#  '346': 'dexseq',
#  '347': 'ProteinInference',
#  '348': 'mass_spectrometry_imaging_segmentations',
#  '349': 'bcftools_call',
#  '350': 'smf_utils_estimate-energy',
#  '351': 'picard_CleanSam',
#  '352': 'vcfvcfintersect',
#  '353': 'EMBOSS: extractseq35',
#  '354': 'ip_projective_transformation_points',
#  '355': 'tp_cut_tool',
#  '356': 'locarna_best_subtree',
#  '357': 'raceid_filtnormconf',
#  '358': 'qiime_pick_closed_reference_otus',
#  '359': 'convert_bc_to_binary_RY.py',
#  '360': 'clustalw',
#  '361': 'charts',
#  '362': 'je_markdupes',
#  '363': 'seurat',
#  '364': 'mothur_summary_seqs',
#  '365': 'MSGFPlusAdapter',
#  '366': 'ggplot2_point',
#  '367': 'mothur_get_oturep',
#  '368': 'graphlan',
#  '369': 'sklearn_build_pipeline',
#  '370': 'bg_protein_properties',
#  '371': 'subtract_query1',
#  '372': 'tp_sed_tool',
#  '373': 'umi_tools_extract',
#  '374': 'gops_coverage_1',
#  '375': 'vcfannotate',
#  '376': 'qiime_assign_taxonomy',
#  '377': 'snpSift_annotate',
#  '378': 'SequenceCoverageCalculator',
#  '379': 'vcfflatten2',
#  '380': 'macs2_callpeak',
#  '381': 'cshl_fasta_formatter',
#  '382': 'bcftools_norm',
#  '383': 'cshl_uniq_tool',
#  '384': 'glimmer_knowlegde-based',
#  '385': 'stacks_refmap',
#  '386': 'meme_meme',
#  '387': 'cuffquant',
#  '388': 'IDMapper',
#  '389': 'tp_cat',
#  '390': 'histogram_rpy',
#  '391': 'uniprot',
#  '392': 'FROGS_filters',
#  '393': 'IDScoreSwitcher',
#  '394': 'megahit',
#  '395': 'lca1',
#  '396': 'raceid_trajectory',
#  '397': 'search_gui',
#  '398': 'deeptools_plot_correlation',
#  '399': 'mass_spectrometry_imaging_filtering',
#  '400': 'GeneModelMapper',
#  '401': 'bandage_image',
#  '402': 'gatk2_haplotype_caller',
#  '403': 'merge_pcr_duplicates.py',
#  '404': 'checkFormat',
#  '405': 'flanking_features_1',
#  '406': 'newick_display',
#  '407': 'rcas',
#  '408': 'combine_metaphlan2_humann2',
#  '409': 'tabular_to_fastq',
#  '410': 'stacks_denovomap',
#  '411': 'gatk2_unified_genotyper',
#  '412': 'racon',
#  '413': 'collection_column_join',
#  '414': 'raceid_inspecttrajectory',
#  '415': 'computeMatrix',
#  '416': 'deeptools_correctGCBias',
#  '417': 'graphclust_align_cluster',
#  '418': 'mothur_chimera_vsearch',
#  '419': 'limma_voom',
#  '420': 'cshl_fastx_nucleotides_distribution',
#  '421': 'get_feature_info',
#  '422': 'rseqc_read_distribution',
#  '423': 'chipseeker',
#  '424': 'graphicsmagick_image_convert',
#  '425': 'samtools_flagstat',
#  '426': 'EMBOSS: revseq82',
#  '427': 'velvetoptimiser',
#  '428': 'interproscan',
#  '429': 'IDConflictResolver',
#  '430': 'Interval_Maf_Merged_Fasta2',
#  '431': 'bed2gff1',
#  '432': 'rseqc_read_duplication',
#  '433': 'ggplot2_heatmap2',
#  '434': 'ssake',
#  '435': 'mothur_filter_seqs',
#  '436': 'iuc_pear',
#  '437': 'cshl_fastx_renamer',
#  '438': 'cmFinder',
#  '439': 'mz_to_sqlite',
#  '440': 'Remove beginning1',
#  '441': 'extract_aln_ends.py',
#  '442': 'mothur_make_shared',
#  '443': 'mycrobiota-split-multi-otutable',
#  '444': 'humann2_renorm_table',
#  '445': 'mothur_align_seqs',
#  '446': 'qiime_split_libraries_fastq',
#  '447': 'ctb_simsearch',
#  '448': 'picard_EstimateLibraryComplexity',
#  '449': 'deeptools_bigwigCompare',
#  '450': 'ConsensusID',
#  '451': 'minfi_read450k',
#  '452': 'qiime_count_seqs',
#  '453': 'gatk2_variant_recalibrator',
#  '454': 'nanopolish_variants',
#  '455': 'rm_spurious_events.py',
#  '456': 'vcftools_isec',
#  '457': 'bedtools_complementbed',
#  '458': 'maldi_quant_peak_detection',
#  '459': 'sam_merge2',
#  '460': 'CONVERTER_gz_to_uncompressed',
#  '461': 'cshl_multijoin',
#  '462': 'uparse',
#  '463': 'hicexplorer_hicfindtads',
#  '464': 'idpqonvert',
#  '465': 'make_families',
#  '466': 'regex1',
#  '467': 'bgchem_fragment_merger',
#  '468': 'rarefaction',
#  '469': 'cutadapt',
#  '470': 'gatk2_reduce_reads',
#  '471': 'maldi_quant_preprocessing',
#  '472': 'tp_find_and_replace',
#  '473': 'raceid_inspectclusters',
#  '474': 'cuffcompare',
#  '475': 'mothur_lefse',
#  '476': 'ExtractFASTAfromFASTQ',
#  '477': 'cardinal_segmentations',
#  '478': 'minfi_getanno',
#  '479': 'bedtools_genomecoveragebed',
#  '480': 'GeMoMa_Annotation_Filter',
#  '481': 'deeptools_bam_compare',
#  '482': 'wiggle2simple1',
#  '483': 'Digestor',
#  '484': 'EMBOSS: shuffleseq87',
#  '485': 'flexbar_no_split',
#  '486': 'CONVERTER_bed_to_gff_0',
#  '487': 'mothur_rarefaction_single',
#  '488': 'RNAlien',
#  '489': 'minfi_mset',
#  '490': 'fastq_quality_trimmer',
#  '491': 'eden_vectorizer',
#  '492': 'mothur_get_seqs',
#  '493': 'gops_basecoverage_1',
#  '494': 'mothur_get_groups',
#  '495': 'multiqc',
#  '496': 'tp_split_on_column',
#  '497': 'snpSift_dbnsfp_generic',
#  '498': 'CONVERTER_gff_to_bed_0',
#  '499': 'viennarna_rnafold',
#  '500': 'fasta_compute_length',
#  '501': 'deg_annotate',
#  '502': 'cardinal_spectra_plots',
#  '503': 'stacks_populations',
#  '504': 'proteomics_search_protein_prophet_1',
#  '505': 'glimmer_build-icm',
#  '506': 'seq_filter_by_mapping',
#  '507': 'Filter1',
#  '508': 'barchart_gnuplot',
#  '509': 'PicardASMetrics',
#  '510': 'svm_classifier',
#  '511': 'bcftools_view',
#  '512': 'plotly_ml_performance_plots',
#  '513': 'trim_galore',
#  '514': 'picard_MarkDuplicatesWithMateCigar',
#  '515': 'heinz_scoring',
#  '516': 'Flash',
#  '517': 'cat1',
#  '518': 'mothur_chimera_uchime',
#  '519': 'vcf2tsv',
#  '520': 'cast',
#  '521': 'rseqc_inner_distance',
#  '522': 'sam2interval',
#  '523': 'pieplots_macs',
#  '524': 'fastq_combiner',
#  '525': 'velveth_jgi',
#  '526': 'EMBOSS: wordcount109',
#  '527': 'get_flanks1',
#  '528': 'cshl_princeton_fastx_barcode_splitter',
#  '529': 'gemini_recessive_and_dominant',
#  '530': 'filter_by_fasta_ids',
#  '531': 'mycrobiota-correct-replicates',
#  '532': 'Count1',
#  '533': 'unicycler',
#  '534': 'mothur_get_communitytype',
#  '535': 'Univariate',
#  '536': 'blast2go',
#  '537': 'graphclust_aggregate_alignments',
#  '538': 'hmmer_hmmbuild',
#  '539': 'macs2_bdgcmp',
#  '540': 'cshl_fastx_quality_statistics',
#  '541': 'minimap2',
#  '542': 'msconvert3_raw',
#  '543': 'mimodd_vcf_filter',
#  '544': 'deeptools_compute_matrix',
#  '545': 'deeptools_plot_coverage',
#  '546': 'bowtie2',
#  '547': 'group_humann2_uniref_abundances_to_go',
#  '548': 'spades',
#  '549': 'CONVERTER_bedgraph_to_bigwig',
#  '550': 'umi_tools_whitelist',
#  '551': 'gops_concat_1',
#  '552': 'map_peptides_to_bed',
#  '553': 'mothur_homova',
#  '554': 'rbc_mafft',
#  '555': 'fastq collapser',
#  '556': 'join1',
#  '557': 'methtools_tiling',
#  '558': 'tp_sort_rows',
#  '559': 'deseq2_single',
#  '560': 'Grep1',
#  '561': 'qiime_validate_mapping_file',
#  '562': 'Extractor',
#  '563': 'blockclust',
#  '564': 'humann2_genefamilies_genus_level',
#  '565': 'ia_coordinates_of_roi',
#  '566': 'cummerbund_to_cuffdiff',
#  '567': 'fastq_to_tabular',
#  '568': 'proteomics_moff',
#  '569': 'datamash_ops',
#  '570': 'mothur_summary_single',
#  '571': 'fasta2tab',
#  '572': 'rbc_mirdeep2',
#  '573': 'table_annovar',
#  '574': 'mothur_amova',
#  '575': 'rseqc_geneBody_coverage',
#  '576': 'augustus',
#  '577': 'bcftools_consensus',
#  '578': 'melt',
#  '579': 'EMBOSS: fuzzpro38',
#  '580': 'nspdk_sparse',
#  '581': 'Add_a_column1',
#  '582': 'minfi_getbeta',
#  '583': 'meme_fimo',
#  '584': 'raceid_clustering',
#  '585': 'fastq_trimmer',
#  '586': 'tag_stat2',
#  '587': 'EMBOSS: seqret84',
#  '588': 'infernal_cmbuild',
#  '589': 'sklearn_svm_classifier',
#  '590': 'sklearn_nn_classifier',
#  '591': 'get_sequences',
#  '592': 'qiime_align_seqs',
#  '593': 'rgPicFixMate',
#  '594': 'Fetch Taxonomic Ranks',
#  '595': 'picard_ReorderSam',
#  '596': 'picard_BamIndexStats',
#  '597': 'Draw_phylogram',
#  '598': 'Show tail1',
#  '599': 'deeptools_plot_enrichment',
#  '600': 'cshl_awk_tool',
#  '601': 'smf_utils_find-boxes',
#  '602': 'cufflinks',
#  '603': 'pilon',
#  '604': 'tp_awk_tool',
#  '605': 'deeptools_heatmapper',
#  '606': 'CONVERTER_bed_gff_or_vcf_to_bigwig_0',
#  '607': 'QCCalculator',
#  '608': 'gatk_unified_genotyper',
#  '609': 'trimmomatic',
#  '610': 'deeptools_plot_fingerprint',
#  '611': 'fastq_filter',
#  '612': 'sed_stream_editor',
#  '613': 'react_cal_pipeline',
#  '614': 'mimodd_varextract',
#  '615': 'prokka',
#  '616': 'ChangeCase',
#  '617': 'modencode_peakcalling_macs2',
#  '618': 'gemini_actionable_mutations',
#  '619': 'tophat2',
#  '620': 'mothur_sub_sample',
#  '621': 'Summary_Statistics1',
#  '622': 'mimodd_varreport',
#  '623': 'meme_chip',
#  '624': 't_coffee',
#  '625': 'varscan_copynumber',
#  '626': 'find_in_reference',
#  '627': 'TextExporter',
#  '628': 'jbrowse',
#  '629': 'treebest_best',
#  '630': 'megablast_xml_parser',
#  '631': 'silac_analyzer',
#  '632': 'ggplot2_heatmap',
#  '633': 'hicexplorer_hicplotmatrix',
#  '634': 'picard_NormalizeFasta',
#  '635': 'mothur_cluster',
#  '636': 'CONVERTER_Bam_Bai_0',
#  '637': '__RELABEL_FROM_FILE__',
#  '638': 'cshl_fastx_trimmer',
#  '639': 'stringtie',
#  '640': 'tp_uniq_tool',
#  '641': 'mothur_nmds',
#  '642': 'picard_CollectRnaSeqMetrics',
#  '643': 'metaphlan2',
#  '644': 'viz_overlay_moving_and_fixed_image',
#  '645': 'ctb_remIons',
#  '646': 'metams_runGC',
#  '647': 'ggplot2_histogram',
#  '648': 'gatk2_base_recalibrator',
#  '649': 'samtools_bedcov',
#  '650': 'snpEff',
#  '651': 'uchime',
#  '652': 'sequence_content_trimmer',
#  '653': 'PicardInsertSize',
#  '654': 'NSPDK_candidateClust',
#  '655': 'ngsutils_bam_filter',
#  '656': 'sample_seqs',
#  '657': 'format_metaphlan2_output',
#  '658': 'seq_composition',
#  '659': 'ctb_compound_convert',
#  '660': 'remove_tail.py',
#  '661': 'Psortb',
#  '662': 'lastz_wrapper_2',
#  '663': 'rseqc_infer_experiment',
#  '664': 'ncbi_tblastn_wrapper',
#  '665': 'wsdl_hmdb',
#  '666': 'dexseq_count',
#  '667': 'mothur_count_groups',
#  '668': 'rnafold',
#  '669': 'hisat2',
#  '670': 'mothur_venn',
#  '671': 'cor2',
#  '672': 'cuffnorm',
#  '673': 'MzTabExporter',
#  '674': '__FLATTEN__',
#  '675': 'bedtools_shufflebed',
#  '676': 'mothur_heatmap_sim',
#  '677': 'IsobaricAnalyzer',
#  '678': 'peakcalling_macs',
#  '679': 'bctools_extract_alignment_ends',
#  '680': 'taxonomy_krona_chart',
#  '681': 'deeptools_compute_gc_bias',
#  '682': 'mothur_dist_shared',
#  '683': 'extract_bcs.py',
#  '684': 'mothur_pcoa',
#  '685': 'FROGS_affiliations_stat',
#  '686': 'megablast_wrapper',
#  '687': 'bedtools_coveragebed',
#  '688': 'FileMerger',
#  '689': 'blastxml_to_top_descr',
#  '690': 'samtools_stats',
#  '691': 'enhanced_bowtie_wrapper',
#  '692': 'secretbt2test',
#  '693': 'transpose',
#  '694': 'mothur_classify_seqs',
#  '695': 'plotly_regression_performance_plots',
#  '696': 'FeatureFinderMetabo',
#  '697': 'annotateMyIDs',
#  '698': 'Batch_correction',
#  '699': 'picard_CASM',
#  '700': 'secure_hash_message_digest',
#  '701': 'cuffmerge',
#  '702': 'mothur_merge_files',
#  '703': 'kraken',
#  '704': 'tp_unfold_column_tool',
#  '705': 'HighResPrecursorMassCorrector',
#  '706': 'export2graphlan',
#  '707': 'bedtools_slopbed',
#  '708': 'createInterval',
#  '709': 'cuffdiff',
#  '710': 'bamCoverage_deepTools',
#  '711': 'abims_xcms_xcmsSet',
#  '712': 'eukaryotic_ncbi_submission',
#  '713': 'snippy_core',
#  '714': 'mothur_tree_shared',
#  '715': 'tsne',
#  '716': 'filter_bed_on_splice_junctions',
#  '717': 'cshl_fastx_artifacts_filter',
#  '718': 'velvet',
#  '719': 'flye',
#  '720': 'mothur_taxonomy_to_krona',
#  '721': 'TrimByLength',
#  '722': 'metilene',
#  '723': 'vcf_filter',
#  '724': 'samtools_idxstats',
#  '725': 'ctb_online_data_fetch',
#  '726': 'gemini_comp_hets',
#  '727': 'mothur_classify_rf',
#  '728': 'CONVERTER_fastqgz_to_fastq',
#  '729': 'kraken-filter',
#  '730': 'methtools_destrand',
#  '731': '16Saligner',
#  '732': 'numeric_clustering',
#  '733': 'cshl_fastq_quality_boxplot',
#  '734': 'sklearn_searchcv',
#  '735': 'picard_SortSam',
#  '736': 'stacks_procrad',
#  '737': 'heinz_visualization',
#  '738': 'picard_SamToFastq',
#  '739': 'picard_FilterSamReads',
#  '740': 'abims_xcms_group',
#  '741': 'bg_sortmerna',
#  '742': 'gemini_interactions',
#  '743': 'FeatureLinkerUnlabeledQT',
#  '744': 'hicexplorer_hicsummatrices',
#  '745': 'cardinal_preprocessing',
#  '746': '__SORTLIST__',
#  '747': 'bedtools_multiintersectbed',
#  '748': 'FeatureLinkerUnlabeled',
#  '749': 'fastq_paired_end_deinterlacer',
#  '750': 'gemini_burden',
#  '751': 'fastq_paired_end_splitter',
#  '752': 'translate_bed_sequences',
#  '753': 'blastxml_to_tabular_selectable',
#  '754': 'gspan',
#  '755': 'MAF_To_Fasta1',
#  '756': 'get_subontology_from',
#  '757': 'rbc_rnacode',
#  '758': 'sort1',
#  '759': 'vcffilter',
#  '760': 'gops_intersect_1',
#  '761': 'msgfplus',
#  '762': 'dexseq_annotate',
#  '763': 'rmcontamination',
#  '764': '__MERGE_COLLECTION__',
#  '765': 'bedtools_annotatebed',
#  '766': 'EMBOSS: water107',
#  '767': 'XY_Plot_1',
#  '768': 'Cut1',
#  '769': 'ggplot_histogram',
#  '770': 'mothur_remove_groups',
#  '771': 'MultiplexResolver',
#  '772': 'gops_cluster_1',
#  '773': 'samtools_split',
#  '774': 'samtool_filter2',
#  '775': 'goenrichment',
#  '776': 'gops_join_1',
#  '777': 'Paste1',
#  '778': 'tophat',
#  '779': 'gff_to_sequence',
#  '780': 'ctb_remSmall',
#  '781': 'sam_pileup',
#  '782': 'mothur_metastats',
#  '783': 'gatk2_depth_of_coverage',
#  '784': 'blast_parser',
#  '785': 'mycrobiota-otutable_add_blast',
#  '786': 'bwa_wrapper',
#  '787': 'kallisto_quant',
#  '788': 'cardinal_combine',
#  '789': 'Nucleosome',
#  '790': 'varscan_mpileup',
#  '791': 'sklearn_ensemble',
#  '792': 'gffread',
#  '793': 'CONVERTER_gff_to_interval_index_0',
#  '794': 'deeptools_profiler',
#  '795': 'tmhmm2',
#  '796': 'msconvert_nix',
#  '797': 'r_correlation_matrix',
#  '798': 'signalp3',
#  '799': 'replace_column_with_key_value_file',
#  '800': 'collapse_dataset',
#  '801': 'ucsc-twobittofa',
#  '802': 'gatk_indel_realigner',
#  '803': '__UNZIP_COLLECTION__',
#  '804': 'dbbuilder',
#  '805': 'w4mclstrpeakpics',
#  '806': 'gemini_pathways',
#  '807': 'mothur_pre_cluster',
#  '808': 'cshl_sed_tool',
#  '809': 'gatk_realigner_target_creator',
#  '810': 'tp_tail_tool',
#  '811': 'gemini_annotate',
#  '812': 'bedtools_subtractbed',
#  '813': 'modencode_peakcalling_spp',
#  '814': 'IDMassAccuracy',
#  '815': 'graphclust_glob_report_no_align',
#  '816': 'column_remove_by_header',
#  '817': 'nn_classifier',
#  '818': 'mothur_parsimony',
#  '819': 'gtftobed12',
#  '820': 'bamleftalign',
#  '821': 'deeptools_computeMatrix',
#  '822': 'fastq_groomer',
#  '823': 'meme_psp_gen',
#  '824': 'gemini_db_info',
#  '825': 'infernal_cmstat',
#  '826': 'p_clip_peaks',
#  '827': 'bg_column_arrange_by_header',
#  '828': 'vegan_rarefaction',
#  '829': 'gemini_load',
#  '830': 'glimmer_not-knowlegde-based',
#  '831': 'edger',
#  '832': 'snpSift_filter',
#  '833': 'rsem_prepare_reference',
#  '834': 'venn_list',
#  '835': 'deeptools_plot_profile',
#  '836': 'blastxml_to_tabular',
#  '837': 'decoyfasta',
#  '838': 'preMloc',
#  '839': 'dt_profiler',
#  '840': 'umi_tools_group',
#  '841': 'bwameth',
#  '842': 'deeptools_plot_pca',
#  '843': 'gbk_to_orf',
#  '844': 'vcfsort',
#  '845': 'minfi_rset',
#  '846': 'vcfcombine',
#  '847': '16Sclassifier',
#  '848': 'ncbi_makeblastdb',
#  '849': 'cshl_fastq_to_fasta',
#  '850': 'MassCalculator',
#  '851': 'MapStatistics',
#  '852': 'bundle_collection',
#  '853': 'bed_to_bigBed',
#  '854': 'rgPicardMarkDups',
#  '855': 'peakachu',
#  '856': 'trinity',
#  '857': 'abims_xcms_summary',
#  '858': 'bedtools_unionbedgraph',
#  '859': 'bedtools_intersectBed',
#  '860': 'DatamashOps',
#  '861': 'deeptools_computeGCBias',
#  '862': 'rgweblogo3',
#  '863': 'sklearn_feature_selection',
#  '864': 'mass_spectrometry_imaging_classification',
#  '865': 'EMBOSS: tranalign100',
#  '866': 'valet',
#  '867': 'proteomics_search_tandem_1',
#  '868': 'vegan_diversity',
#  '869': 'deeptools_plot_heatmap',
#  '870': 'bedtools_bedtobam',
#  '871': 'quast',
#  '872': 'deeptools_bamFingerprint',
#  '873': 'plotly_parallel_coordinates_plot',
#  '874': 'gmx_solvate',
#  '875': '__ZIP_COLLECTION__',
#  '876': 'snpSift_geneSets',
#  '877': 'sam_bw_filter',
#  '878': 'htseq-count',
#  '879': 'gmx_setup',
#  '880': 'tp_sort_header_tool',
#  '881': 'hicexplorer_hicbuildmatrix',
#  '882': 'MapRTTransformer',
#  '883': 'sqlite_to_tabular',
#  '884': 'datamash_transpose',
#  '885': 'scaffold2fasta',
#  '886': 'ctb_change_title',
#  '887': 'nanoplot',
#  '888': 'tp_text_file_with_recurring_lines',
#  '889': 'gemini_query',
#  '890': 'paralyzer',
#  '891': 'tp_replace_in_line',
#  '892': 'mass_spectrometry_imaging_ion_images',
#  '893': 'mothur_unique_seqs',
#  '894': 'biosigner',
#  '895': 'w4mcorcov',
#  '896': 'rseqc_junction_saturation',
#  '897': 'genbank_to_gff',
#  '898': 'qiime_pick_open_reference_otus',
#  '899': 'FileConverter',
#  '900': 'viennarna_rnaplot',
#  '901': 'minfi_getM',
#  '902': 'bedtools_sortbed',
#  '903': 'CONVERTER_interval_to_bedstrict_0',
#  '904': 'locarna_multiple',
#  '905': 'cshl_grep_tool',
#  '906': 'XTandemAdapter',
#  '907': 'flexbar',
#  '908': 'mass_spectrometry_imaging_preprocessing',
#  '909': 'disco',
#  '910': 'Extract_RNA_seq_Evidence',
#  '911': 'mothur_phylotype',
#  '912': 'wolf_psort',
#  '913': 'nonpareil',
#  '914': 'resistome_analyzer',
#  '915': 'mycrobiota-krona-mothur',
#  '916': 'rarefaction_analyzer',
#  '917': 'EMBOSS: newseq59',
#  '918': 'hicexplorer_hicpca',
#  '919': 'bg_diamond',
#  '920': 'blockbuster',
#  '921': 'goslimmer',
#  '922': 'align_families',
#  '923': 'fastqc',
#  '924': 'vcffilter2',
#  '925': 'FROGS_preprocess',
#  '926': 'stacks_genotypes',
#  '927': 'gff_filter_by_attribute',
#  '928': 'vcf2pgSnp',
#  '929': 'cshl_find_and_replace',
#  '930': 'igvtools_count',
#  '931': 'muscle',
#  '932': 'bismark_bowtie2',
#  '933': 'selectsequencesfrommsa',
#  '934': 'abricate',
#  '935': 'sklear_numeric_clustering',
#  '936': 'wc_gnu',
#  '937': 'peakcalling_macs14',
#  '938': 'bedtools_bamtobed',
#  '939': 'gmx_em',
#  '940': 'rsem_calculate_expression',
#  '941': 'cd_hit_dup',
#  '942': 'picard_ARRG',
#  '943': 'cshl_word_list_grep',
#  '944': 'tp_tac',
#  '945': 'samtools_sort',
#  '946': 'mothur_make_contigs',
#  '947': 'MapAlignerPoseClustering',
#  '948': 'EMBOSS: geecee41',
#  '949': 'Convert characters1',
#  '950': 'metaphlan2krona',
#  '951': 'aggregate_scores_in_intervals2',
#  '952': 'FileFilter',
#  '953': 'heinz_bum',
#  '954': 'fgsea',
#  '955': 'hcluster_sg',
#  '956': 'hicexplorer_hicmergematrixbins',
#  '957': 'deeptools_compute_matrix_operations',
#  '958': 'humann2_regroup_table',
#  '959': 'mothur_remove_seqs',
#  '960': 'qiime_make_phylogeny',
#  '961': 'ruvseq',
#  '962': 'FidoAdapter',
#  '963': 'minfi_dmp',
#  '964': 'rbc_splitfasta',
#  '965': 'msconvert2_raw',
#  '966': 'velvetg_jgi',
#  '967': 'CONVERTER_fasta_to_fai',
#  '968': 'CONVERTER_bed_to_bgzip_0',
#  '969': 'featurecounts',
#  '970': 'TrimByN',
#  '971': 'mimodd_varcall'}

# %%
def verify_model(model, tool_sequence, labels, dictionary, reverse_dictionary, compatible_tools, topk=20, max_seq_len=25):
    tl_seq = tool_sequence.split(",")
    last_tool_name = reverse_dictionary[str(tl_seq[-1])]
    last_compatible_tools = compatible_tools[last_tool_name]
    sample = np.zeros(max_seq_len)
    for idx, tool_id in enumerate(tl_seq):
        sample[idx] = int(tool_id)
    sample_reshaped = np.reshape(sample, (1, max_seq_len))

    tool_sequence_names = [reverse_dictionary[str(tool_pos)] for tool_pos in tool_sequence.split(",")]
    print("Tool seq: %s" % ",".join(tool_sequence_names))

    # predict next tools for a test path
    prediction = model.predict(sample_reshaped, verbose=0)
    prediction = np.reshape(prediction, (prediction.shape[1],))
    prediction_pos = np.argsort(prediction, axis=-1)

    # get topk prediction
    topk_prediction_pos = prediction_pos[-topk:]
    topk_prediction_val = [np.round(prediction[pos] * 100, 2) for pos in topk_prediction_pos]

    # read tool names using reverse dictionary
    pred_tool_ids = [reverse_dictionary[str(tool_pos)] for tool_pos in topk_prediction_pos]
    actual_next_tool_ids = list(set(pred_tool_ids).intersection(set(last_compatible_tools.split(","))))      

    print()
    pred_tool_ids_sorted = dict()
    for (tool_pos, tool_pred_val) in zip(topk_prediction_pos, topk_prediction_val):
        tool_name = reverse_dictionary[str(tool_pos)]
        if tool_name in actual_next_tool_ids:
            pred_tool_ids_sorted[tool_name] = tool_pred_val
    pred_tool_ids_sorted = dict(sorted(pred_tool_ids_sorted.items(), key=lambda kv: kv[1], reverse=True))
    
    cls_wt = dict()
    usg_wt = dict()
    inv_wt = dict()
    ids_tools = dict()
    keys = list(pred_tool_ids_sorted.keys())
    for k in keys:
        try:
            cls_wt[k] = np.round(class_weights[str(data_dict[k])], 2)
            usg_wt[k] = np.round(usage_weights[k], 2)
            inv_wt[k] = np.round(inverted_weights[str(data_dict[k])], 2)
        except:
            continue
    print("Predicted tools: \n")
    print(pred_tool_ids_sorted)
    print()
    print("Class weights: \n")
    cls_wt = dict(sorted(cls_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(cls_wt)
    print()
    print("Usage weights: \n")
    usg_wt = dict(sorted(usg_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(usg_wt)
    print()
    total_usage_wt = np.mean(list(usg_wt.values()))
    print("Mean usage wt: %0.4f" % (total_usage_wt))
    print()
    print("Inverted weights: \n")
    inv_wt = dict(sorted(inv_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(inv_wt)
    for key in pred_tool_ids_sorted:
        ids_tools[key] = dictionary[key]
    print()
    print("Tool ids")
    print(ids_tools)
    print("======================================")
    return cls_wt, usg_wt, inv_wt, pred_tool_ids_sorted

topk = 10
tool_seq = "26" #,724,560,581,936,800,768,507,295,176,517,520
class_wt, usage_wt, inverse_wt, pred_tools = verify_model(model, tool_seq, "", dictionary, reverse_dictionary, compatibile_tools, topk)
# Out:
# Tool seq: FeatureFinderMultiplex
#
# Predicted tools:
#
# {}
#
# Class weights:
#
# {}
#
# Usage weights:
#
# {}
#
# Mean usage wt: nan
#
# Inverted weights:
#
# {}
#
# Tool ids
# {}
# ======================================

# %%
list_cls_wt = list()
list_usage_wt = list()
list_pred_wt = list()
list_inv_wt = list()
division_pt = int(len(pred_tools) / 2)

for tool in pred_tools:
    list_pred_wt.append(pred_tools[tool])
    #try:
    list_inv_wt.append(inverse_wt[tool])
    list_usage_wt.append(usage_wt[tool])
    #except:
    #list_inv_wt.append(1)

def plot_scatter(y_val, title, xlabel, ylabel):
    x_val = range(1, len(y_val) + 1)
    plt.figure(figsize=(8, 8))
    plt.plot(x_val[:division_pt], y_val[:division_pt], 'ro')
    plt.plot(x_val[division_pt:], y_val[division_pt:], 'b^')
    plt.xlabel(xlabel, size=size_label)
    plt.ylabel(ylabel, size=size_label)
    plt.legend([("First top-%s" % str(division_pt)), ("Next top-%s" % str(division_pt))])
    plt.title(title, size=size_title)
    plt.grid(True)
    plt.show()

plot_scatter(list_usage_wt, "Usage weights for tools", "Number of tools", "Class weights")
#plot_scatter(ave_prediction_weights, ave_usage_weights, "Prediction vs usage weights", "Prediction scores", "Usage weights")
#plot_scatter(ave_prediction_weights, ave_inverted_weights, "Prediction vs inverted weights", "Prediction scores", "Inverted weights")
