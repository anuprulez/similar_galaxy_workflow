# %%
import numpy as np
import json
import warnings
import operator

import h5py
from keras.models import model_from_json
from keras import backend as K

from matplotlib import pyplot as plt

warnings.filterwarnings("ignore")

size_title = 18
size_label = 14
n_pred = 2

base_path = "data/evaluate_log_usage/" # 3_similar_galaxy_workflow

path_data_dict = base_path + "data_dict.txt"
path_inverted_wt = base_path + "inverted_weights.txt"
path_usage_wt = base_path + "usage_prediction.txt"
path_class_wt = base_path + "class_weights.txt"
path_test_data = base_path + "test_paths_dict.txt"
model_path = base_path + "trained_model.hdf5"

def read_file(file_path):
    with open(file_path, 'r') as data_file:
        data = json.loads(data_file.read())
    return data

class_weights = read_file(path_class_wt)
usage_weights = read_file(path_usage_wt)
inverted_weights = read_file(path_inverted_wt)
data_dict = read_file(path_data_dict)

def create_model(model_path):
    trained_model = h5py.File(model_path, 'r')
    model_config = json.loads(trained_model.get('model_config').value)
    loaded_model = model_from_json(model_config)
    dictionary = json.loads(trained_model.get('data_dictionary').value)
    compatibile_tools = json.loads(trained_model.get('compatible_tools').value)
    reverse_dictionary = dict((str(v), k) for k, v in dictionary.items())
    model_weights = list()
    weight_ctr = 0
    while True:
        try:
            d_key = "weight_" + str(weight_ctr)
            weights = trained_model.get(d_key).value
            model_weights.append(weights)
            weight_ctr += 1
        except Exception as exception:
            break
    # set the model weights
    loaded_model.set_weights(model_weights)
    return loaded_model, dictionary, reverse_dictionary, compatibile_tools

model, dictionary, reverse_dictionary, compatibile_tools = create_model(model_path)

# %%
reverse_dictionary
# Out:
# {'1': 'diffbind-embl',
#  '2': 'velvet',
#  '3': 'term_id_vs_term_def',
#  '4': 'wig_to_bigWig',
#  '5': 'qiime_align_seqs',
#  '6': 'modencode_peakcalling_macs2',
#  '7': 'gmx_setup',
#  '8': 'tp_tail_tool',
#  '9': 'cor2',
#  '10': 'sklear_numeric_clustering',
#  '11': 'replace_column_with_key_value_file',
#  '12': 'Extract_features1',
#  '13': 'seurat',
#  '14': 'roary',
#  '15': 'eden_sequence_converter',
#  '16': 'cshl_find_and_replace',
#  '17': 'unipept',
#  '18': 'infernal_cmstat',
#  '19': 'bg_statistical_hypothesis_testing',
#  '20': 'FeatureLinkerUnlabeledQT',
#  '21': 'mothur_make_biom',
#  '22': 'gatk2_variant_annotator',
#  '23': 'tp_find_and_replace',
#  '24': 'get_sequences',
#  '25': 'XTandemAdapter',
#  '26': 'piranha',
#  '27': 'cshl_fastx_reverse_complement',
#  '28': 'myrimatch',
#  '29': 'featurecounts',
#  '30': 'samtools_rmdup',
#  '31': 'metaphlan2',
#  '32': 'cardinal_mz_images',
#  '33': 'tp_easyjoin_tool',
#  '34': 'ExtractFASTAfromFASTQ',
#  '35': 'qiime_pick_rep_set',
#  '36': 'cufflinks_prok',
#  '37': 'ggplot_point',
#  '38': 'ctb_compound_convert',
#  '39': 'QCCalculator',
#  '40': 'picard_EstimateLibraryComplexity',
#  '41': 'ngsutils_bam_filter',
#  '42': 'bedtools_bamtobed',
#  '43': 'qiime_assign_taxonomy',
#  '44': 'bg_find_subsequences',
#  '45': 'picard_MergeSamFiles',
#  '46': 'minfi_getanno',
#  '47': 'sample_seqs',
#  '48': 'mothur_heatmap_bin',
#  '49': 'bowtie_wrapper',
#  '50': 'ctb_online_data_fetch',
#  '51': 'gatk2_variant_apply_recalibration',
#  '52': 'cuffdiff',
#  '53': 'deeptools_plot_pca',
#  '54': 'bedtools_intersectBed',
#  '55': 'mothur_remove_seqs',
#  '56': 'tophat_fusion_post',
#  '57': 'Determine_BC',
#  '58': 'mothur_sub_sample',
#  '59': 'cshl_multijoin',
#  '60': 'ProteinQuantifier',
#  '61': 'htseq-count',
#  '62': 'barchart_gnuplot',
#  '63': 'tp_sort_rows',
#  '64': 'sqlite_to_tabular',
#  '65': 'glimmer_knowlegde-based',
#  '66': 'tophat2',
#  '67': 'velvetoptimiser',
#  '68': 'EMBOSS: revseq82',
#  '69': 'fgsea',
#  '70': 'rbc_rnacode',
#  '71': 'CONVERTER_Bam_Bai_0',
#  '72': 'mothur_trim_seqs',
#  '73': 'gemini_interactions',
#  '74': 'gatk2_realigner_target_creator',
#  '75': 'resistome_analyzer',
#  '76': 'MapRTTransformer',
#  '77': 'plotly_ml_performance_plots',
#  '78': 'hisat',
#  '79': 'TextExporter',
#  '80': 'deeptools_plot_profile',
#  '81': 'vcfsort',
#  '82': 'tp_sed_tool',
#  '83': 'Summary_Statistics1',
#  '84': 'augustus',
#  '85': 'mothur_chimera_uchime',
#  '86': 'cshl_grep_tool',
#  '87': 'w4mclstrpeakpics',
#  '88': 'gtf2bedgraph',
#  '89': 'ia_coordinates_of_roi',
#  '90': 'extract_aln_ends.py',
#  '91': 'tp_text_file_with_recurring_lines',
#  '92': 'ConsensusID',
#  '93': 'mothur_parsimony',
#  '94': 'cardinal_quality_report',
#  '95': 'mimodd_map',
#  '96': 'EMBOSS: tranalign100',
#  '97': 'IsobaricAnalyzer',
#  '98': 'picard_SamToFastq',
#  '99': 'cardinal_spectra_plots',
#  '100': 'picard_FixMateInformation',
#  '101': 'uparse',
#  '102': 'meme_chip',
#  '103': 'velvetg_jgi',
#  '104': 'glimmer_build-icm',
#  '105': 'bam_to_bigwig',
#  '106': 'addName',
#  '107': 'gmx_npt',
#  '108': 'segemehl',
#  '109': 'umi_tools_dedup',
#  '110': 'rseqc_bam_stat',
#  '111': 'metams_runGC',
#  '112': 'deeptools_profiler',
#  '113': 'PicardASMetrics',
#  '114': 'gops_merge_1',
#  '115': 'qiime_pick_otus',
#  '116': 'samtools_flag_filter',
#  '117': 'nanoplot',
#  '118': 'Remove_ending',
#  '119': 'samtool_filter2',
#  '120': 'meme_meme',
#  '121': 'bg_sortmerna',
#  '122': 'bwa',
#  '123': 'smooth_running_window',
#  '124': 'gtf_filter_by_attribute_values_list',
#  '125': 'Extract_RNA_seq_Evidence',
#  '126': 'iReport',
#  '127': 'stringtie',
#  '128': 'ncbi_blastx_wrapper',
#  '129': 'sklearn_build_pipeline',
#  '130': 'enhanced_bowtie_wrapper',
#  '131': 'flexbar_split_RR_bcs',
#  '132': 'Interval_Maf_Merged_Fasta2',
#  '133': 'mycrobiota-qc-report',
#  '134': '16Sclassifier',
#  '135': 'tp_sort_header_tool',
#  '136': 'heatmapper_deepTools',
#  '137': 'deeptools_bamCoverage',
#  '138': 'qiime_pick_closed_reference_otus',
#  '139': 'EMBOSS: seqret84',
#  '140': 'w4mcorcov',
#  '141': 'vcffilter2',
#  '142': 'tp_sorted_uniq',
#  '143': '__SORTLIST__',
#  '144': 'deeptools_computeMatrix',
#  '145': 'limma_voom',
#  '146': 'blockbuster',
#  '147': 'PeptideIndexer',
#  '148': 'mimodd_vcf_filter',
#  '149': 'blastxml_to_top_descr',
#  '150': 'cummeRbund',
#  '151': 'minfi_ppfun',
#  '152': 'MzTabExporter',
#  '153': 'IDMerger',
#  '154': 'umi_tools_count',
#  '155': 'minfi_dropsnp',
#  '156': 'cardinal_segmentations',
#  '157': 'tp_awk_tool',
#  '158': 'mothur_pre_cluster',
#  '159': 'methtools_calling',
#  '160': 'mycrobiota-make-multi-otutable',
#  '161': 'datamash_ops',
#  '162': 'stacks_refmap',
#  '163': 'valet',
#  '164': 'samtools_slice_bam',
#  '165': 'CONVERTER_bed_gff_or_vcf_to_bigwig_0',
#  '166': 'sort1',
#  '167': 'graphclust_glob_report_no_align',
#  '168': 'metaspades',
#  '169': 'mass_spectrometry_imaging_ion_images',
#  '170': 'preMloc',
#  '171': 'fastq_quality_trimmer',
#  '172': 'mothur_remove_lineage',
#  '173': 'transdecoder',
#  '174': 'quast',
#  '175': 'createInterval',
#  '176': 'minfi_mset',
#  '177': 'DecoyDatabase',
#  '178': 'varscan_mpileup',
#  '179': 'abims_xcms_fillPeaks',
#  '180': 'ncbi_rpsblast_wrapper',
#  '181': 'rmcontamination',
#  '182': 'proteomics_search_peptide_prophet_1',
#  '183': 'get_child_terms',
#  '184': 'abims_xcms_group',
#  '185': 'snpSift_annotate',
#  '186': 'ruvseq',
#  '187': 'mothur_make_shared',
#  '188': 'flexbar_no_split',
#  '189': 'chipsequtil_maptoknowngenes',
#  '190': 'CONVERTER_sam_to_unsorted_bam',
#  '191': 'EMBOSS: fuzztran39',
#  '192': 'column_remove_by_header',
#  '193': 'gatk_indel_realigner',
#  '194': 'ProteinInference',
#  '195': 're_he_maldi_image_registration',
#  '196': 'modencode_peakcalling_spp',
#  '197': 'picard_MarkDuplicatesWithMateCigar',
#  '198': 'minfi_getM',
#  '199': '__RELABEL_FROM_FILE__',
#  '200': 'macs2_bdgcmp',
#  '201': 'EMBOSS: extractseq35',
#  '202': 'FROGS_affiliations_stat',
#  '203': 'CometAdapter',
#  '204': 'gops_intersect_1',
#  '205': 'samtools_mpileup',
#  '206': 'velveth_jgi',
#  '207': 'meme_psp_gen',
#  '208': 'dbbuilder',
#  '209': 'sailfish',
#  '210': 'gemini_de_novo',
#  '211': 'lca1',
#  '212': 'peakcalling_macs14',
#  '213': 'heatmap2',
#  '214': 'sam_pileup',
#  '215': 'gffcompare',
#  '216': 'kraken-translate',
#  '217': 'IDMapper',
#  '218': 'wc_gnu',
#  '219': 'bed2gff1',
#  '220': 'cd_hit_dup',
#  '221': 'heinz',
#  '222': 'mass_spectrometry_imaging_mzplots',
#  '223': 'deeptools_correct_gc_bias',
#  '224': 'krona-text',
#  '225': '__FILTER_FROM_FILE__',
#  '226': 'bedtools_intersectbed',
#  '227': 'gemini_recessive_and_dominant',
#  '228': 'sed_stream_editor',
#  '229': 'NFS_transfer',
#  '230': 'samtools_filter',
#  '231': 'nonpareil',
#  '232': 'EMBOSS: textsearch98',
#  '233': 'picard_ValidateSamFile',
#  '234': 'samtools_sort',
#  '235': 'minimap2',
#  '236': 'CONVERTER_interval_to_bedstrict_0',
#  '237': 'cutadapt',
#  '238': 'peakcalling_macs',
#  '239': 'snippy',
#  '240': 'bedtools_genomecoveragebed',
#  '241': 'correctGCBias',
#  '242': 'regex_replace',
#  '243': 'tp_split_on_column',
#  '244': 'sklearn_nn_classifier',
#  '245': 'gff_filter_by_attribute',
#  '246': 'DatamashTranspose',
#  '247': 'Grep1',
#  '248': 'idpqonvert',
#  '249': 'gops_basecoverage_1',
#  '250': 'racon',
#  '251': 'translate_bed_sequences',
#  '252': 'cuffquant',
#  '253': 'FileInfo',
#  '254': 'stacks_denovomap',
#  '255': 'bedtools_bedtobam',
#  '256': 'smf_utils_fix-fasta-headers',
#  '257': 'fastq_paired_end_joiner',
#  '258': 'mothur_nmds',
#  '259': 'FastTree',
#  '260': 'gafa',
#  '261': 'ip_projective_transformation_points',
#  '262': '__FILTER_FAILED_DATASETS__',
#  '263': 'treebest_best',
#  '264': 'hicexplorer_hicsummatrices',
#  '265': 'sam_merge2',
#  '266': 'CONVERTER_gff_to_interval_index_0',
#  '267': 'sickle',
#  '268': 'msconvert3_raw',
#  '269': 'spades',
#  '270': 'allele_counts_1',
#  '271': 'sklearn_searchcv',
#  '272': 'ggplot2_heatmap',
#  '273': 'Filter1',
#  '274': 'openms_id_mapper',
#  '275': 'dexseq_annotate',
#  '276': 'annotatemyids',
#  '277': 'snippy_core',
#  '278': 'format_metaphlan2_output',
#  '279': 'mothur_rarefaction_single',
#  '280': 'maldi_quant_preprocessing',
#  '281': 'EMBOSS: fuzzpro38',
#  '282': 'humann2',
#  '283': 'pilon',
#  '284': 'picard_CASM',
#  '285': 'rseqc_read_duplication',
#  '286': 'cshl_fastq_to_fasta',
#  '287': 'circgraph',
#  '288': 'w4mclassfilter',
#  '289': 'picard_SortSam',
#  '290': 'hgv_david',
#  '291': 'sklearn_svm_classifier',
#  '292': 'locarna_best_subtree',
#  '293': 'rseqc_geneBody_coverage',
#  '294': 'mothur_remove_groups',
#  '295': 'RNAlien',
#  '296': 'group_humann2_uniref_abundances_to_go',
#  '297': 'CONVERTER_interval_to_bgzip_0',
#  '298': 'HighResPrecursorMassCorrector',
#  '299': 'deeptools_compute_matrix_operations',
#  '300': 'picard_NormalizeFasta',
#  '301': 'secretbt2test',
#  '302': 'cuffmerge',
#  '303': 'bamCoverage_deepTools',
#  '304': 'gmx_solvate',
#  '305': 'cshl_sed_tool',
#  '306': 'PeakPickerHiRes',
#  '307': 'mothur_make_contigs',
#  '308': 'FileMerger',
#  '309': 'Nucleosome',
#  '310': 'viennarna_rnaplot',
#  '311': 'EMBOSS: geecee41',
#  '312': 'fastq_paired_end_splitter',
#  '313': 'cmv',
#  '314': 'gatk2_variant_filtration',
#  '315': 'deeptools_bigwigCompare',
#  '316': 'umi_tools_whitelist',
#  '317': 'shovill',
#  '318': 'merge_pcr_duplicates.py',
#  '319': 'fastq_manipulation',
#  '320': 'uchime',
#  '321': 'vcf2tsv',
#  '322': 'ConsensusMapNormalizer',
#  '323': 'Digestor',
#  '324': 'Convert characters1',
#  '325': 'bedtools_sortbed',
#  '326': 'ggplot2_heatmap2',
#  '327': 'prokaryotic_ncbi_submission',
#  '328': 'gmx_em',
#  '329': 'bedtools_map',
#  '330': '__MERGE_COLLECTION__',
#  '331': 'ggplot2_point',
#  '332': 'bedtools_slopbed',
#  '333': 'bamleftalign',
#  '334': 'fasta2tab',
#  '335': 'deeptools_compute_gc_bias',
#  '336': 'rna_star',
#  '337': 'fastq_trimmer',
#  '338': 'cshl_fastx_barcode_splitter',
#  '339': 'vcfvcfintersect',
#  '340': 'wiggle2simple1',
#  '341': 'viz_overlay_moving_and_fixed_image',
#  '342': 'bedtools_getfastabed',
#  '343': 'mothur_corr_axes',
#  '344': 'rsem_calculate_expression',
#  '345': 'vcfannotate',
#  '346': 'cuffnorm',
#  '347': 'react_cal_pipeline',
#  '348': 'CONVERTER_bed_to_bgzip_0',
#  '349': 'hgv_linkToGProfile',
#  '350': 'Grouping1',
#  '351': 'picard_CollectRnaSeqMetrics',
#  '352': 'TrimPrimer',
#  '353': 'bctools_remove_spurious_events',
#  '354': 'gatk2_variant_recalibrator',
#  '355': 'sam2interval',
#  '356': 'raceid_main',
#  '357': 'hisat2',
#  '358': 'gops_coverage_1',
#  '359': 'hicexplorer_hictransform',
#  '360': 'FeatureFinderMultiplex',
#  '361': 'bwameth',
#  '362': 'ctb_change_title',
#  '363': 'humann2_regroup_table',
#  '364': 'mycrobiota-split-multi-otutable',
#  '365': 'mothur_get_groups',
#  '366': 'interproscan',
#  '367': 'flanking_features_1',
#  '368': 'rnafold',
#  '369': 'cshl_fastx_collapser',
#  '370': 'openms_id_file_converter',
#  '371': 'snpfinder',
#  '372': 'ete_homology_classifier',
#  '373': 'tabular_to_fastq',
#  '374': 'computeMatrix',
#  '375': 'decoyfasta',
#  '376': 'p_clip_peaks',
#  '377': 'bg_column_arrange_by_header',
#  '378': 'dunovo',
#  '379': 'heatmapper',
#  '380': 'ete_genetree_splitter',
#  '381': 'samtools_idxstats',
#  '382': 'methtools_tiling',
#  '383': 'ChooseTag',
#  '384': 'stacks_procrad',
#  '385': 'Extract genomic DNA 1',
#  '386': 'deeptools_plot_enrichment',
#  '387': 'flye',
#  '388': 'vcf_filter',
#  '389': 'random_lines1',
#  '390': 'mimodd_varextract',
#  '391': 'rbc_mafft',
#  '392': 'mcClust',
#  '393': 'MSGFPlusAdapter',
#  '394': 'Cut1',
#  '395': 'mothur_cluster_split',
#  '396': 'cshl_fastq_quality_boxplot',
#  '397': 'deeptools_multi_bigwig_summary',
#  '398': 'picard_CollectWgsMetrics',
#  '399': '__FLATTEN__',
#  '400': 'snpEff_download',
#  '401': 'raceid_clustering',
#  '402': 'extract_bcs.py',
#  '403': 'gemini_annotate',
#  '404': 'query_tabular',
#  '405': 'lfq_protein_quant',
#  '406': 'rbc_splitfasta',
#  '407': 'collection_column_join',
#  '408': 'lastz_wrapper_2',
#  '409': 'gffread',
#  '410': 'make_families',
#  '411': 'filtlong',
#  '412': 'mothur_summary_seqs',
#  '413': 'hicexplorer_hicfindtads',
#  '414': 'porechop',
#  '415': 'mothur_pcoa',
#  '416': 'cshl_fastx_renamer',
#  '417': 'minfi_maptogenome',
#  '418': 'aragorn_trna',
#  '419': 'vcfselectsamples',
#  '420': 'pileometh',
#  '421': 'qiime_make_phylogeny',
#  '422': 'heinz_bum',
#  '423': 'ncbi_makeblastdb',
#  '424': 'addValue',
#  '425': 'msconvert_nix',
#  '426': 'numeric_clustering',
#  '427': 'peptide_shaker',
#  '428': 'align_families',
#  '429': 'IDFileConverter',
#  '430': 'vsearch_dereplication',
#  '431': 'vcftools_annotate',
#  '432': 'bcftools_call',
#  '433': 'cast',
#  '434': 'Paste1',
#  '435': 'tp_tac',
#  '436': 'EMBOSS: wordcount109',
#  '437': 'bedtools_genomecoveragebed_bedgraph',
#  '438': 'cshl_fastx_trimmer',
#  '439': 'je_demultiplex',
#  '440': 'viennarna_rnaalifold',
#  '441': 'minfi_methcpg',
#  '442': 'FalseDiscoveryRate',
#  '443': 'idpassemble',
#  '444': 'bg_uniq',
#  '445': '16Saligner',
#  '446': 'hicexplorer_hicbuildmatrix',
#  '447': 'bam_to_sam',
#  '448': 'hicexplorer_hicmergematrixbins',
#  '449': 'picard_BamIndexStats',
#  '450': 'TrimByN',
#  '451': 'search_gui',
#  '452': 'bctools_extract_alignment_ends',
#  '453': 'mothur_metastats',
#  '454': 'mothur_phylotype',
#  '455': 'Draw_phylogram',
#  '456': 'metaphlan2krona',
#  '457': 'mergeCols1',
#  '458': 'mass_spectrometry_imaging_filtering',
#  '459': 'fasplit',
#  '460': 'heinz_scoring',
#  '461': 'seq_filter_by_mapping',
#  '462': 'ctb_filter',
#  '463': 'tp_replace_in_column',
#  '464': 'deeptools_bamFingerprint',
#  '465': 'ChangeCase',
#  '466': 'gatk2_base_recalibrator',
#  '467': 'naive_variant_caller',
#  '468': 'picard_CollectInsertSizeMetrics',
#  '469': 'length_and_gc_content',
#  '470': 'bedtools_annotatebed',
#  '471': 'sklearn_feature_selection',
#  '472': 'nn_classifier',
#  '473': 'deeptools_correctGCBias',
#  '474': 'trim_galore',
#  '475': 'methtools_filter',
#  '476': 'bcftools_view',
#  '477': 'bedtools_multiintersectbed',
#  '478': 'biosigner',
#  '479': 'join_files_on_column_fuzzy',
#  '480': 'FeatureFinderMetabo',
#  '481': 'bg_diamond',
#  '482': 'mycrobiota-otutable_add_blast',
#  '483': 'qiime_validate_mapping_file',
#  '484': 'gops_cluster_1',
#  '485': 'tp_uniq_tool',
#  '486': 'gff2bed1',
#  '487': 'cufflinks',
#  '488': 'bed_to_bigwig',
#  '489': 'datamash_transpose',
#  '490': 'cshl_fastx_clipper',
#  '491': 'raceid_inspecttrajectory',
#  '492': 'disco',
#  '493': 'qiime_count_seqs',
#  '494': 'CONVERTER_bedgraph_to_bigwig',
#  '495': 'CONVERTER_fasta_to_fai',
#  '496': 'CONVERTER_fastqgz_to_fastq',
#  '497': 'abims_CAMERA_annotateDiffreport',
#  '498': 'find_in_reference',
#  '499': 'rseqc_bam2wig',
#  '500': 'Extractor',
#  '501': 'bedtools_subtractbed',
#  '502': 'SequenceCoverageCalculator',
#  '503': 'MassCalculator',
#  '504': 'hgv_snpFreq',
#  '505': 'je_markdupes',
#  '506': 'fastq_filter',
#  '507': 'deseq2',
#  '508': 'fragmenter',
#  '509': 'cshl_uniq_tool',
#  '510': 'vcfflatten2',
#  '511': 'gatk2_unified_genotyper',
#  '512': 'hmmer_hmmsearch',
#  '513': 'bcftools_consensus',
#  '514': 'hcluster_sg',
#  '515': 'bam-filter',
#  '516': 'fasta_compute_length',
#  '517': 'blast_parser',
#  '518': 'iuc_pear',
#  '519': 'Heatmap',
#  '520': 'bedtools_complementbed',
#  '521': 'vcftools_merge',
#  '522': 'picard_MarkDuplicates',
#  '523': 'blast2go',
#  '524': 'plotly_regression_performance_plots',
#  '525': 'gemini_burden',
#  '526': 'gff_to_sequence',
#  '527': 'graphclust_aggregate_alignments',
#  '528': 'gmx_md',
#  '529': 't2t_report',
#  '530': 'muscle',
#  '531': 'FROGS_preprocess',
#  '532': 'idpquery',
#  '533': 'Btrim64',
#  '534': 'combine_metaphlan2_humann2',
#  '535': 'gtftobed12',
#  '536': 'bedtools_multicovtbed',
#  '537': 'mass_spectrometry_imaging_combine',
#  '538': 'flexbar_split_RYYR_bcs',
#  '539': 'pileup_interval',
#  '540': 'FROGS_remove_chimera',
#  '541': 'selectsequencesfrommsa',
#  '542': 'abims_xcms_xcmsSet',
#  '543': 'tp_cut_tool',
#  '544': 'mass_spectrometry_imaging_qc',
#  '545': 'FeatureFinderCentroided',
#  '546': 'cmFinder',
#  '547': 'tp_cat',
#  '548': 'metaphlan_hclust_heatmap',
#  '549': 'goseq',
#  '550': 'gemini_load',
#  '551': 'samtools_stats',
#  '552': 'fastq_to_tabular',
#  '553': 'deeptools_bamCorrelate',
#  '554': 'MultiplexResolver',
#  '555': 'FROGS_affiliation_OTU',
#  '556': 'sequence_content_trimmer',
#  '557': 'FROGS_filters',
#  '558': 'gops_join_1',
#  '559': 'cshl_fasta_formatter',
#  '560': 'bedtools_windowbed',
#  '561': 'bedtools_intersectbed_bam',
#  '562': 'deeptools_plot_heatmap',
#  '563': 'hicexplorer_hicplotmatrix',
#  '564': 'gops_subtract_1',
#  '565': 'mimodd_varreport',
#  '566': 'rgPicardMarkDups',
#  '567': 'signalp3',
#  '568': 'tp_replace_in_line',
#  '569': 'tp_head_tool',
#  '570': 'kraken-report',
#  '571': 'blastxml_to_tabular',
#  '572': 'rsem_prepare_reference',
#  '573': 'IDMassAccuracy',
#  '574': 'deeptools_bigwig_compare',
#  '575': 'graphlan_annotate',
#  '576': 'fastq_to_fasta_python',
#  '577': 'Psortb',
#  '578': 'snpeff_to_peptides',
#  '579': 'Show beginning1',
#  '580': 'rseqc_inner_distance',
#  '581': 'mothur_count_groups',
#  '582': 'mothur_taxonomy_to_krona',
#  '583': 'mothur_count_seqs',
#  '584': 'samtools_split',
#  '585': 'ncbi_blastn_wrapper',
#  '586': 'bctools_extract_crosslinked_nucleotides',
#  '587': 'ggplot_histogram',
#  '588': 'edger',
#  '589': 'bismark_bowtie',
#  '590': 'tp_grep_tool',
#  '591': 'smf_utils_find-boxes',
#  '592': 'smf_utils_filter-by-energy',
#  '593': 'Datamash',
#  '594': 'bedtools_coveragebed',
#  '595': 'mz_to_sqlite',
#  '596': 'dt_profiler',
#  '597': 'comp1',
#  '598': 'hcluster_sg_parser',
#  '599': 'igvtools_count',
#  '600': 'EMBOSS: getorf42',
#  '601': 'msconvert2_raw',
#  '602': 'picard_CleanSam',
#  '603': 'smf_utils_estimate-energy',
#  '604': 'silac_analyzer',
#  '605': 'rarefaction',
#  '606': 'vcf2pgSnp',
#  '607': 'ncbi_blastp_wrapper',
#  '608': 'mothur_screen_seqs',
#  '609': 'stringtie_merge',
#  '610': 'qiime_pick_open_reference_otus',
#  '611': 'mothur_chimera_vsearch',
#  '612': 'gatk_unified_genotyper',
#  '613': 'FeatureLinkerUnlabeledKD',
#  '614': 'ctb_chemfp_mol2fps',
#  '615': 'FidoAdapter',
#  '616': 'meme_dreme',
#  '617': 'mass_spectrometry_imaging_classification',
#  '618': 'rnaz',
#  '619': 'vcffixup',
#  '620': 'mass_spectrometry_imaging_preprocessing',
#  '621': 'rarefaction_analyzer',
#  '622': 'infernal_cmsearch',
#  '623': 'hicexplorer_hicplottads',
#  '624': 'unicycler',
#  '625': 'antismash',
#  '626': 'rgweblogo3',
#  '627': 'bandage_image',
#  '628': 'idr-embl',
#  '629': 'bg_protein_properties',
#  '630': 'gatk2_indel_realigner',
#  '631': 'rseqc_junction_saturation',
#  '632': 'remove_tail.py',
#  '633': 'cshl_princeton_fastx_barcode_splitter',
#  '634': 'humann2_renorm_table',
#  '635': 'Batch_correction',
#  '636': 'fastq_dump',
#  '637': 'gemini_pathways',
#  '638': 'flexbar',
#  '639': 'mothur_heatmap_sim',
#  '640': 'gemini_windower',
#  '641': '__UNZIP_COLLECTION__',
#  '642': 'bamCompare_deepTools',
#  '643': 'cshl_awk_replace_in_column',
#  '644': 'minfi_read450k',
#  '645': 'eukaryotic_ncbi_submission',
#  '646': 'tp_unfold_column_tool',
#  '647': 'picard_ARRG',
#  '648': 'deeptools_bamCompare',
#  '649': 'bowtie2',
#  '650': 'gspan',
#  '651': 'bismark_bowtie2',
#  '652': 'map_peptides_to_bed',
#  '653': 'TrimByLength',
#  '654': 'rbc_mirdeep2_quantifier',
#  '655': 'r_correlation_matrix',
#  '656': 'cummerbund_to_cuffdiff',
#  '657': 'picard_FilterSamReads',
#  '658': 'mothur_dist_shared',
#  '659': 'rm_spurious_events.py',
#  '660': 'meme_fimo',
#  '661': 'flexbardsc',
#  '662': 'MAF_To_Fasta1',
#  '663': 'deeptools_bam_coverage',
#  '664': 'mothur_get_oturep',
#  '665': 'EMBOSS: newseq59',
#  '666': 'blastxml_to_tabular_selectable',
#  '667': 'methtools_plot',
#  '668': 'gatk2_reduce_reads',
#  '669': 'taxonomy_krona_chart',
#  '670': 'pynast',
#  '671': 'abims_xcms_summary',
#  '672': 'MapStatistics',
#  '673': 'w4mjoinpn',
#  '674': 'raceid_inspectclusters',
#  '675': 'metilene',
#  '676': 'nspdk_sparse',
#  '677': 'proteomics_search_tandem_1',
#  '678': 'aggregate_scores_in_intervals2',
#  '679': 'NSPDK_candidateClust',
#  '680': 'pileup_parser',
#  '681': 'fastq_join',
#  '682': 'chipseeker',
#  '683': 'umi_tools_group',
#  '684': '__APPLY_RULES__',
#  '685': 'get_subontology_from',
#  '686': 'Flash',
#  '687': 'cshl_easyjoin',
#  '688': 'Multivariate',
#  '689': 'sklearn_ensemble',
#  '690': 'egsea',
#  '691': 'freebayes',
#  '692': 'mimodd_varcall',
#  '693': 'mothur_merge_files',
#  '694': 'heinz_visualization',
#  '695': 'bundle_collection',
#  '696': 'samtools_calmd',
#  '697': 'IDFilter',
#  '698': 'bedtools_genomecoveragebed_histogram',
#  '699': 'CONVERTER_bed_to_gff_0',
#  '700': 'vcffilter',
#  '701': 'seq_filter_by_id',
#  '702': 'seq_composition',
#  '703': 'mothur_cluster',
#  '704': 'deeptools_computeGCBias',
#  '705': 'cshl_word_list_grep',
#  '706': 'charts',
#  '707': 'deeptools_multi_bam_summary',
#  '708': 'bams2ratio',
#  '709': 'secure_hash_message_digest',
#  '710': 'megablast_wrapper',
#  '711': 'varscan_copynumber',
#  '712': 'filter_by_fasta_ids',
#  '713': 'mothur_get_seqs',
#  '714': 'ctb_silicos_qed',
#  '715': 'pieplots_macs',
#  '716': 'mothur_amova',
#  '717': 'abricate',
#  '718': 'ggplot2_histogram',
#  '719': 'ctb_simsearch',
#  '720': 'rbc_mirdeep2',
#  '721': 'snpSift_dbnsfp_generic',
#  '722': 'Show tail1',
#  '723': 'rbc_mirdeep2_mapper',
#  '724': 'ncbi_tblastn_wrapper',
#  '725': 'Univariate',
#  '726': 'mothur_make_group',
#  '727': 'ctb_ob_genProp',
#  '728': 'bedtools_mergebed',
#  '729': 'proteomics_search_protein_prophet_1',
#  '730': 'tab2fasta',
#  '731': 'nanopolish_variants',
#  '732': 'tag_stat2',
#  '733': 'tophat',
#  '734': 'join1',
#  '735': 'mothur_classify_rf',
#  '736': 'deg_annotate',
#  '737': 'rgPicFixMate',
#  '738': 'trim_reads',
#  '739': 'rseqc_infer_experiment',
#  '740': 'DatamashOps',
#  '741': 'fastq_paired_end_interlacer',
#  '742': 'minfi_getbeta',
#  '743': 'graphlan',
#  '744': 'cardinal_data_exporter',
#  '745': 'samtools_bedcov',
#  '746': 'collapse_dataset',
#  '747': 'methtools_destrand',
#  '748': 'qiime_split_libraries_fastq',
#  '749': 'cshl_fasta_nucleotides_changer',
#  '750': 'Fetch Taxonomic Ranks',
#  '751': 'ctb_remSmall',
#  '752': 'trimmomatic',
#  '753': 'gatk_depth_of_coverage',
#  '754': 'extract_element_from_collection',
#  '755': 'gatk2_variant_select',
#  '756': 'minfi_dmr',
#  '757': 'htseq_count',
#  '758': 'hmmer_hmmbuild',
#  '759': 'FileFilter',
#  '760': 'methtools_dmr',
#  '761': 'fastq_paired_end_deinterlacer',
#  '762': 'minfi_qc',
#  '763': 'mothur_get_communitytype',
#  '764': 'PicardInsertSize',
#  '765': 'annotateMyIDs',
#  '766': 'XY_Plot_1',
#  '767': 'eden_vectorizer',
#  '768': 'fastq collapser',
#  '769': 'newick_display',
#  '770': 'pureclip',
#  '771': 'bamFilter',
#  '772': 'clustalw',
#  '773': 'locarna_multiple',
#  '774': 'cat1',
#  '775': 'preproc',
#  '776': 'prokka',
#  '777': 'bamtools',
#  '778': 'picard_AddOrReplaceReadGroups',
#  '779': 'mothur_summary_single',
#  '780': 'kraken-filter',
#  '781': 'correct_barcodes',
#  '782': 'cshl_awk_tool',
#  '783': 'get_flanks1',
#  '784': 'sam_to_bam',
#  '785': 'minfi_dmp',
#  '786': 'umi_tools_extract',
#  '787': 'genbank_to_gff',
#  '788': 'mothur_tree_shared',
#  '789': 'mothur_lefse',
#  '790': 'hicexplorer_hiccorrectmatrix',
#  '791': 'bctools_remove_tail',
#  '792': 'scaffold2fasta',
#  '793': 'filter_bed_on_splice_junctions',
#  '794': 'svm_classifier',
#  '795': 'ssake',
#  '796': 'FileConverter',
#  '797': 'GeneModelMapper',
#  '798': 'deeptools_plot_coverage',
#  '799': 'IDConflictResolver',
#  '800': 'proteomics_moff',
#  '801': 'mlocarna',
#  '802': 'samtools_flagstat',
#  '803': 'table_annovar',
#  '804': 'ucsc-twobittofa',
#  '805': 'trimmer',
#  '806': 'get_feature_info',
#  '807': 'wolf_psort',
#  '808': 'cshl_fastq_quality_filter',
#  '809': 'goenrichment',
#  '810': 'cshl_fastx_quality_statistics',
#  '811': 'vegan_diversity',
#  '812': 'bedtools_coveragebed_counts',
#  '813': 'CONVERTER_gz_to_uncompressed',
#  '814': 'tsne',
#  '815': 'stacks_populations',
#  '816': 'gatk2_haplotype_caller',
#  '817': 'snpSift_geneSets',
#  '818': 'ctb_remIons',
#  '819': 'dexseq_count',
#  '820': 'graphclust_align_cluster',
#  '821': 'structure_to_gspan',
#  '822': 'gene2exon1',
#  '823': 'cshl_cut_tool',
#  '824': 'gmx_nvt',
#  '825': 'gemini_actionable_mutations',
#  '826': 'venn_list',
#  '827': 'subtract_query1',
#  '828': 'bedtools_bamtofastq',
#  '829': 'dexseq',
#  '830': 'kraken',
#  '831': 'goslimmer',
#  '832': 'fasta_merge_files_and_filter_unique_sequences',
#  '833': 'raceid_trajectory',
#  '834': 'rnbeads',
#  '835': 'cuffcompare',
#  '836': 'bwa_mem',
#  '837': 'regex1',
#  '838': 'mycrobiota-krona-mothur',
#  '839': 'picard_ReorderSam',
#  '840': 'column_order_header_sort',
#  '841': 'bam2wig',
#  '842': 'wsdl_hmdb',
#  '843': 'qiime_core_diversity',
#  '844': 'MapAlignerPoseClustering',
#  '845': 'fastq_groomer',
#  '846': 'rcas',
#  '847': 'infernal_cmbuild',
#  '848': 'snpsift_vartype',
#  '849': 'scale_image',
#  '850': 'vegan_rarefaction',
#  '851': 'xcms_merge',
#  '852': 'bgchem_fragment_merger',
#  '853': 'deeptools_plot_correlation',
#  '854': 'coords2clnt.py',
#  '855': 'fasta_filter_by_length',
#  '856': 'export2graphlan',
#  '857': 'blockclust',
#  '858': 'vcftools_isec',
#  '859': 'bcftools_norm',
#  '860': 'uniprot',
#  '861': 'Add_a_column1',
#  '862': 'predict_pipeline',
#  '863': 'vt_normalize',
#  '864': 'multiqc',
#  '865': 'mothur_unique_seqs',
#  '866': 'kallisto_quant',
#  '867': 'gops_concat_1',
#  '868': 'cardinal_filtering',
#  '869': 'GeMoMa_Annotation_Filter',
#  '870': 'cardinal_combine',
#  '871': 'mothur_filter_seqs',
#  '872': 'CONVERTER_interval_to_bed_0',
#  '873': 'term_id_vs_term_name',
#  '874': 'gemini_comp_hets',
#  '875': 'snpSift_filter',
#  '876': 'openms_protein_quantifier',
#  '877': 'mothur_venn',
#  '878': 'plotly_parallel_coordinates_plot',
#  '879': 'ProteinResolver',
#  '880': 'mothur_classify_otu',
#  '881': 'Count1',
#  '882': 'cshl_sort_header',
#  '883': 'peakachu',
#  '884': 'minfi_rset',
#  '885': 'checkFormat',
#  '886': 'FeatureLinkerUnlabeled',
#  '887': 'varscan',
#  '888': 'fasta-stats',
#  '889': 'mycrobiota-correct-replicates',
#  '890': 'je_clip',
#  '891': 'mothur_classify_seqs',
#  '892': 'humann2_genefamilies_genus_level',
#  '893': 'fraggenescan',
#  '894': 'mothur_seq_error',
#  '895': 'viennarna_rnafold',
#  '896': 'bwa_wrapper',
#  '897': 'glimmer_not-knowlegde-based',
#  '898': 'mothur_dist_seqs',
#  '899': 'IDScoreSwitcher',
#  '900': 'scpipe',
#  '901': 'transpose',
#  '902': 'megahit',
#  '903': 'deeptools_plot_fingerprint',
#  '904': 'salmon',
#  '905': 'maldi_quant_peak_detection',
#  '906': 'trinity',
#  '907': 'EMBOSS: water107',
#  '908': 'CONVERTER_gff_to_bed_0',
#  '909': 'raceid_filtnormconf',
#  '910': 'gd_raxml',
#  '911': 'ip_projective_transformation',
#  '912': 'cshl_fastx_nucleotides_distribution',
#  '913': 'deeptools_heatmapper',
#  '914': 'jbrowse',
#  '915': 'gemini_query',
#  '916': 'graphicsmagick_image_convert',
#  '917': 'paralyzer',
#  '918': 'IDPosteriorErrorProbability',
#  '919': 'gatk2_print_reads',
#  '920': 'thermo_raw_file_converter',
#  '921': 'gatk2_depth_of_coverage',
#  '922': 'hicexplorer_hicpca',
#  '923': 'convert_bc_to_binary_RY.py',
#  '924': 'varscan_somatic',
#  '925': 'bedtools_unionbedgraph',
#  '926': 'tp_multijoin_tool',
#  '927': 'cardinal_preprocessing',
#  '928': 'vcfgenotypes',
#  '929': 'EMBOSS: transeq101',
#  '930': 'CONVERTER_fasta_to_tabular',
#  '931': 'mass_spectrometry_imaging_segmentations',
#  '932': 'fastq_combiner',
#  '933': 'msgfplus',
#  '934': 'vcfbedintersect',
#  '935': 'get_read_pipeline',
#  '936': 'gatk_realigner_target_creator',
#  '937': 'bedtools_shufflebed',
#  '938': 't_coffee',
#  '939': 'tmhmm2',
#  '940': 'EMBOSS: shuffleseq87',
#  '941': 'fastqc',
#  '942': 'macs2_predictd',
#  '943': 'fasttree',
#  '944': 'deeptools_bam_compare',
#  '945': 'histogram_rpy',
#  '946': 'megablast_xml_parser',
#  '947': 'gemini_db_info',
#  '948': 'qiime_make_otu_heatmap',
#  '949': 'FROGS_clustering',
#  '950': 'bed_to_bigBed',
#  '951': 'deseq2_single',
#  '952': 'stacks_genotypes',
#  '953': 'vcfallelicprimitives',
#  '954': 'sam_bw_filter',
#  '955': 'rseqc_read_distribution',
#  '956': 'mothur_align_seqs',
#  '957': 'sklearn_numeric_clustering',
#  '958': 'bigwig_to_bedgraph',
#  '959': 'gbk_to_orf',
#  '960': 'xpath',
#  '961': 'glob_report',
#  '962': '__ZIP_COLLECTION__',
#  '963': 'melt',
#  '964': 'smf_utils_extract-boxed-sequences',
#  '965': 'snpEff',
#  '966': 'cshl_fastx_artifacts_filter',
#  '967': 'Remove beginning1',
#  '968': 'vcfcombine',
#  '969': 'macs2_callpeak',
#  '970': 'mothur_homova',
#  '971': 'deeptools_compute_matrix'}

# %%
def verify_model(model, tool_sequence, labels, dictionary, reverse_dictionary, compatible_tools, topk=20, max_seq_len=25):
    tl_seq = tool_sequence.split(",")
    last_tool_name = reverse_dictionary[str(tl_seq[-1])]
    last_compatible_tools = compatible_tools[last_tool_name]
    sample = np.zeros(max_seq_len)
    for idx, tool_id in enumerate(tl_seq):
        sample[idx] = int(tool_id)
    sample_reshaped = np.reshape(sample, (1, max_seq_len))
    
    tool_sequence_names = [reverse_dictionary[str(tool_pos)] for tool_pos in tool_sequence.split(",")]
    print("Tool seq: %s" % ",".join(tool_sequence_names))
    # predict next tools for a test path
    prediction = model.predict(sample_reshaped, verbose=0)
    prediction = np.reshape(prediction, (prediction.shape[1],))
    prediction_pos = np.argsort(prediction, axis=-1)

    # get topk prediction
    topk_prediction_pos = prediction_pos[-topk:]
    topk_prediction_val = [np.round(prediction[pos] * 100, 2) for pos in topk_prediction_pos]

    # read tool names using reverse dictionary
    pred_tool_ids = [reverse_dictionary[str(tool_pos)] for tool_pos in topk_prediction_pos]
    actual_next_tool_ids = list(set(pred_tool_ids).intersection(set(last_compatible_tools.split(","))))      

    print()
    pred_tool_ids_sorted = dict()
    for (tool_pos, tool_pred_val) in zip(topk_prediction_pos, topk_prediction_val):
        tool_name = reverse_dictionary[str(tool_pos)]
        if tool_name in actual_next_tool_ids:
            pred_tool_ids_sorted[tool_name] = tool_pred_val
    pred_tool_ids_sorted = dict(sorted(pred_tool_ids_sorted.items(), key=lambda kv: kv[1], reverse=True))
    
    cls_wt = dict()
    usg_wt = dict()
    inv_wt = dict()
    ids_tools = dict()
    keys = list(pred_tool_ids_sorted.keys())
    for k in keys:
        try:
            cls_wt[k] = np.round(class_weights[str(data_dict[k])], 2)
            usg_wt[k] = np.round(usage_weights[k], 2)
            inv_wt[k] = np.round(inverted_weights[str(data_dict[k])], 2)
        except:
            continue
    print("Predicted tools: \n")
    print(pred_tool_ids_sorted)
    print()
    print("Class weights: \n")
    cls_wt = dict(sorted(cls_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(cls_wt)
    print()
    print("Usage weights: \n")
    usg_wt = dict(sorted(usg_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(usg_wt)
    print()
    total_usage_wt = np.mean(list(usg_wt.values()))
    print("Mean usage wt: %0.4f" % (total_usage_wt))
    print()
    print("Inverted weights: \n")
    inv_wt = dict(sorted(inv_wt.items(), key=lambda kv: kv[1], reverse=True))
    print(inv_wt)
    for key in pred_tool_ids_sorted:
        ids_tools[key] = dictionary[key]
    print()
    print("Tool ids")
    print(ids_tools)
    print("======================================")
    return cls_wt, usg_wt, inv_wt, pred_tool_ids_sorted

topk = 10
tool_seq = "836,446" # ,875,223,17
class_wt, usage_wt, inverse_wt, pred_tools = verify_model(model, tool_seq, "", dictionary, reverse_dictionary, compatibile_tools, topk)
# Out:
# Tool seq: bwa_mem,hicexplorer_hicbuildmatrix
#
# Predicted tools:
#
# {'hicexplorer_hiccorrectmatrix': 22.4, 'tp_sed_tool': 8.01, 'multiqc': 6.2, 'hicexplorer_hicplottads': 2.8, 'hicexplorer_hicmergematrixbins': 2.28, 'hicexplorer_hicplotmatrix': 2.28, 'hicexplorer_hicfindtads': 2.02, 'hicexplorer_hicpca': 1.46}
#
# Class weights:
#
# {'multiqc': 6.07, 'hicexplorer_hicplotmatrix': 4.84, 'hicexplorer_hiccorrectmatrix': 4.74, 'hicexplorer_hicplottads': 4.7, 'tp_sed_tool': 3.91, 'hicexplorer_hicfindtads': 3.74, 'hicexplorer_hicmergematrixbins': 3.62, 'hicexplorer_hicpca': 2.59}
#
# Usage weights:
#
# {'multiqc': 434.46, 'hicexplorer_hicplotmatrix': 126.04, 'hicexplorer_hiccorrectmatrix': 114.36, 'hicexplorer_hicplottads': 109.85, 'tp_sed_tool': 49.8, 'hicexplorer_hicfindtads': 42.1, 'hicexplorer_hicmergematrixbins': 37.16, 'hicexplorer_hicpca': 13.36}
#
# Mean usage wt: 115.8913
#
# Inverted weights:
#
# {'hicexplorer_hicmergematrixbins': 21916.25, 'hicexplorer_hicpca': 21916.25, 'hicexplorer_hicfindtads': 17533.0, 'hicexplorer_hiccorrectmatrix': 9740.56, 'hicexplorer_hicplotmatrix': 6261.79, 'hicexplorer_hicplottads': 5479.06, 'tp_sed_tool': 2578.38, 'multiqc': 819.3}
#
# Tool ids
# {'hicexplorer_hiccorrectmatrix': 790, 'tp_sed_tool': 82, 'multiqc': 864, 'hicexplorer_hicplottads': 623, 'hicexplorer_hicmergematrixbins': 448, 'hicexplorer_hicplotmatrix': 563, 'hicexplorer_hicfindtads': 413, 'hicexplorer_hicpca': 922}
# ======================================

# %%
list_cls_wt = list()
list_usage_wt = list()
list_pred_wt = list()
list_inv_wt = list()
division_pt = int(len(pred_tools) / 2)

for tool in pred_tools:
    list_pred_wt.append(pred_tools[tool])
    #try:
    list_inv_wt.append(inverse_wt[tool])
    list_usage_wt.append(usage_wt[tool])
    #except:
    #list_inv_wt.append(1)

def plot_scatter(y_val, title, xlabel, ylabel):
    x_val = range(1, len(y_val) + 1)
    plt.figure(figsize=(8, 8))
    plt.plot(x_val[:division_pt], y_val[:division_pt], 'ro')
    plt.plot(x_val[division_pt:], y_val[division_pt:], 'b^')
    plt.xlabel(xlabel, size=size_label)
    plt.ylabel(ylabel, size=size_label)
    plt.legend([("First top-%s" % str(division_pt)), ("Next top-%s" % str(division_pt))])
    plt.title(title, size=size_title)
    plt.grid(True)
    plt.show()

plot_scatter(list_usage_wt, "Usage weights for tools", "Number of tools", "Class weights")
#plot_scatter(ave_prediction_weights, ave_usage_weights, "Prediction vs usage weights", "Prediction scores", "Usage weights")
#plot_scatter(ave_prediction_weights, ave_inverted_weights, "Prediction vs inverted weights", "Prediction scores", "Inverted weights")
